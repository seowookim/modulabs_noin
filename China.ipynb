# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from gensim.models import word2vec

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# c:\Users\seowoo kim\Desktop\노나없

# %%
# Japan first_read japan data
data_j = pd.read_csv("./intern_review_china_only_sentences.csv")
data_j.head()
# Out:
#                                   SeparatedSentences
# 0  Why even such a beautiful and successful woman...
# 1  It all depends on De Niro.The first half looke...
# 2  For me, the world will be a better place if I ...
# 3  When Hathaway intervened in Streep's strongwom...
# 4  It's been a long time since I've seen Princess...

# %% [markdown]
# # Preprocessing Strategy
#
# 1. Expand contractions : pycontractions
# 2. lowercase
# 3. change numbers to words : inflect
# 4. Remove Punctuations : '!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~'
# 5. Remove remained emoji, japanese, chinese, korean words
# 6. PoS_tagging: from nltk import pos_tag
# 7. If needed, remove PRP, TO, DT, etc.
# 8. Stemming: PorterStemmer
# 9. Find out average sentence length
# 10. Wordcloud

# %%
# Pycontractions doesn't work due to dependency issue. I just modulized it by myself.

from contractions import expand_contractions

contracted_list = []
Sentences = data_j['SeparatedSentences'].copy()

for sentence in Sentences:
    expanded_sentence = expand_contractions(sentence)
    contracted_list.append(expanded_sentence)

# %%
contracted_list[:5]
# Out:
# ['Why even such a beautiful and successful woman in American movies has to accept such an ordinary and cheating husband?',
#  "It all depends on De Niro.The first half looked good, the second half values swallowed conservative and retreated.De Niro's people are a little too perfect.",
#  'For me, the world will be a better place if I can make one or two such warm skits every year that look good and release tears.。。。。',
#  "When Hathaway intervened in Streep's strongwoman life, now De Niro anti-invasion Hathaway life……actually a little ambitious, trying to discuss career women and the older generation, but floating a bit.I like Hathaway a lot, but every little expression of her has a sense of rehearsal and release, especially compared to De Niro's relaxed share.And De Niro is really handsome...…………",
#  'it is been a long time since i have seen Princess Anne, but the movie feels numb, especially after "Fashion Witch" has set the bar so high for professional women and young people, it is also too warm and mediocre.。。']

# %%
# Transform all sentences into lower case! easy!

contracted_list = [text.lower() for text in contracted_list]

# %%
contracted_list[:5]
# Out:
# ['why even such a beautiful and successful woman in american movies has to accept such an ordinary and cheating husband?',
#  "it all depends on de niro.the first half looked good, the second half values swallowed conservative and retreated.de niro's people are a little too perfect.",
#  'for me, the world will be a better place if i can make one or two such warm skits every year that look good and release tears.。。。。',
#  "when hathaway intervened in streep's strongwoman life, now de niro anti-invasion hathaway life……actually a little ambitious, trying to discuss career women and the older generation, but floating a bit.i like hathaway a lot, but every little expression of her has a sense of rehearsal and release, especially compared to de niro's relaxed share.and de niro is really handsome...…………",
#  'it is been a long time since i have seen princess anne, but the movie feels numb, especially after "fashion witch" has set the bar so high for professional women and young people, it is also too warm and mediocre.。。']

# %%
# Change numbers into words
import inflect
p = inflect.engine()

def convert_number(text):
    def replace_number(match):
        number = match.group()
        return p.number_to_words(number)
    
    converted_text = re.sub(r'\d+', replace_number, text)
    return converted_text

inflected_list = []
inflected_list = [convert_number(text) for text in contracted_list]

# %%
# Remove punctuations
rm_punctionations = inflected_list.copy()

def rm_punct(text):
    cleaned_text = re.sub(r'[!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]', ' ', text)
    return cleaned_text

rm_punctionations = [rm_punct(text) for text in rm_punctionations]

# %%
rm_punctionations
# Out:
# ['why even such a beautiful and successful woman in american movies has to accept such an ordinary and cheating husband ',
#  'it all depends on de niro the first half looked good  the second half values swallowed conservative and retreated de niro s people are a little too perfect ',
#  'for me  the world will be a better place if i can make one or two such warm skits every year that look good and release tears 。。。。',
#  'when hathaway intervened in streep s strongwoman life  now de niro anti invasion hathaway life……actually a little ambitious  trying to discuss career women and the older generation  but floating a bit i like hathaway a lot  but every little expression of her has a sense of rehearsal and release  especially compared to de niro s relaxed share and de niro is really handsome   …………',
#  'it is been a long time since i have seen princess anne  but the movie feels numb  especially after  fashion witch  has set the bar so high for professional women and young people  it is also too warm and mediocre 。。',
#  'the bad thing about acting with the bones of the play is that it is not good enough  and the play is eaten up by the other party ',
#  'anne hathaway looks great on you ',
#  'freshly held laughter details  tapping words  massage will be hard  thunder snoring…with a lifetime of experience in the old ginger  no matter how high the academic qualifications also need to get job recognition  to find the rare modern gentleman manners… nancy meyers can always take a good picture in the vulgar subject matter  favorite chick flick director ',
#  ' hopefully it is just a momentary misjudgment  not love   this joy is what she deserves  slow down and enjoy life in tai chi ',
#  'the encounter between the angel of high emotional intelligence and the sweetheart of brooklyn genius is all rubbed into the japanese style warm serenade from homage  back to back to soundtracks  it is fought off the gloom of my thirty year old crisis jules is the future  but ben is the one who owns the world that is the most beautiful thing in my life ',
#  'from hathaway s point of view  who does not want to be able to have an old man who has experienced hardships in life  the content of the guidance is actually shown at the beginning and end  taijiquan   slow  slow  slow ',
#  'good observation and not humble  warm and courteous  advice and never cross the line  principled and interesting  rich experience and never show off  do things properly  ben is nearly seventy years old as a model of my generation this movie also saw de niro s old age calm and intelligent side  it is really all powerful play god seven。six',
#  'a year and a half of e commerce women can run businesses and men can be domestic men new people in the workplace are no longer synonymous with their early twentys  and they can still work as interns at the age of seventy it is a time when gender and age are downplayed as long as you have a healthy body and a positive mind  anything is possible a very warm film annie s clothes look great ',
#  'de niro was so warm that he felt his tenderness and nobility across the screen ',
#  'it is cold  drink chicken soup  and the driver s fan disappears ',
#  'more standard chicken flick  three views  humor  famous characters  the most important thing is to have it all ',
#  'in any case  the development of chuck flick from love to not sacrificing career for family is a huge social progress ',
#  'robert de niro is like grandpa in flying house ',
#  'the novelty of the film lies in balance and balance seventy year olds face up to their own social status quo  do not rely on the old to sell the old  do not emphasize the past  but silently rely on their own experience to help each young person continue to achieve their own value thirty year olds gradually learn to balance everything in life  not to run away from problems in marriage  and not to deliberately curb their inner desires both things are difficult but never give up the enthusiasm to learn and the courage to start ',
#  'old school is not just retro  not old fashioned  not hip hop  it is just a part of people who insist on good things  traditional habits and ideas ',
#  'watched the episode on a plane from new york to san francisco  featuring brooklyn bridge and golden gate bridge ',
#  'basically relying on de niro to support the field  hathaway won the award  in recent years there is another impressive role it does not seem to be ',
#  'at most  it is the version of the post marriage magnification light truck  white lilies of the united states of course  it is a lot of fun or something ',
#  'do not learn from robert dinillo  stand at the entrance of the alley and wait for me ',
#  'a cheesy yet comforting enjoyment。 robert deniro just played a perfect silver daddy in every women and men s dream  no kidding。  i put women before men hope you all see what i suggest here',
#  'nancy meyers has not made a movie in years  and she is been focusing on old people s social relationships for decades  and her up to date start up female entrepreneurial setting is much more interesting than before ',
#  'a warm hearted comedy  the modern costume of anne can not be more beautiful  her performance with de niro is the biggest attraction the story is less fashionable than the queen in prada ',
#  'watching this movie  i feel like i have the most say  i am doing the same thing as a woman  but i am ten zero times smaller than her we have super similarities  but we have more to learn from her there were countless scenes in between that moved me to tears i think i am going to watch it again ',
#  'it is the best tribute to this movie ',
#  'i woke up at five a m  and watched this movie i have always wanted to see oh my god  the beginning of a great day ',
#  'watching this  women in the workplace  movie is like flipping through women s fashion magazines  flipping through pictures to teach you how to dress  read columns and drink feminist chicken soup life is too easy for them  playing taijiquan can be balanced but the casting is still good stay classic。',
#  'too boring  a director shooting a love vacation shooting what workplace story  the whole story is trying to make a fuss in a flat life  so mediocre ',
#  'you look great in it ',
#  'go gentleman like an old man  go passionate like a goddess ',
#  'one hundred and thirty stars at the end ',
#  'the urban version of the elderly and young girls  no matter what age group  people always need to please each other in order to run into each other ',
#  'simple and comfortable  lacking in depth  but making up for it in warmth robert was simply handsome  hathaway was so pretty  her expression was so tight that the little girl who had been an assistant to the demon headed woman became a strongwoman p ',
#  's  this movie is a textbook level dressing tutorial  hathaway s light mature girl ol style  robert s retro suit style  every set is pleasing to the eye ',
#  'so the happy marriage of a strong woman is unsolvable…   especially with the water sign scumman ',
#  'it is a good way to get rid of cheating husbands  but unfortunately not many men have this kind of awareness ',
#  'i think it should be shown on christmas day buy a warm ginger coffee i have seen all of robert de niro s grandpa movies it is brain powder i love the warm and bright images of new york comedy movies   unburdened circumstances  ',
#  'warm  inspiring and humorous with a high degree of completion i also like anna s dress in the movie  exemplary of working women in the eastern united states',
#  'clothing and interior design guidelines the first half is more interesting  and after the relationship is harmonious  the stereotype gradually appears  especially the addition of the husband character  so that the entire film almost degenerates into a standardized bad film ',
#  'i thought the intern meant robert   anne hathaway is too weak to hold such a strongwoman ',
#  'a bowl full of chicken soup  i thought robert de niro and hathaway were going to roll the sheets 。。。。',
#  'the textbook chicken film seriously  hathaway  playing a feminist figure  the whole place is being taught by a daddy  is that really okay ',
#  'three and a half stars  i watched this movie for robert de niro this kind of american feminine inspirational film is not really my thing …',
#  'very warm fairy tale wind two hours does not feel long the background music has always been in a similar tone  a little monotonous princess ann plays the boss is also an assistant feeling  drunk women s rights are a bit superficial the godfather is cute ',
#  'i have had a lot of confusing moments over the years  and a few times i naturally thought of my dad  and then i found out that he just wanted me to go back to my hometown and work as a civil servant movies are movies  reality is reality this kind of  feminine  color allows women to have sufficient lewd space of the subject matter  from the beginning of bj has not gone out of fashion indeed ',
#  'even if you find the ultimate handsome guy  do not you end up on your own ！',
#  'politically correct  interesting material selection  strong cas but the whole movie is full of embarrassment and helplessness apart from the weak tension in the mainline drama  the old man s boring personality  the loose narrative  the protagonist s lack of chemistry  and the fact that holm is blind  the office they live in is too much like a model house hotel it is no use looking at it annie started the fashion show again  but the clothes did not match too well ',
#  'it is a little too good  but i am done with this chicken soup ',
#  'over the years  the dress has changed from msixty five to a high end suit  but the walking posture has not changed at all ',
#  'drink chicken soup and i will identify robert de niro and anne hathaway brands ',
#  'easy and effortless comedy  de niro grandfather super cute  hathaway is also beautiful glittering  after watching the whole person feel very happy ',
#  'ahahahahahahahahaha  ben told jules to pay attention to the  inner peace  bridge when playing taiji is a tribute to the kung fu panda ',
#  'i wanted four stars ',
#  'it was a standard hollywood movie  but it ended with hathaway and scumboy taking a point off ',
#  'late life in corleone 😂',
#  'the content seems to be in line with the trend  but it is actually one of those movies that is basically out of touch with the times  and the screenwriter s total failure to create a conflict  it is just a hot pot of sugar water ',
#  'it is happiness to cherish what you have now  because what you have now does not know when you will lose it do what you like  stick to your original self  and treat life with a tolerant heart ',
#  'walking on the edge of a strange feeling ',
#  'the problem is both at de niro s age in many scenes with the company s young employees  he showed obvious fatigue and perfunctory what is more  his performance style is not suitable for the appearance of external charm to show comedy touch the script was imposing a charismatic aura of goodwill on him  making him quickly the focus of the company s attention  but the audience did not really feel why it should be ',
#  'blinking acting  high end  atmospheric why travel to create some ambiguous suspense  afraid of embarrassment i am nervous it is good to feel the progress of society ',
#  'anne hathaway  from assistant to boss  is still wearing that navy sweater ',
#  'rather than being more mediocre than expected  i am completely off the mark 。。 you know what ',
#  'looking at de niro  i really think that when people get old  the whole character will change into a round ',
#  'life is also like playing tai chi  balancing in one move  between breathing a warm little piece of life  suitable for christmas eve to heal the mood favorite is ben and austin in overtime night conversation  warm lights  ben talked about this is forty years ago used to work in the place  brick by tile and the paulownia trees in front of the window are so familiar  the tacit understanding between the two is quietly growing unfortunately  the film is too formal  and gentlemen must bring handkerchiefs when they go out ',
#  'anne hathaway robert de niro anne hathaway love grows up four and a half stars first he has been translating the title of the film inexplicable  hong kong name won again old and strong old man with princess noble couple  give you a bowl of super positive energy heart chicken soup  but there is a funny  zhong want your master to do the job is to steal  but only to not hurt the old mother s heart  kind movies have a good return 。。',
#  'robert de niro s eq is so high that he can be used as a work textbook  how not to warn the boss  pay attention to the boss s real needs  handle relationships with colleagues  and do his job diligently  etc ',
#  '  。。',
#  'almost four stars ',
#  'people who admire this  old habit  have achieved something in the secondary industry in this style the play is written too casually  the shelves are well built  and the meat inside is not enough porcelain it is good to use the old service industry s strict and self disciplined executives and the new service industry to break the dogma of female strongmen as the starting point for storytelling ',
#  'grandpa is so cute  he is really kind and does not know how to refuse others  leaving steps for others all the time  and he is good at discovering the joy of life ',
#  'great acting  general story ',
#  'the closest non religious relationship you can think of is to be buried with you after death the visual hardware is beautiful  and the story is much better than i thought  thankfully not on the cheesy mother daughter relationship  sexism and retro era feelings  one points out the bruises that have not been scratched in the era  one is involved in nostalgia sighs ',
#  'new york is beautiful ',
#  'the old intern s idea for a standard chick movie adds warmth to the theme of female inspiration ben completely retains the spirit and merits of traditional industries and avoids the cost of moving from secondary to tertiary industries it was nice and healing  and when ben told his and his wife s story not long enough to fall completely once again  i have to lament that all stories are romantic as long as they are middle class ',
#  'the two stars are well chosen  thinking of another version of queen in prada ',
#  'much better looking than i thought  i thought it was another queen in prada  who knows completely upside down anne hathaway s every outfit is really too good looking ！！',
#  'the airplane movie  chicken soup content is as previewed  so most of my focus is on various interior design trance can also see hathaway sitting at the door of aunt may s office as a shadow of a small assistant  and this age de niro has said nothing but look at the expression can become a life mentor ',
#  'unbreakable truth  every well organized hollywood assembly line piece  regardless of its quality  is an example of cultural analysis ',
#  'young women are attracted and controlled by conservative old white men who turn away from contemporary men and rely on their help in their careers and families affirmatism always ends in a positive image and ends in a negative one ',
#  'forty years after  the kramers   hollywood s right wing stance and hypocritical morality have never changed ',
#  'packed as a grown up fairy tale mainly to see the hostess change a set of beautiful clothes  drink the director poured chicken soup and the film itself threw out the topic of work and family issues  there is a workplace entrepreneurship continuation problem  try to ask which one is taken seriously ',
#  'in the end  nothing was resolved at all a thin film the most regrettable thing is to find such a fresh old and young partner  but not able to dig up a deeper spark of interaction ',
#  'ever since i found out that director nancy meyers is also hollywood s top interior designer  i have been staring hard at both the protagonist s house and the to die for office the american style and the natural light of the windows are too comfortable to use    that movie  de niro is pretty cute ',
#  'hathaway s not doing very well ',
#  'taipei is thin  overall it is just a fashion show  the design can not stand the taste  the male character design is too weak ',
#  'robert de niro is my super loved actor  and annie s youth in front of him just compounded the needs of the plot  and the success of the casting is self evident in addition  the workplace in europe and the united states is very natural no matter how to shoot  such as the office to hang a bell  such as the office masseuse and so on on the contrary  when chinese films appear in the workplace  there is a mysterious temperament of  you are fucking kidding me ',
#  ' i do not know why in short  ron is worth four stars ',
#  'chicken soup movies under the guise of feminism  about the career and company should be the main line  independent female and screenwriter are not very perfunctory  female image is that i am busy and obsessive at first  to find a ceo is too large to control  and finally the screenwriter himself forgot this ballast  only to become a family vs career tangled ',
#  'pseudo feminist movie masterpiece  just find a more mature male mentor ',
#  'overtime night talking about ben back to work in the original place  arranged by the space to the big paulownia  is very touching as a new start up office scene  only highlights the unattended desk  and the conference room used several times  there is no good sense of scene the bridge section is very old  especially the four men stealing a computer section  which is a compromise to the contemporary  comedy  robert de niro performed well  but the characters were too warm ',
#  'i have been complaining all day about how much i need this bowl of positive energy chicken soup ',
#  'seventy year old veteran handsome man helps taobao young women shop manager start a warm inspirational story  american internet entrepreneurship ruins your life  cultivating body and mind still rely on chinese qigong ',
#  'taking intern s salary to work twelve hours a day for the boss  but also to help the boss take the child to drive  is this not a disguised squeeze on cheap labor ',
#  'bored to explode ',
#  'hathaway s husband cheated as the biggest tension in the movie  but he resolved it by  husband confesses and realizes   and the real reason why hathaway originally wanted to hire external management  vc pressure is invisible forgotten ',
#  'i thought the end point was how to integrate senior interns into the modern internet workplace ',
#  'as a result  it was how the female boss balanced her career and family  and finally her husband s repentance was unnecessary ',
#  ' i am sorry  but i am talking to you today as an elder i am an intern  but i have seen too much i need to tell you a little bit about my life experience  ',
#  'it was a warm friendship  and there was a bullet curtain cut off   the god who goes down the mountain guides the people who go up the mountain  ',
#  'robert de niro s charm is not diminished it is really cool compared to a bunch of little brats in the movie he said he had a forty two year old marriage  eighteen year old and his wife in love  my mind automatically gave birth to the godfather he stood behind the curtain shooting scene  eighteen year old you met his wife as a gangster…   hahahahahahahahahaha',
#  'ten years later  the little assistant grew up as a strong woman  and his eyes were not broadened  and the first half of the movie was very good  but the whole thing was too light  and the style of deleting emails was very abrupt ',
#  'in the middle of the rules  miao da good old grandfather  fragrant and standard  the appearance of exquisite high cold inner fragile crisis  strong female strongman  the end of the strong points this piece of children s right pants off look  scum man confesses to be forgiven bridge let loose know that must be sprayed into a dog what does that say  wildfires burn  spring breeze again when a turbulent heart sprang up the first time you pinch it  he will grow a second time  a third time  until it becomes hulunbuir prairie  very cocky ',
#  'bright colors  eternal preaching  the elderly minutes to teach you this little woman to be human look and do not look the same ',
#  'commercial but cute story。 the only thing that is upsetting is why the word  feminine rights  appears on the film s usual label ',
#  'the plot is gentle  but the old drama bone acting is really comfortable the greatest secret to not being afraid of old age is to allow time to give yourself valuable wealth  not just wrinkles and gray hair it is also fortunate to have someone like that talk to you when you are lost ',
#  'grandpa de niro cooks a bowl of soul soup for you to drink',
#  'when it is time to eat  just look around and spend a relaxing night without burning your brain  and of course  do not care if you keep looking at the other half the next day ',
#  'it was a great movie to watch on the plane hathaway s fashion show  de niro s gentlemanly demeanor is really charming  ',
#  'i want to see the story of an old intern  okay i do not want to see the family and love stories of young and beautiful entrepreneurial executives if you really want to tell such a story  please change  intern  to  struggling jules  ',
#  'you are never wrong to do the right thing ',
#  'i have seen it twice in a short time whenever attention ran into difficulties  i thought of annie  who used to be a witch wearing prada  and now she is the intern like a distant idol  as she gets better  you walk better  glad ',
#  'it is boring ',
#  'the internship  five the most interesting part of the whole movie is the blue frog ',
#  'the queen of prada ii ',
#  'the subject matter is really brilliant  point to point  the ending is a little less flavor',
#  'gentlemanly workplace light comedy  young and old posts caused by misplaced laughter relaxed chicken movies  pleasant adult fairy tales ten years later  hathaway went from being prada s little assistant to the queen  and de niro was becoming more and more like woody allen ',
#  'i saw the beginning on the plane    have the opportunity to continue watching ',
#  'nancy meyers  script and directing made the film very fluid from the beginning  the story moves forward at a very comfortable and cheerful pace  which is a bit of a  silk like soft  feeling  which most chinese comedies or romantic films cannot do the two main characters are good  especially hathaway looks beautiful and fashionable the overall standard of the film is rather average  lacking a clear theme  and the second half of the film has collapsed a lot  far inferior to  the devil wears prada  ',
#  'to see de niro and anne come  the process looks comfortable the plot is general  why not strengthen the old point  whether from the comedy play or the sublimation of the theme  there is a lot of room ',
#  'the whole world is pink film said that women s rights are funny  it is the general chicken flick ah  but de niro is really too cute  ',
#  'the first half of the plot is very interesting  and the discussion about the definition of men is also very good  which is a little too flattering to women  and it is slightly distorted and unprincipled around the female protagonist ',
#  'although it entered too slowly for commercial films  the emotional agitation of the latter half was very effective due to the fullness of the characters effective  present day feminist values 嗯，just stop blaming yourself for someone else s fault。',
#  'i cannot imagine the young man in taxi driver getting old i did not expect to find an answer in this movie that i have been confused about for a long time ',
#  'plain as water ',
#  'the budget must have gone to the end of the movie ',
#  'parents and the ceo of the recruitment did not even have a shadow ',
#  'however  it is not a story of interesting events between a post eightys boss and a post fortys intern',
#  'grandpa is really perfect ',
#  'a medium sized piece of female chicken yes  chicken fillets are now the world of women s girder this movie raises the standard of warm men to old age at once it is not my uncle s turn  it is my uncle s turn …de niro s acting is really natural  even after the shadow hathaway is seconds   eyes ',
#  'de niro s appearance in this film is a hollywood tragedy it was a good movie star who played taxi driver  good fellas  and it was also heartbreaking to squeeze his eyebrows in such a spat film hollywood reporter wrote an article that also indirectly questioned de niro s personal wealth deficit to the extent that he needed to play bad grandpa  the intern  which is not a movie ',
#  'why is de niro acting so tacky i hate anne hathaway ',
#  'she is a princess diary ',
#  'de niro died handsome  this is called the gentleman  this is called the elegant man the plot does not talk  especially at the end  let hathaway dump the cheating old recognized de niro as godfather ',
#  'the subconscious mind of a traditional patriarchal audience will never allow a successful and powerful woman to end well on screen  and the audience will only want to expel her in the name of patriarchy or sanction her  bankruptcy  failure  infidelity  etc ',
#  '  but postmodern patriarchy hides itself in a more hidden way  they pretend to give a strongwoman a good ending  but only if she is gazed at by a male character who is in control of the whole situation—the  ben   a symbol of patriarchal authority and status when the super powerful woman played by seaway in the movie shows a fragile side in front of ben  the audience who identify themselves as ben has an orgasm in their skull  and at the same time emits a strong stench…',
#  'neymar i also want to have this kind of forgetful friendship in the cause has been moist and silent to show me the way ',
#  'i planted a sleeping gown ',
#  'in general  anne hathaway was beaten back to her original form ',
#  'it is great to be an adult gentleman like de niro anne hathaway  is not she flat chested ！！',
#  'brooklyn is too clean    the second half is all about catching horses ',
#  'an old man  intelligent  gracious  not controlling  and even in love ',
#  'watched the taxi driver on monday  watched this on friday  and within a week he was forty years older but de niro is still handsome smart comedy has a good rhythm  it is very delicate and cute i really appreciate de niro s performance the director is still very skilled ',
#  'i think this movie is weird   i always thought anne hathaway was going to roll the sheets with that seventy year old uncle i have been wondering why they are not getting out of here ',
#  'love the interior design  whether it is the living room kitchen or the office is particularly good  hollywood directors are the best interior design but i do not like the plot  pseudo feminine ben is very attractive ',
#  'on the position of taijiquan in the heart of the american empire',
#  'plain chicken soup ',
#  'lei ren is the heroine of the paragraph about how good men used to be  how men nowadays do not grow big speech i cannot believe this kind of silly forked talk would come out of anne hathaway s mouth once upon a time there was jack nicholson and now there is ezra miller in addition  there are many men who are racists and sexists in the past  so why glorify men who are likely to be the same as gay men who hate and discriminate against their wives as exercise yes  just because they fit more gender stereotypes ',
#  'the thought of such a lovely old man luo going to play the dirty old man in the dirty grandfather was all over the place ',
#  'the bed scene at the end was really embarrassing and almost brought the plot to a bad end there is absolutely no need to create this embarrassing illusion the whole article is still a reflection of the work place  and it is worth seeing ',
#  'i do not know if it is because of anne s relationship  i always think of the queen wearing prada    з」  year old daughter in law staying up as a mother in law ',
#  'it is hard to be a strong woman  but why not be a strong woman ',
#  'if it were me who could not accept cheating husbands  there would be no sand in my eyes ',
#  'fairy tales do not count  it is brainwashing at all  and the united states really wants to send those retirees back to work  and this kind of trick is used everyone in there was pretending to be wearing a thick mask of pig skin but the masks are so beautifully carved that it is hard to notice the grease and abnormalities behind them for a moment ',
#  'the genre determines that it must be avoided on the lighter side  is to tell you that life if not complete and noble and sub complete appearance but at least one thing is true  there are many things that cannot be exchanged ',
#  'this is not a sixty year old senior intern  this is clearly a gentleman vice president with forty years of business experience ',
#  'what is this  adult disney ',
#  'it is unreal ',
#  'annie s clothes are all very pretty ',
#  'grandpa is very cute values are shit ',
#  'basically  you can think of robert de niro as the director himself  she wants to prove that the old man is doing something  you play with your special effects  our old experience is still classic renee russell is old too  and i grew up watching her movies 。',
#  'experience is a curriculum vitae that never goes out of fashion ',
#  'boring time  ending with one star less ',
#  'nine years later  anne is still beautiful the male protagonist is really mary sue like people set ah  people see love  flowers bloom  first step to capture the hearts of all the supporting actors  including the hearts of competitors  and then capture the hearts of boss  even boss daughter…omg  is not that the boss fell in love with me ',
#  'dig in the heart ',
#  'dig in the shit ',
#  'de niro is very warm  too perfect  i ed niro  anne hathaway by comparison is so miserable 。。',
#  'gentlemen are charming all the time ',
#  'i have been looking at all kinds of clothes with ww s last outfit ',
#  'robert downey jr  s dad is older and more handsome than he really is',
#  'inexplicable script did a protagonist s out of focus  the trainee suddenly turned into a psychiatrist  although the two main characters are very realistic and cute  but i still do not understand why i should watch a movie where they finally practice yoga together ',
#  'why does the hostess feel that no one is buried together after the divorce  she is tong liya ',
#  'her own father will not let her bury back to her mother s house ',
#  'grandpa as an intern is very new  he actually gave the female boss a lot of spiritual guidance and courage  life experience is his treasure but in the end  the female boss forgives the cheating husband  which is not very comfortable in the heart ',
#  'love of the shopkeeper ',
#  'this is surprisingly heartwarming and fun。 inspired。',
#  'two thousand and sixteen。three。fifteen nine hundred and forty six just ready to travel before the release of the movie has no time to go to the cinema to see  there is no work recently  thinking that watching a called intern may be helpful very comfortable light comedy with no absurd plot  only solid narratives and normal characters not much to look forward to  but a lot to gain ',
#  'another way of returning is to teach young people how to work and live as a gentleman  but also to be taught by young people how to adapt to modern society  but what do you think is wrong give me a nice old vice president after retirement to advise me on my job at the price of an intern and give me a personal babysitter ',
#  'warm movies such as  love at first sight    when harry met sally    go and leave    danny collins    a little faith  i gave three stars  three stars together with  road movies   feel that these two types of movies are suitable for leisure and relaxation so i have rated so many movies that i have concluded that my own rating of four stars or more is that there has to be some depth ',
#  'forgotten new year s friendship is really in addition to family  love outside the most touching friendship  the standard of women to chicken soup  full of warm feelings uncle de niro s people deeply interpreted what is a gentleman s character  with connotations and cultivation and grace  anne successfully evolved from a work girl to wear prada miranda  family business is difficult the director s filming style is very much to my appetite  idealized story even if i see it ten thousand times again  ah ',
#  'this expounds his old profession when the most emotional   window position  forty years to do the same job…do what is right because it is never wrong ',
#  'is there a lack of comedy in my life everything in my country is missing the main theme ',
#  'two hours of screenwriting is not enough time to see  even the final capture of adultery and divorce have saved the dog blood ',
#  'grandpa s idea would be perfect ',
#  'although the plot is not particularly old fashioned  but the whole movie gives a sense of   good old fashioned ah although i cannot say the follow up plot to come  but after watching it  i will think  this kind of drama is indeed this kind of plot trend and line matching ah ',
#  'so whether it can be defined as college entrance examination composition  intermediate level composition is different  but still can recognize at a glance that this is a college entrance examination composition  too template ',
#  'it is a film that promotes equality between men and women  the quality is actually good  the early stage can give a seven or even eight points but forgiveness at the end is too easy ',
#  ' maybe i am the kind of woman who compromises right away  but i still cannot accept it — especially in this kind of film that promotes equality between men and women ',
#  'warmth and humor are important  seemingly bland but structurally rigorous  and can actually dive down ',
#  'the ending is not very good  but surprisingly i like the story of the entrepreneurial woman leader and the elderly intern ',
#  'variant of princess knight mode unbreakable tackiness is not a big problem  the most serious thing is that neither narrative nor kernel work btw  did the american people start saying goodbye in japanese ',
#  'three and a half stars  the first half was warm and solid  but the last half hour was so confusing ',
#  'the company has an old one  like a big one good old people experience sedimentation over the years and know how to say and do instead of scrambling for seats  going viral for something women deserve to be cheated on and single for the rest of their lives the ending is perfect ！！',
#  'marrying anne hathaway can cheat ',
#  'god s forgiveness of sins is too easy ',
#  'anne hathaway is beautiful of course robert de niro is handsome too more importantly  the story of love and life is very well told  i like it ',
#  ' it is never wrong to do the right thing。  elbow recommended the movie  too much like him ',
#  'the male protagonist is too perfect  the first time to feel the charm of the elderly  completely match the word decent i suddenly realized that it was a feminist color movie  and the intention was very good  but the ending was a little hasty and simple ',
#  '【mature  s oneqycjtwoha code wrgnine 小',
#  'love this old man ！',
#  'compared with our country s fashion comedy genre  we can achieve the complete drama is not easy ',
#  'in the cinema  de niro and heatherway have a good combination the old man found a new job  the woman is a workaholic  save the marriage want to leave  the old man has a new relationship  around a circle still have to dry  but the mood is very different  two people practice taiji  the original life is really good ',
#  'i thought it was the simplicity of the old days to inject vitality into the new generation  but in the end  it was still a suggestion between the elites  so there was no resonance it is still a disney movie let us also look at a relaxed warmth ',
#  ' two thousand and sixteen one three fifteen forty one thirty two',
#  'a warm and relaxing film the male protagonist s setting is too perfect  good subordinates  good colleagues and good friends the united states has energy ps  what i thought was going to happen to the male and female protagonists    think too much 。。╮ ╯▽╰ ╭',
#  'i cannot change the fact that i love this cas anymore ',
#  'there is a respect for oneself and others in the relationship with others it is a noble character ',
#  'it is cool and warm  and it is warm and principled ',
#  'that is good to say ',
#  'the old man is so cute   looks like the old man in up   the story is cute and funny  listen to the old man must be right  everyone has to have a ben around it ',
#  'it is mediocre  but it is also touching ',
#  'there is nothing to say about the plot  but support a play with the main character  plus one star ',
#  'really  i would not have watched this stupid movie if it was not for chris ',
#  'it is a waste of my life 。。',
#  'this kind of angelic thing will not let me catch up easily  i can only try to achieve seven hours of sleep every day ',
#  'it is fun  but it is not a big deal ',
#  'i think it is a waste of time ',
#  'if i can be so relaxed at the age of seventy and have so much love in my heart and live so clearly  it will not be in vain if you want to be robert de niro in china  take more action comedy ',
#  'halfway through the conversation about women in the workplace  nancy meyers  baby boom suddenly came to mind  wondering if it was her movie ',
#  'i watched a movie at home with my brother i have heard and seen posters many times  and i used to think that the hostess was an intern it was a film that inspired me a lot  both at work and in life ',
#  'daydream movies  screenwriters are very respectful of female strongmen  old school gentlemen  but these two are far from the reality of most people ',
#  'an emotionally delicate old school style man',
#  'i wanted to play three stars  but the old man is so cute too hathaway looks great in her clothes ',
#  'in addition to the title of the movie should be called  intern driver nanny   the back of the head can guess the plot ',
#  'seeing that the gods of the past were acting as retired grandfathers  once again i could not help but feel that the hero was late ',
#  'de niro is in god s presence ',
#  'anne went from being an intern at prada to being a big boss and dressed really well  probably the only time i liked her  old robert has a lot of virtue and a lot of love ',
#  'i love it  i love the old man  and i love the old man i love the old man and want to be like him no matter how  clean up your own clean  seventy year old can also meet the heart of the object  but only if you can do it yourself you have to be like yourself  only when you meet the person you like  do not be afraid to fight for  meet a yes  the most impressive thing about this movie is the love of old age ',
#  'it is not so boring as it is an ordinary story  but this kind of cast in the box product looks worthless……',
#  'one star is for the actor s acting and personality  very charming personality spit out a mess without the center of gravity of the plot  and anne hathaway can only frown and mouth of the acting  it is annoying to see ',
#  'robert de niro as a seventy year old man is so cute but the plot is simple without climax 。。',
#  'the old and strong are also constantly learning and integrating into the new social atmosphere  which is admirable the two storylines  which are well blended  and properly amused  will suffice for a good light comedy how lucky and rare it is to have a mentor  also a teacher and friend  to guide you forward to open  just can not be better ',
#  'a fashion magazine intern many years ago has grown into a fashion e commerce ceo how encouraging ',
#  'stay awake ',
#  'do not be fooled ',
#  'three and a half stars ',
#  'how can luo be so cute ！！',
#  'a little rotten tail  the setting is really good  you can say a good story  the end of the hastily and reluctantly  a lot of things are not handled well anne hathaway said that many women wonder where good men like jack nelson harrison ford and so on have gone ',
#  'hathaway is the american zhao wei in this movie barely two points  de niro and hathaway s opponents basically did not call ah  the other supporting actors worse performance of a grade  looks very long this kind of work girl movie  the united states made a level with us ',
#  'robert de niro s character is not established ',
#  'de niro is a star ',
#  'do not follow robert de niro  stand by the alley and wait for me ',
#  'the setting of the story fascinated me  and when i first left the theater  countless friends could not help but say   i do not think i have ever seen a setting like this before  ',
#  'novel  this is the film under the shell of an american comedy film  leaving people with the most distinctive feeling ',
#  'but where is it new a match between an elderly gentleman and a young queen is not uncommon lost in tokyo 。。   deployment ',
#  'for more detailed information  see fifteen words  http   www fifteenyan com topic sheng huo zai bie chu fourxbcjldkszeroe i ',
#  'i watched a movie almost ten years ago  and i was still studying  and i felt childishly that the relationship between superiors and subordinates in the workplace was like this  the assistant was frightened by the queen s order the queen said one  but the little assistant did not dare to say two the queen said you were a horse 。。   deployment ',
#  'there are so many things  school does not teach  parents do not talk  the people want to achieve  all rely on talent  or self study ',
#  'first  how to fall in love  second  how to be a parent  third  how to face aging and death ',
#  'the first two can somehow play one  two  three with innate hormones and a sense of responsibility to be protected by evolution  and play well from the beginning but the third one  everyone is long 。。   deployment ',
#  'i talked to my colleagues about this movie at lunch today  and i did not think about it  saying it was a chicken flick  and that it was made by a female director suddenly my scalp is tight and my heart is screaming ',
#  'no  i am a feminist ',
#  'how could i say such a sexist thing ',
#  'but let us say one thing  strictly observe one on the surface  the intern s temperament looks like nora s 。。   deployment ',
#  'in the words of friends  this kind of chicken flick  i call them  girl heart movies  😌  is more suitable for free time to cry  sitting alone in bed and watching on the computer  affordable and atmospheric there is a little bit of truth to it  but these days there is a real need for fresh  positive energy supply tablets ',
#  ' so i bought the only remaining front row a few minutes before the movie started 。。   deployment ',
#  'when i see the title and the main character  i take it for granted that it is a growing story of hathaway  a female trainee who is full of wisdom  experience  and harshness however  what surprised me was that the intern was de niro  who played a residual heat after retirement  and the ceo  who dominated the scene  was abused by a female demon 。。   deployment ',
#  'this movie may have a spoiler ',
#  'the story is interesting  i have never seen such a subject before ',
#  'at nearly seventy  ben  though once a shrewd and successful businessman  eventually  like most of the elderly  began a bland retirement julian is young but the founder of a famous fashion shopping website but ben was an old man full of new things about the world and became a member of julian s crew 。。   deployment ',
#  'what can i do at seventy bringing grandchildren  basking in the sun  following the old age group around  and sitting in a rocking chair slowly shaking  in the eyes of ordinary people  this is probably the happiest seventy years old ',
#  'ben  a seventy year old man here  is wearing a suit and applying for an internship at an online shopping company from the moment he sat at his desk  i knew he had chosen the right one  and i had come right ',
#  'ben is clean 。。   deployment ',
#  'watch robert de niro and anne hathaway play  regardless of the story  this lineup can also attract a large audience 旸 to be honest  anne hathaway s performance in  the intern  is really average  whether it is the mixed image of a businesswoman and a little girl at first appearance  or the gentle woman s heart later  it is the right thing to do to some extent  she 。。   deployment ',
#  'this movie may have a spoiler ',
#  ' intern  is the most recent american drama i watched  and the ichiyi score is as high as nine points the plot details are interesting  the rhythm is smooth  the humor is funny  the picture is warm after reading this  i personally think that there are three things to gain ',
#  'ben  the protagonist of the drama  is an intern  he is a little different  you cannot imagine that he is a seventy year old man he is wise  open minded  and open minded 。。   deployment ',
#  'after watching this movie  i laughed out of the theater last time it was about time ',
#  'despite the stereotype of the plot  it is really warm and relaxed  and it is absolutely comfortable to watch if you do not want to see this kind of movie  the wall is recommended ',
#  'ben is one of the warmest characters in this movie he was wise enough to understand that his assistant sister needed a little compliment he was friendly  offered to provide accommodation for the supporting actor one and helped 。。   deployment ',
#  'freshly held laughter details  tapping words  massage will be hard  thunder snoring…with a lifetime of experience in the old ginger  no matter how high the academic qualifications also need to get job recognition  to find the rare modern gentleman manners… nancy meyers can always take a good picture in the vulgar subject matter  favorite chick flick director ',
#  ' hopefully it is just a momentary misjudgment  not love   the joy she deserves is  slow down ',
#  ' 。。   deployment ',
#  'this movie may have a spoiler ',
#  'freud said   love and work are all about life   ',
#  ' （freud said  love and work。work and love。that is all there is。 ） a seventy year old widower who accompanied a group of people playing tai chi in the park began the monologue ',
#  'this phrase is often used in the propaganda text of psychology courses  and it is often used in my mouth  just a few 。。   deployment ',
#  'the process of watching is a comfortable film ',
#  'the angle is novel anne hathaway was once a fashion witch and had been crushed to the point where she had become the soul of a company the assistant next to the boss became an older intern ',
#  'from the beginning of ben s self report can know his rich experience  and then from his speech and his own dress can be seen that this is a tradition and good habits 。。   deployment ',
#  'i thought it would be like  queen of prada  type  mainly because i did not see the movie profile at all and downloaded it directly in fact  it is different  even though it is a workplace 。。   deployment ',
#  'this movie may have a spoiler ',
#  'at first  it was nothing more than a  retirement    widow    forty two years of perfect marriage  and  forty years of experience in old fashioned business management    a hole in the heart    daily wear a suit    using a vintage bag  。。   deployment ',
#  'this movie may have a spoiler ',
#  'her film the only pan film culture customized for girls wechat herinfilm went out to do an interview the other day  and the guest asked me a very interesting question  what movie do you think is a feminist movie i was speechless for a moment and could not think of a complete answer ',
#  'for a moment  i suddenly remembered that after the outflow of resources from the intern  many people said that it was a  feminist pornography  movie 。。   deployment ',
#  'the fourth minute of the opening i realized it was a special internship  and it was destined to be a surprising viewing process  where we were used to seeing fresh people helpless and an old man with years of experience returning to the internship 。。   deployment ',
#  'this movie may have a spoiler ',
# ...
#  'the film is romantic and moving ',
#  ' the water in front of the door can still be west  hugh will sing yellow chicken with white hair  to describe ben more appropriate he is really a cool guy at the age when he should have been idle  he wanted to prove his worth again and integrate into this fast paced society  although he began to adapt slightly  but the rich work experience and good interpersonal skills in the first half of his life helped him adapt 。。   deployment ',
#  'everyone has a special place for everyone  and it offers a special role in a perfect group if you meet a good manager  he can make this particularly useful in daily life  wise elders act as managers of a group  keeping the group stable  which is why the ancients used to say that they respected the elderly ',
#  'respect for elders in this connection often leads to between people 。。   deployment ',
#  'this movie may have a spoiler ',
#  'i really like this movie  and i feel like every day is a mess these days and i cannot do anything right as i am about to recruit autumn  the future may not be as successful as the female career  but the personality is really similar  strong and easy to attribute many things to their own head the plot in the movie is always perfect in the end  and the woman s husband makes the right decision but reality is not so happy 。。   deployment ',
#  'this movie may have a spoiler ',
#  'when i did not watch the movie before  i thought anne hathaway was an intern  and i thought this movie was about a young intern growing up  but i did not think the intern was ben  a seventy year old old man ',
#  'at the beginning of the movie  ben had retired and spent a lot of free time  and seeing him say that he would come to starbucks every morning at seven fifteen a m   i felt a sense of participation  i sympathized deeply  i especially like to stay in the cafe  surrounded by nature 。。   deployment ',
#  'when we were in our sophomore year  it was the third season of desperate housewives  our english teacher liked to insert the content of the drama when she said the word  compromise  and used the conversation between gaby and her husband 。。   deployment ',
#  'although it is a two thousand and fifteen movie  but it still looks very fashionable  especially like the exquisite attitude of the male protagonist  and the female protagonist is very beautiful  the street view of the house is very british ',
#  'it was his insight into life  his courage to confront life s problems and not blame them on himself ',
#  'the husband blames his own career for cheating  sometimes not 。。   deployment ',
#  'the film tells the story of juul  a career woman  and a forty year old businessman who retired and re employed ',
#  'juul started her own company a year ago  her husband is full time at home with a baby and has a lovely kindergarten daughter the company has absorbed more than two hundred employees in the past year  and its operation is also very good ',
#  'the company decided to hire some senior interns  and ben applied and was successfully accepted i have been assigned to lead julie  julie 。。   deployment ',
#  'this movie may have a spoiler ',
#  ' you are not just my intern  you are my friend  ',
#  'in the film  jules tells her senior intern ben ',
#  'work and love before the movie  the intern s name reminded me of anne hathaway s two thousand and seven film the queen in prada  in which she was not an intern but a  queen  ',
#  'it is a modern society  marriage and family 。。   deployment ',
#  'this movie is really too warm  anne hathaway is really beautiful 💞 ⭐ i thought it was about the heroine jules during the internship  through her own efforts  a little powerful story however  the main character of the trainee is a grandfather  ben  who is the main character of the movie the woman is already the boss of an internet company ',
#  'about jules 🌙 everyone will be vulnerable to the hostess company from two 。。   deployment ',
#  ' intern  thought it was similar to the female devil  describing hathaway s growth as an intern in the workplace  so it has never been intended to repeat this theme  after all  pearl jade before looking through the  i want to see  series  i stumbled upon the story of hathaway growing up with an elderly intern as a boss although i was late  i was really glad to meet such a warm and positive movie  which healed the long night it is really    \xa0 deployment ',
#  'this movie may have a spoiler ',
#  'one day  listening to fan deng explain  the hundred years of life   or suddenly  in middle age  or even at some point in old age  need to re learn  re find a job ',
#  'movies have different visions  elderly  retired  old  widowed at first as a degree 。。   deployment ',
#  'i have a hole in my life that i have to fill as soon as possible to explore the plight of career women corporate operations  family  business society  gender discrimination in business  the disappearance of male office workers  the rise of female office workers  an elderly person ',
#  'the second spring of career  the second spring of the body  the new office  the old office  the home decentralized because of the calm temperament assigned tasks stealing computers  deleting emails home has an old one  such as one 。。   deployment ',
#  'be optimistic and positive for the rest of your life  and never give up your desire for knowledge ',
#  'if at seventy  you can be as passionate about life as at twenty  every day from getting up and dressing up to white tipped books and yoga to going to bed on time at night  if at seventy  you never give up the trend  your attitude to life remains unchanged 。。   deployment ',
#  'this movie may have a spoiler ',
#  'the movie is beautiful  an entrepreneurial woman in her career and life crisis  just in time to appear a mature older friend maybe he cannot directly help in his career or life  but the spiritual support is infinite  i envy this kind of person  after all  this image of an elderly friend or life mentor is not everyone has a chance to meet 。。   deployment ',
#  'you will gain the following knowledge related to the workplace  one on the first day of work  be sure not to be late  set the alarm clock  and set two if you are too nervous keep a friendly and comfortable distance from your colleagues  so you do not have to come up and please others when you have time  help your colleagues around you observe  do what the boss wants to do and see results after watching the movie  i want to buy some handkerchiefs 。。   deployment ',
#  'it turned out that an actor holding up most of the play was not legendary  and robert de niro did just that ',
#  'this film is set in the workplace and explores the theme of  winners in life  one is an elderly person returning to the workplace  and one is a strong woman who has made a name for herself the elderly do a good job in every basic job  bringing warmth and positive energy to the people around them  the strong women are entangled in their families and careers 。。   deployment ',
#  'some movies can really support most of the drama  the old american actor robert de niro has done this  a smile  a move  absolutely elegant  elegant  through the screen can feel his elegance and nobility it is hard to believe that a seventy two year old man can be so attractive without seeing it for himself ',
#  'this movie belongs to the american soft comedy  it seems 。。   deployment ',
#  'this film review is for learning english only ',
#  'this is an atypical story from an intern to a best friend ',
#  'of course  this is not an inspirational movie  although it also poured a few bowls of chicken soup  after all  the rookie is seventy year old senior  veteran actor robert de niro  the oscar winner  martin scorsese s royal male protagonist  a man who played the godfather 。。。   deployment ',
#  'in life  there are a lot of helplessness and confusion these days we desperately need an experienced ferryman to help us cross the river like jules  clear  authentic character  dare to try the inner thoughts but life cannot always go smoothly  and when jules encounters problems  ben  a kind elder  always gives spiritual encouragement or some advice not much to say  but as long as ben is here  jules will 。。   deployment ',
#  'this movie may have a spoiler ',
#  'i watched the movie  intern  yesterday i used to rely on my age to decide whether a person was old or not but after watching the intern  i found that it was never age but his spirit that determined whether a person was old or not ',
#  'some people in their twentys live like an old man  some in their seventys  but like a teenager let us take a look at this movie together ',
#  'one none 。。   deployment ',
#  'before the movie was over  i ran to tell my friends that i had seen a good movie it is a really good piece of writing   maybe there has to be a reliable person at a time like this ',
#  '  instead of wanting to have someone like that around  i want to be that person – reliable  calm  sincere  always thoughtful  with the rigour and good habits of the previous generation  and constantly making progress  not out of touch with the times ',
#  ' 。。   deployment ',
#  'perhaps because i just finished my internship  i chose this movie the beginning of the film fascinates me when a retired seventy year old man decides to return to work because he has no sense of belonging ',
#  ' it is about getting life going  standing up  going out  going anywhere so he came to a new fashion clothing company to become an elderly intern the setting here 。。   deployment ',
#  'frankly   the intern  was not what i expected this week  but fortunately it was on the recommendation page in time  and fortunately i chose it with little hesitation it was chosen entirely because anne hathaway  sure enough  the goddess produced must be a fine product ',
#  'queen prada s intern has been promoted to boss  and annie in  intern  has been able to adapt to the fast pace and take the initiative 。。   deployment ',
#  'at first  i ran to hathaway  and when i saw the topic of intern  i thought that i should tell the story of a college graduate who entered the workplace  and i thought that i would soon become a social person  so i plan to take a look with such expectations  there will be more excitement when you look at it ',
#  'ben s performance should be to continue the knight culture  but also see some artisan spirit  if i get old can live like ben 。。   deployment ',
#  'one',
#  'i went to  anne hathaway s best movie  and  relaxed workplace comedy  and i was disappointed while it is true that anne hathaway is a light hearted work comedy  it is undeniable that it is a standard inspirational film with no ups and downs ',
#  'two',
#  'the whole movie really does not have ups and downs  although the movie does raise a lot of problems in the workplace 。。   deployment ',
#  'at the beginning of the movie  i saw an old man with a high emotional intelligence  intelligence  and always watching seventy years of age like a circle of fate  let him return to the factory he has spent more than forty years to familiarize himself with  face a strange new world  start working again  and start dating again the setting of the movie is still intriguing  and grandpa faces a new social and new job type as an intern 。。   deployment ',
#  'after watching the movie  i was fascinated by the old gentleman who had a slightly antique style it is the american version of the word but i am glad that his emotional line with the heroine is not vulgar love  and not at all ambiguous   but more like the father s communication with his daughter and the concern between friends ',
#  'then came the gentleman s delightful reason  logic  planning and courage  and so on 。。   deployment ',
#  'blake snyder screenplay beatwatch title  intern genre  fellowship date  two thousand and twenty one pfive  the male protagonist sees the list of interns and is said by the old lady  i cannot understand what it says  you are not young anymore paving the way for pone ten  exhibition 。。   deployment ',
#  'a retired vice president  to a start up internet company to do intern for female bosses  help young people find direction in work and life to find their own plot not too boring  her acting was still unremarkable and good looking  but like the princess diaries  the women in prada  look 。。   deployment ',
#  'the clothes you wear  the words you write  the words you say  the food you eat is who you are ',
#  'the biggest feeling of watching this movie is that ben always cleans himself up and wears a suit and his behavior is also subtly affecting everyone around him  such as the fat little man in his house  and starting to dress like him  formal and professional ',
#  'one',
#  'what a person wears and does is this 。。   deployment ',
#  'as a successful senior in the workplace  he has always been serious  sincere  humble  active  friendly  principled  and never crossed the line i think this is a kind of cultivation and wisdom  which is worth learning from every workplace  and helps us to integrate into the new environment and get respect from others faster 。。   deployment ',
#  'one',
#  'career  family  elders  friends  lovers  children like daily necessities  everyday life appears to us on time  and only when we have to make choices do we realize that they are so important all of us sometimes choose to forgive in the face of betrayal  and life may require us to be softer there are surprises everywhere in life  as long as you are willing to go out and experience it  no time 。。   deployment ',
#  'after work  i watched this movie at the beginning of the movie  the old man s delicate and elegant clothes make me feel comfortable  such as the spring breeze  and then later the old man is always elegant  always enthusiastic  always positive  warm but wise  always talk forever 。。   deployment ',
#  'this movie may have a spoiler ',
#  'demonstrate that competence in the workplace can be transferred ',
#  'in his last job  he took the position of vice president ',
#  'he can do vice presidential level  from his back as an intern  the performance of the workplace can be seen in his characteristics  is very worth learning as a new and even a veteran of the workplace  he is willing to try new things  embrace challenges  seventy years old still willing to learn the internet 。。   deployment ',
#  'this movie has too much conversational art to record  and the don s life state should be what most people aspire to ',
#  'the don first asks his assistant what to pay attention to before he sees her boss and a driver who drinks but still gives him two choices 。。   deployment ',
#  'a movie that makes me very comfortable to watch in particular  most of the first half  relaxed   small humor  let me almost the whole mouth of the whole time  the two main characters  acting is natural  sincere  not flamboyant and true feelings are easy to get into the play 。。   deployment ',
#  'this movie may have a spoiler ',
#  'as an american light comedy film   intern  has a variety of routines  the perfect plot direction  familiar comedy plot  and the well known anne hathaway as anyone who is seen it knows  this movie is a perfect story that is inspired by just one idea throughout many films  few films have had such perfect success ',
#  'at the time of the show  many people were not 。。   deployment ',
#  'this movie may have a spoiler ',
#  'ben  nearly seventy  joined the internet company as an intern  a workplace story that took place between him and founder jules ben is an admirable mature gentleman  and his attitude and spirit of life have inspired me a lot  and that is probably what i want to be — a balanced  influential person ',
#  ...]

# %%
# remove japanese, korean, chinese words

def only_english(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    return cleaned_text

rm_punctionations = [only_english(text) for text in rm_punctionations]

# %%
# POS_tagging

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# 필요한 NLTK 데이터 다운로드
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Text를 단어 토큰과 POS 태그로 변환
def pos_tagging(text):
    word_tokens = word_tokenize(text)
    return pos_tag(word_tokens)

tag_sentence = rm_punctionations.copy()

tag_sentence = [pos_tagging(text) for text in tag_sentence]
# Out:
# [nltk_data] Downloading package punkt to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\seowoo kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
tag_sentence
# Out:
# [[('why', 'WRB'),
#   ('even', 'RB'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('beautiful', 'NN'),
#   ('and', 'CC'),
#   ('successful', 'JJ'),
#   ('woman', 'NN'),
#   ('in', 'IN'),
#   ('american', 'JJ'),
#   ('movies', 'NNS'),
#   ('has', 'VBZ'),
#   ('to', 'TO'),
#   ('accept', 'VB'),
#   ('such', 'PDT'),
#   ('an', 'DT'),
#   ('ordinary', 'JJ'),
#   ('and', 'CC'),
#   ('cheating', 'JJ'),
#   ('husband', 'NN')],
#  [('it', 'PRP'),
#   ('all', 'DT'),
#   ('depends', 'VBZ'),
#   ('on', 'IN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('looked', 'VBD'),
#   ('good', 'JJ'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('half', 'NN'),
#   ('values', 'NNS'),
#   ('swallowed', 'VBN'),
#   ('conservative', 'JJ'),
#   ('and', 'CC'),
#   ('retreated', 'VBD'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('s', 'JJ'),
#   ('people', 'NNS'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('too', 'RB'),
#   ('perfect', 'JJ')],
#  [('for', 'IN'),
#   ('me', 'PRP'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('better', 'JJR'),
#   ('place', 'NN'),
#   ('if', 'IN'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('make', 'VB'),
#   ('one', 'CD'),
#   ('or', 'CC'),
#   ('two', 'CD'),
#   ('such', 'JJ'),
#   ('warm', 'JJ'),
#   ('skits', 'NNS'),
#   ('every', 'DT'),
#   ('year', 'NN'),
#   ('that', 'IN'),
#   ('look', 'NN'),
#   ('good', 'JJ'),
#   ('and', 'CC'),
#   ('release', 'NN'),
#   ('tears', 'NNS')],
#  [('when', 'WRB'),
#   ('hathaway', 'NN'),
#   ('intervened', 'VBD'),
#   ('in', 'IN'),
#   ('streep', 'JJ'),
#   ('s', 'NN'),
#   ('strongwoman', 'JJ'),
#   ('life', 'NN'),
#   ('now', 'RB'),
#   ('de', 'VBZ'),
#   ('niro', 'FW'),
#   ('anti', 'JJ'),
#   ('invasion', 'NN'),
#   ('hathaway', 'NN'),
#   ('life', 'NN'),
#   ('actually', 'RB'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('ambitious', 'JJ'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('discuss', 'VB'),
#   ('career', 'NN'),
#   ('women', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('older', 'JJR'),
#   ('generation', 'NN'),
#   ('but', 'CC'),
#   ('floating', 'VBG'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('i', 'JJ'),
#   ('like', 'IN'),
#   ('hathaway', 'VBP'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('but', 'CC'),
#   ('every', 'DT'),
#   ('little', 'JJ'),
#   ('expression', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PRP'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('sense', 'NN'),
#   ('of', 'IN'),
#   ('rehearsal', 'NN'),
#   ('and', 'CC'),
#   ('release', 'NN'),
#   ('especially', 'RB'),
#   ('compared', 'VBN'),
#   ('to', 'TO'),
#   ('de', 'VB'),
#   ('niro', 'FW'),
#   ('s', 'FW'),
#   ('relaxed', 'FW'),
#   ('share', 'NN'),
#   ('and', 'CC'),
#   ('de', 'VB'),
#   ('niro', 'FW'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('handsome', 'JJ')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('long', 'JJ'),
#   ('time', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('princess', 'JJ'),
#   ('anne', 'NNS'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('feels', 'VBZ'),
#   ('numb', 'CC'),
#   ('especially', 'RB'),
#   ('after', 'IN'),
#   ('fashion', 'NN'),
#   ('witch', 'NN'),
#   ('has', 'VBZ'),
#   ('set', 'VBN'),
#   ('the', 'DT'),
#   ('bar', 'NN'),
#   ('so', 'RB'),
#   ('high', 'JJ'),
#   ('for', 'IN'),
#   ('professional', 'JJ'),
#   ('women', 'NNS'),
#   ('and', 'CC'),
#   ('young', 'JJ'),
#   ('people', 'NNS'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('too', 'RB'),
#   ('warm', 'JJ'),
#   ('and', 'CC'),
#   ('mediocre', 'NN')],
#  [('the', 'DT'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('about', 'IN'),
#   ('acting', 'VBG'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('bones', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('play', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('good', 'JJ'),
#   ('enough', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('play', 'NN'),
#   ('is', 'VBZ'),
#   ('eaten', 'VBN'),
#   ('up', 'RP'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('other', 'JJ'),
#   ('party', 'NN')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('looks', 'VBZ'),
#   ('great', 'JJ'),
#   ('on', 'IN'),
#   ('you', 'PRP')],
#  [('freshly', 'RB'),
#   ('held', 'VBN'),
#   ('laughter', 'NN'),
#   ('details', 'NNS'),
#   ('tapping', 'VBG'),
#   ('words', 'NNS'),
#   ('massage', 'NN'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('hard', 'JJ'),
#   ('thunder', 'NN'),
#   ('snoring', 'VBG'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('lifetime', 'NN'),
#   ('of', 'IN'),
#   ('experience', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('ginger', 'NN'),
#   ('no', 'DT'),
#   ('matter', 'NN'),
#   ('how', 'WRB'),
#   ('high', 'JJ'),
#   ('the', 'DT'),
#   ('academic', 'JJ'),
#   ('qualifications', 'NNS'),
#   ('also', 'RB'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('job', 'NN'),
#   ('recognition', 'NN'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('the', 'DT'),
#   ('rare', 'JJ'),
#   ('modern', 'JJ'),
#   ('gentleman', 'NN'),
#   ('manners', 'NNS'),
#   ('nancy', 'IN'),
#   ('meyers', 'NNS'),
#   ('can', 'MD'),
#   ('always', 'RB'),
#   ('take', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('picture', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('vulgar', 'NN'),
#   ('subject', 'JJ'),
#   ('matter', 'NN'),
#   ('favorite', 'NN'),
#   ('chick', 'NN'),
#   ('flick', 'NN'),
#   ('director', 'NN')],
#  [('hopefully', 'RB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('momentary', 'JJ'),
#   ('misjudgment', 'NN'),
#   ('not', 'RB'),
#   ('love', 'VB'),
#   ('this', 'DT'),
#   ('joy', 'NN'),
#   ('is', 'VBZ'),
#   ('what', 'WP'),
#   ('she', 'PRP'),
#   ('deserves', 'VBZ'),
#   ('slow', 'JJ'),
#   ('down', 'RB'),
#   ('and', 'CC'),
#   ('enjoy', 'JJ'),
#   ('life', 'NN'),
#   ('in', 'IN'),
#   ('tai', 'NN'),
#   ('chi', 'NN')],
#  [('the', 'DT'),
#   ('encounter', 'NN'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('angel', 'NN'),
#   ('of', 'IN'),
#   ('high', 'JJ'),
#   ('emotional', 'JJ'),
#   ('intelligence', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('sweetheart', 'NN'),
#   ('of', 'IN'),
#   ('brooklyn', 'JJ'),
#   ('genius', 'NN'),
#   ('is', 'VBZ'),
#   ('all', 'DT'),
#   ('rubbed', 'VBN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('japanese', 'JJ'),
#   ('style', 'NN'),
#   ('warm', 'JJ'),
#   ('serenade', 'NN'),
#   ('from', 'IN'),
#   ('homage', 'NN'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('back', 'VB'),
#   ('to', 'TO'),
#   ('soundtracks', 'VB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('fought', 'VBN'),
#   ('off', 'RP'),
#   ('the', 'DT'),
#   ('gloom', 'NN'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('thirty', 'JJ'),
#   ('year', 'NN'),
#   ('old', 'JJ'),
#   ('crisis', 'NN'),
#   ('jules', 'NNS'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('future', 'NN'),
#   ('but', 'CC'),
#   ('ben', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('one', 'NN'),
#   ('who', 'WP'),
#   ('owns', 'VBZ'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('beautiful', 'JJ'),
#   ('thing', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('life', 'NN')],
#  [('from', 'IN'),
#   ('hathaway', 'RB'),
#   ('s', 'JJ'),
#   ('point', 'NN'),
#   ('of', 'IN'),
#   ('view', 'NN'),
#   ('who', 'WP'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('an', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('who', 'WP'),
#   ('has', 'VBZ'),
#   ('experienced', 'VBN'),
#   ('hardships', 'NNS'),
#   ('in', 'IN'),
#   ('life', 'NN'),
#   ('the', 'DT'),
#   ('content', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('guidance', 'NN'),
#   ('is', 'VBZ'),
#   ('actually', 'RB'),
#   ('shown', 'VBN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('and', 'CC'),
#   ('end', 'VB'),
#   ('taijiquan', 'JJ'),
#   ('slow', 'JJ'),
#   ('slow', 'NN'),
#   ('slow', 'NN')],
#  [('good', 'JJ'),
#   ('observation', 'NN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('humble', 'JJ'),
#   ('warm', 'NN'),
#   ('and', 'CC'),
#   ('courteous', 'JJ'),
#   ('advice', 'NN'),
#   ('and', 'CC'),
#   ('never', 'RB'),
#   ('cross', 'VB'),
#   ('the', 'DT'),
#   ('line', 'NN'),
#   ('principled', 'VBN'),
#   ('and', 'CC'),
#   ('interesting', 'JJ'),
#   ('rich', 'JJ'),
#   ('experience', 'NN'),
#   ('and', 'CC'),
#   ('never', 'RB'),
#   ('show', 'VB'),
#   ('off', 'RP'),
#   ('do', 'VBP'),
#   ('things', 'NNS'),
#   ('properly', 'RB'),
#   ('ben', 'VBP'),
#   ('is', 'VBZ'),
#   ('nearly', 'RB'),
#   ('seventy', 'JJ'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('generation', 'NN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('also', 'RB'),
#   ('saw', 'VBD'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('s', 'JJ'),
#   ('old', 'JJ'),
#   ('age', 'NN'),
#   ('calm', 'NN'),
#   ('and', 'CC'),
#   ('intelligent', 'JJ'),
#   ('side', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('all', 'DT'),
#   ('powerful', 'JJ'),
#   ('play', 'NN'),
#   ('god', 'VBD'),
#   ('seven', 'CD'),
#   ('six', 'CD')],
#  [('a', 'DT'),
#   ('year', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('half', 'NN'),
#   ('of', 'IN'),
#   ('e', 'JJ'),
#   ('commerce', 'JJ'),
#   ('women', 'NNS'),
#   ('can', 'MD'),
#   ('run', 'VB'),
#   ('businesses', 'NNS'),
#   ('and', 'CC'),
#   ('men', 'NNS'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('domestic', 'JJ'),
#   ('men', 'NNS'),
#   ('new', 'JJ'),
#   ('people', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('are', 'VBP'),
#   ('no', 'RB'),
#   ('longer', 'RB'),
#   ('synonymous', 'JJ'),
#   ('with', 'IN'),
#   ('their', 'PRP$'),
#   ('early', 'JJ'),
#   ('twentys', 'NN'),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('can', 'MD'),
#   ('still', 'RB'),
#   ('work', 'VB'),
#   ('as', 'IN'),
#   ('interns', 'NNS'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('age', 'NN'),
#   ('of', 'IN'),
#   ('seventy', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('time', 'NN'),
#   ('when', 'WRB'),
#   ('gender', 'NN'),
#   ('and', 'CC'),
#   ('age', 'NN'),
#   ('are', 'VBP'),
#   ('downplayed', 'VBN'),
#   ('as', 'RB'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('body', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('positive', 'JJ'),
#   ('mind', 'NN'),
#   ('anything', 'NN'),
#   ('is', 'VBZ'),
#   ('possible', 'JJ'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('warm', 'JJ'),
#   ('film', 'NN'),
#   ('annie', 'NN'),
#   ('s', 'NN'),
#   ('clothes', 'NNS'),
#   ('look', 'VBP'),
#   ('great', 'JJ')],
#  [('de', 'IN'),
#   ('niro', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('warm', 'JJ'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('felt', 'VBD'),
#   ('his', 'PRP$'),
#   ('tenderness', 'NN'),
#   ('and', 'CC'),
#   ('nobility', 'NN'),
#   ('across', 'IN'),
#   ('the', 'DT'),
#   ('screen', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('cold', 'JJ'),
#   ('drink', 'NN'),
#   ('chicken', 'VBN'),
#   ('soup', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('driver', 'NN'),
#   ('s', 'NN'),
#   ('fan', 'NN'),
#   ('disappears', 'NNS')],
#  [('more', 'RBR'),
#   ('standard', 'JJ'),
#   ('chicken', 'NN'),
#   ('flick', 'NN'),
#   ('three', 'CD'),
#   ('views', 'NNS'),
#   ('humor', 'VBP'),
#   ('famous', 'JJ'),
#   ('characters', 'NNS'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('important', 'JJ'),
#   ('thing', 'NN'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('it', 'PRP'),
#   ('all', 'DT')],
#  [('in', 'IN'),
#   ('any', 'DT'),
#   ('case', 'NN'),
#   ('the', 'DT'),
#   ('development', 'NN'),
#   ('of', 'IN'),
#   ('chuck', 'NN'),
#   ('flick', 'NN'),
#   ('from', 'IN'),
#   ('love', 'NN'),
#   ('to', 'TO'),
#   ('not', 'RB'),
#   ('sacrificing', 'VBG'),
#   ('career', 'NN'),
#   ('for', 'IN'),
#   ('family', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('huge', 'JJ'),
#   ('social', 'JJ'),
#   ('progress', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('is', 'VBZ'),
#   ('like', 'IN'),
#   ('grandpa', 'NN'),
#   ('in', 'IN'),
#   ('flying', 'VBG'),
#   ('house', 'NN')],
#  [('the', 'DT'),
#   ('novelty', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('lies', 'VBZ'),
#   ('in', 'IN'),
#   ('balance', 'NN'),
#   ('and', 'CC'),
#   ('balance', 'NN'),
#   ('seventy', 'NN'),
#   ('year', 'NN'),
#   ('olds', 'NNS'),
#   ('face', 'VBP'),
#   ('up', 'RB'),
#   ('to', 'TO'),
#   ('their', 'PRP$'),
#   ('own', 'JJ'),
#   ('social', 'JJ'),
#   ('status', 'NN'),
#   ('quo', 'NNS'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('rely', 'VB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('to', 'TO'),
#   ('sell', 'VB'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('emphasize', 'VB'),
#   ('the', 'DT'),
#   ('past', 'JJ'),
#   ('but', 'CC'),
#   ('silently', 'RB'),
#   ('rely', 'RB'),
#   ('on', 'IN'),
#   ('their', 'PRP$'),
#   ('own', 'JJ'),
#   ('experience', 'NN'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('each', 'DT'),
#   ('young', 'JJ'),
#   ('person', 'NN'),
#   ('continue', 'VBP'),
#   ('to', 'TO'),
#   ('achieve', 'VB'),
#   ('their', 'PRP$'),
#   ('own', 'JJ'),
#   ('value', 'NN'),
#   ('thirty', 'NN'),
#   ('year', 'NN'),
#   ('olds', 'NNS'),
#   ('gradually', 'RB'),
#   ('learn', 'VBP'),
#   ('to', 'TO'),
#   ('balance', 'VB'),
#   ('everything', 'NN'),
#   ('in', 'IN'),
#   ('life', 'NN'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('run', 'VB'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('problems', 'NNS'),
#   ('in', 'IN'),
#   ('marriage', 'NN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('deliberately', 'RB'),
#   ('curb', 'VB'),
#   ('their', 'PRP$'),
#   ('inner', 'NN'),
#   ('desires', 'VBZ'),
#   ('both', 'DT'),
#   ('things', 'NNS'),
#   ('are', 'VBP'),
#   ('difficult', 'JJ'),
#   ('but', 'CC'),
#   ('never', 'RB'),
#   ('give', 'VBP'),
#   ('up', 'RP'),
#   ('the', 'DT'),
#   ('enthusiasm', 'NN'),
#   ('to', 'TO'),
#   ('learn', 'VB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('courage', 'NN'),
#   ('to', 'TO'),
#   ('start', 'VB')],
#  [('old', 'JJ'),
#   ('school', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('just', 'RB'),
#   ('retro', 'VB'),
#   ('not', 'RB'),
#   ('old', 'JJ'),
#   ('fashioned', 'VBD'),
#   ('not', 'RB'),
#   ('hip', 'JJ'),
#   ('hop', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('people', 'NNS'),
#   ('who', 'WP'),
#   ('insist', 'VBP'),
#   ('on', 'IN'),
#   ('good', 'JJ'),
#   ('things', 'NNS'),
#   ('traditional', 'JJ'),
#   ('habits', 'NNS'),
#   ('and', 'CC'),
#   ('ideas', 'NNS')],
#  [('watched', 'VBD'),
#   ('the', 'DT'),
#   ('episode', 'NN'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('plane', 'NN'),
#   ('from', 'IN'),
#   ('new', 'JJ'),
#   ('york', 'NN'),
#   ('to', 'TO'),
#   ('san', 'VB'),
#   ('francisco', 'JJ'),
#   ('featuring', 'VBG'),
#   ('brooklyn', 'NN'),
#   ('bridge', 'NN'),
#   ('and', 'CC'),
#   ('golden', 'JJ'),
#   ('gate', 'NN'),
#   ('bridge', 'NN')],
#  [('basically', 'RB'),
#   ('relying', 'VBG'),
#   ('on', 'IN'),
#   ('de', 'NNS'),
#   ('niro', 'FW'),
#   ('to', 'TO'),
#   ('support', 'VB'),
#   ('the', 'DT'),
#   ('field', 'NN'),
#   ('hathaway', 'NN'),
#   ('won', 'VBD'),
#   ('the', 'DT'),
#   ('award', 'NN'),
#   ('in', 'IN'),
#   ('recent', 'JJ'),
#   ('years', 'NNS'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('another', 'DT'),
#   ('impressive', 'JJ'),
#   ('role', 'NN'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB')],
#  [('at', 'IN'),
#   ('most', 'JJS'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('version', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('post', 'NN'),
#   ('marriage', 'NN'),
#   ('magnification', 'NN'),
#   ('light', 'JJ'),
#   ('truck', 'NN'),
#   ('white', 'JJ'),
#   ('lilies', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('united', 'JJ'),
#   ('states', 'NNS'),
#   ('of', 'IN'),
#   ('course', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('fun', 'NN'),
#   ('or', 'CC'),
#   ('something', 'NN')],
#  [('do', 'VB'),
#   ('not', 'RB'),
#   ('learn', 'VB'),
#   ('from', 'IN'),
#   ('robert', 'JJ'),
#   ('dinillo', 'NN'),
#   ('stand', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('entrance', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('alley', 'NN'),
#   ('and', 'CC'),
#   ('wait', 'NN'),
#   ('for', 'IN'),
#   ('me', 'PRP')],
#  [('a', 'DT'),
#   ('cheesy', 'NN'),
#   ('yet', 'RB'),
#   ('comforting', 'VBG'),
#   ('enjoyment', 'NN'),
#   ('robert', 'NN'),
#   ('deniro', 'NN'),
#   ('just', 'RB'),
#   ('played', 'VBD'),
#   ('a', 'DT'),
#   ('perfect', 'JJ'),
#   ('silver', 'NN'),
#   ('daddy', 'NN'),
#   ('in', 'IN'),
#   ('every', 'DT'),
#   ('women', 'NNS'),
#   ('and', 'CC'),
#   ('men', 'NNS'),
#   ('s', 'VBP'),
#   ('dream', 'NN'),
#   ('no', 'DT'),
#   ('kidding', 'NN'),
#   ('i', 'NN'),
#   ('put', 'VBD'),
#   ('women', 'NNS'),
#   ('before', 'IN'),
#   ('men', 'NNS'),
#   ('hope', 'VBP'),
#   ('you', 'PRP'),
#   ('all', 'DT'),
#   ('see', 'VBP'),
#   ('what', 'WP'),
#   ('i', 'VB'),
#   ('suggest', 'VBP'),
#   ('here', 'RB')],
#  [('nancy', 'NN'),
#   ('meyers', 'NNS'),
#   ('has', 'VBZ'),
#   ('not', 'RB'),
#   ('made', 'VBN'),
#   ('a', 'DT'),
#   ('movie', 'NN'),
#   ('in', 'IN'),
#   ('years', 'NNS'),
#   ('and', 'CC'),
#   ('she', 'PRP'),
#   ('is', 'VBZ'),
#   ('been', 'VBN'),
#   ('focusing', 'VBG'),
#   ('on', 'IN'),
#   ('old', 'JJ'),
#   ('people', 'NNS'),
#   ('s', 'VBP'),
#   ('social', 'JJ'),
#   ('relationships', 'NNS'),
#   ('for', 'IN'),
#   ('decades', 'NNS'),
#   ('and', 'CC'),
#   ('her', 'PRP$'),
#   ('up', 'NN'),
#   ('to', 'TO'),
#   ('date', 'NN'),
#   ('start', 'VB'),
#   ('up', 'RP'),
#   ('female', 'JJ'),
#   ('entrepreneurial', 'JJ'),
#   ('setting', 'NN'),
#   ('is', 'VBZ'),
#   ('much', 'RB'),
#   ('more', 'RBR'),
#   ('interesting', 'JJ'),
#   ('than', 'IN'),
#   ('before', 'IN')],
#  [('a', 'DT'),
#   ('warm', 'JJ'),
#   ('hearted', 'VBN'),
#   ('comedy', 'NN'),
#   ('the', 'DT'),
#   ('modern', 'JJ'),
#   ('costume', 'NN'),
#   ('of', 'IN'),
#   ('anne', 'NN'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('more', 'RBR'),
#   ('beautiful', 'JJ'),
#   ('her', 'PRP$'),
#   ('performance', 'NN'),
#   ('with', 'IN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('biggest', 'JJS'),
#   ('attraction', 'NN'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('less', 'RBR'),
#   ('fashionable', 'JJ'),
#   ('than', 'IN'),
#   ('the', 'DT'),
#   ('queen', 'NN'),
#   ('in', 'IN'),
#   ('prada', 'NN')],
#  [('watching', 'VBG'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('i', 'VBZ'),
#   ('feel', 'VBP'),
#   ('like', 'IN'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('say', 'VBP'),
#   ('i', 'NNS'),
#   ('am', 'VBP'),
#   ('doing', 'VBG'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('thing', 'NN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('woman', 'NN'),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('ten', 'VBN'),
#   ('zero', 'CD'),
#   ('times', 'NNS'),
#   ('smaller', 'JJR'),
#   ('than', 'IN'),
#   ('her', 'PRP$'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('super', 'JJ'),
#   ('similarities', 'NNS'),
#   ('but', 'CC'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('more', 'JJR'),
#   ('to', 'TO'),
#   ('learn', 'VB'),
#   ('from', 'IN'),
#   ('her', 'PRP$'),
#   ('there', 'EX'),
#   ('were', 'VBD'),
#   ('countless', 'JJ'),
#   ('scenes', 'NNS'),
#   ('in', 'IN'),
#   ('between', 'IN'),
#   ('that', 'DT'),
#   ('moved', 'VBD'),
#   ('me', 'PRP'),
#   ('to', 'TO'),
#   ('tears', 'VB'),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   ('i', 'JJ'),
#   ('am', 'VBP'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('it', 'PRP'),
#   ('again', 'RB')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('tribute', 'NN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('i', 'NN'),
#   ('woke', 'VBD'),
#   ('up', 'RP'),
#   ('at', 'IN'),
#   ('five', 'CD'),
#   ('a', 'DT'),
#   ('m', 'NN'),
#   ('and', 'CC'),
#   ('watched', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('always', 'RB'),
#   ('wanted', 'VBN'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('oh', 'JJ'),
#   ('my', 'PRP$'),
#   ('god', 'NN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('day', 'NN')],
#  [('watching', 'VBG'),
#   ('this', 'DT'),
#   ('women', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('like', 'IN'),
#   ('flipping', 'VBG'),
#   ('through', 'IN'),
#   ('women', 'NNS'),
#   ('s', 'JJ'),
#   ('fashion', 'NN'),
#   ('magazines', 'NNS'),
#   ('flipping', 'VBG'),
#   ('through', 'IN'),
#   ('pictures', 'NNS'),
#   ('to', 'TO'),
#   ('teach', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('dress', 'VB'),
#   ('read', 'JJ'),
#   ('columns', 'NN'),
#   ('and', 'CC'),
#   ('drink', 'VB'),
#   ('feminist', 'JJ'),
#   ('chicken', 'NN'),
#   ('soup', 'NN'),
#   ('life', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('easy', 'JJ'),
#   ('for', 'IN'),
#   ('them', 'PRP'),
#   ('playing', 'VBG'),
#   ('taijiquan', 'NNS'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('balanced', 'VBN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('casting', 'NN'),
#   ('is', 'VBZ'),
#   ('still', 'RB'),
#   ('good', 'JJ'),
#   ('stay', 'NN'),
#   ('classic', 'JJ')],
#  [('too', 'RB'),
#   ('boring', 'VBG'),
#   ('a', 'DT'),
#   ('director', 'NN'),
#   ('shooting', 'VBG'),
#   ('a', 'DT'),
#   ('love', 'NN'),
#   ('vacation', 'NN'),
#   ('shooting', 'VBG'),
#   ('what', 'WP'),
#   ('workplace', 'NN'),
#   ('story', 'NN'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('a', 'DT'),
#   ('fuss', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('flat', 'JJ'),
#   ('life', 'NN'),
#   ('so', 'RB'),
#   ('mediocre', 'JJ')],
#  [('you', 'PRP'),
#   ('look', 'VBP'),
#   ('great', 'JJ'),
#   ('in', 'IN'),
#   ('it', 'PRP')],
#  [('go', 'VB'),
#   ('gentleman', 'NN'),
#   ('like', 'IN'),
#   ('an', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('go', 'VBP'),
#   ('passionate', 'NN'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('goddess', 'NN')],
#  [('one', 'CD'),
#   ('hundred', 'CD'),
#   ('and', 'CC'),
#   ('thirty', 'JJ'),
#   ('stars', 'NNS'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN')],
#  [('the', 'DT'),
#   ('urban', 'JJ'),
#   ('version', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('elderly', 'JJ'),
#   ('and', 'CC'),
#   ('young', 'JJ'),
#   ('girls', 'NNS'),
#   ('no', 'DT'),
#   ('matter', 'NN'),
#   ('what', 'WP'),
#   ('age', 'NN'),
#   ('group', 'NN'),
#   ('people', 'NNS'),
#   ('always', 'RB'),
#   ('need', 'VBP'),
#   ('to', 'TO'),
#   ('please', 'VB'),
#   ('each', 'DT'),
#   ('other', 'JJ'),
#   ('in', 'IN'),
#   ('order', 'NN'),
#   ('to', 'TO'),
#   ('run', 'VB'),
#   ('into', 'IN'),
#   ('each', 'DT'),
#   ('other', 'JJ')],
#  [('simple', 'NN'),
#   ('and', 'CC'),
#   ('comfortable', 'JJ'),
#   ('lacking', 'NN'),
#   ('in', 'IN'),
#   ('depth', 'NN'),
#   ('but', 'CC'),
#   ('making', 'VBG'),
#   ('up', 'RP'),
#   ('for', 'IN'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('warmth', 'NN'),
#   ('robert', 'NN'),
#   ('was', 'VBD'),
#   ('simply', 'RB'),
#   ('handsome', 'JJ'),
#   ('hathaway', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('pretty', 'RB'),
#   ('her', 'PRP$'),
#   ('expression', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('tight', 'JJ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('little', 'JJ'),
#   ('girl', 'NN'),
#   ('who', 'WP'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('an', 'DT'),
#   ('assistant', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('demon', 'NN'),
#   ('headed', 'VBD'),
#   ('woman', 'NN'),
#   ('became', 'VBD'),
#   ('a', 'DT'),
#   ('strongwoman', 'NN'),
#   ('p', 'NN')],
#  [('s', 'NN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('textbook', 'NN'),
#   ('level', 'NN'),
#   ('dressing', 'VBG'),
#   ('tutorial', 'JJ'),
#   ('hathaway', 'NN'),
#   ('s', 'NN'),
#   ('light', 'JJ'),
#   ('mature', 'NN'),
#   ('girl', 'NN'),
#   ('ol', 'JJ'),
#   ('style', 'NN'),
#   ('robert', 'NN'),
#   ('s', 'VBD'),
#   ('retro', 'JJ'),
#   ('suit', 'NN'),
#   ('style', 'NN'),
#   ('every', 'DT'),
#   ('set', 'NN'),
#   ('is', 'VBZ'),
#   ('pleasing', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('eye', 'NN')],
#  [('so', 'RB'),
#   ('the', 'DT'),
#   ('happy', 'JJ'),
#   ('marriage', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('strong', 'JJ'),
#   ('woman', 'NN'),
#   ('is', 'VBZ'),
#   ('unsolvable', 'JJ'),
#   ('especially', 'RB'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('water', 'NN'),
#   ('sign', 'NN'),
#   ('scumman', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('rid', 'JJ'),
#   ('of', 'IN'),
#   ('cheating', 'VBG'),
#   ('husbands', 'NNS'),
#   ('but', 'CC'),
#   ('unfortunately', 'RB'),
#   ('not', 'RB'),
#   ('many', 'JJ'),
#   ('men', 'NNS'),
#   ('have', 'VBP'),
#   ('this', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('awareness', 'NN')],
#  [('i', 'NN'),
#   ('think', 'VBP'),
#   ('it', 'PRP'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('shown', 'VBN'),
#   ('on', 'IN'),
#   ('christmas', 'NN'),
#   ('day', 'NN'),
#   ('buy', 'VB'),
#   ('a', 'DT'),
#   ('warm', 'JJ'),
#   ('ginger', 'NN'),
#   ('coffee', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('s', 'JJ'),
#   ('grandpa', 'NN'),
#   ('movies', 'NNS'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('brain', 'NN'),
#   ('powder', 'NN'),
#   ('i', 'NN'),
#   ('love', 'VBP'),
#   ('the', 'DT'),
#   ('warm', 'NN'),
#   ('and', 'CC'),
#   ('bright', 'JJ'),
#   ('images', 'NNS'),
#   ('of', 'IN'),
#   ('new', 'JJ'),
#   ('york', 'NN'),
#   ('comedy', 'NN'),
#   ('movies', 'NNS'),
#   ('unburdened', 'VBD'),
#   ('circumstances', 'NNS')],
#  [('warm', 'JJ'),
#   ('inspiring', 'NN'),
#   ('and', 'CC'),
#   ('humorous', 'JJ'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('high', 'JJ'),
#   ('degree', 'NN'),
#   ('of', 'IN'),
#   ('completion', 'NN'),
#   ('i', 'NN'),
#   ('also', 'RB'),
#   ('like', 'IN'),
#   ('anna', 'NN'),
#   ('s', 'NN'),
#   ('dress', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('exemplary', 'NN'),
#   ('of', 'IN'),
#   ('working', 'VBG'),
#   ('women', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('eastern', 'JJ'),
#   ('united', 'JJ'),
#   ('states', 'NNS')],
#  [('clothing', 'NN'),
#   ('and', 'CC'),
#   ('interior', 'JJ'),
#   ('design', 'NN'),
#   ('guidelines', 'NNS'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('is', 'VBZ'),
#   ('more', 'RBR'),
#   ('interesting', 'JJ'),
#   ('and', 'CC'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('relationship', 'NN'),
#   ('is', 'VBZ'),
#   ('harmonious', 'JJ'),
#   ('the', 'DT'),
#   ('stereotype', 'NN'),
#   ('gradually', 'RB'),
#   ('appears', 'VBZ'),
#   ('especially', 'RB'),
#   ('the', 'DT'),
#   ('addition', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('husband', 'NN'),
#   ('character', 'NN'),
#   ('so', 'IN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('entire', 'JJ'),
#   ('film', 'NN'),
#   ('almost', 'RB'),
#   ('degenerates', 'VBZ'),
#   ('into', 'IN'),
#   ('a', 'DT'),
#   ('standardized', 'JJ'),
#   ('bad', 'JJ'),
#   ('film', 'NN')],
#  [('i', 'NN'),
#   ('thought', 'VBD'),
#   ('the', 'DT'),
#   ('intern', 'JJ'),
#   ('meant', 'NN'),
#   ('robert', 'NN'),
#   ('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('weak', 'JJ'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('such', 'JJ'),
#   ('a', 'DT'),
#   ('strongwoman', 'NN')],
#  [('a', 'DT'),
#   ('bowl', 'NN'),
#   ('full', 'JJ'),
#   ('of', 'IN'),
#   ('chicken', 'NN'),
#   ('soup', 'NN'),
#   ('i', 'NN'),
#   ('thought', 'VBD'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('were', 'VBD'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('roll', 'VB'),
#   ('the', 'DT'),
#   ('sheets', 'NNS')],
#  [('the', 'DT'),
#   ('textbook', 'NN'),
#   ('chicken', 'NN'),
#   ('film', 'NN'),
#   ('seriously', 'RB'),
#   ('hathaway', 'RB'),
#   ('playing', 'VBG'),
#   ('a', 'DT'),
#   ('feminist', 'JJ'),
#   ('figure', 'NN'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('place', 'NN'),
#   ('is', 'VBZ'),
#   ('being', 'VBG'),
#   ('taught', 'VBN'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('daddy', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('really', 'RB'),
#   ('okay', 'VB')],
#  [('three', 'CD'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('half', 'JJ'),
#   ('stars', 'NNS'),
#   ('i', 'RB'),
#   ('watched', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('for', 'IN'),
#   ('robert', 'NN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('this', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('american', 'JJ'),
#   ('feminine', 'JJ'),
#   ('inspirational', 'JJ'),
#   ('film', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('really', 'RB'),
#   ('my', 'PRP$'),
#   ('thing', 'NN')],
#  [('very', 'RB'),
#   ('warm', 'JJ'),
#   ('fairy', 'NN'),
#   ('tale', 'NN'),
#   ('wind', 'NN'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('feel', 'VB'),
#   ('long', 'RB'),
#   ('the', 'DT'),
#   ('background', 'NN'),
#   ('music', 'NN'),
#   ('has', 'VBZ'),
#   ('always', 'RB'),
#   ('been', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('similar', 'JJ'),
#   ('tone', 'NN'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('monotonous', 'JJ'),
#   ('princess', 'NN'),
#   ('ann', 'NN'),
#   ('plays', 'VBZ'),
#   ('the', 'DT'),
#   ('boss', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('an', 'DT'),
#   ('assistant', 'NN'),
#   ('feeling', 'VBG'),
#   ('drunk', 'JJ'),
#   ('women', 'NNS'),
#   ('s', 'JJ'),
#   ('rights', 'NNS'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('superficial', 'JJ'),
#   ('the', 'DT'),
#   ('godfather', 'NN'),
#   ('is', 'VBZ'),
#   ('cute', 'JJ')],
#  [('i', 'NN'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('confusing', 'VBG'),
#   ('moments', 'NNS'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('years', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('times', 'NNS'),
#   ('i', 'VBP'),
#   ('naturally', 'RB'),
#   ('thought', 'VBN'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('dad', 'NN'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'VB'),
#   ('found', 'VBD'),
#   ('out', 'IN'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('just', 'RB'),
#   ('wanted', 'VBD'),
#   ('me', 'PRP'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('my', 'PRP$'),
#   ('hometown', 'NN'),
#   ('and', 'CC'),
#   ('work', 'NN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('civil', 'JJ'),
#   ('servant', 'NN'),
#   ('movies', 'NNS'),
#   ('are', 'VBP'),
#   ('movies', 'NNS'),
#   ('reality', 'NN'),
#   ('is', 'VBZ'),
#   ('reality', 'NN'),
#   ('this', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('feminine', 'NN'),
#   ('color', 'NN'),
#   ('allows', 'VBZ'),
#   ('women', 'NNS'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('sufficient', 'JJ'),
#   ('lewd', 'JJ'),
#   ('space', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('subject', 'JJ'),
#   ('matter', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('of', 'IN'),
#   ('bj', 'NN'),
#   ('has', 'VBZ'),
#   ('not', 'RB'),
#   ('gone', 'VBN'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('fashion', 'NN'),
#   ('indeed', 'RB')],
#  [('even', 'RB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('find', 'VBP'),
#   ('the', 'DT'),
#   ('ultimate', 'JJ'),
#   ('handsome', 'NN'),
#   ('guy', 'NN'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('you', 'PRP'),
#   ('end', 'VBP'),
#   ('up', 'RP'),
#   ('on', 'IN'),
#   ('your', 'PRP$'),
#   ('own', 'JJ')],
#  [('politically', 'RB'),
#   ('correct', 'JJ'),
#   ('interesting', 'JJ'),
#   ('material', 'NN'),
#   ('selection', 'NN'),
#   ('strong', 'JJ'),
#   ('cas', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('full', 'JJ'),
#   ('of', 'IN'),
#   ('embarrassment', 'NN'),
#   ('and', 'CC'),
#   ('helplessness', 'JJ'),
#   ('apart', 'RB'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('weak', 'JJ'),
#   ('tension', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('mainline', 'NN'),
#   ('drama', 'VBZ'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('s', 'VBZ'),
#   ('boring', 'JJ'),
#   ('personality', 'NN'),
#   ('the', 'DT'),
#   ('loose', 'JJ'),
#   ('narrative', 'JJ'),
#   ('the', 'DT'),
#   ('protagonist', 'NN'),
#   ('s', 'JJ'),
#   ('lack', 'NN'),
#   ('of', 'IN'),
#   ('chemistry', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('that', 'IN'),
#   ('holm', 'NN'),
#   ('is', 'VBZ'),
#   ('blind', 'IN'),
#   ('the', 'DT'),
#   ('office', 'NN'),
#   ('they', 'PRP'),
#   ('live', 'VBP'),
#   ('in', 'IN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('much', 'JJ'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('model', 'NN'),
#   ('house', 'NN'),
#   ('hotel', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('no', 'DT'),
#   ('use', 'NN'),
#   ('looking', 'VBG'),
#   ('at', 'IN'),
#   ('it', 'PRP'),
#   ('annie', 'RB'),
#   ('started', 'VBD'),
#   ('the', 'DT'),
#   ('fashion', 'NN'),
#   ('show', 'NN'),
#   ('again', 'RB'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('clothes', 'NNS'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('match', 'VB'),
#   ('too', 'RB'),
#   ('well', 'RB')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('too', 'RB'),
#   ('good', 'JJ'),
#   ('but', 'CC'),
#   ('i', 'JJ'),
#   ('am', 'VBP'),
#   ('done', 'VBN'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('chicken', 'NN'),
#   ('soup', 'NN')],
#  [('over', 'IN'),
#   ('the', 'DT'),
#   ('years', 'NNS'),
#   ('the', 'DT'),
#   ('dress', 'NN'),
#   ('has', 'VBZ'),
#   ('changed', 'VBN'),
#   ('from', 'IN'),
#   ('msixty', 'NN'),
#   ('five', 'CD'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('high', 'JJ'),
#   ('end', 'NN'),
#   ('suit', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('walking', 'NN'),
#   ('posture', 'NN'),
#   ('has', 'VBZ'),
#   ('not', 'RB'),
#   ('changed', 'VBN'),
#   ('at', 'IN'),
#   ('all', 'DT')],
#  [('drink', 'VB'),
#   ('chicken', 'VBN'),
#   ('soup', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('identify', 'VB'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('and', 'CC'),
#   ('anne', 'VB'),
#   ('hathaway', 'JJR'),
#   ('brands', 'NNS')],
#  [('easy', 'JJ'),
#   ('and', 'CC'),
#   ('effortless', 'JJ'),
#   ('comedy', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('grandfather', 'FW'),
#   ('super', 'JJR'),
#   ('cute', 'NN'),
#   ('hathaway', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('beautiful', 'JJ'),
#   ('glittering', 'NN'),
#   ('after', 'IN'),
#   ('watching', 'VBG'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('person', 'NN'),
#   ('feel', 'VB'),
#   ('very', 'RB'),
#   ('happy', 'JJ')],
#  [('ahahahahahahahahaha', 'NN'),
#   ('ben', 'NN'),
#   ('told', 'VBD'),
#   ('jules', 'NNS'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('inner', 'JJ'),
#   ('peace', 'NN'),
#   ('bridge', 'NN'),
#   ('when', 'WRB'),
#   ('playing', 'VBG'),
#   ('taiji', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('tribute', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('kung', 'NN'),
#   ('fu', 'NN'),
#   ('panda', 'NN')],
#  [('i', 'RB'), ('wanted', 'VBD'), ('four', 'CD'), ('stars', 'NNS')],
#  [('it', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('standard', 'JJ'),
#   ('hollywood', 'NN'),
#   ('movie', 'NN'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('ended', 'VBD'),
#   ('with', 'IN'),
#   ('hathaway', 'NN'),
#   ('and', 'CC'),
#   ('scumboy', 'NN'),
#   ('taking', 'VBG'),
#   ('a', 'DT'),
#   ('point', 'NN'),
#   ('off', 'RP')],
#  [('late', 'JJ'), ('life', 'NN'), ('in', 'IN'), ('corleone', 'NN')],
#  [('the', 'DT'),
#   ('content', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('in', 'IN'),
#   ('line', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('trend', 'NN'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('actually', 'RB'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('those', 'DT'),
#   ('movies', 'NNS'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('basically', 'RB'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('touch', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('times', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('screenwriter', 'NN'),
#   ('s', 'NN'),
#   ('total', 'JJ'),
#   ('failure', 'NN'),
#   ('to', 'TO'),
#   ('create', 'VB'),
#   ('a', 'DT'),
#   ('conflict', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('hot', 'JJ'),
#   ('pot', 'NN'),
#   ('of', 'IN'),
#   ('sugar', 'NN'),
#   ('water', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('happiness', 'JJ'),
#   ('to', 'TO'),
#   ('cherish', 'VB'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('now', 'RB'),
#   ('because', 'IN'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('now', 'RB'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ('will', 'MD'),
#   ('lose', 'VB'),
#   ('it', 'PRP'),
#   ('do', 'VB'),
#   ('what', 'WP'),
#   ('you', 'PRP'),
#   ('like', 'VBP'),
#   ('stick', 'JJ'),
#   ('to', 'TO'),
#   ('your', 'PRP$'),
#   ('original', 'JJ'),
#   ('self', 'NN'),
#   ('and', 'CC'),
#   ('treat', 'JJ'),
#   ('life', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('tolerant', 'JJ'),
#   ('heart', 'NN')],
#  [('walking', 'VBG'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('edge', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('strange', 'JJ'),
#   ('feeling', 'NN')],
#  [('the', 'DT'),
#   ('problem', 'NN'),
#   ('is', 'VBZ'),
#   ('both', 'DT'),
#   ('at', 'IN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('s', 'JJ'),
#   ('age', 'NN'),
#   ('in', 'IN'),
#   ('many', 'JJ'),
#   ('scenes', 'NNS'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('s', 'VB'),
#   ('young', 'JJ'),
#   ('employees', 'NNS'),
#   ('he', 'PRP'),
#   ('showed', 'VBD'),
#   ('obvious', 'JJ'),
#   ('fatigue', 'NN'),
#   ('and', 'CC'),
#   ('perfunctory', 'NN'),
#   ('what', 'WP'),
#   ('is', 'VBZ'),
#   ('more', 'JJR'),
#   ('his', 'PRP$'),
#   ('performance', 'NN'),
#   ('style', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('suitable', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('appearance', 'NN'),
#   ('of', 'IN'),
#   ('external', 'JJ'),
#   ('charm', 'NN'),
#   ('to', 'TO'),
#   ('show', 'VB'),
#   ('comedy', 'NN'),
#   ('touch', 'IN'),
#   ('the', 'DT'),
#   ('script', 'NN'),
#   ('was', 'VBD'),
#   ('imposing', 'VBG'),
#   ('a', 'DT'),
#   ('charismatic', 'JJ'),
#   ('aura', 'NN'),
#   ('of', 'IN'),
#   ('goodwill', 'NN'),
#   ('on', 'IN'),
#   ('him', 'PRP'),
#   ('making', 'VBG'),
#   ('him', 'PRP'),
#   ('quickly', 'RB'),
#   ('the', 'DT'),
#   ('focus', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('s', 'JJ'),
#   ('attention', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('audience', 'NN'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('really', 'RB'),
#   ('feel', 'VB'),
#   ('why', 'WRB'),
#   ('it', 'PRP'),
#   ('should', 'MD'),
#   ('be', 'VB')],
#  [('blinking', 'VBG'),
#   ('acting', 'VBG'),
#   ('high', 'JJ'),
#   ('end', 'NN'),
#   ('atmospheric', 'JJ'),
#   ('why', 'WRB'),
#   ('travel', 'NN'),
#   ('to', 'TO'),
#   ('create', 'VB'),
#   ('some', 'DT'),
#   ('ambiguous', 'JJ'),
#   ('suspense', 'NN'),
#   ('afraid', 'NN'),
#   ('of', 'IN'),
#   ('embarrassment', 'NN'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('nervous', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('to', 'TO'),
#   ('feel', 'VB'),
#   ('the', 'DT'),
#   ('progress', 'NN'),
#   ('of', 'IN'),
#   ('society', 'NN')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('from', 'IN'),
#   ('assistant', 'NN'),
#   ('to', 'TO'),
#   ('boss', 'NN'),
#   ('is', 'VBZ'),
#   ('still', 'RB'),
#   ('wearing', 'VBG'),
#   ('that', 'IN'),
#   ('navy', 'JJ'),
#   ('sweater', 'NN')],
#  [('rather', 'RB'),
#   ('than', 'IN'),
#   ('being', 'VBG'),
#   ('more', 'JJR'),
#   ('mediocre', 'NN'),
#   ('than', 'IN'),
#   ('expected', 'VBN'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('completely', 'RB'),
#   ('off', 'IN'),
#   ('the', 'DT'),
#   ('mark', 'NN'),
#   ('you', 'PRP'),
#   ('know', 'VBP'),
#   ('what', 'WP')],
#  [('looking', 'VBG'),
#   ('at', 'IN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('i', 'NNS'),
#   ('really', 'RB'),
#   ('think', 'VBP'),
#   ('that', 'IN'),
#   ('when', 'WRB'),
#   ('people', 'NNS'),
#   ('get', 'VBP'),
#   ('old', 'JJ'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('character', 'NN'),
#   ('will', 'MD'),
#   ('change', 'VB'),
#   ('into', 'IN'),
#   ('a', 'DT'),
#   ('round', 'NN')],
#  [('life', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('like', 'JJ'),
#   ('playing', 'VBG'),
#   ('tai', 'NN'),
#   ('chi', 'NN'),
#   ('balancing', 'VBG'),
#   ('in', 'IN'),
#   ('one', 'CD'),
#   ('move', 'NN'),
#   ('between', 'IN'),
#   ('breathing', 'VBG'),
#   ('a', 'DT'),
#   ('warm', 'JJ'),
#   ('little', 'JJ'),
#   ('piece', 'NN'),
#   ('of', 'IN'),
#   ('life', 'NN'),
#   ('suitable', 'JJ'),
#   ('for', 'IN'),
#   ('christmas', 'NN'),
#   ('eve', 'VBP'),
#   ('to', 'TO'),
#   ('heal', 'VB'),
#   ('the', 'DT'),
#   ('mood', 'NN'),
#   ('favorite', 'NN'),
#   ('is', 'VBZ'),
#   ('ben', 'JJ'),
#   ('and', 'CC'),
#   ('austin', 'NN'),
#   ('in', 'IN'),
#   ('overtime', 'JJ'),
#   ('night', 'NN'),
#   ('conversation', 'NN'),
#   ('warm', 'JJ'),
#   ('lights', 'NNS'),
#   ('ben', 'NN'),
#   ('talked', 'VBD'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('forty', 'JJ'),
#   ('years', 'NNS'),
#   ('ago', 'RB'),
#   ('used', 'VBD'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('place', 'NN'),
#   ('brick', 'NN'),
#   ('by', 'IN'),
#   ('tile', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('paulownia', 'NN'),
#   ('trees', 'NNS'),
#   ('in', 'IN'),
#   ('front', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('window', 'NN'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('familiar', 'JJ'),
#   ('the', 'DT'),
#   ('tacit', 'JJ'),
#   ('understanding', 'NN'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('is', 'VBZ'),
#   ('quietly', 'RB'),
#   ('growing', 'VBG'),
#   ('unfortunately', 'RB'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('formal', 'JJ'),
#   ('and', 'CC'),
#   ('gentlemen', 'NNS'),
#   ('must', 'MD'),
#   ('bring', 'VB'),
#   ('handkerchiefs', 'NNS'),
#   ('when', 'WRB'),
#   ('they', 'PRP'),
#   ('go', 'VBP'),
#   ('out', 'RP')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('love', 'NN'),
#   ('grows', 'VBZ'),
#   ('up', 'RP'),
#   ('four', 'CD'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('half', 'NN'),
#   ('stars', 'VBZ'),
#   ('first', 'RB'),
#   ('he', 'PRP'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('translating', 'VBG'),
#   ('the', 'DT'),
#   ('title', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('inexplicable', 'JJ'),
#   ('hong', 'NN'),
#   ('kong', 'NN'),
#   ('name', 'NN'),
#   ('won', 'VBD'),
#   ('again', 'RB'),
#   ('old', 'JJ'),
#   ('and', 'CC'),
#   ('strong', 'JJ'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('with', 'IN'),
#   ('princess', 'NN'),
#   ('noble', 'JJ'),
#   ('couple', 'NN'),
#   ('give', 'VBP'),
#   ('you', 'PRP'),
#   ('a', 'DT'),
#   ('bowl', 'NN'),
#   ('of', 'IN'),
#   ('super', 'JJ'),
#   ('positive', 'JJ'),
#   ('energy', 'NN'),
#   ('heart', 'NN'),
#   ('chicken', 'NN'),
#   ('soup', 'NN'),
#   ('but', 'CC'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('funny', 'JJ'),
#   ('zhong', 'NN'),
#   ('want', 'VBP'),
#   ('your', 'PRP$'),
#   ('master', 'NN'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('the', 'DT'),
#   ('job', 'NN'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('steal', 'VB'),
#   ('but', 'CC'),
#   ('only', 'RB'),
#   ('to', 'TO'),
#   ('not', 'RB'),
#   ('hurt', 'VB'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('mother', 'NN'),
#   ('s', 'JJ'),
#   ('heart', 'NN'),
#   ('kind', 'NN'),
#   ('movies', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('return', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('s', 'JJ'),
#   ('eq', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('high', 'JJ'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('used', 'VBN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('work', 'NN'),
#   ('textbook', 'NN'),
#   ('how', 'WRB'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('warn', 'VB'),
#   ('the', 'DT'),
#   ('boss', 'NN'),
#   ('pay', 'NN'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('boss', 'NN'),
#   ('s', 'JJ'),
#   ('real', 'JJ'),
#   ('needs', 'NNS'),
#   ('handle', 'JJ'),
#   ('relationships', 'NNS'),
#   ('with', 'IN'),
#   ('colleagues', 'NNS'),
#   ('and', 'CC'),
#   ('do', 'VB'),
#   ('his', 'PRP$'),
#   ('job', 'NN'),
#   ('diligently', 'RB'),
#   ('etc', 'FW')],
#  [],
#  [('almost', 'RB'), ('four', 'CD'), ('stars', 'NNS')],
#  [('people', 'NNS'),
#   ('who', 'WP'),
#   ('admire', 'VBP'),
#   ('this', 'DT'),
#   ('old', 'JJ'),
#   ('habit', 'NN'),
#   ('have', 'VBP'),
#   ('achieved', 'VBN'),
#   ('something', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('secondary', 'JJ'),
#   ('industry', 'NN'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('style', 'NN'),
#   ('the', 'DT'),
#   ('play', 'NN'),
#   ('is', 'VBZ'),
#   ('written', 'VBN'),
#   ('too', 'RB'),
#   ('casually', 'RB'),
#   ('the', 'DT'),
#   ('shelves', 'NNS'),
#   ('are', 'VBP'),
#   ('well', 'RB'),
#   ('built', 'VBN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('meat', 'NN'),
#   ('inside', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('enough', 'RB'),
#   ('porcelain', 'VB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('to', 'TO'),
#   ('use', 'VB'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('service', 'NN'),
#   ('industry', 'NN'),
#   ('s', 'VBZ'),
#   ('strict', 'JJ'),
#   ('and', 'CC'),
#   ('self', 'NN'),
#   ('disciplined', 'VBN'),
#   ('executives', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('service', 'NN'),
#   ('industry', 'NN'),
#   ('to', 'TO'),
#   ('break', 'VB'),
#   ('the', 'DT'),
#   ('dogma', 'NN'),
#   ('of', 'IN'),
#   ('female', 'JJ'),
#   ('strongmen', 'NNS'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('starting', 'NN'),
#   ('point', 'NN'),
#   ('for', 'IN'),
#   ('storytelling', 'VBG')],
#  [('grandpa', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('kind', 'NN'),
#   ('and', 'CC'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('refuse', 'VB'),
#   ('others', 'NNS'),
#   ('leaving', 'VBG'),
#   ('steps', 'NNS'),
#   ('for', 'IN'),
#   ('others', 'NNS'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('and', 'CC'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('at', 'IN'),
#   ('discovering', 'VBG'),
#   ('the', 'DT'),
#   ('joy', 'NN'),
#   ('of', 'IN'),
#   ('life', 'NN')],
#  [('great', 'JJ'), ('acting', 'VBG'), ('general', 'JJ'), ('story', 'NN')],
#  [('the', 'DT'),
#   ('closest', 'JJS'),
#   ('non', 'RB'),
#   ('religious', 'JJ'),
#   ('relationship', 'NN'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('think', 'VB'),
#   ('of', 'IN'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('buried', 'VBN'),
#   ('with', 'IN'),
#   ('you', 'PRP'),
#   ('after', 'IN'),
#   ('death', 'NN'),
#   ('the', 'DT'),
#   ('visual', 'JJ'),
#   ('hardware', 'NN'),
#   ('is', 'VBZ'),
#   ('beautiful', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('much', 'RB'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('i', 'JJ'),
#   ('thought', 'VBN'),
#   ('thankfully', 'RB'),
#   ('not', 'RB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('cheesy', 'NN'),
#   ('mother', 'NN'),
#   ('daughter', 'NN'),
#   ('relationship', 'NN'),
#   ('sexism', 'NN'),
#   ('and', 'CC'),
#   ('retro', 'VB'),
#   ('era', 'NN'),
#   ('feelings', 'NNS'),
#   ('one', 'CD'),
#   ('points', 'NNS'),
#   ('out', 'IN'),
#   ('the', 'DT'),
#   ('bruises', 'NNS'),
#   ('that', 'WDT'),
#   ('have', 'VBP'),
#   ('not', 'RB'),
#   ('been', 'VBN'),
#   ('scratched', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('era', 'NN'),
#   ('one', 'NN'),
#   ('is', 'VBZ'),
#   ('involved', 'VBN'),
#   ('in', 'IN'),
#   ('nostalgia', 'JJ'),
#   ('sighs', 'NNS')],
#  [('new', 'JJ'), ('york', 'NN'), ('is', 'VBZ'), ('beautiful', 'JJ')],
#  [('the', 'DT'),
#   ('old', 'JJ'),
#   ('intern', 'JJ'),
#   ('s', 'NN'),
#   ('idea', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('standard', 'JJ'),
#   ('chick', 'NN'),
#   ('movie', 'NN'),
#   ('adds', 'VBZ'),
#   ('warmth', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('theme', 'NN'),
#   ('of', 'IN'),
#   ('female', 'JJ'),
#   ('inspiration', 'NN'),
#   ('ben', 'NN'),
#   ('completely', 'RB'),
#   ('retains', 'VBZ'),
#   ('the', 'DT'),
#   ('spirit', 'NN'),
#   ('and', 'CC'),
#   ('merits', 'NNS'),
#   ('of', 'IN'),
#   ('traditional', 'JJ'),
#   ('industries', 'NNS'),
#   ('and', 'CC'),
#   ('avoids', 'VB'),
#   ('the', 'DT'),
#   ('cost', 'NN'),
#   ('of', 'IN'),
#   ('moving', 'VBG'),
#   ('from', 'IN'),
#   ('secondary', 'JJ'),
#   ('to', 'TO'),
#   ('tertiary', 'JJ'),
#   ('industries', 'NNS'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('nice', 'JJ'),
#   ('and', 'CC'),
#   ('healing', 'NN'),
#   ('and', 'CC'),
#   ('when', 'WRB'),
#   ('ben', 'NN'),
#   ('told', 'VBD'),
#   ('his', 'PRP$'),
#   ('and', 'CC'),
#   ('his', 'PRP$'),
#   ('wife', 'NN'),
#   ('s', 'VBD'),
#   ('story', 'NN'),
#   ('not', 'RB'),
#   ('long', 'RB'),
#   ('enough', 'RB'),
#   ('to', 'TO'),
#   ('fall', 'VB'),
#   ('completely', 'RB'),
#   ('once', 'RB'),
#   ('again', 'RB'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('lament', 'VB'),
#   ('that', 'IN'),
#   ('all', 'DT'),
#   ('stories', 'NNS'),
#   ('are', 'VBP'),
#   ('romantic', 'JJ'),
#   ('as', 'RB'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('middle', 'JJ'),
#   ('class', 'NN')],
#  [('the', 'DT'),
#   ('two', 'CD'),
#   ('stars', 'NNS'),
#   ('are', 'VBP'),
#   ('well', 'RB'),
#   ('chosen', 'VBN'),
#   ('thinking', 'NN'),
#   ('of', 'IN'),
#   ('another', 'DT'),
#   ('version', 'NN'),
#   ('of', 'IN'),
#   ('queen', 'NN'),
#   ('in', 'IN'),
#   ('prada', 'NN')],
#  [('much', 'JJ'),
#   ('better', 'RBR'),
#   ('looking', 'VBG'),
#   ('than', 'IN'),
#   ('i', 'JJ'),
#   ('thought', 'VBD'),
#   ('i', 'RB'),
#   ('thought', 'VBD'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('another', 'DT'),
#   ('queen', 'NN'),
#   ('in', 'IN'),
#   ('prada', 'NN'),
#   ('who', 'WP'),
#   ('knows', 'VBZ'),
#   ('completely', 'RB'),
#   ('upside', 'JJ'),
#   ('down', 'RB'),
#   ('anne', 'RB'),
#   ('hathaway', 'JJ'),
#   ('s', 'NN'),
#   ('every', 'DT'),
#   ('outfit', 'NN'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('too', 'RB'),
#   ('good', 'JJ'),
#   ('looking', 'VBG')],
#  [('the', 'DT'),
#   ('airplane', 'NN'),
#   ('movie', 'NN'),
#   ('chicken', 'VBN'),
#   ('soup', 'NN'),
#   ('content', 'NN'),
#   ('is', 'VBZ'),
#   ('as', 'IN'),
#   ('previewed', 'VBN'),
#   ('so', 'IN'),
#   ('most', 'JJS'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
# ...
#   ('ups', 'NNS'),
#   ('and', 'CC'),
#   ('downs', 'NNS')],
#  [('two', 'CD')],
#  [('the', 'DT'),
#   ('whole', 'JJ'),
#   ('movie', 'NN'),
#   ('really', 'RB'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('have', 'VB'),
#   ('ups', 'NNS'),
#   ('and', 'CC'),
#   ('downs', 'NNS'),
#   ('although', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('does', 'VBZ'),
#   ('raise', 'VB'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('problems', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('deployment', 'NN')],
#  [('at', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('saw', 'VBD'),
#   ('an', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('high', 'JJ'),
#   ('emotional', 'JJ'),
#   ('intelligence', 'NN'),
#   ('intelligence', 'NN'),
#   ('and', 'CC'),
#   ('always', 'RB'),
#   ('watching', 'VBG'),
#   ('seventy', 'JJ'),
#   ('years', 'NNS'),
#   ('of', 'IN'),
#   ('age', 'NN'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('circle', 'NN'),
#   ('of', 'IN'),
#   ('fate', 'JJ'),
#   ('let', 'NN'),
#   ('him', 'PRP'),
#   ('return', 'VB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('factory', 'NN'),
#   ('he', 'PRP'),
#   ('has', 'VBZ'),
#   ('spent', 'VBN'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('forty', 'CD'),
#   ('years', 'NNS'),
#   ('to', 'TO'),
#   ('familiarize', 'VB'),
#   ('himself', 'PRP'),
#   ('with', 'IN'),
#   ('face', 'NN'),
#   ('a', 'DT'),
#   ('strange', 'JJ'),
#   ('new', 'JJ'),
#   ('world', 'NN'),
#   ('start', 'NN'),
#   ('working', 'VBG'),
#   ('again', 'RB'),
#   ('and', 'CC'),
#   ('start', 'VB'),
#   ('dating', 'VBG'),
#   ('again', 'RB'),
#   ('the', 'DT'),
#   ('setting', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('still', 'RB'),
#   ('intriguing', 'JJ'),
#   ('and', 'CC'),
#   ('grandpa', 'JJ'),
#   ('faces', 'VBZ'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('social', 'JJ'),
#   ('and', 'CC'),
#   ('new', 'JJ'),
#   ('job', 'NN'),
#   ('type', 'NN'),
#   ('as', 'IN'),
#   ('an', 'DT'),
#   ('intern', 'JJ'),
#   ('deployment', 'NN')],
#  [('after', 'IN'),
#   ('watching', 'VBG'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('fascinated', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('gentleman', 'NN'),
#   ('who', 'WP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('slightly', 'RB'),
#   ('antique', 'JJ'),
#   ('style', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('american', 'JJ'),
#   ('version', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('word', 'NN'),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('glad', 'NN'),
#   ('that', 'IN'),
#   ('his', 'PRP$'),
#   ('emotional', 'JJ'),
#   ('line', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('heroine', 'NN'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('vulgar', 'JJ'),
#   ('love', 'NN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   ('ambiguous', 'JJ'),
#   ('but', 'CC'),
#   ('more', 'RBR'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('father', 'NN'),
#   ('s', 'NN'),
#   ('communication', 'NN'),
#   ('with', 'IN'),
#   ('his', 'PRP$'),
#   ('daughter', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('concern', 'NN'),
#   ('between', 'IN'),
#   ('friends', 'NNS')],
#  [('then', 'RB'),
#   ('came', 'VBD'),
#   ('the', 'DT'),
#   ('gentleman', 'NN'),
#   ('s', 'VBZ'),
#   ('delightful', 'JJ'),
#   ('reason', 'NN'),
#   ('logic', 'NN'),
#   ('planning', 'NN'),
#   ('and', 'CC'),
#   ('courage', 'NN'),
#   ('and', 'CC'),
#   ('so', 'RB'),
#   ('on', 'IN'),
#   ('deployment', 'NN')],
#  [('blake', 'NN'),
#   ('snyder', 'NN'),
#   ('screenplay', 'NN'),
#   ('beatwatch', 'NN'),
#   ('title', 'NN'),
#   ('intern', 'JJ'),
#   ('genre', 'NN'),
#   ('fellowship', 'NN'),
#   ('date', 'NN'),
#   ('two', 'CD'),
#   ('thousand', 'NN'),
#   ('and', 'CC'),
#   ('twenty', 'VB'),
#   ('one', 'CD'),
#   ('pfive', 'NN'),
#   ('the', 'DT'),
#   ('male', 'JJ'),
#   ('protagonist', 'NN'),
#   ('sees', 'VBZ'),
#   ('the', 'DT'),
#   ('list', 'NN'),
#   ('of', 'IN'),
#   ('interns', 'NNS'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('said', 'VBD'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('lady', 'NN'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('understand', 'VB'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('says', 'VBZ'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('not', 'RB'),
#   ('young', 'JJ'),
#   ('anymore', 'RB'),
#   ('paving', 'VBG'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('for', 'IN'),
#   ('pone', 'NN'),
#   ('ten', 'CD'),
#   ('exhibition', 'NN'),
#   ('deployment', 'NN')],
#  [('a', 'DT'),
#   ('retired', 'JJ'),
#   ('vice', 'NN'),
#   ('president', 'NN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('start', 'NN'),
#   ('up', 'RP'),
#   ('internet', 'NN'),
#   ('company', 'NN'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('intern', 'VB'),
#   ('for', 'IN'),
#   ('female', 'JJ'),
#   ('bosses', 'NNS'),
#   ('help', 'VBP'),
#   ('young', 'JJ'),
#   ('people', 'NNS'),
#   ('find', 'VBP'),
#   ('direction', 'NN'),
#   ('in', 'IN'),
#   ('work', 'NN'),
#   ('and', 'CC'),
#   ('life', 'NN'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('their', 'PRP$'),
#   ('own', 'JJ'),
#   ('plot', 'NN'),
#   ('not', 'RB'),
#   ('too', 'RB'),
#   ('boring', 'VBG'),
#   ('her', 'PRP$'),
#   ('acting', 'NN'),
#   ('was', 'VBD'),
#   ('still', 'RB'),
#   ('unremarkable', 'JJ'),
#   ('and', 'CC'),
#   ('good', 'JJ'),
#   ('looking', 'VBG'),
#   ('but', 'CC'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('princess', 'NN'),
#   ('diaries', 'VBZ'),
#   ('the', 'DT'),
#   ('women', 'NNS'),
#   ('in', 'IN'),
#   ('prada', 'JJ'),
#   ('look', 'NN'),
#   ('deployment', 'NN')],
#  [('the', 'DT'),
#   ('clothes', 'NNS'),
#   ('you', 'PRP'),
#   ('wear', 'VBP'),
#   ('the', 'DT'),
#   ('words', 'NNS'),
#   ('you', 'PRP'),
#   ('write', 'VBP'),
#   ('the', 'DT'),
#   ('words', 'NNS'),
#   ('you', 'PRP'),
#   ('say', 'VBP'),
#   ('the', 'DT'),
#   ('food', 'NN'),
#   ('you', 'PRP'),
#   ('eat', 'VBP'),
#   ('is', 'VBZ'),
#   ('who', 'WP'),
#   ('you', 'PRP'),
#   ('are', 'VBP')],
#  [('the', 'DT'),
#   ('biggest', 'JJS'),
#   ('feeling', 'NN'),
#   ('of', 'IN'),
#   ('watching', 'VBG'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('ben', 'NN'),
#   ('always', 'RB'),
#   ('cleans', 'VBZ'),
#   ('himself', 'PRP'),
#   ('up', 'IN'),
#   ('and', 'CC'),
#   ('wears', 'VBZ'),
#   ('a', 'DT'),
#   ('suit', 'NN'),
#   ('and', 'CC'),
#   ('his', 'PRP$'),
#   ('behavior', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('subtly', 'RB'),
#   ('affecting', 'VBG'),
#   ('everyone', 'NN'),
#   ('around', 'IN'),
#   ('him', 'PRP'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('fat', 'JJ'),
#   ('little', 'JJ'),
#   ('man', 'NN'),
#   ('in', 'IN'),
#   ('his', 'PRP$'),
#   ('house', 'NN'),
#   ('and', 'CC'),
#   ('starting', 'VBG'),
#   ('to', 'TO'),
#   ('dress', 'VB'),
#   ('like', 'IN'),
#   ('him', 'PRP'),
#   ('formal', 'JJ'),
#   ('and', 'CC'),
#   ('professional', 'JJ')],
#  [('one', 'CD')],
#  [('what', 'WP'),
#   ('a', 'DT'),
#   ('person', 'NN'),
#   ('wears', 'NNS'),
#   ('and', 'CC'),
#   ('does', 'VBZ'),
#   ('is', 'VBZ'),
#   ('this', 'DT'),
#   ('deployment', 'NN')],
#  [('as', 'IN'),
#   ('a', 'DT'),
#   ('successful', 'JJ'),
#   ('senior', 'JJ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('he', 'PRP'),
#   ('has', 'VBZ'),
#   ('always', 'RB'),
#   ('been', 'VBN'),
#   ('serious', 'JJ'),
#   ('sincere', 'RB'),
#   ('humble', 'JJ'),
#   ('active', 'JJ'),
#   ('friendly', 'JJ'),
#   ('principled', 'VBN'),
#   ('and', 'CC'),
#   ('never', 'RB'),
#   ('crossed', 'VBD'),
#   ('the', 'DT'),
#   ('line', 'NN'),
#   ('i', 'NN'),
#   ('think', 'VBP'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('cultivation', 'NN'),
#   ('and', 'CC'),
#   ('wisdom', 'NN'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('worth', 'JJ'),
#   ('learning', 'VBG'),
#   ('from', 'IN'),
#   ('every', 'DT'),
#   ('workplace', 'NN'),
#   ('and', 'CC'),
#   ('helps', 'VBZ'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('integrate', 'VB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('environment', 'NN'),
#   ('and', 'CC'),
#   ('get', 'VB'),
#   ('respect', 'NN'),
#   ('from', 'IN'),
#   ('others', 'NNS'),
#   ('faster', 'RBR'),
#   ('deployment', 'NN')],
#  [('one', 'CD')],
#  [('career', 'NN'),
#   ('family', 'NN'),
#   ('elders', 'NNS'),
#   ('friends', 'VBZ'),
#   ('lovers', 'NNS'),
#   ('children', 'NNS'),
#   ('like', 'IN'),
#   ('daily', 'JJ'),
#   ('necessities', 'NNS'),
#   ('everyday', 'JJ'),
#   ('life', 'NN'),
#   ('appears', 'VBZ'),
#   ('to', 'TO'),
#   ('us', 'PRP'),
#   ('on', 'IN'),
#   ('time', 'NN'),
#   ('and', 'CC'),
#   ('only', 'RB'),
#   ('when', 'WRB'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('choices', 'NNS'),
#   ('do', 'VB'),
#   ('we', 'PRP'),
#   ('realize', 'VB'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('important', 'JJ'),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('us', 'PRP'),
#   ('sometimes', 'RB'),
#   ('choose', 'VBP'),
#   ('to', 'TO'),
#   ('forgive', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('face', 'NN'),
#   ('of', 'IN'),
#   ('betrayal', 'NN'),
#   ('and', 'CC'),
#   ('life', 'NN'),
#   ('may', 'MD'),
#   ('require', 'VB'),
#   ('us', 'PRP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('softer', 'JJR'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('surprises', 'NNS'),
#   ('everywhere', 'RB'),
#   ('in', 'IN'),
#   ('life', 'NN'),
#   ('as', 'RB'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('out', 'RP'),
#   ('and', 'CC'),
#   ('experience', 'VB'),
#   ('it', 'PRP'),
#   ('no', 'DT'),
#   ('time', 'NN'),
#   ('deployment', 'NN')],
#  [('after', 'IN'),
#   ('work', 'NN'),
#   ('i', 'RB'),
#   ('watched', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('s', 'NN'),
#   ('delicate', 'NN'),
#   ('and', 'CC'),
#   ('elegant', 'JJ'),
#   ('clothes', 'NNS'),
#   ('make', 'VBP'),
#   ('me', 'PRP'),
#   ('feel', 'VB'),
#   ('comfortable', 'JJ'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('spring', 'NN'),
#   ('breeze', 'NN'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('later', 'RB'),
#   ('the', 'DT'),
#   ('old', 'JJ'),
#   ('man', 'NN'),
#   ('is', 'VBZ'),
#   ('always', 'RB'),
#   ('elegant', 'JJ'),
#   ('always', 'RB'),
#   ('enthusiastic', 'JJ'),
#   ('always', 'RB'),
#   ('positive', 'JJ'),
#   ('warm', 'NN'),
#   ('but', 'CC'),
#   ('wise', 'NN'),
#   ('always', 'RB'),
#   ('talk', 'VB'),
#   ('forever', 'RB'),
#   ('deployment', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('may', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('spoiler', 'NN')],
#  [('demonstrate', 'NN'),
#   ('that', 'WDT'),
#   ('competence', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('transferred', 'VBN')],
#  [('in', 'IN'),
#   ('his', 'PRP$'),
#   ('last', 'JJ'),
#   ('job', 'NN'),
#   ('he', 'PRP'),
#   ('took', 'VBD'),
#   ('the', 'DT'),
#   ('position', 'NN'),
#   ('of', 'IN'),
#   ('vice', 'NN'),
#   ('president', 'NN')],
#  [('he', 'PRP'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('vice', 'NN'),
#   ('presidential', 'JJ'),
#   ('level', 'NN'),
#   ('from', 'IN'),
#   ('his', 'PRP$'),
#   ('back', 'NN'),
#   ('as', 'IN'),
#   ('an', 'DT'),
#   ('intern', 'JJ'),
#   ('the', 'DT'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('seen', 'VBN'),
#   ('in', 'IN'),
#   ('his', 'PRP$'),
#   ('characteristics', 'NNS'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('worth', 'JJ'),
#   ('learning', 'VBG'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('and', 'CC'),
#   ('even', 'RB'),
#   ('a', 'DT'),
#   ('veteran', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('workplace', 'NN'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('try', 'VB'),
#   ('new', 'JJ'),
#   ('things', 'NNS'),
#   ('embrace', 'NN'),
#   ('challenges', 'VBZ'),
#   ('seventy', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   ('still', 'RB'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('learn', 'VB'),
#   ('the', 'DT'),
#   ('internet', 'NN'),
#   ('deployment', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('has', 'VBZ'),
#   ('too', 'RB'),
#   ('much', 'JJ'),
#   ('conversational', 'JJ'),
#   ('art', 'NN'),
#   ('to', 'TO'),
#   ('record', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('don', 'NN'),
#   ('s', 'JJ'),
#   ('life', 'NN'),
#   ('state', 'NN'),
#   ('should', 'MD'),
#   ('be', 'VB'),
#   ('what', 'WP'),
#   ('most', 'JJS'),
#   ('people', 'NNS'),
#   ('aspire', 'VBP'),
#   ('to', 'TO')],
#  [('the', 'DT'),
#   ('don', 'NN'),
#   ('first', 'RB'),
#   ('asks', 'VBZ'),
#   ('his', 'PRP$'),
#   ('assistant', 'NN'),
#   ('what', 'WP'),
#   ('to', 'TO'),
#   ('pay', 'VB'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('before', 'IN'),
#   ('he', 'PRP'),
#   ('sees', 'VBZ'),
#   ('her', 'PRP$'),
#   ('boss', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('driver', 'NN'),
#   ('who', 'WP'),
#   ('drinks', 'VBZ'),
#   ('but', 'CC'),
#   ('still', 'RB'),
#   ('gives', 'VBZ'),
#   ('him', 'PRP'),
#   ('two', 'CD'),
#   ('choices', 'NNS'),
#   ('deployment', 'NN')],
#  [('a', 'DT'),
#   ('movie', 'NN'),
#   ('that', 'WDT'),
#   ('makes', 'VBZ'),
#   ('me', 'PRP'),
#   ('very', 'RB'),
#   ('comfortable', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('in', 'IN'),
#   ('particular', 'JJ'),
#   ('most', 'JJS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('relaxed', 'VBD'),
#   ('small', 'JJ'),
#   ('humor', 'NN'),
#   ('let', 'VB'),
#   ('me', 'PRP'),
#   ('almost', 'RB'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('mouth', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('time', 'NN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('main', 'JJ'),
#   ('characters', 'NNS'),
#   ('acting', 'VBG'),
#   ('is', 'VBZ'),
#   ('natural', 'JJ'),
#   ('sincere', 'RB'),
#   ('not', 'RB'),
#   ('flamboyant', 'JJ'),
#   ('and', 'CC'),
#   ('true', 'JJ'),
#   ('feelings', 'NNS'),
#   ('are', 'VBP'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('play', 'NN'),
#   ('deployment', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('may', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('spoiler', 'NN')],
#  [('as', 'IN'),
#   ('an', 'DT'),
#   ('american', 'JJ'),
#   ('light', 'NN'),
#   ('comedy', 'NN'),
#   ('film', 'NN'),
#   ('intern', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('variety', 'NN'),
#   ('of', 'IN'),
#   ('routines', 'NNS'),
#   ('the', 'DT'),
#   ('perfect', 'JJ'),
#   ('plot', 'NN'),
#   ('direction', 'NN'),
#   ('familiar', 'JJ'),
#   ('comedy', 'NN'),
#   ('plot', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('well', 'RB'),
#   ('known', 'VBN'),
#   ('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('as', 'IN'),
#   ('anyone', 'NN'),
#   ('who', 'WP'),
#   ('is', 'VBZ'),
#   ('seen', 'VBN'),
#   ('it', 'PRP'),
#   ('knows', 'VBZ'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('perfect', 'JJ'),
#   ('story', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('inspired', 'VBN'),
#   ('by', 'IN'),
#   ('just', 'RB'),
#   ('one', 'CD'),
#   ('idea', 'NN'),
#   ('throughout', 'IN'),
#   ('many', 'JJ'),
#   ('films', 'NNS'),
#   ('few', 'JJ'),
#   ('films', 'NNS'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('such', 'JJ'),
#   ('perfect', 'JJ'),
#   ('success', 'NN')],
#  [('at', 'IN'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('show', 'NN'),
#   ('many', 'JJ'),
#   ('people', 'NNS'),
#   ('were', 'VBD'),
#   ('not', 'RB'),
#   ('deployment', 'JJ')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('may', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('spoiler', 'NN')],
#  [('ben', 'RB'),
#   ('nearly', 'RB'),
#   ('seventy', 'NN'),
#   ('joined', 'VBD'),
#   ('the', 'DT'),
#   ('internet', 'NN'),
#   ('company', 'NN'),
#   ('as', 'IN'),
#   ('an', 'DT'),
#   ('intern', 'NN'),
#   ('a', 'DT'),
#   ('workplace', 'NN'),
#   ('story', 'NN'),
#   ('that', 'WDT'),
#   ('took', 'VBD'),
#   ('place', 'NN'),
#   ('between', 'IN'),
#   ('him', 'PRP'),
#   ('and', 'CC'),
#   ('founder', 'NN'),
#   ('jules', 'NNS'),
#   ('ben', 'NN'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('admirable', 'JJ'),
#   ('mature', 'NN'),
#   ('gentleman', 'NN'),
#   ('and', 'CC'),
#   ('his', 'PRP$'),
#   ('attitude', 'NN'),
#   ('and', 'CC'),
#   ('spirit', 'NN'),
#   ('of', 'IN'),
#   ('life', 'NN'),
#   ('have', 'VBP'),
#   ('inspired', 'VBN'),
#   ('me', 'PRP'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('and', 'CC'),
#   ('that', 'DT'),
#   ('is', 'VBZ'),
#   ('probably', 'RB'),
#   ('what', 'WP'),
#   ('i', 'VBZ'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('balanced', 'JJ'),
#   ('influential', 'JJ'),
#   ('person', 'NN')],
#  ...]

# %%
nltk.download('tagsets')
nltk.help.upenn_tagset('WRB')
# Out:
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# [nltk_data] Downloading package tagsets to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Remove IN, PRP, CC, PRP$, DT, TO, FW, WP
def remove_specific_tags(tagged_sentence, tags_to_remove):
    return [word for word, tag in tagged_sentence if tag not in tags_to_remove]

tags_to_remove = {"IN", "PRP", "CC", "PRP$", "DT", "TO", "FW", "WP", "WRB"}

tag_rm = tag_sentence.copy()
tag_rm = [remove_specific_tags(text, tags_to_remove) for text in tag_rm]

# %%
tag_rm_sentence = [pos_tag(sentence) for sentence in tag_rm]
tag_rm_sentence[:5]
# Out:
# [[('even', 'RB'),
#   ('such', 'JJ'),
#   ('beautiful', 'JJ'),
#   ('successful', 'JJ'),
#   ('woman', 'NN'),
#   ('american', 'JJ'),
#   ('movies', 'NNS'),
#   ('has', 'VBZ'),
#   ('accept', 'NNS'),
#   ('such', 'JJ'),
#   ('ordinary', 'JJ'),
#   ('cheating', 'NN'),
#   ('husband', 'NN')],
#  [('depends', 'NNS'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('looked', 'VBD'),
#   ('good', 'JJ'),
#   ('second', 'JJ'),
#   ('half', 'NN'),
#   ('values', 'NNS'),
#   ('swallowed', 'VBD'),
#   ('conservative', 'JJ'),
#   ('retreated', 'JJ'),
#   ('s', 'NN'),
#   ('people', 'NNS'),
#   ('are', 'VBP'),
#   ('little', 'JJ'),
#   ('too', 'RB'),
#   ('perfect', 'JJ')],
#  [('world', 'NN'),
#   ('will', 'MD'),
#   ('be', 'VB'),
#   ('better', 'JJR'),
#   ('place', 'NN'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('make', 'VB'),
#   ('one', 'CD'),
#   ('two', 'CD'),
#   ('such', 'JJ'),
#   ('warm', 'JJ'),
#   ('skits', 'NNS'),
#   ('year', 'NN'),
#   ('look', 'VBP'),
#   ('good', 'JJ'),
#   ('release', 'NN'),
#   ('tears', 'NNS')],
#  [('hathaway', 'NN'),
#   ('intervened', 'VBD'),
#   ('streep', 'JJ'),
#   ('s', 'NN'),
#   ('strongwoman', 'JJ'),
#   ('life', 'NN'),
#   ('now', 'RB'),
#   ('de', 'VBZ'),
#   ('anti', 'JJ'),
#   ('invasion', 'NN'),
#   ('hathaway', 'NN'),
#   ('life', 'NN'),
#   ('actually', 'RB'),
#   ('little', 'JJ'),
#   ('ambitious', 'JJ'),
#   ('trying', 'VBG'),
#   ('discuss', 'JJ'),
#   ('career', 'NN'),
#   ('women', 'NNS'),
#   ('older', 'JJR'),
#   ('generation', 'NN'),
#   ('floating', 'VBG'),
#   ('bit', 'NN'),
#   ('i', 'JJ'),
#   ('hathaway', 'NN'),
#   ('lot', 'NN'),
#   ('little', 'JJ'),
#   ('expression', 'NN'),
#   ('has', 'VBZ'),
#   ('sense', 'VBN'),
#   ('rehearsal', 'JJ'),
#   ('release', 'NN'),
#   ('especially', 'RB'),
#   ('compared', 'VBN'),
#   ('de', 'IN'),
#   ('share', 'NN'),
#   ('de', 'FW'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('handsome', 'JJ')],
#  [('is', 'VBZ'),
#   ('been', 'VBN'),
#   ('long', 'JJ'),
#   ('time', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('princess', 'JJ'),
#   ('anne', 'JJ'),
#   ('movie', 'NN'),
#   ('feels', 'NNS'),
#   ('especially', 'RB'),
#   ('fashion', 'NN'),
#   ('witch', 'NN'),
#   ('has', 'VBZ'),
#   ('set', 'VBN'),
#   ('bar', 'NN'),
#   ('so', 'RB'),
#   ('high', 'JJ'),
#   ('professional', 'JJ'),
#   ('women', 'NNS'),
#   ('young', 'JJ'),
#   ('people', 'NNS'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('too', 'RB'),
#   ('warm', 'JJ'),
#   ('mediocre', 'NN')]]

# %%
# Lemmatize & remove stopwords

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import wordnet as wn

nltk.download('wordnet')

# inflect engine initialize
p = inflect.engine()

# WordNetLemmatizer initialize
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wn.ADJ
    elif treebank_tag.startswith('V'):
        return wn.VERB
    elif treebank_tag.startswith('N'):
        return wn.NOUN
    elif treebank_tag.startswith('R'):
        return wn.ADV
    else:
        return None

def singularize_and_lemmatize(tagged_words):
    new_words = []
    
    for word, tag in tagged_words:
        if tag.startswith('N'):
            singular_word = p.singular_noun(word)
            if singular_word:
                new_words.append(singular_word)
            else:
                new_words.append(word)
        else:
            wn_tag = get_wordnet_pos(tag)
            if wn_tag is not None:
                lemma_word = lemmatizer.lemmatize(word, wn_tag)
                new_words.append(lemma_word)
            else:
                new_words.append(word)
    
    return new_words
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
processed_sentences = [singularize_and_lemmatize(sentence) for sentence in tag_rm_sentence]

# %%
processed_sentences
# Out:
# [['even',
#   'such',
#   'beautiful',
#   'successful',
#   'woman',
#   'american',
#   'movie',
#   'have',
#   'accept',
#   'such',
#   'ordinary',
#   'cheating',
#   'husband'],
#  ['depend',
#   'first',
#   'half',
#   'look',
#   'good',
#   'second',
#   'half',
#   'value',
#   'swallow',
#   'conservative',
#   'retreated',
#   's',
#   'person',
#   'be',
#   'little',
#   'too',
#   'perfect'],
#  ['world',
#   'will',
#   'be',
#   'good',
#   'place',
#   'i',
#   'can',
#   'make',
#   'one',
#   'two',
#   'such',
#   'warm',
#   'skit',
#   'year',
#   'look',
#   'good',
#   'release',
#   'tear'],
#  ['hathaway',
#   'intervene',
#   'streep',
#   's',
#   'strongwoman',
#   'life',
#   'now',
#   'de',
#   'anti',
#   'invasion',
#   'hathaway',
#   'life',
#   'actually',
#   'little',
#   'ambitious',
#   'try',
#   'discuss',
#   'career',
#   'woman',
#   'old',
#   'generation',
#   'float',
#   'bit',
#   'i',
#   'hathaway',
#   'lot',
#   'little',
#   'expression',
#   'have',
#   'sense',
#   'rehearsal',
#   'release',
#   'especially',
#   'compare',
#   'de',
#   'share',
#   'de',
#   'be',
#   'really',
#   'handsome'],
#  ['be',
#   'be',
#   'long',
#   'time',
#   'i',
#   'have',
#   'see',
#   'princess',
#   'anne',
#   'movie',
#   'feel',
#   'especially',
#   'fashion',
#   'witch',
#   'have',
#   'set',
#   'bar',
#   'so',
#   'high',
#   'professional',
#   'woman',
#   'young',
#   'person',
#   'be',
#   'also',
#   'too',
#   'warm',
#   'mediocre'],
#  ['bad',
#   'thing',
#   'act',
#   'bone',
#   'play',
#   'be',
#   'be',
#   'not',
#   'good',
#   'enough',
#   'play',
#   'be',
#   'eat',
#   'up',
#   'other',
#   'party'],
#  ['anne', 'hathaway', 'look', 'great'],
#  ['freshly',
#   'hold',
#   'laughter',
#   'detail',
#   'tap',
#   'word',
#   'massage',
#   'will',
#   'be',
#   'hard',
#   'thunder',
#   'snore',
#   'lifetime',
#   'experience',
#   'old',
#   'ginger',
#   'matter',
#   'high',
#   'academic',
#   'qualification',
#   'also',
#   'need',
#   'get',
#   'job',
#   'recognition',
#   'find',
#   'rare',
#   'modern',
#   'gentleman',
#   'manner',
#   'meyer',
#   'can',
#   'always',
#   'take',
#   'good',
#   'picture',
#   'vulgar',
#   'subject',
#   'matter',
#   'favorite',
#   'chick',
#   'flick',
#   'director'],
#  ['hopefully',
#   'be',
#   'just',
#   'momentary',
#   'misjudgment',
#   'not',
#   'love',
#   'joy',
#   'be',
#   'deserve',
#   'slow',
#   'down',
#   'enjoy',
#   'life',
#   'tai',
#   'chi'],
#  ['encounter',
#   'angel',
#   'high',
#   'emotional',
#   'intelligence',
#   'sweetheart',
#   'brooklyn',
#   'geniu',
#   'be',
#   'rub',
#   'japanese',
#   'style',
#   'warm',
#   'serenade',
#   'homage',
#   'back',
#   'back',
#   'soundtrack',
#   'be',
#   'fight',
#   'off',
#   'gloom',
#   'thirty',
#   'year',
#   'old',
#   'crisi',
#   'jule',
#   'be',
#   'future',
#   'ben',
#   'be',
#   'one',
#   'own',
#   'world',
#   'that',
#   'be',
#   'most',
#   'beautiful',
#   'thing',
#   'life'],
#  ['hathaway',
#   's',
#   'point',
#   'view',
#   'do',
#   'not',
#   'want',
#   'be',
#   'able',
#   'have',
#   'old',
#   'man',
#   'have',
#   'experience',
#   'hardship',
#   'life',
#   'content',
#   'guidance',
#   'be',
#   'actually',
#   'show',
#   'begin',
#   'end',
#   'taijiquan',
#   'slow',
#   'slow',
#   'slow'],
#  ['good',
#   'observation',
#   'not',
#   'humble',
#   'warm',
#   'courteous',
#   'advice',
#   'never',
#   'cross',
#   'line',
#   'principled',
#   'interesting',
#   'rich',
#   'experience',
#   'never',
#   'show',
#   'off',
#   'do',
#   'thing',
#   'properly',
#   'ben',
#   'be',
#   'nearly',
#   'seventy',
#   'year',
#   'old',
#   'model',
#   'generation',
#   'movie',
#   'also',
#   'saw',
#   's',
#   'old',
#   'age',
#   'calm',
#   'intelligent',
#   'side',
#   'be',
#   'really',
#   'powerful',
#   'play',
#   'god',
#   'seven',
#   'six'],
#  ['year',
#   'half',
#   'e',
#   'commerce',
#   'woman',
#   'can',
#   'run',
#   'business',
#   'man',
#   'can',
#   'be',
#   'domestic',
#   'man',
#   'new',
#   'person',
#   'workplace',
#   'be',
#   'no',
#   'longer',
#   'synonymous',
#   'early',
#   'twenty',
#   'can',
#   'still',
#   'work',
#   'interns',
#   'age',
#   'seventy',
#   'be',
#   'time',
#   'gender',
#   'age',
#   'be',
#   'downplay',
#   'as',
#   'long',
#   'have',
#   'healthy',
#   'body',
#   'positive',
#   'mind',
#   'anything',
#   'be',
#   'possible',
#   'very',
#   'warm',
#   'film',
#   'annie',
#   's',
#   'clothe',
#   'look',
#   'great'],
#  ['niro', 'be', 'so', 'warm', 'felt', 'tendernes', 'nobility', 'screen'],
#  ['be', 'cold', 'drink', 'chicken', 'soup', 'driver', 's', 'fan', 'disappear'],
#  ['more',
#   'standard',
#   'chicken',
#   'flick',
#   'three',
#   'view',
#   'humor',
#   'famous',
#   'character',
#   'most',
#   'important',
#   'thing',
#   'be',
#   'have'],
#  ['case',
#   'development',
#   'chuck',
#   'flick',
#   'love',
#   'not',
#   'sacrifice',
#   'career',
#   'family',
#   'be',
#   'huge',
#   'social',
#   'progres'],
#  ['robert', 'be', 'grandpa', 'fly', 'house'],
#  ['novelty',
#   'film',
#   'lie',
#   'balance',
#   'balance',
#   'seventy',
#   'year',
#   'old',
#   'face',
#   'up',
#   'own',
#   'social',
#   'status',
#   'quo',
#   'do',
#   'not',
#   'rely',
#   'old',
#   'sell',
#   'old',
#   'do',
#   'not',
#   'emphasize',
#   'past',
#   'silently',
#   'rely',
#   'own',
#   'experience',
#   'help',
#   'young',
#   'person',
#   'continue',
#   'achieve',
#   'own',
#   'value',
#   'thirty',
#   'year',
#   'old',
#   'gradually',
#   'learn',
#   'balance',
#   'everything',
#   'life',
#   'not',
#   'run',
#   'away',
#   'problem',
#   'marriage',
#   'not',
#   'deliberately',
#   'curb',
#   'inner',
#   'desire',
#   'thing',
#   'be',
#   'difficult',
#   'never',
#   'give',
#   'up',
#   'enthusiasm',
#   'learn',
#   'courage',
#   'start'],
#  ['old',
#   'school',
#   'be',
#   'not',
#   'just',
#   'retro',
#   'not',
#   'old',
#   'fashion',
#   'not',
#   'hip',
#   'hop',
#   'be',
#   'just',
#   'part',
#   'person',
#   'insist',
#   'good',
#   'thing',
#   'traditional',
#   'habit',
#   'idea'],
#  ['watch',
#   'episode',
#   'plane',
#   'new',
#   'york',
#   'san',
#   'francisco',
#   'feature',
#   'brooklyn',
#   'bridge',
#   'golden',
#   'gate',
#   'bridge'],
#  ['basically',
#   'rely',
#   'de',
#   'support',
#   'field',
#   'hathaway',
#   'win',
#   'award',
#   'recent',
#   'year',
#   'there',
#   'be',
#   'impressive',
#   'role',
#   'do',
#   'not',
#   'seem',
#   'be'],
#  ['most',
#   'be',
#   'version',
#   'post',
#   'marriage',
#   'magnification',
#   'light',
#   'truck',
#   'white',
#   'lily',
#   'united',
#   'state',
#   'course',
#   'be',
#   'lot',
#   'fun',
#   'something'],
#  ['do',
#   'not',
#   'learn',
#   'robert',
#   'dinillo',
#   'stand',
#   'entrance',
#   'alley',
#   'wait'],
#  ['cheesy',
#   'yet',
#   'comfort',
#   'enjoyment',
#   'robert',
#   'deniro',
#   'just',
#   'play',
#   'perfect',
#   'silver',
#   'daddy',
#   'woman',
#   'man',
#   's',
#   'dream',
#   'kidding',
#   'i',
#   'put',
#   'woman',
#   'man',
#   'hope',
#   'see',
#   'i',
#   'suggest',
#   'here'],
#  ['nancy',
#   'meyer',
#   'have',
#   'not',
#   'make',
#   'movie',
#   'year',
#   'be',
#   'be',
#   'focus',
#   'old',
#   'person',
#   's',
#   'social',
#   'relationship',
#   'decades',
#   'up',
#   'date',
#   'start',
#   'up',
#   'female',
#   'entrepreneurial',
#   'setting',
#   'be',
#   'much',
#   'more',
#   'interesting'],
#  ['warm',
#   'hearted',
#   'comedy',
#   'modern',
#   'costume',
#   'anne',
#   'can',
#   'not',
#   'be',
#   'more',
#   'beautiful',
#   'performance',
#   'be',
#   'big',
#   'attraction',
#   'story',
#   'be',
#   'less',
#   'fashionable',
#   'queen',
#   'prada'],
#  ['watch',
#   'movie',
#   'i',
#   'feel',
#   'i',
#   'have',
#   'most',
#   'say',
#   'i',
#   'be',
#   'do',
#   'same',
#   'thing',
#   'woman',
#   'i',
#   'be',
#   'ten',
#   'zero',
#   'time',
#   'small',
#   'have',
#   'super',
#   'similarity',
#   'have',
#   'more',
#   'learn',
#   'there',
#   'be',
#   'countless',
#   'scene',
#   'move',
#   'tear',
#   'i',
#   'think',
#   'i',
#   'be',
#   'go',
#   'watch',
#   'again'],
#  ['be', 'best', 'tribute', 'movie'],
#  ['i',
#   'wake',
#   'up',
#   'five',
#   'm',
#   'watch',
#   'movie',
#   'i',
#   'have',
#   'always',
#   'want',
#   'see',
#   'oh',
#   'god',
#   'begin',
#   'great',
#   'day'],
#  ['watch',
#   'woman',
#   'workplace',
#   'movie',
#   'be',
#   'flip',
#   'woman',
#   's',
#   'fashion',
#   'magazine',
#   'flip',
#   'picture',
#   'teach',
#   'dres',
#   'read',
#   'column',
#   'drink',
#   'feminist',
#   'chicken',
#   'soup',
#   'life',
#   'be',
#   'too',
#   'easy',
#   'play',
#   'taijiquan',
#   'can',
#   'be',
#   'balance',
#   'casting',
#   'be',
#   'still',
#   'good',
#   'stay',
#   'classic'],
#  ['too',
#   'boring',
#   'director',
#   'shoot',
#   'love',
#   'vacation',
#   'shoot',
#   'workplace',
#   'story',
#   'whole',
#   'story',
#   'be',
#   'try',
#   'make',
#   'fuss',
#   'flat',
#   'life',
#   'so',
#   'mediocre'],
#  ['look', 'great'],
#  ['go', 'gentleman', 'old', 'man', 'go', 'passionate', 'goddes'],
#  ['one', 'hundred', 'thirty', 'star', 'end'],
#  ['urban',
#   'version',
#   'elderly',
#   'young',
#   'girl',
#   'matter',
#   'age',
#   'group',
#   'person',
#   'always',
#   'need',
#   'please',
#   'other',
#   'order',
#   'run',
#   'other'],
#  ['simple',
#   'comfortable',
#   'lack',
#   'depth',
#   'make',
#   'up',
#   'warmth',
#   'robert',
#   'be',
#   'simply',
#   'handsome',
#   'hathaway',
#   'be',
#   'so',
#   'pretty',
#   'expression',
#   'be',
#   'so',
#   'tight',
#   'little',
#   'girl',
#   'have',
#   'be',
#   'assistant',
#   'demon',
#   'head',
#   'woman',
#   'become',
#   'strongwoman',
#   'p'],
#  ['s',
#   'movie',
#   'be',
#   'textbook',
#   'level',
#   'dress',
#   'tutorial',
#   'hathaway',
#   's',
#   'light',
#   'mature',
#   'girl',
#   'ol',
#   'style',
#   'robert',
#   's',
#   'retro',
#   'suit',
#   'style',
#   'set',
#   'be',
#   'please',
#   'eye'],
#  ['so',
#   'happy',
#   'marriage',
#   'strong',
#   'woman',
#   'be',
#   'unsolvable',
#   'especially',
#   'water',
#   'sign',
#   'scumman'],
#  ['be',
#   'good',
#   'way',
#   'get',
#   'rid',
#   'cheat',
#   'husband',
#   'unfortunately',
#   'not',
#   'many',
#   'man',
#   'have',
#   'kind',
#   'awarenes'],
#  ['i',
#   'think',
#   'should',
#   'be',
#   'show',
#   'christmas',
#   'day',
#   'buy',
#   'warm',
#   'ginger',
#   'coffee',
#   'i',
#   'have',
#   'see',
#   'robert',
#   's',
#   'grandpa',
#   'movie',
#   'be',
#   'brain',
#   'powder',
#   'i',
#   'love',
#   'warm',
#   'bright',
#   'image',
#   'new',
#   'york',
#   'comedy',
#   'movie',
#   'unburden',
#   'circumstance'],
#  ['warm',
#   'inspiring',
#   'humorous',
#   'high',
#   'degree',
#   'completion',
#   'i',
#   'also',
#   'anna',
#   's',
#   'dres',
#   'movie',
#   'exemplary',
#   'work',
#   'woman',
#   'eastern',
#   'united',
#   'state'],
#  ['clothing',
#   'interior',
#   'design',
#   'guideline',
#   'first',
#   'half',
#   'be',
#   'more',
#   'interesting',
#   'relationship',
#   'be',
#   'harmonious',
#   'stereotype',
#   'gradually',
#   'appear',
#   'especially',
#   'addition',
#   'husband',
#   'character',
#   'entire',
#   'film',
#   'almost',
#   'degenerate',
#   'standardized',
#   'bad',
#   'film'],
#  ['i',
#   'think',
#   'intern',
#   'meant',
#   'robert',
#   'anne',
#   'hathaway',
#   'be',
#   'too',
#   'weak',
#   'hold',
#   'such',
#   'strongwoman'],
#  ['bowl',
#   'full',
#   'chicken',
#   'soup',
#   'i',
#   'think',
#   'robert',
#   'hathaway',
#   'be',
#   'go',
#   'roll',
#   'sheet'],
#  ['textbook',
#   'chicken',
#   'film',
#   'seriously',
#   'hathaway',
#   'play',
#   'feminist',
#   'figure',
#   'whole',
#   'place',
#   'be',
#   'be',
#   'taught',
#   'daddy',
#   'be',
#   'really',
#   'okay'],
#  ['three',
#   'half',
#   'star',
#   'i',
#   'watch',
#   'movie',
#   'robert',
#   'kind',
#   'american',
#   'feminine',
#   'inspirational',
#   'film',
#   'be',
#   'not',
#   'really',
#   'thing'],
#  ['very',
#   'warm',
#   'fairy',
#   'tale',
#   'wind',
#   'two',
#   'hour',
#   'do',
#   'not',
#   'feel',
#   'long',
#   'background',
#   'music',
#   'have',
#   'always',
#   'be',
#   'similar',
#   'tone',
#   'little',
#   'monotonous',
#   'princes',
#   'ann',
#   'play',
#   'bos',
#   'be',
#   'also',
#   'assistant',
#   'feel',
#   'drunk',
#   'woman',
#   's',
#   'right',
#   'be',
#   'bit',
#   'superficial',
#   'godfather',
#   'be',
#   'cute'],
#  ['i',
#   'have',
#   'have',
#   'lot',
#   'confuse',
#   'moment',
#   'year',
#   'few',
#   'time',
#   'i',
#   'naturally',
#   'think',
#   'dad',
#   'then',
#   'i',
#   'find',
#   'just',
#   'want',
#   'go',
#   'back',
#   'hometown',
#   'work',
#   'civil',
#   'servant',
#   'movie',
#   'be',
#   'movie',
#   'reality',
#   'be',
#   'reality',
#   'kind',
#   'feminine',
#   'color',
#   'allow',
#   'woman',
#   'have',
#   'sufficient',
#   'lewd',
#   'space',
#   'subject',
#   'matter',
#   'begin',
#   'bj',
#   'have',
#   'not',
#   'go',
#   'fashion',
#   'indeed'],
#  ['even',
#   'find',
#   'ultimate',
#   'handsome',
#   'guy',
#   'do',
#   'not',
#   'end',
#   'up',
#   'own'],
#  ['politically',
#   'correct',
#   'interesting',
#   'material',
#   'selection',
#   'strong',
#   'cas',
#   'whole',
#   'movie',
#   'be',
#   'full',
#   'embarrassment',
#   'helplessnes',
#   'apart',
#   'weak',
#   'tension',
#   'mainline',
#   'drama',
#   'old',
#   'man',
#   's',
#   'boring',
#   'personality',
#   'loose',
#   'narrative',
#   'protagonist',
#   's',
#   'lack',
#   'chemistry',
#   'fact',
#   'holm',
#   'be',
#   'office',
#   'live',
#   'be',
#   'too',
#   'much',
#   'model',
#   'house',
#   'hotel',
#   'be',
#   'use',
#   'look',
#   'annie',
#   'start',
#   'fashion',
#   'show',
#   'again',
#   'clothe',
#   'do',
#   'not',
#   'match',
#   'too',
#   'well'],
#  ['be', 'little', 'too', 'good', 'i', 'be', 'do', 'chicken', 'soup'],
#  ['year',
#   'dres',
#   'have',
#   'change',
#   'msixty',
#   'five',
#   'high',
#   'end',
#   'suit',
#   'walk',
#   'posture',
#   'have',
#   'not',
#   'change'],
#  ['drink',
#   'chicken',
#   'soup',
#   'i',
#   'will',
#   'identify',
#   'robert',
#   'anne',
#   'hathaway',
#   'brand'],
#  ['easy',
#   'effortless',
#   'comedy',
#   'super',
#   'cute',
#   'hathaway',
#   'be',
#   'also',
#   'beautiful',
#   'glitter',
#   'watch',
#   'whole',
#   'person',
#   'feel',
#   'very',
#   'happy'],
#  ['ahahahahahahahahaha',
#   'ben',
#   'tell',
#   'jule',
#   'pay',
#   'attention',
#   'inner',
#   'peace',
#   'bridge',
#   'play',
#   'taiji',
#   'be',
#   'tribute',
#   'kung',
#   'fu',
#   'panda'],
#  ['i', 'want', 'four', 'star'],
#  ['be',
#   'standard',
#   'hollywood',
#   'movie',
#   'end',
#   'hathaway',
#   'scumboy',
#   'take',
#   'point',
#   'off'],
#  ['late', 'life', 'corleone'],
#  ['content',
#   'seem',
#   'be',
#   'line',
#   'trend',
#   'be',
#   'actually',
#   'one',
#   'movie',
#   'that',
#   'be',
#   'basically',
#   'touch',
#   'time',
#   'screenwriter',
#   's',
#   'total',
#   'failure',
#   'create',
#   'conflict',
#   'be',
#   'just',
#   'hot',
#   'pot',
#   'sugar',
#   'water'],
#  ['be',
#   'happiness',
#   'cherish',
#   'have',
#   'now',
#   'have',
#   'now',
#   'do',
#   'not',
#   'know',
#   'will',
#   'lose',
#   'do',
#   'like',
#   'stick',
#   'original',
#   'self',
#   'treat',
#   'life',
#   'tolerant',
#   'heart'],
#  ['walk', 'edge', 'strange', 'feeling'],
#  ['problem',
#   'be',
#   's',
#   'age',
#   'many',
#   'scene',
#   'company',
#   's',
#   'young',
#   'employee',
#   'show',
#   'obvious',
#   'fatigue',
#   'perfunctory',
#   'be',
#   'more',
#   'performance',
#   'style',
#   'be',
#   'not',
#   'suitable',
#   'appearance',
#   'external',
#   'charm',
#   'show',
#   'comedy',
#   'script',
#   'be',
#   'impose',
#   'charismatic',
#   'aura',
#   'goodwill',
#   'make',
#   'quickly',
#   'focus',
#   'company',
#   's',
#   'attention',
#   'audience',
#   'do',
#   'not',
#   'really',
#   'feel',
#   'should',
#   'be'],
#  ['blink',
#   'act',
#   'high',
#   'end',
#   'atmospheric',
#   'travel',
#   'create',
#   'ambiguous',
#   'suspense',
#   'afraid',
#   'embarrassment',
#   'i',
#   'be',
#   'nervous',
#   'be',
#   'good',
#   'feel',
#   'progres',
#   'society'],
#  ['anne',
#   'hathaway',
#   'assistant',
#   'bos',
#   'be',
#   'still',
#   'wear',
#   'navy',
#   'sweater'],
#  ['rather',
#   'be',
#   'more',
#   'mediocre',
#   'expect',
#   'i',
#   'be',
#   'completely',
#   'mark',
#   'know'],
#  ['look',
#   'i',
#   'really',
#   'think',
#   'person',
#   'get',
#   'old',
#   'whole',
#   'character',
#   'will',
#   'change',
#   'round'],
#  ['life',
#   'be',
#   'also',
#   'like',
#   'play',
#   'tai',
#   'chi',
#   'balance',
#   'one',
#   'move',
#   'breathing',
#   'warm',
#   'little',
#   'piece',
#   'life',
#   'suitable',
#   'christma',
#   'eve',
#   'heal',
#   'mood',
#   'favorite',
#   'be',
#   'ben',
#   'austin',
#   'overtime',
#   'night',
#   'conversation',
#   'warm',
#   'light',
#   'ben',
#   'talk',
#   'be',
#   'forty',
#   'year',
#   'ago',
#   'use',
#   'work',
#   'place',
#   'brick',
#   'tile',
#   'paulownia',
#   'tree',
#   'front',
#   'window',
#   'be',
#   'so',
#   'familiar',
#   'tacit',
#   'understand',
#   'two',
#   'be',
#   'quietly',
#   'grow',
#   'unfortunately',
#   'film',
#   'be',
#   'too',
#   'formal',
#   'gentleman',
#   'must',
#   'bring',
#   'handkerchief',
#   'go',
#   'out'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'anne',
#   'hathaway',
#   'love',
#   'grow',
#   'up',
#   'four',
#   'half',
#   'star',
#   'first',
#   'have',
#   'be',
#   'translate',
#   'title',
#   'film',
#   'inexplicable',
#   'hong',
#   'kong',
#   'name',
#   'win',
#   'again',
#   'old',
#   'strong',
#   'old',
#   'man',
#   'princes',
#   'noble',
#   'couple',
#   'give',
#   'bowl',
#   'super',
#   'positive',
#   'energy',
#   'heart',
#   'chicken',
#   'soup',
#   'there',
#   'be',
#   'funny',
#   'zhong',
#   'want',
#   'master',
#   'do',
#   'job',
#   'be',
#   'steal',
#   'only',
#   'not',
#   'hurt',
#   'old',
#   'mother',
#   's',
#   'heart',
#   'kind',
#   'movie',
#   'have',
#   'good',
#   'return'],
#  ['robert',
#   's',
#   'eq',
#   'be',
#   'so',
#   'high',
#   'can',
#   'be',
#   'use',
#   'work',
#   'textbook',
#   'not',
#   'warn',
#   'boss',
#   'pay',
#   'attention',
#   'boss',
#   's',
#   'real',
#   'need',
#   'handle',
#   'relationship',
#   'colleague',
#   'do',
#   'job',
#   'diligently'],
#  [],
#  ['almost', 'four', 'star'],
#  ['person',
#   'admire',
#   'old',
#   'habit',
#   'have',
#   'achieve',
#   'something',
#   'secondary',
#   'industry',
#   'style',
#   'play',
#   'be',
#   'write',
#   'too',
#   'casually',
#   'shelf',
#   'be',
#   'well',
#   'build',
#   'meat',
#   'inside',
#   'be',
#   'not',
#   'enough',
#   'porcelain',
#   'be',
#   'good',
#   'use',
#   'old',
#   'service',
#   'industry',
#   's',
#   'strict',
#   'self',
#   'discipline',
#   'executive',
#   'new',
#   'service',
#   'industry',
#   'break',
#   'dogma',
#   'female',
#   'strongman',
#   'start',
#   'point',
#   'storytelling'],
#  ['grandpa',
#   'be',
#   'so',
#   'cute',
#   'be',
#   'really',
#   'kind',
#   'do',
#   'not',
#   'know',
#   'refuse',
#   'other',
#   'leave',
#   'step',
#   'other',
#   'all',
#   'time',
#   'be',
#   'good',
#   'discover',
#   'joy',
#   'life'],
#  ['great', 'act', 'general', 'story'],
#  ['close',
#   'non',
#   'religious',
#   'relationship',
#   'can',
#   'think',
#   'be',
#   'be',
#   'bury',
#   'death',
#   'visual',
#   'hardware',
#   'be',
#   'beautiful',
#   'story',
#   'be',
#   'much',
#   'good',
#   'i',
#   'think',
#   'thankfully',
#   'not',
#   'cheesy',
#   'mother',
#   'daughter',
#   'relationship',
#   'sexism',
#   'retro',
#   'era',
#   'feel',
#   'one',
#   'point',
#   'bruise',
#   'that',
#   'have',
#   'not',
#   'be',
#   'scratch',
#   'era',
#   'one',
#   'be',
#   'involve',
#   'nostalgia',
#   'sigh'],
#  ['new', 'york', 'be', 'beautiful'],
#  ['old',
#   'intern',
#   's',
#   'idea',
#   'standard',
#   'chick',
#   'movie',
#   'add',
#   'warmth',
#   'theme',
#   'female',
#   'inspiration',
#   'ben',
#   'completely',
#   'retain',
#   'spirit',
#   'merit',
#   'traditional',
#   'industry',
#   'avoid',
#   'cost',
#   'move',
#   'secondary',
#   'tertiary',
#   'industry',
#   'be',
#   'nice',
#   'healing',
#   'ben',
#   'tell',
#   'wife',
#   's',
#   'story',
#   'not',
#   'long',
#   'enough',
#   'fall',
#   'completely',
#   'once',
#   'again',
#   'i',
#   'have',
#   'lament',
#   'story',
#   'be',
#   'romantic',
#   'as',
#   'long',
#   'be',
#   'middle',
#   'clas'],
#  ['two', 'star', 'be', 'well', 'choose', 'think', 'version', 'queen', 'prada'],
#  ['much',
#   'well',
#   'look',
#   'i',
#   'think',
#   'i',
#   'think',
#   'be',
#   'queen',
#   'prada',
#   'know',
#   'completely',
#   'upside',
#   'down',
#   'anne',
#   'hathaway',
#   's',
#   'outfit',
#   'be',
#   'really',
#   'too',
#   'good',
#   'look'],
#  ['airplane',
#   'movie',
#   'chicken',
#   'soup',
#   'content',
#   'be',
#   'preview',
#   'most',
#   'focu',
#   'be',
#   'various',
#   'interior',
#   'design',
#   'trance',
#   'can',
#   'also',
#   'see',
#   'hathaway',
#   'sit',
#   'door',
#   'aunt',
#   'may',
#   's',
#   'office',
#   'shadow',
#   'small',
#   'assistant',
#   'age',
#   'have',
#   'say',
#   'nothing',
#   'look',
#   'expression',
#   'can',
#   'become',
#   'life',
#   'mentor'],
#  ['unbreakable',
#   'truth',
#   'well',
#   'organize',
#   'hollywood',
#   'assembly',
#   'line',
#   'piece',
#   'regardless',
#   'quality',
#   'be',
#   'example',
#   'cultural',
#   'analysi'],
#  ['young',
#   'woman',
#   'be',
#   'attract',
#   'controlled',
#   'conservative',
#   'old',
#   'white',
#   'man',
#   'turn',
#   'away',
#   'contemporary',
#   'man',
#   'rely',
#   'help',
#   'career',
#   'family',
#   'affirmatism',
#   'always',
#   'end',
#   'positive',
#   'image',
#   'end',
#   'negative',
#   'one'],
#  ['forty',
#   'year',
#   'kramer',
#   'hollywood',
#   's',
#   'right',
#   'wing',
#   'stance',
#   'hypocritical',
#   'morality',
#   'have',
#   'never',
#   'change'],
#  ['pack',
#   'grow',
#   'up',
#   'fairy',
#   'tale',
#   'mainly',
#   'see',
#   'hostess',
#   'change',
#   'set',
#   'beautiful',
#   'clothe',
#   'drink',
#   'director',
#   'pour',
#   'chicken',
#   'soup',
#   'film',
#   'throw',
#   'out',
#   'topic',
#   'work',
#   'family',
#   'issue',
#   'there',
#   'be',
#   'workplace',
#   'entrepreneurship',
#   'continuation',
#   'problem',
#   'try',
#   'ask',
#   'which',
#   'one',
#   'be',
#   'take',
#   'seriously'],
#  ['end',
#   'nothing',
#   'be',
#   'resolve',
#   'all',
#   'thin',
#   'film',
#   'most',
#   'regrettable',
#   'thing',
#   'be',
#   'find',
#   'such',
#   'fresh',
#   'old',
#   'young',
#   'partner',
#   'not',
#   'able',
#   'dig',
#   'up',
#   'deep',
#   'spark',
#   'interaction'],
#  ['ever',
#   'i',
#   'find',
#   'out',
#   'director',
#   'nancy',
#   'meyer',
#   'be',
#   'also',
#   'hollywood',
#   's',
#   'top',
#   'interior',
#   'designer',
#   'i',
#   'have',
#   'be',
#   'star',
#   'hard',
#   'protagonist',
#   's',
#   'house',
#   'die',
#   'office',
#   'american',
#   'style',
#   'natural',
#   'light',
#   'window',
#   'be',
#   'too',
#   'comfortable',
#   'use',
#   'movie',
#   'be',
#   'pretty',
#   'cute'],
#  ['hathaway', 's', 'not', 'do', 'very', 'well'],
#  ['taipei',
#   'be',
#   'thin',
#   'overall',
#   'be',
#   'just',
#   'fashion',
#   'show',
#   'design',
#   'can',
#   'not',
#   'stand',
#   'taste',
#   'male',
#   'character',
#   'design',
#   'be',
#   'too',
#   'weak'],
#  ['robert',
#   'be',
#   'super',
#   'love',
#   'actor',
#   'annie',
#   's',
#   'youth',
#   'front',
#   'just',
#   'compound',
#   'need',
#   'plot',
#   'succes',
#   'casting',
#   'be',
#   'self',
#   'evident',
#   'addition',
#   'workplace',
#   'europe',
#   'united',
#   'state',
#   'be',
#   'very',
#   'natural',
#   'matter',
#   'shoot',
#   'such',
#   'office',
#   'hang',
#   'bell',
#   'such',
#   'office',
#   'masseuse',
#   'so',
#   'contrary',
#   'chinese',
#   'film',
#   'appear',
#   'workplace',
#   'there',
#   'be',
#   'mysterious',
#   'temperament',
#   'be',
#   'fuck',
#   'kid'],
#  ['i', 'do', 'not', 'know', 'short', 'ron', 'be', 'worth', 'four', 'star'],
#  ['chicken',
#   'soup',
#   'movie',
#   'guise',
#   'feminism',
#   'career',
#   'company',
#   'should',
#   'be',
#   'main',
#   'line',
#   'independent',
#   'female',
#   'screenwriter',
#   'be',
#   'not',
#   'very',
#   'perfunctory',
#   'female',
#   'image',
#   'be',
#   'i',
#   'be',
#   'busy',
#   'obsessive',
#   'first',
#   'find',
#   'ceo',
#   'be',
#   'too',
#   'large',
#   'control',
#   'finally',
#   'screenwriter',
#   'forget',
#   'ballast',
#   'only',
#   'become',
#   'family',
#   'vs',
#   'career',
#   'tangle'],
#  ['pseudo',
#   'feminist',
#   'movie',
#   'masterpiece',
#   'just',
#   'find',
#   'more',
#   'mature',
#   'male',
#   'mentor'],
#  ['overtime',
#   'night',
#   'talk',
#   'ben',
#   'back',
#   'work',
#   'original',
#   'place',
#   'arrange',
#   'space',
#   'big',
#   'paulownia',
#   'be',
#   'very',
#   'touching',
#   'new',
#   'start',
#   'office',
#   'scene',
#   'only',
#   'highlight',
#   'unattended',
#   'desk',
#   'conference',
#   'room',
#   'use',
#   'several',
#   'time',
#   'there',
#   'be',
#   'good',
#   'sense',
#   'scene',
#   'bridge',
#   'section',
#   'be',
#   'very',
#   'old',
#   'especially',
#   'four',
#   'man',
#   'steal',
#   'computer',
#   'section',
#   'which',
#   'be',
#   'compromise',
#   'contemporary',
#   'comedy',
#   'robert',
#   'perform',
#   'well',
#   'character',
#   'be',
#   'too',
#   'warm'],
#  ['i',
#   'have',
#   'be',
#   'complain',
#   'day',
#   'much',
#   'i',
#   'need',
#   'bowl',
#   'positive',
#   'energy',
#   'chicken',
#   'soup'],
#  ['seventy',
#   'year',
#   'old',
#   'veteran',
#   'handsome',
#   'man',
#   'help',
#   'taobao',
#   'young',
#   'woman',
#   'shop',
#   'manager',
#   'start',
#   'warm',
#   'inspirational',
#   'story',
#   'american',
#   'internet',
#   'entrepreneurship',
#   'ruin',
#   'life',
#   'cultivate',
#   'body',
#   'mind',
#   'still',
#   'rely',
#   'chinese',
#   'qigong'],
#  ['take',
#   'intern',
#   's',
#   'salary',
#   'work',
#   'twelve',
#   'hour',
#   'day',
#   'boss',
#   'also',
#   'help',
#   'bos',
#   'take',
#   'child',
#   'drive',
#   'be',
#   'not',
#   'disguise',
#   'squeeze',
#   'cheap',
#   'labor'],
#  ['bore', 'explode'],
#  ['hathaway',
#   's',
#   'husband',
#   'cheat',
#   'big',
#   'tension',
#   'movie',
#   'resolve',
#   'husband',
#   'confess',
#   'realize',
#   'real',
#   'reason',
#   'hathaway',
#   'originally',
#   'want',
#   'hire',
#   'external',
#   'management',
#   'vc',
#   'pressure',
#   'be',
#   'invisible',
#   'forgotten'],
#  ['i',
#   'think',
#   'end',
#   'point',
#   'be',
#   'integrate',
#   'senior',
#   'intern',
#   'modern',
#   'internet',
#   'workplace'],
#  ['result',
#   'be',
#   'female',
#   'bos',
#   'balance',
#   'career',
#   'family',
#   'finally',
#   'husband',
#   's',
#   'repentance',
#   'be',
#   'unnecessary'],
#  ['i',
#   'be',
#   'sorry',
#   'i',
#   'be',
#   'talk',
#   'today',
#   'elder',
#   'i',
#   'be',
#   'intern',
#   'i',
#   'have',
#   'see',
#   'too',
#   'much',
#   'i',
#   'need',
#   'tell',
#   'little',
#   'bit',
#   'life',
#   'experience'],
#  ['be',
#   'warm',
#   'friendship',
#   'there',
#   'be',
#   'bullet',
#   'curtain',
#   'cut',
#   'off',
#   'god',
#   'go',
#   'down',
#   'mountain',
#   'guides',
#   'person',
#   'go',
#   'up',
#   'mountain'],
#  ['robert',
#   's',
#   'charm',
#   'be',
#   'not',
#   'diminish',
#   'be',
#   'really',
#   'cool',
#   'compare',
#   'bunch',
#   'little',
#   'brat',
#   'movie',
#   'say',
#   'have',
#   'forty',
#   'two',
#   'year',
#   'old',
#   'marriage',
#   'eighteen',
#   'year',
#   'old',
#   'wife',
#   'love',
#   'mind',
#   'automatically',
#   'give',
#   'birth',
#   'godfather',
#   'stand',
#   'curtain',
#   'shoot',
#   'scene',
#   'eighteen',
#   'year',
#   'old',
#   'meet',
#   'wife',
#   'gangster',
#   'hahahahahahahahahaha'],
#  ['ten',
#   'year',
#   'later',
#   'little',
#   'assistant',
#   'grow',
#   'up',
#   'strong',
#   'woman',
#   'eye',
#   'be',
#   'not',
#   'broaden',
#   'first',
#   'half',
#   'movie',
#   'be',
#   'very',
#   'good',
#   'whole',
#   'thing',
#   'be',
#   'too',
#   'light',
#   'style',
#   'delete',
#   'email',
#   'be',
#   'very',
#   'abrupt'],
#  ['middle',
#   'rule',
#   'miao',
#   'da',
#   'good',
#   'old',
#   'grandfather',
#   'fragrant',
#   'standard',
#   'appearance',
#   'exquisite',
#   'high',
#   'cold',
#   'inner',
#   'fragile',
#   'crisi',
#   'strong',
#   'female',
#   'strongman',
#   'end',
#   'strong',
#   'point',
#   'piece',
#   'child',
#   's',
#   'right',
#   'pant',
#   'look',
#   'scum',
#   'man',
#   'confess',
#   'be',
#   'forgive',
#   'bridge',
#   'let',
#   'loose',
#   'know',
#   'must',
#   'be',
#   'spray',
#   'dog',
#   'do',
#   'say',
#   'wildfire',
#   'burn',
#   'spring',
#   'breeze',
#   'again',
#   'turbulent',
#   'heart',
#   'spring',
#   'up',
#   'first',
#   'time',
#   'pinch',
#   'will',
#   'grow',
#   'second',
#   'time',
#   'third',
#   'time',
#   'become',
#   'hulunbuir',
#   'prairie',
#   'very',
#   'cocky'],
#  ['bright',
#   'color',
#   'eternal',
#   'preach',
#   'elderly',
#   'minute',
#   'teach',
#   'little',
#   'woman',
#   'be',
#   'human',
#   'look',
#   'do',
#   'not',
#   'look',
#   'same'],
#  ['commercial',
#   'cute',
#   'story',
#   'only',
#   'thing',
#   'that',
#   'be',
#   'upsetting',
#   'be',
#   'word',
#   'feminine',
#   'right',
#   'appear',
#   'film',
#   's',
#   'usual',
#   'label'],
#  ['plot',
#   'be',
#   'gentle',
#   'old',
#   'drama',
#   'bone',
#   'acting',
#   'be',
#   'really',
#   'comfortable',
#   'great',
#   'secret',
#   'not',
#   'be',
#   'afraid',
#   'old',
#   'age',
#   'be',
#   'allow',
#   'time',
#   'give',
#   'valuable',
#   'wealth',
#   'not',
#   'just',
#   'wrinkle',
#   'gray',
#   'hair',
#   'be',
#   'also',
#   'fortunate',
#   'have',
#   'someone',
#   'talk',
#   'be',
#   'lose'],
#  ['grandpa', 'cook', 'bowl', 'soul', 'soup', 'drink'],
#  ['be',
#   'time',
#   'eat',
#   'just',
#   'look',
#   'around',
#   'spend',
#   'relax',
#   'night',
#   'burn',
#   'brain',
#   'course',
#   'do',
#   'not',
#   'care',
#   'keep',
#   'look',
#   'other',
#   'half',
#   'next',
#   'day'],
#  ['be',
#   'great',
#   'movie',
#   'watch',
#   'plane',
#   'hathaway',
#   's',
#   'fashion',
#   'show',
#   'gentlemanly',
#   'demeanor',
#   'be',
#   'really',
#   'charm'],
#  ['i',
#   'want',
#   'see',
#   'story',
#   'old',
#   'intern',
#   'okay',
#   'i',
#   'do',
#   'not',
#   'want',
#   'see',
#   'family',
#   'love',
#   'story',
#   'young',
#   'beautiful',
#   'entrepreneurial',
#   'executive',
#   'really',
#   'want',
#   'tell',
#   'such',
#   'story',
#   'please',
#   'change',
#   'intern',
#   'struggle',
#   'jule'],
#  ['be', 'never', 'wrong', 'do', 'right', 'thing'],
#  ['i',
#   'have',
#   'see',
#   'twice',
#   'short',
#   'time',
#   'attention',
#   'run',
#   'difficulty',
#   'i',
#   'think',
#   'annie',
#   'use',
#   'be',
#   'witch',
#   'wear',
#   'prada',
#   'now',
#   'be',
#   'intern',
#   'distant',
#   'idol',
#   'get',
#   'good',
#   'walk',
#   'well',
#   'glad'],
#  ['be', 'bore'],
#  ['internship',
#   'five',
#   'most',
#   'interesting',
#   'part',
#   'whole',
#   'movie',
#   'be',
#   'blue',
#   'frog'],
#  ['queen', 'prada', 'ii'],
#  ['subject',
#   'matter',
#   'be',
#   'really',
#   'brilliant',
#   'point',
#   'point',
#   'end',
#   'be',
#   'little',
#   'less',
#   'flavor'],
#  ['gentlemanly',
#   'workplace',
#   'light',
#   'comedy',
#   'young',
#   'old',
#   'post',
#   'cause',
#   'misplaced',
#   'laughter',
#   'relax',
#   'chicken',
#   'movie',
#   'pleasant',
#   'adult',
#   'fairy',
#   'tale',
#   'ten',
#   'year',
#   'later',
#   'hathaway',
#   'go',
#   'be',
#   'prada',
#   's',
#   'little',
#   'assistant',
#   'queen',
#   'be',
#   'become',
#   'more',
#   'more',
#   'woody',
#   'allen'],
#  ['i', 'saw', 'begin', 'plane', 'have', 'opportunity', 'continue', 'watch'],
#  ['nancy',
#   'meyer',
#   'script',
#   'direct',
#   'make',
#   'film',
#   'very',
#   'fluid',
#   'begin',
#   'story',
#   'move',
#   'forward',
#   'very',
#   'comfortable',
#   'cheerful',
#   'pace',
#   'which',
#   'be',
#   'bit',
#   'silk',
#   'soft',
#   'feeling',
#   'which',
#   'most',
#   'chinese',
#   'comedy',
#   'romantic',
#   'film',
#   'can',
#   'not',
#   'do',
#   'two',
#   'main',
#   'character',
#   'be',
#   'good',
#   'especially',
#   'hathaway',
#   'look',
#   'beautiful',
#   'fashionable',
#   'overall',
#   'standard',
#   'film',
#   'be',
#   'rather',
#   'average',
#   'lack',
#   'clear',
#   'theme',
#   'second',
#   'half',
#   'film',
#   'have',
#   'collapse',
#   'lot',
#   'far',
#   'inferior',
#   'devil',
#   'wear',
#   'prada'],
#  ['see',
#   'anne',
#   'come',
#   'proces',
#   'look',
#   'comfortable',
#   'plot',
#   'be',
#   'general',
#   'not',
#   'strengthen',
#   'old',
#   'point',
#   'comedy',
#   'play',
#   'sublimation',
#   'theme',
#   'there',
#   'be',
#   'lot',
#   'room'],
#  ['whole',
#   'world',
#   'be',
#   'pink',
#   'film',
#   'say',
#   'woman',
#   's',
#   'right',
#   'be',
#   'funny',
#   'be',
#   'general',
#   'chicken',
#   'flick',
#   'ah',
#   'be',
#   'really',
#   'too',
#   'cute'],
#  ['first',
#   'half',
#   'plot',
#   'be',
#   'very',
#   'interesting',
#   'discussion',
#   'definition',
#   'man',
#   'be',
#   'also',
#   'very',
#   'good',
#   'which',
#   'be',
#   'little',
#   'too',
#   'flattering',
#   'woman',
#   'be',
#   'slightly',
#   'distort',
#   'unprincipled',
#   'female',
#   'protagonist'],
#  ['enter',
#   'too',
#   'slowly',
#   'commercial',
#   'film',
#   'emotional',
#   'agitation',
#   'latter',
#   'half',
#   'be',
#   'very',
#   'effective',
#   'due',
#   'fullnes',
#   'character',
#   'effective',
#   'present',
#   'day',
#   'feminist',
#   'value',
#   'just',
#   'stop',
#   'blame',
#   'someone',
#   'else',
#   's',
#   'fault'],
#  ['i',
#   'can',
#   'not',
#   'imagine',
#   'young',
#   'man',
#   'taxi',
#   'driver',
#   'get',
#   'old',
#   'i',
#   'do',
#   'not',
#   'expect',
#   'find',
#   'answer',
#   'movie',
#   'i',
#   'have',
#   'be',
#   'confuse',
#   'long',
#   'time'],
#  ['plain', 'water'],
#  ['budget', 'must', 'have', 'go', 'end', 'movie'],
#  ['parent', 'ceo', 'recruitment', 'do', 'not', 'even', 'have', 'shadow'],
#  ['however',
#   'be',
#   'not',
#   'story',
#   'interesting',
#   'event',
#   'post',
#   'eightys',
#   'boss',
#   'post',
#   'forty',
#   'intern'],
#  ['grandpa', 'be', 'really', 'perfect'],
#  ['medium',
#   'size',
#   'piece',
#   'female',
#   'chicken',
#   'yes',
#   'chicken',
#   'fillet',
#   'be',
#   'now',
#   'world',
#   'woman',
#   's',
#   'girder',
#   'movie',
#   'raise',
#   'standard',
#   'warm',
#   'man',
#   'old',
#   'age',
#   'be',
#   'not',
#   'uncle',
#   's',
#   'turn',
#   'be',
#   'uncle',
#   's',
#   'turn',
#   'acting',
#   'be',
#   'really',
#   'natural',
#   'even',
#   'shadow',
#   'hathaway',
#   'be',
#   'seconds',
#   'eye'],
#  ['s',
#   'appearance',
#   'film',
#   'be',
#   'hollywood',
#   'tragedy',
#   'be',
#   'good',
#   'movie',
#   'star',
#   'play',
#   'taxi',
#   'driver',
#   'good',
#   'fella',
#   'be',
#   'also',
#   'heartbreaking',
#   'squeeze',
#   'eyebrow',
#   'such',
#   'spat',
#   'film',
#   'hollywood',
#   'reporter',
#   'write',
#   'article',
#   'that',
#   'also',
#   'indirectly',
#   'question',
#   's',
#   'personal',
#   'wealth',
#   'deficit',
#   'extent',
#   'need',
#   'play',
#   'bad',
#   'grandpa',
#   'intern',
#   'which',
#   'be',
#   'not',
#   'movie'],
#  ['be', 'act', 'so', 'tacky', 'i', 'hate', 'anne', 'hathaway'],
#  ['be', 'princess', 'diary'],
#  ['die',
#   'handsome',
#   'be',
#   'call',
#   'gentleman',
#   'be',
#   'call',
#   'elegant',
#   'man',
#   'plot',
#   'do',
#   'not',
#   'talk',
#   'especially',
#   'end',
#   'let',
#   'dump',
#   'cheat',
#   'old',
#   'recognize',
#   'de',
#   'godfather'],
#  ['subconscious',
#   'mind',
#   'traditional',
#   'patriarchal',
#   'audience',
#   'will',
#   'never',
#   'allow',
#   'successful',
#   'powerful',
#   'woman',
#   'end',
#   'well',
#   'screen',
#   'audience',
#   'will',
#   'only',
#   'want',
#   'expel',
#   'name',
#   'patriarchy',
#   'sanction',
#   'bankruptcy',
#   'failure',
#   'infidelity',
#   'etc'],
#  ['postmodern',
#   'patriarchy',
#   'hide',
#   'more',
#   'hidden',
#   'way',
#   'pretend',
#   'give',
#   'strongwoman',
#   'good',
#   'end',
#   'only',
#   'be',
#   'gaze',
#   'male',
#   'character',
#   'be',
#   'control',
#   'whole',
#   'situation',
#   'ben',
#   'symbol',
#   'patriarchal',
#   'authority',
#   'status',
#   'super',
#   'powerful',
#   'woman',
#   'play',
#   'seaway',
#   'movie',
#   'show',
#   'fragile',
#   'side',
#   'front',
#   'ben',
#   'audience',
#   'identify',
#   'ben',
#   'have',
#   'orgasm',
#   'skull',
#   'same',
#   'time',
#   'emit',
#   'strong',
#   'stench'],
#  ['neymar',
#   'i',
#   'also',
#   'want',
#   'have',
#   'kind',
#   'forgetful',
#   'friendship',
#   'cause',
#   'have',
#   'be',
#   'moist',
#   'silent',
#   'show',
#   'way'],
#  ['i', 'plant', 'sleep', 'gown'],
#  ['general', 'anne', 'hathaway', 'be', 'beat', 'back', 'original', 'form'],
#  ['be',
#   'great',
#   'be',
#   'adult',
#   'gentleman',
#   'hathaway',
#   'be',
#   'not',
#   'flat',
#   'chested'],
#  ['brooklyn', 'be', 'too', 'clean', 'second', 'half', 'be', 'catch', 'horse'],
#  ['old', 'man', 'intelligent', 'gracious', 'not', 'control', 'even', 'love'],
#  ['watch',
#   'taxi',
#   'driver',
#   'monday',
#   'watch',
#   'friday',
#   'week',
#   'be',
#   'forty',
#   'year',
#   'old',
#   'de',
#   'be',
#   'still',
#   'handsome',
#   'smart',
#   'comedy',
#   'have',
#   'good',
#   'rhythm',
#   'be',
#   'very',
#   'delicate',
#   'cute',
#   'i',
#   'really',
#   'appreciate',
#   's',
#   'performance',
#   'director',
#   'be',
#   'still',
#   'very',
#   'skilled'],
#  ['i',
#   'think',
#   'movie',
#   'be',
#   'weird',
#   'i',
#   'always',
#   'think',
#   'anne',
#   'hathaway',
#   'be',
#   'go',
#   'roll',
#   'sheet',
#   'seventy',
#   'year',
#   'old',
#   'uncle',
#   'i',
#   'have',
#   'be',
#   'wonder',
#   'be',
#   'not',
#   'get',
#   'here'],
#  ['love',
#   'interior',
#   'design',
#   'be',
#   'live',
#   'room',
#   'kitchen',
#   'office',
#   'be',
#   'particularly',
#   'good',
#   'hollywood',
#   'director',
#   'be',
#   'best',
#   'interior',
#   'design',
#   'i',
#   'do',
#   'not',
#   'plot',
#   'pseudo',
#   'feminine',
#   'ben',
#   'be',
#   'very',
#   'attractive'],
#  ['position', 'taijiquan', 'heart', 'american', 'empire'],
#  ['plain', 'chicken', 'soup'],
#  ['lei',
#   'ren',
#   'be',
#   'heroine',
#   'paragraph',
#   'good',
#   'man',
#   'use',
#   'be',
#   'man',
#   'nowadays',
#   'do',
#   'not',
#   'grow',
#   'big',
#   'speech',
#   'i',
#   'can',
#   'not',
#   'believe',
#   'kind',
#   'silly',
#   'fork',
#   'talk',
#   'would',
#   'come',
#   'anne',
#   'hathaway',
#   's',
#   'mouth',
#   'once',
#   'time',
#   'there',
#   'be',
#   'jack',
#   'nicholson',
#   'now',
#   'there',
#   'be',
#   'ezra',
#   'miller',
#   'addition',
#   'there',
#   'be',
#   'many',
#   'man',
#   'be',
#   'racist',
#   'sexist',
#   'past',
#   'so',
#   'glorify',
#   'man',
#   'be',
#   'likely',
#   'be',
#   'same',
#   'gay',
#   'man',
#   'hate',
#   'discriminate',
#   'wife',
#   'exercise',
#   'yes',
#   'just',
#   'fit',
#   'more',
#   'gender',
#   'stereotype'],
#  ['thought',
#   'such',
#   'lovely',
#   'old',
#   'man',
#   'luo',
#   'go',
#   'play',
#   'dirty',
#   'old',
#   'man',
#   'dirty',
#   'grandfather',
#   'be',
#   'place'],
#  ['bed',
#   'scene',
#   'end',
#   'be',
#   'really',
#   'embarrass',
#   'almost',
#   'bring',
#   'plot',
#   'bad',
#   'end',
#   'there',
#   'be',
#   'absolutely',
#   'need',
#   'create',
#   'embarrass',
#   'illusion',
#   'whole',
#   'article',
#   'be',
#   'still',
#   'reflection',
#   'work',
#   'place',
#   'be',
#   'worth',
#   'see'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'be',
#   'anne',
#   's',
#   'relationship',
#   'i',
#   'always',
#   'think',
#   'queen',
#   'wear',
#   'prada',
#   'year',
#   'old',
#   'daughter',
#   'law',
#   'stay',
#   'up',
#   'mother',
#   'law'],
#  ['be', 'hard', 'be', 'strong', 'woman', 'not', 'be', 'strong', 'woman'],
#  ['be',
#   'could',
#   'not',
#   'accept',
#   'cheat',
#   'husband',
#   'there',
#   'would',
#   'be',
#   'sand',
#   'eye'],
#  ['fairy',
#   'tale',
#   'do',
#   'not',
#   'count',
#   'be',
#   'brainwash',
#   'united',
#   'state',
#   'really',
#   'want',
#   'send',
#   'retiree',
#   'back',
#   'work',
#   'kind',
#   'trick',
#   'be',
#   'use',
#   'everyone',
#   'there',
#   'be',
#   'pretend',
#   'be',
#   'wear',
#   'thick',
#   'mask',
#   'pig',
#   'skin',
#   'mask',
#   'be',
#   'so',
#   'beautifully',
#   'carve',
#   'be',
#   'hard',
#   'notice',
#   'grease',
#   'abnormality',
#   'moment'],
#  ['genre',
#   'determine',
#   'must',
#   'be',
#   'avoid',
#   'light',
#   'side',
#   'be',
#   'tell',
#   'life',
#   'not',
#   'complete',
#   'noble',
#   'sub',
#   'complete',
#   'appearance',
#   'least',
#   'one',
#   'thing',
#   'be',
#   'true',
#   'there',
#   'be',
#   'many',
#   'thing',
#   'that',
#   'can',
#   'not',
#   'be',
#   'exchange'],
#  ['be',
#   'not',
#   'sixty',
#   'year',
#   'old',
#   'senior',
#   'intern',
#   'be',
#   'clearly',
#   'gentleman',
#   'vice',
#   'president',
#   'forty',
#   'year',
#   'busines',
#   'experience'],
#  ['be', 'adult', 'disney'],
#  ['be', 'unreal'],
#  ['annie', 's', 'clothe', 'be', 'very', 'pretty'],
#  ['grandpa', 'be', 'very', 'cute', 'value', 'be', 'shit'],
#  ['basically',
#   'can',
#   'think',
#   'robert',
#   'director',
#   'want',
#   'prove',
#   'old',
#   'man',
#   'be',
#   'do',
#   'something',
#   'play',
#   'special',
#   'effect',
#   'old',
#   'experience',
#   'be',
#   'still',
#   'classic',
#   'renee',
#   'russell',
#   'be',
#   'old',
#   'too',
#   'i',
#   'grow',
#   'up',
#   'watch',
#   'movie'],
#  ['experience', 'be', 'curriculum', 'vita', 'that', 'never', 'go', 'fashion'],
#  ['boring', 'time', 'end', 'one', 'star', 'less'],
#  ['nine',
#   'year',
#   'later',
#   'anne',
#   'be',
#   'still',
#   'beautiful',
#   'male',
#   'protagonist',
#   'be',
#   'really',
#   'mary',
#   'sue',
#   'person',
#   'set',
#   'ah',
#   'person',
#   'see',
#   'love',
#   'flower',
#   'bloom',
#   'first',
#   'step',
#   'capture',
#   'hearts',
#   'all',
#   'support',
#   'actor',
#   'include',
#   'heart',
#   'competitor',
#   'then',
#   'capture',
#   'heart',
#   'boss',
#   'even',
#   'daughter',
#   'omg',
#   'be',
#   'not',
#   'boss',
#   'fell',
#   'love'],
#  ['dig', 'heart'],
#  ['dig', 'shit'],
#  ['be',
#   'very',
#   'warm',
#   'too',
#   'perfect',
#   'i',
#   'ed',
#   'niro',
#   'anne',
#   'hathaway',
#   'comparison',
#   'be',
#   'so',
#   'miserable'],
#  ['gentleman', 'be', 'charm', 'all', 'time'],
#  ['i', 'have', 'be', 'look', 'kind', 'clothe', 'ww', 's', 'last', 'outfit'],
#  ['robert',
#   'downey',
#   'jr',
#   's',
#   'dad',
#   'be',
#   'old',
#   'more',
#   'handsome',
#   'really',
#   'be'],
#  ['inexplicable',
#   'script',
#   'do',
#   'protagonist',
#   's',
#   'focu',
#   'trainee',
#   'suddenly',
#   'turn',
#   'psychiatrist',
#   'two',
#   'main',
#   'character',
#   'be',
#   'very',
#   'realistic',
#   'cute',
#   'i',
#   'still',
#   'do',
#   'not',
#   'understand',
#   'i',
#   'should',
#   'watch',
#   'movie',
#   'finally',
#   'practice',
#   'yoga',
#   'together'],
#  ['do',
#   'host',
#   'feel',
#   'one',
#   'be',
#   'bury',
#   'together',
#   'divorce',
#   'be',
#   'tong',
#   'liya'],
#  ['own',
#   'father',
#   'will',
#   'not',
#   'let',
#   'bury',
#   'back',
#   'mother',
#   's',
#   'house'],
#  ['grandpa',
#   'intern',
#   'be',
#   'very',
#   'new',
#   'actually',
#   'give',
#   'female',
#   'bos',
#   'lot',
#   'spiritual',
#   'guidance',
#   'courage',
#   'life',
#   'experience',
#   'be',
#   'treasure',
#   'end',
#   'female',
#   'bos',
#   'forgive',
#   'cheat',
#   'husband',
#   'which',
#   'be',
#   'not',
#   'very',
#   'comfortable',
#   'heart'],
#  ['love', 'shopkeeper'],
#  ['be', 'surprisingly', 'heartwarming', 'fun', 'inspire'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'three',
#   'fifteen',
#   'nine',
#   'hundred',
#   'forty',
#   'six',
#   'just',
#   'ready',
#   'travel',
#   'release',
#   'movie',
#   'have',
#   'time',
#   'go',
#   'cinema',
#   'see',
#   'there',
#   'be',
#   'work',
#   'recently',
#   'think',
#   'watch',
#   'call',
#   'intern',
#   'may',
#   'be',
#   'helpful',
#   'very',
#   'comfortable',
#   'light',
#   'comedy',
#   'absurd',
#   'plot',
#   'only',
#   'solid',
#   'narrative',
#   'normal',
#   'character',
#   'not',
#   'much',
#   'look',
#   'forward',
#   'lot',
#   'gain'],
#  ['way',
#   'return',
#   'be',
#   'teach',
#   'young',
#   'person',
#   'work',
#   'live',
#   'gentleman',
#   'also',
#   'be',
#   'taught',
#   'young',
#   'person',
#   'adapt',
#   'modern',
#   'society',
#   'do',
#   'think',
#   'be',
#   'wrong',
#   'give',
#   'nice',
#   'old',
#   'vice',
#   'president',
#   'retirement',
#   'advise',
#   'job',
#   'price',
#   'intern',
#   'give',
#   'personal',
#   'babysitter'],
#  ['warm',
#   'movie',
#   'such',
#   'love',
#   'first',
#   'sight',
#   'harry',
#   'meet',
#   'sally',
#   'go',
#   'leave',
#   'danny',
#   'collin',
#   'little',
#   'faith',
#   'i',
#   'give',
#   'three',
#   'star',
#   'three',
#   'star',
#   'together',
#   'road',
#   'movie',
#   'feel',
#   'two',
#   'type',
#   'movie',
#   'be',
#   'suitable',
#   'leisure',
#   'relaxation',
#   'so',
#   'i',
#   'have',
#   'rat',
#   'so',
#   'many',
#   'movie',
#   'i',
#   'have',
#   'conclude',
#   'own',
#   'rating',
#   'four',
#   'star',
#   'more',
#   'be',
#   'there',
#   'have',
#   'be',
#   'depth'],
#  ['forgotten',
#   'new',
#   'year',
#   's',
#   'friendship',
#   'be',
#   'really',
#   'addition',
#   'family',
#   'love',
#   'most',
#   'touching',
#   'friendship',
#   'standard',
#   'woman',
#   'chicken',
#   'soup',
#   'full',
#   'warm',
#   'feeling',
#   'uncle',
#   's',
#   'person',
#   'deeply',
#   'interpret',
#   'be',
#   'gentleman',
#   's',
#   'character',
#   'connotation',
#   'cultivation',
#   'grace',
#   'anne',
#   'successfully',
#   'evolve',
#   'work',
#   'girl',
#   'wear',
#   'prada',
#   'miranda',
#   'family',
#   'busines',
#   'be',
#   'difficult',
#   'director',
#   's',
#   'filming',
#   'style',
#   'be',
#   'very',
#   'much',
#   'appetite',
#   'idealize',
#   'story',
#   'even',
#   'i',
#   'see',
#   'ten',
#   'thousand',
#   'time',
#   'again',
#   'ah'],
#  ['expound',
#   'old',
#   'profession',
#   'most',
#   'emotional',
#   'window',
#   'position',
#   'forty',
#   'year',
#   'do',
#   'same',
#   'job',
#   'do',
#   'be',
#   'right',
#   'be',
#   'never',
#   'wrong'],
#  ['be',
#   'there',
#   'lack',
#   'comedy',
#   'life',
#   'everything',
#   'country',
#   'be',
#   'miss',
#   'main',
#   'theme'],
#  ['two',
#   'hour',
#   'screenwriting',
#   'be',
#   'not',
#   'enough',
#   'time',
#   'see',
#   'even',
#   'final',
#   'capture',
#   'adultery',
#   'divorce',
#   'have',
#   'save',
#   'dog',
#   'blood'],
#  ['grandpa', 's', 'idea', 'would', 'be', 'perfect'],
#  ['plot',
#   'be',
#   'not',
#   'particularly',
#   'old',
#   'fashion',
#   'whole',
#   'movie',
#   'give',
#   'sense',
#   'good',
#   'old',
#   'fashion',
#   'i',
#   'can',
#   'not',
#   'say',
#   'follow',
#   'up',
#   'plot',
#   'come',
#   'watch',
#   'i',
#   'will',
#   'think',
#   'kind',
#   'drama',
#   'be',
#   'indeed',
#   'kind',
#   'plot',
#   'trend',
#   'line',
#   'match',
#   'ah'],
#  ['so',
#   'can',
#   'be',
#   'define',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'intermediate',
#   'level',
#   'composition',
#   'be',
#   'different',
#   'still',
#   'can',
#   'recognize',
#   'glance',
#   'be',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'too',
#   'template'],
#  ['be',
#   'film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman',
#   'quality',
#   'be',
#   'actually',
#   'good',
#   'early',
#   'stage',
#   'can',
#   'give',
#   'seven',
#   'even',
#   'eight',
#   'point',
#   'forgiveness',
#   'end',
#   'be',
#   'too',
#   'easy'],
#  ['maybe',
#   'i',
#   'be',
#   'kind',
#   'woman',
#   'compromise',
#   'right',
#   'away',
#   'i',
#   'still',
#   'can',
#   'not',
#   'accept',
#   'especially',
#   'kind',
#   'film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman'],
#  ['warmth',
#   'humor',
#   'be',
#   'important',
#   'seemingly',
#   'bland',
#   'structurally',
#   'rigorous',
#   'can',
#   'actually',
#   'dive',
#   'down'],
#  ['end',
#   'be',
#   'not',
#   'very',
#   'good',
#   'surprisingly',
#   'i',
#   'story',
#   'entrepreneurial',
#   'woman',
#   'leader',
#   'elderly',
#   'intern'],
#  ['variant',
#   'princes',
#   'knight',
#   'mode',
#   'unbreakable',
#   'tackines',
#   'be',
#   'not',
#   'big',
#   'problem',
#   'most',
#   'serious',
#   'thing',
#   'be',
#   'narrative',
#   'kernel',
#   'work',
#   'btw',
#   'do',
#   'american',
#   'person',
#   'start',
#   'say',
#   'goodbye',
#   'japanese'],
#  ['three',
#   'half',
#   'star',
#   'first',
#   'half',
#   'be',
#   'warm',
#   'solid',
#   'last',
#   'half',
#   'hour',
#   'be',
#   'so',
#   'confusing'],
#  ['company',
#   'have',
#   'old',
#   'one',
#   'big',
#   'one',
#   'good',
#   'old',
#   'person',
#   'experience',
#   'sedimentation',
#   'year',
#   'know',
#   'say',
#   'do',
#   'instead',
#   'scramble',
#   'seat',
#   'go',
#   'viral',
#   'something',
#   'woman',
#   'deserve',
#   'be',
#   'cheat',
#   'single',
#   'rest',
#   'life',
#   'end',
#   'be',
#   'perfect'],
#  ['marry', 'anne', 'hathaway', 'can', 'cheat'],
#  ['god', 's', 'forgiveness', 'sin', 'be', 'too', 'easy'],
#  ['anne',
#   'hathaway',
#   'be',
#   'beautiful',
#   'course',
#   'robert',
#   'be',
#   'handsome',
#   'too',
#   'more',
#   'importantly',
#   'story',
#   'love',
#   'life',
#   'be',
#   'very',
#   'well',
#   'tell',
#   'i'],
#  ['be',
#   'never',
#   'wrong',
#   'do',
#   'right',
#   'thing',
#   'elbow',
#   'recommend',
#   'movie',
#   'too',
#   'much'],
#  ['male',
#   'protagonist',
#   'be',
#   'too',
#   'perfect',
#   'first',
#   'time',
#   'feel',
#   'charm',
#   'elderly',
#   'completely',
#   'match',
#   'word',
#   'decent',
#   'i',
#   'suddenly',
#   'realize',
#   'be',
#   'feminist',
#   'color',
#   'movie',
#   'intention',
#   'be',
#   'very',
#   'good',
#   'end',
#   'be',
#   'little',
#   'hasty',
#   'simple'],
#  ['mature', 's', 'oneqycjtwoha', 'code', 'wrgnine'],
#  ['love', 'old', 'man'],
#  ['compare',
#   'country',
#   's',
#   'fashion',
#   'comedy',
#   'can',
#   'achieve',
#   'complete',
#   'drama',
#   'be',
#   'not',
#   'easy'],
#  ['cinema',
#   'heatherway',
#   'have',
#   'good',
#   'combination',
#   'old',
#   'man',
#   'find',
#   'new',
#   'job',
#   'woman',
#   'be',
#   'workaholic',
#   'save',
#   'marriage',
#   'want',
#   'leave',
#   'old',
#   'man',
#   'have',
#   'new',
#   'relationship',
#   'circle',
#   'still',
#   'have',
#   'dry',
#   'mood',
#   'be',
#   'very',
#   'different',
#   'two',
#   'person',
#   'practice',
#   'original',
#   'life',
#   'be',
#   'really',
#   'good'],
#  ['i',
#   'think',
#   'be',
#   'simplicity',
#   'old',
#   'day',
#   'inject',
#   'vitality',
#   'new',
#   'generation',
#   'end',
#   'be',
#   'still',
#   'suggestion',
#   'elite',
#   'there',
#   'be',
#   'resonance',
#   'be',
#   'still',
#   'disney',
#   'movie',
#   'let',
#   'also',
#   'look',
#   'relaxed',
#   'warmth'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'one',
#   'three',
#   'fifteen',
#   'forty',
#   'one',
#   'thirty',
#   'two'],
#  ['warm',
#   'relaxing',
#   'film',
#   'male',
#   'protagonist',
#   's',
#   'setting',
#   'be',
#   'too',
#   'perfect',
#   'good',
#   'subordinate',
#   'good',
#   'colleague',
#   'good',
#   'friend',
#   'united',
#   'state',
#   'have',
#   'energy',
#   'i',
#   'think',
#   'be',
#   'go',
#   'happen',
#   'male',
#   'female',
#   'protagonist',
#   'think',
#   'too',
#   'much'],
#  ['i', 'can', 'not', 'change', 'fact', 'i', 'love', 'ca', 'anymore'],
#  ['there',
#   'be',
#   'respect',
#   'oneself',
#   'other',
#   'relationship',
#   'other',
#   'be',
#   'noble',
#   'character'],
#  ['be', 'cool', 'warm', 'be', 'warm', 'principled'],
#  ['be', 'good', 'say'],
#  ['old',
#   'man',
#   'be',
#   'so',
#   'cute',
#   'look',
#   'old',
#   'man',
#   'up',
#   'story',
#   'be',
#   'cute',
#   'funny',
#   'listen',
#   'old',
#   'man',
#   'must',
#   'be',
#   'right',
#   'everyone',
#   'have',
#   'have',
#   'ben'],
#  ['be', 'mediocre', 'be', 'also', 'touch'],
#  ['there',
#   'be',
#   'nothing',
#   'say',
#   'plot',
#   'support',
#   'play',
#   'main',
#   'character',
#   'one',
#   'star'],
#  ['really',
#   'i',
#   'would',
#   'not',
#   'have',
#   'watch',
#   'stupid',
#   'movie',
#   'be',
#   'not',
#   'chris'],
#  ['be', 'waste', 'life'],
#  ['kind',
#   'angelic',
#   'thing',
#   'will',
#   'not',
#   'let',
#   'catch',
#   'up',
#   'easily',
#   'i',
#   'can',
#   'only',
#   'try',
#   'achieve',
#   'seven',
#   'hour',
#   'sleep',
#   'day'],
#  ['be', 'fun', 'be', 'not', 'big', 'deal'],
#  ['i', 'think', 'be', 'waste', 'time'],
#  ['i',
#   'can',
#   'be',
#   'so',
#   'relaxed',
#   'age',
#   'seventy',
#   'have',
#   'so',
#   'much',
#   'love',
#   'heart',
#   'live',
#   'so',
#   'clearly',
#   'will',
#   'not',
#   'be',
#   'vain',
#   'want',
#   'be',
#   'robert',
# ...
#   'juul',
#   'career',
#   'woman',
#   'forty',
#   'year',
#   'old',
#   'businessman',
#   'retire',
#   're',
#   'employ'],
#  ['juul',
#   'start',
#   'own',
#   'company',
#   'year',
#   'husband',
#   'be',
#   'full',
#   'time',
#   'home',
#   'baby',
#   'have',
#   'lovely',
#   'kindergarten',
#   'daughter',
#   'company',
#   'have',
#   'absorb',
#   'more',
#   'two',
#   'hundred',
#   'employee',
#   'past',
#   'year',
#   'operation',
#   'be',
#   'also',
#   'very',
#   'good'],
#  ['company',
#   'decide',
#   'hire',
#   'senior',
#   'intern',
#   'ben',
#   'apply',
#   'be',
#   'successfully',
#   'accept',
#   'i',
#   'have',
#   'be',
#   'assign',
#   'lead',
#   'julie',
#   'julie',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['be', 'not', 'just', 'intern', 'be', 'friend'],
#  ['film', 'jule', 'tell', 'senior', 'intern', 'ben'],
#  ['work',
#   'love',
#   'movie',
#   'intern',
#   's',
#   'name',
#   'remind',
#   'anne',
#   'hathaway',
#   's',
#   'two',
#   'thousand',
#   'seven',
#   'film',
#   'queen',
#   'prada',
#   'which',
#   'be',
#   'not',
#   'intern',
#   'queen'],
#  ['be', 'modern', 'society', 'marriage', 'family', 'deployment'],
#  ['movie',
#   'be',
#   'really',
#   'too',
#   'warm',
#   'anne',
#   'hathaway',
#   'be',
#   'really',
#   'beautiful',
#   'i',
#   'think',
#   'be',
#   'heroine',
#   'jule',
#   'internship',
#   'own',
#   'effort',
#   'little',
#   'powerful',
#   'story',
#   'however',
#   'main',
#   'character',
#   'trainee',
#   'be',
#   'grandfather',
#   'ben',
#   'be',
#   'main',
#   'character',
#   'movie',
#   'woman',
#   'be',
#   'already',
#   'boss',
#   'internet',
#   'company'],
#  ['jule',
#   'everyone',
#   'will',
#   'be',
#   'vulnerable',
#   'hostess',
#   'company',
#   'two',
#   'deployment'],
#  ['intern',
#   'thought',
#   'be',
#   'similar',
#   'female',
#   'devil',
#   'describe',
#   'hathaway',
#   's',
#   'growth',
#   'intern',
#   'workplace',
#   'have',
#   'never',
#   'be',
#   'intend',
#   'repeat',
#   'theme',
#   'pearl',
#   'jade',
#   'look',
#   'i',
#   'want',
#   'see',
#   'series',
#   'i',
#   'stumble',
#   'story',
#   'hathaway',
#   'grow',
#   'up',
#   'elderly',
#   'intern',
#   'bos',
#   'i',
#   'be',
#   'late',
#   'i',
#   'be',
#   'really',
#   'glad',
#   'meet',
#   'such',
#   'warm',
#   'positive',
#   'movie',
#   'which',
#   'heal',
#   'long',
#   'night',
#   'be',
#   'really',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['one',
#   'day',
#   'listen',
#   'fan',
#   'deng',
#   'explain',
#   'hundred',
#   'year',
#   'life',
#   'suddenly',
#   'middle',
#   'age',
#   'even',
#   'point',
#   'old',
#   'age',
#   'need',
#   're',
#   'learn',
#   're',
#   'find',
#   'job'],
#  ['movie',
#   'have',
#   'different',
#   'vision',
#   'elderly',
#   'retire',
#   'old',
#   'widow',
#   'first',
#   'degree',
#   'deployment'],
#  ['i',
#   'have',
#   'hole',
#   'life',
#   'i',
#   'have',
#   'fill',
#   'as',
#   'soon',
#   'possible',
#   'explore',
#   'plight',
#   'career',
#   'woman',
#   'corporate',
#   'operation',
#   'family',
#   'busines',
#   'society',
#   'gender',
#   'discrimination',
#   'busines',
#   'disappearance',
#   'male',
#   'office',
#   'worker',
#   'rise',
#   'female',
#   'office',
#   'worker',
#   'elderly',
#   'person'],
#  ['second',
#   'spring',
#   'career',
#   'second',
#   'spring',
#   'body',
#   'new',
#   'office',
#   'old',
#   'office',
#   'home',
#   'decentralize',
#   'calm',
#   'temperament',
#   'assign',
#   'task',
#   'steal',
#   'computer',
#   'delete',
#   'emails',
#   'home',
#   'have',
#   'old',
#   'one',
#   'such',
#   'one',
#   'deployment'],
#  ['be',
#   'optimistic',
#   'positive',
#   'rest',
#   'life',
#   'never',
#   'give',
#   'up',
#   'desire',
#   'knowledge'],
#  ['seventy',
#   'can',
#   'be',
#   'passionate',
#   'life',
#   'twenty',
#   'day',
#   'get',
#   'up',
#   'dress',
#   'up',
#   'white',
#   'tipped',
#   'book',
#   'yoga',
#   'go',
#   'bed',
#   'time',
#   'night',
#   'seventy',
#   'never',
#   'give',
#   'up',
#   'trend',
#   'attitude',
#   'life',
#   'remain',
#   'unchanged',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['movie',
#   'be',
#   'beautiful',
#   'entrepreneurial',
#   'woman',
#   'career',
#   'life',
#   'crisi',
#   'just',
#   'time',
#   'appear',
#   'mature',
#   'old',
#   'friend',
#   'maybe',
#   'can',
#   'not',
#   'directly',
#   'help',
#   'career',
#   'life',
#   'spiritual',
#   'support',
#   'be',
#   'infinite',
#   'i',
#   'envy',
#   'kind',
#   'person',
#   'all',
#   'image',
#   'elderly',
#   'friend',
#   'life',
#   'mentor',
#   'be',
#   'not',
#   'everyone',
#   'have',
#   'chance',
#   'meet',
#   'deployment'],
#  ['will',
#   'gain',
#   'follow',
#   'knowledge',
#   'relate',
#   'workplace',
#   'one',
#   'first',
#   'day',
#   'work',
#   'be',
#   'sure',
#   'not',
#   'be',
#   'late',
#   'set',
#   'alarm',
#   'clock',
#   'set',
#   'two',
#   'be',
#   'too',
#   'nervous',
#   'keep',
#   'friendly',
#   'comfortable',
#   'distance',
#   'colleague',
#   'do',
#   'not',
#   'have',
#   'come',
#   'up',
#   'please',
#   'other',
#   'have',
#   'time',
#   'help',
#   'colleague',
#   'observe',
#   'do',
#   'boss',
#   'want',
#   'do',
#   'see',
#   'result',
#   'watch',
#   'movie',
#   'i',
#   'want',
#   'buy',
#   'handkerchief',
#   'deployment'],
#  ['turn',
#   'out',
#   'actor',
#   'hold',
#   'up',
#   'most',
#   'play',
#   'be',
#   'not',
#   'legendary',
#   'robert',
#   'do',
#   'just'],
#  ['film',
#   'be',
#   'set',
#   'workplace',
#   'explore',
#   'theme',
#   'winner',
#   'life',
#   'one',
#   'be',
#   'elderly',
#   'person',
#   'return',
#   'workplace',
#   'one',
#   'be',
#   'strong',
#   'woman',
#   'have',
#   'make',
#   'name',
#   'elderly',
#   'do',
#   'good',
#   'job',
#   'basic',
#   'job',
#   'bring',
#   'warmth',
#   'positive',
#   'energy',
#   'person',
#   'strong',
#   'woman',
#   'be',
#   'entangled',
#   'family',
#   'career',
#   'deployment'],
#  ['movie',
#   'can',
#   'really',
#   'support',
#   'most',
#   'drama',
#   'old',
#   'american',
#   'actor',
#   'robert',
#   'have',
#   'do',
#   'smile',
#   'move',
#   'absolutely',
#   'elegant',
#   'elegant',
#   'screen',
#   'can',
#   'feel',
#   'elegance',
#   'nobility',
#   'be',
#   'hard',
#   'believe',
#   'seventy',
#   'two',
#   'year',
#   'old',
#   'man',
#   'can',
#   'be',
#   'so',
#   'attractive',
#   'seeing'],
#  ['movie', 'belong', 'american', 'soft', 'comedy', 'seem', 'deployment'],
#  ['film', 'review', 'be', 'learn', 'english', 'only'],
#  ['be', 'atypical', 'story', 'intern', 'best', 'friend'],
#  ['course',
#   'be',
#   'not',
#   'inspirational',
#   'movie',
#   'also',
#   'pour',
#   'few',
#   'bowl',
#   'chicken',
#   'soup',
#   'all',
#   'rookie',
#   'be',
#   'seventy',
#   'year',
#   'old',
#   'senior',
#   'veteran',
#   'actor',
#   'robert',
#   'oscar',
#   'winner',
#   'scorsese',
#   's',
#   'royal',
#   'male',
#   'protagonist',
#   'man',
#   'play',
#   'godfather',
#   'deployment'],
#  ['life',
#   'there',
#   'be',
#   'lot',
#   'helplessness',
#   'confusion',
#   'day',
#   'desperately',
#   'need',
#   'experienced',
#   'ferryman',
#   'help',
#   'cross',
#   'river',
#   'jule',
#   'clear',
#   'authentic',
#   'character',
#   'dare',
#   'try',
#   'inner',
#   'thought',
#   'life',
#   'can',
#   'not',
#   'always',
#   'go',
#   'smoothly',
#   'jule',
#   'encounter',
#   'problem',
#   'ben',
#   'kind',
#   'elder',
#   'always',
#   'give',
#   'spiritual',
#   'encouragement',
#   'advice',
#   'not',
#   'much',
#   'say',
#   'as',
#   'long',
#   'ben',
#   'be',
#   'here',
#   'jule',
#   'will',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['i',
#   'watch',
#   'movie',
#   'intern',
#   'yesterday',
#   'i',
#   'use',
#   'rely',
#   'age',
#   'decide',
#   'person',
#   'be',
#   'old',
#   'not',
#   'watch',
#   'intern',
#   'i',
#   'find',
#   'be',
#   'never',
#   'age',
#   'spirit',
#   'that',
#   'determine',
#   'person',
#   'be',
#   'old',
#   'not'],
#  ['person',
#   'twentys',
#   'live',
#   'old',
#   'man',
#   'seventys',
#   'teenager',
#   'let',
#   'take',
#   'look',
#   'movie',
#   'together'],
#  ['one', 'none', 'deployment'],
#  ['movie',
#   'be',
#   'i',
#   'run',
#   'tell',
#   'friend',
#   'i',
#   'have',
#   'see',
#   'good',
#   'movie',
#   'be',
#   'really',
#   'good',
#   'piece',
#   'write',
#   'maybe',
#   'there',
#   'have',
#   'be',
#   'reliable',
#   'person',
#   'time'],
#  ['instead',
#   'want',
#   'have',
#   'someone',
#   'i',
#   'want',
#   'be',
#   'person',
#   'reliable',
#   'calm',
#   'sincere',
#   'always',
#   'thoughtful',
#   'rigour',
#   'good',
#   'habit',
#   'previous',
#   'generation',
#   'constantly',
#   'make',
#   'progres',
#   'not',
#   'touch',
#   'time'],
#  ['deployment'],
#  ['perhaps',
#   'i',
#   'just',
#   'finish',
#   'internship',
#   'i',
#   'choose',
#   'movie',
#   'beginning',
#   'film',
#   'fascinate',
#   'retire',
#   'seventy',
#   'year',
#   'old',
#   'man',
#   'decide',
#   'return',
#   'work',
#   'because',
#   'have',
#   'sense',
#   'belonging'],
#  ['be',
#   'get',
#   'life',
#   'go',
#   'stand',
#   'up',
#   'go',
#   'go',
#   'anywhere',
#   'so',
#   'come',
#   'new',
#   'fashion',
#   'clothing',
#   'company',
#   'become',
#   'elderly',
#   'intern',
#   'set',
#   'here',
#   'deployment'],
#  ['frankly',
#   'intern',
#   'be',
#   'not',
#   'i',
#   'expect',
#   'week',
#   'fortunately',
#   'be',
#   'recommendation',
#   'page',
#   'time',
#   'fortunately',
#   'i',
#   'choose',
#   'little',
#   'hesitation',
#   'be',
#   'choose',
#   'entirely',
#   'anne',
#   'hathaway',
#   'sure',
#   'enough',
#   'goddes',
#   'produce',
#   'must',
#   'be',
#   'fine',
#   'product'],
#  ['queen',
#   'prada',
#   's',
#   'intern',
#   'have',
#   'be',
#   'promote',
#   'boss',
#   'annie',
#   'intern',
#   'have',
#   'be',
#   'able',
#   'adapt',
#   'fast',
#   'pace',
#   'take',
#   'initiative',
#   'deployment'],
#  ['first',
#   'i',
#   'run',
#   'hathaway',
#   'i',
#   'saw',
#   'topic',
#   'intern',
#   'i',
#   'think',
#   'i',
#   'should',
#   'tell',
#   'story',
#   'college',
#   'graduate',
#   'enter',
#   'workplace',
#   'i',
#   'think',
#   'i',
#   'would',
#   'soon',
#   'become',
#   'social',
#   'person',
#   'i',
#   'plan',
#   'take',
#   'look',
#   'such',
#   'expectation',
#   'there',
#   'will',
#   'be',
#   'more',
#   'excitement',
#   'look'],
#  ['ben',
#   's',
#   'performance',
#   'should',
#   'be',
#   'continue',
#   'knight',
#   'culture',
#   'also',
#   'see',
#   'artisan',
#   'spirit',
#   'i',
#   'get',
#   'old',
#   'can',
#   'live',
#   'ben',
#   'deployment'],
#  ['one'],
#  ['i',
#   'go',
#   'anne',
#   'hathaway',
#   's',
#   'best',
#   'movie',
#   'relax',
#   'workplace',
#   'comedy',
#   'i',
#   'be',
#   'disappoint',
#   'be',
#   'true',
#   'anne',
#   'hathaway',
#   'be',
#   'light',
#   'hearted',
#   'work',
#   'comedy',
#   'be',
#   'undeniable',
#   'be',
#   'standard',
#   'inspirational',
#   'film',
#   'up',
#   'down'],
#  ['two'],
#  ['whole',
#   'movie',
#   'really',
#   'do',
#   'not',
#   'have',
#   'up',
#   'downs',
#   'movie',
#   'do',
#   'raise',
#   'lot',
#   'problem',
#   'workplace',
#   'deployment'],
#  ['begin',
#   'movie',
#   'i',
#   'saw',
#   'old',
#   'man',
#   'high',
#   'emotional',
#   'intelligence',
#   'intelligence',
#   'always',
#   'watch',
#   'seventy',
#   'year',
#   'age',
#   'circle',
#   'fate',
#   'let',
#   'return',
#   'factory',
#   'have',
#   'spend',
#   'more',
#   'forty',
#   'year',
#   'familiarize',
#   'face',
#   'strange',
#   'new',
#   'world',
#   'start',
#   'work',
#   'again',
#   'start',
#   'date',
#   'again',
#   'set',
#   'movie',
#   'be',
#   'still',
#   'intriguing',
#   'grandpa',
#   'face',
#   'new',
#   'social',
#   'new',
#   'job',
#   'type',
#   'intern',
#   'deployment'],
#  ['watch',
#   'movie',
#   'i',
#   'be',
#   'fascinate',
#   'old',
#   'gentleman',
#   'have',
#   'slightly',
#   'antique',
#   'style',
#   'be',
#   'american',
#   'version',
#   'word',
#   'i',
#   'be',
#   'glad',
#   'emotional',
#   'line',
#   'heroine',
#   'be',
#   'not',
#   'vulgar',
#   'love',
#   'not',
#   'ambiguous',
#   'more',
#   'father',
#   's',
#   'communication',
#   'daughter',
#   'concern',
#   'friend'],
#  ['then',
#   'come',
#   'gentleman',
#   's',
#   'delightful',
#   'reason',
#   'logic',
#   'planning',
#   'courage',
#   'so',
#   'deployment'],
#  ['blake',
#   'snyder',
#   'screenplay',
#   'beatwatch',
#   'title',
#   'intern',
#   'genre',
#   'fellowship',
#   'date',
#   'two',
#   'thousand',
#   'twenty',
#   'one',
#   'pfive',
#   'male',
#   'protagonist',
#   'see',
#   'list',
#   'intern',
#   'be',
#   'say',
#   'old',
#   'lady',
#   'i',
#   'can',
#   'not',
#   'understand',
#   'say',
#   'be',
#   'not',
#   'young',
#   'anymore',
#   'pave',
#   'way',
#   'pone',
#   'ten',
#   'exhibition',
#   'deployment'],
#  ['retired',
#   'vice',
#   'president',
#   'start',
#   'up',
#   'internet',
#   'company',
#   'do',
#   'intern',
#   'female',
#   'boss',
#   'help',
#   'young',
#   'person',
#   'find',
#   'direction',
#   'work',
#   'life',
#   'find',
#   'own',
#   'plot',
#   'not',
#   'too',
#   'boring',
#   'acting',
#   'be',
#   'still',
#   'unremarkable',
#   'good',
#   'look',
#   'princess',
#   'diary',
#   'woman',
#   'prada',
#   'look',
#   'deployment'],
#  ['clothe', 'wear', 'word', 'write', 'word', 'say', 'food', 'eat', 'be', 'be'],
#  ['big',
#   'feel',
#   'watch',
#   'movie',
#   'be',
#   'ben',
#   'always',
#   'clean',
#   'wear',
#   'suit',
#   'behavior',
#   'be',
#   'also',
#   'subtly',
#   'affect',
#   'everyone',
#   'such',
#   'fat',
#   'little',
#   'man',
#   'house',
#   'start',
#   'dres',
#   'formal',
#   'professional'],
#  ['one'],
#  ['person', 'wear', 'do', 'be', 'deployment'],
#  ['successful',
#   'senior',
#   'workplace',
#   'have',
#   'always',
#   'be',
#   'serious',
#   'sincere',
#   'humble',
#   'active',
#   'friendly',
#   'principled',
#   'never',
#   'cross',
#   'line',
#   'i',
#   'think',
#   'be',
#   'kind',
#   'cultivation',
#   'wisdom',
#   'which',
#   'be',
#   'worth',
#   'learn',
#   'workplace',
#   'help',
#   'integrate',
#   'new',
#   'environment',
#   'get',
#   'respect',
#   'other',
#   'faster',
#   'deployment'],
#  ['one'],
#  ['career',
#   'family',
#   'elder',
#   'friends',
#   'lover',
#   'child',
#   'daily',
#   'necessity',
#   'everyday',
#   'life',
#   'appear',
#   'time',
#   'only',
#   'have',
#   'make',
#   'choice',
#   'do',
#   'realize',
#   'be',
#   'so',
#   'important',
#   'sometime',
#   'choose',
#   'forgive',
#   'face',
#   'betrayal',
#   'life',
#   'may',
#   'require',
#   'be',
#   'soft',
#   'there',
#   'be',
#   'surprise',
#   'everywhere',
#   'life',
#   'as',
#   'long',
#   'be',
#   'willing',
#   'go',
#   'out',
#   'experience',
#   'time',
#   'deployment'],
#  ['work',
#   'i',
#   'watch',
#   'movie',
#   'begin',
#   'movie',
#   'old',
#   'man',
#   's',
#   'delicate',
#   'elegant',
#   'clothe',
#   'make',
#   'feel',
#   'comfortable',
#   'such',
#   'spring',
#   'breeze',
#   'then',
#   'later',
#   'old',
#   'man',
#   'be',
#   'always',
#   'elegant',
#   'always',
#   'enthusiastic',
#   'always',
#   'positive',
#   'warm',
#   'wise',
#   'always',
#   'talk',
#   'forever',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['demonstrate', 'that', 'competence', 'workplace', 'can', 'be', 'transfer'],
#  ['last', 'job', 'take', 'position', 'vice', 'president'],
#  ['can',
#   'do',
#   'vice',
#   'presidential',
#   'level',
#   'back',
#   'intern',
#   'performance',
#   'workplace',
#   'can',
#   'be',
#   'see',
#   'characteristic',
#   'be',
#   'very',
#   'worth',
#   'learn',
#   'new',
#   'even',
#   'veteran',
#   'workplace',
#   'be',
#   'willing',
#   'try',
#   'new',
#   'thing',
#   'embrace',
#   'challenge',
#   'seventy',
#   'year',
#   'old',
#   'still',
#   'willing',
#   'learn',
#   'internet',
#   'deployment'],
#  ['movie',
#   'have',
#   'too',
#   'much',
#   'conversational',
#   'art',
#   'record',
#   'don',
#   's',
#   'life',
#   'state',
#   'should',
#   'be',
#   'most',
#   'person',
#   'aspire'],
#  ['don',
#   'first',
#   'ask',
#   'assistant',
#   'pay',
#   'attention',
#   'see',
#   'boss',
#   'driver',
#   'drink',
#   'still',
#   'give',
#   'two',
#   'choice',
#   'deployment'],
#  ['movie',
#   'that',
#   'make',
#   'very',
#   'comfortable',
#   'watch',
#   'particular',
#   'most',
#   'first',
#   'half',
#   'relax',
#   'small',
#   'humor',
#   'let',
#   'almost',
#   'whole',
#   'mouth',
#   'whole',
#   'time',
#   'two',
#   'main',
#   'character',
#   'act',
#   'be',
#   'natural',
#   'sincere',
#   'not',
#   'flamboyant',
#   'true',
#   'feeling',
#   'be',
#   'easy',
#   'get',
#   'play',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['american',
#   'light',
#   'comedy',
#   'film',
#   'intern',
#   'have',
#   'variety',
#   'routine',
#   'perfect',
#   'plot',
#   'direction',
#   'familiar',
#   'comedy',
#   'plot',
#   'well',
#   'know',
#   'anne',
#   'hathaway',
#   'anyone',
#   'be',
#   'see',
#   'know',
#   'movie',
#   'be',
#   'perfect',
#   'story',
#   'that',
#   'be',
#   'inspire',
#   'just',
#   'one',
#   'idea',
#   'many',
#   'film',
#   'few',
#   'film',
#   'have',
#   'have',
#   'such',
#   'perfect',
#   'succes'],
#  ['time', 'show', 'many', 'person', 'be', 'not', 'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['ben',
#   'nearly',
#   'seventy',
#   'join',
#   'internet',
#   'company',
#   'intern',
#   'workplace',
#   'story',
#   'that',
#   'take',
#   'place',
#   'founder',
#   'jule',
#   'ben',
#   'be',
#   'admirable',
#   'mature',
#   'gentleman',
#   'attitude',
#   'spirit',
#   'life',
#   'have',
#   'inspire',
#   'lot',
#   'be',
#   'probably',
#   'i',
#   'want',
#   'be',
#   'balance',
#   'influential',
#   'person'],
#  ...]

# %%
# stopwords
def remove_verbs(words):
    verbs_to_remove = {"am", "be", "are", "was", "were", "being", "is"}
    filtered_words = [word for word in words if word not in verbs_to_remove]
    return filtered_words

processed_sentences_no_stopwords = [remove_verbs(word) for word in processed_sentences]

# %%
processed_sentences_no_stopwords
# Out:
# [['even',
#   'such',
#   'beautiful',
#   'successful',
#   'woman',
#   'american',
#   'movie',
#   'have',
#   'accept',
#   'such',
#   'ordinary',
#   'cheating',
#   'husband'],
#  ['depend',
#   'first',
#   'half',
#   'look',
#   'good',
#   'second',
#   'half',
#   'value',
#   'swallow',
#   'conservative',
#   'retreated',
#   's',
#   'person',
#   'little',
#   'too',
#   'perfect'],
#  ['world',
#   'will',
#   'good',
#   'place',
#   'i',
#   'can',
#   'make',
#   'one',
#   'two',
#   'such',
#   'warm',
#   'skit',
#   'year',
#   'look',
#   'good',
#   'release',
#   'tear'],
#  ['hathaway',
#   'intervene',
#   'streep',
#   's',
#   'strongwoman',
#   'life',
#   'now',
#   'de',
#   'anti',
#   'invasion',
#   'hathaway',
#   'life',
#   'actually',
#   'little',
#   'ambitious',
#   'try',
#   'discuss',
#   'career',
#   'woman',
#   'old',
#   'generation',
#   'float',
#   'bit',
#   'i',
#   'hathaway',
#   'lot',
#   'little',
#   'expression',
#   'have',
#   'sense',
#   'rehearsal',
#   'release',
#   'especially',
#   'compare',
#   'de',
#   'share',
#   'de',
#   'really',
#   'handsome'],
#  ['long',
#   'time',
#   'i',
#   'have',
#   'see',
#   'princess',
#   'anne',
#   'movie',
#   'feel',
#   'especially',
#   'fashion',
#   'witch',
#   'have',
#   'set',
#   'bar',
#   'so',
#   'high',
#   'professional',
#   'woman',
#   'young',
#   'person',
#   'also',
#   'too',
#   'warm',
#   'mediocre'],
#  ['bad',
#   'thing',
#   'act',
#   'bone',
#   'play',
#   'not',
#   'good',
#   'enough',
#   'play',
#   'eat',
#   'up',
#   'other',
#   'party'],
#  ['anne', 'hathaway', 'look', 'great'],
#  ['freshly',
#   'hold',
#   'laughter',
#   'detail',
#   'tap',
#   'word',
#   'massage',
#   'will',
#   'hard',
#   'thunder',
#   'snore',
#   'lifetime',
#   'experience',
#   'old',
#   'ginger',
#   'matter',
#   'high',
#   'academic',
#   'qualification',
#   'also',
#   'need',
#   'get',
#   'job',
#   'recognition',
#   'find',
#   'rare',
#   'modern',
#   'gentleman',
#   'manner',
#   'meyer',
#   'can',
#   'always',
#   'take',
#   'good',
#   'picture',
#   'vulgar',
#   'subject',
#   'matter',
#   'favorite',
#   'chick',
#   'flick',
#   'director'],
#  ['hopefully',
#   'just',
#   'momentary',
#   'misjudgment',
#   'not',
#   'love',
#   'joy',
#   'deserve',
#   'slow',
#   'down',
#   'enjoy',
#   'life',
#   'tai',
#   'chi'],
#  ['encounter',
#   'angel',
#   'high',
#   'emotional',
#   'intelligence',
#   'sweetheart',
#   'brooklyn',
#   'geniu',
#   'rub',
#   'japanese',
#   'style',
#   'warm',
#   'serenade',
#   'homage',
#   'back',
#   'back',
#   'soundtrack',
#   'fight',
#   'off',
#   'gloom',
#   'thirty',
#   'year',
#   'old',
#   'crisi',
#   'jule',
#   'future',
#   'ben',
#   'one',
#   'own',
#   'world',
#   'that',
#   'most',
#   'beautiful',
#   'thing',
#   'life'],
#  ['hathaway',
#   's',
#   'point',
#   'view',
#   'do',
#   'not',
#   'want',
#   'able',
#   'have',
#   'old',
#   'man',
#   'have',
#   'experience',
#   'hardship',
#   'life',
#   'content',
#   'guidance',
#   'actually',
#   'show',
#   'begin',
#   'end',
#   'taijiquan',
#   'slow',
#   'slow',
#   'slow'],
#  ['good',
#   'observation',
#   'not',
#   'humble',
#   'warm',
#   'courteous',
#   'advice',
#   'never',
#   'cross',
#   'line',
#   'principled',
#   'interesting',
#   'rich',
#   'experience',
#   'never',
#   'show',
#   'off',
#   'do',
#   'thing',
#   'properly',
#   'ben',
#   'nearly',
#   'seventy',
#   'year',
#   'old',
#   'model',
#   'generation',
#   'movie',
#   'also',
#   'saw',
#   's',
#   'old',
#   'age',
#   'calm',
#   'intelligent',
#   'side',
#   'really',
#   'powerful',
#   'play',
#   'god',
#   'seven',
#   'six'],
#  ['year',
#   'half',
#   'e',
#   'commerce',
#   'woman',
#   'can',
#   'run',
#   'business',
#   'man',
#   'can',
#   'domestic',
#   'man',
#   'new',
#   'person',
#   'workplace',
#   'no',
#   'longer',
#   'synonymous',
#   'early',
#   'twenty',
#   'can',
#   'still',
#   'work',
#   'interns',
#   'age',
#   'seventy',
#   'time',
#   'gender',
#   'age',
#   'downplay',
#   'as',
#   'long',
#   'have',
#   'healthy',
#   'body',
#   'positive',
#   'mind',
#   'anything',
#   'possible',
#   'very',
#   'warm',
#   'film',
#   'annie',
#   's',
#   'clothe',
#   'look',
#   'great'],
#  ['niro', 'so', 'warm', 'felt', 'tendernes', 'nobility', 'screen'],
#  ['cold', 'drink', 'chicken', 'soup', 'driver', 's', 'fan', 'disappear'],
#  ['more',
#   'standard',
#   'chicken',
#   'flick',
#   'three',
#   'view',
#   'humor',
#   'famous',
#   'character',
#   'most',
#   'important',
#   'thing',
#   'have'],
#  ['case',
#   'development',
#   'chuck',
#   'flick',
#   'love',
#   'not',
#   'sacrifice',
#   'career',
#   'family',
#   'huge',
#   'social',
#   'progres'],
#  ['robert', 'grandpa', 'fly', 'house'],
#  ['novelty',
#   'film',
#   'lie',
#   'balance',
#   'balance',
#   'seventy',
#   'year',
#   'old',
#   'face',
#   'up',
#   'own',
#   'social',
#   'status',
#   'quo',
#   'do',
#   'not',
#   'rely',
#   'old',
#   'sell',
#   'old',
#   'do',
#   'not',
#   'emphasize',
#   'past',
#   'silently',
#   'rely',
#   'own',
#   'experience',
#   'help',
#   'young',
#   'person',
#   'continue',
#   'achieve',
#   'own',
#   'value',
#   'thirty',
#   'year',
#   'old',
#   'gradually',
#   'learn',
#   'balance',
#   'everything',
#   'life',
#   'not',
#   'run',
#   'away',
#   'problem',
#   'marriage',
#   'not',
#   'deliberately',
#   'curb',
#   'inner',
#   'desire',
#   'thing',
#   'difficult',
#   'never',
#   'give',
#   'up',
#   'enthusiasm',
#   'learn',
#   'courage',
#   'start'],
#  ['old',
#   'school',
#   'not',
#   'just',
#   'retro',
#   'not',
#   'old',
#   'fashion',
#   'not',
#   'hip',
#   'hop',
#   'just',
#   'part',
#   'person',
#   'insist',
#   'good',
#   'thing',
#   'traditional',
#   'habit',
#   'idea'],
#  ['watch',
#   'episode',
#   'plane',
#   'new',
#   'york',
#   'san',
#   'francisco',
#   'feature',
#   'brooklyn',
#   'bridge',
#   'golden',
#   'gate',
#   'bridge'],
#  ['basically',
#   'rely',
#   'de',
#   'support',
#   'field',
#   'hathaway',
#   'win',
#   'award',
#   'recent',
#   'year',
#   'there',
#   'impressive',
#   'role',
#   'do',
#   'not',
#   'seem'],
#  ['most',
#   'version',
#   'post',
#   'marriage',
#   'magnification',
#   'light',
#   'truck',
#   'white',
#   'lily',
#   'united',
#   'state',
#   'course',
#   'lot',
#   'fun',
#   'something'],
#  ['do',
#   'not',
#   'learn',
#   'robert',
#   'dinillo',
#   'stand',
#   'entrance',
#   'alley',
#   'wait'],
#  ['cheesy',
#   'yet',
#   'comfort',
#   'enjoyment',
#   'robert',
#   'deniro',
#   'just',
#   'play',
#   'perfect',
#   'silver',
#   'daddy',
#   'woman',
#   'man',
#   's',
#   'dream',
#   'kidding',
#   'i',
#   'put',
#   'woman',
#   'man',
#   'hope',
#   'see',
#   'i',
#   'suggest',
#   'here'],
#  ['nancy',
#   'meyer',
#   'have',
#   'not',
#   'make',
#   'movie',
#   'year',
#   'focus',
#   'old',
#   'person',
#   's',
#   'social',
#   'relationship',
#   'decades',
#   'up',
#   'date',
#   'start',
#   'up',
#   'female',
#   'entrepreneurial',
#   'setting',
#   'much',
#   'more',
#   'interesting'],
#  ['warm',
#   'hearted',
#   'comedy',
#   'modern',
#   'costume',
#   'anne',
#   'can',
#   'not',
#   'more',
#   'beautiful',
#   'performance',
#   'big',
#   'attraction',
#   'story',
#   'less',
#   'fashionable',
#   'queen',
#   'prada'],
#  ['watch',
#   'movie',
#   'i',
#   'feel',
#   'i',
#   'have',
#   'most',
#   'say',
#   'i',
#   'do',
#   'same',
#   'thing',
#   'woman',
#   'i',
#   'ten',
#   'zero',
#   'time',
#   'small',
#   'have',
#   'super',
#   'similarity',
#   'have',
#   'more',
#   'learn',
#   'there',
#   'countless',
#   'scene',
#   'move',
#   'tear',
#   'i',
#   'think',
#   'i',
#   'go',
#   'watch',
#   'again'],
#  ['best', 'tribute', 'movie'],
#  ['i',
#   'wake',
#   'up',
#   'five',
#   'm',
#   'watch',
#   'movie',
#   'i',
#   'have',
#   'always',
#   'want',
#   'see',
#   'oh',
#   'god',
#   'begin',
#   'great',
#   'day'],
#  ['watch',
#   'woman',
#   'workplace',
#   'movie',
#   'flip',
#   'woman',
#   's',
#   'fashion',
#   'magazine',
#   'flip',
#   'picture',
#   'teach',
#   'dres',
#   'read',
#   'column',
#   'drink',
#   'feminist',
#   'chicken',
#   'soup',
#   'life',
#   'too',
#   'easy',
#   'play',
#   'taijiquan',
#   'can',
#   'balance',
#   'casting',
#   'still',
#   'good',
#   'stay',
#   'classic'],
#  ['too',
#   'boring',
#   'director',
#   'shoot',
#   'love',
#   'vacation',
#   'shoot',
#   'workplace',
#   'story',
#   'whole',
#   'story',
#   'try',
#   'make',
#   'fuss',
#   'flat',
#   'life',
#   'so',
#   'mediocre'],
#  ['look', 'great'],
#  ['go', 'gentleman', 'old', 'man', 'go', 'passionate', 'goddes'],
#  ['one', 'hundred', 'thirty', 'star', 'end'],
#  ['urban',
#   'version',
#   'elderly',
#   'young',
#   'girl',
#   'matter',
#   'age',
#   'group',
#   'person',
#   'always',
#   'need',
#   'please',
#   'other',
#   'order',
#   'run',
#   'other'],
#  ['simple',
#   'comfortable',
#   'lack',
#   'depth',
#   'make',
#   'up',
#   'warmth',
#   'robert',
#   'simply',
#   'handsome',
#   'hathaway',
#   'so',
#   'pretty',
#   'expression',
#   'so',
#   'tight',
#   'little',
#   'girl',
#   'have',
#   'assistant',
#   'demon',
#   'head',
#   'woman',
#   'become',
#   'strongwoman',
#   'p'],
#  ['s',
#   'movie',
#   'textbook',
#   'level',
#   'dress',
#   'tutorial',
#   'hathaway',
#   's',
#   'light',
#   'mature',
#   'girl',
#   'ol',
#   'style',
#   'robert',
#   's',
#   'retro',
#   'suit',
#   'style',
#   'set',
#   'please',
#   'eye'],
#  ['so',
#   'happy',
#   'marriage',
#   'strong',
#   'woman',
#   'unsolvable',
#   'especially',
#   'water',
#   'sign',
#   'scumman'],
#  ['good',
#   'way',
#   'get',
#   'rid',
#   'cheat',
#   'husband',
#   'unfortunately',
#   'not',
#   'many',
#   'man',
#   'have',
#   'kind',
#   'awarenes'],
#  ['i',
#   'think',
#   'should',
#   'show',
#   'christmas',
#   'day',
#   'buy',
#   'warm',
#   'ginger',
#   'coffee',
#   'i',
#   'have',
#   'see',
#   'robert',
#   's',
#   'grandpa',
#   'movie',
#   'brain',
#   'powder',
#   'i',
#   'love',
#   'warm',
#   'bright',
#   'image',
#   'new',
#   'york',
#   'comedy',
#   'movie',
#   'unburden',
#   'circumstance'],
#  ['warm',
#   'inspiring',
#   'humorous',
#   'high',
#   'degree',
#   'completion',
#   'i',
#   'also',
#   'anna',
#   's',
#   'dres',
#   'movie',
#   'exemplary',
#   'work',
#   'woman',
#   'eastern',
#   'united',
#   'state'],
#  ['clothing',
#   'interior',
#   'design',
#   'guideline',
#   'first',
#   'half',
#   'more',
#   'interesting',
#   'relationship',
#   'harmonious',
#   'stereotype',
#   'gradually',
#   'appear',
#   'especially',
#   'addition',
#   'husband',
#   'character',
#   'entire',
#   'film',
#   'almost',
#   'degenerate',
#   'standardized',
#   'bad',
#   'film'],
#  ['i',
#   'think',
#   'intern',
#   'meant',
#   'robert',
#   'anne',
#   'hathaway',
#   'too',
#   'weak',
#   'hold',
#   'such',
#   'strongwoman'],
#  ['bowl',
#   'full',
#   'chicken',
#   'soup',
#   'i',
#   'think',
#   'robert',
#   'hathaway',
#   'go',
#   'roll',
#   'sheet'],
#  ['textbook',
#   'chicken',
#   'film',
#   'seriously',
#   'hathaway',
#   'play',
#   'feminist',
#   'figure',
#   'whole',
#   'place',
#   'taught',
#   'daddy',
#   'really',
#   'okay'],
#  ['three',
#   'half',
#   'star',
#   'i',
#   'watch',
#   'movie',
#   'robert',
#   'kind',
#   'american',
#   'feminine',
#   'inspirational',
#   'film',
#   'not',
#   'really',
#   'thing'],
#  ['very',
#   'warm',
#   'fairy',
#   'tale',
#   'wind',
#   'two',
#   'hour',
#   'do',
#   'not',
#   'feel',
#   'long',
#   'background',
#   'music',
#   'have',
#   'always',
#   'similar',
#   'tone',
#   'little',
#   'monotonous',
#   'princes',
#   'ann',
#   'play',
#   'bos',
#   'also',
#   'assistant',
#   'feel',
#   'drunk',
#   'woman',
#   's',
#   'right',
#   'bit',
#   'superficial',
#   'godfather',
#   'cute'],
#  ['i',
#   'have',
#   'have',
#   'lot',
#   'confuse',
#   'moment',
#   'year',
#   'few',
#   'time',
#   'i',
#   'naturally',
#   'think',
#   'dad',
#   'then',
#   'i',
#   'find',
#   'just',
#   'want',
#   'go',
#   'back',
#   'hometown',
#   'work',
#   'civil',
#   'servant',
#   'movie',
#   'movie',
#   'reality',
#   'reality',
#   'kind',
#   'feminine',
#   'color',
#   'allow',
#   'woman',
#   'have',
#   'sufficient',
#   'lewd',
#   'space',
#   'subject',
#   'matter',
#   'begin',
#   'bj',
#   'have',
#   'not',
#   'go',
#   'fashion',
#   'indeed'],
#  ['even',
#   'find',
#   'ultimate',
#   'handsome',
#   'guy',
#   'do',
#   'not',
#   'end',
#   'up',
#   'own'],
#  ['politically',
#   'correct',
#   'interesting',
#   'material',
#   'selection',
#   'strong',
#   'cas',
#   'whole',
#   'movie',
#   'full',
#   'embarrassment',
#   'helplessnes',
#   'apart',
#   'weak',
#   'tension',
#   'mainline',
#   'drama',
#   'old',
#   'man',
#   's',
#   'boring',
#   'personality',
#   'loose',
#   'narrative',
#   'protagonist',
#   's',
#   'lack',
#   'chemistry',
#   'fact',
#   'holm',
#   'office',
#   'live',
#   'too',
#   'much',
#   'model',
#   'house',
#   'hotel',
#   'use',
#   'look',
#   'annie',
#   'start',
#   'fashion',
#   'show',
#   'again',
#   'clothe',
#   'do',
#   'not',
#   'match',
#   'too',
#   'well'],
#  ['little', 'too', 'good', 'i', 'do', 'chicken', 'soup'],
#  ['year',
#   'dres',
#   'have',
#   'change',
#   'msixty',
#   'five',
#   'high',
#   'end',
#   'suit',
#   'walk',
#   'posture',
#   'have',
#   'not',
#   'change'],
#  ['drink',
#   'chicken',
#   'soup',
#   'i',
#   'will',
#   'identify',
#   'robert',
#   'anne',
#   'hathaway',
#   'brand'],
#  ['easy',
#   'effortless',
#   'comedy',
#   'super',
#   'cute',
#   'hathaway',
#   'also',
#   'beautiful',
#   'glitter',
#   'watch',
#   'whole',
#   'person',
#   'feel',
#   'very',
#   'happy'],
#  ['ahahahahahahahahaha',
#   'ben',
#   'tell',
#   'jule',
#   'pay',
#   'attention',
#   'inner',
#   'peace',
#   'bridge',
#   'play',
#   'taiji',
#   'tribute',
#   'kung',
#   'fu',
#   'panda'],
#  ['i', 'want', 'four', 'star'],
#  ['standard',
#   'hollywood',
#   'movie',
#   'end',
#   'hathaway',
#   'scumboy',
#   'take',
#   'point',
#   'off'],
#  ['late', 'life', 'corleone'],
#  ['content',
#   'seem',
#   'line',
#   'trend',
#   'actually',
#   'one',
#   'movie',
#   'that',
#   'basically',
#   'touch',
#   'time',
#   'screenwriter',
#   's',
#   'total',
#   'failure',
#   'create',
#   'conflict',
#   'just',
#   'hot',
#   'pot',
#   'sugar',
#   'water'],
#  ['happiness',
#   'cherish',
#   'have',
#   'now',
#   'have',
#   'now',
#   'do',
#   'not',
#   'know',
#   'will',
#   'lose',
#   'do',
#   'like',
#   'stick',
#   'original',
#   'self',
#   'treat',
#   'life',
#   'tolerant',
#   'heart'],
#  ['walk', 'edge', 'strange', 'feeling'],
#  ['problem',
#   's',
#   'age',
#   'many',
#   'scene',
#   'company',
#   's',
#   'young',
#   'employee',
#   'show',
#   'obvious',
#   'fatigue',
#   'perfunctory',
#   'more',
#   'performance',
#   'style',
#   'not',
#   'suitable',
#   'appearance',
#   'external',
#   'charm',
#   'show',
#   'comedy',
#   'script',
#   'impose',
#   'charismatic',
#   'aura',
#   'goodwill',
#   'make',
#   'quickly',
#   'focus',
#   'company',
#   's',
#   'attention',
#   'audience',
#   'do',
#   'not',
#   'really',
#   'feel',
#   'should'],
#  ['blink',
#   'act',
#   'high',
#   'end',
#   'atmospheric',
#   'travel',
#   'create',
#   'ambiguous',
#   'suspense',
#   'afraid',
#   'embarrassment',
#   'i',
#   'nervous',
#   'good',
#   'feel',
#   'progres',
#   'society'],
#  ['anne', 'hathaway', 'assistant', 'bos', 'still', 'wear', 'navy', 'sweater'],
#  ['rather', 'more', 'mediocre', 'expect', 'i', 'completely', 'mark', 'know'],
#  ['look',
#   'i',
#   'really',
#   'think',
#   'person',
#   'get',
#   'old',
#   'whole',
#   'character',
#   'will',
#   'change',
#   'round'],
#  ['life',
#   'also',
#   'like',
#   'play',
#   'tai',
#   'chi',
#   'balance',
#   'one',
#   'move',
#   'breathing',
#   'warm',
#   'little',
#   'piece',
#   'life',
#   'suitable',
#   'christma',
#   'eve',
#   'heal',
#   'mood',
#   'favorite',
#   'ben',
#   'austin',
#   'overtime',
#   'night',
#   'conversation',
#   'warm',
#   'light',
#   'ben',
#   'talk',
#   'forty',
#   'year',
#   'ago',
#   'use',
#   'work',
#   'place',
#   'brick',
#   'tile',
#   'paulownia',
#   'tree',
#   'front',
#   'window',
#   'so',
#   'familiar',
#   'tacit',
#   'understand',
#   'two',
#   'quietly',
#   'grow',
#   'unfortunately',
#   'film',
#   'too',
#   'formal',
#   'gentleman',
#   'must',
#   'bring',
#   'handkerchief',
#   'go',
#   'out'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'anne',
#   'hathaway',
#   'love',
#   'grow',
#   'up',
#   'four',
#   'half',
#   'star',
#   'first',
#   'have',
#   'translate',
#   'title',
#   'film',
#   'inexplicable',
#   'hong',
#   'kong',
#   'name',
#   'win',
#   'again',
#   'old',
#   'strong',
#   'old',
#   'man',
#   'princes',
#   'noble',
#   'couple',
#   'give',
#   'bowl',
#   'super',
#   'positive',
#   'energy',
#   'heart',
#   'chicken',
#   'soup',
#   'there',
#   'funny',
#   'zhong',
#   'want',
#   'master',
#   'do',
#   'job',
#   'steal',
#   'only',
#   'not',
#   'hurt',
#   'old',
#   'mother',
#   's',
#   'heart',
#   'kind',
#   'movie',
#   'have',
#   'good',
#   'return'],
#  ['robert',
#   's',
#   'eq',
#   'so',
#   'high',
#   'can',
#   'use',
#   'work',
#   'textbook',
#   'not',
#   'warn',
#   'boss',
#   'pay',
#   'attention',
#   'boss',
#   's',
#   'real',
#   'need',
#   'handle',
#   'relationship',
#   'colleague',
#   'do',
#   'job',
#   'diligently'],
#  [],
#  ['almost', 'four', 'star'],
#  ['person',
#   'admire',
#   'old',
#   'habit',
#   'have',
#   'achieve',
#   'something',
#   'secondary',
#   'industry',
#   'style',
#   'play',
#   'write',
#   'too',
#   'casually',
#   'shelf',
#   'well',
#   'build',
#   'meat',
#   'inside',
#   'not',
#   'enough',
#   'porcelain',
#   'good',
#   'use',
#   'old',
#   'service',
#   'industry',
#   's',
#   'strict',
#   'self',
#   'discipline',
#   'executive',
#   'new',
#   'service',
#   'industry',
#   'break',
#   'dogma',
#   'female',
#   'strongman',
#   'start',
#   'point',
#   'storytelling'],
#  ['grandpa',
#   'so',
#   'cute',
#   'really',
#   'kind',
#   'do',
#   'not',
#   'know',
#   'refuse',
#   'other',
#   'leave',
#   'step',
#   'other',
#   'all',
#   'time',
#   'good',
#   'discover',
#   'joy',
#   'life'],
#  ['great', 'act', 'general', 'story'],
#  ['close',
#   'non',
#   'religious',
#   'relationship',
#   'can',
#   'think',
#   'bury',
#   'death',
#   'visual',
#   'hardware',
#   'beautiful',
#   'story',
#   'much',
#   'good',
#   'i',
#   'think',
#   'thankfully',
#   'not',
#   'cheesy',
#   'mother',
#   'daughter',
#   'relationship',
#   'sexism',
#   'retro',
#   'era',
#   'feel',
#   'one',
#   'point',
#   'bruise',
#   'that',
#   'have',
#   'not',
#   'scratch',
#   'era',
#   'one',
#   'involve',
#   'nostalgia',
#   'sigh'],
#  ['new', 'york', 'beautiful'],
#  ['old',
#   'intern',
#   's',
#   'idea',
#   'standard',
#   'chick',
#   'movie',
#   'add',
#   'warmth',
#   'theme',
#   'female',
#   'inspiration',
#   'ben',
#   'completely',
#   'retain',
#   'spirit',
#   'merit',
#   'traditional',
#   'industry',
#   'avoid',
#   'cost',
#   'move',
#   'secondary',
#   'tertiary',
#   'industry',
#   'nice',
#   'healing',
#   'ben',
#   'tell',
#   'wife',
#   's',
#   'story',
#   'not',
#   'long',
#   'enough',
#   'fall',
#   'completely',
#   'once',
#   'again',
#   'i',
#   'have',
#   'lament',
#   'story',
#   'romantic',
#   'as',
#   'long',
#   'middle',
#   'clas'],
#  ['two', 'star', 'well', 'choose', 'think', 'version', 'queen', 'prada'],
#  ['much',
#   'well',
#   'look',
#   'i',
#   'think',
#   'i',
#   'think',
#   'queen',
#   'prada',
#   'know',
#   'completely',
#   'upside',
#   'down',
#   'anne',
#   'hathaway',
#   's',
#   'outfit',
#   'really',
#   'too',
#   'good',
#   'look'],
#  ['airplane',
#   'movie',
#   'chicken',
#   'soup',
#   'content',
#   'preview',
#   'most',
#   'focu',
#   'various',
#   'interior',
#   'design',
#   'trance',
#   'can',
#   'also',
#   'see',
#   'hathaway',
#   'sit',
#   'door',
#   'aunt',
#   'may',
#   's',
#   'office',
#   'shadow',
#   'small',
#   'assistant',
#   'age',
#   'have',
#   'say',
#   'nothing',
#   'look',
#   'expression',
#   'can',
#   'become',
#   'life',
#   'mentor'],
#  ['unbreakable',
#   'truth',
#   'well',
#   'organize',
#   'hollywood',
#   'assembly',
#   'line',
#   'piece',
#   'regardless',
#   'quality',
#   'example',
#   'cultural',
#   'analysi'],
#  ['young',
#   'woman',
#   'attract',
#   'controlled',
#   'conservative',
#   'old',
#   'white',
#   'man',
#   'turn',
#   'away',
#   'contemporary',
#   'man',
#   'rely',
#   'help',
#   'career',
#   'family',
#   'affirmatism',
#   'always',
#   'end',
#   'positive',
#   'image',
#   'end',
#   'negative',
#   'one'],
#  ['forty',
#   'year',
#   'kramer',
#   'hollywood',
#   's',
#   'right',
#   'wing',
#   'stance',
#   'hypocritical',
#   'morality',
#   'have',
#   'never',
#   'change'],
#  ['pack',
#   'grow',
#   'up',
#   'fairy',
#   'tale',
#   'mainly',
#   'see',
#   'hostess',
#   'change',
#   'set',
#   'beautiful',
#   'clothe',
#   'drink',
#   'director',
#   'pour',
#   'chicken',
#   'soup',
#   'film',
#   'throw',
#   'out',
#   'topic',
#   'work',
#   'family',
#   'issue',
#   'there',
#   'workplace',
#   'entrepreneurship',
#   'continuation',
#   'problem',
#   'try',
#   'ask',
#   'which',
#   'one',
#   'take',
#   'seriously'],
#  ['end',
#   'nothing',
#   'resolve',
#   'all',
#   'thin',
#   'film',
#   'most',
#   'regrettable',
#   'thing',
#   'find',
#   'such',
#   'fresh',
#   'old',
#   'young',
#   'partner',
#   'not',
#   'able',
#   'dig',
#   'up',
#   'deep',
#   'spark',
#   'interaction'],
#  ['ever',
#   'i',
#   'find',
#   'out',
#   'director',
#   'nancy',
#   'meyer',
#   'also',
#   'hollywood',
#   's',
#   'top',
#   'interior',
#   'designer',
#   'i',
#   'have',
#   'star',
#   'hard',
#   'protagonist',
#   's',
#   'house',
#   'die',
#   'office',
#   'american',
#   'style',
#   'natural',
#   'light',
#   'window',
#   'too',
#   'comfortable',
#   'use',
#   'movie',
#   'pretty',
#   'cute'],
#  ['hathaway', 's', 'not', 'do', 'very', 'well'],
#  ['taipei',
#   'thin',
#   'overall',
#   'just',
#   'fashion',
#   'show',
#   'design',
#   'can',
#   'not',
#   'stand',
#   'taste',
#   'male',
#   'character',
#   'design',
#   'too',
#   'weak'],
#  ['robert',
#   'super',
#   'love',
#   'actor',
#   'annie',
#   's',
#   'youth',
#   'front',
#   'just',
#   'compound',
#   'need',
#   'plot',
#   'succes',
#   'casting',
#   'self',
#   'evident',
#   'addition',
#   'workplace',
#   'europe',
#   'united',
#   'state',
#   'very',
#   'natural',
#   'matter',
#   'shoot',
#   'such',
#   'office',
#   'hang',
#   'bell',
#   'such',
#   'office',
#   'masseuse',
#   'so',
#   'contrary',
#   'chinese',
#   'film',
#   'appear',
#   'workplace',
#   'there',
#   'mysterious',
#   'temperament',
#   'fuck',
#   'kid'],
#  ['i', 'do', 'not', 'know', 'short', 'ron', 'worth', 'four', 'star'],
#  ['chicken',
#   'soup',
#   'movie',
#   'guise',
#   'feminism',
#   'career',
#   'company',
#   'should',
#   'main',
#   'line',
#   'independent',
#   'female',
#   'screenwriter',
#   'not',
#   'very',
#   'perfunctory',
#   'female',
#   'image',
#   'i',
#   'busy',
#   'obsessive',
#   'first',
#   'find',
#   'ceo',
#   'too',
#   'large',
#   'control',
#   'finally',
#   'screenwriter',
#   'forget',
#   'ballast',
#   'only',
#   'become',
#   'family',
#   'vs',
#   'career',
#   'tangle'],
#  ['pseudo',
#   'feminist',
#   'movie',
#   'masterpiece',
#   'just',
#   'find',
#   'more',
#   'mature',
#   'male',
#   'mentor'],
#  ['overtime',
#   'night',
#   'talk',
#   'ben',
#   'back',
#   'work',
#   'original',
#   'place',
#   'arrange',
#   'space',
#   'big',
#   'paulownia',
#   'very',
#   'touching',
#   'new',
#   'start',
#   'office',
#   'scene',
#   'only',
#   'highlight',
#   'unattended',
#   'desk',
#   'conference',
#   'room',
#   'use',
#   'several',
#   'time',
#   'there',
#   'good',
#   'sense',
#   'scene',
#   'bridge',
#   'section',
#   'very',
#   'old',
#   'especially',
#   'four',
#   'man',
#   'steal',
#   'computer',
#   'section',
#   'which',
#   'compromise',
#   'contemporary',
#   'comedy',
#   'robert',
#   'perform',
#   'well',
#   'character',
#   'too',
#   'warm'],
#  ['i',
#   'have',
#   'complain',
#   'day',
#   'much',
#   'i',
#   'need',
#   'bowl',
#   'positive',
#   'energy',
#   'chicken',
#   'soup'],
#  ['seventy',
#   'year',
#   'old',
#   'veteran',
#   'handsome',
#   'man',
#   'help',
#   'taobao',
#   'young',
#   'woman',
#   'shop',
#   'manager',
#   'start',
#   'warm',
#   'inspirational',
#   'story',
#   'american',
#   'internet',
#   'entrepreneurship',
#   'ruin',
#   'life',
#   'cultivate',
#   'body',
#   'mind',
#   'still',
#   'rely',
#   'chinese',
#   'qigong'],
#  ['take',
#   'intern',
#   's',
#   'salary',
#   'work',
#   'twelve',
#   'hour',
#   'day',
#   'boss',
#   'also',
#   'help',
#   'bos',
#   'take',
#   'child',
#   'drive',
#   'not',
#   'disguise',
#   'squeeze',
#   'cheap',
#   'labor'],
#  ['bore', 'explode'],
#  ['hathaway',
#   's',
#   'husband',
#   'cheat',
#   'big',
#   'tension',
#   'movie',
#   'resolve',
#   'husband',
#   'confess',
#   'realize',
#   'real',
#   'reason',
#   'hathaway',
#   'originally',
#   'want',
#   'hire',
#   'external',
#   'management',
#   'vc',
#   'pressure',
#   'invisible',
#   'forgotten'],
#  ['i',
#   'think',
#   'end',
#   'point',
#   'integrate',
#   'senior',
#   'intern',
#   'modern',
#   'internet',
#   'workplace'],
#  ['result',
#   'female',
#   'bos',
#   'balance',
#   'career',
#   'family',
#   'finally',
#   'husband',
#   's',
#   'repentance',
#   'unnecessary'],
#  ['i',
#   'sorry',
#   'i',
#   'talk',
#   'today',
#   'elder',
#   'i',
#   'intern',
#   'i',
#   'have',
#   'see',
#   'too',
#   'much',
#   'i',
#   'need',
#   'tell',
#   'little',
#   'bit',
#   'life',
#   'experience'],
#  ['warm',
#   'friendship',
#   'there',
#   'bullet',
#   'curtain',
#   'cut',
#   'off',
#   'god',
#   'go',
#   'down',
#   'mountain',
#   'guides',
#   'person',
#   'go',
#   'up',
#   'mountain'],
#  ['robert',
#   's',
#   'charm',
#   'not',
#   'diminish',
#   'really',
#   'cool',
#   'compare',
#   'bunch',
#   'little',
#   'brat',
#   'movie',
#   'say',
#   'have',
#   'forty',
#   'two',
#   'year',
#   'old',
#   'marriage',
#   'eighteen',
#   'year',
#   'old',
#   'wife',
#   'love',
#   'mind',
#   'automatically',
#   'give',
#   'birth',
#   'godfather',
#   'stand',
#   'curtain',
#   'shoot',
#   'scene',
#   'eighteen',
#   'year',
#   'old',
#   'meet',
#   'wife',
#   'gangster',
#   'hahahahahahahahahaha'],
#  ['ten',
#   'year',
#   'later',
#   'little',
#   'assistant',
#   'grow',
#   'up',
#   'strong',
#   'woman',
#   'eye',
#   'not',
#   'broaden',
#   'first',
#   'half',
#   'movie',
#   'very',
#   'good',
#   'whole',
#   'thing',
#   'too',
#   'light',
#   'style',
#   'delete',
#   'email',
#   'very',
#   'abrupt'],
#  ['middle',
#   'rule',
#   'miao',
#   'da',
#   'good',
#   'old',
#   'grandfather',
#   'fragrant',
#   'standard',
#   'appearance',
#   'exquisite',
#   'high',
#   'cold',
#   'inner',
#   'fragile',
#   'crisi',
#   'strong',
#   'female',
#   'strongman',
#   'end',
#   'strong',
#   'point',
#   'piece',
#   'child',
#   's',
#   'right',
#   'pant',
#   'look',
#   'scum',
#   'man',
#   'confess',
#   'forgive',
#   'bridge',
#   'let',
#   'loose',
#   'know',
#   'must',
#   'spray',
#   'dog',
#   'do',
#   'say',
#   'wildfire',
#   'burn',
#   'spring',
#   'breeze',
#   'again',
#   'turbulent',
#   'heart',
#   'spring',
#   'up',
#   'first',
#   'time',
#   'pinch',
#   'will',
#   'grow',
#   'second',
#   'time',
#   'third',
#   'time',
#   'become',
#   'hulunbuir',
#   'prairie',
#   'very',
#   'cocky'],
#  ['bright',
#   'color',
#   'eternal',
#   'preach',
#   'elderly',
#   'minute',
#   'teach',
#   'little',
#   'woman',
#   'human',
#   'look',
#   'do',
#   'not',
#   'look',
#   'same'],
#  ['commercial',
#   'cute',
#   'story',
#   'only',
#   'thing',
#   'that',
#   'upsetting',
#   'word',
#   'feminine',
#   'right',
#   'appear',
#   'film',
#   's',
#   'usual',
#   'label'],
#  ['plot',
#   'gentle',
#   'old',
#   'drama',
#   'bone',
#   'acting',
#   'really',
#   'comfortable',
#   'great',
#   'secret',
#   'not',
#   'afraid',
#   'old',
#   'age',
#   'allow',
#   'time',
#   'give',
#   'valuable',
#   'wealth',
#   'not',
#   'just',
#   'wrinkle',
#   'gray',
#   'hair',
#   'also',
#   'fortunate',
#   'have',
#   'someone',
#   'talk',
#   'lose'],
#  ['grandpa', 'cook', 'bowl', 'soul', 'soup', 'drink'],
#  ['time',
#   'eat',
#   'just',
#   'look',
#   'around',
#   'spend',
#   'relax',
#   'night',
#   'burn',
#   'brain',
#   'course',
#   'do',
#   'not',
#   'care',
#   'keep',
#   'look',
#   'other',
#   'half',
#   'next',
#   'day'],
#  ['great',
#   'movie',
#   'watch',
#   'plane',
#   'hathaway',
#   's',
#   'fashion',
#   'show',
#   'gentlemanly',
#   'demeanor',
#   'really',
#   'charm'],
#  ['i',
#   'want',
#   'see',
#   'story',
#   'old',
#   'intern',
#   'okay',
#   'i',
#   'do',
#   'not',
#   'want',
#   'see',
#   'family',
#   'love',
#   'story',
#   'young',
#   'beautiful',
#   'entrepreneurial',
#   'executive',
#   'really',
#   'want',
#   'tell',
#   'such',
#   'story',
#   'please',
#   'change',
#   'intern',
#   'struggle',
#   'jule'],
#  ['never', 'wrong', 'do', 'right', 'thing'],
#  ['i',
#   'have',
#   'see',
#   'twice',
#   'short',
#   'time',
#   'attention',
#   'run',
#   'difficulty',
#   'i',
#   'think',
#   'annie',
#   'use',
#   'witch',
#   'wear',
#   'prada',
#   'now',
#   'intern',
#   'distant',
#   'idol',
#   'get',
#   'good',
#   'walk',
#   'well',
#   'glad'],
#  ['bore'],
#  ['internship',
#   'five',
#   'most',
#   'interesting',
#   'part',
#   'whole',
#   'movie',
#   'blue',
#   'frog'],
#  ['queen', 'prada', 'ii'],
#  ['subject',
#   'matter',
#   'really',
#   'brilliant',
#   'point',
#   'point',
#   'end',
#   'little',
#   'less',
#   'flavor'],
#  ['gentlemanly',
#   'workplace',
#   'light',
#   'comedy',
#   'young',
#   'old',
#   'post',
#   'cause',
#   'misplaced',
#   'laughter',
#   'relax',
#   'chicken',
#   'movie',
#   'pleasant',
#   'adult',
#   'fairy',
#   'tale',
#   'ten',
#   'year',
#   'later',
#   'hathaway',
#   'go',
#   'prada',
#   's',
#   'little',
#   'assistant',
#   'queen',
#   'become',
#   'more',
#   'more',
#   'woody',
#   'allen'],
#  ['i', 'saw', 'begin', 'plane', 'have', 'opportunity', 'continue', 'watch'],
#  ['nancy',
#   'meyer',
#   'script',
#   'direct',
#   'make',
#   'film',
#   'very',
#   'fluid',
#   'begin',
#   'story',
#   'move',
#   'forward',
#   'very',
#   'comfortable',
#   'cheerful',
#   'pace',
#   'which',
#   'bit',
#   'silk',
#   'soft',
#   'feeling',
#   'which',
#   'most',
#   'chinese',
#   'comedy',
#   'romantic',
#   'film',
#   'can',
#   'not',
#   'do',
#   'two',
#   'main',
#   'character',
#   'good',
#   'especially',
#   'hathaway',
#   'look',
#   'beautiful',
#   'fashionable',
#   'overall',
#   'standard',
#   'film',
#   'rather',
#   'average',
#   'lack',
#   'clear',
#   'theme',
#   'second',
#   'half',
#   'film',
#   'have',
#   'collapse',
#   'lot',
#   'far',
#   'inferior',
#   'devil',
#   'wear',
#   'prada'],
#  ['see',
#   'anne',
#   'come',
#   'proces',
#   'look',
#   'comfortable',
#   'plot',
#   'general',
#   'not',
#   'strengthen',
#   'old',
#   'point',
#   'comedy',
#   'play',
#   'sublimation',
#   'theme',
#   'there',
#   'lot',
#   'room'],
#  ['whole',
#   'world',
#   'pink',
#   'film',
#   'say',
#   'woman',
#   's',
#   'right',
#   'funny',
#   'general',
#   'chicken',
#   'flick',
#   'ah',
#   'really',
#   'too',
#   'cute'],
#  ['first',
#   'half',
#   'plot',
#   'very',
#   'interesting',
#   'discussion',
#   'definition',
#   'man',
#   'also',
#   'very',
#   'good',
#   'which',
#   'little',
#   'too',
#   'flattering',
#   'woman',
#   'slightly',
#   'distort',
#   'unprincipled',
#   'female',
#   'protagonist'],
#  ['enter',
#   'too',
#   'slowly',
#   'commercial',
#   'film',
#   'emotional',
#   'agitation',
#   'latter',
#   'half',
#   'very',
#   'effective',
#   'due',
#   'fullnes',
#   'character',
#   'effective',
#   'present',
#   'day',
#   'feminist',
#   'value',
#   'just',
#   'stop',
#   'blame',
#   'someone',
#   'else',
#   's',
#   'fault'],
#  ['i',
#   'can',
#   'not',
#   'imagine',
#   'young',
#   'man',
#   'taxi',
#   'driver',
#   'get',
#   'old',
#   'i',
#   'do',
#   'not',
#   'expect',
#   'find',
#   'answer',
#   'movie',
#   'i',
#   'have',
#   'confuse',
#   'long',
#   'time'],
#  ['plain', 'water'],
#  ['budget', 'must', 'have', 'go', 'end', 'movie'],
#  ['parent', 'ceo', 'recruitment', 'do', 'not', 'even', 'have', 'shadow'],
#  ['however',
#   'not',
#   'story',
#   'interesting',
#   'event',
#   'post',
#   'eightys',
#   'boss',
#   'post',
#   'forty',
#   'intern'],
#  ['grandpa', 'really', 'perfect'],
#  ['medium',
#   'size',
#   'piece',
#   'female',
#   'chicken',
#   'yes',
#   'chicken',
#   'fillet',
#   'now',
#   'world',
#   'woman',
#   's',
#   'girder',
#   'movie',
#   'raise',
#   'standard',
#   'warm',
#   'man',
#   'old',
#   'age',
#   'not',
#   'uncle',
#   's',
#   'turn',
#   'uncle',
#   's',
#   'turn',
#   'acting',
#   'really',
#   'natural',
#   'even',
#   'shadow',
#   'hathaway',
#   'seconds',
#   'eye'],
#  ['s',
#   'appearance',
#   'film',
#   'hollywood',
#   'tragedy',
#   'good',
#   'movie',
#   'star',
#   'play',
#   'taxi',
#   'driver',
#   'good',
#   'fella',
#   'also',
#   'heartbreaking',
#   'squeeze',
#   'eyebrow',
#   'such',
#   'spat',
#   'film',
#   'hollywood',
#   'reporter',
#   'write',
#   'article',
#   'that',
#   'also',
#   'indirectly',
#   'question',
#   's',
#   'personal',
#   'wealth',
#   'deficit',
#   'extent',
#   'need',
#   'play',
#   'bad',
#   'grandpa',
#   'intern',
#   'which',
#   'not',
#   'movie'],
#  ['act', 'so', 'tacky', 'i', 'hate', 'anne', 'hathaway'],
#  ['princess', 'diary'],
#  ['die',
#   'handsome',
#   'call',
#   'gentleman',
#   'call',
#   'elegant',
#   'man',
#   'plot',
#   'do',
#   'not',
#   'talk',
#   'especially',
#   'end',
#   'let',
#   'dump',
#   'cheat',
#   'old',
#   'recognize',
#   'de',
#   'godfather'],
#  ['subconscious',
#   'mind',
#   'traditional',
#   'patriarchal',
#   'audience',
#   'will',
#   'never',
#   'allow',
#   'successful',
#   'powerful',
#   'woman',
#   'end',
#   'well',
#   'screen',
#   'audience',
#   'will',
#   'only',
#   'want',
#   'expel',
#   'name',
#   'patriarchy',
#   'sanction',
#   'bankruptcy',
#   'failure',
#   'infidelity',
#   'etc'],
#  ['postmodern',
#   'patriarchy',
#   'hide',
#   'more',
#   'hidden',
#   'way',
#   'pretend',
#   'give',
#   'strongwoman',
#   'good',
#   'end',
#   'only',
#   'gaze',
#   'male',
#   'character',
#   'control',
#   'whole',
#   'situation',
#   'ben',
#   'symbol',
#   'patriarchal',
#   'authority',
#   'status',
#   'super',
#   'powerful',
#   'woman',
#   'play',
#   'seaway',
#   'movie',
#   'show',
#   'fragile',
#   'side',
#   'front',
#   'ben',
#   'audience',
#   'identify',
#   'ben',
#   'have',
#   'orgasm',
#   'skull',
#   'same',
#   'time',
#   'emit',
#   'strong',
#   'stench'],
#  ['neymar',
#   'i',
#   'also',
#   'want',
#   'have',
#   'kind',
#   'forgetful',
#   'friendship',
#   'cause',
#   'have',
#   'moist',
#   'silent',
#   'show',
#   'way'],
#  ['i', 'plant', 'sleep', 'gown'],
#  ['general', 'anne', 'hathaway', 'beat', 'back', 'original', 'form'],
#  ['great', 'adult', 'gentleman', 'hathaway', 'not', 'flat', 'chested'],
#  ['brooklyn', 'too', 'clean', 'second', 'half', 'catch', 'horse'],
#  ['old', 'man', 'intelligent', 'gracious', 'not', 'control', 'even', 'love'],
#  ['watch',
#   'taxi',
#   'driver',
#   'monday',
#   'watch',
#   'friday',
#   'week',
#   'forty',
#   'year',
#   'old',
#   'de',
#   'still',
#   'handsome',
#   'smart',
#   'comedy',
#   'have',
#   'good',
#   'rhythm',
#   'very',
#   'delicate',
#   'cute',
#   'i',
#   'really',
#   'appreciate',
#   's',
#   'performance',
#   'director',
#   'still',
#   'very',
#   'skilled'],
#  ['i',
#   'think',
#   'movie',
#   'weird',
#   'i',
#   'always',
#   'think',
#   'anne',
#   'hathaway',
#   'go',
#   'roll',
#   'sheet',
#   'seventy',
#   'year',
#   'old',
#   'uncle',
#   'i',
#   'have',
#   'wonder',
#   'not',
#   'get',
#   'here'],
#  ['love',
#   'interior',
#   'design',
#   'live',
#   'room',
#   'kitchen',
#   'office',
#   'particularly',
#   'good',
#   'hollywood',
#   'director',
#   'best',
#   'interior',
#   'design',
#   'i',
#   'do',
#   'not',
#   'plot',
#   'pseudo',
#   'feminine',
#   'ben',
#   'very',
#   'attractive'],
#  ['position', 'taijiquan', 'heart', 'american', 'empire'],
#  ['plain', 'chicken', 'soup'],
#  ['lei',
#   'ren',
#   'heroine',
#   'paragraph',
#   'good',
#   'man',
#   'use',
#   'man',
#   'nowadays',
#   'do',
#   'not',
#   'grow',
#   'big',
#   'speech',
#   'i',
#   'can',
#   'not',
#   'believe',
#   'kind',
#   'silly',
#   'fork',
#   'talk',
#   'would',
#   'come',
#   'anne',
#   'hathaway',
#   's',
#   'mouth',
#   'once',
#   'time',
#   'there',
#   'jack',
#   'nicholson',
#   'now',
#   'there',
#   'ezra',
#   'miller',
#   'addition',
#   'there',
#   'many',
#   'man',
#   'racist',
#   'sexist',
#   'past',
#   'so',
#   'glorify',
#   'man',
#   'likely',
#   'same',
#   'gay',
#   'man',
#   'hate',
#   'discriminate',
#   'wife',
#   'exercise',
#   'yes',
#   'just',
#   'fit',
#   'more',
#   'gender',
#   'stereotype'],
#  ['thought',
#   'such',
#   'lovely',
#   'old',
#   'man',
#   'luo',
#   'go',
#   'play',
#   'dirty',
#   'old',
#   'man',
#   'dirty',
#   'grandfather',
#   'place'],
#  ['bed',
#   'scene',
#   'end',
#   'really',
#   'embarrass',
#   'almost',
#   'bring',
#   'plot',
#   'bad',
#   'end',
#   'there',
#   'absolutely',
#   'need',
#   'create',
#   'embarrass',
#   'illusion',
#   'whole',
#   'article',
#   'still',
#   'reflection',
#   'work',
#   'place',
#   'worth',
#   'see'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'anne',
#   's',
#   'relationship',
#   'i',
#   'always',
#   'think',
#   'queen',
#   'wear',
#   'prada',
#   'year',
#   'old',
#   'daughter',
#   'law',
#   'stay',
#   'up',
#   'mother',
#   'law'],
#  ['hard', 'strong', 'woman', 'not', 'strong', 'woman'],
#  ['could',
#   'not',
#   'accept',
#   'cheat',
#   'husband',
#   'there',
#   'would',
#   'sand',
#   'eye'],
#  ['fairy',
#   'tale',
#   'do',
#   'not',
#   'count',
#   'brainwash',
#   'united',
#   'state',
#   'really',
#   'want',
#   'send',
#   'retiree',
#   'back',
#   'work',
#   'kind',
#   'trick',
#   'use',
#   'everyone',
#   'there',
#   'pretend',
#   'wear',
#   'thick',
#   'mask',
#   'pig',
#   'skin',
#   'mask',
#   'so',
#   'beautifully',
#   'carve',
#   'hard',
#   'notice',
#   'grease',
#   'abnormality',
#   'moment'],
#  ['genre',
#   'determine',
#   'must',
#   'avoid',
#   'light',
#   'side',
#   'tell',
#   'life',
#   'not',
#   'complete',
#   'noble',
#   'sub',
#   'complete',
#   'appearance',
#   'least',
#   'one',
#   'thing',
#   'true',
#   'there',
#   'many',
#   'thing',
#   'that',
#   'can',
#   'not',
#   'exchange'],
#  ['not',
#   'sixty',
#   'year',
#   'old',
#   'senior',
#   'intern',
#   'clearly',
#   'gentleman',
#   'vice',
#   'president',
#   'forty',
#   'year',
#   'busines',
#   'experience'],
#  ['adult', 'disney'],
#  ['unreal'],
#  ['annie', 's', 'clothe', 'very', 'pretty'],
#  ['grandpa', 'very', 'cute', 'value', 'shit'],
#  ['basically',
#   'can',
#   'think',
#   'robert',
#   'director',
#   'want',
#   'prove',
#   'old',
#   'man',
#   'do',
#   'something',
#   'play',
#   'special',
#   'effect',
#   'old',
#   'experience',
#   'still',
#   'classic',
#   'renee',
#   'russell',
#   'old',
#   'too',
#   'i',
#   'grow',
#   'up',
#   'watch',
#   'movie'],
#  ['experience', 'curriculum', 'vita', 'that', 'never', 'go', 'fashion'],
#  ['boring', 'time', 'end', 'one', 'star', 'less'],
#  ['nine',
#   'year',
#   'later',
#   'anne',
#   'still',
#   'beautiful',
#   'male',
#   'protagonist',
#   'really',
#   'mary',
#   'sue',
#   'person',
#   'set',
#   'ah',
#   'person',
#   'see',
#   'love',
#   'flower',
#   'bloom',
#   'first',
#   'step',
#   'capture',
#   'hearts',
#   'all',
#   'support',
#   'actor',
#   'include',
#   'heart',
#   'competitor',
#   'then',
#   'capture',
#   'heart',
#   'boss',
#   'even',
#   'daughter',
#   'omg',
#   'not',
#   'boss',
#   'fell',
#   'love'],
#  ['dig', 'heart'],
#  ['dig', 'shit'],
#  ['very',
#   'warm',
#   'too',
#   'perfect',
#   'i',
#   'ed',
#   'niro',
#   'anne',
#   'hathaway',
#   'comparison',
#   'so',
#   'miserable'],
#  ['gentleman', 'charm', 'all', 'time'],
#  ['i', 'have', 'look', 'kind', 'clothe', 'ww', 's', 'last', 'outfit'],
#  ['robert', 'downey', 'jr', 's', 'dad', 'old', 'more', 'handsome', 'really'],
#  ['inexplicable',
#   'script',
#   'do',
#   'protagonist',
#   's',
#   'focu',
#   'trainee',
#   'suddenly',
#   'turn',
#   'psychiatrist',
#   'two',
#   'main',
#   'character',
#   'very',
#   'realistic',
#   'cute',
#   'i',
#   'still',
#   'do',
#   'not',
#   'understand',
#   'i',
#   'should',
#   'watch',
#   'movie',
#   'finally',
#   'practice',
#   'yoga',
#   'together'],
#  ['do', 'host', 'feel', 'one', 'bury', 'together', 'divorce', 'tong', 'liya'],
#  ['own',
#   'father',
#   'will',
#   'not',
#   'let',
#   'bury',
#   'back',
#   'mother',
#   's',
#   'house'],
#  ['grandpa',
#   'intern',
#   'very',
#   'new',
#   'actually',
#   'give',
#   'female',
#   'bos',
#   'lot',
#   'spiritual',
#   'guidance',
#   'courage',
#   'life',
#   'experience',
#   'treasure',
#   'end',
#   'female',
#   'bos',
#   'forgive',
#   'cheat',
#   'husband',
#   'which',
#   'not',
#   'very',
#   'comfortable',
#   'heart'],
#  ['love', 'shopkeeper'],
#  ['surprisingly', 'heartwarming', 'fun', 'inspire'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'three',
#   'fifteen',
#   'nine',
#   'hundred',
#   'forty',
#   'six',
#   'just',
#   'ready',
#   'travel',
#   'release',
#   'movie',
#   'have',
#   'time',
#   'go',
#   'cinema',
#   'see',
#   'there',
#   'work',
#   'recently',
#   'think',
#   'watch',
#   'call',
#   'intern',
#   'may',
#   'helpful',
#   'very',
#   'comfortable',
#   'light',
#   'comedy',
#   'absurd',
#   'plot',
#   'only',
#   'solid',
#   'narrative',
#   'normal',
#   'character',
#   'not',
#   'much',
#   'look',
#   'forward',
#   'lot',
#   'gain'],
#  ['way',
#   'return',
#   'teach',
#   'young',
#   'person',
#   'work',
#   'live',
#   'gentleman',
#   'also',
#   'taught',
#   'young',
#   'person',
#   'adapt',
#   'modern',
#   'society',
#   'do',
#   'think',
#   'wrong',
#   'give',
#   'nice',
#   'old',
#   'vice',
#   'president',
#   'retirement',
#   'advise',
#   'job',
#   'price',
#   'intern',
#   'give',
#   'personal',
#   'babysitter'],
#  ['warm',
#   'movie',
#   'such',
#   'love',
#   'first',
#   'sight',
#   'harry',
#   'meet',
#   'sally',
#   'go',
#   'leave',
#   'danny',
#   'collin',
#   'little',
#   'faith',
#   'i',
#   'give',
#   'three',
#   'star',
#   'three',
#   'star',
#   'together',
#   'road',
#   'movie',
#   'feel',
#   'two',
#   'type',
#   'movie',
#   'suitable',
#   'leisure',
#   'relaxation',
#   'so',
#   'i',
#   'have',
#   'rat',
#   'so',
#   'many',
#   'movie',
#   'i',
#   'have',
#   'conclude',
#   'own',
#   'rating',
#   'four',
#   'star',
#   'more',
#   'there',
#   'have',
#   'depth'],
#  ['forgotten',
#   'new',
#   'year',
#   's',
#   'friendship',
#   'really',
#   'addition',
#   'family',
#   'love',
#   'most',
#   'touching',
#   'friendship',
#   'standard',
#   'woman',
#   'chicken',
#   'soup',
#   'full',
#   'warm',
#   'feeling',
#   'uncle',
#   's',
#   'person',
#   'deeply',
#   'interpret',
#   'gentleman',
#   's',
#   'character',
#   'connotation',
#   'cultivation',
#   'grace',
#   'anne',
#   'successfully',
#   'evolve',
#   'work',
#   'girl',
#   'wear',
#   'prada',
#   'miranda',
#   'family',
#   'busines',
#   'difficult',
#   'director',
#   's',
#   'filming',
#   'style',
#   'very',
#   'much',
#   'appetite',
#   'idealize',
#   'story',
#   'even',
#   'i',
#   'see',
#   'ten',
#   'thousand',
#   'time',
#   'again',
#   'ah'],
#  ['expound',
#   'old',
#   'profession',
#   'most',
#   'emotional',
#   'window',
#   'position',
#   'forty',
#   'year',
#   'do',
#   'same',
#   'job',
#   'do',
#   'right',
#   'never',
#   'wrong'],
#  ['there',
#   'lack',
#   'comedy',
#   'life',
#   'everything',
#   'country',
#   'miss',
#   'main',
#   'theme'],
#  ['two',
#   'hour',
#   'screenwriting',
#   'not',
#   'enough',
#   'time',
#   'see',
#   'even',
#   'final',
#   'capture',
#   'adultery',
#   'divorce',
#   'have',
#   'save',
#   'dog',
#   'blood'],
#  ['grandpa', 's', 'idea', 'would', 'perfect'],
#  ['plot',
#   'not',
#   'particularly',
#   'old',
#   'fashion',
#   'whole',
#   'movie',
#   'give',
#   'sense',
#   'good',
#   'old',
#   'fashion',
#   'i',
#   'can',
#   'not',
#   'say',
#   'follow',
#   'up',
#   'plot',
#   'come',
#   'watch',
#   'i',
#   'will',
#   'think',
#   'kind',
#   'drama',
#   'indeed',
#   'kind',
#   'plot',
#   'trend',
#   'line',
#   'match',
#   'ah'],
#  ['so',
#   'can',
#   'define',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'intermediate',
#   'level',
#   'composition',
#   'different',
#   'still',
#   'can',
#   'recognize',
#   'glance',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'too',
#   'template'],
#  ['film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman',
#   'quality',
#   'actually',
#   'good',
#   'early',
#   'stage',
#   'can',
#   'give',
#   'seven',
#   'even',
#   'eight',
#   'point',
#   'forgiveness',
#   'end',
#   'too',
#   'easy'],
#  ['maybe',
#   'i',
#   'kind',
#   'woman',
#   'compromise',
#   'right',
#   'away',
#   'i',
#   'still',
#   'can',
#   'not',
#   'accept',
#   'especially',
#   'kind',
#   'film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman'],
#  ['warmth',
#   'humor',
#   'important',
#   'seemingly',
#   'bland',
#   'structurally',
#   'rigorous',
#   'can',
#   'actually',
#   'dive',
#   'down'],
#  ['end',
#   'not',
#   'very',
#   'good',
#   'surprisingly',
#   'i',
#   'story',
#   'entrepreneurial',
#   'woman',
#   'leader',
#   'elderly',
#   'intern'],
#  ['variant',
#   'princes',
#   'knight',
#   'mode',
#   'unbreakable',
#   'tackines',
#   'not',
#   'big',
#   'problem',
#   'most',
#   'serious',
#   'thing',
#   'narrative',
#   'kernel',
#   'work',
#   'btw',
#   'do',
#   'american',
#   'person',
#   'start',
#   'say',
#   'goodbye',
#   'japanese'],
#  ['three',
#   'half',
#   'star',
#   'first',
#   'half',
#   'warm',
#   'solid',
#   'last',
#   'half',
#   'hour',
#   'so',
#   'confusing'],
#  ['company',
#   'have',
#   'old',
#   'one',
#   'big',
#   'one',
#   'good',
#   'old',
#   'person',
#   'experience',
#   'sedimentation',
#   'year',
#   'know',
#   'say',
#   'do',
#   'instead',
#   'scramble',
#   'seat',
#   'go',
#   'viral',
#   'something',
#   'woman',
#   'deserve',
#   'cheat',
#   'single',
#   'rest',
#   'life',
#   'end',
#   'perfect'],
#  ['marry', 'anne', 'hathaway', 'can', 'cheat'],
#  ['god', 's', 'forgiveness', 'sin', 'too', 'easy'],
#  ['anne',
#   'hathaway',
#   'beautiful',
#   'course',
#   'robert',
#   'handsome',
#   'too',
#   'more',
#   'importantly',
#   'story',
#   'love',
#   'life',
#   'very',
#   'well',
#   'tell',
#   'i'],
#  ['never',
#   'wrong',
#   'do',
#   'right',
#   'thing',
#   'elbow',
#   'recommend',
#   'movie',
#   'too',
#   'much'],
#  ['male',
#   'protagonist',
#   'too',
#   'perfect',
#   'first',
#   'time',
#   'feel',
#   'charm',
#   'elderly',
#   'completely',
#   'match',
#   'word',
#   'decent',
#   'i',
#   'suddenly',
#   'realize',
#   'feminist',
#   'color',
#   'movie',
#   'intention',
#   'very',
#   'good',
#   'end',
#   'little',
#   'hasty',
#   'simple'],
#  ['mature', 's', 'oneqycjtwoha', 'code', 'wrgnine'],
#  ['love', 'old', 'man'],
#  ['compare',
#   'country',
#   's',
#   'fashion',
#   'comedy',
#   'can',
#   'achieve',
#   'complete',
#   'drama',
#   'not',
#   'easy'],
#  ['cinema',
#   'heatherway',
#   'have',
#   'good',
#   'combination',
#   'old',
#   'man',
#   'find',
#   'new',
#   'job',
#   'woman',
#   'workaholic',
#   'save',
#   'marriage',
#   'want',
#   'leave',
#   'old',
#   'man',
#   'have',
#   'new',
#   'relationship',
#   'circle',
#   'still',
#   'have',
#   'dry',
#   'mood',
#   'very',
#   'different',
#   'two',
#   'person',
#   'practice',
#   'original',
#   'life',
#   'really',
#   'good'],
#  ['i',
#   'think',
#   'simplicity',
#   'old',
#   'day',
#   'inject',
#   'vitality',
#   'new',
#   'generation',
#   'end',
#   'still',
#   'suggestion',
#   'elite',
#   'there',
#   'resonance',
#   'still',
#   'disney',
#   'movie',
#   'let',
#   'also',
#   'look',
#   'relaxed',
#   'warmth'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'one',
#   'three',
#   'fifteen',
#   'forty',
#   'one',
#   'thirty',
#   'two'],
#  ['warm',
#   'relaxing',
#   'film',
#   'male',
#   'protagonist',
#   's',
#   'setting',
#   'too',
#   'perfect',
#   'good',
#   'subordinate',
#   'good',
#   'colleague',
#   'good',
#   'friend',
#   'united',
#   'state',
#   'have',
#   'energy',
#   'i',
#   'think',
#   'go',
#   'happen',
#   'male',
#   'female',
#   'protagonist',
#   'think',
#   'too',
#   'much'],
#  ['i', 'can', 'not', 'change', 'fact', 'i', 'love', 'ca', 'anymore'],
#  ['there',
#   'respect',
#   'oneself',
#   'other',
#   'relationship',
#   'other',
#   'noble',
#   'character'],
#  ['cool', 'warm', 'warm', 'principled'],
#  ['good', 'say'],
#  ['old',
#   'man',
#   'so',
#   'cute',
#   'look',
#   'old',
#   'man',
#   'up',
#   'story',
#   'cute',
#   'funny',
#   'listen',
#   'old',
#   'man',
#   'must',
#   'right',
#   'everyone',
#   'have',
#   'have',
#   'ben'],
#  ['mediocre', 'also', 'touch'],
#  ['there',
#   'nothing',
#   'say',
#   'plot',
#   'support',
#   'play',
#   'main',
#   'character',
#   'one',
#   'star'],
#  ['really',
#   'i',
#   'would',
#   'not',
#   'have',
#   'watch',
#   'stupid',
#   'movie',
#   'not',
#   'chris'],
#  ['waste', 'life'],
#  ['kind',
#   'angelic',
#   'thing',
#   'will',
#   'not',
#   'let',
#   'catch',
#   'up',
#   'easily',
#   'i',
#   'can',
#   'only',
#   'try',
#   'achieve',
#   'seven',
#   'hour',
#   'sleep',
#   'day'],
#  ['fun', 'not', 'big', 'deal'],
#  ['i', 'think', 'waste', 'time'],
#  ['i',
#   'can',
#   'so',
#   'relaxed',
#   'age',
#   'seventy',
#   'have',
#   'so',
#   'much',
#   'love',
#   'heart',
#   'live',
#   'so',
#   'clearly',
#   'will',
#   'not',
#   'vain',
#   'want',
#   'robert',
#   'china',
#   'take',
#   'more',
#   'action',
#   'comedy'],
#  ['halfway',
#   'conversation',
#   'woman',
#   'workplace',
#   'nancy',
#   'meyer',
#   'baby',
#   'boom',
#   'suddenly',
#   'come',
#   'mind',
#   'wondering',
#   'movie'],
#  ['i',
#   'watch',
#   'movie',
#   'home',
#   'brother',
#   'i',
#   'have',
#   'hear',
#   'see',
#   'poster',
#   'many',
#   'time',
#   'i',
#   'use',
#   'think',
#   'hostes',
#   'intern',
#   'film',
#   'that',
#   'inspire',
#   'lot',
#   'work',
#   'life'],
#  ['daydream',
#   'movie',
#   'screenwriter',
#   'very',
#   'respectful',
#   'female',
#   'strongman',
#   'old',
#   'school',
#   'gentleman',
#   'two',
#   'far',
#   'reality',
#   'most',
#   'person'],
#  ['emotionally', 'delicate', 'old', 'school', 'style', 'man'],
#  ['i',
#   'want',
#   'play',
#   'three',
#   'star',
#   'old',
#   'man',
#   'so',
#   'cute',
#   'too',
#   'hathaway',
#   'look',
#   'great',
#   'clothe'],
#  ['addition',
#   'title',
#   'movie',
#   'should',
#   'call',
#   'intern',
#   'driver',
#   'back',
#   'head',
#   'can',
#   'guess',
#   'plot'],
#  ['see',
#   'god',
#   'past',
#   'act',
#   'as',
#   'retired',
#   'grandfather',
#   'once',
#   'again',
#   'i',
#   'could',
#   'not',
#   'help',
#   'feel',
#   'hero',
#   'late'],
#  ['god', 's', 'presence'],
#  ['anne',
#   'go',
#   'intern',
#   'prada',
#   'big',
#   'bos',
#   'dress',
#   'really',
#   'well',
#   'probably',
#   'only',
#   'time',
#   'i',
#   'like',
#   'old',
#   'robert',
#   'have',
#   'lot',
#   'virtue',
#   'lot',
#   'love'],
#  ['i',
#   'love',
#   'i',
#   'love',
#   'old',
#   'man',
#   'i',
#   'love',
#   'old',
#   'man',
#   'i',
#   'love',
#   'old',
#   'man',
#   'want',
#   'matter',
#   'clean',
#   'up',
#   'own',
#   'clean',
#   'seventy',
#   'year',
#   'old',
#   'can',
#   'also',
#   'meet',
#   'heart',
#   'object',
#   'only',
#   'can',
#   'do',
#   'have',
#   'only',
#   'meet',
#   'person',
#   'like',
#   'do',
#   'not',
#   'afraid',
#   'fight',
#   'meet',
#   'ye',
#   'most',
#   'impressive',
#   'thing',
#   'movie',
#   'love',
#   'old',
#   'age'],
#  ['not',
#   'so',
#   'boring',
#   'ordinary',
#   'story',
#   'kind',
#   'cast',
#   'box',
#   'product',
#   'look',
#   'worthless'],
#  ['one',
#   'star',
#   'actor',
#   's',
#   'act',
#   'personality',
#   'very',
#   'charming',
#   'personality',
#   'spit',
#   'out',
#   'mes',
#   'center',
#   'gravity',
#   'plot',
#   'anne',
#   'hathaway',
#   'can',
#   'only',
#   'frown',
#   'mouth',
#   'acting',
#   'annoy',
#   'see'],
#  ['robert',
#   'seventy',
#   'year',
#   'old',
#   'man',
#   'so',
#   'cute',
#   'plot',
#   'simple',
#   'climax'],
#  ['old',
#   'strong',
#   'also',
#   'constantly',
#   'learn',
#   'integrate',
#   'new',
#   'social',
#   'atmosphere',
#   'which',
#   'admirable',
#   'two',
#   'storyline',
#   'which',
#   'well',
#   'blend',
#   'properly',
#   'amuse',
#   'will',
#   'suffice',
#   'good',
#   'light',
#   'comedy',
#   'lucky',
#   'rare',
#   'have',
#   'mentor',
#   'also',
#   'teacher',
#   'friend',
#   'guide',
#   'forward',
#   'open',
#   'just',
#   'can',
#   'not',
#   'good'],
#  ['fashion',
#   'magazine',
#   'intern',
#   'many',
#   'year',
#   'ago',
#   'have',
#   'grow',
#   'fashion',
#   'e',
#   'commerce',
#   'ceo',
#   'encouraging'],
#  ['stay', 'awake'],
#  ['do', 'not', 'fool'],
#  ['three', 'half', 'star'],
#  ['can', 'luo', 'so', 'cute'],
#  ['little',
#   'rotten',
#   'tail',
#   'setting',
# ...
#   'year',
#   'third',
#   'season',
#   'desperate',
#   'housewife',
#   'english',
#   'teacher',
#   'like',
#   'insert',
#   'content',
#   'drama',
#   'say',
#   'word',
#   'compromise',
#   'use',
#   'conversation',
#   'gaby',
#   'husband',
#   'deployment'],
#  ['two',
#   'thousand',
#   'fifteen',
#   'movie',
#   'still',
#   'look',
#   'very',
#   'fashionable',
#   'especially',
#   'exquisite',
#   'attitude',
#   'male',
#   'protagonist',
#   'female',
#   'protagonist',
#   'very',
#   'beautiful',
#   'street',
#   'view',
#   'house',
#   'very',
#   'british'],
#  ['insight',
#   'life',
#   'courage',
#   'confront',
#   'life',
#   's',
#   'problem',
#   'not',
#   'blame'],
#  ['husband',
#   'blame',
#   'own',
#   'career',
#   'cheat',
#   'sometimes',
#   'not',
#   'deployment'],
#  ['film',
#   'tell',
#   'story',
#   'juul',
#   'career',
#   'woman',
#   'forty',
#   'year',
#   'old',
#   'businessman',
#   'retire',
#   're',
#   'employ'],
#  ['juul',
#   'start',
#   'own',
#   'company',
#   'year',
#   'husband',
#   'full',
#   'time',
#   'home',
#   'baby',
#   'have',
#   'lovely',
#   'kindergarten',
#   'daughter',
#   'company',
#   'have',
#   'absorb',
#   'more',
#   'two',
#   'hundred',
#   'employee',
#   'past',
#   'year',
#   'operation',
#   'also',
#   'very',
#   'good'],
#  ['company',
#   'decide',
#   'hire',
#   'senior',
#   'intern',
#   'ben',
#   'apply',
#   'successfully',
#   'accept',
#   'i',
#   'have',
#   'assign',
#   'lead',
#   'julie',
#   'julie',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['not', 'just', 'intern', 'friend'],
#  ['film', 'jule', 'tell', 'senior', 'intern', 'ben'],
#  ['work',
#   'love',
#   'movie',
#   'intern',
#   's',
#   'name',
#   'remind',
#   'anne',
#   'hathaway',
#   's',
#   'two',
#   'thousand',
#   'seven',
#   'film',
#   'queen',
#   'prada',
#   'which',
#   'not',
#   'intern',
#   'queen'],
#  ['modern', 'society', 'marriage', 'family', 'deployment'],
#  ['movie',
#   'really',
#   'too',
#   'warm',
#   'anne',
#   'hathaway',
#   'really',
#   'beautiful',
#   'i',
#   'think',
#   'heroine',
#   'jule',
#   'internship',
#   'own',
#   'effort',
#   'little',
#   'powerful',
#   'story',
#   'however',
#   'main',
#   'character',
#   'trainee',
#   'grandfather',
#   'ben',
#   'main',
#   'character',
#   'movie',
#   'woman',
#   'already',
#   'boss',
#   'internet',
#   'company'],
#  ['jule',
#   'everyone',
#   'will',
#   'vulnerable',
#   'hostess',
#   'company',
#   'two',
#   'deployment'],
#  ['intern',
#   'thought',
#   'similar',
#   'female',
#   'devil',
#   'describe',
#   'hathaway',
#   's',
#   'growth',
#   'intern',
#   'workplace',
#   'have',
#   'never',
#   'intend',
#   'repeat',
#   'theme',
#   'pearl',
#   'jade',
#   'look',
#   'i',
#   'want',
#   'see',
#   'series',
#   'i',
#   'stumble',
#   'story',
#   'hathaway',
#   'grow',
#   'up',
#   'elderly',
#   'intern',
#   'bos',
#   'i',
#   'late',
#   'i',
#   'really',
#   'glad',
#   'meet',
#   'such',
#   'warm',
#   'positive',
#   'movie',
#   'which',
#   'heal',
#   'long',
#   'night',
#   'really',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['one',
#   'day',
#   'listen',
#   'fan',
#   'deng',
#   'explain',
#   'hundred',
#   'year',
#   'life',
#   'suddenly',
#   'middle',
#   'age',
#   'even',
#   'point',
#   'old',
#   'age',
#   'need',
#   're',
#   'learn',
#   're',
#   'find',
#   'job'],
#  ['movie',
#   'have',
#   'different',
#   'vision',
#   'elderly',
#   'retire',
#   'old',
#   'widow',
#   'first',
#   'degree',
#   'deployment'],
#  ['i',
#   'have',
#   'hole',
#   'life',
#   'i',
#   'have',
#   'fill',
#   'as',
#   'soon',
#   'possible',
#   'explore',
#   'plight',
#   'career',
#   'woman',
#   'corporate',
#   'operation',
#   'family',
#   'busines',
#   'society',
#   'gender',
#   'discrimination',
#   'busines',
#   'disappearance',
#   'male',
#   'office',
#   'worker',
#   'rise',
#   'female',
#   'office',
#   'worker',
#   'elderly',
#   'person'],
#  ['second',
#   'spring',
#   'career',
#   'second',
#   'spring',
#   'body',
#   'new',
#   'office',
#   'old',
#   'office',
#   'home',
#   'decentralize',
#   'calm',
#   'temperament',
#   'assign',
#   'task',
#   'steal',
#   'computer',
#   'delete',
#   'emails',
#   'home',
#   'have',
#   'old',
#   'one',
#   'such',
#   'one',
#   'deployment'],
#  ['optimistic',
#   'positive',
#   'rest',
#   'life',
#   'never',
#   'give',
#   'up',
#   'desire',
#   'knowledge'],
#  ['seventy',
#   'can',
#   'passionate',
#   'life',
#   'twenty',
#   'day',
#   'get',
#   'up',
#   'dress',
#   'up',
#   'white',
#   'tipped',
#   'book',
#   'yoga',
#   'go',
#   'bed',
#   'time',
#   'night',
#   'seventy',
#   'never',
#   'give',
#   'up',
#   'trend',
#   'attitude',
#   'life',
#   'remain',
#   'unchanged',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['movie',
#   'beautiful',
#   'entrepreneurial',
#   'woman',
#   'career',
#   'life',
#   'crisi',
#   'just',
#   'time',
#   'appear',
#   'mature',
#   'old',
#   'friend',
#   'maybe',
#   'can',
#   'not',
#   'directly',
#   'help',
#   'career',
#   'life',
#   'spiritual',
#   'support',
#   'infinite',
#   'i',
#   'envy',
#   'kind',
#   'person',
#   'all',
#   'image',
#   'elderly',
#   'friend',
#   'life',
#   'mentor',
#   'not',
#   'everyone',
#   'have',
#   'chance',
#   'meet',
#   'deployment'],
#  ['will',
#   'gain',
#   'follow',
#   'knowledge',
#   'relate',
#   'workplace',
#   'one',
#   'first',
#   'day',
#   'work',
#   'sure',
#   'not',
#   'late',
#   'set',
#   'alarm',
#   'clock',
#   'set',
#   'two',
#   'too',
#   'nervous',
#   'keep',
#   'friendly',
#   'comfortable',
#   'distance',
#   'colleague',
#   'do',
#   'not',
#   'have',
#   'come',
#   'up',
#   'please',
#   'other',
#   'have',
#   'time',
#   'help',
#   'colleague',
#   'observe',
#   'do',
#   'boss',
#   'want',
#   'do',
#   'see',
#   'result',
#   'watch',
#   'movie',
#   'i',
#   'want',
#   'buy',
#   'handkerchief',
#   'deployment'],
#  ['turn',
#   'out',
#   'actor',
#   'hold',
#   'up',
#   'most',
#   'play',
#   'not',
#   'legendary',
#   'robert',
#   'do',
#   'just'],
#  ['film',
#   'set',
#   'workplace',
#   'explore',
#   'theme',
#   'winner',
#   'life',
#   'one',
#   'elderly',
#   'person',
#   'return',
#   'workplace',
#   'one',
#   'strong',
#   'woman',
#   'have',
#   'make',
#   'name',
#   'elderly',
#   'do',
#   'good',
#   'job',
#   'basic',
#   'job',
#   'bring',
#   'warmth',
#   'positive',
#   'energy',
#   'person',
#   'strong',
#   'woman',
#   'entangled',
#   'family',
#   'career',
#   'deployment'],
#  ['movie',
#   'can',
#   'really',
#   'support',
#   'most',
#   'drama',
#   'old',
#   'american',
#   'actor',
#   'robert',
#   'have',
#   'do',
#   'smile',
#   'move',
#   'absolutely',
#   'elegant',
#   'elegant',
#   'screen',
#   'can',
#   'feel',
#   'elegance',
#   'nobility',
#   'hard',
#   'believe',
#   'seventy',
#   'two',
#   'year',
#   'old',
#   'man',
#   'can',
#   'so',
#   'attractive',
#   'seeing'],
#  ['movie', 'belong', 'american', 'soft', 'comedy', 'seem', 'deployment'],
#  ['film', 'review', 'learn', 'english', 'only'],
#  ['atypical', 'story', 'intern', 'best', 'friend'],
#  ['course',
#   'not',
#   'inspirational',
#   'movie',
#   'also',
#   'pour',
#   'few',
#   'bowl',
#   'chicken',
#   'soup',
#   'all',
#   'rookie',
#   'seventy',
#   'year',
#   'old',
#   'senior',
#   'veteran',
#   'actor',
#   'robert',
#   'oscar',
#   'winner',
#   'scorsese',
#   's',
#   'royal',
#   'male',
#   'protagonist',
#   'man',
#   'play',
#   'godfather',
#   'deployment'],
#  ['life',
#   'there',
#   'lot',
#   'helplessness',
#   'confusion',
#   'day',
#   'desperately',
#   'need',
#   'experienced',
#   'ferryman',
#   'help',
#   'cross',
#   'river',
#   'jule',
#   'clear',
#   'authentic',
#   'character',
#   'dare',
#   'try',
#   'inner',
#   'thought',
#   'life',
#   'can',
#   'not',
#   'always',
#   'go',
#   'smoothly',
#   'jule',
#   'encounter',
#   'problem',
#   'ben',
#   'kind',
#   'elder',
#   'always',
#   'give',
#   'spiritual',
#   'encouragement',
#   'advice',
#   'not',
#   'much',
#   'say',
#   'as',
#   'long',
#   'ben',
#   'here',
#   'jule',
#   'will',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['i',
#   'watch',
#   'movie',
#   'intern',
#   'yesterday',
#   'i',
#   'use',
#   'rely',
#   'age',
#   'decide',
#   'person',
#   'old',
#   'not',
#   'watch',
#   'intern',
#   'i',
#   'find',
#   'never',
#   'age',
#   'spirit',
#   'that',
#   'determine',
#   'person',
#   'old',
#   'not'],
#  ['person',
#   'twentys',
#   'live',
#   'old',
#   'man',
#   'seventys',
#   'teenager',
#   'let',
#   'take',
#   'look',
#   'movie',
#   'together'],
#  ['one', 'none', 'deployment'],
#  ['movie',
#   'i',
#   'run',
#   'tell',
#   'friend',
#   'i',
#   'have',
#   'see',
#   'good',
#   'movie',
#   'really',
#   'good',
#   'piece',
#   'write',
#   'maybe',
#   'there',
#   'have',
#   'reliable',
#   'person',
#   'time'],
#  ['instead',
#   'want',
#   'have',
#   'someone',
#   'i',
#   'want',
#   'person',
#   'reliable',
#   'calm',
#   'sincere',
#   'always',
#   'thoughtful',
#   'rigour',
#   'good',
#   'habit',
#   'previous',
#   'generation',
#   'constantly',
#   'make',
#   'progres',
#   'not',
#   'touch',
#   'time'],
#  ['deployment'],
#  ['perhaps',
#   'i',
#   'just',
#   'finish',
#   'internship',
#   'i',
#   'choose',
#   'movie',
#   'beginning',
#   'film',
#   'fascinate',
#   'retire',
#   'seventy',
#   'year',
#   'old',
#   'man',
#   'decide',
#   'return',
#   'work',
#   'because',
#   'have',
#   'sense',
#   'belonging'],
#  ['get',
#   'life',
#   'go',
#   'stand',
#   'up',
#   'go',
#   'go',
#   'anywhere',
#   'so',
#   'come',
#   'new',
#   'fashion',
#   'clothing',
#   'company',
#   'become',
#   'elderly',
#   'intern',
#   'set',
#   'here',
#   'deployment'],
#  ['frankly',
#   'intern',
#   'not',
#   'i',
#   'expect',
#   'week',
#   'fortunately',
#   'recommendation',
#   'page',
#   'time',
#   'fortunately',
#   'i',
#   'choose',
#   'little',
#   'hesitation',
#   'choose',
#   'entirely',
#   'anne',
#   'hathaway',
#   'sure',
#   'enough',
#   'goddes',
#   'produce',
#   'must',
#   'fine',
#   'product'],
#  ['queen',
#   'prada',
#   's',
#   'intern',
#   'have',
#   'promote',
#   'boss',
#   'annie',
#   'intern',
#   'have',
#   'able',
#   'adapt',
#   'fast',
#   'pace',
#   'take',
#   'initiative',
#   'deployment'],
#  ['first',
#   'i',
#   'run',
#   'hathaway',
#   'i',
#   'saw',
#   'topic',
#   'intern',
#   'i',
#   'think',
#   'i',
#   'should',
#   'tell',
#   'story',
#   'college',
#   'graduate',
#   'enter',
#   'workplace',
#   'i',
#   'think',
#   'i',
#   'would',
#   'soon',
#   'become',
#   'social',
#   'person',
#   'i',
#   'plan',
#   'take',
#   'look',
#   'such',
#   'expectation',
#   'there',
#   'will',
#   'more',
#   'excitement',
#   'look'],
#  ['ben',
#   's',
#   'performance',
#   'should',
#   'continue',
#   'knight',
#   'culture',
#   'also',
#   'see',
#   'artisan',
#   'spirit',
#   'i',
#   'get',
#   'old',
#   'can',
#   'live',
#   'ben',
#   'deployment'],
#  ['one'],
#  ['i',
#   'go',
#   'anne',
#   'hathaway',
#   's',
#   'best',
#   'movie',
#   'relax',
#   'workplace',
#   'comedy',
#   'i',
#   'disappoint',
#   'true',
#   'anne',
#   'hathaway',
#   'light',
#   'hearted',
#   'work',
#   'comedy',
#   'undeniable',
#   'standard',
#   'inspirational',
#   'film',
#   'up',
#   'down'],
#  ['two'],
#  ['whole',
#   'movie',
#   'really',
#   'do',
#   'not',
#   'have',
#   'up',
#   'downs',
#   'movie',
#   'do',
#   'raise',
#   'lot',
#   'problem',
#   'workplace',
#   'deployment'],
#  ['begin',
#   'movie',
#   'i',
#   'saw',
#   'old',
#   'man',
#   'high',
#   'emotional',
#   'intelligence',
#   'intelligence',
#   'always',
#   'watch',
#   'seventy',
#   'year',
#   'age',
#   'circle',
#   'fate',
#   'let',
#   'return',
#   'factory',
#   'have',
#   'spend',
#   'more',
#   'forty',
#   'year',
#   'familiarize',
#   'face',
#   'strange',
#   'new',
#   'world',
#   'start',
#   'work',
#   'again',
#   'start',
#   'date',
#   'again',
#   'set',
#   'movie',
#   'still',
#   'intriguing',
#   'grandpa',
#   'face',
#   'new',
#   'social',
#   'new',
#   'job',
#   'type',
#   'intern',
#   'deployment'],
#  ['watch',
#   'movie',
#   'i',
#   'fascinate',
#   'old',
#   'gentleman',
#   'have',
#   'slightly',
#   'antique',
#   'style',
#   'american',
#   'version',
#   'word',
#   'i',
#   'glad',
#   'emotional',
#   'line',
#   'heroine',
#   'not',
#   'vulgar',
#   'love',
#   'not',
#   'ambiguous',
#   'more',
#   'father',
#   's',
#   'communication',
#   'daughter',
#   'concern',
#   'friend'],
#  ['then',
#   'come',
#   'gentleman',
#   's',
#   'delightful',
#   'reason',
#   'logic',
#   'planning',
#   'courage',
#   'so',
#   'deployment'],
#  ['blake',
#   'snyder',
#   'screenplay',
#   'beatwatch',
#   'title',
#   'intern',
#   'genre',
#   'fellowship',
#   'date',
#   'two',
#   'thousand',
#   'twenty',
#   'one',
#   'pfive',
#   'male',
#   'protagonist',
#   'see',
#   'list',
#   'intern',
#   'say',
#   'old',
#   'lady',
#   'i',
#   'can',
#   'not',
#   'understand',
#   'say',
#   'not',
#   'young',
#   'anymore',
#   'pave',
#   'way',
#   'pone',
#   'ten',
#   'exhibition',
#   'deployment'],
#  ['retired',
#   'vice',
#   'president',
#   'start',
#   'up',
#   'internet',
#   'company',
#   'do',
#   'intern',
#   'female',
#   'boss',
#   'help',
#   'young',
#   'person',
#   'find',
#   'direction',
#   'work',
#   'life',
#   'find',
#   'own',
#   'plot',
#   'not',
#   'too',
#   'boring',
#   'acting',
#   'still',
#   'unremarkable',
#   'good',
#   'look',
#   'princess',
#   'diary',
#   'woman',
#   'prada',
#   'look',
#   'deployment'],
#  ['clothe', 'wear', 'word', 'write', 'word', 'say', 'food', 'eat'],
#  ['big',
#   'feel',
#   'watch',
#   'movie',
#   'ben',
#   'always',
#   'clean',
#   'wear',
#   'suit',
#   'behavior',
#   'also',
#   'subtly',
#   'affect',
#   'everyone',
#   'such',
#   'fat',
#   'little',
#   'man',
#   'house',
#   'start',
#   'dres',
#   'formal',
#   'professional'],
#  ['one'],
#  ['person', 'wear', 'do', 'deployment'],
#  ['successful',
#   'senior',
#   'workplace',
#   'have',
#   'always',
#   'serious',
#   'sincere',
#   'humble',
#   'active',
#   'friendly',
#   'principled',
#   'never',
#   'cross',
#   'line',
#   'i',
#   'think',
#   'kind',
#   'cultivation',
#   'wisdom',
#   'which',
#   'worth',
#   'learn',
#   'workplace',
#   'help',
#   'integrate',
#   'new',
#   'environment',
#   'get',
#   'respect',
#   'other',
#   'faster',
#   'deployment'],
#  ['one'],
#  ['career',
#   'family',
#   'elder',
#   'friends',
#   'lover',
#   'child',
#   'daily',
#   'necessity',
#   'everyday',
#   'life',
#   'appear',
#   'time',
#   'only',
#   'have',
#   'make',
#   'choice',
#   'do',
#   'realize',
#   'so',
#   'important',
#   'sometime',
#   'choose',
#   'forgive',
#   'face',
#   'betrayal',
#   'life',
#   'may',
#   'require',
#   'soft',
#   'there',
#   'surprise',
#   'everywhere',
#   'life',
#   'as',
#   'long',
#   'willing',
#   'go',
#   'out',
#   'experience',
#   'time',
#   'deployment'],
#  ['work',
#   'i',
#   'watch',
#   'movie',
#   'begin',
#   'movie',
#   'old',
#   'man',
#   's',
#   'delicate',
#   'elegant',
#   'clothe',
#   'make',
#   'feel',
#   'comfortable',
#   'such',
#   'spring',
#   'breeze',
#   'then',
#   'later',
#   'old',
#   'man',
#   'always',
#   'elegant',
#   'always',
#   'enthusiastic',
#   'always',
#   'positive',
#   'warm',
#   'wise',
#   'always',
#   'talk',
#   'forever',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['demonstrate', 'that', 'competence', 'workplace', 'can', 'transfer'],
#  ['last', 'job', 'take', 'position', 'vice', 'president'],
#  ['can',
#   'do',
#   'vice',
#   'presidential',
#   'level',
#   'back',
#   'intern',
#   'performance',
#   'workplace',
#   'can',
#   'see',
#   'characteristic',
#   'very',
#   'worth',
#   'learn',
#   'new',
#   'even',
#   'veteran',
#   'workplace',
#   'willing',
#   'try',
#   'new',
#   'thing',
#   'embrace',
#   'challenge',
#   'seventy',
#   'year',
#   'old',
#   'still',
#   'willing',
#   'learn',
#   'internet',
#   'deployment'],
#  ['movie',
#   'have',
#   'too',
#   'much',
#   'conversational',
#   'art',
#   'record',
#   'don',
#   's',
#   'life',
#   'state',
#   'should',
#   'most',
#   'person',
#   'aspire'],
#  ['don',
#   'first',
#   'ask',
#   'assistant',
#   'pay',
#   'attention',
#   'see',
#   'boss',
#   'driver',
#   'drink',
#   'still',
#   'give',
#   'two',
#   'choice',
#   'deployment'],
#  ['movie',
#   'that',
#   'make',
#   'very',
#   'comfortable',
#   'watch',
#   'particular',
#   'most',
#   'first',
#   'half',
#   'relax',
#   'small',
#   'humor',
#   'let',
#   'almost',
#   'whole',
#   'mouth',
#   'whole',
#   'time',
#   'two',
#   'main',
#   'character',
#   'act',
#   'natural',
#   'sincere',
#   'not',
#   'flamboyant',
#   'true',
#   'feeling',
#   'easy',
#   'get',
#   'play',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['american',
#   'light',
#   'comedy',
#   'film',
#   'intern',
#   'have',
#   'variety',
#   'routine',
#   'perfect',
#   'plot',
#   'direction',
#   'familiar',
#   'comedy',
#   'plot',
#   'well',
#   'know',
#   'anne',
#   'hathaway',
#   'anyone',
#   'see',
#   'know',
#   'movie',
#   'perfect',
#   'story',
#   'that',
#   'inspire',
#   'just',
#   'one',
#   'idea',
#   'many',
#   'film',
#   'few',
#   'film',
#   'have',
#   'have',
#   'such',
#   'perfect',
#   'succes'],
#  ['time', 'show', 'many', 'person', 'not', 'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['ben',
#   'nearly',
#   'seventy',
#   'join',
#   'internet',
#   'company',
#   'intern',
#   'workplace',
#   'story',
#   'that',
#   'take',
#   'place',
#   'founder',
#   'jule',
#   'ben',
#   'admirable',
#   'mature',
#   'gentleman',
#   'attitude',
#   'spirit',
#   'life',
#   'have',
#   'inspire',
#   'lot',
#   'probably',
#   'i',
#   'want',
#   'balance',
#   'influential',
#   'person'],
#  ...]

# %%
# final..refine!

def replace_words(sentence):
    replacements = {
        r'\binternben\b': ['intern', 'ben'],
        r'\bexperiencesben\b': ['experience', 'ben'],
        r'\bbeingben\b': ['being', 'ben'],
        r'\bbentwo\b': ['ben', 'two'],
        r'\bbens\b': ['ben'],
        r'\bitben\b': ['it', 'ben'],
        r'\bheartben\b': ['heart', 'ben'],
        r'\botherben\b': ['other', 'ben'],
        r'\bbentheir\b': ['ben', 'their'],
        r'\bfamilyben\b': ['family', 'ben'],
        r'\bfunben\b': ['fun', 'ben'],
        r'\binternrobert\b': ['intern', 'robert'],
        r'\buprobert\b': ['up', 'robert'],
        r'\brealisticrobert\b': ['realistic', 'robert'],
        r'\btemperrobert\b': ['temper', 'robert'],
        r'\bplacerobert\b': ['place', 'robert'],
        r'\btimesrobert\b': ['time', 'robert'],
        r'\bniros\b': ['niro'],
        r'\bdeniro\b': ['niro'],
        r'\bniroi\b': ['niro', 'I'],
        r'\bmyershe\b': ['she'],
        r'\bmyersworking\b': ['working'],
        r'\banhathaway\b': ['hathaway'],
        r'\bsceneanhathaway\b': ['scene', 'hathaway'],
        r'\banhathawayhis\b': ['hathaway', 'his'],
        r'\bhathawayde\b': ['hathaway', 'de'],
        r'\bhathaways\b': ['hathaway'],
        r'\banhathaways\b': ['hathaway'],
        r'\brottenanhathaway\b': ['rotten', 'hathaway'],
        r'\btherejules\b': ['there', 'jule'],
        r'\bweakjule\b': ['weak', 'jule'],
        r'\bjules\b': ['jule'],
        r'\broutinejule\b': ['routine', 'jule'],
        r'\bagejule\b': ['age', 'jule'],
    }
    for pattern, replacement in replacements.items():
        sentence = re.sub(pattern, ' '.join(replacement), sentence)

    return sentence.split()

modified_sentences = [replace_words(' '.join(sentence)) for sentence in processed_sentences_no_stopwords]

# %%
modified_sentences
# Out:
# [['even',
#   'such',
#   'beautiful',
#   'successful',
#   'woman',
#   'american',
#   'movie',
#   'have',
#   'accept',
#   'such',
#   'ordinary',
#   'cheating',
#   'husband'],
#  ['depend',
#   'first',
#   'half',
#   'look',
#   'good',
#   'second',
#   'half',
#   'value',
#   'swallow',
#   'conservative',
#   'retreated',
#   's',
#   'person',
#   'little',
#   'too',
#   'perfect'],
#  ['world',
#   'will',
#   'good',
#   'place',
#   'i',
#   'can',
#   'make',
#   'one',
#   'two',
#   'such',
#   'warm',
#   'skit',
#   'year',
#   'look',
#   'good',
#   'release',
#   'tear'],
#  ['hathaway',
#   'intervene',
#   'streep',
#   's',
#   'strongwoman',
#   'life',
#   'now',
#   'de',
#   'anti',
#   'invasion',
#   'hathaway',
#   'life',
#   'actually',
#   'little',
#   'ambitious',
#   'try',
#   'discuss',
#   'career',
#   'woman',
#   'old',
#   'generation',
#   'float',
#   'bit',
#   'i',
#   'hathaway',
#   'lot',
#   'little',
#   'expression',
#   'have',
#   'sense',
#   'rehearsal',
#   'release',
#   'especially',
#   'compare',
#   'de',
#   'share',
#   'de',
#   'really',
#   'handsome'],
#  ['long',
#   'time',
#   'i',
#   'have',
#   'see',
#   'princess',
#   'anne',
#   'movie',
#   'feel',
#   'especially',
#   'fashion',
#   'witch',
#   'have',
#   'set',
#   'bar',
#   'so',
#   'high',
#   'professional',
#   'woman',
#   'young',
#   'person',
#   'also',
#   'too',
#   'warm',
#   'mediocre'],
#  ['bad',
#   'thing',
#   'act',
#   'bone',
#   'play',
#   'not',
#   'good',
#   'enough',
#   'play',
#   'eat',
#   'up',
#   'other',
#   'party'],
#  ['anne', 'hathaway', 'look', 'great'],
#  ['freshly',
#   'hold',
#   'laughter',
#   'detail',
#   'tap',
#   'word',
#   'massage',
#   'will',
#   'hard',
#   'thunder',
#   'snore',
#   'lifetime',
#   'experience',
#   'old',
#   'ginger',
#   'matter',
#   'high',
#   'academic',
#   'qualification',
#   'also',
#   'need',
#   'get',
#   'job',
#   'recognition',
#   'find',
#   'rare',
#   'modern',
#   'gentleman',
#   'manner',
#   'meyer',
#   'can',
#   'always',
#   'take',
#   'good',
#   'picture',
#   'vulgar',
#   'subject',
#   'matter',
#   'favorite',
#   'chick',
#   'flick',
#   'director'],
#  ['hopefully',
#   'just',
#   'momentary',
#   'misjudgment',
#   'not',
#   'love',
#   'joy',
#   'deserve',
#   'slow',
#   'down',
#   'enjoy',
#   'life',
#   'tai',
#   'chi'],
#  ['encounter',
#   'angel',
#   'high',
#   'emotional',
#   'intelligence',
#   'sweetheart',
#   'brooklyn',
#   'geniu',
#   'rub',
#   'japanese',
#   'style',
#   'warm',
#   'serenade',
#   'homage',
#   'back',
#   'back',
#   'soundtrack',
#   'fight',
#   'off',
#   'gloom',
#   'thirty',
#   'year',
#   'old',
#   'crisi',
#   'jule',
#   'future',
#   'ben',
#   'one',
#   'own',
#   'world',
#   'that',
#   'most',
#   'beautiful',
#   'thing',
#   'life'],
#  ['hathaway',
#   's',
#   'point',
#   'view',
#   'do',
#   'not',
#   'want',
#   'able',
#   'have',
#   'old',
#   'man',
#   'have',
#   'experience',
#   'hardship',
#   'life',
#   'content',
#   'guidance',
#   'actually',
#   'show',
#   'begin',
#   'end',
#   'taijiquan',
#   'slow',
#   'slow',
#   'slow'],
#  ['good',
#   'observation',
#   'not',
#   'humble',
#   'warm',
#   'courteous',
#   'advice',
#   'never',
#   'cross',
#   'line',
#   'principled',
#   'interesting',
#   'rich',
#   'experience',
#   'never',
#   'show',
#   'off',
#   'do',
#   'thing',
#   'properly',
#   'ben',
#   'nearly',
#   'seventy',
#   'year',
#   'old',
#   'model',
#   'generation',
#   'movie',
#   'also',
#   'saw',
#   's',
#   'old',
#   'age',
#   'calm',
#   'intelligent',
#   'side',
#   'really',
#   'powerful',
#   'play',
#   'god',
#   'seven',
#   'six'],
#  ['year',
#   'half',
#   'e',
#   'commerce',
#   'woman',
#   'can',
#   'run',
#   'business',
#   'man',
#   'can',
#   'domestic',
#   'man',
#   'new',
#   'person',
#   'workplace',
#   'no',
#   'longer',
#   'synonymous',
#   'early',
#   'twenty',
#   'can',
#   'still',
#   'work',
#   'interns',
#   'age',
#   'seventy',
#   'time',
#   'gender',
#   'age',
#   'downplay',
#   'as',
#   'long',
#   'have',
#   'healthy',
#   'body',
#   'positive',
#   'mind',
#   'anything',
#   'possible',
#   'very',
#   'warm',
#   'film',
#   'annie',
#   's',
#   'clothe',
#   'look',
#   'great'],
#  ['niro', 'so', 'warm', 'felt', 'tendernes', 'nobility', 'screen'],
#  ['cold', 'drink', 'chicken', 'soup', 'driver', 's', 'fan', 'disappear'],
#  ['more',
#   'standard',
#   'chicken',
#   'flick',
#   'three',
#   'view',
#   'humor',
#   'famous',
#   'character',
#   'most',
#   'important',
#   'thing',
#   'have'],
#  ['case',
#   'development',
#   'chuck',
#   'flick',
#   'love',
#   'not',
#   'sacrifice',
#   'career',
#   'family',
#   'huge',
#   'social',
#   'progres'],
#  ['robert', 'grandpa', 'fly', 'house'],
#  ['novelty',
#   'film',
#   'lie',
#   'balance',
#   'balance',
#   'seventy',
#   'year',
#   'old',
#   'face',
#   'up',
#   'own',
#   'social',
#   'status',
#   'quo',
#   'do',
#   'not',
#   'rely',
#   'old',
#   'sell',
#   'old',
#   'do',
#   'not',
#   'emphasize',
#   'past',
#   'silently',
#   'rely',
#   'own',
#   'experience',
#   'help',
#   'young',
#   'person',
#   'continue',
#   'achieve',
#   'own',
#   'value',
#   'thirty',
#   'year',
#   'old',
#   'gradually',
#   'learn',
#   'balance',
#   'everything',
#   'life',
#   'not',
#   'run',
#   'away',
#   'problem',
#   'marriage',
#   'not',
#   'deliberately',
#   'curb',
#   'inner',
#   'desire',
#   'thing',
#   'difficult',
#   'never',
#   'give',
#   'up',
#   'enthusiasm',
#   'learn',
#   'courage',
#   'start'],
#  ['old',
#   'school',
#   'not',
#   'just',
#   'retro',
#   'not',
#   'old',
#   'fashion',
#   'not',
#   'hip',
#   'hop',
#   'just',
#   'part',
#   'person',
#   'insist',
#   'good',
#   'thing',
#   'traditional',
#   'habit',
#   'idea'],
#  ['watch',
#   'episode',
#   'plane',
#   'new',
#   'york',
#   'san',
#   'francisco',
#   'feature',
#   'brooklyn',
#   'bridge',
#   'golden',
#   'gate',
#   'bridge'],
#  ['basically',
#   'rely',
#   'de',
#   'support',
#   'field',
#   'hathaway',
#   'win',
#   'award',
#   'recent',
#   'year',
#   'there',
#   'impressive',
#   'role',
#   'do',
#   'not',
#   'seem'],
#  ['most',
#   'version',
#   'post',
#   'marriage',
#   'magnification',
#   'light',
#   'truck',
#   'white',
#   'lily',
#   'united',
#   'state',
#   'course',
#   'lot',
#   'fun',
#   'something'],
#  ['do',
#   'not',
#   'learn',
#   'robert',
#   'dinillo',
#   'stand',
#   'entrance',
#   'alley',
#   'wait'],
#  ['cheesy',
#   'yet',
#   'comfort',
#   'enjoyment',
#   'robert',
#   'niro',
#   'just',
#   'play',
#   'perfect',
#   'silver',
#   'daddy',
#   'woman',
#   'man',
#   's',
#   'dream',
#   'kidding',
#   'i',
#   'put',
#   'woman',
#   'man',
#   'hope',
#   'see',
#   'i',
#   'suggest',
#   'here'],
#  ['nancy',
#   'meyer',
#   'have',
#   'not',
#   'make',
#   'movie',
#   'year',
#   'focus',
#   'old',
#   'person',
#   's',
#   'social',
#   'relationship',
#   'decades',
#   'up',
#   'date',
#   'start',
#   'up',
#   'female',
#   'entrepreneurial',
#   'setting',
#   'much',
#   'more',
#   'interesting'],
#  ['warm',
#   'hearted',
#   'comedy',
#   'modern',
#   'costume',
#   'anne',
#   'can',
#   'not',
#   'more',
#   'beautiful',
#   'performance',
#   'big',
#   'attraction',
#   'story',
#   'less',
#   'fashionable',
#   'queen',
#   'prada'],
#  ['watch',
#   'movie',
#   'i',
#   'feel',
#   'i',
#   'have',
#   'most',
#   'say',
#   'i',
#   'do',
#   'same',
#   'thing',
#   'woman',
#   'i',
#   'ten',
#   'zero',
#   'time',
#   'small',
#   'have',
#   'super',
#   'similarity',
#   'have',
#   'more',
#   'learn',
#   'there',
#   'countless',
#   'scene',
#   'move',
#   'tear',
#   'i',
#   'think',
#   'i',
#   'go',
#   'watch',
#   'again'],
#  ['best', 'tribute', 'movie'],
#  ['i',
#   'wake',
#   'up',
#   'five',
#   'm',
#   'watch',
#   'movie',
#   'i',
#   'have',
#   'always',
#   'want',
#   'see',
#   'oh',
#   'god',
#   'begin',
#   'great',
#   'day'],
#  ['watch',
#   'woman',
#   'workplace',
#   'movie',
#   'flip',
#   'woman',
#   's',
#   'fashion',
#   'magazine',
#   'flip',
#   'picture',
#   'teach',
#   'dres',
#   'read',
#   'column',
#   'drink',
#   'feminist',
#   'chicken',
#   'soup',
#   'life',
#   'too',
#   'easy',
#   'play',
#   'taijiquan',
#   'can',
#   'balance',
#   'casting',
#   'still',
#   'good',
#   'stay',
#   'classic'],
#  ['too',
#   'boring',
#   'director',
#   'shoot',
#   'love',
#   'vacation',
#   'shoot',
#   'workplace',
#   'story',
#   'whole',
#   'story',
#   'try',
#   'make',
#   'fuss',
#   'flat',
#   'life',
#   'so',
#   'mediocre'],
#  ['look', 'great'],
#  ['go', 'gentleman', 'old', 'man', 'go', 'passionate', 'goddes'],
#  ['one', 'hundred', 'thirty', 'star', 'end'],
#  ['urban',
#   'version',
#   'elderly',
#   'young',
#   'girl',
#   'matter',
#   'age',
#   'group',
#   'person',
#   'always',
#   'need',
#   'please',
#   'other',
#   'order',
#   'run',
#   'other'],
#  ['simple',
#   'comfortable',
#   'lack',
#   'depth',
#   'make',
#   'up',
#   'warmth',
#   'robert',
#   'simply',
#   'handsome',
#   'hathaway',
#   'so',
#   'pretty',
#   'expression',
#   'so',
#   'tight',
#   'little',
#   'girl',
#   'have',
#   'assistant',
#   'demon',
#   'head',
#   'woman',
#   'become',
#   'strongwoman',
#   'p'],
#  ['s',
#   'movie',
#   'textbook',
#   'level',
#   'dress',
#   'tutorial',
#   'hathaway',
#   's',
#   'light',
#   'mature',
#   'girl',
#   'ol',
#   'style',
#   'robert',
#   's',
#   'retro',
#   'suit',
#   'style',
#   'set',
#   'please',
#   'eye'],
#  ['so',
#   'happy',
#   'marriage',
#   'strong',
#   'woman',
#   'unsolvable',
#   'especially',
#   'water',
#   'sign',
#   'scumman'],
#  ['good',
#   'way',
#   'get',
#   'rid',
#   'cheat',
#   'husband',
#   'unfortunately',
#   'not',
#   'many',
#   'man',
#   'have',
#   'kind',
#   'awarenes'],
#  ['i',
#   'think',
#   'should',
#   'show',
#   'christmas',
#   'day',
#   'buy',
#   'warm',
#   'ginger',
#   'coffee',
#   'i',
#   'have',
#   'see',
#   'robert',
#   's',
#   'grandpa',
#   'movie',
#   'brain',
#   'powder',
#   'i',
#   'love',
#   'warm',
#   'bright',
#   'image',
#   'new',
#   'york',
#   'comedy',
#   'movie',
#   'unburden',
#   'circumstance'],
#  ['warm',
#   'inspiring',
#   'humorous',
#   'high',
#   'degree',
#   'completion',
#   'i',
#   'also',
#   'anna',
#   's',
#   'dres',
#   'movie',
#   'exemplary',
#   'work',
#   'woman',
#   'eastern',
#   'united',
#   'state'],
#  ['clothing',
#   'interior',
#   'design',
#   'guideline',
#   'first',
#   'half',
#   'more',
#   'interesting',
#   'relationship',
#   'harmonious',
#   'stereotype',
#   'gradually',
#   'appear',
#   'especially',
#   'addition',
#   'husband',
#   'character',
#   'entire',
#   'film',
#   'almost',
#   'degenerate',
#   'standardized',
#   'bad',
#   'film'],
#  ['i',
#   'think',
#   'intern',
#   'meant',
#   'robert',
#   'anne',
#   'hathaway',
#   'too',
#   'weak',
#   'hold',
#   'such',
#   'strongwoman'],
#  ['bowl',
#   'full',
#   'chicken',
#   'soup',
#   'i',
#   'think',
#   'robert',
#   'hathaway',
#   'go',
#   'roll',
#   'sheet'],
#  ['textbook',
#   'chicken',
#   'film',
#   'seriously',
#   'hathaway',
#   'play',
#   'feminist',
#   'figure',
#   'whole',
#   'place',
#   'taught',
#   'daddy',
#   'really',
#   'okay'],
#  ['three',
#   'half',
#   'star',
#   'i',
#   'watch',
#   'movie',
#   'robert',
#   'kind',
#   'american',
#   'feminine',
#   'inspirational',
#   'film',
#   'not',
#   'really',
#   'thing'],
#  ['very',
#   'warm',
#   'fairy',
#   'tale',
#   'wind',
#   'two',
#   'hour',
#   'do',
#   'not',
#   'feel',
#   'long',
#   'background',
#   'music',
#   'have',
#   'always',
#   'similar',
#   'tone',
#   'little',
#   'monotonous',
#   'princes',
#   'ann',
#   'play',
#   'bos',
#   'also',
#   'assistant',
#   'feel',
#   'drunk',
#   'woman',
#   's',
#   'right',
#   'bit',
#   'superficial',
#   'godfather',
#   'cute'],
#  ['i',
#   'have',
#   'have',
#   'lot',
#   'confuse',
#   'moment',
#   'year',
#   'few',
#   'time',
#   'i',
#   'naturally',
#   'think',
#   'dad',
#   'then',
#   'i',
#   'find',
#   'just',
#   'want',
#   'go',
#   'back',
#   'hometown',
#   'work',
#   'civil',
#   'servant',
#   'movie',
#   'movie',
#   'reality',
#   'reality',
#   'kind',
#   'feminine',
#   'color',
#   'allow',
#   'woman',
#   'have',
#   'sufficient',
#   'lewd',
#   'space',
#   'subject',
#   'matter',
#   'begin',
#   'bj',
#   'have',
#   'not',
#   'go',
#   'fashion',
#   'indeed'],
#  ['even',
#   'find',
#   'ultimate',
#   'handsome',
#   'guy',
#   'do',
#   'not',
#   'end',
#   'up',
#   'own'],
#  ['politically',
#   'correct',
#   'interesting',
#   'material',
#   'selection',
#   'strong',
#   'cas',
#   'whole',
#   'movie',
#   'full',
#   'embarrassment',
#   'helplessnes',
#   'apart',
#   'weak',
#   'tension',
#   'mainline',
#   'drama',
#   'old',
#   'man',
#   's',
#   'boring',
#   'personality',
#   'loose',
#   'narrative',
#   'protagonist',
#   's',
#   'lack',
#   'chemistry',
#   'fact',
#   'holm',
#   'office',
#   'live',
#   'too',
#   'much',
#   'model',
#   'house',
#   'hotel',
#   'use',
#   'look',
#   'annie',
#   'start',
#   'fashion',
#   'show',
#   'again',
#   'clothe',
#   'do',
#   'not',
#   'match',
#   'too',
#   'well'],
#  ['little', 'too', 'good', 'i', 'do', 'chicken', 'soup'],
#  ['year',
#   'dres',
#   'have',
#   'change',
#   'msixty',
#   'five',
#   'high',
#   'end',
#   'suit',
#   'walk',
#   'posture',
#   'have',
#   'not',
#   'change'],
#  ['drink',
#   'chicken',
#   'soup',
#   'i',
#   'will',
#   'identify',
#   'robert',
#   'anne',
#   'hathaway',
#   'brand'],
#  ['easy',
#   'effortless',
#   'comedy',
#   'super',
#   'cute',
#   'hathaway',
#   'also',
#   'beautiful',
#   'glitter',
#   'watch',
#   'whole',
#   'person',
#   'feel',
#   'very',
#   'happy'],
#  ['ahahahahahahahahaha',
#   'ben',
#   'tell',
#   'jule',
#   'pay',
#   'attention',
#   'inner',
#   'peace',
#   'bridge',
#   'play',
#   'taiji',
#   'tribute',
#   'kung',
#   'fu',
#   'panda'],
#  ['i', 'want', 'four', 'star'],
#  ['standard',
#   'hollywood',
#   'movie',
#   'end',
#   'hathaway',
#   'scumboy',
#   'take',
#   'point',
#   'off'],
#  ['late', 'life', 'corleone'],
#  ['content',
#   'seem',
#   'line',
#   'trend',
#   'actually',
#   'one',
#   'movie',
#   'that',
#   'basically',
#   'touch',
#   'time',
#   'screenwriter',
#   's',
#   'total',
#   'failure',
#   'create',
#   'conflict',
#   'just',
#   'hot',
#   'pot',
#   'sugar',
#   'water'],
#  ['happiness',
#   'cherish',
#   'have',
#   'now',
#   'have',
#   'now',
#   'do',
#   'not',
#   'know',
#   'will',
#   'lose',
#   'do',
#   'like',
#   'stick',
#   'original',
#   'self',
#   'treat',
#   'life',
#   'tolerant',
#   'heart'],
#  ['walk', 'edge', 'strange', 'feeling'],
#  ['problem',
#   's',
#   'age',
#   'many',
#   'scene',
#   'company',
#   's',
#   'young',
#   'employee',
#   'show',
#   'obvious',
#   'fatigue',
#   'perfunctory',
#   'more',
#   'performance',
#   'style',
#   'not',
#   'suitable',
#   'appearance',
#   'external',
#   'charm',
#   'show',
#   'comedy',
#   'script',
#   'impose',
#   'charismatic',
#   'aura',
#   'goodwill',
#   'make',
#   'quickly',
#   'focus',
#   'company',
#   's',
#   'attention',
#   'audience',
#   'do',
#   'not',
#   'really',
#   'feel',
#   'should'],
#  ['blink',
#   'act',
#   'high',
#   'end',
#   'atmospheric',
#   'travel',
#   'create',
#   'ambiguous',
#   'suspense',
#   'afraid',
#   'embarrassment',
#   'i',
#   'nervous',
#   'good',
#   'feel',
#   'progres',
#   'society'],
#  ['anne', 'hathaway', 'assistant', 'bos', 'still', 'wear', 'navy', 'sweater'],
#  ['rather', 'more', 'mediocre', 'expect', 'i', 'completely', 'mark', 'know'],
#  ['look',
#   'i',
#   'really',
#   'think',
#   'person',
#   'get',
#   'old',
#   'whole',
#   'character',
#   'will',
#   'change',
#   'round'],
#  ['life',
#   'also',
#   'like',
#   'play',
#   'tai',
#   'chi',
#   'balance',
#   'one',
#   'move',
#   'breathing',
#   'warm',
#   'little',
#   'piece',
#   'life',
#   'suitable',
#   'christma',
#   'eve',
#   'heal',
#   'mood',
#   'favorite',
#   'ben',
#   'austin',
#   'overtime',
#   'night',
#   'conversation',
#   'warm',
#   'light',
#   'ben',
#   'talk',
#   'forty',
#   'year',
#   'ago',
#   'use',
#   'work',
#   'place',
#   'brick',
#   'tile',
#   'paulownia',
#   'tree',
#   'front',
#   'window',
#   'so',
#   'familiar',
#   'tacit',
#   'understand',
#   'two',
#   'quietly',
#   'grow',
#   'unfortunately',
#   'film',
#   'too',
#   'formal',
#   'gentleman',
#   'must',
#   'bring',
#   'handkerchief',
#   'go',
#   'out'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'anne',
#   'hathaway',
#   'love',
#   'grow',
#   'up',
#   'four',
#   'half',
#   'star',
#   'first',
#   'have',
#   'translate',
#   'title',
#   'film',
#   'inexplicable',
#   'hong',
#   'kong',
#   'name',
#   'win',
#   'again',
#   'old',
#   'strong',
#   'old',
#   'man',
#   'princes',
#   'noble',
#   'couple',
#   'give',
#   'bowl',
#   'super',
#   'positive',
#   'energy',
#   'heart',
#   'chicken',
#   'soup',
#   'there',
#   'funny',
#   'zhong',
#   'want',
#   'master',
#   'do',
#   'job',
#   'steal',
#   'only',
#   'not',
#   'hurt',
#   'old',
#   'mother',
#   's',
#   'heart',
#   'kind',
#   'movie',
#   'have',
#   'good',
#   'return'],
#  ['robert',
#   's',
#   'eq',
#   'so',
#   'high',
#   'can',
#   'use',
#   'work',
#   'textbook',
#   'not',
#   'warn',
#   'boss',
#   'pay',
#   'attention',
#   'boss',
#   's',
#   'real',
#   'need',
#   'handle',
#   'relationship',
#   'colleague',
#   'do',
#   'job',
#   'diligently'],
#  [],
#  ['almost', 'four', 'star'],
#  ['person',
#   'admire',
#   'old',
#   'habit',
#   'have',
#   'achieve',
#   'something',
#   'secondary',
#   'industry',
#   'style',
#   'play',
#   'write',
#   'too',
#   'casually',
#   'shelf',
#   'well',
#   'build',
#   'meat',
#   'inside',
#   'not',
#   'enough',
#   'porcelain',
#   'good',
#   'use',
#   'old',
#   'service',
#   'industry',
#   's',
#   'strict',
#   'self',
#   'discipline',
#   'executive',
#   'new',
#   'service',
#   'industry',
#   'break',
#   'dogma',
#   'female',
#   'strongman',
#   'start',
#   'point',
#   'storytelling'],
#  ['grandpa',
#   'so',
#   'cute',
#   'really',
#   'kind',
#   'do',
#   'not',
#   'know',
#   'refuse',
#   'other',
#   'leave',
#   'step',
#   'other',
#   'all',
#   'time',
#   'good',
#   'discover',
#   'joy',
#   'life'],
#  ['great', 'act', 'general', 'story'],
#  ['close',
#   'non',
#   'religious',
#   'relationship',
#   'can',
#   'think',
#   'bury',
#   'death',
#   'visual',
#   'hardware',
#   'beautiful',
#   'story',
#   'much',
#   'good',
#   'i',
#   'think',
#   'thankfully',
#   'not',
#   'cheesy',
#   'mother',
#   'daughter',
#   'relationship',
#   'sexism',
#   'retro',
#   'era',
#   'feel',
#   'one',
#   'point',
#   'bruise',
#   'that',
#   'have',
#   'not',
#   'scratch',
#   'era',
#   'one',
#   'involve',
#   'nostalgia',
#   'sigh'],
#  ['new', 'york', 'beautiful'],
#  ['old',
#   'intern',
#   's',
#   'idea',
#   'standard',
#   'chick',
#   'movie',
#   'add',
#   'warmth',
#   'theme',
#   'female',
#   'inspiration',
#   'ben',
#   'completely',
#   'retain',
#   'spirit',
#   'merit',
#   'traditional',
#   'industry',
#   'avoid',
#   'cost',
#   'move',
#   'secondary',
#   'tertiary',
#   'industry',
#   'nice',
#   'healing',
#   'ben',
#   'tell',
#   'wife',
#   's',
#   'story',
#   'not',
#   'long',
#   'enough',
#   'fall',
#   'completely',
#   'once',
#   'again',
#   'i',
#   'have',
#   'lament',
#   'story',
#   'romantic',
#   'as',
#   'long',
#   'middle',
#   'clas'],
#  ['two', 'star', 'well', 'choose', 'think', 'version', 'queen', 'prada'],
#  ['much',
#   'well',
#   'look',
#   'i',
#   'think',
#   'i',
#   'think',
#   'queen',
#   'prada',
#   'know',
#   'completely',
#   'upside',
#   'down',
#   'anne',
#   'hathaway',
#   's',
#   'outfit',
#   'really',
#   'too',
#   'good',
#   'look'],
#  ['airplane',
#   'movie',
#   'chicken',
#   'soup',
#   'content',
#   'preview',
#   'most',
#   'focu',
#   'various',
#   'interior',
#   'design',
#   'trance',
#   'can',
#   'also',
#   'see',
#   'hathaway',
#   'sit',
#   'door',
#   'aunt',
#   'may',
#   's',
#   'office',
#   'shadow',
#   'small',
#   'assistant',
#   'age',
#   'have',
#   'say',
#   'nothing',
#   'look',
#   'expression',
#   'can',
#   'become',
#   'life',
#   'mentor'],
#  ['unbreakable',
#   'truth',
#   'well',
#   'organize',
#   'hollywood',
#   'assembly',
#   'line',
#   'piece',
#   'regardless',
#   'quality',
#   'example',
#   'cultural',
#   'analysi'],
#  ['young',
#   'woman',
#   'attract',
#   'controlled',
#   'conservative',
#   'old',
#   'white',
#   'man',
#   'turn',
#   'away',
#   'contemporary',
#   'man',
#   'rely',
#   'help',
#   'career',
#   'family',
#   'affirmatism',
#   'always',
#   'end',
#   'positive',
#   'image',
#   'end',
#   'negative',
#   'one'],
#  ['forty',
#   'year',
#   'kramer',
#   'hollywood',
#   's',
#   'right',
#   'wing',
#   'stance',
#   'hypocritical',
#   'morality',
#   'have',
#   'never',
#   'change'],
#  ['pack',
#   'grow',
#   'up',
#   'fairy',
#   'tale',
#   'mainly',
#   'see',
#   'hostess',
#   'change',
#   'set',
#   'beautiful',
#   'clothe',
#   'drink',
#   'director',
#   'pour',
#   'chicken',
#   'soup',
#   'film',
#   'throw',
#   'out',
#   'topic',
#   'work',
#   'family',
#   'issue',
#   'there',
#   'workplace',
#   'entrepreneurship',
#   'continuation',
#   'problem',
#   'try',
#   'ask',
#   'which',
#   'one',
#   'take',
#   'seriously'],
#  ['end',
#   'nothing',
#   'resolve',
#   'all',
#   'thin',
#   'film',
#   'most',
#   'regrettable',
#   'thing',
#   'find',
#   'such',
#   'fresh',
#   'old',
#   'young',
#   'partner',
#   'not',
#   'able',
#   'dig',
#   'up',
#   'deep',
#   'spark',
#   'interaction'],
#  ['ever',
#   'i',
#   'find',
#   'out',
#   'director',
#   'nancy',
#   'meyer',
#   'also',
#   'hollywood',
#   's',
#   'top',
#   'interior',
#   'designer',
#   'i',
#   'have',
#   'star',
#   'hard',
#   'protagonist',
#   's',
#   'house',
#   'die',
#   'office',
#   'american',
#   'style',
#   'natural',
#   'light',
#   'window',
#   'too',
#   'comfortable',
#   'use',
#   'movie',
#   'pretty',
#   'cute'],
#  ['hathaway', 's', 'not', 'do', 'very', 'well'],
#  ['taipei',
#   'thin',
#   'overall',
#   'just',
#   'fashion',
#   'show',
#   'design',
#   'can',
#   'not',
#   'stand',
#   'taste',
#   'male',
#   'character',
#   'design',
#   'too',
#   'weak'],
#  ['robert',
#   'super',
#   'love',
#   'actor',
#   'annie',
#   's',
#   'youth',
#   'front',
#   'just',
#   'compound',
#   'need',
#   'plot',
#   'succes',
#   'casting',
#   'self',
#   'evident',
#   'addition',
#   'workplace',
#   'europe',
#   'united',
#   'state',
#   'very',
#   'natural',
#   'matter',
#   'shoot',
#   'such',
#   'office',
#   'hang',
#   'bell',
#   'such',
#   'office',
#   'masseuse',
#   'so',
#   'contrary',
#   'chinese',
#   'film',
#   'appear',
#   'workplace',
#   'there',
#   'mysterious',
#   'temperament',
#   'fuck',
#   'kid'],
#  ['i', 'do', 'not', 'know', 'short', 'ron', 'worth', 'four', 'star'],
#  ['chicken',
#   'soup',
#   'movie',
#   'guise',
#   'feminism',
#   'career',
#   'company',
#   'should',
#   'main',
#   'line',
#   'independent',
#   'female',
#   'screenwriter',
#   'not',
#   'very',
#   'perfunctory',
#   'female',
#   'image',
#   'i',
#   'busy',
#   'obsessive',
#   'first',
#   'find',
#   'ceo',
#   'too',
#   'large',
#   'control',
#   'finally',
#   'screenwriter',
#   'forget',
#   'ballast',
#   'only',
#   'become',
#   'family',
#   'vs',
#   'career',
#   'tangle'],
#  ['pseudo',
#   'feminist',
#   'movie',
#   'masterpiece',
#   'just',
#   'find',
#   'more',
#   'mature',
#   'male',
#   'mentor'],
#  ['overtime',
#   'night',
#   'talk',
#   'ben',
#   'back',
#   'work',
#   'original',
#   'place',
#   'arrange',
#   'space',
#   'big',
#   'paulownia',
#   'very',
#   'touching',
#   'new',
#   'start',
#   'office',
#   'scene',
#   'only',
#   'highlight',
#   'unattended',
#   'desk',
#   'conference',
#   'room',
#   'use',
#   'several',
#   'time',
#   'there',
#   'good',
#   'sense',
#   'scene',
#   'bridge',
#   'section',
#   'very',
#   'old',
#   'especially',
#   'four',
#   'man',
#   'steal',
#   'computer',
#   'section',
#   'which',
#   'compromise',
#   'contemporary',
#   'comedy',
#   'robert',
#   'perform',
#   'well',
#   'character',
#   'too',
#   'warm'],
#  ['i',
#   'have',
#   'complain',
#   'day',
#   'much',
#   'i',
#   'need',
#   'bowl',
#   'positive',
#   'energy',
#   'chicken',
#   'soup'],
#  ['seventy',
#   'year',
#   'old',
#   'veteran',
#   'handsome',
#   'man',
#   'help',
#   'taobao',
#   'young',
#   'woman',
#   'shop',
#   'manager',
#   'start',
#   'warm',
#   'inspirational',
#   'story',
#   'american',
#   'internet',
#   'entrepreneurship',
#   'ruin',
#   'life',
#   'cultivate',
#   'body',
#   'mind',
#   'still',
#   'rely',
#   'chinese',
#   'qigong'],
#  ['take',
#   'intern',
#   's',
#   'salary',
#   'work',
#   'twelve',
#   'hour',
#   'day',
#   'boss',
#   'also',
#   'help',
#   'bos',
#   'take',
#   'child',
#   'drive',
#   'not',
#   'disguise',
#   'squeeze',
#   'cheap',
#   'labor'],
#  ['bore', 'explode'],
#  ['hathaway',
#   's',
#   'husband',
#   'cheat',
#   'big',
#   'tension',
#   'movie',
#   'resolve',
#   'husband',
#   'confess',
#   'realize',
#   'real',
#   'reason',
#   'hathaway',
#   'originally',
#   'want',
#   'hire',
#   'external',
#   'management',
#   'vc',
#   'pressure',
#   'invisible',
#   'forgotten'],
#  ['i',
#   'think',
#   'end',
#   'point',
#   'integrate',
#   'senior',
#   'intern',
#   'modern',
#   'internet',
#   'workplace'],
#  ['result',
#   'female',
#   'bos',
#   'balance',
#   'career',
#   'family',
#   'finally',
#   'husband',
#   's',
#   'repentance',
#   'unnecessary'],
#  ['i',
#   'sorry',
#   'i',
#   'talk',
#   'today',
#   'elder',
#   'i',
#   'intern',
#   'i',
#   'have',
#   'see',
#   'too',
#   'much',
#   'i',
#   'need',
#   'tell',
#   'little',
#   'bit',
#   'life',
#   'experience'],
#  ['warm',
#   'friendship',
#   'there',
#   'bullet',
#   'curtain',
#   'cut',
#   'off',
#   'god',
#   'go',
#   'down',
#   'mountain',
#   'guides',
#   'person',
#   'go',
#   'up',
#   'mountain'],
#  ['robert',
#   's',
#   'charm',
#   'not',
#   'diminish',
#   'really',
#   'cool',
#   'compare',
#   'bunch',
#   'little',
#   'brat',
#   'movie',
#   'say',
#   'have',
#   'forty',
#   'two',
#   'year',
#   'old',
#   'marriage',
#   'eighteen',
#   'year',
#   'old',
#   'wife',
#   'love',
#   'mind',
#   'automatically',
#   'give',
#   'birth',
#   'godfather',
#   'stand',
#   'curtain',
#   'shoot',
#   'scene',
#   'eighteen',
#   'year',
#   'old',
#   'meet',
#   'wife',
#   'gangster',
#   'hahahahahahahahahaha'],
#  ['ten',
#   'year',
#   'later',
#   'little',
#   'assistant',
#   'grow',
#   'up',
#   'strong',
#   'woman',
#   'eye',
#   'not',
#   'broaden',
#   'first',
#   'half',
#   'movie',
#   'very',
#   'good',
#   'whole',
#   'thing',
#   'too',
#   'light',
#   'style',
#   'delete',
#   'email',
#   'very',
#   'abrupt'],
#  ['middle',
#   'rule',
#   'miao',
#   'da',
#   'good',
#   'old',
#   'grandfather',
#   'fragrant',
#   'standard',
#   'appearance',
#   'exquisite',
#   'high',
#   'cold',
#   'inner',
#   'fragile',
#   'crisi',
#   'strong',
#   'female',
#   'strongman',
#   'end',
#   'strong',
#   'point',
#   'piece',
#   'child',
#   's',
#   'right',
#   'pant',
#   'look',
#   'scum',
#   'man',
#   'confess',
#   'forgive',
#   'bridge',
#   'let',
#   'loose',
#   'know',
#   'must',
#   'spray',
#   'dog',
#   'do',
#   'say',
#   'wildfire',
#   'burn',
#   'spring',
#   'breeze',
#   'again',
#   'turbulent',
#   'heart',
#   'spring',
#   'up',
#   'first',
#   'time',
#   'pinch',
#   'will',
#   'grow',
#   'second',
#   'time',
#   'third',
#   'time',
#   'become',
#   'hulunbuir',
#   'prairie',
#   'very',
#   'cocky'],
#  ['bright',
#   'color',
#   'eternal',
#   'preach',
#   'elderly',
#   'minute',
#   'teach',
#   'little',
#   'woman',
#   'human',
#   'look',
#   'do',
#   'not',
#   'look',
#   'same'],
#  ['commercial',
#   'cute',
#   'story',
#   'only',
#   'thing',
#   'that',
#   'upsetting',
#   'word',
#   'feminine',
#   'right',
#   'appear',
#   'film',
#   's',
#   'usual',
#   'label'],
#  ['plot',
#   'gentle',
#   'old',
#   'drama',
#   'bone',
#   'acting',
#   'really',
#   'comfortable',
#   'great',
#   'secret',
#   'not',
#   'afraid',
#   'old',
#   'age',
#   'allow',
#   'time',
#   'give',
#   'valuable',
#   'wealth',
#   'not',
#   'just',
#   'wrinkle',
#   'gray',
#   'hair',
#   'also',
#   'fortunate',
#   'have',
#   'someone',
#   'talk',
#   'lose'],
#  ['grandpa', 'cook', 'bowl', 'soul', 'soup', 'drink'],
#  ['time',
#   'eat',
#   'just',
#   'look',
#   'around',
#   'spend',
#   'relax',
#   'night',
#   'burn',
#   'brain',
#   'course',
#   'do',
#   'not',
#   'care',
#   'keep',
#   'look',
#   'other',
#   'half',
#   'next',
#   'day'],
#  ['great',
#   'movie',
#   'watch',
#   'plane',
#   'hathaway',
#   's',
#   'fashion',
#   'show',
#   'gentlemanly',
#   'demeanor',
#   'really',
#   'charm'],
#  ['i',
#   'want',
#   'see',
#   'story',
#   'old',
#   'intern',
#   'okay',
#   'i',
#   'do',
#   'not',
#   'want',
#   'see',
#   'family',
#   'love',
#   'story',
#   'young',
#   'beautiful',
#   'entrepreneurial',
#   'executive',
#   'really',
#   'want',
#   'tell',
#   'such',
#   'story',
#   'please',
#   'change',
#   'intern',
#   'struggle',
#   'jule'],
#  ['never', 'wrong', 'do', 'right', 'thing'],
#  ['i',
#   'have',
#   'see',
#   'twice',
#   'short',
#   'time',
#   'attention',
#   'run',
#   'difficulty',
#   'i',
#   'think',
#   'annie',
#   'use',
#   'witch',
#   'wear',
#   'prada',
#   'now',
#   'intern',
#   'distant',
#   'idol',
#   'get',
#   'good',
#   'walk',
#   'well',
#   'glad'],
#  ['bore'],
#  ['internship',
#   'five',
#   'most',
#   'interesting',
#   'part',
#   'whole',
#   'movie',
#   'blue',
#   'frog'],
#  ['queen', 'prada', 'ii'],
#  ['subject',
#   'matter',
#   'really',
#   'brilliant',
#   'point',
#   'point',
#   'end',
#   'little',
#   'less',
#   'flavor'],
#  ['gentlemanly',
#   'workplace',
#   'light',
#   'comedy',
#   'young',
#   'old',
#   'post',
#   'cause',
#   'misplaced',
#   'laughter',
#   'relax',
#   'chicken',
#   'movie',
#   'pleasant',
#   'adult',
#   'fairy',
#   'tale',
#   'ten',
#   'year',
#   'later',
#   'hathaway',
#   'go',
#   'prada',
#   's',
#   'little',
#   'assistant',
#   'queen',
#   'become',
#   'more',
#   'more',
#   'woody',
#   'allen'],
#  ['i', 'saw', 'begin', 'plane', 'have', 'opportunity', 'continue', 'watch'],
#  ['nancy',
#   'meyer',
#   'script',
#   'direct',
#   'make',
#   'film',
#   'very',
#   'fluid',
#   'begin',
#   'story',
#   'move',
#   'forward',
#   'very',
#   'comfortable',
#   'cheerful',
#   'pace',
#   'which',
#   'bit',
#   'silk',
#   'soft',
#   'feeling',
#   'which',
#   'most',
#   'chinese',
#   'comedy',
#   'romantic',
#   'film',
#   'can',
#   'not',
#   'do',
#   'two',
#   'main',
#   'character',
#   'good',
#   'especially',
#   'hathaway',
#   'look',
#   'beautiful',
#   'fashionable',
#   'overall',
#   'standard',
#   'film',
#   'rather',
#   'average',
#   'lack',
#   'clear',
#   'theme',
#   'second',
#   'half',
#   'film',
#   'have',
#   'collapse',
#   'lot',
#   'far',
#   'inferior',
#   'devil',
#   'wear',
#   'prada'],
#  ['see',
#   'anne',
#   'come',
#   'proces',
#   'look',
#   'comfortable',
#   'plot',
#   'general',
#   'not',
#   'strengthen',
#   'old',
#   'point',
#   'comedy',
#   'play',
#   'sublimation',
#   'theme',
#   'there',
#   'lot',
#   'room'],
#  ['whole',
#   'world',
#   'pink',
#   'film',
#   'say',
#   'woman',
#   's',
#   'right',
#   'funny',
#   'general',
#   'chicken',
#   'flick',
#   'ah',
#   'really',
#   'too',
#   'cute'],
#  ['first',
#   'half',
#   'plot',
#   'very',
#   'interesting',
#   'discussion',
#   'definition',
#   'man',
#   'also',
#   'very',
#   'good',
#   'which',
#   'little',
#   'too',
#   'flattering',
#   'woman',
#   'slightly',
#   'distort',
#   'unprincipled',
#   'female',
#   'protagonist'],
#  ['enter',
#   'too',
#   'slowly',
#   'commercial',
#   'film',
#   'emotional',
#   'agitation',
#   'latter',
#   'half',
#   'very',
#   'effective',
#   'due',
#   'fullnes',
#   'character',
#   'effective',
#   'present',
#   'day',
#   'feminist',
#   'value',
#   'just',
#   'stop',
#   'blame',
#   'someone',
#   'else',
#   's',
#   'fault'],
#  ['i',
#   'can',
#   'not',
#   'imagine',
#   'young',
#   'man',
#   'taxi',
#   'driver',
#   'get',
#   'old',
#   'i',
#   'do',
#   'not',
#   'expect',
#   'find',
#   'answer',
#   'movie',
#   'i',
#   'have',
#   'confuse',
#   'long',
#   'time'],
#  ['plain', 'water'],
#  ['budget', 'must', 'have', 'go', 'end', 'movie'],
#  ['parent', 'ceo', 'recruitment', 'do', 'not', 'even', 'have', 'shadow'],
#  ['however',
#   'not',
#   'story',
#   'interesting',
#   'event',
#   'post',
#   'eightys',
#   'boss',
#   'post',
#   'forty',
#   'intern'],
#  ['grandpa', 'really', 'perfect'],
#  ['medium',
#   'size',
#   'piece',
#   'female',
#   'chicken',
#   'yes',
#   'chicken',
#   'fillet',
#   'now',
#   'world',
#   'woman',
#   's',
#   'girder',
#   'movie',
#   'raise',
#   'standard',
#   'warm',
#   'man',
#   'old',
#   'age',
#   'not',
#   'uncle',
#   's',
#   'turn',
#   'uncle',
#   's',
#   'turn',
#   'acting',
#   'really',
#   'natural',
#   'even',
#   'shadow',
#   'hathaway',
#   'seconds',
#   'eye'],
#  ['s',
#   'appearance',
#   'film',
#   'hollywood',
#   'tragedy',
#   'good',
#   'movie',
#   'star',
#   'play',
#   'taxi',
#   'driver',
#   'good',
#   'fella',
#   'also',
#   'heartbreaking',
#   'squeeze',
#   'eyebrow',
#   'such',
#   'spat',
#   'film',
#   'hollywood',
#   'reporter',
#   'write',
#   'article',
#   'that',
#   'also',
#   'indirectly',
#   'question',
#   's',
#   'personal',
#   'wealth',
#   'deficit',
#   'extent',
#   'need',
#   'play',
#   'bad',
#   'grandpa',
#   'intern',
#   'which',
#   'not',
#   'movie'],
#  ['act', 'so', 'tacky', 'i', 'hate', 'anne', 'hathaway'],
#  ['princess', 'diary'],
#  ['die',
#   'handsome',
#   'call',
#   'gentleman',
#   'call',
#   'elegant',
#   'man',
#   'plot',
#   'do',
#   'not',
#   'talk',
#   'especially',
#   'end',
#   'let',
#   'dump',
#   'cheat',
#   'old',
#   'recognize',
#   'de',
#   'godfather'],
#  ['subconscious',
#   'mind',
#   'traditional',
#   'patriarchal',
#   'audience',
#   'will',
#   'never',
#   'allow',
#   'successful',
#   'powerful',
#   'woman',
#   'end',
#   'well',
#   'screen',
#   'audience',
#   'will',
#   'only',
#   'want',
#   'expel',
#   'name',
#   'patriarchy',
#   'sanction',
#   'bankruptcy',
#   'failure',
#   'infidelity',
#   'etc'],
#  ['postmodern',
#   'patriarchy',
#   'hide',
#   'more',
#   'hidden',
#   'way',
#   'pretend',
#   'give',
#   'strongwoman',
#   'good',
#   'end',
#   'only',
#   'gaze',
#   'male',
#   'character',
#   'control',
#   'whole',
#   'situation',
#   'ben',
#   'symbol',
#   'patriarchal',
#   'authority',
#   'status',
#   'super',
#   'powerful',
#   'woman',
#   'play',
#   'seaway',
#   'movie',
#   'show',
#   'fragile',
#   'side',
#   'front',
#   'ben',
#   'audience',
#   'identify',
#   'ben',
#   'have',
#   'orgasm',
#   'skull',
#   'same',
#   'time',
#   'emit',
#   'strong',
#   'stench'],
#  ['neymar',
#   'i',
#   'also',
#   'want',
#   'have',
#   'kind',
#   'forgetful',
#   'friendship',
#   'cause',
#   'have',
#   'moist',
#   'silent',
#   'show',
#   'way'],
#  ['i', 'plant', 'sleep', 'gown'],
#  ['general', 'anne', 'hathaway', 'beat', 'back', 'original', 'form'],
#  ['great', 'adult', 'gentleman', 'hathaway', 'not', 'flat', 'chested'],
#  ['brooklyn', 'too', 'clean', 'second', 'half', 'catch', 'horse'],
#  ['old', 'man', 'intelligent', 'gracious', 'not', 'control', 'even', 'love'],
#  ['watch',
#   'taxi',
#   'driver',
#   'monday',
#   'watch',
#   'friday',
#   'week',
#   'forty',
#   'year',
#   'old',
#   'de',
#   'still',
#   'handsome',
#   'smart',
#   'comedy',
#   'have',
#   'good',
#   'rhythm',
#   'very',
#   'delicate',
#   'cute',
#   'i',
#   'really',
#   'appreciate',
#   's',
#   'performance',
#   'director',
#   'still',
#   'very',
#   'skilled'],
#  ['i',
#   'think',
#   'movie',
#   'weird',
#   'i',
#   'always',
#   'think',
#   'anne',
#   'hathaway',
#   'go',
#   'roll',
#   'sheet',
#   'seventy',
#   'year',
#   'old',
#   'uncle',
#   'i',
#   'have',
#   'wonder',
#   'not',
#   'get',
#   'here'],
#  ['love',
#   'interior',
#   'design',
#   'live',
#   'room',
#   'kitchen',
#   'office',
#   'particularly',
#   'good',
#   'hollywood',
#   'director',
#   'best',
#   'interior',
#   'design',
#   'i',
#   'do',
#   'not',
#   'plot',
#   'pseudo',
#   'feminine',
#   'ben',
#   'very',
#   'attractive'],
#  ['position', 'taijiquan', 'heart', 'american', 'empire'],
#  ['plain', 'chicken', 'soup'],
#  ['lei',
#   'ren',
#   'heroine',
#   'paragraph',
#   'good',
#   'man',
#   'use',
#   'man',
#   'nowadays',
#   'do',
#   'not',
#   'grow',
#   'big',
#   'speech',
#   'i',
#   'can',
#   'not',
#   'believe',
#   'kind',
#   'silly',
#   'fork',
#   'talk',
#   'would',
#   'come',
#   'anne',
#   'hathaway',
#   's',
#   'mouth',
#   'once',
#   'time',
#   'there',
#   'jack',
#   'nicholson',
#   'now',
#   'there',
#   'ezra',
#   'miller',
#   'addition',
#   'there',
#   'many',
#   'man',
#   'racist',
#   'sexist',
#   'past',
#   'so',
#   'glorify',
#   'man',
#   'likely',
#   'same',
#   'gay',
#   'man',
#   'hate',
#   'discriminate',
#   'wife',
#   'exercise',
#   'yes',
#   'just',
#   'fit',
#   'more',
#   'gender',
#   'stereotype'],
#  ['thought',
#   'such',
#   'lovely',
#   'old',
#   'man',
#   'luo',
#   'go',
#   'play',
#   'dirty',
#   'old',
#   'man',
#   'dirty',
#   'grandfather',
#   'place'],
#  ['bed',
#   'scene',
#   'end',
#   'really',
#   'embarrass',
#   'almost',
#   'bring',
#   'plot',
#   'bad',
#   'end',
#   'there',
#   'absolutely',
#   'need',
#   'create',
#   'embarrass',
#   'illusion',
#   'whole',
#   'article',
#   'still',
#   'reflection',
#   'work',
#   'place',
#   'worth',
#   'see'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'anne',
#   's',
#   'relationship',
#   'i',
#   'always',
#   'think',
#   'queen',
#   'wear',
#   'prada',
#   'year',
#   'old',
#   'daughter',
#   'law',
#   'stay',
#   'up',
#   'mother',
#   'law'],
#  ['hard', 'strong', 'woman', 'not', 'strong', 'woman'],
#  ['could',
#   'not',
#   'accept',
#   'cheat',
#   'husband',
#   'there',
#   'would',
#   'sand',
#   'eye'],
#  ['fairy',
#   'tale',
#   'do',
#   'not',
#   'count',
#   'brainwash',
#   'united',
#   'state',
#   'really',
#   'want',
#   'send',
#   'retiree',
#   'back',
#   'work',
#   'kind',
#   'trick',
#   'use',
#   'everyone',
#   'there',
#   'pretend',
#   'wear',
#   'thick',
#   'mask',
#   'pig',
#   'skin',
#   'mask',
#   'so',
#   'beautifully',
#   'carve',
#   'hard',
#   'notice',
#   'grease',
#   'abnormality',
#   'moment'],
#  ['genre',
#   'determine',
#   'must',
#   'avoid',
#   'light',
#   'side',
#   'tell',
#   'life',
#   'not',
#   'complete',
#   'noble',
#   'sub',
#   'complete',
#   'appearance',
#   'least',
#   'one',
#   'thing',
#   'true',
#   'there',
#   'many',
#   'thing',
#   'that',
#   'can',
#   'not',
#   'exchange'],
#  ['not',
#   'sixty',
#   'year',
#   'old',
#   'senior',
#   'intern',
#   'clearly',
#   'gentleman',
#   'vice',
#   'president',
#   'forty',
#   'year',
#   'busines',
#   'experience'],
#  ['adult', 'disney'],
#  ['unreal'],
#  ['annie', 's', 'clothe', 'very', 'pretty'],
#  ['grandpa', 'very', 'cute', 'value', 'shit'],
#  ['basically',
#   'can',
#   'think',
#   'robert',
#   'director',
#   'want',
#   'prove',
#   'old',
#   'man',
#   'do',
#   'something',
#   'play',
#   'special',
#   'effect',
#   'old',
#   'experience',
#   'still',
#   'classic',
#   'renee',
#   'russell',
#   'old',
#   'too',
#   'i',
#   'grow',
#   'up',
#   'watch',
#   'movie'],
#  ['experience', 'curriculum', 'vita', 'that', 'never', 'go', 'fashion'],
#  ['boring', 'time', 'end', 'one', 'star', 'less'],
#  ['nine',
#   'year',
#   'later',
#   'anne',
#   'still',
#   'beautiful',
#   'male',
#   'protagonist',
#   'really',
#   'mary',
#   'sue',
#   'person',
#   'set',
#   'ah',
#   'person',
#   'see',
#   'love',
#   'flower',
#   'bloom',
#   'first',
#   'step',
#   'capture',
#   'hearts',
#   'all',
#   'support',
#   'actor',
#   'include',
#   'heart',
#   'competitor',
#   'then',
#   'capture',
#   'heart',
#   'boss',
#   'even',
#   'daughter',
#   'omg',
#   'not',
#   'boss',
#   'fell',
#   'love'],
#  ['dig', 'heart'],
#  ['dig', 'shit'],
#  ['very',
#   'warm',
#   'too',
#   'perfect',
#   'i',
#   'ed',
#   'niro',
#   'anne',
#   'hathaway',
#   'comparison',
#   'so',
#   'miserable'],
#  ['gentleman', 'charm', 'all', 'time'],
#  ['i', 'have', 'look', 'kind', 'clothe', 'ww', 's', 'last', 'outfit'],
#  ['robert', 'downey', 'jr', 's', 'dad', 'old', 'more', 'handsome', 'really'],
#  ['inexplicable',
#   'script',
#   'do',
#   'protagonist',
#   's',
#   'focu',
#   'trainee',
#   'suddenly',
#   'turn',
#   'psychiatrist',
#   'two',
#   'main',
#   'character',
#   'very',
#   'realistic',
#   'cute',
#   'i',
#   'still',
#   'do',
#   'not',
#   'understand',
#   'i',
#   'should',
#   'watch',
#   'movie',
#   'finally',
#   'practice',
#   'yoga',
#   'together'],
#  ['do', 'host', 'feel', 'one', 'bury', 'together', 'divorce', 'tong', 'liya'],
#  ['own',
#   'father',
#   'will',
#   'not',
#   'let',
#   'bury',
#   'back',
#   'mother',
#   's',
#   'house'],
#  ['grandpa',
#   'intern',
#   'very',
#   'new',
#   'actually',
#   'give',
#   'female',
#   'bos',
#   'lot',
#   'spiritual',
#   'guidance',
#   'courage',
#   'life',
#   'experience',
#   'treasure',
#   'end',
#   'female',
#   'bos',
#   'forgive',
#   'cheat',
#   'husband',
#   'which',
#   'not',
#   'very',
#   'comfortable',
#   'heart'],
#  ['love', 'shopkeeper'],
#  ['surprisingly', 'heartwarming', 'fun', 'inspire'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'three',
#   'fifteen',
#   'nine',
#   'hundred',
#   'forty',
#   'six',
#   'just',
#   'ready',
#   'travel',
#   'release',
#   'movie',
#   'have',
#   'time',
#   'go',
#   'cinema',
#   'see',
#   'there',
#   'work',
#   'recently',
#   'think',
#   'watch',
#   'call',
#   'intern',
#   'may',
#   'helpful',
#   'very',
#   'comfortable',
#   'light',
#   'comedy',
#   'absurd',
#   'plot',
#   'only',
#   'solid',
#   'narrative',
#   'normal',
#   'character',
#   'not',
#   'much',
#   'look',
#   'forward',
#   'lot',
#   'gain'],
#  ['way',
#   'return',
#   'teach',
#   'young',
#   'person',
#   'work',
#   'live',
#   'gentleman',
#   'also',
#   'taught',
#   'young',
#   'person',
#   'adapt',
#   'modern',
#   'society',
#   'do',
#   'think',
#   'wrong',
#   'give',
#   'nice',
#   'old',
#   'vice',
#   'president',
#   'retirement',
#   'advise',
#   'job',
#   'price',
#   'intern',
#   'give',
#   'personal',
#   'babysitter'],
#  ['warm',
#   'movie',
#   'such',
#   'love',
#   'first',
#   'sight',
#   'harry',
#   'meet',
#   'sally',
#   'go',
#   'leave',
#   'danny',
#   'collin',
#   'little',
#   'faith',
#   'i',
#   'give',
#   'three',
#   'star',
#   'three',
#   'star',
#   'together',
#   'road',
#   'movie',
#   'feel',
#   'two',
#   'type',
#   'movie',
#   'suitable',
#   'leisure',
#   'relaxation',
#   'so',
#   'i',
#   'have',
#   'rat',
#   'so',
#   'many',
#   'movie',
#   'i',
#   'have',
#   'conclude',
#   'own',
#   'rating',
#   'four',
#   'star',
#   'more',
#   'there',
#   'have',
#   'depth'],
#  ['forgotten',
#   'new',
#   'year',
#   's',
#   'friendship',
#   'really',
#   'addition',
#   'family',
#   'love',
#   'most',
#   'touching',
#   'friendship',
#   'standard',
#   'woman',
#   'chicken',
#   'soup',
#   'full',
#   'warm',
#   'feeling',
#   'uncle',
#   's',
#   'person',
#   'deeply',
#   'interpret',
#   'gentleman',
#   's',
#   'character',
#   'connotation',
#   'cultivation',
#   'grace',
#   'anne',
#   'successfully',
#   'evolve',
#   'work',
#   'girl',
#   'wear',
#   'prada',
#   'miranda',
#   'family',
#   'busines',
#   'difficult',
#   'director',
#   's',
#   'filming',
#   'style',
#   'very',
#   'much',
#   'appetite',
#   'idealize',
#   'story',
#   'even',
#   'i',
#   'see',
#   'ten',
#   'thousand',
#   'time',
#   'again',
#   'ah'],
#  ['expound',
#   'old',
#   'profession',
#   'most',
#   'emotional',
#   'window',
#   'position',
#   'forty',
#   'year',
#   'do',
#   'same',
#   'job',
#   'do',
#   'right',
#   'never',
#   'wrong'],
#  ['there',
#   'lack',
#   'comedy',
#   'life',
#   'everything',
#   'country',
#   'miss',
#   'main',
#   'theme'],
#  ['two',
#   'hour',
#   'screenwriting',
#   'not',
#   'enough',
#   'time',
#   'see',
#   'even',
#   'final',
#   'capture',
#   'adultery',
#   'divorce',
#   'have',
#   'save',
#   'dog',
#   'blood'],
#  ['grandpa', 's', 'idea', 'would', 'perfect'],
#  ['plot',
#   'not',
#   'particularly',
#   'old',
#   'fashion',
#   'whole',
#   'movie',
#   'give',
#   'sense',
#   'good',
#   'old',
#   'fashion',
#   'i',
#   'can',
#   'not',
#   'say',
#   'follow',
#   'up',
#   'plot',
#   'come',
#   'watch',
#   'i',
#   'will',
#   'think',
#   'kind',
#   'drama',
#   'indeed',
#   'kind',
#   'plot',
#   'trend',
#   'line',
#   'match',
#   'ah'],
#  ['so',
#   'can',
#   'define',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'intermediate',
#   'level',
#   'composition',
#   'different',
#   'still',
#   'can',
#   'recognize',
#   'glance',
#   'college',
#   'entrance',
#   'examination',
#   'composition',
#   'too',
#   'template'],
#  ['film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman',
#   'quality',
#   'actually',
#   'good',
#   'early',
#   'stage',
#   'can',
#   'give',
#   'seven',
#   'even',
#   'eight',
#   'point',
#   'forgiveness',
#   'end',
#   'too',
#   'easy'],
#  ['maybe',
#   'i',
#   'kind',
#   'woman',
#   'compromise',
#   'right',
#   'away',
#   'i',
#   'still',
#   'can',
#   'not',
#   'accept',
#   'especially',
#   'kind',
#   'film',
#   'that',
#   'promote',
#   'equality',
#   'man',
#   'woman'],
#  ['warmth',
#   'humor',
#   'important',
#   'seemingly',
#   'bland',
#   'structurally',
#   'rigorous',
#   'can',
#   'actually',
#   'dive',
#   'down'],
#  ['end',
#   'not',
#   'very',
#   'good',
#   'surprisingly',
#   'i',
#   'story',
#   'entrepreneurial',
#   'woman',
#   'leader',
#   'elderly',
#   'intern'],
#  ['variant',
#   'princes',
#   'knight',
#   'mode',
#   'unbreakable',
#   'tackines',
#   'not',
#   'big',
#   'problem',
#   'most',
#   'serious',
#   'thing',
#   'narrative',
#   'kernel',
#   'work',
#   'btw',
#   'do',
#   'american',
#   'person',
#   'start',
#   'say',
#   'goodbye',
#   'japanese'],
#  ['three',
#   'half',
#   'star',
#   'first',
#   'half',
#   'warm',
#   'solid',
#   'last',
#   'half',
#   'hour',
#   'so',
#   'confusing'],
#  ['company',
#   'have',
#   'old',
#   'one',
#   'big',
#   'one',
#   'good',
#   'old',
#   'person',
#   'experience',
#   'sedimentation',
#   'year',
#   'know',
#   'say',
#   'do',
#   'instead',
#   'scramble',
#   'seat',
#   'go',
#   'viral',
#   'something',
#   'woman',
#   'deserve',
#   'cheat',
#   'single',
#   'rest',
#   'life',
#   'end',
#   'perfect'],
#  ['marry', 'anne', 'hathaway', 'can', 'cheat'],
#  ['god', 's', 'forgiveness', 'sin', 'too', 'easy'],
#  ['anne',
#   'hathaway',
#   'beautiful',
#   'course',
#   'robert',
#   'handsome',
#   'too',
#   'more',
#   'importantly',
#   'story',
#   'love',
#   'life',
#   'very',
#   'well',
#   'tell',
#   'i'],
#  ['never',
#   'wrong',
#   'do',
#   'right',
#   'thing',
#   'elbow',
#   'recommend',
#   'movie',
#   'too',
#   'much'],
#  ['male',
#   'protagonist',
#   'too',
#   'perfect',
#   'first',
#   'time',
#   'feel',
#   'charm',
#   'elderly',
#   'completely',
#   'match',
#   'word',
#   'decent',
#   'i',
#   'suddenly',
#   'realize',
#   'feminist',
#   'color',
#   'movie',
#   'intention',
#   'very',
#   'good',
#   'end',
#   'little',
#   'hasty',
#   'simple'],
#  ['mature', 's', 'oneqycjtwoha', 'code', 'wrgnine'],
#  ['love', 'old', 'man'],
#  ['compare',
#   'country',
#   's',
#   'fashion',
#   'comedy',
#   'can',
#   'achieve',
#   'complete',
#   'drama',
#   'not',
#   'easy'],
#  ['cinema',
#   'heatherway',
#   'have',
#   'good',
#   'combination',
#   'old',
#   'man',
#   'find',
#   'new',
#   'job',
#   'woman',
#   'workaholic',
#   'save',
#   'marriage',
#   'want',
#   'leave',
#   'old',
#   'man',
#   'have',
#   'new',
#   'relationship',
#   'circle',
#   'still',
#   'have',
#   'dry',
#   'mood',
#   'very',
#   'different',
#   'two',
#   'person',
#   'practice',
#   'original',
#   'life',
#   'really',
#   'good'],
#  ['i',
#   'think',
#   'simplicity',
#   'old',
#   'day',
#   'inject',
#   'vitality',
#   'new',
#   'generation',
#   'end',
#   'still',
#   'suggestion',
#   'elite',
#   'there',
#   'resonance',
#   'still',
#   'disney',
#   'movie',
#   'let',
#   'also',
#   'look',
#   'relaxed',
#   'warmth'],
#  ['two',
#   'thousand',
#   'sixteen',
#   'one',
#   'three',
#   'fifteen',
#   'forty',
#   'one',
#   'thirty',
#   'two'],
#  ['warm',
#   'relaxing',
#   'film',
#   'male',
#   'protagonist',
#   's',
#   'setting',
#   'too',
#   'perfect',
#   'good',
#   'subordinate',
#   'good',
#   'colleague',
#   'good',
#   'friend',
#   'united',
#   'state',
#   'have',
#   'energy',
#   'i',
#   'think',
#   'go',
#   'happen',
#   'male',
#   'female',
#   'protagonist',
#   'think',
#   'too',
#   'much'],
#  ['i', 'can', 'not', 'change', 'fact', 'i', 'love', 'ca', 'anymore'],
#  ['there',
#   'respect',
#   'oneself',
#   'other',
#   'relationship',
#   'other',
#   'noble',
#   'character'],
#  ['cool', 'warm', 'warm', 'principled'],
#  ['good', 'say'],
#  ['old',
#   'man',
#   'so',
#   'cute',
#   'look',
#   'old',
#   'man',
#   'up',
#   'story',
#   'cute',
#   'funny',
#   'listen',
#   'old',
#   'man',
#   'must',
#   'right',
#   'everyone',
#   'have',
#   'have',
#   'ben'],
#  ['mediocre', 'also', 'touch'],
#  ['there',
#   'nothing',
#   'say',
#   'plot',
#   'support',
#   'play',
#   'main',
#   'character',
#   'one',
#   'star'],
#  ['really',
#   'i',
#   'would',
#   'not',
#   'have',
#   'watch',
#   'stupid',
#   'movie',
#   'not',
#   'chris'],
#  ['waste', 'life'],
#  ['kind',
#   'angelic',
#   'thing',
#   'will',
#   'not',
#   'let',
#   'catch',
#   'up',
#   'easily',
#   'i',
#   'can',
#   'only',
#   'try',
#   'achieve',
#   'seven',
#   'hour',
#   'sleep',
#   'day'],
#  ['fun', 'not', 'big', 'deal'],
#  ['i', 'think', 'waste', 'time'],
#  ['i',
#   'can',
#   'so',
#   'relaxed',
#   'age',
#   'seventy',
#   'have',
#   'so',
#   'much',
#   'love',
#   'heart',
#   'live',
#   'so',
#   'clearly',
#   'will',
#   'not',
#   'vain',
#   'want',
#   'robert',
#   'china',
#   'take',
#   'more',
#   'action',
#   'comedy'],
#  ['halfway',
#   'conversation',
#   'woman',
#   'workplace',
#   'nancy',
#   'meyer',
#   'baby',
#   'boom',
#   'suddenly',
#   'come',
#   'mind',
#   'wondering',
#   'movie'],
#  ['i',
#   'watch',
#   'movie',
#   'home',
#   'brother',
#   'i',
#   'have',
#   'hear',
#   'see',
#   'poster',
#   'many',
#   'time',
#   'i',
#   'use',
#   'think',
#   'hostes',
#   'intern',
#   'film',
#   'that',
#   'inspire',
#   'lot',
#   'work',
#   'life'],
#  ['daydream',
#   'movie',
#   'screenwriter',
#   'very',
#   'respectful',
#   'female',
#   'strongman',
#   'old',
#   'school',
#   'gentleman',
#   'two',
#   'far',
#   'reality',
#   'most',
#   'person'],
#  ['emotionally', 'delicate', 'old', 'school', 'style', 'man'],
#  ['i',
#   'want',
#   'play',
#   'three',
#   'star',
#   'old',
#   'man',
#   'so',
#   'cute',
#   'too',
#   'hathaway',
#   'look',
#   'great',
#   'clothe'],
#  ['addition',
#   'title',
#   'movie',
#   'should',
#   'call',
#   'intern',
#   'driver',
#   'back',
#   'head',
#   'can',
#   'guess',
#   'plot'],
#  ['see',
#   'god',
#   'past',
#   'act',
#   'as',
#   'retired',
#   'grandfather',
#   'once',
#   'again',
#   'i',
#   'could',
#   'not',
#   'help',
#   'feel',
#   'hero',
#   'late'],
#  ['god', 's', 'presence'],
#  ['anne',
#   'go',
#   'intern',
#   'prada',
#   'big',
#   'bos',
#   'dress',
#   'really',
#   'well',
#   'probably',
#   'only',
#   'time',
#   'i',
#   'like',
#   'old',
#   'robert',
#   'have',
#   'lot',
#   'virtue',
#   'lot',
#   'love'],
#  ['i',
#   'love',
#   'i',
#   'love',
#   'old',
#   'man',
#   'i',
#   'love',
#   'old',
#   'man',
#   'i',
#   'love',
#   'old',
#   'man',
#   'want',
#   'matter',
#   'clean',
#   'up',
#   'own',
#   'clean',
#   'seventy',
#   'year',
#   'old',
#   'can',
#   'also',
#   'meet',
#   'heart',
#   'object',
#   'only',
#   'can',
#   'do',
#   'have',
#   'only',
#   'meet',
#   'person',
#   'like',
#   'do',
#   'not',
#   'afraid',
#   'fight',
#   'meet',
#   'ye',
#   'most',
#   'impressive',
#   'thing',
#   'movie',
#   'love',
#   'old',
#   'age'],
#  ['not',
#   'so',
#   'boring',
#   'ordinary',
#   'story',
#   'kind',
#   'cast',
#   'box',
#   'product',
#   'look',
#   'worthless'],
#  ['one',
#   'star',
#   'actor',
#   's',
#   'act',
#   'personality',
#   'very',
#   'charming',
#   'personality',
#   'spit',
#   'out',
#   'mes',
#   'center',
#   'gravity',
#   'plot',
#   'anne',
#   'hathaway',
#   'can',
#   'only',
#   'frown',
#   'mouth',
#   'acting',
#   'annoy',
#   'see'],
#  ['robert',
#   'seventy',
#   'year',
#   'old',
#   'man',
#   'so',
#   'cute',
#   'plot',
#   'simple',
#   'climax'],
#  ['old',
#   'strong',
#   'also',
#   'constantly',
#   'learn',
#   'integrate',
#   'new',
#   'social',
#   'atmosphere',
#   'which',
#   'admirable',
#   'two',
#   'storyline',
#   'which',
#   'well',
#   'blend',
#   'properly',
#   'amuse',
#   'will',
#   'suffice',
#   'good',
#   'light',
#   'comedy',
#   'lucky',
#   'rare',
#   'have',
#   'mentor',
#   'also',
#   'teacher',
#   'friend',
#   'guide',
#   'forward',
#   'open',
#   'just',
#   'can',
#   'not',
#   'good'],
#  ['fashion',
#   'magazine',
#   'intern',
#   'many',
#   'year',
#   'ago',
#   'have',
#   'grow',
#   'fashion',
#   'e',
#   'commerce',
#   'ceo',
#   'encouraging'],
#  ['stay', 'awake'],
#  ['do', 'not', 'fool'],
#  ['three', 'half', 'star'],
#  ['can', 'luo', 'so', 'cute'],
#  ['little',
#   'rotten',
#   'tail',
#   'setting',
# ...
#   'year',
#   'third',
#   'season',
#   'desperate',
#   'housewife',
#   'english',
#   'teacher',
#   'like',
#   'insert',
#   'content',
#   'drama',
#   'say',
#   'word',
#   'compromise',
#   'use',
#   'conversation',
#   'gaby',
#   'husband',
#   'deployment'],
#  ['two',
#   'thousand',
#   'fifteen',
#   'movie',
#   'still',
#   'look',
#   'very',
#   'fashionable',
#   'especially',
#   'exquisite',
#   'attitude',
#   'male',
#   'protagonist',
#   'female',
#   'protagonist',
#   'very',
#   'beautiful',
#   'street',
#   'view',
#   'house',
#   'very',
#   'british'],
#  ['insight',
#   'life',
#   'courage',
#   'confront',
#   'life',
#   's',
#   'problem',
#   'not',
#   'blame'],
#  ['husband',
#   'blame',
#   'own',
#   'career',
#   'cheat',
#   'sometimes',
#   'not',
#   'deployment'],
#  ['film',
#   'tell',
#   'story',
#   'juul',
#   'career',
#   'woman',
#   'forty',
#   'year',
#   'old',
#   'businessman',
#   'retire',
#   're',
#   'employ'],
#  ['juul',
#   'start',
#   'own',
#   'company',
#   'year',
#   'husband',
#   'full',
#   'time',
#   'home',
#   'baby',
#   'have',
#   'lovely',
#   'kindergarten',
#   'daughter',
#   'company',
#   'have',
#   'absorb',
#   'more',
#   'two',
#   'hundred',
#   'employee',
#   'past',
#   'year',
#   'operation',
#   'also',
#   'very',
#   'good'],
#  ['company',
#   'decide',
#   'hire',
#   'senior',
#   'intern',
#   'ben',
#   'apply',
#   'successfully',
#   'accept',
#   'i',
#   'have',
#   'assign',
#   'lead',
#   'julie',
#   'julie',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['not', 'just', 'intern', 'friend'],
#  ['film', 'jule', 'tell', 'senior', 'intern', 'ben'],
#  ['work',
#   'love',
#   'movie',
#   'intern',
#   's',
#   'name',
#   'remind',
#   'anne',
#   'hathaway',
#   's',
#   'two',
#   'thousand',
#   'seven',
#   'film',
#   'queen',
#   'prada',
#   'which',
#   'not',
#   'intern',
#   'queen'],
#  ['modern', 'society', 'marriage', 'family', 'deployment'],
#  ['movie',
#   'really',
#   'too',
#   'warm',
#   'anne',
#   'hathaway',
#   'really',
#   'beautiful',
#   'i',
#   'think',
#   'heroine',
#   'jule',
#   'internship',
#   'own',
#   'effort',
#   'little',
#   'powerful',
#   'story',
#   'however',
#   'main',
#   'character',
#   'trainee',
#   'grandfather',
#   'ben',
#   'main',
#   'character',
#   'movie',
#   'woman',
#   'already',
#   'boss',
#   'internet',
#   'company'],
#  ['jule',
#   'everyone',
#   'will',
#   'vulnerable',
#   'hostess',
#   'company',
#   'two',
#   'deployment'],
#  ['intern',
#   'thought',
#   'similar',
#   'female',
#   'devil',
#   'describe',
#   'hathaway',
#   's',
#   'growth',
#   'intern',
#   'workplace',
#   'have',
#   'never',
#   'intend',
#   'repeat',
#   'theme',
#   'pearl',
#   'jade',
#   'look',
#   'i',
#   'want',
#   'see',
#   'series',
#   'i',
#   'stumble',
#   'story',
#   'hathaway',
#   'grow',
#   'up',
#   'elderly',
#   'intern',
#   'bos',
#   'i',
#   'late',
#   'i',
#   'really',
#   'glad',
#   'meet',
#   'such',
#   'warm',
#   'positive',
#   'movie',
#   'which',
#   'heal',
#   'long',
#   'night',
#   'really',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['one',
#   'day',
#   'listen',
#   'fan',
#   'deng',
#   'explain',
#   'hundred',
#   'year',
#   'life',
#   'suddenly',
#   'middle',
#   'age',
#   'even',
#   'point',
#   'old',
#   'age',
#   'need',
#   're',
#   'learn',
#   're',
#   'find',
#   'job'],
#  ['movie',
#   'have',
#   'different',
#   'vision',
#   'elderly',
#   'retire',
#   'old',
#   'widow',
#   'first',
#   'degree',
#   'deployment'],
#  ['i',
#   'have',
#   'hole',
#   'life',
#   'i',
#   'have',
#   'fill',
#   'as',
#   'soon',
#   'possible',
#   'explore',
#   'plight',
#   'career',
#   'woman',
#   'corporate',
#   'operation',
#   'family',
#   'busines',
#   'society',
#   'gender',
#   'discrimination',
#   'busines',
#   'disappearance',
#   'male',
#   'office',
#   'worker',
#   'rise',
#   'female',
#   'office',
#   'worker',
#   'elderly',
#   'person'],
#  ['second',
#   'spring',
#   'career',
#   'second',
#   'spring',
#   'body',
#   'new',
#   'office',
#   'old',
#   'office',
#   'home',
#   'decentralize',
#   'calm',
#   'temperament',
#   'assign',
#   'task',
#   'steal',
#   'computer',
#   'delete',
#   'emails',
#   'home',
#   'have',
#   'old',
#   'one',
#   'such',
#   'one',
#   'deployment'],
#  ['optimistic',
#   'positive',
#   'rest',
#   'life',
#   'never',
#   'give',
#   'up',
#   'desire',
#   'knowledge'],
#  ['seventy',
#   'can',
#   'passionate',
#   'life',
#   'twenty',
#   'day',
#   'get',
#   'up',
#   'dress',
#   'up',
#   'white',
#   'tipped',
#   'book',
#   'yoga',
#   'go',
#   'bed',
#   'time',
#   'night',
#   'seventy',
#   'never',
#   'give',
#   'up',
#   'trend',
#   'attitude',
#   'life',
#   'remain',
#   'unchanged',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['movie',
#   'beautiful',
#   'entrepreneurial',
#   'woman',
#   'career',
#   'life',
#   'crisi',
#   'just',
#   'time',
#   'appear',
#   'mature',
#   'old',
#   'friend',
#   'maybe',
#   'can',
#   'not',
#   'directly',
#   'help',
#   'career',
#   'life',
#   'spiritual',
#   'support',
#   'infinite',
#   'i',
#   'envy',
#   'kind',
#   'person',
#   'all',
#   'image',
#   'elderly',
#   'friend',
#   'life',
#   'mentor',
#   'not',
#   'everyone',
#   'have',
#   'chance',
#   'meet',
#   'deployment'],
#  ['will',
#   'gain',
#   'follow',
#   'knowledge',
#   'relate',
#   'workplace',
#   'one',
#   'first',
#   'day',
#   'work',
#   'sure',
#   'not',
#   'late',
#   'set',
#   'alarm',
#   'clock',
#   'set',
#   'two',
#   'too',
#   'nervous',
#   'keep',
#   'friendly',
#   'comfortable',
#   'distance',
#   'colleague',
#   'do',
#   'not',
#   'have',
#   'come',
#   'up',
#   'please',
#   'other',
#   'have',
#   'time',
#   'help',
#   'colleague',
#   'observe',
#   'do',
#   'boss',
#   'want',
#   'do',
#   'see',
#   'result',
#   'watch',
#   'movie',
#   'i',
#   'want',
#   'buy',
#   'handkerchief',
#   'deployment'],
#  ['turn',
#   'out',
#   'actor',
#   'hold',
#   'up',
#   'most',
#   'play',
#   'not',
#   'legendary',
#   'robert',
#   'do',
#   'just'],
#  ['film',
#   'set',
#   'workplace',
#   'explore',
#   'theme',
#   'winner',
#   'life',
#   'one',
#   'elderly',
#   'person',
#   'return',
#   'workplace',
#   'one',
#   'strong',
#   'woman',
#   'have',
#   'make',
#   'name',
#   'elderly',
#   'do',
#   'good',
#   'job',
#   'basic',
#   'job',
#   'bring',
#   'warmth',
#   'positive',
#   'energy',
#   'person',
#   'strong',
#   'woman',
#   'entangled',
#   'family',
#   'career',
#   'deployment'],
#  ['movie',
#   'can',
#   'really',
#   'support',
#   'most',
#   'drama',
#   'old',
#   'american',
#   'actor',
#   'robert',
#   'have',
#   'do',
#   'smile',
#   'move',
#   'absolutely',
#   'elegant',
#   'elegant',
#   'screen',
#   'can',
#   'feel',
#   'elegance',
#   'nobility',
#   'hard',
#   'believe',
#   'seventy',
#   'two',
#   'year',
#   'old',
#   'man',
#   'can',
#   'so',
#   'attractive',
#   'seeing'],
#  ['movie', 'belong', 'american', 'soft', 'comedy', 'seem', 'deployment'],
#  ['film', 'review', 'learn', 'english', 'only'],
#  ['atypical', 'story', 'intern', 'best', 'friend'],
#  ['course',
#   'not',
#   'inspirational',
#   'movie',
#   'also',
#   'pour',
#   'few',
#   'bowl',
#   'chicken',
#   'soup',
#   'all',
#   'rookie',
#   'seventy',
#   'year',
#   'old',
#   'senior',
#   'veteran',
#   'actor',
#   'robert',
#   'oscar',
#   'winner',
#   'scorsese',
#   's',
#   'royal',
#   'male',
#   'protagonist',
#   'man',
#   'play',
#   'godfather',
#   'deployment'],
#  ['life',
#   'there',
#   'lot',
#   'helplessness',
#   'confusion',
#   'day',
#   'desperately',
#   'need',
#   'experienced',
#   'ferryman',
#   'help',
#   'cross',
#   'river',
#   'jule',
#   'clear',
#   'authentic',
#   'character',
#   'dare',
#   'try',
#   'inner',
#   'thought',
#   'life',
#   'can',
#   'not',
#   'always',
#   'go',
#   'smoothly',
#   'jule',
#   'encounter',
#   'problem',
#   'ben',
#   'kind',
#   'elder',
#   'always',
#   'give',
#   'spiritual',
#   'encouragement',
#   'advice',
#   'not',
#   'much',
#   'say',
#   'as',
#   'long',
#   'ben',
#   'here',
#   'jule',
#   'will',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['i',
#   'watch',
#   'movie',
#   'intern',
#   'yesterday',
#   'i',
#   'use',
#   'rely',
#   'age',
#   'decide',
#   'person',
#   'old',
#   'not',
#   'watch',
#   'intern',
#   'i',
#   'find',
#   'never',
#   'age',
#   'spirit',
#   'that',
#   'determine',
#   'person',
#   'old',
#   'not'],
#  ['person',
#   'twentys',
#   'live',
#   'old',
#   'man',
#   'seventys',
#   'teenager',
#   'let',
#   'take',
#   'look',
#   'movie',
#   'together'],
#  ['one', 'none', 'deployment'],
#  ['movie',
#   'i',
#   'run',
#   'tell',
#   'friend',
#   'i',
#   'have',
#   'see',
#   'good',
#   'movie',
#   'really',
#   'good',
#   'piece',
#   'write',
#   'maybe',
#   'there',
#   'have',
#   'reliable',
#   'person',
#   'time'],
#  ['instead',
#   'want',
#   'have',
#   'someone',
#   'i',
#   'want',
#   'person',
#   'reliable',
#   'calm',
#   'sincere',
#   'always',
#   'thoughtful',
#   'rigour',
#   'good',
#   'habit',
#   'previous',
#   'generation',
#   'constantly',
#   'make',
#   'progres',
#   'not',
#   'touch',
#   'time'],
#  ['deployment'],
#  ['perhaps',
#   'i',
#   'just',
#   'finish',
#   'internship',
#   'i',
#   'choose',
#   'movie',
#   'beginning',
#   'film',
#   'fascinate',
#   'retire',
#   'seventy',
#   'year',
#   'old',
#   'man',
#   'decide',
#   'return',
#   'work',
#   'because',
#   'have',
#   'sense',
#   'belonging'],
#  ['get',
#   'life',
#   'go',
#   'stand',
#   'up',
#   'go',
#   'go',
#   'anywhere',
#   'so',
#   'come',
#   'new',
#   'fashion',
#   'clothing',
#   'company',
#   'become',
#   'elderly',
#   'intern',
#   'set',
#   'here',
#   'deployment'],
#  ['frankly',
#   'intern',
#   'not',
#   'i',
#   'expect',
#   'week',
#   'fortunately',
#   'recommendation',
#   'page',
#   'time',
#   'fortunately',
#   'i',
#   'choose',
#   'little',
#   'hesitation',
#   'choose',
#   'entirely',
#   'anne',
#   'hathaway',
#   'sure',
#   'enough',
#   'goddes',
#   'produce',
#   'must',
#   'fine',
#   'product'],
#  ['queen',
#   'prada',
#   's',
#   'intern',
#   'have',
#   'promote',
#   'boss',
#   'annie',
#   'intern',
#   'have',
#   'able',
#   'adapt',
#   'fast',
#   'pace',
#   'take',
#   'initiative',
#   'deployment'],
#  ['first',
#   'i',
#   'run',
#   'hathaway',
#   'i',
#   'saw',
#   'topic',
#   'intern',
#   'i',
#   'think',
#   'i',
#   'should',
#   'tell',
#   'story',
#   'college',
#   'graduate',
#   'enter',
#   'workplace',
#   'i',
#   'think',
#   'i',
#   'would',
#   'soon',
#   'become',
#   'social',
#   'person',
#   'i',
#   'plan',
#   'take',
#   'look',
#   'such',
#   'expectation',
#   'there',
#   'will',
#   'more',
#   'excitement',
#   'look'],
#  ['ben',
#   's',
#   'performance',
#   'should',
#   'continue',
#   'knight',
#   'culture',
#   'also',
#   'see',
#   'artisan',
#   'spirit',
#   'i',
#   'get',
#   'old',
#   'can',
#   'live',
#   'ben',
#   'deployment'],
#  ['one'],
#  ['i',
#   'go',
#   'anne',
#   'hathaway',
#   's',
#   'best',
#   'movie',
#   'relax',
#   'workplace',
#   'comedy',
#   'i',
#   'disappoint',
#   'true',
#   'anne',
#   'hathaway',
#   'light',
#   'hearted',
#   'work',
#   'comedy',
#   'undeniable',
#   'standard',
#   'inspirational',
#   'film',
#   'up',
#   'down'],
#  ['two'],
#  ['whole',
#   'movie',
#   'really',
#   'do',
#   'not',
#   'have',
#   'up',
#   'downs',
#   'movie',
#   'do',
#   'raise',
#   'lot',
#   'problem',
#   'workplace',
#   'deployment'],
#  ['begin',
#   'movie',
#   'i',
#   'saw',
#   'old',
#   'man',
#   'high',
#   'emotional',
#   'intelligence',
#   'intelligence',
#   'always',
#   'watch',
#   'seventy',
#   'year',
#   'age',
#   'circle',
#   'fate',
#   'let',
#   'return',
#   'factory',
#   'have',
#   'spend',
#   'more',
#   'forty',
#   'year',
#   'familiarize',
#   'face',
#   'strange',
#   'new',
#   'world',
#   'start',
#   'work',
#   'again',
#   'start',
#   'date',
#   'again',
#   'set',
#   'movie',
#   'still',
#   'intriguing',
#   'grandpa',
#   'face',
#   'new',
#   'social',
#   'new',
#   'job',
#   'type',
#   'intern',
#   'deployment'],
#  ['watch',
#   'movie',
#   'i',
#   'fascinate',
#   'old',
#   'gentleman',
#   'have',
#   'slightly',
#   'antique',
#   'style',
#   'american',
#   'version',
#   'word',
#   'i',
#   'glad',
#   'emotional',
#   'line',
#   'heroine',
#   'not',
#   'vulgar',
#   'love',
#   'not',
#   'ambiguous',
#   'more',
#   'father',
#   's',
#   'communication',
#   'daughter',
#   'concern',
#   'friend'],
#  ['then',
#   'come',
#   'gentleman',
#   's',
#   'delightful',
#   'reason',
#   'logic',
#   'planning',
#   'courage',
#   'so',
#   'deployment'],
#  ['blake',
#   'snyder',
#   'screenplay',
#   'beatwatch',
#   'title',
#   'intern',
#   'genre',
#   'fellowship',
#   'date',
#   'two',
#   'thousand',
#   'twenty',
#   'one',
#   'pfive',
#   'male',
#   'protagonist',
#   'see',
#   'list',
#   'intern',
#   'say',
#   'old',
#   'lady',
#   'i',
#   'can',
#   'not',
#   'understand',
#   'say',
#   'not',
#   'young',
#   'anymore',
#   'pave',
#   'way',
#   'pone',
#   'ten',
#   'exhibition',
#   'deployment'],
#  ['retired',
#   'vice',
#   'president',
#   'start',
#   'up',
#   'internet',
#   'company',
#   'do',
#   'intern',
#   'female',
#   'boss',
#   'help',
#   'young',
#   'person',
#   'find',
#   'direction',
#   'work',
#   'life',
#   'find',
#   'own',
#   'plot',
#   'not',
#   'too',
#   'boring',
#   'acting',
#   'still',
#   'unremarkable',
#   'good',
#   'look',
#   'princess',
#   'diary',
#   'woman',
#   'prada',
#   'look',
#   'deployment'],
#  ['clothe', 'wear', 'word', 'write', 'word', 'say', 'food', 'eat'],
#  ['big',
#   'feel',
#   'watch',
#   'movie',
#   'ben',
#   'always',
#   'clean',
#   'wear',
#   'suit',
#   'behavior',
#   'also',
#   'subtly',
#   'affect',
#   'everyone',
#   'such',
#   'fat',
#   'little',
#   'man',
#   'house',
#   'start',
#   'dres',
#   'formal',
#   'professional'],
#  ['one'],
#  ['person', 'wear', 'do', 'deployment'],
#  ['successful',
#   'senior',
#   'workplace',
#   'have',
#   'always',
#   'serious',
#   'sincere',
#   'humble',
#   'active',
#   'friendly',
#   'principled',
#   'never',
#   'cross',
#   'line',
#   'i',
#   'think',
#   'kind',
#   'cultivation',
#   'wisdom',
#   'which',
#   'worth',
#   'learn',
#   'workplace',
#   'help',
#   'integrate',
#   'new',
#   'environment',
#   'get',
#   'respect',
#   'other',
#   'faster',
#   'deployment'],
#  ['one'],
#  ['career',
#   'family',
#   'elder',
#   'friends',
#   'lover',
#   'child',
#   'daily',
#   'necessity',
#   'everyday',
#   'life',
#   'appear',
#   'time',
#   'only',
#   'have',
#   'make',
#   'choice',
#   'do',
#   'realize',
#   'so',
#   'important',
#   'sometime',
#   'choose',
#   'forgive',
#   'face',
#   'betrayal',
#   'life',
#   'may',
#   'require',
#   'soft',
#   'there',
#   'surprise',
#   'everywhere',
#   'life',
#   'as',
#   'long',
#   'willing',
#   'go',
#   'out',
#   'experience',
#   'time',
#   'deployment'],
#  ['work',
#   'i',
#   'watch',
#   'movie',
#   'begin',
#   'movie',
#   'old',
#   'man',
#   's',
#   'delicate',
#   'elegant',
#   'clothe',
#   'make',
#   'feel',
#   'comfortable',
#   'such',
#   'spring',
#   'breeze',
#   'then',
#   'later',
#   'old',
#   'man',
#   'always',
#   'elegant',
#   'always',
#   'enthusiastic',
#   'always',
#   'positive',
#   'warm',
#   'wise',
#   'always',
#   'talk',
#   'forever',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['demonstrate', 'that', 'competence', 'workplace', 'can', 'transfer'],
#  ['last', 'job', 'take', 'position', 'vice', 'president'],
#  ['can',
#   'do',
#   'vice',
#   'presidential',
#   'level',
#   'back',
#   'intern',
#   'performance',
#   'workplace',
#   'can',
#   'see',
#   'characteristic',
#   'very',
#   'worth',
#   'learn',
#   'new',
#   'even',
#   'veteran',
#   'workplace',
#   'willing',
#   'try',
#   'new',
#   'thing',
#   'embrace',
#   'challenge',
#   'seventy',
#   'year',
#   'old',
#   'still',
#   'willing',
#   'learn',
#   'internet',
#   'deployment'],
#  ['movie',
#   'have',
#   'too',
#   'much',
#   'conversational',
#   'art',
#   'record',
#   'don',
#   's',
#   'life',
#   'state',
#   'should',
#   'most',
#   'person',
#   'aspire'],
#  ['don',
#   'first',
#   'ask',
#   'assistant',
#   'pay',
#   'attention',
#   'see',
#   'boss',
#   'driver',
#   'drink',
#   'still',
#   'give',
#   'two',
#   'choice',
#   'deployment'],
#  ['movie',
#   'that',
#   'make',
#   'very',
#   'comfortable',
#   'watch',
#   'particular',
#   'most',
#   'first',
#   'half',
#   'relax',
#   'small',
#   'humor',
#   'let',
#   'almost',
#   'whole',
#   'mouth',
#   'whole',
#   'time',
#   'two',
#   'main',
#   'character',
#   'act',
#   'natural',
#   'sincere',
#   'not',
#   'flamboyant',
#   'true',
#   'feeling',
#   'easy',
#   'get',
#   'play',
#   'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['american',
#   'light',
#   'comedy',
#   'film',
#   'intern',
#   'have',
#   'variety',
#   'routine',
#   'perfect',
#   'plot',
#   'direction',
#   'familiar',
#   'comedy',
#   'plot',
#   'well',
#   'know',
#   'anne',
#   'hathaway',
#   'anyone',
#   'see',
#   'know',
#   'movie',
#   'perfect',
#   'story',
#   'that',
#   'inspire',
#   'just',
#   'one',
#   'idea',
#   'many',
#   'film',
#   'few',
#   'film',
#   'have',
#   'have',
#   'such',
#   'perfect',
#   'succes'],
#  ['time', 'show', 'many', 'person', 'not', 'deployment'],
#  ['movie', 'may', 'have', 'spoiler'],
#  ['ben',
#   'nearly',
#   'seventy',
#   'join',
#   'internet',
#   'company',
#   'intern',
#   'workplace',
#   'story',
#   'that',
#   'take',
#   'place',
#   'founder',
#   'jule',
#   'ben',
#   'admirable',
#   'mature',
#   'gentleman',
#   'attitude',
#   'spirit',
#   'life',
#   'have',
#   'inspire',
#   'lot',
#   'probably',
#   'i',
#   'want',
#   'balance',
#   'influential',
#   'person'],
#  ...]

# %%
# remove empty list
modified_sentences = [sentence for sentence in modified_sentences if sentence]

# %%
lengths = [len(sentence) for sentence in modified_sentences]

# sentence lenths discriptive analysis
median = np.median(lengths)
mean = np.mean(lengths)
percentile_75 = np.percentile(lengths, 75)
percentile_90 = np.percentile(lengths, 90)
percentile_95 = np.percentile(lengths, 95)

print ('median: ', median, 
       'mean: ', mean, 
       'per_75: ', percentile_75, 
       'per_90: ', percentile_90, 
       'per_95: ', percentile_95)
# Out:
# median:  12.0 mean:  16.64184978681535 per_75:  26.0 per_90:  39.0 per_95:  46.0

# %%
#wordcloud
from wordcloud import WordCloud
text_data_japan = " ".join([" ".join(sentence) for sentence in modified_sentences])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data_japan)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from collections import Counter
all_words = [word for sentence in modified_sentences for word in sentence]
word_freq= Counter(all_words)
print(word_freq)
# Out:
# Counter({'i': 1568, 'movie': 1177, 'have': 1165, 'deployment': 938, 'not': 927, 'old': 780, 'do': 612, 'life': 579, 's': 569, 'intern': 531, 'ben': 489, 'year': 461, 'work': 443, 'person': 425, 'may': 394, 'can': 386, 'man': 384, 'spoiler': 351, 'film': 337, 'good': 309, 'see': 303, 'think': 296, 'very': 293, 'hathaway': 289, 'time': 288, 'woman': 287, 'seventy': 272, 'watch': 271, 'love': 269, 'one': 264, 'anne': 248, 'company': 243, 'there': 241, 'so': 234, 'thing': 225, 'young': 219, 'two': 214, 'really': 214, 'go': 211, 'first': 205, 'will': 202, 'say': 201, 'also': 194, 'jule': 191, 'new': 191, 'want': 185, 'still': 177, 'more': 172, 'story': 172, 'warm': 171, 'experience': 171, 'just': 169, 'look': 164, 'always': 161, 'feel': 160, 'make': 155, 'too': 151, 'up': 150, 'age': 143, 'workplace': 136, 'robert': 136, 'family': 134, 'find': 133, 'that': 131, 'play': 130, 'get': 129, 'female': 128, 'saw': 124, 'other': 123, 'most': 121, 'day': 121, 'retirement': 121, 'know': 118, 'only': 116, 'many': 115, 'such': 114, 'even': 112, 'right': 112, 'lot': 111, 'give': 108, 'wife': 107, 'retire': 107, 'begin': 105, 'kind': 104, 'career': 103, 'end': 102, 'become': 102, 'gentleman': 100, 'little': 99, 'which': 99, 'live': 98, 'husband': 95, 'character': 95, 'learn': 95, 'protagonist': 95, 'long': 92, 'need': 92, 'elderly': 92, 'never': 89, 'start': 89, 'beautiful': 87, 'tell': 86, 'heart': 86, 'help': 85, 'high': 83, 'take': 82, 'own': 79, 'three': 79, 'prada': 77, 'friend': 77, 'well': 76, 'male': 76, 'come': 76, 'much': 75, 'strong': 75, 'way': 75, 'would': 75, 'plot': 73, 'world': 72, 'comedy': 72, 'full': 70, 'job': 69, 'forty': 69, 'big': 68, 'then': 67, 'let': 67, 'fashion': 66, 'like': 66, 'out': 66, 'everyone': 66, 'use': 65, 'could': 65, 'great': 64, 'should': 64, 'word': 62, 'whole': 62, 'senior': 62, 'try': 61, 'thousand': 61, 'internship': 60, 'home': 60, 'point': 59, 'talk': 59, 'understand': 59, 'perfect': 58, 'face': 58, 'seem': 58, 'successful': 57, 'twenty': 57, 'small': 57, 'again': 57, 'star': 57, 'bos': 57, 'meet': 57, 'boss': 56, 'child': 56, 'queen': 55, 'drama': 55, 'grandfather': 55, 'hard': 54, 'five': 54, 'change': 54, 'main': 54, 'return': 53, 'emotional': 52, 'wear': 52, 'colleague': 52, 'internet': 52, 'president': 52, 'show': 51, 'problem': 51, 'role': 51, 'back': 50, 'open': 49, 'comfortable': 48, 'name': 48, 'choose': 48, 'now': 47, 'same': 47, 'all': 47, 'ceo': 47, 'self': 46, 'feeling': 46, 'grow': 46, 'intelligence': 45, 'as': 45, 'idea': 45, 'cheat': 45, 'fact': 45, 'office': 45, 'different': 45, 'american': 44, 'half': 44, 'second': 44, 'sense': 44, 'set': 44, 'eye': 44, 'night': 44, 'theme': 44, 'wrong': 44, 'busines': 44, 'chicken': 43, 'important': 43, 'everything': 43, 'turn': 43, 'director': 42, 'down': 42, 'something': 42, 'assistant': 42, 'write': 42, 'last': 42, 'attitude': 42, 'state': 41, 'girl': 41, 'society': 41, 'must': 41, 'call': 41, 'relationship': 40, 'ten': 40, 'few': 40, 'poster': 40, 'willing': 40, 'actually': 39, 'especially': 39, 'school': 39, 'light': 39, 'hundred': 39, 'busy': 39, 'review': 39, 'book': 39, 'marriage': 38, 'move': 38, 'four': 38, 'leave': 38, 'once': 38, 'later': 38, 'keep': 38, 'expand': 38, 'line': 37, 'easy': 37, 'vice': 37, 'place': 36, 'balance': 36, 'actor': 36, 'heroine': 36, 'alone': 36, 'enough': 35, 'positive': 35, 'happy': 35, 'bring': 35, 'value': 34, 'felt': 34, 'almost': 34, 'cute': 34, 'lose': 34, 'die': 34, 'finally': 34, 'founder': 34, 'style': 33, 'interesting': 33, 'calm': 33, 'house': 33, 'suit': 33, 'death': 33, 'enter': 33, 'happen': 33, 'wise': 33, 'detail': 32, 'read': 32, 'order': 32, 'touch': 32, 'charm': 32, 'reason': 32, 'matter': 31, 'e': 31, 'mind': 31, 'completely': 30, 'ago': 30, 'worth': 30, 'nine': 30, 'maybe': 30, 'wisdom': 30, 'freud': 30, 'bad': 29, 'soup': 29, 'difficult': 29, 'part': 29, 'best': 29, 'hour': 29, 'nothing': 29, 'probably': 29, 'remember': 29, 'hand': 29, 'commerce': 28, 'grandpa': 28, 'employee': 28, 'today ...

# %%
df_word_freq = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency'])
df_word_freq.sort_values(by='Frequency', ascending=False, inplace=True)
df_word_freq
# Out:
#                 Word  Frequency
# 30                 i       1568
# 6              movie       1177
# 7               have       1165
# 1407      deployment        938
# 88               not        927
# ...              ...        ...
# 2691         utopian          1
# 2690  inauthenticity          1
# 2689          overly          1
# 2688      thoroughly          1
# 4464            hell          1
#
# [4465 rows x 2 columns]

# %%
! pip install openpyxl
df_word_freq.to_excel('word_freq_china.xlsx')
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\seowoo kim\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\seowoo kim\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# # word2Vec

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences=modified_sentences, vector_size=100, window=40, min_count=2, workers=1)

# %%
model.save("word2vec_china.model")

# %%
word_vectors = model.wv

# %%
similar_words = word_vectors.most_similar('intern')
print(similar_words)
# Out:
# [('story', 0.999578595161438), ('company', 0.9995533227920532), ('internet', 0.9995458126068115), ('jule', 0.9995185136795044), ('ben', 0.9995002746582031), ('new', 0.999448299407959), ('s', 0.9994390606880188), ('president', 0.9993955492973328), ('retire', 0.9993798732757568), ('man', 0.9993698596954346)]

# %%
similar_words_100 = word_vectors.most_similar('age', topn=100)
print("Top 100 similar words:", similar_words_100)
# Out:
# Top 100 similar words: [('gentleman', 0.9998363852500916), ('most', 0.9997977018356323), ('learn', 0.9997840523719788), ('begin', 0.9997739791870117), ('play', 0.9997727870941162), ('use', 0.999756932258606), ('help', 0.9997566342353821), ('problem', 0.9997540712356567), ('also', 0.9997491836547852), ('alone', 0.9997488856315613), ('person', 0.9997395277023315), ('other', 0.9997338056564331), ('busy', 0.9997310638427734), ('day', 0.9997265338897705), ('fashion', 0.9997220039367676), ('choose', 0.9997186064720154), ('go', 0.9997185468673706), ('internship', 0.9997182488441467), ('give', 0.9997135400772095), ('job', 0.9997069239616394), ('attitude', 0.9997029304504395), ('twenty', 0.9997023344039917), ('there', 0.9996997117996216), ('retirement', 0.9996967315673828), ('experience', 0.9996958374977112), ('become', 0.9996944665908813), ('let', 0.9996920228004456), ('own', 0.9996898770332336), ('come', 0.9996897578239441), ('busines', 0.9996895790100098), ('start', 0.9996885061264038), ('know', 0.9996809363365173), ('society', 0.9996772408485413), ('face', 0.9996728301048279), ('just', 0.9996725916862488), ('colleague', 0.9996708035469055), ('set', 0.9996699690818787), ('ceo', 0.999668300151825), ('suit', 0.9996662139892578), ('boss', 0.9996597766876221), ('successful', 0.999657928943634), ('talk', 0.9996473789215088), ('will', 0.9996444582939148), ('world', 0.9996365308761597), ('bos', 0.9996322989463806), ('still', 0.9996299743652344), ('workplace', 0.9996293783187866), ('clothing', 0.9996274709701538), ('intelligence', 0.9996253252029419), ('once', 0.999618649482727), ('even', 0.9996181726455688), ('change', 0.9996142387390137), ('understand', 0.9996073842048645), ('one', 0.9995970129966736), ('career', 0.9995967745780945), ('home', 0.9995923042297363), ('handkerchief', 0.9995893239974976), ('then', 0.9995886087417603), ('show', 0.9995824098587036), ('back', 0.9995818734169006), ('senior', 0.9995743632316589), ('many', 0.9995712041854858), ('family', 0.9995696544647217), ('robert', 0.999568521976471), ('little', 0.9995630383491516), ('protagonist', 0.9995583295822144), ('male', 0.9995572566986084), ('need', 0.9995568990707397), ('mother', 0.999548077583313), ('too', 0.9995437860488892), ('value', 0.9995389580726624), ('make', 0.9995366930961609), ('character', 0.9995335936546326), ('find', 0.9995284080505371), ('order', 0.999523937702179), ('like', 0.9995177388191223), ('happen', 0.9995109438896179), ('sense', 0.9995105266571045), ('easy', 0.9995080828666687), ('re', 0.9995055198669434), ('elderly', 0.9995037317276001), ('director', 0.9995031952857971), ('deployment', 0.9995009899139404), ('more', 0.9994981288909912), ('marriage', 0.9994961619377136), ('call', 0.9994940161705017), ('end', 0.9994853734970093), ('everything', 0.9994828104972839), ('school', 0.9994817972183228), ('accept', 0.9994776844978333), ('female', 0.9994758367538452), ('up', 0.9994753003120422), ('respect', 0.9994723796844482), ('struggle', 0.9994715452194214), ('film', 0.999468982219696), ('leave', 0.9994665384292603), ('say', 0.999460756778717), ('take', 0.9994569420814514), ('mind', 0.9994555115699768), ('hand', 0.999454140663147)]
