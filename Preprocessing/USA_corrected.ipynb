# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from gensim.models import word2vec

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# c:\Users\seowoo kim\Desktop\노나없

# %%
# Import usa data
data_j = pd.read_csv("./review_data_american_only_sentences.csv")
data_j.head()
# Out:
#                                   SeparatedSentences
# 0                            Wasn't what I expected.
# 1                                 Really enjoyed it.
# 2      Including the hope for redemption at the end.
# 3  A true feel good movie that I wish I saw in th...
# 4  Anne Hathaway and Robert DeNiro have great che...

# %% [markdown]
# # Preprocessing Strategy
#
# 1. Expand contractions : pycontractions
# 2. lowercase
# 3. change numbers to words : inflect
# 4. Remove Punctuations : '!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~'
# 5. Remove remained emoji, japanese, chinese, korean words
# 6. PoS_tagging: from nltk import pos_tag
# 7. If needed, remove PRP, TO, DT, etc.
# 8. Stemming: PorterStemmer
# 9. Find out average sentence length
# 10. Wordcloud

# %%
# Pycontractions doesn't work due to dependency issue. I just modulized it by myself.

from contractions import expand_contractions

contracted_list = []
Sentences = data_j['SeparatedSentences'].copy()

for sentence in Sentences:
    expanded_sentence = expand_contractions(sentence)
    contracted_list.append(expanded_sentence)

# %%
contracted_list[:5]
# Out:
# ['was not what I expected.',
#  'Really enjoyed it.',
#  'Including the hope for redemption at the end.',
#  'A true feel good movie that I wish I saw in theaters.',
#  'Anne Hathaway and Robert DeNiro have great chemistry and the movie tells a great story of 2 people generations apart growing closer and learning from each other.']

# %%
# Transform all sentences into lower case! easy!

contracted_list = [text.lower() for text in contracted_list]

# %%
contracted_list[:5]
# Out:
# ['was not what i expected.',
#  'really enjoyed it.',
#  'including the hope for redemption at the end.',
#  'a true feel good movie that i wish i saw in theaters.',
#  'anne hathaway and robert deniro have great chemistry and the movie tells a great story of 2 people generations apart growing closer and learning from each other.']

# %%
# Change numbers into words
import inflect
p = inflect.engine()

def convert_number(text):
    def replace_number(match):
        number = match.group()
        return p.number_to_words(number)
    
    converted_text = re.sub(r'\d+', replace_number, text)
    return converted_text

inflected_list = []
inflected_list = [convert_number(text) for text in contracted_list]

# %%
# Remove punctuations
rm_punctionations = inflected_list.copy()

def rm_punct(text):
    cleaned_text = re.sub(r'[!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]', ' ', text)
    return cleaned_text

rm_punctionations = [rm_punct(text) for text in rm_punctionations]

# %%
rm_punctionations
# Out:
# ['was not what i expected ',
#  'really enjoyed it ',
#  'including the hope for redemption at the end ',
#  'a true feel good movie that i wish i saw in theaters ',
#  'anne hathaway and robert deniro have great chemistry and the movie tells a great story of two people generations apart growing closer and learning from each other ',
#  'there is strong character development and a solid cast all around ',
#  'i recommend it to anyone ',
#  'all the pieces seem to be there except a truly appropriate third act ',
#  'the intern  has chemistry rich lead performances and a tenured auteur behind the camera ',
#  'brilliant movie ',
#  'so warm  so satisfying and so moved ',
#  'recommend',
#  'these two bonified great actors somehow have a great chemistry that truly makes this movie worth watching ',
#  'it rushes the story along but that does not take away from the heartwarming affect it was going for ',
#  'the movie was very good ',
#  'i cannot believe what other critics are rating and saying about this movie ',
#  'two legendary actors with a good script ',
#  'good film overall  loved robert de niro  who fit the role really well ',
#  'the story was pretty standard stuff however fun to watch and something to take away ',
#  'very entertaining movie for when you just want to have a good time ',
#  'i really enjoyed a lot of this ',
#  'thought de niro really nailed his part  he was at the top of his game ',
#  'well worth a watch  although i wished a couple of the endings went a different way ',
#  'a gentle film with low stakes and surface level lessons values ',
#  'beautifully shot and well acted  but the story lacks depth ',
#  'de niro and hathaway s mad acting skills manage to raise an otherwise boring film to very nearly interesting ',
#  'odd  that in all of hathaway s meetings  she never one considered hiring a female ceo ',
#  'sadly  the successful entrepreneur will continue burning themself out because they cannot let go and struggle to delegate unless a flawless person who always says the right things magically shows up ',
#  'o filme até que é bom  bastante divertido ',
#  'mas o final não fez nenhum sentido  filme bem sessão da tarde mesmo ',
#  'this movie was a good one to just throw on and enjoy  it is usually not my type of movie but i quite enjoyed the duo onscreen and the lessons you learn along the way ',
#  'if you are looking for a feel good film  this is it ',
#  'a fantastic cast and a compelling story ',
#  'we all know what it is to spread ourselves too thin and feel like an outsider ',
#  'learn something about work life balance and how to fit in by being yourself ',
#  'i came across this movie because i was looking for a wholesome movie that would make me regain some sort of faith in humanity ',
#  'for the most part  this movie delivered ',
#  'i am not sure i agree with her decision in the end  but that was her decision i guess ',
#  'idk  the first half was very wholesome   but it got messy towards the end ',
#  'but i guess that is life   messy ',
#  'this is a terrible movie with an awful message ',
#  'the only pro i give is the feminism behind showing that women can be on top but it is done in the most disgraceful way ',
#  'hathaway s character is out is control  clearly not able to handle a growing company  completely oblivious of tech  like not using email recall   and sinking it even more out of her power trip of not having a boss ',
#  'a lot of shaming the new generation of men and glorifying the boomers ',
#  'extremely capitalist and pro destroying everything around you for your job ',
#  'wtf with going to bars with employees  which you do not know their name because you are too  powerful   instead of going home and spend time with your family ',
#  'the idea of feminism is to become better collectively and not for women to start acting like the stereotypical men ',
#  'also  sexual harrassment is out there like a joke   really ',
#  'is it ok because it is done to a guy ',
#  'special effects  one zero sound effects  one zero acting  one zero story  two zero',
#  'just a classic  pulls at all the good heartstrings  the best duo ',
#  'it is so well written  the characters are all adorable ',
#  'it is funny and sad  suspenseful and action packed ',
#  'what could be better ',
#  'like it ',
#  'i bit long but good story',
#  'why whyyy is this movie not rated above ninety  ',
#  ' ',
#  'it is one it is kind ',
#  'so fresh  warm  cozy and positive ',
#  'it somehow teaches way of living ',
#  'i always go hopeful  happy  and content after watching this movie ',
#  'a definitely must watch  ',
#  ' ',
#  'very beautiful  well written movie ',
#  'hats off to the creator ❤️🥳',
#  'the tell phone rings in the background    heart thought it was my stalking baby mama   had to quit immediatly',
#  'it makes me feel warm and cozy in my chest   a very nostalgic feeling',
#  'this movie is one of the sweetest you will ever watch ',
#  'it has both the comedy and drama as well as a really sweet story ',
#  'overall it is an awsome movie ',
#  'if you want to simply smile for two hours straight  go ahead and watch this movie ',
#  'i have zero clue why anyone would rated this under five stars for a comedy drama ',
#  'the chemistry between de niro and hathaway is tremendous ',
#  'i bought the whole thing and somehow there is actually a decent premise and storyline ',
#  'simple but sweet ',
#  'i would been having a terrible week where everything has gone wrong  and this movie was on tv in my hotel room and helped to distract me for a bit ',
#  'i found myself smiling at some parts  and it was overall just a nice movie',
#  'deniro and hathaway have good chemistry here  but the overall emotional tone is too mushy for me  feels manipulative ',
#  'deniro s character is too good to be true ',
#  'because he is deniro he can almost get away with it ',
#  'the messages about social and gender roles seem overly simplified and sort of muddy at the same time ',
#  'worth the attempt  but did not quite pull it off',
#  'serviceable ',
#  'has a low key feel to it ',
#  'something about it though brought me back to watch it again ',
#  'so there is something to it    although i do not think it ever really hit the mark it was aiming for ',
#  'cute movie  it is a nice two hours well spent if you have nothing better to do ',
#  'solid flick ',
#  'worth a watch ',
#  'def fresh',
#  'if you don’t vibe with the charm nancy meyers brings  just move on ',
#  'very boring ',
#  'seemed film was more interested in creating a statement than making it an enjoyable film ',
#  'this movie makes people emotional and reminds us of why senior people are still very important in our society ',
#  'robert de niro makes such an amazing character that actually makes me feel calm to ',
#  'anne hathway also makes an awsome character  power woman and rmaking a refrence to working moms which is a social issue today ',
#  'the plot is good ',
#  'it is a movie that makes you smile and laught a little ',
#  'what a movie it was  i do not know why this movie has low rating but believe me this is masterpiece  mood changer🥰',
#  'esta pelicula da una buena vibra con la quimica de sus talentos protagonistas',
#  'this movie is old but gold ',
#  'nancy meyer s take on this movie is a breath of air ',
#  'anne hathaway and robert deniro played their characters very well that made the movie more interesting to watch ',
#  'i love this movie  the mix of old and modern references is amazing ',
#  'this movie is for those that don’t take life to seriously and are just laid back ',
#  'my therapist metros like film it is too dark knight esque ',
#  'will be one of the all time classics  as good as  its a wonderful life  and others ',
#  'what the film does  is instil those good old values and attributes in a modern digital world  mixed into the emotions of old school gentleman ',
#  'a golden future classic ',
#  'great movie  it shows different story in one movie',
#  'undemanding ',
#  'pleasant way to spend a couple of hours ',
#  'this movie was so wholesome and amazing 👏 there were times i almost cried 😢 and alot times it made me smile',
#  'i had chosen this movie because i am great anne hathaway fan ',
#  'so obviously i was sure the movie was to be great ',
#  'but when i watched it  i found the movie to be a fresh watch  something so subtle but touching with glimpses of laughs ',
#  'the thing which touched the most was the story and the performances of robert de niro and anne hathaway ',
#  'specially that moment when they both work late night and he says he used to work at the same spot years ago ',
#  'must watch movie ',
#  'this is a good movie ',
#  'the story is good the music is beautiful ',
#  'robert de niro plays a wonderful character ',
#  'to watch',
#  'less about what is said  ',
#  'more about how it is said ',
#  'simple story where the ending is apparent from the outset ',
#  'the point is  with this film  in watching the plot unfold ',
#  'nothing deep ',
#  'nothing urging you to set a date to watch it again ',
#  'rather  more something about how people can feel ',
#  'interactions ',
#  'we all know about what it takes to put a winning production together ',
#  'good writing ',
#  'good acting  ',
#  'and all the rest ',
#  'this is no gone with the wind  it is just a show about  ',
#  'about people ',
#  'nothing more ',
#  'and you wind up with a pleased smile ',
#  'pick your own person to identify with ',
#  'i am older  so deniro is for me ',
#  'taught me the value of keeping my mouth shut more often ',
#  'pays off ',
#  'perfect three stars ',
#  'i liked this movie from start to finish ',
#  'loved the relationship between the intern and jules  it made me think of a very proud granddad who tries to help his niece out ',
#  'two very well spent hours ',
#  'enjoyed deniro for the first time in awhile ',
#  'loved the burglary sequence ',
#  'robert de niro in a comedy movie  a very decent movie ',
#  'did enjoy it ',
#  'seven five ten',
#  'very lame movie and the acting was forced in most scenes ',
#  'not recommended',
#  'a feel good dramedy which  although drawn out in places  has its moments and is bound to make you smile ',
#  'i am surprised the critics gave this one such poor ratings ',
#  'makes me wonder if they ever know how to enjoy a good movie ',
#  'so  it is not original  so it raises a few issues that we may not agree on or whatever but this movie made me laugh  then cry  and in the end  it left me with a feeling of warmth ',
#  'i enjoyed this so much ',
#  'i used to watch movies based on critic s ratings but now i know better ',
#  'a touching story with great actors ',
#  'awesome ',
#  'the script  the acting of the two leads  the story and how much you feel for the relationships  all very well done  except for anders holm acting ',
#  'if jules  husband was played by some actor with better acting it would have been stellar ',
#  'anders really did not make me connect with or feel for the husband at all ',
#  'his face was the same ninety nine  of the time he is on screen ',
#  'anyhow still a well executed  emotionally mature  well written movie to watch ',
#  'kudos to robert deniro and anne hathaway ',
#  'at the beginning  i felt good  but after a while all that cringe came in and ruined everything ',
#  'not so feel good movie ',
#  'its good ',
#  'de niro is so cool in that movie',
#  'la película trata horrible los problemas de una pareja al acordar sus propias metas  la historia es malísima pero robert de niro y anne hathaway no la vuelven aburrida ',
#  'really enjoy watching the movie ',
#  'love the performance of anne and robert',
#  'why all the great reviews ',
#  'worst movie i have seen mr de niro in ',
#  'movie is to reflect a work place that never in a thousand years would exist ',
#  'or am i just narrow minded ',
#  'whatever  terrible ',
#  'this movie is just such a feel good movie  i always end up so happy after watching it ',
#  'robert de niro ha trovato ormai casa in queste commedie in cui può esprimere un lato più divertente di sè  a lungo sovrastato da grandi performance drammatiche ',
#  ' the intern  è un film piacevole  originale e con davvero pochi difetti  lo si guarda con piacere dall inizio alla fine ',
#  'magari  sarebbe stato interessante  completare la sceneggiatura con qualche personaggio di contorno più interessante  a tratti si sente un po  la mancanza ',
#  'both the stars acting compliments each other ',
#  'a very enjoyable movie',
#  'this movie is really healing me ',
#  'i could see the importance of occupation at life ',
#  'do work because it makes me think of myself with pride and self esteem  rather to obsess over money ',
#  'a good hearted drama comedy that entertains without becoming overly sentimental ',
#  'it is a relaxing watch ',
#  'robert de niro jako alfa i omega',
#  'this is my favorite movie ever     watch it ',
#  '  ',
#  'one of nancy meyers  absolute humane best with the usual charm turned sweetness into something unexpectedly wholesomely heartening  benefitting from the finely casted chemistries that were enough to make this hilarious  insightful comedy one of the best feel good films in recent memory ',
#  ' a  ',
#  'not even the inmense acting chops of deniro and hathaway could save this film from the lack of focus and story ',
#  'this isnt a bad movie  its just not interesting or memorable ',
#  'its bland ',
#  'it is so fun to watch from beginning til the end ',
#  'i have always been a fan of stories about building friendships between young and old people  particularly in their exchange of wisdom which involves respect  mutual admiration  and compassion ',
#  'it is a feel good story ',
#  'great movie very wholesome to watch ',
#  'the two stars are fantastic and well matched  but hathaway s character get a terrible sexist arch that seems to defend men cheating on women if they are too impowered ',
#  ' mark zuckerberg never brought in a ceo   and he was a teenager  ',
#  'the movie is about love  life  lessons  falls  and getups ',
#  'surprisingly touching and happy ',
#  'it puts life  feminism  work  marriage  kids on the table and discusses it ',
#  'life lessons are demonstrated naturally and not in a boring way ',
#  'de niro still a great actor ',
#  'now older  he is doing more dramatic movies and the man still on fire ',
#  'some facial expressions are his and no one else could ever do it ',
#  'the chemistry he got with hathaway is touching and happy ',
#  'it is almost as they are connected with each other and with you and me ',
#  'and what about hathaway ',
#  'she is gorgeous  frenetic  and as expressive as de niro ',
#  'they could do those scenes without even talk ',
#  ' the intern  has a slow and tiring narrative  the script barely moves and the ending is disappointing',
#  'this movie is very sweet and does a fantastic job of building the relationship between the two main characters',
#  'this is a really good movie ',
#  'it is not the kind of movie i like seeing de niro in but i have to admit him and hathaway are very good together in this movie ',
#  'its story is quite cliché  but it is redeemed thanks to its modern approach and the chemistry of its leads ',
#  'i love this movie ',
#  'i have seen this several times ',
#  'it is a feel good film ',
#  'i think the whole world should have a senior intern because it helps them to adapt with the new norms ',
#  'it also make them feel that they belong or they are still part of something    a community ',
#  'i love anne hathaway ',
#  'i think she is a great actress ',
#  'the relationship of jules  hathaway  and ben  de niro  is very admirable ',
#  'he is like a father to her more than a colleague ',
#  'what i did not like though was when matt  jules  husband  had an affair and made jules feel that it was her fault because her company became successful in less than two years ',
#  'however  the ending was great ',
#  'everything just fell into place ',
#  'so this is what anne hathaway did after she left  the runway  in  devil wears prada  ',
#  'are we in some sort of anne hathaway and fashion cinematic universe perhaps ',
#  'even if we are  i would not mind it ',
#  'jokes aside   the intern  is truly a heartfelt  cheerful and emotionally uplifting film powered by beautiful and nuanced performances by rober de niro and anne hathaway ',
#  'some subplots can feel irrelevant to the final story and feel crammed in to fit the runtime ',
#  'by no means  the film gets boring but you feel that there is not much substance here ',
#  'the film looks good though  the cinematography is fantastic ',
#  'the dialogues are quirky and witty ',
#  'the chemistry between de niro and hathaway is what lifts this film from average to good ',
#  'recommended ',
#  'the best thing i can say about the intern is that it does not suck ',
#  'it draws you in so well you want it to be good ',
#  'then it punches you in the gut and you never recover ',
#  'it ends with you feeling like the writer got to the one yard line and then he dropped the ball ',
#  'great run  no touchdown ',
#  'i was pleasantly surprised how much i liked this movie  a retired businessman and widower  de niro  decides to apply as an intern for a successful online fashion start up company founded by ambitious jules ostin  ann hathaway     they are generations apart but they find a way to successfully work and support each other ',
#  'along the way  both are able to find friendship and reliable people they can count on ',
#  'highly recommended ',
#  'it has an intriguing premise  but does not evolve too much commentaires aside from the clichéd situations ',
#  'still  it is charming movie and a good watch and really works because of the chemistry of anne hathaway  doing her best  and robert de niro  truly a standout  ',
#  'commedia più che dignitosa che nasconde una morale più profonda del previsto e del necessario ',
#  'nella seconda metà del film si sbarca in territori pericolosi proponendo un idea di fondo forzata con risvolti narrativi inconsistenti ',
#  'la buona sintonia tra la coppia dei protagonisti rende comunque il film assolutamente apprezzabile  un esperienza leggera e passeggera ',
#  'this is one of those movies that just puts you in a happy mood ',
#  'it is not classic cinema  but it also was not meant to be ',
#  'the main success is the chemistry by the entire cast  particularly the two leads ',
#  'i do not necessarily dislike this film  but it has way too many cheesy cringey moments for me to enjoy it ',
#  'robert de niro and anne hathaway are good  though a lot of their meaningful scenes feel forced due to the writing and dialogue ',
#  'i would have let it slide if  the intern  was not on for two hours   that is too much cheese for me ',
#  'the story was beautifully portrayed by very powerful actors ',
#  'like a breath of fresh air   no violence  swearing  politics     just considerate people ',
#  'de niro was great helping everyone out with everything   but it was a two way street    all the young employees were very respectful to him too ',
#  'like george martin said about billy preston s time with the beatles     he was like a  lubricant     everyone loved him  all the band members were politer to each other and in better spirits   there was no pettyness   john wanted him in the band permanently     when preston left he was really missed ',
#  'really great chemistry between de niro and hathaway  subtle and intelligent dialogue ',
#  'however  i think if the husband wife roles had been reversed  viewers would not be so pleased with conclusion that  homemaker  should be totally behind  breadwinner    shut up and mind the child ',
#  '‘the intern  is a must see ',
#  'the film is not only heartwarming  but leaves you with a good feeling inside ',
#  'it is such a positive message that drives home what being a good person and a hard worker means ',
#  'one of my favorite movies of all time ',
#  'it was    okay ',
#  'it really liked playing with old people stereotypes but not in a bad way just in a ham fisted way ',
#  'i do not really know what the movie was trying to teach me ',
#  'what i got is   woman can be good bosses but also should forgive cheaters  ',
#  'i cannot wipe the smile off my face while watching this ',
#  'it is the ultimate feel good movie  and it tackles issues in the most wholesome way possible ',
#  'stellar acting from de niro and hathaway as well ',
#  'one of the best feel good movies of this generation and gives a nod to old school customs ',
#  'i appreciated de niro s gentlemanly  likable character and hathaway s character development from micro to macro despite the horrendous husband debacle ',
#  'personally  could have done with out that part of the movie but critics already said this movie was not edgy enough   ',
#  'i will watch this again  to me that says it all   ',
#  'the intern suffers from lack of ideas  their development and history itself ',
#  'everything unfolds in areas almost white phones of the golden age of hollywood ',
#  'neither of them has problems other than being workaholics ',
#  'and when a problem arises  everything will be resolved sooner rather than later ',
#  'a nice movie to see with your family ',
#  'this movie made me laugh zero times 🤦\u200d♂️ basically this movie is if u wanna c robert deniro act like a reg ',
#  'guy ',
#  'this movie cements my love for de nero  a feel good movie that started brilliantly introducing that scary side of a seventy year old widower s insufferable life  which changed a lot when he accidentally found a flyer about a senior internship program ',
#  'the movie is at its best when ben is the focus ',
#  'which does not happen too much thanks to anne hathaway s character and her uninteresting in going relationship with her husband   a bad actor by the way ',
#  'great cast and enjoyable story',
#  'entertaining  funny and sometimes touching plot ',
#  'good acting throughout ',
#  'i find it hard to say anything negative about this film ',
#  'de niro and hathaway really worked well together ',
#  'both a funny and at times heart warming film  de niro proves his talents brilliantly in a more gentle  fatherly role ',
#  'she’s cute  de niro is pathetic and a terrible actor ',
#  'save your money ',
#  'a friend of mine who is also a movie lover described this movie in a few simples words   why did robert de niro do this movie ',
#  'normally older actor accept projects they really like ',
#  'good story to tell  however it never explained why a man with all his experience could not take administrative chores off the boss ',
#  'very entertaining ',
#  'it is refreshing to see deniro take on a role that does not tap into his best acting skills and still play a role perfectly ',
#  'in character ',
#  'i have seen this movie at least three times and always enjoy it every time ',
#  'robert deniro s character brings a calm and focus to a very upended office environment ',
#  'my favorite scene  in his closet  explaining why all men should carry handkerchiefs ',
#  'cute movie  would recommend ',
#  'sentimental ending',
#  'the intern is funny and heartwarming ',
#  'it is a wonder de niro went from this to the appalling dirty grandpa ',
#  'actually pretty funny and heart warming',
#  'such a sweet film ',
#  'i laughed  i cried ',
#  'major feel good  original  best acting i have seen out of anne hathaway in several years ',
#  'would highly recommend ',
#  'its a feel good movie and i am sure that everyone is going to wish for an intern from now😉',
#  'lovely enjoyable film ',
#  'hathaway and deniro are great in this film ',
#  'ok movie  de nero sucked in this movie ',
#  'really liked this movie  the cast is great and the story full of surprises ',
#  'the next genocidal uprising ',
#  'hathaway is in great form in the intern ',
#  'she really is believable as ceo jules ostin and really excels in the role ',
#  'nancy meyers really excels at these rom com movies that make you feel like the characters are believable and the storyline  even no matter how absurd  might actually be believable ',
#  'aside from hathaway  de niro is a breath of fresh air as a seventy year old widower who is just trying to figure out life as a retiree ',
#  'the only negative that i could grasp from this movie is the fact that all the younger people took a page from de niro s  experience  and started molding towards his way of life  but he never reciprocated that behavior ',
#  'i guess having him sign up for facebook ',
#  'as a workaholics fan  i really enjoyed seeing anders in a more serious role and he really performed it quite well ',
#  'well until he had to cry that is ',
#  'great chemistry from robert deniro and anne hathaway ',
#  'fun and funny ',
#  'a perfect choice for our datenight ',
#  'who wrote this garbage',
#  'it was a feel good movie was some heart and some laughs but nothing special ',
#  'the movie earns one star for being outstandingly bland  to the point that it would be fair to call this the cinematic equivalent of a pack of white k mart dress shirts    watched using boxxy software yesterday ',
#  'in one word  not bad ',
#  'great movie i loved every part of it   i loved the spontaneity in it   and i have to say robert de niro and anne hathaway are the dynamic duo and i would kill to see them again   i would watch this masterpiece multiple time and still be happy every time ',
#  'touching and heart felt ',
#  'great performances by hathaway and deniro ',
#  'smart and witty what a great match ',
#  'i get what others are saying about his acting  its tired and old  just like him ',
#  'sad he is got to stoop to this crap ',
#  'the intern is like a stack of pancakes ',
#  'it is warm  sweet and leaves you with a touch of a belly ache ',
#  'you are  no doubt  drawn in by the casting and who could resist a movie that brings together robert de niro and anne hathaway ',
#  'they are the best actors of their respective generations  but   wow ',
#  '  you keep wishing that they could find each other in a better movie ',
#  'the intern is not bad exactly  it is light  breezy but is of no real significance ',
#  'de niro  who seems to have retired from the hard boiled  challenging roles that made him famous  plays a good hearted retired widower named ben whittaker ',
#  'retired from a now defunct company that made phone books  he now spends his days trying to figure out how to spend his days ',
#  'his wife of forty two years is dead and he needs a challenge ',
#  'so  he answers an ad for an outreach program for senior interns  senior as in age  to help out at  about to fit   a successful internet company that specializes in women s clothing ',
#  'ben gets the unenviable task of being the intern to the company s ceo  a supposedly tough as nails career woman named jules ostin  hathaway  ',
#  'she claims she does not need him  but romantic comedy law demands that she discover how much she really does need him  not just in the office but in her personal life as well ',
#  'he becomes her driver  driving miss hathaway  ',
#  'and eventually he becomes her confidant ',
#  'the two build a nice friendship that  it is a relief to report  does not bloom into a may december ',
#  'the problem is  that is about it ',
#  'the movie is as bland and superfluous as it gets ',
#  'director nancy meyer sets up the inner office environment with the reverie of shop worn sitcom ',
#  'it is pleasant and nice but it is only established so that ben s old school experience can teach the young a thing or two  but none of it has any significant payoff ',
#  'the people around the office are young whipper snappers whose function in the film is to be young whipper snappers and they do not matter either ',
#  'they are not developed as characters  they are just onlookers to ben s successes ',
#  'ben develops a half written and pointless semi sorta romance with the company s on site masseuse  rene russo  which goes nowhere and also does not seem to matter ',
#  'the plot developments are pointless too ',
#  'are we surprised to find that jules  home life is burdened by the fact that her husband matt gave up his career plans to be a stay at home dad ',
#  'nearly all of jules and matt s scenes are dedicated to talking about the fact that they never see each other ',
#  'hmmm ',
#  'for about the first hour of the intern i was fairly bored ',
#  'i liked jules and ben but i wanted the movie to clear out the junky plot points and just let them talk  let them be human beings who connected with each other ',
#  'to that point  the movie had no real dramatic tensions  ',
#  'then it happens ',
#  'a dramatic situation develops that actually seems to give the movie some dramatic weight ',
#  'not to give anything away  but ben discovers something about matt that troubles him ',
#  'when he brings it to jules  the two have a heartfelt conversation that seems to be drawn from the characters  not from the screenplay ',
#  'unfortunately  the results of that dramatic event are crushed by a resolution that nobody   but nobody   is going be happy with ',
#  'the intern was written and directed by nancy meyers who specializes in cupcake sweet confections like it is complicated and something s got to give and the father of the bride movies ',
#  'her films seem to have a consistent pattern ',
#  'they contain a germ of human interest wrapped up in a gimmicky script that is fit for a bad television sitcom ',
#  'the exception is a great comedy she made thirty years ago called irreconcilable differences  about a kid who divorces her squabbling parents ',
#  'that movie had truth and human interest ',
#  'the intern has only faint echos of humanity ',
#  'it has moments here and there when it shows the promise of what it might have been ',
#  'it is a nice  sweet  uncomplicated movie that will begin disappearing from your mind before you get out of the theater and will have left you completely by the time you get to the car ',
#  'well my cup of tea ',
#  'binge watching it over n over again',
#  'the intern no tiene mucho que contar tampoco que trasmitir es un film de domingo en la tarde que olvidaras a ver visto por que no tiene grandes cosas que aportar  no es una mala cinta pero realmente no tiene mucho que resaltar ',
#  'enjoyed this way more than i expected ',
#  'super pleasant  easy watching if you need something feel good ',
#  'de niro and hathaway were awesome ',
#  'this is a heartwarming movie  despite a muddled plot  uneven performances  and some implausible situations ',
#  'robert deniro stars as a retiree who led a traditional business life and is struggling with boredom during his retired years ',
#  'he wants to get back out and meet people with purpose  and enrolls in a senior intern program at an internet startup ',
#  'apparently this place only employs people under thirty five who also happen to be loveable characters with some simple problems that deniro s character can solve ',
#  'deniro plays his character compellingly but a little too straight to convincingly be able to win over the heart of anyone he talks to in just a couple minutes ',
#  'sadly  the other actors are not up to caliber  with a wincingly badly directed and badly acted scene at the climax of the film ',
#  'also  do not think too hard about this movie  there are plot holes ',
#  'but it is nice to see a movie valuing the wisdom that often comes with age  even if they overdo it quite a bit ',
#  'it is pleasant ',
#  'i really enjoyed watching this movie ',
#  'robert de niro comes across as genuine and sincere ',
#  'a throw back to when men were men ',
#  'wheres my hanky ',
#  'anne hathaway gives a terrific performance as well ',
#  'this is a great date movie ',
#  'an amazing performance by de niro as well as an awesome supporting cast ',
#  'this movie had me hooked from the word go ',
#  'i laughed  i cried  i was invested in the characters ',
#  'absolutely loved this one ',
#  'over all the movie was a great depiction of the unique friendship between generations ',
#  'the movie has some problems with it is plot especially with the family husband storyline ',
#  'the ending was abrupt  out of place and extremely unsatisfactory ',
#  'this movie made me cryyyy so much ',
#  'not the sad kind of cry but it teared me up in knowing how good the movie was ',
#  'it brings so much joy ',
#  'the movie really touched me through the bones ',
#  'the first time i cried so much for a movie because it was just soooo damn good ',
#  'it was truly the best and inspiring movie ',
#  'one of the best comedy drama films i have ever seen ',
#  'the dialogue is hilarious ',
#  'the chemistry between anne hathaway and robert de niro is fantastic and funny ',
#  'great work and lessons learned for life as a senior ',
#  'let me know the importance of being a gentlemen ',
#  'as a comedy and drama film  this one is pretty good ',
#  'the intern was a refreshing change of pace for me  theatrically speaking ',
#  'a story with a heart  solid acting and quite a bit of realism ',
#  'i love deniro and hathaway anyway  but the chemistry between the two was very strong ',
#  'the performances will not get recognized at the award level  but i have not enjoyed deniro this much in a long time ',
#  'it was a departure for him and he was precious ',
#  'the vibe of the film was reminiscent of similarly themed eightys and ninetys films  but i have not really seen anything like this in almost twenty years ',
#  'they just do not make these kind of movies anymore ',
#  'for someone my age  it was a pleasure to watch ',
#  'de niro plays a mary poppins jeeves type character who never puts a foot wrong his unbelievable  sage  kindly older man  who can also get an erection  character is fairly two dimensional ',
#  'the movie tries too hard to be progressive ',
#  'virtually shoving its modernity down our throats ',
#  'here s some feminism  take a kick in the nuts ageism  gender roles  boom ',
#  'see ya  ',
#  'no laughs  no genuine emotion ',
#  'overall  just pretty meh ',
#  'pretty much just ok  had kind of touching dramatic moments as well as funny ones  and also digs a little deep at times that flow well with the movie dealing with topics like work life balance  women in the workplace and infidelity ',
#  'it felt kind of slow though and despite the fact that some of the characters do go through hard times  the deniros performance and the movie in general was so light hearted it was hard to really believe anything was at stake or anything bad would happen ',
#  'also the movie feels kind of like a giant apple advertisement  but maybe that is just me ',
#  'i enjoyed the movie ',
#  'de niro taught the milleniels how to be classy',
#  'this movie had a lot of heart ',
#  'but it’s listed as a comedy and i must say the laughs were good but sparse ',
#  'this should be listed as a drama ',
#  'i was in the mood for a laugh and that’s why i picked this movie ',
#  'but as you’ll see you’ll actually share a few tears by the end ',
#  'if it’s a drama it’s four stars ',
#  'but if your looking for a comedy i would give it only one star ',
#  'good luck ',
#  'great movie ',
#  'well written and a wonderful cast ',
#  'you’ll laugh and maybe even cry a little ',
#  'academy award winner robert deniro has been hitting bad times recently in terms of the quality of his film ',
#  'appearing in garbage such as  meet the fockers  and  little fockers  and  dirty grandpa  ',
#  'it is nice to see that among the trash is a movie deserving of his talents and worth your time ',
#  ' the intern  is not specatular by any means ',
#  'however there is a lot to like about it ',
#  'the thing to like the most is deniro ',
#  'he carries this movie on his shoulders and does so very well ',
#  'he also has very good chemistry with academy award winner anne hathaway ',
#  'their scenes together seem very genuine ',
#  'almost like they are not scripted ',
#  'he alone makes this movie worth seeing ',
#  'the script is a little formulaic in terms of its storyline  but it still makes for a entertaining film that i do recommend ',
#  'original mostly clean comedy',
#  'loved this side of deniro ',
#  'he is so known for his tough guy roles  that it was refreshing to see this very reserved performance ',
#  'he and ann hathaway made this a very touching movie  with a lot of commentary on life and what should be important ',
#  'sweet  touching  well developed story for today ',
#  'diabolical romantic non drama  written and directed by nancy meyers  so all the blame rests with her ',
#  'de niro has his own reasons for lining up these turkeys ',
#  'his is the only decent performance  trying to extract pathos and subtlety where there is none ',
#  'anne hathaway is incredibly irritating ',
#  'a real clunker ',
#  'this movie is really charming  especially in the beginning ',
#  'and as it was going along i kept thinking do not mess this up  do not mess this up ',
#  'i think it goes adrift a bit  but i still liked it overall ',
#  'i can see where some people would not like this movie at all ',
#  'robert de niro s character is too perfect  the ending is tied up way too neat  the scene where they break into the mother s house belongs in a different movie  and so on ',
#  'i tried not to let those things bother me though  because i really enjoyed the two leads and i wanted to see where their stories would go ',
#  'if you have seen any other nancy meyers movies  somehow i have seen all of them   you know what you are getting into here ',
#  'there is nothing challenging or all that memorable but you will feel good after watching it ',
#  'thoroughly enjoyed it ',
#  'it was generally a good movie ',
#  'the movie was intriguing and heart warming',
#  'nice film  easy watching',
#  'this is a cute and funny movie ',
#  'cliched but delightfully so',
#  'loved it ',
#  'heart warming  funny ',
#  'nice chemistry between de niro   hathaway ',
#  'by far one of my new favorite movies ',
#  'definitely in my top ten ',
#  'very biased and an obvious propaganda piece ',
#  'written and directed by nancy meyers starring movie veteran icon robert deniro as ben whittaker coming out of retirement and eventually being accepted as an intern for internet selling sensation ceo magnet jules ostin  anne hathaway ',
#  'an average feel good movie ',
#  'cool concept ',
#  'was better in the beginning ',
#  'pretty good but not amazing ',
#  'scott   dr  scott allison  professor of psychology  university of richmond  well greg  robert de niro doesn t appear to be in any hurry to retire    both in real life and in this movie ',
#  'greg   greg smith  founder of agile writers of richmond  va  i found the whole thing  re tiring ',
#  'let s recap  scott  we meet ben whitaker  robert de niro   a seventy year old widower who is restless and dissatisfied with his life as a retiree ',
#  'while searching for something meaningful to do with his time  he stumbles across an advertisement for an senior internship program ',
#  'he decides to apply as an intern at a company called about the fit  a fast growing business that sells fashionable clothing online ',
#  'ben s interview goes well and he is hired as an intern ',
#  'greg   greg smith  founder of agile writers of richmond  va  but his new boss is jules  a high strung workaholic young woman  anne hathaway  who micromanages everyone ',
#  'at first she shuns ben claiming that she doesn t need an assistant ',
#  'ben employs his old school discipline of never leaving the building before the boss and picking up the boss s loose ends ',
#  'one day  he notices her driver is a bit too drunk to drive and he takes his place as jules driver ',
#  'and before you know it they re best buddies ',
#  'scott  if you ve been following our movie reviews over the years  you know that i haven t been much of a fan of robert deniro s recent body of work ',
#  'with the intern  there is now some promising indication that his slump is over ',
#  'deniro shines in his portrayal of a retired gentleman from a bygone era who takes on the role of a rookie intern in a quest to inject his geezerly life with some meaning ',
#  'he not only finds what he is looking for  he also manages to endow several other people s lives with richness  wisdom  and direction ',
#  'the hero s journey here takes on a unique and interesting form ',
#  'ben starts out as a useless minion to jules  but over time he evolves into a trusted sidekick ',
#  'by the end of the film  ben is arguably jules equal  and also her mentor ',
#  'to the extent that ben and jules are equals  one could argue that they are buddy heroes who follow the classic pattern of being at odds with each other at first and then grow into bffl s  whether ben is her sidekick  mentor  or buddy is open to interpretation here ',
#  'regardless  their relationship evolves and becomes transformative for them both ',
#  'greg  i thought this movie was too reminiscent of last year s the interns starring vince vaughn and owen wilson ',
#  'similarly  we have two older salesmen who teach old school lessons to the internet savvy youngsters of google ',
#  'the intern is a little more personal in that ben takes on a more mentorly role early in the film ',
#  'in fact  he much reminds me of a butler similar to hobson in one thousand  nine hundred and eighty one s arthur   or even mary poppins ',
#  'he takes jules daughter to kindergarten and fixes her relationship with her stay at home husband ',
#  'scott  we just reviewed the martian where astronaut watney graduates from hero to teacher ',
#  'in that review we noted the ultimate destination for the hero is to become a mentor ',
#  'and i think we see this pattern revisited here in the intern ',
#  'ben has been a leader of a major company and has retired to a sedate life ',
#  'now  with this new opportunity  he has a chance to pass on his wealth of knowledge not only to jules  but also to all the members of her staff ',
#  'he has found his final destination ',
#  'scott  greg  this movie has a sweetness to it that i found extremely appealing ',
#  'both of the lead characters need something  and what they need can only be found with help from the other ',
#  'jules wants to be seen as independent and so she resists ben s help ',
#  'she is smart enough to know that ben represents no threat to her authority and legitimacy as a leader ',
#  'so she bends  and as befitting a good hero story  her receptivity to change is brought about by a deep hurt    the devastating reality of her husband cheating on her ',
#  'as you point out  greg  ben himself has already accomplished in life many of the goals that jules is now seeking ',
#  'and so he is developmentally ready to just assume a helping role  a mentoring function ',
#  'as they say  when the student is ready  the teacher will appear ',
#  'the first half of this movie is devoted to jules not being ready ',
#  'all heroes are humbled in some way  and this ends up being the key to her openness to transformation ',
#  'i enjoyed watching these two heroes do all the things that heroes do when they are in two different stages of life ',
#  'thirty or forty years in the future  i can easily envision jules doing all the things that ben is doing in this movie ',
#  'greg  actually  scott  i found this movie somewhat patronizing ',
#  'aside from jules  all the other characters in the story were caricatures and stereotypes of millennials ',
#  'ben is seated with the other interns  all of whom are recent college graduates ',
#  'young davis is being kicked out of his parent s basement ',
#  'so ben takes him in and teaches him the importance of getting out of bed on time and dressing in a suit and tie ',
#  'young jason is too interested in partying and ben shows him the way of moderation ',
#  'and young administrative assistant becky is drawn to tears when she fears ben is getting more attention than she is ',
#  'i ve got a degree in marketing from harvard wah wah wah and of course ben calms her down with a pat and a hanky   then pushes jules to delegate some of her authority to becky ',
#  'these are all stereotypes that will appeal to the older crowd  who appear to be the target audience ',
#  'there s no nuance here ',
#  'jules is the female mark zuckerberg who needs a nudge to realize that if she s going to play with the big boys  she has to grow a pair ',
#  'and it s ben s gentle nudging that gets her there ',
#  'i found it all very patronizing verging on condescending ',
#  'scott  sorry you felt that way  greg ',
#  'the intern represents a comeback of sorts for actor robert de niro  who shines as an older man looking for a way to live a meaningful life ',
#  'his heroic urge to mentor others is fulfilled when he is partnered with a rising business star  played with great zest and skill by anne hathaway ',
#  'this movie accomplishes what all good hero stories should accomplish it teaches us that when we re young  we need good mentors ',
#  'and that when we re old  we need to give back  to do good mentoring ',
#  'there s nothing condescending about needing help and giving help  it s just a reality of lifespan development ',
#  'for giving us a sweet tale of two lives intertwined across generations  i award this movie four reels out of five ',
#  'the two hero s journeys of our lead characters are fun to watch  and they show how two people who need each other can help each other grow and evolve ',
#  'ben is wise enough to know he needs to come out of retirement to meet his need to mentor  and jules becomes wise enough to recognize that she needs mentoring ',
#  'the movie s ending is ambiguous    does ben no longer need to mentor ',
#  'this dual hero story is moving  sometimes silly  but compelling overall ',
#  'i give this pair four heroes out of five ',
#  'the supporting cast is adequate but not terribly memorable ',
#  'another intern is a comic figure ',
#  'one of jules employees is also comedic in a pathetic sort of way ',
#  'there s no real villainy to speak of ',
#  'this is a story of people growing and developing more than it is a story of overcoming any particular villain ',
#  'overall  the supporting characters earn a decent rating of three out of five ',
#  'movie  cast  hero  greg  i found the intern to be an overly simplistic  melodramatic  under humored and pandering to the older generation ',
#  'even the idea that a woman could run her own company was undermined by her having to be taught the values of bygone days by an older man ',
#  'i felt it was a boring  and like it or not  condescending look at a fantasy of modern business ',
#  'i can t muster more than two reels out of five for the intern ',
#  'i ll grant you a nice hero s journey for both ben and jules ',
#  'it s a pattern i don t think we ve seen a lot of   a mentor who needs his up and coming apprentice ',
#  'and an apprentice who needs the mentoring of a former hero to rise to her own potential ',
#  'i give these odd couple buddy heroes three out of five heroes ',
#  'the supporting cast were all weak cardboard cutouts of young people stereotypes ',
#  'i ve already outlined my thoughts on them ',
#  'two out of five cast points ',
#  'movie  cast  hero ',
#  'thirty year old ceo  jules  anne hathaway  who has grown up her company with more than two hundred employees in a year and a half ',
#  'time is too short for her to be perfect for both home and work ',
#  'she gets a seventy year old intern  ben  robert de niro  who have been living his life and trying to start unconventional life after retirement ',
#  'ben s first job as a senior intern coming through a senior intern program is jules s secretary ',
#  'she feels uncomfortable to him because he is older than her ',
#  'however  she starts to open her mind to him  who is always polite and attentive to her ',
#  'it cannot be found free time of her life in the company who is involved in the all managements of in the company and rides a bike in order to manage her physical fitness in the company ',
#  'jules  company is a big online shopping mall  and all the systems are very high tech  but ben is still analog ',
#  'however  he fully adapts to work in the job due to his rich lifestyle and unique sociability ',
#  'he has used to analog  but his mind is still hot ',
#  'although he may seem trivial  it is in fact crucial in terms of today s concern over different from the average seventy years old people we imagine ',
#  'however  as like the impression given by the title  intern   in the beginning of this movie  an unusual intern gives the impression of enjoying an interesting intern  but it starts to escape from the topic more and more ',
#  'even though it is not an ordinary intern  it is what happen when trying to break through the point that if the company looks reality  there are many restrictions ',
# ...
#  'started of great and ended horribly ',
#  'i liked it very much  light funny and happy ',
#  'dragged at points  but still very funny overall ',
#  'i love de niro   he is sincere and self deprecating and loveable however hathaway is unconvincing playing the same character as usual ',
#  'it is a sweet little movie but the ending is very unsatisfactory ',
#  'if it was anyone other than de niro this would get one star ',
#  'the premise might seem funny  but it is a gentle comedy at best  all seen through the eyes of robert de niro s character  who is instantly forgettable ',
#  'started off with promise  good actors   reasonable story  however failed to progress  no depth and just stopped without an ending ',
#  'it is not the comedy that will make you laugh  it is the comedy that will make you smile ',
#  'nancy meyers makes movies for women  and this time for senior as well ',
#  'there is no single story  more like fragments of people s lives ',
#  'senior internship program of an e commerce start up founded by a young female already set the scene up for the drama and conflicts ',
#  'women can relate to this movie  especially women with a purpose ',
#  'it was also nice to see the office scenes with a lot of open space  macbooks  large windows  and the ceo bikes in the office ',
#  'easy to watch   not too taxing in the brain   crap ending though and they miscast the husband of anne hathaway completely  ',
#  'this movie surprised me ',
#  'i thought it was going to constantly make jokes about older people and while it does have a few jokes of that nature  it is more about how mentorship can positively change you ',
#  'it was nice to see a movie where the characters are all basically good  but flawed ',
#  'it also makes you feel good and warms the heart ',
#  'you need that from time to time ',
#  'have grown up watching de nero playing great roles in godfather part two  casino  goodfellows etc ',
#  'really did not  want to watch this movie because he was so far removed from this genre ',
#  'sat down and watched the flick with my three girls and really enjoyed it ',
#  'btw just do not understand the bad wraps on anne hathaway  thought she was great',
#  'la directora nancy meyers sabe hacer unos estupendos  chick flicks    it is complicated    something s gotta give  y  what women want   son algunos ejemplos ',
#  ' the intern  no es la excepción  la historia de un hombre viudo de seventy años  un estupendo robert de niro  que termina convirtiéndose en un practicante de una empresa de ropa por internet es definitivamente entrañable ',
#  'la química entre de niro y anne hathaway  su joven jefe  es maravillosa y hace de esta cinta algo muy  pero muy entretenido ',
#  'good chemistry between hathaway and de niro carries this movie off and anyone over fifty five will enjoy the  ageless  focus ',
#  'recommended ',
#  'top movie really enjoyed this one',
#  'personally one of my favourite movies now every time i watch it i still love it  great film ',
#  'the intern is without a shadow of doubt a two thousand and fifteen film ',
#  'twenty years ago  the intern would not of been made ',
#  'atleast  not like this ',
#  'it handles a driven  young working woman with seemingly infinite hustle and a stay at home father with nary a hint of ridicule ',
#  'the characters accept this as simply as you would wearing socks with shoes ',
#  'the elephant in the room is ben  played supurbly by robert de niro with just the right mix of understated sensitivity and decades of life experience without the  i told you so  snark ',
#  'ben s the very senior intern to anne hathaway s jules ostin  a hustlin  twenty onest century sister doin  it for herself  her daughter   her stay at home husband ',
#  'ben never condescends  is always humble and willing to go above and beyond for the good of his motley crew of co workers ',
#  'this is taken to it is logical conclusion during a daring heist ben heads up with his fellow desk jockeys to delete a disparaging email their not so fearless female leader accidently sent to her mother ',
#  'easily the film s most ridiculous moment  but it did not outstay it is welcome and serves as an effective palate cleanser in the middle of the movie ',
#  'there is an interesting twist a little after the hiest which was definitely needed  because as good as the intern is  it never layed down a firm mission statement for either of the leads to accomplish by the end  and the twist gave some welcome drama to what i found to be a very enjoyable  sweet and likable film ',
#  'fine  but nothing incredible or groundbreaking ',
#  'despite having a solid and intriguing premise  it primarily coasts on the chemistry of its large cast ',
#  'bonus points for the interior design porn ',
#  'made me feel good  ',
#  'it is ice cream ',
#  'plain ',
#  'simple ',
#  'this is one of those perfect  late night tbs flicks that you catch when you are hanging out  ironically enough  at your grandparent s house ',
#  'the film is simple and the cast is earnest and charming ',
#  'leave your cynicism at the door  and you will be fine   even when you get to the abrupt ending ',
#  'a great movie with a lot of potential   a film with perfect flow of story  great collection of plot and an awesome pair   incredible cast but still  robert di nero   ',
#  'what an actor   ',
#  'you never fail to amaze us with ur charming performance   never ever   ',
#  'always be the right person with great performance  ',
#  'and anna was also incredible so were the rest of the cast   ',
#  'overall full on fun   great entertainment   ',
#  'nancy made an incredible film    hats off    ',
#  'really good ',
#  'wanna watch for the twond time   ',
#  'eight thirty one sixteen i actually disliked watching this film ',
#  'at the beginning  i did enjoy it because it was  cute  ',
#  'after a while though  it became very obvious that this story was made up and i could envision someone sitting there writing the script ',
#  'in authenticity is never a good thing ',
#  'then  about half way through the film  it becomes much darker  and quite frankly  just depressing ',
#  'the resolution in the end is not really a good resolution either ',
#  'so  to me it is fake and depressing ',
#  'not great entertainment if you ask me ',
#  'it is good until the end  not such a big fan of the ending but other then that it is a great movie and great cast',
#  'it was quite a nice film to be honest ',
#  'anne hathaway never looked better   ',
#  'i actually kind of liked her after all these years    ',
#  'bit cheesy but it is worth watching',
#  'really good movie ',
#  'brilliant acting and storyline ',
#  'enjoyable but forgettable ',
#  'a better movie for de niro then some of his recent stuff ',
#  'the ending left a lot to be desired ',
#  'it just ended ',
#  'dumb ',
#  'relatable and very relevant ',
#  'dynamic between characters was sweet  funny ',
#  'and genuine ',
#  'it was ok ',
#  'i felt it started off strong but kind of fizzled as it wore on ',
#  'i actually thought it would be more of a comedy but the jokes it did have was the first half of the movie ',
#  'the acting by de niro and hathaway was great but i hated the abrupt ending ',
#  'it was a nice storyline that i enjoyed watching ',
#  'what a great movie  i did not want it to end for the last half of the movie  i kept thinking she was going to hire ben as the ceo though ',
#  'cute  yet thin storyline ',
#  'enjoyed the pairing of hathaway and de niro ',
#  'felt cheated by hathaway s character s obvious storyline and wished they would given de niro s character more of a story    that being said  maybe that was point  to have a senior character quietly and resolutely and prominently affect one s life ',
#  'thought de niro was great with the younger men  providing guidance and support ',
#  'nice watching the young men evolve ',
#  'disneyesque predictability',
#  'i am not one to watch these types of movies ',
#  'i tend to prefer horror action ',
#  'however  this one strays from the expectations of its kind ',
#  ' spoiler  ',
#  'i was almost expecting a scene where deniro s character would mess up and everyone would see that he is not perfect  but in the end they would find they love him anyway  but it was what i hoped  the  elder wisdom  he provided seemed to be the answer to everything and i think it is what is lacking in recent generations ',
#  'i am glad this movie was made ',
#  'it shows what is missing   what is needed in not only the youth of today  but the companies of today ',
#  'good job ',
#  'funny  and a pretty witty satire about the politics in today s business office ',
#  'just the right mix of serious and humor ',
#  'good date night movie ',
#  'heartfelt movie    great story and fantastic acting ',
#  'a retired seventy year old widower  ben  played by robert de niro   is bored with retired life ',
#  'he applies to a be a senior intern at an online fashion retailer and gets the position ',
#  'the founder of the company is jules ostin  anne hathaway   a tireless  driven  demanding  dynamic workaholic ',
#  'ben is made her intern  but this is a nominal role   she does not intend to give him work and it is just window dressing ',
#  'however  ben proves to be quite useful and  more than that  a source of support and wisdom ',
#  'good  and surprisingly so ',
#  'i was expecting a farcical half baked comedy about how an old guy rejoins the work force and struggles with modern gadgets and work processes ',
#  'there are a few examples of that but the movie is far more than a story about generational differences ',
#  'it is more a drama than a comedy  and is a good one too ',
#  'there is themes of generational wisdom  not judging people by their age  or anything superficial  and making the most of people s talents ',
#  'it is also a movie about starting over  and doing what you enjoy ',
#  'moreover  it is simply a nice story ',
#  'solid work by robert de niro in the lead role ',
#  'he does not do bad performances  but that has not stopped him in the past from taking on roles and movies that are well below his standards ',
#  'this is not one of those roles or movies ',
#  'sensitively played  and ideal for the role ',
#  'good work too by anne hathaway  who is very convincing as the go getting entrepreneur ',
#  'bottom line robert d made this movie ',
#  'really enjoyed it ',
#  'anne hathaway also played a great part also  ',
#  'a film that differentiates the young and old generation ',
#  'i would definitely say it is the director s best film ',
#  'i have liked her other films  but this is a lot different from them ',
#  'i mean it was well written screenplay with much better understood the contemporary world than just focusing on the relationships as usual ',
#  'so the addition of digital world stuffs made all the difference and i completely enjoyed it ',
#  'do not think it would be another  the internship  as i initially thought  but slightly it is and much better everyway ',
#  'you are going to agree with me that the film s posters or the trailers were not very impressive as what the actual film did to grab our full attention ',
#  'the two hours films are always a concern to me  but when a film like this runs for that long  i can even sit for another half an hour ',
#  'anyway  with this story and its runtime  the pace was incredible ',
#  'when there is something interesting is going on  we forget to focus on the flaws and enjoy our time  which is what i exactly did in here ',
#  'this is not a comedy where you are going to laugh openly loud  it is a comedy in the sense of the set of characters the film has ',
#  'i mean  the story is about the digital business and most of them who are into the computers are considered as geeks ',
#  'so theirs world is nothing  but just hooked to their works and forgetting the actual world around them ',
#  'even for the someone in the next room  they tweet ',
#  'for them to remind only they have changed  not the physical world and that is where our main character who is old and wise influence the younger generation people ',
#  'so the actors were undoubtedly the best thing apart from the direction and the story ',
#  'the seventy three years old robert de niro still impressing with his extraordinary character display ',
#  'i do not know whoever was in mind when it was written  but this role perfectly fits none other than him ',
#  'and then there is anne hathaway on the opposite side who equaled with de niro with her part ',
#  'from the narration point of view  it started with deniro s  but quickly around in the middle it took a circle to cover others as well ',
#  'and then comes from the professional to the personal life topic when it was developed and brought a small family who were affected by the workaholic mother ',
#  'so if you enter it expecting a comedy  probably you will not disappoint with what it delivers against your wish which is a heartwarming drama with some emotional moments ',
#  'surely recommended  especially the youngsters who re addicted to the digital world ',
#  'two thousand and twenty four eight ten zero zero zero',
#  'loved this movie from beggining to end ',
#  'i do not know  robert de niro seems too perfect to turn me off here ',
#  'really enjoyed this movie ',
#  'two thousand and twenty four ten ten zero zero zero',
#  'the intern is funny  charming  and heartwarming ',
#  'a movie about an older man that is retired going back into the outdoor world and getting a job as a intern in a young people work place is a great plot ',
#  'i thought this movie was going to be bad  but it was not ',
#  'however  towards the end of the movie it does get kind of boring ',
#  'overall  it is a great movie ',
#  'robert de niro s and anne hathaway s best movie yet ',
#  'two thumbs up ',
#  'i would very much suggest this movie ',
#  '    average i am internally grateful that you are taking a few minutes out of your day to read my cheesy review of writer director nancy meyers  comedy  the intern  ',
#  'i hope you make it through this puntership with flying colors ',
#  'anyways  the movie stars robert de niro as ben whittaker ',
#  'ben is a seventy year old widower who is living out retired days  but needs to fill a void ',
#  'he comes across an opportunity to be an intern in a senior citizens  internship program for a start up fashion online company ',
#  'anne hathaway co stars as jules  the founder of the company who at first is reluctant to work with an older crowd  but then takes a genuine liking to ben as not only a dependable intern  but a father figure ',
#  'of course  there are conflicts that are incorporated into the film that causes their relationship some challenges  and jules  own relationship with her husband ',
#  'i admired how meyers directed the first hour of the movie  but then it looked like  the intern  ran out of steam during the second half with too many elongated scenes  and that is why i could not give  the intern  a review promotion ',
#  'i did like de niro as ben  and hathaway as jules was not too shabby either ',
#  ' the intern  was two hours long  it did not have to be ',
#  'this intern could have done it is job in a sheer ninety minutes  but it stayed for not needed overtime  and for that i cannot highly recommend for you to hire  the intern  into your movie watch company ',
#  'it was a really good movie  a wholesome  not goofy dirty liberal trash heap ',
#  'it was just a good movie ',
#  'this is a film i liked it made me fell good and happy',
#  'as long as you do not really pay attention to the plot  it is a nice movie ',
#  'when watching the previews i was reluctant to watch this film because i thought the only possible story line was the older intern would end up dying ',
#  'this movie is nothing about that  instead it is adorable and probably one of my new favorite movies ',
#  'the ending is a little abrupt but overall i highly recommend it ',
#  'i actually enjoyed this movie ',
#  'robert di nero was fun  hilarious  and downright adorable ',
#  'i have always loved anne hathaway  and i thought she was great in the film ',
#  'the only part that annoyed me was the small husband cheating story ',
#  ...]

# %%
# remove japanese, korean, chinese words

def only_english(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    return cleaned_text

rm_punctionations = [only_english(text) for text in rm_punctionations]

# %%
# POS_tagging

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# 필요한 NLTK 데이터 다운로드
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Text를 단어 토큰과 POS 태그로 변환
def pos_tagging(text):
    word_tokens = word_tokenize(text)
    return pos_tag(word_tokens)

tag_sentence = rm_punctionations.copy()

tag_sentence = [pos_tagging(text) for text in tag_sentence]
# Out:
# [nltk_data] Downloading package punkt to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\seowoo kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
tag_sentence
# Out:
# [[('was', 'VBD'),
#   ('not', 'RB'),
#   ('what', 'WP'),
#   ('i', 'NN'),
#   ('expected', 'VBD')],
#  [('really', 'RB'), ('enjoyed', 'VBN'), ('it', 'PRP')],
#  [('including', 'VBG'),
#   ('the', 'DT'),
#   ('hope', 'NN'),
#   ('for', 'IN'),
#   ('redemption', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN')],
#  [('a', 'DT'),
#   ('true', 'JJ'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('movie', 'NN'),
#   ('that', 'IN'),
#   ('i', 'JJ'),
#   ('wish', 'VBP'),
#   ('i', 'NN'),
#   ('saw', 'NN'),
#   ('in', 'IN'),
#   ('theaters', 'NNS')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('and', 'CC'),
#   ('robert', 'NN'),
#   ('deniro', 'NN'),
#   ('have', 'VBP'),
#   ('great', 'JJ'),
#   ('chemistry', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('tells', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('story', 'NN'),
#   ('of', 'IN'),
#   ('two', 'CD'),
#   ('people', 'NNS'),
#   ('generations', 'NNS'),
#   ('apart', 'RB'),
#   ('growing', 'VBG'),
#   ('closer', 'RBR'),
#   ('and', 'CC'),
#   ('learning', 'VBG'),
#   ('from', 'IN'),
#   ('each', 'DT'),
#   ('other', 'JJ')],
#  [('there', 'EX'),
#   ('is', 'VBZ'),
#   ('strong', 'JJ'),
#   ('character', 'NN'),
#   ('development', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('solid', 'JJ'),
#   ('cast', 'NN'),
#   ('all', 'DT'),
#   ('around', 'IN')],
#  [('i', 'JJ'),
#   ('recommend', 'VBP'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('anyone', 'NN')],
#  [('all', 'PDT'),
#   ('the', 'DT'),
#   ('pieces', 'NNS'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('there', 'RB'),
#   ('except', 'IN'),
#   ('a', 'DT'),
#   ('truly', 'RB'),
#   ('appropriate', 'JJ'),
#   ('third', 'JJ'),
#   ('act', 'NN')],
#  [('the', 'DT'),
#   ('intern', 'NN'),
#   ('has', 'VBZ'),
#   ('chemistry', 'VBN'),
#   ('rich', 'JJ'),
#   ('lead', 'NN'),
#   ('performances', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('tenured', 'JJ'),
#   ('auteur', 'NN'),
#   ('behind', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN')],
#  [('brilliant', 'JJ'), ('movie', 'NN')],
#  [('so', 'RB'),
#   ('warm', 'JJ'),
#   ('so', 'IN'),
#   ('satisfying', 'JJ'),
#   ('and', 'CC'),
#   ('so', 'RB'),
#   ('moved', 'VBD')],
#  [('recommend', 'NN')],
#  [('these', 'DT'),
#   ('two', 'CD'),
#   ('bonified', 'VBD'),
#   ('great', 'JJ'),
#   ('actors', 'NNS'),
#   ('somehow', 'RB'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('chemistry', 'NN'),
#   ('that', 'WDT'),
#   ('truly', 'RB'),
#   ('makes', 'VBZ'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('worth', 'NN'),
#   ('watching', 'VBG')],
#  [('it', 'PRP'),
#   ('rushes', 'VBZ'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('along', 'IN'),
#   ('but', 'CC'),
#   ('that', 'IN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('take', 'VB'),
#   ('away', 'RP'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('heartwarming', 'VBG'),
#   ('affect', 'NN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('going', 'VBG'),
#   ('for', 'IN')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('good', 'JJ')],
#  [('i', 'NN'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('believe', 'VB'),
#   ('what', 'WP'),
#   ('other', 'JJ'),
#   ('critics', 'NNS'),
#   ('are', 'VBP'),
#   ('rating', 'NN'),
#   ('and', 'CC'),
#   ('saying', 'VBG'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('two', 'CD'),
#   ('legendary', 'JJ'),
#   ('actors', 'NNS'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('script', 'NN')],
#  [('good', 'JJ'),
#   ('film', 'NN'),
#   ('overall', 'JJ'),
#   ('loved', 'VBD'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('who', 'WP'),
#   ('fit', 'VBP'),
#   ('the', 'DT'),
#   ('role', 'NN'),
#   ('really', 'RB'),
#   ('well', 'RB')],
#  [('the', 'DT'),
#   ('story', 'NN'),
#   ('was', 'VBD'),
#   ('pretty', 'RB'),
#   ('standard', 'JJ'),
#   ('stuff', 'NN'),
#   ('however', 'RB'),
#   ('fun', 'VBZ'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('and', 'CC'),
#   ('something', 'NN'),
#   ('to', 'TO'),
#   ('take', 'VB'),
#   ('away', 'RP')],
#  [('very', 'RB'),
#   ('entertaining', 'JJ'),
#   ('movie', 'NN'),
#   ('for', 'IN'),
#   ('when', 'WRB'),
#   ('you', 'PRP'),
#   ('just', 'RB'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('time', 'NN')],
#  [('i', 'NN'),
#   ('really', 'RB'),
#   ('enjoyed', 'VBD'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT')],
#  [('thought', 'VBN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('really', 'RB'),
#   ('nailed', 'VBN'),
#   ('his', 'PRP$'),
#   ('part', 'NN'),
#   ('he', 'PRP'),
#   ('was', 'VBD'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('top', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('game', 'NN')],
#  [('well', 'RB'),
#   ('worth', 'IN'),
#   ('a', 'DT'),
#   ('watch', 'NN'),
#   ('although', 'IN'),
#   ('i', 'NN'),
#   ('wished', 'VBD'),
#   ('a', 'DT'),
#   ('couple', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('endings', 'NNS'),
#   ('went', 'VBD'),
#   ('a', 'DT'),
#   ('different', 'JJ'),
#   ('way', 'NN')],
#  [('a', 'DT'),
#   ('gentle', 'JJ'),
#   ('film', 'NN'),
#   ('with', 'IN'),
#   ('low', 'JJ'),
#   ('stakes', 'NNS'),
#   ('and', 'CC'),
#   ('surface', 'NN'),
#   ('level', 'NN'),
#   ('lessons', 'NNS'),
#   ('values', 'NNS')],
#  [('beautifully', 'RB'),
#   ('shot', 'JJ'),
#   ('and', 'CC'),
#   ('well', 'RB'),
#   ('acted', 'VBN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('lacks', 'VBZ'),
#   ('depth', 'NN')],
#  [('de', 'IN'),
#   ('niro', 'FW'),
#   ('and', 'CC'),
#   ('hathaway', 'RB'),
#   ('s', 'JJ'),
#   ('mad', 'NN'),
#   ('acting', 'VBG'),
#   ('skills', 'NNS'),
#   ('manage', 'NN'),
#   ('to', 'TO'),
#   ('raise', 'VB'),
#   ('an', 'DT'),
#   ('otherwise', 'RB'),
#   ('boring', 'JJ'),
#   ('film', 'NN'),
#   ('to', 'TO'),
#   ('very', 'RB'),
#   ('nearly', 'RB'),
#   ('interesting', 'JJ')],
#  [('odd', 'NN'),
#   ('that', 'IN'),
#   ('in', 'IN'),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('hathaway', 'NN'),
#   ('s', 'JJ'),
#   ('meetings', 'NNS'),
#   ('she', 'PRP'),
#   ('never', 'RB'),
#   ('one', 'CD'),
#   ('considered', 'VBD'),
#   ('hiring', 'VBG'),
#   ('a', 'DT'),
#   ('female', 'JJ'),
#   ('ceo', 'NN')],
#  [('sadly', 'RB'),
#   ('the', 'DT'),
#   ('successful', 'JJ'),
#   ('entrepreneur', 'NN'),
#   ('will', 'MD'),
#   ('continue', 'VB'),
#   ('burning', 'VBG'),
#   ('themself', 'PRP'),
#   ('out', 'RP'),
#   ('because', 'IN'),
#   ('they', 'PRP'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('let', 'VB'),
#   ('go', 'VB'),
#   ('and', 'CC'),
#   ('struggle', 'VB'),
#   ('to', 'TO'),
#   ('delegate', 'VB'),
#   ('unless', 'IN'),
#   ('a', 'DT'),
#   ('flawless', 'JJ'),
#   ('person', 'NN'),
#   ('who', 'WP'),
#   ('always', 'RB'),
#   ('says', 'VBZ'),
#   ('the', 'DT'),
#   ('right', 'JJ'),
#   ('things', 'NNS'),
#   ('magically', 'RB'),
#   ('shows', 'VBZ'),
#   ('up', 'RP')],
#  [('o', 'JJ'),
#   ('filme', 'NN'),
#   ('at', 'IN'),
#   ('que', 'JJ'),
#   ('bom', 'NN'),
#   ('bastante', 'NN'),
#   ('divertido', 'NN')],
#  [('mas', 'NN'),
#   ('o', 'MD'),
#   ('final', 'JJ'),
#   ('n', 'NN'),
#   ('o', 'NN'),
#   ('fez', 'NN'),
#   ('nenhum', 'JJ'),
#   ('sentido', 'NN'),
#   ('filme', 'NN'),
#   ('bem', 'NN'),
#   ('sess', 'NN'),
#   ('o', 'IN'),
#   ('da', 'NN'),
#   ('tarde', 'NN'),
#   ('mesmo', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('one', 'CD'),
#   ('to', 'TO'),
#   ('just', 'RB'),
#   ('throw', 'VB'),
#   ('on', 'IN'),
#   ('and', 'CC'),
#   ('enjoy', 'VB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('usually', 'RB'),
#   ('not', 'RB'),
#   ('my', 'PRP$'),
#   ('type', 'NN'),
#   ('of', 'IN'),
#   ('movie', 'NN'),
#   ('but', 'CC'),
#   ('i', 'JJ'),
#   ('quite', 'RB'),
#   ('enjoyed', 'VBD'),
#   ('the', 'DT'),
#   ('duo', 'NN'),
#   ('onscreen', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('lessons', 'NNS'),
#   ('you', 'PRP'),
#   ('learn', 'VBP'),
#   ('along', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN')],
#  [('if', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('film', 'NN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('it', 'PRP')],
#  [('a', 'DT'),
#   ('fantastic', 'JJ'),
#   ('cast', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('compelling', 'JJ'),
#   ('story', 'NN')],
#  [('we', 'PRP'),
#   ('all', 'DT'),
#   ('know', 'VBP'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('spread', 'VB'),
#   ('ourselves', 'PRP'),
#   ('too', 'RB'),
#   ('thin', 'JJ'),
#   ('and', 'CC'),
#   ('feel', 'VB'),
#   ('like', 'IN'),
#   ('an', 'DT'),
#   ('outsider', 'NN')],
#  [('learn', 'VB'),
#   ('something', 'NN'),
#   ('about', 'IN'),
#   ('work', 'NN'),
#   ('life', 'NN'),
#   ('balance', 'NN'),
#   ('and', 'CC'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('fit', 'VB'),
#   ('in', 'IN'),
#   ('by', 'IN'),
#   ('being', 'VBG'),
#   ('yourself', 'PRP')],
#  [('i', 'NN'),
#   ('came', 'VBD'),
#   ('across', 'IN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('wholesome', 'JJ'),
#   ('movie', 'NN'),
#   ('that', 'WDT'),
#   ('would', 'MD'),
#   ('make', 'VB'),
#   ('me', 'PRP'),
#   ('regain', 'VB'),
#   ('some', 'DT'),
#   ('sort', 'NN'),
#   ('of', 'IN'),
#   ('faith', 'NN'),
#   ('in', 'IN'),
#   ('humanity', 'NN')],
#  [('for', 'IN'),
#   ('the', 'DT'),
#   ('most', 'JJS'),
#   ('part', 'NN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('delivered', 'VBD')],
#  [('i', 'NN'),
#   ('am', 'VBP'),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('i', 'NNS'),
#   ('agree', 'VBP'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('decision', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('but', 'CC'),
#   ('that', 'DT'),
#   ('was', 'VBD'),
#   ('her', 'PRP$'),
#   ('decision', 'NN'),
#   ('i', 'NN'),
#   ('guess', 'NN')],
#  [('idk', 'VB'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('half', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('wholesome', 'JJ'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('got', 'VBD'),
#   ('messy', 'JJ'),
#   ('towards', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN')],
#  [('but', 'CC'),
#   ('i', 'JJ'),
#   ('guess', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('life', 'NN'),
#   ('messy', 'NN')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('terrible', 'JJ'),
#   ('movie', 'NN'),
#   ('with', 'IN'),
#   ('an', 'DT'),
#   ('awful', 'JJ'),
#   ('message', 'NN')],
#  [('the', 'DT'),
#   ('only', 'JJ'),
#   ('pro', 'FW'),
#   ('i', 'FW'),
#   ('give', 'VBP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('feminism', 'NN'),
#   ('behind', 'IN'),
#   ('showing', 'VBG'),
#   ('that', 'IN'),
#   ('women', 'NNS'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('on', 'IN'),
#   ('top', 'JJ'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('done', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('disgraceful', 'JJ'),
#   ('way', 'NN')],
#  [('hathaway', 'RB'),
#   ('s', 'JJ'),
#   ('character', 'NN'),
#   ('is', 'VBZ'),
#   ('out', 'RP'),
#   ('is', 'VBZ'),
#   ('control', 'VB'),
#   ('clearly', 'RB'),
#   ('not', 'RB'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('handle', 'VB'),
#   ('a', 'DT'),
#   ('growing', 'VBG'),
#   ('company', 'NN'),
#   ('completely', 'RB'),
#   ('oblivious', 'JJ'),
#   ('of', 'IN'),
#   ('tech', 'NN'),
#   ('like', 'IN'),
#   ('not', 'RB'),
#   ('using', 'VBG'),
#   ('email', 'VB'),
#   ('recall', 'NN'),
#   ('and', 'CC'),
#   ('sinking', 'VBG'),
#   ('it', 'PRP'),
#   ('even', 'RB'),
#   ('more', 'RBR'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('power', 'NN'),
#   ('trip', 'NN'),
#   ('of', 'IN'),
#   ('not', 'RB'),
#   ('having', 'VBG'),
#   ('a', 'DT'),
#   ('boss', 'NN')],
#  [('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('shaming', 'VBG'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('generation', 'NN'),
#   ('of', 'IN'),
#   ('men', 'NNS'),
#   ('and', 'CC'),
#   ('glorifying', 'VBG'),
#   ('the', 'DT'),
#   ('boomers', 'NNS')],
#  [('extremely', 'RB'),
#   ('capitalist', 'JJ'),
#   ('and', 'CC'),
#   ('pro', 'JJ'),
#   ('destroying', 'VBG'),
#   ('everything', 'NN'),
#   ('around', 'IN'),
#   ('you', 'PRP'),
#   ('for', 'IN'),
#   ('your', 'PRP$'),
#   ('job', 'NN')],
#  [('wtf', 'NN'),
#   ('with', 'IN'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('bars', 'VB'),
#   ('with', 'IN'),
#   ('employees', 'NNS'),
#   ('which', 'WDT'),
#   ('you', 'PRP'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('their', 'PRP$'),
#   ('name', 'NN'),
#   ('because', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('too', 'RB'),
#   ('powerful', 'JJ'),
#   ('instead', 'RB'),
#   ('of', 'IN'),
#   ('going', 'VBG'),
#   ('home', 'NN'),
#   ('and', 'CC'),
#   ('spend', 'JJ'),
#   ('time', 'NN'),
#   ('with', 'IN'),
#   ('your', 'PRP$'),
#   ('family', 'NN')],
#  [('the', 'DT'),
#   ('idea', 'NN'),
#   ('of', 'IN'),
#   ('feminism', 'NN'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('become', 'VB'),
#   ('better', 'RBR'),
#   ('collectively', 'RB'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('for', 'IN'),
#   ('women', 'NNS'),
#   ('to', 'TO'),
#   ('start', 'VB'),
#   ('acting', 'VBG'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('stereotypical', 'JJ'),
#   ('men', 'NNS')],
#  [('also', 'RB'),
#   ('sexual', 'JJ'),
#   ('harrassment', 'NN'),
#   ('is', 'VBZ'),
#   ('out', 'RP'),
#   ('there', 'RB'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('joke', 'NN'),
#   ('really', 'RB')],
#  [('is', 'VBZ'),
#   ('it', 'PRP'),
#   ('ok', 'RB'),
#   ('because', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('done', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('guy', 'NN')],
#  [('special', 'JJ'),
#   ('effects', 'NNS'),
#   ('one', 'CD'),
#   ('zero', 'CD'),
#   ('sound', 'NN'),
#   ('effects', 'NNS'),
#   ('one', 'CD'),
#   ('zero', 'CD'),
#   ('acting', 'VBG'),
#   ('one', 'CD'),
#   ('zero', 'CD'),
#   ('story', 'NN'),
#   ('two', 'CD'),
#   ('zero', 'NN')],
#  [('just', 'RB'),
#   ('a', 'DT'),
#   ('classic', 'JJ'),
#   ('pulls', 'NNS'),
#   ('at', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('good', 'JJ'),
#   ('heartstrings', 'NNS'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('duo', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('well', 'RB'),
#   ('written', 'VBN'),
#   ('the', 'DT'),
#   ('characters', 'NNS'),
#   ('are', 'VBP'),
#   ('all', 'DT'),
#   ('adorable', 'JJ')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('funny', 'JJ'),
#   ('and', 'CC'),
#   ('sad', 'JJ'),
#   ('suspenseful', 'NN'),
#   ('and', 'CC'),
#   ('action', 'NN'),
#   ('packed', 'VBD')],
#  [('what', 'WP'), ('could', 'MD'), ('be', 'VB'), ('better', 'JJR')],
#  [('like', 'IN'), ('it', 'PRP')],
#  [('i', 'JJ'),
#   ('bit', 'NN'),
#   ('long', 'JJ'),
#   ('but', 'CC'),
#   ('good', 'JJ'),
#   ('story', 'NN')],
#  [('why', 'WRB'),
#   ('whyyy', 'NN'),
#   ('is', 'VBZ'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('not', 'RB'),
#   ('rated', 'VBN'),
#   ('above', 'IN'),
#   ('ninety', 'NN')],
#  [],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('one', 'CD'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('kind', 'NN')],
#  [('so', 'RB'),
#   ('fresh', 'JJ'),
#   ('warm', 'NN'),
#   ('cozy', 'NN'),
#   ('and', 'CC'),
#   ('positive', 'JJ')],
#  [('it', 'PRP'),
#   ('somehow', 'RB'),
#   ('teaches', 'VBZ'),
#   ('way', 'NN'),
#   ('of', 'IN'),
#   ('living', 'NN')],
#  [('i', 'NN'),
#   ('always', 'RB'),
#   ('go', 'VBP'),
#   ('hopeful', 'JJ'),
#   ('happy', 'JJ'),
#   ('and', 'CC'),
#   ('content', 'NN'),
#   ('after', 'IN'),
#   ('watching', 'VBG'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('a', 'DT'), ('definitely', 'RB'), ('must', 'MD'), ('watch', 'VB')],
#  [],
#  [('very', 'RB'),
#   ('beautiful', 'JJ'),
#   ('well', 'RB'),
#   ('written', 'VBN'),
#   ('movie', 'NN')],
#  [('hats', 'NNS'),
#   ('off', 'VBP'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('creator', 'NN')],
#  [('the', 'DT'),
#   ('tell', 'NN'),
#   ('phone', 'NN'),
#   ('rings', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('background', 'NN'),
#   ('heart', 'NN'),
#   ('thought', 'VBD'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('my', 'PRP$'),
#   ('stalking', 'JJ'),
#   ('baby', 'NN'),
#   ('mama', 'NN'),
#   ('had', 'VBD'),
#   ('to', 'TO'),
#   ('quit', 'VB'),
#   ('immediatly', 'RB')],
#  [('it', 'PRP'),
#   ('makes', 'VBZ'),
#   ('me', 'PRP'),
#   ('feel', 'VB'),
#   ('warm', 'JJ'),
#   ('and', 'CC'),
#   ('cozy', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('chest', 'NN'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('nostalgic', 'JJ'),
#   ('feeling', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('sweetest', 'JJS'),
#   ('you', 'PRP'),
#   ('will', 'MD'),
#   ('ever', 'RB'),
#   ('watch', 'VB')],
#  [('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('both', 'CC'),
#   ('the', 'DT'),
#   ('comedy', 'NN'),
#   ('and', 'CC'),
#   ('drama', 'NN'),
#   ('as', 'RB'),
#   ('well', 'RB'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('really', 'RB'),
#   ('sweet', 'JJ'),
#   ('story', 'NN')],
#  [('overall', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('an', 'DT'),
#   ('awsome', 'JJ'),
#   ('movie', 'NN')],
#  [('if', 'IN'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('simply', 'RB'),
#   ('smile', 'VB'),
#   ('for', 'IN'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('straight', 'VBD'),
#   ('go', 'VB'),
#   ('ahead', 'RB'),
#   ('and', 'CC'),
#   ('watch', 'VB'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('i', 'NNS'),
#   ('have', 'VBP'),
#   ('zero', 'CD'),
#   ('clue', 'NN'),
#   ('why', 'WRB'),
#   ('anyone', 'NN'),
#   ('would', 'MD'),
#   ('rated', 'VB'),
#   ('this', 'DT'),
#   ('under', 'IN'),
#   ('five', 'CD'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('comedy', 'NN'),
#   ('drama', 'NN')],
#  [('the', 'DT'),
#   ('chemistry', 'NN'),
#   ('between', 'IN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('is', 'VBZ'),
#   ('tremendous', 'JJ')],
#  [('i', 'NN'),
#   ('bought', 'VBD'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('thing', 'NN'),
#   ('and', 'CC'),
#   ('somehow', 'NN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('actually', 'RB'),
#   ('a', 'DT'),
#   ('decent', 'JJ'),
#   ('premise', 'NN'),
#   ('and', 'CC'),
#   ('storyline', 'NN')],
#  [('simple', 'NN'), ('but', 'CC'), ('sweet', 'JJ')],
#  [('i', 'NN'),
#   ('would', 'MD'),
#   ('been', 'VBN'),
#   ('having', 'VBG'),
#   ('a', 'DT'),
#   ('terrible', 'JJ'),
#   ('week', 'NN'),
#   ('where', 'WRB'),
#   ('everything', 'NN'),
#   ('has', 'VBZ'),
#   ('gone', 'VBN'),
#   ('wrong', 'JJ'),
#   ('and', 'CC'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('on', 'IN'),
#   ('tv', 'NN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('hotel', 'NN'),
#   ('room', 'NN'),
#   ('and', 'CC'),
#   ('helped', 'VBD'),
#   ('to', 'TO'),
#   ('distract', 'VB'),
#   ('me', 'PRP'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('bit', 'NN')],
#  [('i', 'NN'),
#   ('found', 'VBD'),
#   ('myself', 'PRP'),
#   ('smiling', 'VBG'),
#   ('at', 'IN'),
#   ('some', 'DT'),
#   ('parts', 'NNS'),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('overall', 'JJ'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('movie', 'NN')],
#  [('deniro', 'NN'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('have', 'VBP'),
#   ('good', 'JJ'),
#   ('chemistry', 'NN'),
#   ('here', 'RB'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('overall', 'JJ'),
#   ('emotional', 'JJ'),
#   ('tone', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('mushy', 'JJ'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('feels', 'NNS'),
#   ('manipulative', 'VBP')],
#  [('deniro', 'NN'),
#   ('s', 'JJ'),
#   ('character', 'NN'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('good', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('true', 'JJ')],
#  [('because', 'IN'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('deniro', 'IN'),
#   ('he', 'PRP'),
#   ('can', 'MD'),
#   ('almost', 'RB'),
#   ('get', 'VB'),
#   ('away', 'RP'),
#   ('with', 'IN'),
#   ('it', 'PRP')],
#  [('the', 'DT'),
#   ('messages', 'NNS'),
#   ('about', 'IN'),
#   ('social', 'JJ'),
#   ('and', 'CC'),
#   ('gender', 'JJ'),
#   ('roles', 'NNS'),
#   ('seem', 'VBP'),
#   ('overly', 'RB'),
#   ('simplified', 'VBN'),
#   ('and', 'CC'),
#   ('sort', 'NN'),
#   ('of', 'IN'),
#   ('muddy', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('time', 'NN')],
#  [('worth', 'IN'),
#   ('the', 'DT'),
#   ('attempt', 'NN'),
#   ('but', 'CC'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('quite', 'RB'),
#   ('pull', 'VB'),
#   ('it', 'PRP'),
#   ('off', 'RP')],
#  [('serviceable', 'JJ')],
#  [('has', 'VBZ'),
#   ('a', 'DT'),
#   ('low', 'JJ'),
#   ('key', 'NN'),
#   ('feel', 'NN'),
#   ('to', 'TO'),
#   ('it', 'PRP')],
#  [('something', 'NN'),
#   ('about', 'IN'),
#   ('it', 'PRP'),
#   ('though', 'IN'),
#   ('brought', 'VBN'),
#   ('me', 'PRP'),
#   ('back', 'RB'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('it', 'PRP'),
#   ('again', 'RB')],
#  [('so', 'RB'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('something', 'NN'),
#   ('to', 'TO'),
#   ('it', 'PRP'),
#   ('although', 'IN'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('think', 'VB'),
#   ('it', 'PRP'),
#   ('ever', 'RB'),
#   ('really', 'RB'),
#   ('hit', 'VB'),
#   ('the', 'DT'),
#   ('mark', 'NN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('aiming', 'VBG'),
#   ('for', 'IN')],
#  [('cute', 'JJ'),
#   ('movie', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('well', 'RB'),
#   ('spent', 'VB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('have', 'VBP'),
#   ('nothing', 'NN'),
#   ('better', 'RBR'),
#   ('to', 'TO'),
#   ('do', 'VB')],
#  [('solid', 'JJ'), ('flick', 'NN')],
#  [('worth', 'IN'), ('a', 'DT'), ('watch', 'NN')],
#  [('def', 'NN'), ('fresh', 'NN')],
#  [('if', 'IN'),
#   ('you', 'PRP'),
#   ('don', 'VBP'),
#   ('t', 'JJ'),
#   ('vibe', 'NN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('charm', 'NN'),
#   ('nancy', 'NN'),
#   ('meyers', 'NNS'),
#   ('brings', 'VBZ'),
#   ('just', 'RB'),
#   ('move', 'VB'),
#   ('on', 'IN')],
#  [('very', 'RB'), ('boring', 'JJ')],
#  [('seemed', 'VBD'),
#   ('film', 'NN'),
#   ('was', 'VBD'),
#   ('more', 'RBR'),
#   ('interested', 'JJ'),
#   ('in', 'IN'),
#   ('creating', 'VBG'),
#   ('a', 'DT'),
#   ('statement', 'NN'),
#   ('than', 'IN'),
#   ('making', 'VBG'),
#   ('it', 'PRP'),
#   ('an', 'DT'),
#   ('enjoyable', 'JJ'),
#   ('film', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('makes', 'VBZ'),
#   ('people', 'NNS'),
#   ('emotional', 'JJ'),
#   ('and', 'CC'),
#   ('reminds', 'VBZ'),
#   ('us', 'PRP'),
#   ('of', 'IN'),
#   ('why', 'WRB'),
#   ('senior', 'JJ'),
#   ('people', 'NNS'),
#   ('are', 'VBP'),
#   ('still', 'RB'),
#   ('very', 'RB'),
#   ('important', 'JJ'),
#   ('in', 'IN'),
#   ('our', 'PRP$'),
#   ('society', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('makes', 'VBZ'),
#   ('such', 'PDT'),
#   ('an', 'DT'),
#   ('amazing', 'JJ'),
#   ('character', 'NN'),
#   ('that', 'WDT'),
#   ('actually', 'RB'),
#   ('makes', 'VBZ'),
#   ('me', 'PRP'),
#   ('feel', 'VB'),
#   ('calm', 'NNS'),
#   ('to', 'TO')],
#  [('anne', 'NN'),
#   ('hathway', 'NN'),
#   ('also', 'RB'),
#   ('makes', 'VBZ'),
#   ('an', 'DT'),
#   ('awsome', 'JJ'),
#   ('character', 'NN'),
#   ('power', 'NN'),
#   ('woman', 'NN'),
#   ('and', 'CC'),
#   ('rmaking', 'VBG'),
#   ('a', 'DT'),
#   ('refrence', 'NN'),
#   ('to', 'TO'),
#   ('working', 'VBG'),
#   ('moms', 'NNS'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('social', 'JJ'),
#   ('issue', 'NN'),
#   ('today', 'NN')],
#  [('the', 'DT'), ('plot', 'NN'), ('is', 'VBZ'), ('good', 'JJ')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('movie', 'NN'),
#   ('that', 'WDT'),
#   ('makes', 'VBZ'),
#   ('you', 'PRP'),
#   ('smile', 'JJ'),
#   ('and', 'CC'),
#   ('laught', 'VBD'),
#   ('a', 'DT'),
#   ('little', 'JJ')],
#  [('what', 'WP'),
#   ('a', 'DT'),
#   ('movie', 'NN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('i', 'RB'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('why', 'WRB'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('has', 'VBZ'),
#   ('low', 'JJ'),
#   ('rating', 'NN'),
#   ('but', 'CC'),
#   ('believe', 'VB'),
#   ('me', 'PRP'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('masterpiece', 'JJ'),
#   ('mood', 'NN'),
#   ('changer', 'NN')],
#  [('esta', 'JJ'),
#   ('pelicula', 'NN'),
#   ('da', 'NN'),
#   ('una', 'JJ'),
#   ('buena', 'NN'),
#   ('vibra', 'NN'),
#   ('con', 'NN'),
#   ('la', 'NN'),
#   ('quimica', 'FW'),
#   ('de', 'FW'),
#   ('sus', 'FW'),
#   ('talentos', 'NNS'),
#   ('protagonistas', 'NNS')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('old', 'JJ'),
#   ('but', 'CC'),
#   ('gold', 'NN')],
#  [('nancy', 'NN'),
#   ('meyer', 'NN'),
#   ('s', 'NNS'),
#   ('take', 'VBP'),
#   ('on', 'IN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('breath', 'NN'),
#   ('of', 'IN'),
#   ('air', 'NN')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('and', 'CC'),
#   ('robert', 'NN'),
#   ('deniro', 'NN'),
#   ('played', 'VBD'),
#   ('their', 'PRP$'),
#   ('characters', 'NNS'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('that', 'IN'),
#   ('made', 'VBD'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('more', 'RBR'),
#   ('interesting', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB')],
#  [('i', 'RB'),
#   ('love', 'VBP'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('the', 'DT'),
#   ('mix', 'NN'),
#   ('of', 'IN'),
#   ('old', 'JJ'),
#   ('and', 'CC'),
#   ('modern', 'JJ'),
#   ('references', 'NNS'),
#   ('is', 'VBZ'),
#   ('amazing', 'VBG')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('for', 'IN'),
#   ('those', 'DT'),
#   ('that', 'WDT'),
#   ('don', 'VBP'),
#   ('t', 'NNS'),
#   ('take', 'VB'),
#   ('life', 'NN'),
#   ('to', 'TO'),
#   ('seriously', 'RB'),
#   ('and', 'CC'),
#   ('are', 'VBP'),
#   ('just', 'RB'),
#   ('laid', 'VBN'),
#   ('back', 'RP')],
#  [('my', 'PRP$'),
#   ('therapist', 'JJ'),
#   ('metros', 'NNS'),
#   ('like', 'IN'),
#   ('film', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('too', 'RB'),
#   ('dark', 'JJ'),
#   ('knight', 'NN'),
#   ('esque', 'NN')],
#  [('will', 'MD'),
#   ('be', 'VB'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('all', 'DT'),
#   ('time', 'NN'),
#   ('classics', 'NNS'),
#   ('as', 'RB'),
#   ('good', 'JJ'),
#   ('as', 'IN'),
#   ('its', 'PRP$'),
#   ('a', 'DT'),
#   ('wonderful', 'JJ'),
#   ('life', 'NN'),
#   ('and', 'CC'),
#   ('others', 'NNS')],
#  [('what', 'WP'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('does', 'VBZ'),
#   ('is', 'VBZ'),
#   ('instil', 'VB'),
#   ('those', 'DT'),
#   ('good', 'JJ'),
#   ('old', 'JJ'),
#   ('values', 'NNS'),
#   ('and', 'CC'),
#   ('attributes', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('modern', 'JJ'),
#   ('digital', 'JJ'),
#   ('world', 'NN'),
#   ('mixed', 'VBD'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('emotions', 'NNS'),
#   ('of', 'IN'),
#   ('old', 'JJ'),
#   ('school', 'NN'),
#   ('gentleman', 'NN')],
#  [('a', 'DT'), ('golden', 'JJ'), ('future', 'NN'), ('classic', 'NN')],
#  [('great', 'JJ'),
#   ('movie', 'NN'),
#   ('it', 'PRP'),
#   ('shows', 'VBZ'),
#   ('different', 'JJ'),
#   ('story', 'NN'),
#   ('in', 'IN'),
#   ('one', 'CD'),
#   ('movie', 'NN')],
#  [('undemanding', 'VBG')],
#  [('pleasant', 'JJ'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('spend', 'VB'),
#   ('a', 'DT'),
#   ('couple', 'NN'),
#   ('of', 'IN'),
#   ('hours', 'NNS')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('so', 'RB'),
#   ('wholesome', 'JJ'),
#   ('and', 'CC'),
#   ('amazing', 'VBG'),
#   ('there', 'EX'),
#   ('were', 'VBD'),
#   ('times', 'NNS'),
#   ('i', 'JJ'),
#   ('almost', 'RB'),
#   ('cried', 'VBN'),
#   ('and', 'CC'),
#   ('alot', 'JJ'),
#   ('times', 'NNS'),
#   ('it', 'PRP'),
#   ('made', 'VBD'),
#   ('me', 'PRP'),
#   ('smile', 'VB')],
#  [('i', 'NN'),
#   ('had', 'VBD'),
#   ('chosen', 'VBN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('great', 'JJ'),
#   ('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('fan', 'NN')],
#  [('so', 'RB'),
#   ('obviously', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('sure', 'JJ'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('great', 'JJ')],
#  [('but', 'CC'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('watched', 'VBD'),
#   ('it', 'PRP'),
#   ('i', 'VBZ'),
#   ('found', 'VBD'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('fresh', 'JJ'),
#   ('watch', 'NN'),
#   ('something', 'NN'),
#   ('so', 'RB'),
#   ('subtle', 'JJ'),
#   ('but', 'CC'),
#   ('touching', 'VBG'),
#   ('with', 'IN'),
#   ('glimpses', 'NNS'),
#   ('of', 'IN'),
#   ('laughs', 'NNS')],
#  [('the', 'DT'),
#   ('thing', 'NN'),
#   ('which', 'WDT'),
#   ('touched', 'VBD'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('performances', 'NNS'),
#   ('of', 'IN'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('and', 'CC'),
#   ('anne', 'VB'),
#   ('hathaway', 'NN')],
#  [('specially', 'RB'),
#   ('that', 'DT'),
#   ('moment', 'NN'),
#   ('when', 'WRB'),
#   ('they', 'PRP'),
#   ('both', 'DT'),
#   ('work', 'VBP'),
#   ('late', 'JJ'),
#   ('night', 'NN'),
#   ('and', 'CC'),
#   ('he', 'PRP'),
#   ('says', 'VBZ'),
#   ('he', 'PRP'),
#   ('used', 'VBD'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('spot', 'NN'),
#   ('years', 'NNS'),
#   ('ago', 'RB')],
#  [('must', 'MD'), ('watch', 'VB'), ('movie', 'NN')],
#  [('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('movie', 'NN')],
#  [('the', 'DT'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('the', 'DT'),
#   ('music', 'NN'),
#   ('is', 'VBZ'),
#   ('beautiful', 'JJ')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('plays', 'VBZ'),
#   ('a', 'DT'),
#   ('wonderful', 'JJ'),
#   ('character', 'NN')],
#  [('to', 'TO'), ('watch', 'VB')],
#  [('less', 'RBR'),
#   ('about', 'IN'),
#   ('what', 'WP'),
#   ('is', 'VBZ'),
#   ('said', 'VBD')],
#  [('more', 'RBR'),
#   ('about', 'IN'),
#   ('how', 'WRB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('said', 'VBD')],
#  [('simple', 'JJ'),
#   ('story', 'NN'),
#   ('where', 'WRB'),
#   ('the', 'DT'),
#   ('ending', 'VBG'),
#   ('is', 'VBZ'),
#   ('apparent', 'JJ'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('outset', 'NN')],
#  [('the', 'DT'),
#   ('point', 'NN'),
#   ('is', 'VBZ'),
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('film', 'NN'),
#   ('in', 'IN'),
#   ('watching', 'VBG'),
#   ('the', 'DT'),
#   ('plot', 'NN'),
#   ('unfold', 'JJ')],
#  [('nothing', 'NN'), ('deep', 'NN')],
#  [('nothing', 'NN'),
#   ('urging', 'VBG'),
#   ('you', 'PRP'),
#   ('to', 'TO'),
#   ('set', 'VB'),
#   ('a', 'DT'),
#   ('date', 'NN'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('it', 'PRP'),
#   ('again', 'RB')],
#  [('rather', 'RB'),
#   ('more', 'RBR'),
#   ('something', 'NN'),
#   ('about', 'IN'),
#   ('how', 'WRB'),
#   ('people', 'NNS'),
#   ('can', 'MD'),
#   ('feel', 'VB')],
#  [('interactions', 'NNS')],
#  [('we', 'PRP'),
#   ('all', 'DT'),
#   ('know', 'VBP'),
#   ('about', 'IN'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('takes', 'VBZ'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('a', 'DT'),
#   ('winning', 'NN'),
#   ('production', 'NN'),
#   ('together', 'RB')],
#  [('good', 'JJ'), ('writing', 'NN')],
#  [('good', 'JJ'), ('acting', 'NN')],
#  [('and', 'CC'), ('all', 'PDT'), ('the', 'DT'), ('rest', 'NN')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('no', 'DT'),
#   ('gone', 'VBN'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('wind', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('show', 'NN'),
#   ('about', 'IN')],
#  [('about', 'IN'), ('people', 'NNS')],
#  [('nothing', 'NN'), ('more', 'RBR')],
#  [('and', 'CC'),
#   ('you', 'PRP'),
#   ('wind', 'VBP'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('pleased', 'JJ'),
#   ('smile', 'NN')],
#  [('pick', 'VB'),
#   ('your', 'PRP$'),
#   ('own', 'JJ'),
#   ('person', 'NN'),
#   ('to', 'TO'),
#   ('identify', 'VB'),
#   ('with', 'IN')],
#  [('i', 'NN'),
#   ('am', 'VBP'),
#   ('older', 'JJR'),
#   ('so', 'RB'),
#   ('deniro', 'JJ'),
#   ('is', 'VBZ'),
#   ('for', 'IN'),
#   ('me', 'PRP')],
#  [('taught', 'IN'),
#   ('me', 'PRP'),
#   ('the', 'DT'),
#   ('value', 'NN'),
#   ('of', 'IN'),
#   ('keeping', 'VBG'),
#   ('my', 'PRP$'),
#   ('mouth', 'NN'),
#   ('shut', 'VBD'),
#   ('more', 'RBR'),
#   ('often', 'RB')],
#  [('pays', 'NNS'), ('off', 'RP')],
#  [('perfect', 'JJ'), ('three', 'CD'), ('stars', 'NNS')],
#  [('i', 'NN'),
#   ('liked', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('from', 'IN'),
#   ('start', 'NN'),
#   ('to', 'TO'),
#   ('finish', 'VB')],
#  [('loved', 'VBD'),
#   ('the', 'DT'),
#   ('relationship', 'NN'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('intern', 'JJ'),
#   ('and', 'CC'),
#   ('jules', 'NNS'),
#   ('it', 'PRP'),
#   ('made', 'VBD'),
#   ('me', 'PRP'),
#   ('think', 'VB'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('proud', 'JJ'),
#   ('granddad', 'NN'),
#   ('who', 'WP'),
#   ('tries', 'VBZ'),
#   ('to', 'TO'),
#   ('help', 'VB'),
#   ('his', 'PRP$'),
#   ('niece', 'NN'),
#   ('out', 'RP')],
#  [('two', 'CD'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('spent', 'JJ'),
#   ('hours', 'NNS')],
#  [('enjoyed', 'VBN'),
#   ('deniro', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('in', 'IN'),
#   ('awhile', 'NN')],
#  [('loved', 'VBD'), ('the', 'DT'), ('burglary', 'NN'), ('sequence', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('comedy', 'NN'),
#   ('movie', 'NN'),
#   ('a', 'DT'),
#   ('very', 'RB'),
#   ('decent', 'JJ'),
#   ('movie', 'NN')],
#  [('did', 'VBD'), ('enjoy', 'VB'), ('it', 'PRP')],
#  [('seven', 'CD'), ('five', 'CD'), ('ten', 'NNS')],
#  [('very', 'RB'),
#   ('lame', 'JJ'),
#   ('movie', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('acting', 'NN'),
#   ('was', 'VBD'),
#   ('forced', 'VBN'),
#   ('in', 'IN'),
#   ('most', 'JJS'),
#   ('scenes', 'NNS')],
#  [('not', 'RB'), ('recommended', 'VBN')],
#  [('a', 'DT'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('dramedy', 'NN'),
#   ('which', 'WDT'),
#   ('although', 'IN'),
#   ('drawn', 'NN'),
#   ('out', 'IN'),
#   ('in', 'IN'),
#   ('places', 'NNS'),
#   ('has', 'VBZ'),
#   ('its', 'PRP$'),
#   ('moments', 'NNS'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('bound', 'VBN'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('you', 'PRP'),
#   ('smile', 'VB')],
#  [('i', 'NN'),
#   ('am', 'VBP'),
#   ('surprised', 'VBN'),
#   ('the', 'DT'),
#   ('critics', 'NNS'),
#   ('gave', 'VBD'),
#   ('this', 'DT'),
#   ('one', 'CD'),
#   ('such', 'JJ'),
#   ('poor', 'JJ'),
#   ('ratings', 'NNS')],
#  [('makes', 'VBZ'),
#   ('me', 'PRP'),
#   ('wonder', 'VB'),
#   ('if', 'IN'),
#   ('they', 'PRP'),
#   ('ever', 'RB'),
#   ('know', 'VBP'),
#   ('how', 'WRB'),
#   ('to', 'TO'),
#   ('enjoy', 'VB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('movie', 'NN')],
#  [('so', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('original', 'JJ'),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('raises', 'VBZ'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('issues', 'NNS'),
#   ('that', 'IN'),
#   ('we', 'PRP'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('agree', 'VB'),
#   ('on', 'IN'),
#   ('or', 'CC'),
#   ('whatever', 'WDT'),
#   ('but', 'CC'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('made', 'VBD'),
#   ('me', 'PRP'),
#   ('laugh', 'IN'),
#   ('then', 'RB'),
#   ('cry', 'NN'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('it', 'PRP'),
#   ('left', 'VBD'),
#   ('me', 'PRP'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('feeling', 'NN'),
#   ('of', 'IN'),
#   ('warmth', 'NN')],
#  [('i', 'RB'),
#   ('enjoyed', 'VBN'),
#   ('this', 'DT'),
#   ('so', 'RB'),
#   ('much', 'JJ')],
#  [('i', 'NN'),
#   ('used', 'VBN'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('movies', 'NNS'),
#   ('based', 'VBN'),
#   ('on', 'IN'),
#   ('critic', 'JJ'),
#   ('s', 'JJ'),
#   ('ratings', 'NNS'),
#   ('but', 'CC'),
#   ('now', 'RB'),
#   ('i', 'VBP'),
#   ('know', 'VBP'),
#   ('better', 'JJR')],
#  [('a', 'DT'),
#   ('touching', 'JJ'),
#   ('story', 'NN'),
#   ('with', 'IN'),
#   ('great', 'JJ'),
#   ('actors', 'NNS')],
#  [('awesome', 'NN')],
#  [('the', 'DT'),
#   ('script', 'NN'),
#   ('the', 'DT'),
#   ('acting', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('leads', 'VBZ'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('and', 'CC'),
#   ('how', 'WRB'),
#   ('much', 'JJ'),
#   ('you', 'PRP'),
#   ('feel', 'VBP'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('relationships', 'NNS'),
#   ('all', 'DT'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('done', 'VBN'),
#   ('except', 'IN'),
#   ('for', 'IN'),
#   ('anders', 'NNS'),
#   ('holm', 'VBP'),
#   ('acting', 'VBG')],
#  [('if', 'IN'),
#   ('jules', 'NNS'),
#   ('husband', 'VBP'),
#   ('was', 'VBD'),
#   ('played', 'VBN'),
#   ('by', 'IN'),
#   ('some', 'DT'),
#   ('actor', 'NN'),
#   ('with', 'IN'),
#   ('better', 'JJR'),
#   ('acting', 'VBG'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('stellar', 'JJ')],
#  [('anders', 'NNS'),
#   ('really', 'RB'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('make', 'VB'),
#   ('me', 'PRP'),
#   ('connect', 'VB'),
#   ('with', 'IN'),
#   ('or', 'CC'),
#   ('feel', 'VB'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('husband', 'NN'),
#   ('at', 'IN'),
#   ('all', 'DT')],
#  [('his', 'PRP$'),
#   ('face', 'NN'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('ninety', 'NN'),
#   ('nine', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('on', 'IN'),
#   ('screen', 'NN')],
#  [('anyhow', 'NN'),
#   ('still', 'RB'),
#   ('a', 'DT'),
#   ('well', 'RB'),
#   ('executed', 'VBN'),
#   ('emotionally', 'RB'),
#   ('mature', 'RB'),
#   ('well', 'RB'),
#   ('written', 'VBN'),
#   ('movie', 'NN'),
#   ('to', 'TO'),
#   ('watch', 'VB')],
#  [('kudos', 'NNS'),
#   ('to', 'TO'),
#   ('robert', 'VB'),
#   ('deniro', 'NN'),
#   ('and', 'CC'),
#   ('anne', 'VB'),
#   ('hathaway', 'NN')],
#  [('at', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('i', 'NN'),
#   ('felt', 'VBD'),
#   ('good', 'JJ'),
#   ('but', 'CC'),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('while', 'NN'),
#   ('all', 'PDT'),
#   ('that', 'IN'),
#   ('cringe', 'NN'),
#   ('came', 'VBD'),
#   ('in', 'IN'),
#   ('and', 'CC'),
#   ('ruined', 'VBD'),
#   ('everything', 'NN')],
#  [('not', 'RB'),
#   ('so', 'RB'),
#   ('feel', 'VB'),
#   ('good', 'JJ'),
#   ('movie', 'NN')],
#  [('its', 'PRP$'), ('good', 'JJ')],
#  [('de', 'IN'),
#   ('niro', 'FW'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cool', 'JJ'),
#   ('in', 'IN'),
#   ('that', 'DT'),
#   ('movie', 'NN')],
#  [('la', 'NN'),
#   ('pel', 'FW'),
#   ('cula', 'NN'),
#   ('trata', 'NN'),
#   ('horrible', 'JJ'),
#   ('los', 'JJ'),
#   ('problemas', 'NN'),
#   ('de', 'IN'),
#   ('una', 'JJ'),
#   ('pareja', 'NN'),
#   ('al', 'NN'),
#   ('acordar', 'NN'),
#   ('sus', 'NN'),
#   ('propias', 'NN'),
#   ('metas', 'NNS'),
#   ('la', 'VBP'),
#   ('historia', 'NNS'),
#   ('es', 'VBP'),
#   ('mal', 'JJ'),
#   ('sima', 'NN'),
#   ('pero', 'NN'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('y', 'FW'),
#   ('anne', 'FW'),
#   ('hathaway', 'RB'),
#   ('no', 'DT'),
#   ('la', 'NN'),
#   ('vuelven', 'RB'),
#   ('aburrida', 'VBD')],
#  [('really', 'RB'),
#   ('enjoy', 'VB'),
#   ('watching', 'VBG'),
#   ('the', 'DT'),
#   ('movie', 'NN')],
#  [('love', 'VB'),
#   ('the', 'DT'),
#   ('performance', 'NN'),
#   ('of', 'IN'),
#   ('anne', 'NN'),
#   ('and', 'CC'),
#   ('robert', 'NN')],
#  [('why', 'WRB'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('great', 'JJ'),
#   ('reviews', 'NNS')],
#  [('worst', 'JJ'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('mr', 'FW'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('in', 'IN')],
#  [('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('to', 'TO'),
#   ('reflect', 'VB'),
#   ('a', 'DT'),
#   ('work', 'NN'),
#   ('place', 'NN'),
#   ('that', 'WDT'),
#   ('never', 'RB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('thousand', 'CD'),
#   ('years', 'NNS'),
#   ('would', 'MD'),
#   ('exist', 'VB')],
#  [('or', 'CC'),
#   ('am', 'VBP'),
#   ('i', 'JJ'),
#   ('just', 'RB'),
#   ('narrow', 'NN'),
#   ('minded', 'VBD')],
#  [('whatever', 'WDT'), ('terrible', 'JJ')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('just', 'RB'),
#   ('such', 'JJ'),
#   ('a', 'DT'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('always', 'RB'),
#   ('end', 'VBP'),
#   ('up', 'RP'),
#   ('so', 'RB'),
#   ('happy', 'JJ'),
#   ('after', 'IN'),
#   ('watching', 'VBG'),
#   ('it', 'PRP')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('ha', 'NN'),
#   ('trovato', 'NN'),
#   ('ormai', 'NN'),
#   ('casa', 'NN'),
#   ('in', 'IN'),
#   ('queste', 'NN'),
#   ('commedie', 'NN'),
#   ('in', 'IN'),
#   ('cui', 'NN'),
#   ('pu', 'NN'),
#   ('esprimere', 'RB'),
#   ('un', 'JJ'),
#   ('lato', 'NN'),
#   ('pi', 'NN'),
#   ('divertente', 'NN'),
#   ('di', 'FW'),
#   ('s', 'VBZ'),
#   ('a', 'DT'),
#   ('lungo', 'JJ'),
#   ('sovrastato', 'NN'),
#   ('da', 'NN'),
#   ('grandi', 'NN'),
#   ('performance', 'NN'),
#   ('drammatiche', 'NN')],
#  [('the', 'DT'),
#   ('intern', 'JJ'),
#   ('un', 'JJ'),
#   ('film', 'NN'),
#   ('piacevole', 'JJ'),
#   ('originale', 'NN'),
#   ('e', 'NN'),
#   ('con', 'NN'),
#   ('davvero', 'NN'),
#   ('pochi', 'NN'),
#   ('difetti', 'NN'),
#   ('lo', 'NN'),
#   ('si', 'NN'),
#   ('guarda', 'NN'),
#   ('con', 'NN'),
#   ('piacere', 'RB'),
#   ('dall', 'JJ'),
#   ('inizio', 'NN'),
#   ('alla', 'NN'),
#   ('fine', 'NN')],
#  [('magari', 'NN'),
#   ('sarebbe', 'NN'),
#   ('stato', 'NN'),
#   ('interessante', 'NN'),
#   ('completare', 'NN'),
#   ('la', 'FW'),
#   ('sceneggiatura', 'FW'),
#   ('con', 'NN'),
#   ('qualche', 'NN'),
#   ('personaggio', 'NN'),
#   ('di', 'NN'),
#   ('contorno', 'NN'),
#   ('pi', 'NN'),
#   ('interessante', 'VBZ'),
#   ('a', 'DT'),
#   ('tratti', 'JJ'),
#   ('si', 'NN'),
#   ('sente', 'NN'),
#   ('un', 'JJ'),
#   ('po', 'NN'),
#   ('la', 'NN'),
#   ('mancanza', 'NN')],
#  [('both', 'DT'),
#   ('the', 'DT'),
#   ('stars', 'NNS'),
#   ('acting', 'VBG'),
#   ('compliments', 'NNS'),
#   ('each', 'DT'),
#   ('other', 'JJ')],
#  [('a', 'DT'), ('very', 'RB'), ('enjoyable', 'JJ'), ('movie', 'NN')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('healing', 'VBG'),
#   ('me', 'PRP')],
#  [('i', 'NN'),
#   ('could', 'MD'),
#   ('see', 'VB'),
#   ('the', 'DT'),
#   ('importance', 'NN'),
#   ('of', 'IN'),
#   ('occupation', 'NN'),
#   ('at', 'IN'),
#   ('life', 'NN')],
#  [('do', 'VB'),
#   ('work', 'NN'),
#   ('because', 'IN'),
#   ('it', 'PRP'),
#   ('makes', 'VBZ'),
#   ('me', 'PRP'),
#   ('think', 'VB'),
#   ('of', 'IN'),
#   ('myself', 'PRP'),
#   ('with', 'IN'),
#   ('pride', 'NN'),
#   ('and', 'CC'),
#   ('self', 'PRP'),
#   ('esteem', 'VBP'),
#   ('rather', 'RB'),
#   ('to', 'TO'),
#   ('obsess', 'VB'),
#   ('over', 'IN'),
#   ('money', 'NN')],
#  [('a', 'DT'),
#   ('good', 'JJ'),
#   ('hearted', 'JJ'),
#   ('drama', 'NN'),
#   ('comedy', 'NN'),
#   ('that', 'WDT'),
#   ('entertains', 'VBZ'),
#   ('without', 'IN'),
#   ('becoming', 'VBG'),
#   ('overly', 'RB'),
#   ('sentimental', 'JJ')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('relaxing', 'JJ'),
#   ('watch', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('jako', 'NN'),
#   ('alfa', 'NN'),
#   ('i', 'NN'),
#   ('omega', 'VBP')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('my', 'PRP$'),
#   ('favorite', 'JJ'),
#   ('movie', 'NN'),
#   ('ever', 'RB'),
#   ('watch', 'VB'),
#   ('it', 'PRP')],
#  [],
#  [('one', 'CD'),
#   ('of', 'IN'),
#   ('nancy', 'NN'),
#   ('meyers', 'NNS'),
#   ('absolute', 'VBP'),
#   ('humane', 'NN'),
#   ('best', 'RBS'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('usual', 'JJ'),
#   ('charm', 'NN'),
#   ('turned', 'VBD'),
#   ('sweetness', 'RB'),
#   ('into', 'IN'),
#   ('something', 'NN'),
#   ('unexpectedly', 'RB'),
#   ('wholesomely', 'RB'),
#   ('heartening', 'VBG'),
#   ('benefitting', 'VBG'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('finely', 'RB'),
#   ('casted', 'JJ'),
#   ('chemistries', 'NNS'),
#   ('that', 'WDT'),
#   ('were', 'VBD'),
#   ('enough', 'RB'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('this', 'DT'),
#   ('hilarious', 'JJ'),
#   ('insightful', 'JJ'),
#   ('comedy', 'NN'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('films', 'NNS'),
#   ('in', 'IN'),
#   ('recent', 'JJ'),
#   ('memory', 'NN')],
#  [('a', 'DT')],
#  [('not', 'RB'),
#   ('even', 'RB'),
#   ('the', 'DT'),
#   ('inmense', 'NN'),
#   ('acting', 'VBG'),
#   ('chops', 'NNS'),
#   ('of', 'IN'),
#   ('deniro', 'NN'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('could', 'MD'),
#   ('save', 'VB'),
#   ('this', 'DT'),
#   ('film', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('lack', 'NN'),
#   ('of', 'IN'),
#   ('focus', 'NN'),
#   ('and', 'CC'),
#   ('story', 'NN')],
#  [('this', 'DT'),
#   ('isnt', 'VBZ'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('movie', 'NN'),
#   ('its', 'PRP$'),
#   ('just', 'RB'),
#   ('not', 'RB'),
#   ('interesting', 'JJ'),
#   ('or', 'CC'),
#   ('memorable', 'JJ')],
#  [('its', 'PRP$'), ('bland', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('fun', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('from', 'IN'),
#   ('beginning', 'VBG'),
#   ('til', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN')],
#  [('i', 'NNS'),
#   ('have', 'VBP'),
#   ('always', 'RB'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('fan', 'NN'),
#   ('of', 'IN'),
#   ('stories', 'NNS'),
#   ('about', 'IN'),
#   ('building', 'VBG'),
#   ('friendships', 'NNS'),
#   ('between', 'IN'),
#   ('young', 'JJ'),
#   ('and', 'CC'),
#   ('old', 'JJ'),
#   ('people', 'NNS'),
#   ('particularly', 'RB'),
#   ('in', 'IN'),
#   ('their', 'PRP$'),
#   ('exchange', 'NN'),
#   ('of', 'IN'),
#   ('wisdom', 'NN'),
#   ('which', 'WDT'),
#   ('involves', 'VBZ'),
#   ('respect', 'VBP'),
#   ('mutual', 'JJ'),
#   ('admiration', 'NN'),
#   ('and', 'CC'),
#   ('compassion', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('story', 'NN')],
#  [('great', 'JJ'),
#   ('movie', 'NN'),
#   ('very', 'RB'),
#   ('wholesome', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB')],
#  [('the', 'DT'),
#   ('two', 'CD'),
#   ('stars', 'NNS'),
#   ('are', 'VBP'),
#   ('fantastic', 'JJ'),
#   ('and', 'CC'),
#   ('well', 'RB'),
#   ('matched', 'VBN'),
#   ('but', 'CC'),
#   ('hathaway', 'RB'),
#   ('s', 'JJ'),
#   ('character', 'NN'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('terrible', 'JJ'),
#   ('sexist', 'NN'),
#   ('arch', 'NN'),
#   ('that', 'WDT'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('defend', 'VB'),
#   ('men', 'NNS'),
#   ('cheating', 'VBG'),
#   ('on', 'IN'),
#   ('women', 'NNS'),
#   ('if', 'IN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('too', 'RB'),
#   ('impowered', 'JJ')],
#  [('mark', 'NN'),
#   ('zuckerberg', 'NN'),
#   ('never', 'RB'),
#   ('brought', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('ceo', 'NN'),
#   ('and', 'CC'),
#   ('he', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('teenager', 'NN')],
#  [('the', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('about', 'IN'),
#   ('love', 'JJ'),
#   ('life', 'NN'),
#   ('lessons', 'NNS'),
#   ('falls', 'NNS'),
#   ('and', 'CC'),
#   ('getups', 'NNS')],
#  [('surprisingly', 'RB'), ('touching', 'VBG'), ('and', 'CC'), ('happy', 'JJ')],
#  [('it', 'PRP'),
#   ('puts', 'VBZ'),
#   ('life', 'NN'),
#   ('feminism', 'NN'),
#   ('work', 'NN'),
#   ('marriage', 'NN'),
#   ('kids', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('table', 'NN'),
#   ('and', 'CC'),
#   ('discusses', 'VBZ'),
#   ('it', 'PRP')],
#  [('life', 'NN'),
#   ('lessons', 'NNS'),
#   ('are', 'VBP'),
#   ('demonstrated', 'VBN'),
#   ('naturally', 'RB'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('boring', 'JJ'),
#   ('way', 'NN')],
#  [('de', 'IN'),
#   ('niro', 'FW'),
#   ('still', 'RB'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('actor', 'NN')],
#  [('now', 'RB'),
#   ('older', 'JJR'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('doing', 'VBG'),
#   ('more', 'RBR'),
#   ('dramatic', 'JJ'),
#   ('movies', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('man', 'NN'),
#   ('still', 'RB'),
#   ('on', 'IN'),
#   ('fire', 'NN')],
#  [('some', 'DT'),
#   ('facial', 'JJ'),
#   ('expressions', 'NNS'),
#   ('are', 'VBP'),
#   ('his', 'PRP$'),
#   ('and', 'CC'),
#   ('no', 'DT'),
#   ('one', 'NN'),
#   ('else', 'RB'),
#   ('could', 'MD'),
#   ('ever', 'RB'),
#   ('do', 'VB'),
#   ('it', 'PRP')],
#  [('the', 'DT'),
#   ('chemistry', 'NN'),
#   ('he', 'PRP'),
#   ('got', 'VBD'),
#   ('with', 'IN'),
#   ('hathaway', 'NN'),
#   ('is', 'VBZ'),
#   ('touching', 'VBG'),
#   ('and', 'CC'),
#   ('happy', 'JJ')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('almost', 'RB'),
#   ('as', 'IN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('connected', 'VBN'),
#   ('with', 'IN'),
#   ('each', 'DT'),
#   ('other', 'JJ'),
#   ('and', 'CC'),
#   ('with', 'IN'),
#   ('you', 'PRP'),
#   ('and', 'CC'),
#   ('me', 'PRP')],
#  [('and', 'CC'), ('what', 'WP'), ('about', 'IN'), ('hathaway', 'NN')],
#  [('she', 'PRP'),
#   ('is', 'VBZ'),
#   ('gorgeous', 'JJ'),
#   ('frenetic', 'JJ'),
#   ('and', 'CC'),
#   ('as', 'RB'),
#   ('expressive', 'JJ'),
#   ('as', 'IN'),
#   ('de', 'IN'),
#   ('niro', 'NN')],
#  [('they', 'PRP'),
#   ('could', 'MD'),
#   ('do', 'VB'),
#   ('those', 'DT'),
#   ('scenes', 'NNS'),
#   ('without', 'IN'),
#   ('even', 'RB'),
#   ('talk', 'NN')],
#  [('the', 'DT'),
#   ('intern', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('slow', 'JJ'),
#   ('and', 'CC'),
#   ('tiring', 'VBG'),
#   ('narrative', 'JJ'),
#   ('the', 'DT'),
#   ('script', 'NN'),
#   ('barely', 'RB'),
#   ('moves', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('ending', 'VBG'),
#   ('is', 'VBZ'),
#   ('disappointing', 'VBG')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('sweet', 'JJ'),
#   ('and', 'CC'),
#   ('does', 'VBZ'),
#   ('a', 'DT'),
#   ('fantastic', 'JJ'),
#   ('job', 'NN'),
#   ('of', 'IN'),
#   ('building', 'VBG'),
#   ('the', 'DT'),
#   ('relationship', 'NN'),
#   ('between', 'IN'),
#   ('the', 'DT'),
#   ('two', 'CD'),
#   ('main', 'JJ'),
#   ('characters', 'NNS')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('movie', 'NN')],
#  [('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('the', 'DT'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('movie', 'NN'),
#   ('i', 'NN'),
#   ('like', 'IN'),
#   ('seeing', 'VBG'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('in', 'IN'),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('to', 'TO'),
#   ('admit', 'VB'),
#   ('him', 'PRP'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('are', 'VBP'),
#   ('very', 'RB'),
#   ('good', 'JJ'),
#   ('together', 'RB'),
#   ('in', 'IN'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('its', 'PRP$'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('quite', 'RB'),
#   ('clich', 'JJ'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('redeemed', 'VBN'),
#   ('thanks', 'NNS'),
#   ('to', 'TO'),
#   ('its', 'PRP$'),
#   ('modern', 'JJ'),
#   ('approach', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('chemistry', 'NN'),
#   ('of', 'IN'),
#   ('its', 'PRP$'),
#   ('leads', 'NNS')],
#  [('i', 'RB'), ('love', 'VBP'), ('this', 'DT'), ('movie', 'NN')],
#  [('i', 'NNS'),
#   ('have', 'VBP'),
#   ('seen', 'VBN'),
#   ('this', 'DT'),
#   ('several', 'JJ'),
#   ('times', 'NNS')],
#  [('it', 'PRP'),
# ...
#   ('with', 'IN'),
#   ('this', 'DT'),
#   ('story', 'NN'),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('runtime', 'NN'),
#   ('the', 'DT'),
#   ('pace', 'NN'),
#   ('was', 'VBD'),
#   ('incredible', 'JJ')],
#  [('when', 'WRB'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('something', 'NN'),
#   ('interesting', 'JJ'),
#   ('is', 'VBZ'),
#   ('going', 'VBG'),
#   ('on', 'IN'),
#   ('we', 'PRP'),
#   ('forget', 'VBP'),
#   ('to', 'TO'),
#   ('focus', 'VB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('flaws', 'NNS'),
#   ('and', 'CC'),
#   ('enjoy', 'VB'),
#   ('our', 'PRP$'),
#   ('time', 'NN'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('what', 'WP'),
#   ('i', 'VBZ'),
#   ('exactly', 'RB'),
#   ('did', 'VBD'),
#   ('in', 'IN'),
#   ('here', 'RB')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('comedy', 'NN'),
#   ('where', 'WRB'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('laugh', 'VB'),
#   ('openly', 'RB'),
#   ('loud', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('comedy', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('sense', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('set', 'NN'),
#   ('of', 'IN'),
#   ('characters', 'NNS'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('has', 'VBZ')],
#  [('i', 'JJ'),
#   ('mean', 'VBP'),
#   ('the', 'DT'),
#   ('story', 'NN'),
#   ('is', 'VBZ'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('digital', 'JJ'),
#   ('business', 'NN'),
#   ('and', 'CC'),
#   ('most', 'JJS'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   ('who', 'WP'),
#   ('are', 'VBP'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('computers', 'NNS'),
#   ('are', 'VBP'),
#   ('considered', 'VBN'),
#   ('as', 'IN'),
#   ('geeks', 'NNS')],
#  [('so', 'RB'),
#   ('theirs', 'JJ'),
#   ('world', 'NN'),
#   ('is', 'VBZ'),
#   ('nothing', 'NN'),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('hooked', 'VBN'),
#   ('to', 'TO'),
#   ('their', 'PRP$'),
#   ('works', 'NNS'),
#   ('and', 'CC'),
#   ('forgetting', 'VBG'),
#   ('the', 'DT'),
#   ('actual', 'JJ'),
#   ('world', 'NN'),
#   ('around', 'IN'),
#   ('them', 'PRP')],
#  [('even', 'RB'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('someone', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('next', 'JJ'),
#   ('room', 'NN'),
#   ('they', 'PRP'),
#   ('tweet', 'VBP')],
#  [('for', 'IN'),
#   ('them', 'PRP'),
#   ('to', 'TO'),
#   ('remind', 'VB'),
#   ('only', 'RB'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('changed', 'VBN'),
#   ('not', 'RB'),
#   ('the', 'DT'),
#   ('physical', 'JJ'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('that', 'DT'),
#   ('is', 'VBZ'),
#   ('where', 'WRB'),
#   ('our', 'PRP$'),
#   ('main', 'JJ'),
#   ('character', 'NN'),
#   ('who', 'WP'),
#   ('is', 'VBZ'),
#   ('old', 'JJ'),
#   ('and', 'CC'),
#   ('wise', 'JJ'),
#   ('influence', 'NN'),
#   ('the', 'DT'),
#   ('younger', 'JJR'),
#   ('generation', 'NN'),
#   ('people', 'NNS')],
#  [('so', 'RB'),
#   ('the', 'DT'),
#   ('actors', 'NNS'),
#   ('were', 'VBD'),
#   ('undoubtedly', 'RB'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('thing', 'NN'),
#   ('apart', 'RB'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('direction', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('story', 'NN')],
#  [('the', 'DT'),
#   ('seventy', 'NN'),
#   ('three', 'CD'),
#   ('years', 'NNS'),
#   ('old', 'JJ'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('still', 'RB'),
#   ('impressing', 'VBG'),
#   ('with', 'IN'),
#   ('his', 'PRP$'),
#   ('extraordinary', 'JJ'),
#   ('character', 'NN'),
#   ('display', 'NN')],
#  [('i', 'NNS'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('whoever', 'NN'),
#   ('was', 'VBD'),
#   ('in', 'IN'),
#   ('mind', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('written', 'VBN'),
#   ('but', 'CC'),
#   ('this', 'DT'),
#   ('role', 'NN'),
#   ('perfectly', 'RB'),
#   ('fits', 'VBZ'),
#   ('none', 'NN'),
#   ('other', 'JJ'),
#   ('than', 'IN'),
#   ('him', 'PRP')],
#  [('and', 'CC'),
#   ('then', 'RB'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('anne', 'JJ'),
#   ('hathaway', 'RB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('opposite', 'JJ'),
#   ('side', 'NN'),
#   ('who', 'WP'),
#   ('equaled', 'VBD'),
#   ('with', 'IN'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('part', 'NN')],
#  [('from', 'IN'),
#   ('the', 'DT'),
#   ('narration', 'NN'),
#   ('point', 'NN'),
#   ('of', 'IN'),
#   ('view', 'NN'),
#   ('it', 'PRP'),
#   ('started', 'VBD'),
#   ('with', 'IN'),
#   ('deniro', 'NN'),
#   ('s', 'NNS'),
#   ('but', 'CC'),
#   ('quickly', 'RB'),
#   ('around', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('middle', 'NN'),
#   ('it', 'PRP'),
#   ('took', 'VBD'),
#   ('a', 'DT'),
#   ('circle', 'NN'),
#   ('to', 'TO'),
#   ('cover', 'VB'),
#   ('others', 'NNS'),
#   ('as', 'IN'),
#   ('well', 'RB')],
#  [('and', 'CC'),
#   ('then', 'RB'),
#   ('comes', 'VBZ'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('professional', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('personal', 'JJ'),
#   ('life', 'NN'),
#   ('topic', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('developed', 'VBN'),
#   ('and', 'CC'),
#   ('brought', 'VBD'),
#   ('a', 'DT'),
#   ('small', 'JJ'),
#   ('family', 'NN'),
#   ('who', 'WP'),
#   ('were', 'VBD'),
#   ('affected', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('workaholic', 'NN'),
#   ('mother', 'NN')],
#  [('so', 'RB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('enter', 'VBP'),
#   ('it', 'PRP'),
#   ('expecting', 'VBG'),
#   ('a', 'DT'),
#   ('comedy', 'NN'),
#   ('probably', 'RB'),
#   ('you', 'PRP'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('disappoint', 'VB'),
#   ('with', 'IN'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('delivers', 'VBZ'),
#   ('against', 'IN'),
#   ('your', 'PRP$'),
#   ('wish', 'JJ'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('heartwarming', 'JJ'),
#   ('drama', 'NN'),
#   ('with', 'IN'),
#   ('some', 'DT'),
#   ('emotional', 'JJ'),
#   ('moments', 'NNS')],
#  [('surely', 'RB'),
#   ('recommended', 'VBN'),
#   ('especially', 'RB'),
#   ('the', 'DT'),
#   ('youngsters', 'NNS'),
#   ('who', 'WP'),
#   ('re', 'VBP'),
#   ('addicted', 'VBN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('digital', 'JJ'),
#   ('world', 'NN')],
#  [('two', 'CD'),
#   ('thousand', 'CD'),
#   ('and', 'CC'),
#   ('twenty', 'VB'),
#   ('four', 'CD'),
#   ('eight', 'CD'),
#   ('ten', 'NNS'),
#   ('zero', 'CD'),
#   ('zero', 'CD'),
#   ('zero', 'NN')],
#  [('loved', 'VBN'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('from', 'IN'),
#   ('beggining', 'VBG'),
#   ('to', 'TO'),
#   ('end', 'VB')],
#  [('i', 'NNS'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('know', 'VB'),
#   ('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('seems', 'VBZ'),
#   ('too', 'RB'),
#   ('perfect', 'JJ'),
#   ('to', 'TO'),
#   ('turn', 'VB'),
#   ('me', 'PRP'),
#   ('off', 'RP'),
#   ('here', 'RB')],
#  [('really', 'RB'), ('enjoyed', 'VBN'), ('this', 'DT'), ('movie', 'NN')],
#  [('two', 'CD'),
#   ('thousand', 'CD'),
#   ('and', 'CC'),
#   ('twenty', 'VB'),
#   ('four', 'CD'),
#   ('ten', 'NNS'),
#   ('ten', 'VBP'),
#   ('zero', 'CD'),
#   ('zero', 'NN'),
#   ('zero', 'NN')],
#  [('the', 'DT'),
#   ('intern', 'NN'),
#   ('is', 'VBZ'),
#   ('funny', 'JJ'),
#   ('charming', 'VBG'),
#   ('and', 'CC'),
#   ('heartwarming', 'VBG')],
#  [('a', 'DT'),
#   ('movie', 'NN'),
#   ('about', 'IN'),
#   ('an', 'DT'),
#   ('older', 'JJR'),
#   ('man', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('retired', 'VBN'),
#   ('going', 'VBG'),
#   ('back', 'RB'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('outdoor', 'JJ'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('getting', 'VBG'),
#   ('a', 'DT'),
#   ('job', 'NN'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('intern', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('young', 'JJ'),
#   ('people', 'NNS'),
#   ('work', 'VBP'),
#   ('place', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('plot', 'NN')],
#  [('i', 'NN'),
#   ('thought', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN'),
#   ('was', 'VBD'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('bad', 'JJ'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('not', 'RB')],
#  [('however', 'RB'),
#   ('towards', 'IN'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ('get', 'VB'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('boring', 'NN')],
#  [('overall', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('movie', 'NN')],
#  [('robert', 'NN'),
#   ('de', 'IN'),
#   ('niro', 'FW'),
#   ('s', 'NN'),
#   ('and', 'CC'),
#   ('anne', 'VB'),
#   ('hathaway', 'RB'),
#   ('s', 'JJ'),
#   ('best', 'JJS'),
#   ('movie', 'NN'),
#   ('yet', 'RB')],
#  [('two', 'CD'), ('thumbs', 'VBZ'), ('up', 'IN')],
#  [('i', 'NN'),
#   ('would', 'MD'),
#   ('very', 'RB'),
#   ('much', 'RB'),
#   ('suggest', 'VB'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('average', 'JJ'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('internally', 'RB'),
#   ('grateful', 'JJ'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('taking', 'VBG'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('minutes', 'NNS'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('your', 'PRP$'),
#   ('day', 'NN'),
#   ('to', 'TO'),
#   ('read', 'VB'),
#   ('my', 'PRP$'),
#   ('cheesy', 'JJ'),
#   ('review', 'NN'),
#   ('of', 'IN'),
#   ('writer', 'NN'),
#   ('director', 'NN'),
#   ('nancy', 'NN'),
#   ('meyers', 'NNS'),
#   ('comedy', 'VBP'),
#   ('the', 'DT'),
#   ('intern', 'NN')],
#  [('i', 'NNS'),
#   ('hope', 'VBP'),
#   ('you', 'PRP'),
#   ('make', 'VBP'),
#   ('it', 'PRP'),
#   ('through', 'IN'),
#   ('this', 'DT'),
#   ('puntership', 'NN'),
#   ('with', 'IN'),
#   ('flying', 'VBG'),
#   ('colors', 'NNS')],
#  [('anyways', 'VBZ'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('stars', 'VBZ'),
#   ('robert', 'FW'),
#   ('de', 'FW'),
#   ('niro', 'FW'),
#   ('as', 'IN'),
#   ('ben', 'NN'),
#   ('whittaker', 'NN')],
#  [('ben', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('seventy', 'JJ'),
#   ('year', 'NN'),
#   ('old', 'JJ'),
#   ('widower', 'NN'),
#   ('who', 'WP'),
#   ('is', 'VBZ'),
#   ('living', 'VBG'),
#   ('out', 'RP'),
#   ('retired', 'JJ'),
#   ('days', 'NNS'),
#   ('but', 'CC'),
#   ('needs', 'VBZ'),
#   ('to', 'TO'),
#   ('fill', 'VB'),
#   ('a', 'DT'),
#   ('void', 'NN')],
#  [('he', 'PRP'),
#   ('comes', 'VBZ'),
#   ('across', 'IN'),
#   ('an', 'DT'),
#   ('opportunity', 'NN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('intern', 'JJ'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('senior', 'JJ'),
#   ('citizens', 'NNS'),
#   ('internship', 'JJ'),
#   ('program', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('start', 'NN'),
#   ('up', 'RP'),
#   ('fashion', 'NN'),
#   ('online', 'NN'),
#   ('company', 'NN')],
#  [('anne', 'RB'),
#   ('hathaway', 'RB'),
#   ('co', 'JJ'),
#   ('stars', 'NNS'),
#   ('as', 'IN'),
#   ('jules', 'NNS'),
#   ('the', 'DT'),
#   ('founder', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('company', 'NN'),
#   ('who', 'WP'),
#   ('at', 'IN'),
#   ('first', 'JJ'),
#   ('is', 'VBZ'),
#   ('reluctant', 'JJ'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('an', 'DT'),
#   ('older', 'JJR'),
#   ('crowd', 'NN'),
#   ('but', 'CC'),
#   ('then', 'RB'),
#   ('takes', 'VBZ'),
#   ('a', 'DT'),
#   ('genuine', 'JJ'),
#   ('liking', 'NN'),
#   ('to', 'TO'),
#   ('ben', 'VB'),
#   ('as', 'IN'),
#   ('not', 'RB'),
#   ('only', 'RB'),
#   ('a', 'DT'),
#   ('dependable', 'JJ'),
#   ('intern', 'NN'),
#   ('but', 'CC'),
#   ('a', 'DT'),
#   ('father', 'NN'),
#   ('figure', 'NN')],
#  [('of', 'IN'),
#   ('course', 'NN'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('conflicts', 'NNS'),
#   ('that', 'WDT'),
#   ('are', 'VBP'),
#   ('incorporated', 'VBN'),
#   ('into', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN'),
#   ('that', 'WDT'),
#   ('causes', 'VBZ'),
#   ('their', 'PRP$'),
#   ('relationship', 'NN'),
#   ('some', 'DT'),
#   ('challenges', 'NNS'),
#   ('and', 'CC'),
#   ('jules', 'NNS'),
#   ('own', 'VBP'),
#   ('relationship', 'NN'),
#   ('with', 'IN'),
#   ('her', 'PRP$'),
#   ('husband', 'NN')],
#  [('i', 'NN'),
#   ('admired', 'VBD'),
#   ('how', 'WRB'),
#   ('meyers', 'NNS'),
#   ('directed', 'VBD'),
#   ('the', 'DT'),
#   ('first', 'JJ'),
#   ('hour', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('movie', 'NN'),
#   ('but', 'CC'),
#   ('then', 'RB'),
#   ('it', 'PRP'),
#   ('looked', 'VBD'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('intern', 'JJ'),
#   ('ran', 'VBD'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('steam', 'NN'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('half', 'NN'),
#   ('with', 'IN'),
#   ('too', 'RB'),
#   ('many', 'JJ'),
#   ('elongated', 'VBN'),
#   ('scenes', 'NNS'),
#   ('and', 'CC'),
#   ('that', 'DT'),
#   ('is', 'VBZ'),
#   ('why', 'WRB'),
#   ('i', 'NN'),
#   ('could', 'MD'),
#   ('not', 'RB'),
#   ('give', 'VB'),
#   ('the', 'DT'),
#   ('intern', 'NN'),
#   ('a', 'DT'),
#   ('review', 'NN'),
#   ('promotion', 'NN')],
#  [('i', 'NN'),
#   ('did', 'VBD'),
#   ('like', 'IN'),
#   ('de', 'NN'),
#   ('niro', 'FW'),
#   ('as', 'IN'),
#   ('ben', 'NN'),
#   ('and', 'CC'),
#   ('hathaway', 'NN'),
#   ('as', 'IN'),
#   ('jules', 'NNS'),
#   ('was', 'VBD'),
#   ('not', 'RB'),
#   ('too', 'RB'),
#   ('shabby', 'JJ'),
#   ('either', 'CC')],
#  [('the', 'DT'),
#   ('intern', 'NN'),
#   ('was', 'VBD'),
#   ('two', 'CD'),
#   ('hours', 'NNS'),
#   ('long', 'IN'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('not', 'RB'),
#   ('have', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB')],
#  [('this', 'DT'),
#   ('intern', 'NN'),
#   ('could', 'MD'),
#   ('have', 'VB'),
#   ('done', 'VBN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('job', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('sheer', 'NN'),
#   ('ninety', 'NN'),
#   ('minutes', 'NNS'),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('stayed', 'VBD'),
#   ('for', 'IN'),
#   ('not', 'RB'),
#   ('needed', 'VBN'),
#   ('overtime', 'NN'),
#   ('and', 'CC'),
#   ('for', 'IN'),
#   ('that', 'DT'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('not', 'RB'),
#   ('highly', 'RB'),
#   ('recommend', 'VB'),
#   ('for', 'IN'),
#   ('you', 'PRP'),
#   ('to', 'TO'),
#   ('hire', 'VB'),
#   ('the', 'DT'),
#   ('intern', 'JJ'),
#   ('into', 'IN'),
#   ('your', 'PRP$'),
#   ('movie', 'NN'),
#   ('watch', 'NN'),
#   ('company', 'NN')],
#  [('it', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('really', 'RB'),
#   ('good', 'JJ'),
#   ('movie', 'NN'),
#   ('a', 'DT'),
#   ('wholesome', 'NN'),
#   ('not', 'RB'),
#   ('goofy', 'JJ'),
#   ('dirty', 'JJ'),
#   ('liberal', 'JJ'),
#   ('trash', 'NN'),
#   ('heap', 'NN')],
#  [('it', 'PRP'),
#   ('was', 'VBD'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('movie', 'NN')],
#  [('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('film', 'NN'),
#   ('i', 'NN'),
#   ('liked', 'VBD'),
#   ('it', 'PRP'),
#   ('made', 'VBD'),
#   ('me', 'PRP'),
#   ('fell', 'VBD'),
#   ('good', 'JJ'),
#   ('and', 'CC'),
#   ('happy', 'JJ')],
#  [('as', 'RB'),
#   ('long', 'RB'),
#   ('as', 'IN'),
#   ('you', 'PRP'),
#   ('do', 'VBP'),
#   ('not', 'RB'),
#   ('really', 'RB'),
#   ('pay', 'VB'),
#   ('attention', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('plot', 'NN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('nice', 'JJ'),
#   ('movie', 'NN')],
#  [('when', 'WRB'),
#   ('watching', 'VBG'),
#   ('the', 'DT'),
#   ('previews', 'NN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('reluctant', 'JJ'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('this', 'DT'),
#   ('film', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('thought', 'VBD'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('possible', 'JJ'),
#   ('story', 'NN'),
#   ('line', 'NN'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('older', 'JJR'),
#   ('intern', 'NN'),
#   ('would', 'MD'),
#   ('end', 'VB'),
#   ('up', 'RP'),
#   ('dying', 'VBG')],
#  [('this', 'DT'),
#   ('movie', 'NN'),
#   ('is', 'VBZ'),
#   ('nothing', 'NN'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('instead', 'RB'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('adorable', 'JJ'),
#   ('and', 'CC'),
#   ('probably', 'RB'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('new', 'JJ'),
#   ('favorite', 'JJ'),
#   ('movies', 'NNS')],
#  [('the', 'DT'),
#   ('ending', 'VBG'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('abrupt', 'JJ'),
#   ('but', 'CC'),
#   ('overall', 'JJ'),
#   ('i', 'NN'),
#   ('highly', 'RB'),
#   ('recommend', 'VBP'),
#   ('it', 'PRP')],
#  [('i', 'NN'),
#   ('actually', 'RB'),
#   ('enjoyed', 'VBD'),
#   ('this', 'DT'),
#   ('movie', 'NN')],
#  [('robert', 'NN'),
#   ('di', 'NN'),
#   ('nero', 'NN'),
#   ('was', 'VBD'),
#   ('fun', 'RB'),
#   ('hilarious', 'JJ'),
#   ('and', 'CC'),
#   ('downright', 'VBD'),
#   ('adorable', 'JJ')],
#  [('i', 'NNS'),
#   ('have', 'VBP'),
#   ('always', 'RB'),
#   ('loved', 'VBN'),
#   ('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('thought', 'VBD'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('great', 'JJ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('film', 'NN')],
#  [('the', 'DT'),
#   ('only', 'JJ'),
#   ('part', 'NN'),
#   ('that', 'IN'),
#   ('annoyed', 'VBD'),
#   ('me', 'PRP'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('small', 'JJ'),
#   ('husband', 'NN'),
#   ('cheating', 'VBG'),
#   ('story', 'NN')],
#  ...]

# %%
nltk.download('tagsets')
nltk.help.upenn_tagset('WRB')
# Out:
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# [nltk_data] Downloading package tagsets to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Remove IN, PRP, CC, PRP$, DT, TO, FW, WP
def remove_specific_tags(tagged_sentence, tags_to_remove):
    return [word for word, tag in tagged_sentence if tag not in tags_to_remove]

tags_to_remove = {"IN", "PRP", "CC", "PRP$", "DT", "TO", "FW", "WP", "WRB"}

tag_rm = tag_sentence.copy()
tag_rm = [remove_specific_tags(text, tags_to_remove) for text in tag_rm]

# %%
tag_rm_sentence = [pos_tag(sentence) for sentence in tag_rm]
tag_rm_sentence[:5]
# Out:
# [[('was', 'VBD'), ('not', 'RB'), ('i', 'JJ'), ('expected', 'VBD')],
#  [('really', 'RB'), ('enjoyed', 'VBN')],
#  [('including', 'VBG'), ('hope', 'NN'), ('redemption', 'NN'), ('end', 'NN')],
#  [('true', 'JJ'),
#   ('feel', 'NN'),
#   ('good', 'JJ'),
#   ('movie', 'NN'),
#   ('i', 'IN'),
#   ('wish', 'JJ'),
#   ('i', 'NN'),
#   ('saw', 'VBD'),
#   ('theaters', 'NNS')],
#  [('anne', 'JJ'),
#   ('hathaway', 'NN'),
#   ('robert', 'NN'),
#   ('deniro', 'NN'),
#   ('have', 'VBP'),
#   ('great', 'JJ'),
#   ('chemistry', 'NN'),
#   ('movie', 'NN'),
#   ('tells', 'VBZ'),
#   ('great', 'JJ'),
#   ('story', 'NN'),
#   ('two', 'CD'),
#   ('people', 'NNS'),
#   ('generations', 'NNS'),
#   ('apart', 'RB'),
#   ('growing', 'VBG'),
#   ('closer', 'RBR'),
#   ('learning', 'VBG'),
#   ('other', 'JJ')]]

# %%
# Lemmatize & remove stopwords

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import wordnet as wn

nltk.download('wordnet')

# inflect engine initialize
p = inflect.engine()

# WordNetLemmatizer initialize
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wn.ADJ
    elif treebank_tag.startswith('V'):
        return wn.VERB
    elif treebank_tag.startswith('N'):
        return wn.NOUN
    elif treebank_tag.startswith('R'):
        return wn.ADV
    else:
        return None

def singularize_and_lemmatize(tagged_words):
    new_words = []
    
    for word, tag in tagged_words:
        if tag.startswith('N'):
            singular_word = p.singular_noun(word)
            if singular_word:
                new_words.append(singular_word)
            else:
                new_words.append(word)
        else:
            wn_tag = get_wordnet_pos(tag)
            if wn_tag is not None:
                lemma_word = lemmatizer.lemmatize(word, wn_tag)
                new_words.append(lemma_word)
            else:
                new_words.append(word)
    
    return new_words
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\seowoo
# [nltk_data]     kim\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
processed_sentences = [singularize_and_lemmatize(sentence) for sentence in tag_rm_sentence]

# %%
processed_sentences
# Out:
# [['be', 'not', 'i', 'expect'],
#  ['really', 'enjoy'],
#  ['include', 'hope', 'redemption', 'end'],
#  ['true', 'feel', 'good', 'movie', 'i', 'wish', 'i', 'saw', 'theater'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'deniro',
#   'have',
#   'great',
#   'chemistry',
#   'movie',
#   'tell',
#   'great',
#   'story',
#   'two',
#   'person',
#   'generation',
#   'apart',
#   'grow',
#   'closer',
#   'learn',
#   'other'],
#  ['there', 'be', 'strong', 'character', 'development', 'solid', 'cast'],
#  ['i', 'recommend', 'anyone'],
#  ['all',
#   'piece',
#   'seem',
#   'be',
#   'there',
#   'truly',
#   'appropriate',
#   'third',
#   'act'],
#  ['intern',
#   'have',
#   'chemistry',
#   'rich',
#   'lead',
#   'performance',
#   'tenure',
#   'auteur',
#   'camera'],
#  ['brilliant', 'movie'],
#  ['so', 'warm', 'satisfying', 'so', 'move'],
#  ['recommend'],
#  ['two',
#   'bonified',
#   'great',
#   'actor',
#   'somehow',
#   'have',
#   'great',
#   'chemistry',
#   'that',
#   'truly',
#   'make',
#   'movie',
#   'worth',
#   'watch'],
#  ['rush',
#   'story',
#   'do',
#   'not',
#   'take',
#   'away',
#   'heartwarming',
#   'affect',
#   'be',
#   'go'],
#  ['movie', 'be', 'very', 'good'],
#  ['i',
#   'can',
#   'not',
#   'believe',
#   'other',
#   'critic',
#   'be',
#   'rating',
#   'say',
#   'movie'],
#  ['two', 'legendary', 'actor', 'good', 'script'],
#  ['good',
#   'film',
#   'overall',
#   'love',
#   'robert',
#   'fit',
#   'role',
#   'really',
#   'well'],
#  ['story',
#   'be',
#   'pretty',
#   'standard',
#   'stuff',
#   'however',
#   'fun',
#   'watch',
#   'something',
#   'take',
#   'away'],
#  ['very', 'entertaining', 'movie', 'just', 'want', 'have', 'good', 'time'],
#  ['i', 'really', 'enjoy', 'lot'],
#  ['think', 'really', 'nailed', 'part', 'be', 'top', 'game'],
#  ['well', 'watch', 'i', 'wish', 'couple', 'ending', 'go', 'different', 'way'],
#  ['gentle', 'film', 'low', 'stake', 'surface', 'level', 'lesson', 'value'],
#  ['beautifully', 'shoot', 'well', 'acted', 'story', 'lack', 'depth'],
#  ['hathaway',
#   's',
#   'mad',
#   'act',
#   'skill',
#   'manage',
#   'raise',
#   'otherwise',
#   'boring',
#   'film',
#   'very',
#   'nearly',
#   'interesting'],
#  ['odd',
#   'hathaway',
#   's',
#   'meeting',
#   'never',
#   'one',
#   'consider',
#   'hire',
#   'female',
#   'ceo'],
#  ['sadly',
#   'successful',
#   'entrepreneur',
#   'will',
#   'continue',
#   'burn',
#   'out',
#   'can',
#   'not',
#   'let',
#   'go',
#   'struggle',
#   'delegate',
#   'flawles',
#   'person',
#   'always',
#   'say',
#   'right',
#   'thing',
#   'magically',
#   'show',
#   'up'],
#  ['o', 'filme', 'que', 'bom', 'bastante', 'divertido'],
#  ['ma',
#   'o',
#   'final',
#   'n',
#   'o',
#   'fez',
#   'nenhum',
#   'sentido',
#   'filme',
#   'bem',
#   'ses',
#   'da',
#   'tarde',
#   'mesmo'],
#  ['movie',
#   'be',
#   'good',
#   'one',
#   'just',
#   'throw',
#   'enjoy',
#   'be',
#   'usually',
#   'not',
#   'type',
#   'movie',
#   'i',
#   'quite',
#   'enjoy',
#   'duo',
#   'onscreen',
#   'lesson',
#   'learn',
#   'way'],
#  ['be', 'look', 'feel', 'good', 'film', 'be'],
#  ['fantastic', 'cast', 'compelling', 'story'],
#  ['know', 'be', 'spread', 'too', 'thin', 'feel', 'outsider'],
#  ['learn', 'something', 'work', 'life', 'balance', 'fit', 'be'],
#  ['i',
#   'come',
#   'movie',
#   'i',
#   'be',
#   'look',
#   'wholesome',
#   'movie',
#   'that',
#   'would',
#   'make',
#   'regain',
#   'sort',
#   'faith',
#   'humanity'],
#  ['most', 'part', 'movie', 'deliver'],
#  ['i',
#   'be',
#   'not',
#   'sure',
#   'i',
#   'agree',
#   'decision',
#   'end',
#   'be',
#   'decision',
#   'i',
#   'gues'],
#  ['idk', 'first', 'half', 'be', 'very', 'wholesome', 'get', 'messy', 'end'],
#  ['i', 'gues', 'that', 'be', 'life', 'messy'],
#  ['be', 'terrible', 'movie', 'awful', 'message'],
#  ['only',
#   'give',
#   'be',
#   'feminism',
#   'show',
#   'woman',
#   'can',
#   'be',
#   'top',
#   'be',
#   'do',
#   'most',
#   'disgraceful',
#   'way'],
#  ['hathaway',
#   's',
#   'character',
#   'be',
#   'out',
#   'be',
#   'control',
#   'clearly',
#   'not',
#   'able',
#   'handle',
#   'grow',
#   'company',
#   'completely',
#   'oblivious',
#   'tech',
#   'not',
#   'use',
#   'email',
#   'recall',
#   'sink',
#   'even',
#   'more',
#   'power',
#   'trip',
#   'not',
#   'have',
#   'bos'],
#  ['lot', 'sham', 'new', 'generation', 'man', 'glorify', 'boomer'],
#  ['extremely', 'capitalist', 'pro', 'destroy', 'everything', 'job'],
#  ['wtf',
#   'go',
#   'bar',
#   'employee',
#   'which',
#   'do',
#   'not',
#   'know',
#   'name',
#   'be',
#   'too',
#   'powerful',
#   'instead',
#   'go',
#   'home',
#   'spend',
#   'time',
#   'family'],
#  ['idea',
#   'feminism',
#   'be',
#   'become',
#   'well',
#   'collectively',
#   'not',
#   'woman',
#   'start',
#   'act',
#   'stereotypical',
#   'man'],
#  ['also', 'sexual', 'harrassment', 'be', 'out', 'there', 'joke', 'really'],
#  ['be', 'ok', 'be', 'do', 'guy'],
#  ['special',
#   'effect',
#   'one',
#   'zero',
#   'sound',
#   'effect',
#   'one',
#   'zero',
#   'act',
#   'one',
#   'zero',
#   'story',
#   'two',
#   'zero'],
#  ['just', 'classic', 'pull', 'all', 'good', 'heartstring', 'best', 'duo'],
#  ['be', 'so', 'well', 'write', 'character', 'be', 'adorable'],
#  ['be', 'funny', 'sad', 'suspenseful', 'action', 'pack'],
#  ['could', 'be', 'good'],
#  [],
#  ['i', 'bit', 'long', 'good', 'story'],
#  ['whyyy', 'be', 'movie', 'not', 'rat', 'ninety'],
#  [],
#  ['be', 'one', 'be', 'kind'],
#  ['so', 'fresh', 'warm', 'cozy', 'positive'],
#  ['somehow', 'teach', 'way', 'living'],
#  ['i', 'always', 'go', 'hopeful', 'happy', 'content', 'watch', 'movie'],
#  ['definitely', 'must', 'watch'],
#  [],
#  ['very', 'beautiful', 'well', 'write', 'movie'],
#  ['hat', 'off', 'creator'],
#  ['tell',
#   'phone',
#   'ring',
#   'background',
#   'heart',
#   'thought',
#   'be',
#   'stalk',
#   'baby',
#   'mama',
#   'have',
#   'quit',
#   'immediatly'],
#  ['make', 'feel', 'warm', 'cozy', 'chest', 'very', 'nostalgic', 'feeling'],
#  ['movie', 'be', 'one', 'sweetest', 'will', 'ever', 'watch'],
#  ['have', 'comedy', 'drama', 'as', 'well', 'really', 'sweet', 'story'],
#  ['overall', 'be', 'awsome', 'movie'],
#  ['want',
#   'simply',
#   'smile',
#   'two',
#   'hour',
#   'straight',
#   'go',
#   'ahead',
#   'watch',
#   'movie'],
#  ['i',
#   'have',
#   'zero',
#   'clue',
#   'anyone',
#   'would',
#   'rat',
#   'five',
#   'star',
#   'comedy',
#   'drama'],
#  ['chemistry', 'hathaway', 'be', 'tremendous'],
#  ['i',
#   'buy',
#   'whole',
#   'thing',
#   'somehow',
#   'there',
#   'be',
#   'actually',
#   'decent',
#   'premise',
#   'storyline'],
#  ['simple', 'sweet'],
#  ['i',
#   'would',
#   'be',
#   'have',
#   'terrible',
#   'week',
#   'everything',
#   'have',
#   'go',
#   'wrong',
#   'movie',
#   'be',
#   'tv',
#   'hotel',
#   'room',
#   'help',
#   'distract',
#   'bit'],
#  ['i', 'find', 'smile', 'part', 'be', 'overall', 'just', 'nice', 'movie'],
#  ['deniro',
#   'hathaway',
#   'have',
#   'good',
#   'chemistry',
#   'here',
#   'overall',
#   'emotional',
#   'tone',
#   'be',
#   'too',
#   'mushy',
#   'feel',
#   'manipulative'],
#  ['deniro', 's', 'character', 'be', 'too', 'good', 'be', 'true'],
#  ['be', 'can', 'almost', 'get', 'away'],
#  ['message',
#   'social',
#   'gender',
#   'role',
#   'seem',
#   'overly',
#   'simplify',
#   'sort',
#   'muddy',
#   'same',
#   'time'],
#  ['attempt', 'do', 'not', 'quite', 'pull', 'off'],
#  ['serviceable'],
#  ['have', 'low', 'key', 'feel'],
#  ['something', 'bring', 'back', 'watch', 'again'],
#  ['so',
#   'there',
#   'be',
#   'something',
#   'i',
#   'do',
#   'not',
#   'think',
#   'ever',
#   'really',
#   'hit',
#   'mark',
#   'be',
#   'aim'],
#  ['cute',
#   'movie',
#   'be',
#   'nice',
#   'two',
#   'hour',
#   'well',
#   'spend',
#   'have',
#   'nothing',
#   'well',
#   'do'],
#  ['solid', 'flick'],
#  ['watch'],
#  ['def', 'fresh'],
#  ['don', 't', 'vibe', 'charm', 'nancy', 'meyer', 'bring', 'just', 'move'],
#  ['very', 'boring'],
#  ['seem',
#   'film',
#   'be',
#   'more',
#   'interested',
#   'create',
#   'statement',
#   'make',
#   'enjoyable',
#   'film'],
#  ['movie',
#   'make',
#   'person',
#   'emotional',
#   'remind',
#   'senior',
#   'person',
#   'be',
#   'still',
#   'very',
#   'important',
#   'society'],
#  ['robert',
#   'make',
#   'such',
#   'amazing',
#   'character',
#   'that',
#   'actually',
#   'make',
#   'feel',
#   'calm'],
#  ['anne',
#   'hathway',
#   'also',
#   'make',
#   'awsome',
#   'character',
#   'power',
#   'woman',
#   'rmaking',
#   'refrence',
#   'work',
#   'mom',
#   'which',
#   'be',
#   'social',
#   'issue',
#   'today'],
#  ['plot', 'be', 'good'],
#  ['be', 'movie', 'that', 'make', 'smile', 'laught', 'little'],
#  ['movie',
#   'be',
#   'i',
#   'do',
#   'not',
#   'know',
#   'movie',
#   'have',
#   'low',
#   'rating',
#   'believe',
#   'be',
#   'masterpiece',
#   'mood',
#   'changer'],
#  ['esta',
#   'pelicula',
#   'da',
#   'una',
#   'buena',
#   'vibra',
#   'con',
#   'la',
#   'talento',
#   'protagonista'],
#  ['movie', 'be', 'old', 'gold'],
#  ['nancy', 'meyer', 's', 'take', 'movie', 'be', 'breath', 'air'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'deniro',
#   'play',
#   'character',
#   'very',
#   'well',
#   'make',
#   'movie',
#   'more',
#   'interesting',
#   'watch'],
#  ['i', 'love', 'movie', 'mix', 'old', 'modern', 'reference', 'be', 'amaze'],
#  ['movie',
#   'be',
#   'that',
#   'don',
#   't',
#   'take',
#   'life',
#   'seriously',
#   'be',
#   'just',
#   'lay',
#   'back'],
#  ['therapist', 'metro', 'film', 'be', 'too', 'dark', 'knight', 'esque'],
#  ['will',
#   'be',
#   'one',
#   'time',
#   'classic',
#   'as',
#   'good',
#   'wonderful',
#   'life',
#   'other'],
#  ['film',
#   'do',
#   'be',
#   'instil',
#   'good',
#   'old',
#   'value',
#   'attribute',
#   'modern',
#   'digital',
#   'world',
#   'mixed',
#   'emotion',
#   'old',
#   'school',
#   'gentleman'],
#  ['golden', 'future', 'classic'],
#  ['great', 'movie', 'show', 'different', 'story', 'one', 'movie'],
#  ['undemanding'],
#  ['pleasant', 'way', 'spend', 'couple', 'hour'],
#  ['movie',
#   'be',
#   'so',
#   'wholesome',
#   'amazing',
#   'there',
#   'be',
#   'time',
#   'i',
#   'almost',
#   'cry',
#   'alot',
#   'time',
#   'make',
#   'smile'],
#  ['i',
#   'have',
#   'choose',
#   'movie',
#   'i',
#   'be',
#   'great',
#   'anne',
#   'hathaway',
#   'fan'],
#  ['so', 'obviously', 'i', 'be', 'sure', 'movie', 'be', 'be', 'great'],
#  ['i',
#   'watch',
#   'i',
#   'find',
#   'movie',
#   'be',
#   'fresh',
#   'watch',
#   'something',
#   'so',
#   'subtle',
#   'touch',
#   'glimpse',
#   'laugh'],
#  ['thing',
#   'which',
#   'touch',
#   'most',
#   'be',
#   'story',
#   'performance',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['specially',
#   'moment',
#   'work',
#   'late',
#   'night',
#   'say',
#   'use',
#   'work',
#   'same',
#   'spot',
#   'year',
#   'ago'],
#  ['must', 'watch', 'movie'],
#  ['be', 'good', 'movie'],
#  ['story', 'be', 'good', 'music', 'be', 'beautiful'],
#  ['robert', 'play', 'wonderful', 'character'],
#  ['watch'],
#  ['less', 'be', 'say'],
#  ['more', 'be', 'say'],
#  ['simple', 'story', 'end', 'be', 'apparent', 'outset'],
#  ['point', 'be', 'film', 'watch', 'plot', 'unfold'],
#  ['nothing', 'deep'],
#  ['nothing', 'urge', 'set', 'date', 'watch', 'again'],
#  ['rather', 'more', 'something', 'person', 'can', 'feel'],
#  ['interaction'],
#  ['know', 'take', 'put', 'win', 'production', 'together'],
#  ['good', 'writing'],
#  ['good', 'acting'],
#  ['all', 'rest'],
#  ['be', 'go', 'wind', 'be', 'just', 'show'],
#  ['person'],
#  ['nothing', 'more'],
#  ['wind', 'up', 'pleased', 'smile'],
#  ['pick', 'own', 'person', 'identify'],
#  ['i', 'be', 'old', 'so', 'deniro', 'be'],
#  ['value', 'keep', 'mouth', 'shut', 'more', 'often'],
#  ['pay', 'off'],
#  ['perfect', 'three', 'star'],
#  ['i', 'like', 'movie', 'start', 'finish'],
#  ['love',
#   'relationship',
#   'intern',
#   'jule',
#   'make',
#   'think',
#   'very',
#   'proud',
#   'granddad',
#   'try',
#   'help',
#   'niece',
#   'out'],
#  ['two', 'very', 'well', 'spent', 'hour'],
#  ['enjoy', 'deniro', 'first', 'time', 'awhile'],
#  ['love', 'burglary', 'sequence'],
#  ['robert', 'comedy', 'movie', 'very', 'decent', 'movie'],
#  ['do', 'enjoy'],
#  ['seven', 'five', 'ten'],
#  ['very', 'lame', 'movie', 'acting', 'be', 'force', 'most', 'scene'],
#  ['not', 'recommend'],
#  ['feel',
#   'good',
#   'dramedy',
#   'which',
#   'drawn',
#   'place',
#   'have',
#   'moment',
#   'be',
#   'bound',
#   'make',
#   'smile'],
#  ['i', 'be', 'surprised', 'critic', 'give', 'one', 'such', 'poor', 'rating'],
#  ['make', 'wonder', 'ever', 'know', 'enjoy', 'good', 'movie'],
#  ['be',
#   'not',
#   'original',
#   'raise',
#   'few',
#   'issue',
#   'may',
#   'not',
#   'agree',
#   'whatever',
#   'movie',
#   'make',
#   'then',
#   'cry',
#   'end',
#   'leave',
#   'feeling',
#   'warmth'],
#  ['i', 'enjoy', 'so', 'much'],
#  ['i',
#   'use',
#   'watch',
#   'movie',
#   'base',
#   'critic',
#   's',
#   'rating',
#   'now',
#   'i',
#   'know',
#   'good'],
#  ['touch', 'story', 'great', 'actor'],
#  ['awesome'],
#  ['script',
#   'act',
#   'two',
#   'lead',
#   'story',
#   'much',
#   'feel',
#   'relationship',
#   'very',
#   'well',
#   'do',
#   'ander',
#   'holm',
#   'act'],
#  ['jule',
#   'husband',
#   'be',
#   'play',
#   'actor',
#   'well',
#   'act',
#   'would',
#   'have',
#   'be',
#   'stellar'],
#  ['ander', 'really', 'do', 'not', 'make', 'connect', 'feel', 'husband'],
#  ['face', 'be', 'same', 'ninety', 'nine', 'time', 'be', 'screen'],
#  ['anyhow',
#   'still',
#   'well',
#   'execute',
#   'emotionally',
#   'mature',
#   'well',
#   'write',
#   'movie',
#   'watch'],
#  ['kudo', 'robert', 'deniro', 'anne', 'hathaway'],
#  ['begin',
#   'i',
#   'felt',
#   'good',
#   'while',
#   'all',
#   'cringe',
#   'come',
#   'ruin',
#   'everything'],
#  ['not', 'so', 'feel', 'good', 'movie'],
#  ['good'],
#  ['be', 'so', 'cool', 'movie'],
#  ['la',
#   'cula',
#   'trata',
#   'horrible',
#   'lo',
#   'problema',
#   'una',
#   'pareja',
#   'al',
#   'acordar',
#   'su',
#   'propia',
#   'meta',
#   'la',
#   'historia',
#   'es',
#   'mal',
#   'sima',
#   'pero',
#   'robert',
#   'hathaway',
#   'la',
#   'vuelven',
#   'aburrida'],
#  ['really', 'enjoy', 'watch', 'movie'],
#  ['love', 'performance', 'anne', 'robert'],
#  ['all', 'great', 'review'],
#  ['bad', 'movie', 'i', 'have', 'see'],
#  ['movie',
#   'be',
#   'reflect',
#   'work',
#   'place',
#   'that',
#   'never',
#   'thousand',
#   'year',
#   'would',
#   'exist'],
#  ['be', 'i', 'just', 'narrow', 'mind'],
#  ['whatever', 'terrible'],
#  ['movie',
#   'be',
#   'just',
#   'such',
#   'feel',
#   'good',
#   'movie',
#   'i',
#   'always',
#   'end',
#   'up',
#   'so',
#   'happy',
#   'watching'],
#  ['robert',
#   'ha',
#   'trovato',
#   'ormai',
#   'casa',
#   'queste',
#   'commedie',
#   'cui',
#   'pu',
#   'esprimere',
#   'un',
#   'lato',
#   'pi',
#   'divertente',
#   's',
#   'lungo',
#   'sovrastato',
#   'da',
#   'grandi',
#   'performance',
#   'drammatiche'],
#  ['intern',
#   'un',
#   'film',
#   'piacevole',
#   'originale',
#   'e',
#   'con',
#   'davvero',
#   'pochi',
#   'difetti',
#   'lo',
#   'si',
#   'guarda',
#   'con',
#   'piacere',
#   'dall',
#   'inizio',
#   'alla',
#   'fine'],
#  ['magari',
#   'sarebbe',
#   'stato',
#   'interessante',
#   'completare',
#   'con',
#   'qualche',
#   'personaggio',
#   'di',
#   'contorno',
#   'pi',
#   'interessante',
#   'tratti',
#   'si',
#   'sente',
#   'un',
#   'po',
#   'la',
#   'mancanza'],
#  ['star', 'act', 'compliment', 'other'],
#  ['very', 'enjoyable', 'movie'],
#  ['movie', 'be', 'really', 'heal'],
#  ['i', 'could', 'see', 'importance', 'occupation', 'life'],
#  ['do',
#   'work',
#   'make',
#   'think',
#   'pride',
#   'esteem',
#   'rather',
#   'obsess',
#   'money'],
#  ['good',
#   'hearted',
#   'drama',
#   'comedy',
#   'that',
#   'entertain',
#   'become',
#   'overly',
#   'sentimental'],
#  ['be', 'relax', 'watch'],
#  ['robert', 'jako', 'alfa', 'i', 'omega'],
#  ['be', 'favorite', 'movie', 'ever', 'watch'],
#  [],
#  ['one',
#   'nancy',
#   'meyer',
#   'absolute',
#   'humane',
#   'best',
#   'usual',
#   'charm',
#   'turn',
#   'sweetness',
#   'something',
#   'unexpectedly',
#   'wholesomely',
#   'hearten',
#   'benefit',
#   'finely',
#   'cast',
#   'chemistry',
#   'that',
#   'be',
#   'enough',
#   'make',
#   'hilarious',
#   'insightful',
#   'comedy',
#   'one',
#   'best',
#   'feel',
#   'good',
#   'film',
#   'recent',
#   'memory'],
#  [],
#  ['not',
#   'even',
#   'inmense',
#   'act',
#   'chop',
#   'deniro',
#   'hathaway',
#   'could',
#   'save',
#   'film',
#   'lack',
#   'focu',
#   'story'],
#  ['isnt', 'bad', 'movie', 'just', 'not', 'interest', 'memorable'],
#  ['bland'],
#  ['be', 'so', 'fun', 'watch', 'begin', 'end'],
#  ['i',
#   'have',
#   'always',
#   'be',
#   'fan',
#   'story',
#   'build',
#   'friendship',
#   'young',
#   'old',
#   'person',
#   'particularly',
#   'exchange',
#   'wisdom',
#   'which',
#   'involve',
#   'respect',
#   'mutual',
#   'admiration',
#   'compassion'],
#  ['be', 'feel', 'good', 'story'],
#  ['great', 'movie', 'very', 'wholesome', 'watch'],
#  ['two',
#   'star',
#   'be',
#   'fantastic',
#   'well',
#   'match',
#   'hathaway',
#   's',
#   'character',
#   'get',
#   'terrible',
#   'sexist',
#   'arch',
#   'that',
#   'seem',
#   'defend',
#   'man',
#   'cheat',
#   'woman',
#   'be',
#   'too',
#   'impowered'],
#  ['mark', 'zuckerberg', 'never', 'bring', 'ceo', 'be', 'teenager'],
#  ['movie', 'be', 'love', 'life', 'lesson', 'fall', 'getup'],
#  ['surprisingly', 'touch', 'happy'],
#  ['puts', 'life', 'feminism', 'work', 'marriage', 'kid', 'table', 'discuss'],
#  ['life', 'lesson', 'be', 'demonstrate', 'naturally', 'not', 'boring', 'way'],
#  ['still', 'great', 'actor'],
#  ['now',
#   'old',
#   'be',
#   'do',
#   'more',
#   'dramatic',
#   'movie',
#   'man',
#   'still',
#   'fire'],
#  ['facial', 'expression', 'be', 'one', 'else', 'could', 'ever', 'do'],
#  ['chemistry', 'get', 'hathaway', 'be', 'touch', 'happy'],
#  ['be', 'almost', 'be', 'connect', 'other'],
#  ['hathaway'],
#  ['be', 'gorgeous', 'frenetic', 'as', 'expressive', 'niro'],
#  ['could', 'do', 'scene', 'even', 'talk'],
#  ['intern',
#   'have',
#   'slow',
#   'tire',
#   'narrative',
#   'script',
#   'barely',
#   'move',
#   'end',
#   'be',
#   'disappoint'],
#  ['movie',
#   'be',
#   'very',
#   'sweet',
#   'do',
#   'fantastic',
#   'job',
#   'build',
#   'relationship',
#   'two',
#   'main',
#   'character'],
#  ['be', 'really', 'good', 'movie'],
#  ['be',
#   'not',
#   'kind',
#   'movie',
#   'i',
#   'see',
#   'i',
#   'have',
#   'admit',
#   'hathaway',
#   'be',
#   'very',
#   'good',
#   'together',
#   'movie'],
#  ['story',
#   'be',
#   'quite',
#   'clich',
#   'be',
#   'redeem',
#   'thank',
#   'modern',
#   'approach',
#   'chemistry',
#   'lead'],
#  ['i', 'love', 'movie'],
#  ['i', 'have', 'see', 'several', 'time'],
#  ['be', 'feel', 'good', 'film'],
#  ['i',
#   'think',
#   'whole',
#   'world',
#   'should',
#   'have',
#   'senior',
#   'intern',
#   'help',
#   'adapt',
#   'new',
#   'norm'],
#  ['also',
#   'make',
#   'feel',
#   'belong',
#   'be',
#   'still',
#   'part',
#   'something',
#   'community'],
#  ['i', 'love', 'anne', 'hathaway'],
#  ['i', 'think', 'be', 'great', 'actres'],
#  ['relationship', 'jules', 'hathaway', 'ben', 'be', 'very', 'admirable'],
#  ['be', 'father', 'more', 'colleague'],
#  ['i',
#   'do',
#   'not',
#   'though',
#   'be',
#   'matt',
#   'jule',
#   'husband',
#   'have',
#   'affair',
#   'make',
#   'jule',
#   'feel',
#   'be',
#   'fault',
#   'company',
#   'become',
#   'successful',
#   'less',
#   'two',
#   'year'],
#  ['however', 'end', 'be', 'great'],
#  ['everything', 'just', 'fell', 'place'],
#  ['so',
#   'be',
#   'anne',
#   'hathaway',
#   'do',
#   'leave',
#   'runway',
#   'devil',
#   'wear',
#   'prada'],
#  ['be',
#   'sort',
#   'anne',
#   'hathaway',
#   'fashion',
#   'cinematic',
#   'universe',
#   'perhaps'],
#  ['even', 'be', 'i', 'would', 'not', 'mind'],
#  ['joke',
#   'aside',
#   'intern',
#   'be',
#   'truly',
#   'heartfelt',
#   'cheerful',
#   'emotionally',
#   'uplifting',
#   'film',
#   'power',
#   'beautiful',
#   'nuanced',
#   'performance',
#   'rober',
#   'anne',
#   'hathaway'],
#  ['subplot',
#   'can',
#   'feel',
#   'irrelevant',
#   'final',
#   'story',
#   'feel',
#   'cram',
#   'fit',
#   'runtime'],
#  ['mean',
#   'film',
#   'get',
#   'boring',
#   'feel',
#   'there',
#   'be',
#   'not',
#   'much',
#   'substance',
#   'here'],
#  ['film', 'look', 'good', 'cinematography', 'be', 'fantastic'],
#  ['dialogue', 'be', 'quirky', 'witty'],
#  ['chemistry', 'hathaway', 'be', 'lifts', 'film', 'average', 'good'],
#  ['recommend'],
#  ['best', 'thing', 'i', 'can', 'say', 'intern', 'be', 'do', 'not', 'suck'],
#  ['draw', 'so', 'well', 'want', 'be', 'good'],
#  ['then', 'punch', 'gut', 'never', 'recover'],
#  ['end',
#   'feel',
#   'writer',
#   'get',
#   'one',
#   'yard',
#   'line',
#   'then',
#   'drop',
#   'ball'],
#  ['great', 'run', 'touchdown'],
#  ['i',
#   'be',
#   'pleasantly',
#   'surprised',
#   'much',
#   'i',
#   'like',
#   'movie',
#   'retire',
#   'businessman',
#   'widower',
#   'decide',
#   'apply',
#   'intern',
#   'successful',
#   'online',
#   'fashion',
#   'start',
#   'up',
#   'company',
#   'found',
#   'ambitious',
#   'jule',
#   'ostin',
#   'ann',
#   'hathaway',
#   'be',
#   'generation',
#   'apart',
#   'find',
#   'way',
#   'successfully',
#   'work',
#   'support',
#   'other'],
#  ['way',
#   'be',
#   'able',
#   'find',
#   'friendship',
#   'reliable',
#   'person',
#   'can',
#   'count'],
#  ['highly', 'recommended'],
#  ['have',
#   'intriguing',
#   'premise',
#   'do',
#   'not',
#   'evolve',
#   'too',
#   'much',
#   'commentaire',
#   'aside',
#   'clich',
#   'd',
#   'situation'],
#  ['still',
#   'be',
#   'charm',
#   'movie',
#   'good',
#   'watch',
#   'really',
#   'work',
#   'chemistry',
#   'anne',
#   'hathaway',
#   'do',
#   'best',
#   'robert',
#   'truly',
#   'standout'],
#  ['commedia',
#   'pi',
#   'che',
#   'dignitosa',
#   'che',
#   'nasconde',
#   'una',
#   'morale',
#   'pi',
#   'profonda',
#   'del',
#   'previsto',
#   'e',
#   'del',
#   'necessario'],
#  ['nella',
#   'seconda',
#   'meet',
#   'del',
#   'film',
#   'si',
#   'sbarca',
#   'territori',
#   'pericolosi',
#   'proponendo',
#   'un',
#   'idea',
#   'di',
#   'fondo',
#   'forzata',
#   'con',
#   'risvolti',
#   'narrativi',
#   'inconsistenti'],
#  ['la',
#   'buona',
#   'sintonia',
#   'tra',
#   'la',
#   'coppia',
#   'dei',
#   'protagonisti',
#   'rende',
#   'comunque',
#   'il',
#   'film',
#   'assolutamente',
#   'un',
#   'esperienza',
#   'leggera',
#   'e',
#   'passeggera'],
#  ['be', 'one', 'movie', 'that', 'just', 'put', 'happy', 'mood'],
#  ['be', 'not', 'classic', 'cinema', 'also', 'be', 'not', 'meant', 'be'],
#  ['main',
#   'succes',
#   'be',
#   'chemistry',
#   'entire',
#   'cast',
#   'particularly',
#   'two',
#   'lead'],
#  ['i',
#   'do',
#   'not',
#   'necessarily',
#   'dislike',
#   'film',
#   'have',
#   'way',
#   'too',
#   'many',
#   'cheesy',
#   'cringey',
#   'moment',
#   'enjoy'],
#  ['robert',
#   'anne',
#   'hathaway',
#   'be',
#   'good',
#   'lot',
#   'meaningful',
#   'scene',
#   'feel',
#   'force',
#   'due',
#   'write',
#   'dialogue'],
#  ['i',
#   'would',
#   'have',
#   'let',
#   'slide',
#   'intern',
#   'be',
#   'not',
#   'two',
#   'hour',
#   'that',
#   'be',
#   'too',
#   'much',
#   'cheese'],
#  ['story', 'be', 'beautifully', 'portrayed', 'very', 'powerful', 'actor'],
#  ['breath',
#   'fresh',
#   'air',
#   'violence',
#   'swear',
#   'politic',
#   'just',
#   'considerate',
#   'person'],
#  ['niro',
#   'be',
#   'great',
#   'help',
#   'everyone',
#   'everything',
#   'be',
#   'two',
#   'way',
#   'street',
#   'all',
#   'young',
#   'employee',
#   'be',
#   'very',
#   'respectful',
#   'too'],
#  ['george',
#   'martin',
#   'say',
#   'billy',
#   'preston',
#   's',
#   'time',
#   'beatle',
#   'be',
#   'lubricant',
#   'everyone',
#   'love',
#   'all',
#   'band',
#   'member',
#   'be',
#   'politer',
#   'other',
#   'good',
#   'spirit',
#   'there',
#   'be',
#   'pettynes',
#   'john',
#   'want',
#   'band',
#   'permanently',
#   'preston',
#   'leave',
#   'be',
#   'really',
#   'miss'],
#  ['really',
#   'great',
#   'chemistry',
#   'hathaway',
#   'subtle',
#   'intelligent',
#   'dialogue'],
#  ['however',
#   'i',
#   'think',
#   'husband',
#   'wife',
#   'role',
#   'have',
#   'be',
#   'reverse',
#   'viewer',
#   'would',
#   'not',
#   'be',
#   'so',
#   'pleased',
#   'conclusion',
#   'homemaker',
#   'should',
#   'be',
#   'totally',
#   'breadwinner',
#   'shut',
#   'up',
#   'mind',
#   'child'],
#  ['intern', 'be', 'must', 'see'],
#  ['film', 'be', 'not', 'only', 'heartwarming', 'leaf', 'good', 'feeling'],
#  ['be',
#   'such',
#   'positive',
#   'message',
#   'that',
#   'drive',
#   'home',
#   'be',
#   'good',
#   'person',
#   'hard',
#   'worker',
#   'mean'],
#  ['one', 'favorite', 'movie', 'time'],
#  ['be', 'okay'],
#  ['really',
#   'liked',
#   'play',
#   'old',
#   'person',
#   'stereotype',
#   'not',
#   'bad',
#   'way',
#   'just',
#   'ham',
#   'fisted',
#   'way'],
#  ['i', 'do', 'not', 'really', 'know', 'movie', 'be', 'try', 'teach'],
#  ['i',
#   'get',
#   'be',
#   'woman',
#   'can',
#   'be',
#   'good',
#   'boss',
#   'also',
#   'should',
#   'forgive',
#   'cheater'],
#  ['i', 'can', 'not', 'wipe', 'smile', 'face', 'watch'],
#  ['be',
#   'ultimate',
#   'feel',
#   'good',
#   'movie',
#   'tackle',
#   'issue',
#   'most',
#   'wholesome',
#   'way',
#   'possible'],
#  ['stellar', 'act', 'niro', 'hathaway', 'as', 'well'],
#  ['one',
#   'best',
#   'feel',
#   'good',
#   'movie',
#   'generation',
#   'give',
#   'nod',
#   'old',
#   'school',
#   'custom'],
#  ['i',
#   'appreciate',
#   'gentlemanly',
#   'likable',
#   'character',
#   'hathaway',
#   's',
#   'character',
#   'development',
#   'micro',
#   'macro',
#   'horrendous',
#   'husband',
#   'debacle'],
#  ['personally',
#   'could',
#   'have',
#   'do',
#   'out',
#   'part',
#   'movie',
#   'critic',
#   'already',
#   'say',
#   'movie',
#   'be',
#   'not',
#   'edgy',
#   'enough'],
#  ['i', 'will', 'watch', 'again', 'say'],
#  ['intern', 'suffer', 'lack', 'ideas', 'development', 'history'],
#  ['everything',
#   'unfold',
#   'area',
#   'almost',
#   'white',
#   'phone',
#   'golden',
#   'age',
#   'hollywood'],
#  ['have', 'problem', 'other', 'be', 'workaholic'],
#  ['problem',
#   'arise',
#   'everything',
#   'will',
#   'be',
#   'resolve',
#   'sooner',
#   'rather',
#   'later'],
#  ['nice', 'movie', 'see', 'family'],
#  ['movie',
#   'make',
#   'zero',
#   'time',
#   'basically',
#   'movie',
#   'be',
#   'u',
#   'wan',
#   'c',
#   'robert',
#   'deniro',
#   'act',
#   'reg'],
#  ['guy'],
#  ['movie',
#   'cement',
#   'love',
#   'feel',
#   'good',
#   'movie',
#   'that',
#   'start',
#   'brilliantly',
#   'introduce',
#   'scary',
#   'side',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   's',
#   'insufferable',
#   'life',
#   'which',
#   'change',
#   'lot',
#   'accidentally',
#   'find',
#   'flyer',
#   'senior',
#   'internship',
#   'program'],
#  ['movie', 'be', 'best', 'ben', 'be', 'focus'],
#  ['which',
#   'do',
#   'not',
#   'happen',
#   'too',
#   'much',
#   'thank',
#   'anne',
#   'hathaway',
#   's',
#   'character',
#   'uninteresting',
#   'go',
#   'relationship',
#   'husband',
#   'bad',
#   'actor',
#   'way'],
#  ['great', 'cast', 'enjoyable', 'story'],
#  ['entertain', 'funny', 'sometimes', 'touch', 'plot'],
#  ['good', 'acting'],
#  ['i', 'find', 'hard', 'say', 'anything', 'negative', 'film'],
#  ['hathaway', 'really', 'work', 'well', 'together'],
#  ['funny',
#   'time',
#   'heart',
#   'warm',
#   'film',
#   'prove',
#   'talent',
#   'brilliantly',
#   'more',
#   'gentle',
#   'fatherly',
#   'role'],
#  ['s', 'cute', 'be', 'pathetic', 'terrible', 'actor'],
#  ['save', 'money'],
#  ['friend',
#   'mine',
#   'be',
#   'also',
#   'movie',
#   'lover',
#   'describe',
#   'movie',
#   'few',
#   'simple',
#   'word',
#   'do',
#   'robert',
#   'de',
#   'do',
#   'movie'],
#  ['normally', 'old', 'actor', 'project', 'really'],
#  ['good',
#   'story',
#   'tell',
#   'however',
#   'never',
#   'explain',
#   'man',
#   'all',
#   'experience',
#   'could',
#   'not',
#   'take',
#   'administrative',
#   'chore',
#   'boss'],
#  ['very', 'entertaining'],
#  ['be',
#   'refresh',
#   'see',
#   'deniro',
#   'take',
#   'role',
#   'that',
#   'do',
#   'not',
#   'tap',
#   'best',
#   'act',
#   'skill',
#   'still',
#   'play',
#   'role',
#   'perfectly'],
#  ['character'],
#  ['i',
#   'have',
#   'see',
#   'movie',
#   'least',
#   'three',
#   'time',
#   'always',
#   'enjoy',
#   'time'],
#  ['robert',
#   'deniro',
#   's',
#   'character',
#   'bring',
#   'calm',
#   'focu',
#   'very',
#   'upended',
#   'office',
#   'environment'],
#  ['favorite',
#   'scene',
#   'closet',
#   'explain',
#   'man',
#   'should',
#   'carry',
#   'handkerchief'],
#  ['cute', 'movie', 'would', 'recommend'],
#  ['sentimental', 'end'],
#  ['intern', 'be', 'funny', 'heartwarming'],
#  ['be', 'wonder', 'go', 'appal', 'dirty', 'grandpa'],
#  ['actually', 'pretty', 'funny', 'heart', 'warm'],
#  ['such', 'sweet', 'film'],
#  ['i', 'laugh', 'i', 'cry'],
#  ['major',
#   'feel',
#   'good',
#   'original',
#   'best',
#   'act',
#   'i',
#   'have',
#   'see',
#   'anne',
#   'hathaway',
#   'several',
#   'year'],
#  ['would', 'highly', 'recommend'],
#  ['feel',
#   'good',
#   'movie',
#   'i',
#   'be',
#   'sure',
#   'everyone',
#   'be',
#   'go',
#   'wish',
#   'intern',
#   'now'],
#  ['lovely', 'enjoyable', 'film'],
#  ['hathaway', 'deniro', 'be', 'great', 'film'],
#  ['ok', 'movie', 'suck', 'movie'],
#  ['really',
#   'liked',
#   'movie',
#   'cast',
#   'be',
#   'great',
#   'story',
#   'full',
#   'surprise'],
#  ['next', 'genocidal', 'uprising'],
#  ['hathaway', 'be', 'great', 'form', 'intern'],
#  ['really',
#   'be',
#   'believable',
#   'ceo',
#   'jule',
#   'ostin',
#   'really',
#   'excels',
#   'role'],
#  ['nancy',
#   'meyer',
#   'really',
#   'excel',
#   'rom',
#   'com',
#   'movie',
#   'that',
#   'make',
#   'feel',
#   'character',
#   'be',
#   'believable',
#   'storyline',
#   'even',
#   'matter',
#   'absurd',
#   'might',
#   'actually',
#   'be',
#   'believable'],
#  ['aside',
#   'hathaway',
#   'be',
#   'breath',
#   'fresh',
#   'air',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'be',
#   'just',
#   'try',
#   'figure',
#   'out',
#   'life',
#   'retiree'],
#  ['only',
#   'negative',
#   'i',
#   'could',
#   'grasp',
#   'movie',
#   'be',
#   'fact',
#   'all',
#   'young',
#   'person',
#   'take',
#   'page',
#   's',
#   'experience',
#   'start',
#   'mold',
#   'way',
#   'life',
#   'never',
#   'reciprocate',
#   'behavior'],
#  ['i', 'gues', 'have', 'sign', 'up', 'facebook'],
#  ['workaholic',
#   'fan',
#   'i',
#   'really',
#   'enjoy',
#   'see',
#   'ander',
#   'more',
#   'serious',
#   'role',
#   'really',
#   'perform',
#   'quite',
#   'well'],
#  ['well', 'have', 'cry', 'be'],
#  ['great', 'chemistry', 'robert', 'deniro', 'anne', 'hathaway'],
#  ['fun', 'funny'],
#  ['perfect', 'choice', 'datenight'],
#  ['write', 'garbage'],
#  ['be', 'feel', 'good', 'movie', 'be', 'heart', 'laugh', 'nothing', 'special'],
#  ['movie',
#   'earn',
#   'one',
#   'star',
#   'be',
#   'outstandingly',
#   'bland',
#   'point',
#   'would',
#   'be',
#   'fair',
#   'call',
#   'cinematic',
#   'equivalent',
#   'pack',
#   'white',
#   'k',
#   'mart',
#   'dres',
#   'shirt',
#   'watch',
#   'use',
#   'boxxy',
#   'software',
#   'yesterday'],
#  ['one', 'word', 'not', 'bad'],
#  ['great',
#   'movie',
#   'i',
#   'love',
#   'part',
#   'i',
#   'love',
#   'spontaneity',
#   'i',
#   'have',
#   'say',
#   'robert',
#   'anne',
#   'hathaway',
#   'be',
#   'dynamic',
#   'duo',
#   'i',
#   'would',
#   'kill',
#   'see',
#   'again',
#   'i',
#   'would',
#   'watch',
#   'masterpiece',
#   'multiple',
#   'time',
#   'still',
#   'be',
#   'happy',
#   'time'],
#  ['touch', 'heart', 'felt'],
#  ['great', 'performance', 'hathaway', 'deniro'],
#  ['smart', 'witty', 'great', 'match'],
#  ['i', 'get', 'other', 'be', 'say', 'act', 'tire', 'old', 'just'],
#  ['sad', 'be', 'got', 'stoop', 'crap'],
#  ['intern', 'be', 'stack', 'pancake'],
#  ['be', 'warm', 'sweet', 'leaf', 'touch', 'belly', 'ache'],
#  ['be',
#   'doubt',
#   'drawn',
#   'cast',
#   'could',
#   'resist',
#   'movie',
#   'that',
#   'bring',
#   'together',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['be', 'best', 'actor', 'respective', 'generation', 'wow'],
#  ['keep', 'wishing', 'could', 'find', 'other', 'good', 'movie'],
#  ['intern',
#   'be',
#   'not',
#   'bad',
#   'exactly',
#   'be',
#   'light',
#   'breezy',
#   'be',
#   'real',
#   'significance'],
#  ['niro',
#   'seem',
#   'have',
#   'retire',
#   'hard',
#   'boil',
#   'challenge',
#   'role',
#   'that',
#   'make',
#   'famous',
#   'play',
#   'good',
#   'hearted',
#   'retired',
#   'widower',
#   'name',
#   'ben',
#   'whittaker'],
#  ['retire',
#   'now',
#   'defunct',
#   'company',
#   'that',
#   'make',
#   'phone',
#   'book',
#   'now',
#   'spend',
#   'day',
#   'try',
#   'figure',
#   'out',
#   'spend',
#   'day'],
#  ['wife', 'forty', 'two', 'year', 'be', 'dead', 'need', 'challenge'],
#  ['so',
#   'answer',
#   'ad',
#   'outreach',
#   'program',
#   'senior',
#   'intern',
#   'senior',
#   'age',
#   'help',
#   'out',
#   'about',
#   'fit',
#   'successful',
#   'internet',
#   'company',
#   'that',
#   'specialize',
#   'woman',
#   's',
#   'clothing'],
#  ['ben',
#   'get',
#   'unenviable',
#   'task',
#   'be',
#   'intern',
#   'company',
#   's',
#   'ceo',
#   'supposedly',
#   'tough',
#   'nail',
#   'career',
#   'woman',
#   'name',
#   'jule',
#   'ostin',
#   'hathaway'],
#  ['claim',
#   'do',
#   'not',
#   'need',
#   'romantic',
#   'comedy',
#   'law',
#   'demand',
#   'discover',
#   'much',
#   'really',
#   'do',
#   'need',
#   'not',
#   'just',
#   'office',
#   'personal',
#   'life',
#   'as',
#   'well'],
#  ['become', 'driver', 'drive', 'miss', 'hathaway'],
#  ['eventually', 'become', 'confidant'],
#  ['two',
#   'build',
#   'nice',
#   'friendship',
#   'be',
#   'relief',
#   'report',
#   'do',
#   'not',
#   'bloom',
#   'may',
#   'december'],
#  ['problem', 'be', 'be'],
#  ['movie', 'be', 'bland', 'superfluous', 'get'],
#  ['director',
#   'nancy',
#   'meyer',
#   'set',
#   'up',
#   'inner',
#   'office',
#   'environment',
#   'reverie',
#   'shop',
#   'wear',
#   'sitcom'],
#  ['be',
#   'pleasant',
#   'nice',
#   'be',
#   'only',
#   'establish',
#   'so',
#   'ben',
#   's',
#   'old',
#   'school',
#   'experience',
#   'can',
#   'teach',
#   'young',
#   'thing',
#   'two',
#   'none',
#   'have',
#   'significant',
#   'payoff'],
#  ['person',
#   'office',
#   'be',
#   'young',
#   'snapper',
#   'whose',
#   'function',
#   'film',
#   'be',
#   'be',
#   'young',
#   'whipper',
#   'snapper',
#   'do',
#   'not',
#   'matter',
#   'either'],
#  ['be',
#   'not',
#   'developed',
#   'character',
#   'be',
#   'just',
#   'onlooker',
#   'ben',
#   's',
#   'success'],
#  ['ben',
#   'develop',
#   'half',
#   'write',
#   'pointless',
#   'semi',
#   'sorta',
#   'romance',
#   'company',
#   's',
#   'site',
#   'masseuse',
#   'rene',
#   'russo',
#   'which',
#   'go',
#   'nowhere',
#   'also',
#   'do',
#   'not',
#   'seem',
#   'matter'],
#  ['plot', 'development', 'be', 'pointless', 'too'],
#  ['be',
#   'surprised',
#   'find',
#   'jule',
#   'home',
#   'life',
#   'be',
#   'burden',
#   'fact',
#   'husband',
#   'matt',
#   'give',
#   'up',
#   'career',
#   'plan',
#   'be',
#   'stay',
#   'home',
#   'dad'],
#  ['nearly',
#   'jule',
#   'matt',
#   's',
#   'scene',
#   'be',
#   'dedicate',
#   'talk',
#   'fact',
#   'never',
#   'see',
#   'other'],
#  ['hmmm'],
#  ['first', 'hour', 'intern', 'i', 'be', 'fairly', 'bore'],
#  ['i',
#   'like',
#   'jule',
#   'ben',
#   'i',
#   'want',
#   'movie',
#   'clear',
#   'out',
#   'junky',
#   'plot',
#   'point',
#   'just',
#   'let',
#   'talk',
#   'let',
#   'be',
#   'human',
#   'being',
#   'connect',
#   'other'],
#  ['point', 'movie', 'have', 'real', 'dramatic', 'tension'],
#  ['then', 'happen'],
#  ['dramatic',
#   'situation',
#   'develop',
#   'actually',
#   'seem',
#   'give',
#   'movie',
#   'dramatic',
#   'weight'],
#  ['not',
#   'give',
#   'anything',
#   'away',
#   'ben',
#   'discover',
#   'something',
#   'matt',
#   'that',
#   'trouble'],
#  ['bring',
#   'jule',
#   'two',
#   'have',
#   'heartfelt',
#   'conversation',
#   'that',
#   'seem',
#   'be',
#   'draw',
#   'character',
#   'not',
#   'screenplay'],
#  ['unfortunately',
#   'result',
#   'dramatic',
#   'event',
#   'be',
#   'crush',
#   'resolution',
#   'nobody',
#   'nobody',
#   'be',
#   'go',
#   'be',
#   'happy'],
#  ['intern',
#   'be',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'specialize',
#   'cupcake',
#   'sweet',
#   'confection',
#   'be',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'give',
#   'father',
#   'bride',
#   'movie'],
#  ['film', 'seem', 'have', 'consistent', 'pattern'],
#  ['contain',
#   'germ',
#   'human',
#   'interest',
#   'wrap',
#   'up',
#   'gimmicky',
#   'script',
#   'that',
#   'be',
#   'fit',
#   'bad',
#   'television',
#   'sitcom'],
#  ['exception',
#   'be',
#   'great',
#   'comedy',
#   'make',
#   'thirty',
#   'year',
#   'ago',
#   'call',
#   'irreconcilable',
#   'difference',
#   'kid',
#   'divorce',
#   'squabble',
#   'parent'],
#  ['movie', 'have', 'truth', 'human', 'interest'],
#  ['intern', 'have', 'only', 'faint', 'echo', 'humanity'],
#  ['have', 'moment', 'here', 'there', 'show', 'promise', 'might', 'have', 'be'],
#  ['be',
#   'nice',
#   'sweet',
#   'uncomplicated',
#   'movie',
#   'that',
#   'will',
#   'begin',
#   'disappear',
#   'mind',
#   'get',
#   'theater',
#   'will',
#   'have',
#   'leave',
#   'completely',
#   'time',
#   'get',
#   'car'],
#  ['well', 'cup', 'tea'],
#  ['binge', 'watch', 'n', 'again'],
#  ['intern',
#   'tiene',
#   'mucho',
#   'que',
#   'contar',
#   'tampoco',
#   'que',
#   'trasmitir',
#   'e',
#   'un',
#   'film',
#   'que',
#   'ver',
#   'visto',
#   'por',
#   'que',
#   'tiene',
#   'grande',
#   'cosas',
#   'que',
#   'aportar',
#   'e',
#   'una',
#   'mala',
#   'cinta',
#   'pero',
#   'realmente',
#   'tiene',
#   'mucho',
#   'que',
#   'resaltar'],
#  ['enjoyed', 'way', 'more', 'i', 'expect'],
#  ['super', 'pleasant', 'easy', 'watch', 'need', 'something', 'feel', 'good'],
#  ['hathaway', 'be', 'awesome'],
#  ['be',
#   'heartwarming',
#   'movie',
#   'muddle',
#   'plot',
#   'uneven',
#   'performance',
#   'implausible',
#   'situation'],
#  ['robert',
#   'deniro',
#   'star',
#   'retiree',
#   'lead',
#   'traditional',
#   'busines',
#   'life',
#   'be',
#   'struggle',
#   'boredom',
#   'retire',
#   'year'],
#  ['want',
#   'get',
#   'back',
#   'out',
#   'meet',
#   'person',
#   'purpose',
#   'enroll',
#   'senior',
#   'intern',
#   'program',
#   'internet',
#   'startup'],
#  ['apparently',
#   'place',
#   'only',
#   'employ',
#   'person',
#   'thirty',
#   'five',
#   'also',
#   'happen',
#   'be',
#   'loveable',
#   'character',
#   'simple',
#   'problem',
#   'that',
#   'deniro',
#   's',
#   'character',
#   'can',
#   'solve'],
#  ['deniro',
#   'play',
#   'character',
#   'compellingly',
#   'little',
#   'too',
#   'straight',
#   'convincingly',
#   'be',
#   'able',
#   'win',
#   'heart',
#   'anyone',
#   'talk',
#   'just',
#   'couple',
#   'minute'],
#  ['sadly',
#   'other',
#   'actor',
#   'be',
#   'not',
#   'caliber',
#   'wincingly',
#   'badly',
#   'direct',
#   'badly',
#   'act',
#   'scene',
#   'climax',
#   'film'],
#  ['also',
#   'do',
#   'not',
#   'think',
#   'too',
#   'hard',
#   'movie',
#   'there',
#   'be',
#   'plot',
#   'hole'],
#  ['be',
#   'nice',
#   'see',
#   'movie',
#   'value',
#   'wisdom',
#   'that',
#   'often',
#   'come',
#   'age',
#   'even',
#   'overdo',
#   'quite',
#   'bit'],
#  ['be', 'pleasant'],
#  ['i', 'really', 'enjoy', 'watch', 'movie'],
#  ['robert', 'come', 'genuine', 'sincere'],
#  ['throw', 'back', 'man', 'be', 'man'],
#  ['where', 'hanky'],
#  ['anne', 'hathaway', 'give', 'terrific', 'performance', 'as', 'well'],
#  ['be', 'great', 'date', 'movie'],
#  ['amaze', 'performance', 'as', 'well', 'awesome', 'support', 'cast'],
#  ['movie', 'have', 'hook', 'word', 'go'],
#  ['i', 'laugh', 'i', 'cry', 'i', 'be', 'invest', 'character'],
#  ['absolutely', 'love', 'one'],
#  ['all',
#   'movie',
#   'be',
#   'great',
#   'depiction',
#   'unique',
#   'friendship',
#   'generation'],
#  ['movie',
#   'have',
#   'problem',
#   'be',
#   'plot',
#   'especially',
#   'family',
#   'husband',
#   'storyline'],
#  ['end', 'be', 'abrupt', 'place', 'extremely', 'unsatisfactory'],
#  ['movie', 'make', 'cryyyy', 'so', 'much'],
#  ['not', 'sad', 'kind', 'cry', 'tear', 'up', 'know', 'good', 'movie', 'be'],
#  ['bring', 'so', 'much', 'joy'],
#  ['movie', 'really', 'touch', 'bone'],
#  ['first',
#   'time',
#   'i',
#   'cry',
#   'so',
#   'much',
#   'movie',
#   'be',
#   'just',
#   'soooo',
#   'damn',
#   'good'],
#  ['be', 'truly', 'best', 'inspiring', 'movie'],
#  ['one', 'best', 'comedy', 'drama', 'film', 'i', 'have', 'ever', 'see'],
#  ['dialogue', 'be', 'hilarious'],
#  ['chemistry', 'anne', 'hathaway', 'robert', 'be', 'fantastic', 'funny'],
#  ['great', 'work', 'lesson', 'learn', 'life', 'senior'],
#  ['let', 'know', 'importance', 'be', 'gentleman'],
#  ['comedy', 'drama', 'film', 'one', 'be', 'pretty', 'good'],
#  ['intern', 'be', 'refresh', 'change', 'pace', 'theatrically', 'speak'],
#  ['story', 'heart', 'solid', 'act', 'quite', 'bit', 'realism'],
#  ['i',
#   'love',
#   'deniro',
#   'hathaway',
#   'anyway',
#   'chemistry',
#   'two',
#   'be',
#   'very',
#   'strong'],
#  ['performance',
#   'will',
#   'not',
#   'get',
#   'recognize',
#   'award',
#   'level',
#   'i',
#   'have',
#   'not',
#   'enjoy',
#   'deniro',
#   'much',
#   'long',
#   'time'],
#  ['be', 'departure', 'be', 'precious'],
#  ['vibe',
#   'film',
#   'be',
#   'reminiscent',
#   'similarly',
#   'theme',
#   'eightys',
#   'ninetys',
#   'film',
#   'i',
#   'have',
#   'not',
#   'really',
#   'see',
#   'anything',
#   'almost',
#   'twenty',
#   'year'],
#  ['just', 'do', 'not', 'make', 'kind', 'movie', 'anymore'],
#  ['someone', 'age', 'be', 'pleasure', 'watch'],
#  ['play',
#   'mary',
#   'poppin',
#   'jeeve',
#   'type',
#   'character',
#   'never',
#   'put',
#   'foot',
#   'wrong',
#   'unbelievable',
#   'sage',
#   'kindly',
#   'old',
#   'man',
#   'can',
#   'also',
#   'get',
#   'erection',
#   'character',
#   'be',
#   'fairly',
#   'two',
#   'dimensional'],
#  ['movie', 'try', 'too', 'hard', 'be', 'progressive'],
#  ['virtually', 'shove', 'modernity', 'down', 'throat'],
#  ['here',
#   's',
#   'feminism',
#   'take',
#   'kick',
#   'nut',
#   'ageism',
#   'gender',
#   'role',
#   'boom'],
#  ['see', 'ya'],
#  ['laugh', 'genuine', 'emotion'],
#  ['overall', 'just', 'pretty', 'meh'],
#  ['pretty',
#   'much',
#   'just',
#   'ok',
#   'have',
#   'kind',
#   'touch',
#   'dramatic',
#   'moment',
#   'as',
#   'well',
#   'funny',
#   'one',
#   'also',
#   'dig',
#   'little',
#   'deep',
#   'time',
#   'that',
#   'flow',
#   'well',
#   'movie',
#   'deal',
#   'topic',
#   'work',
#   'life',
#   'balance',
#   'woman',
#   'workplace',
#   'infidelity'],
#  ['felt',
#   'kind',
#   'slow',
#   'though',
#   'fact',
#   'character',
#   'do',
#   'go',
#   'hard',
#   'time',
#   'deniros',
#   'performance',
#   'movie',
#   'general',
#   'be',
#   'so',
#   'light',
#   'hearted',
#   'be',
#   'hard',
#   'really',
#   'believe',
#   'anything',
#   'be',
#   'stake',
#   'anything',
#   'bad',
#   'would',
#   'happen'],
#  ['also',
#   'movie',
#   'feel',
#   'kind',
#   'giant',
#   'apple',
#   'advertisement',
#   'maybe',
#   'be',
#   'just'],
#  ['i', 'enjoy', 'movie'],
#  ['taught', 'milleniel', 'be', 'classy'],
#  ['movie', 'have', 'lot', 'heart'],
#  ['s', 'list', 'comedy', 'i', 'must', 'say', 'laugh', 'be', 'good', 'sparse'],
#  ['should', 'be', 'list', 'drama'],
#  ['i', 'be', 'mood', 'laugh', 's', 'i', 'pick', 'movie'],
#  ['ll', 'see', 'll', 'actually', 'share', 'few', 'tear', 'end'],
#  ['s', 'drama', 's', 'four', 'star'],
#  ['look', 'comedy', 'i', 'would', 'give', 'only', 'one', 'star'],
#  ['good', 'luck'],
#  ['great', 'movie'],
#  ['well', 'write', 'wonderful', 'cast'],
#  ['ll', 'laugh', 'maybe', 'even', 'cry', 'little'],
#  ['academy',
#   'award',
#   'winner',
#   'robert',
#   'deniro',
#   'have',
#   'be',
#   'hit',
#   'bad',
#   'time',
#   'recently',
#   'term',
#   'quality',
#   'film'],
#  ['appear',
#   'garbage',
#   'such',
#   'meet',
#   'focker',
#   'little',
#   'focker',
#   'dirty',
#   'grandpa'],
#  ['be',
#   'nice',
#   'see',
#   'trash',
#   'be',
#   'movie',
#   'deserve',
#   'talent',
#   'worth',
#   'time'],
#  ['intern', 'be', 'not', 'specatular', 'mean'],
#  ['however', 'there', 'be', 'lot', 'like'],
#  ['thing', 'like', 'most', 'be', 'deniro'],
#  ['carry', 'movie', 'shoulder', 'do', 'so', 'very', 'well'],
#  ['also',
#   'have',
#   'very',
#   'good',
#   'chemistry',
#   'academy',
#   'award',
#   'winner',
#   'anne',
#   'hathaway'],
#  ['scene', 'together', 'seem', 'very', 'genuine'],
#  ['almost', 'be', 'not', 'script'],
#  ['alone', 'make', 'movie', 'see'],
#  ['script',
#   'be',
#   'little',
#   'formulaic',
#   'term',
#   'storyline',
#   'still',
#   'make',
#   'entertaining',
#   'film',
#   'i',
#   'do',
#   'recommend'],
#  ['original', 'mostly', 'clean', 'comedy'],
#  ['loved', 'side', 'deniro'],
#  ['be',
#   'so',
#   'known',
#   'tough',
#   'guy',
#   'role',
#   'be',
#   'refresh',
#   'see',
#   'very',
#   'reserved',
#   'performance'],
#  ['ann',
#   'hathaway',
#   'make',
#   'very',
#   'touching',
#   'movie',
#   'lot',
#   'commentary',
#   'life',
#   'should',
#   'be',
#   'important'],
#  ['sweet', 'touch', 'well', 'develop', 'story', 'today'],
#  ['diabolical',
#   'romantic',
#   'non',
#   'drama',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'so',
#   'all',
#   'blame',
#   'rest'],
#  ['de', 'niro', 'have', 'own', 'reason', 'line', 'up', 'turkey'],
#  ['be',
#   'only',
#   'decent',
#   'performance',
#   'try',
#   'extract',
#   'pathos',
#   'subtlety',
#   'there',
#   'be',
#   'none'],
#  ['anne', 'hathaway', 'be', 'incredibly', 'irritate'],
#  ['real', 'clunker'],
#  ['movie', 'be', 'really', 'charm', 'especially', 'begin'],
#  ['be',
#   'go',
#   'i',
#   'keep',
#   'think',
#   'do',
#   'not',
#   'mess',
#   'up',
#   'do',
#   'not',
#   'mess',
#   'up'],
#  ['i', 'think', 'go', 'adrift', 'bit', 'i', 'still', 'like', 'overall'],
#  ['i', 'can', 'see', 'person', 'would', 'not', 'like', 'movie'],
#  ['robert',
#   's',
#   'character',
#   'be',
#   'too',
#   'perfect',
#   'end',
#   'be',
#   'tie',
#   'up',
#   'way',
#   'too',
#   'neat',
#   'scene',
#   'break',
#   'mother',
#   's',
#   'house',
#   'belong',
#   'different',
#   'movie',
#   'so'],
#  ['i',
#   'try',
#   'not',
#   'let',
#   'thing',
#   'bother',
#   'i',
#   'really',
#   'enjoy',
#   'two',
#   'lead',
#   'i',
#   'want',
#   'see',
#   'story',
#   'would',
#   'go'],
#  ['have',
#   'see',
#   'other',
#   'nancy',
#   'meyer',
#   'movie',
#   'somehow',
#   'i',
#   'have',
#   'see',
#   'know',
#   'be',
#   'get',
#   'here'],
#  ['there',
#   'be',
#   'nothing',
#   'challenge',
#   'all',
#   'memorable',
#   'will',
#   'feel',
#   'good',
#   'watching'],
#  ['thoroughly', 'enjoy'],
#  ['be', 'generally', 'good', 'movie'],
#  ['movie', 'be', 'intrigue', 'heart', 'warm'],
#  ['nice', 'film', 'easy', 'watching'],
#  ['be', 'cute', 'funny', 'movie'],
#  ['cliched', 'delightfully', 'so'],
#  ['love'],
#  ['heart', 'warm', 'funny'],
#  ['nice', 'chemistry', 'hathaway'],
#  ['far', 'one', 'new', 'favorite', 'movie'],
#  ['definitely', 'top', 'ten'],
#  ['very', 'biased', 'obvious', 'propaganda', 'piece'],
#  ['write',
#   'directed',
#   'nancy',
#   'meyer',
#   'star',
#   'movie',
#   'veteran',
#   'icon',
#   'robert',
#   'deniro',
#   'ben',
#   'whittaker',
#   'come',
#   'retirement',
#   'eventually',
#   'be',
#   'accept',
#   'intern',
#   'internet',
#   'sell',
#   'sensation',
#   'ceo',
#   'magnet',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway'],
#  ['average', 'feel', 'good', 'movie'],
#  ['cool', 'concept'],
#  ['be', 'well', 'begin'],
#  ['pretty', 'good', 'not', 'amaze'],
#  ['scott',
#   'dr',
#   'scott',
#   'allison',
#   'professor',
#   'psychology',
#   'university',
#   'richmond',
#   'well',
#   'greg',
#   'robert',
#   'doesn',
#   't',
#   'appear',
#   'be',
#   'hurry',
#   'retire',
#   'real',
#   'life',
#   'movie'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'i',
#   'find',
#   'whole',
#   'thing',
#   're',
#   'tire'],
#  ['let',
#   'recap',
#   'scott',
#   'meet',
#   'ben',
#   'whitaker',
#   'robert',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'be',
#   'restless',
#   'dissatisfied',
#   'life',
#   'retiree'],
#  ['search',
#   'something',
#   'meaningful',
#   'do',
#   'time',
#   'stumble',
#   'advertisement',
#   'senior',
#   'internship',
#   'program'],
#  ['decide',
#   'apply',
#   'intern',
#   'company',
#   'call',
#   'fit',
#   'fast',
#   'grow',
#   'busines',
#   'that',
#   'sell',
#   'fashionable',
#   'clothing',
#   'online'],
#  ['ben', 's', 'interview', 'go', 'well', 'be', 'hire', 'intern'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'new',
#   'bos',
#   'be',
#   'jule',
#   'high',
#   'strung',
#   'workaholic',
#   'young',
#   'woman',
#   'anne',
#   'hathaway',
#   'micromanage',
#   'everyone'],
#  ['first', 'shun', 'ben', 'claim', 'doesn', 't', 'need', 'assistant'],
#  ['ben',
#   'employ',
#   'old',
#   'school',
#   'discipline',
#   'never',
#   'leave',
#   'building',
#   'bos',
#   'pick',
#   'up',
#   'boss',
#   's',
#   'loose',
#   'end'],
#  ['one',
#   'day',
#   'notice',
#   'driver',
#   'be',
#   'bit',
#   'too',
#   'drunk',
#   'drive',
#   'take',
#   'place',
#   'jule'],
#  ['know', 're', 'best', 'buddy'],
#  ['scott',
#   've',
#   'be',
#   'follow',
#   'movie',
#   'review',
#   'year',
#   'know',
#   'i',
#   'haven',
#   't',
#   'be',
#   'much',
#   'fan',
#   'robert',
#   'deniro',
#   's',
#   'recent',
#   'body',
#   'work'],
#  ['intern', 'there', 'be', 'now', 'promising', 'indication', 'slump', 'be'],
#  ['deniro',
#   'shine',
#   'portrayal',
#   'retire',
#   'gentleman',
#   'bygone',
#   'era',
#   'take',
#   'role',
#   'rookie',
#   'intern',
#   'quest',
#   'inject',
#   'geezerly',
#   'life',
#   'meaning'],
#  ['not',
#   'only',
#   'find',
#   'be',
#   'look',
#   'also',
#   'manage',
#   'endow',
#   'several',
#   'other',
#   'person',
#   's',
#   'live',
#   'richness',
#   'wisdom',
#   'direction'],
#  ['hero', 's', 'journey', 'here', 'take', 'unique', 'interesting', 'form'],
#  ['ben',
#   'start',
#   'out',
#   'useless',
#   'minion',
#   'jule',
#   'time',
#   'evolve',
#   'trust',
#   'sidekick'],
#  ['end', 'film', 'ben', 'be', 'arguably', 'jule', 'equal', 'also', 'mentor'],
#  ['extent',
#   'ben',
#   'jule',
#   'be',
#   'equal',
#   'one',
#   'could',
#   'argue',
#   'be',
#   'buddy',
#   'hero',
#   'follow',
#   'classic',
#   'pattern',
#   'be',
#   'odd',
#   'other',
#   'first',
#   'then',
#   'grow',
#   'bffl',
#   's',
#   'ben',
#   'be',
#   'sidekick',
#   'mentor',
#   'buddy',
#   'be',
#   'open',
#   'interpretation',
#   'here'],
#  ['regardless', 'relationship', 'evolve', 'become', 'transformative'],
#  ['greg',
#   'i',
#   'think',
#   'movie',
#   'be',
#   'too',
#   'reminiscent',
#   'last',
#   'year',
#   's',
#   'intern',
#   'star',
#   'vince',
#   'vaughn',
#   'owen',
#   'wilson'],
#  ['similarly',
#   'have',
#   'two',
#   'old',
#   'salesman',
#   'teach',
#   'old',
#   'school',
#   'lesson',
#   'internet',
#   'savvy',
#   'youngster',
#   'google'],
#  ['intern',
#   'be',
#   'little',
#   'more',
#   'personal',
#   'ben',
#   'take',
#   'more',
#   'mentorly',
#   'role',
#   'early',
#   'film'],
#  ['fact',
#   'much',
#   'remind',
#   'butler',
#   'similar',
#   'hobson',
#   'one',
#   'thousand',
#   'nine',
#   'hundred',
#   'eighty',
#   'one',
#   's',
#   'arthur',
#   'even',
#   'mary',
#   'poppin'],
#  ['take',
#   'jule',
#   'daughter',
#   'kindergarten',
#   'fixes',
#   'relationship',
#   'stay',
#   'home',
#   'husband'],
#  ['scott',
#   'just',
#   'review',
#   'martian',
#   'astronaut',
#   'watney',
#   'graduate',
#   'hero',
#   'teacher'],
#  ['review',
#   'note',
#   'ultimate',
#   'destination',
#   'hero',
#   'be',
#   'become',
#   'mentor'],
#  ['i', 'think', 'see', 'pattern', 'revisit', 'here', 'intern'],
#  ['ben',
#   'have',
#   'be',
#   'leader',
#   'major',
#   'company',
#   'have',
#   'retire',
#   'sedate',
#   'life'],
#  ['now',
#   'new',
#   'opportunity',
#   'have',
#   'chance',
#   'pas',
#   'wealth',
#   'knowledge',
#   'not',
#   'only',
# ...
#   'nancy',
#   'meyer',
#   'sabe',
#   'hacer',
#   'unos',
#   'estupendo',
#   'chick',
#   'flick',
#   'be',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'ta',
#   'give',
#   'y',
#   'woman',
#   'want',
#   'son',
#   'alguno',
#   'ejemplos'],
#  ['intern',
#   'e',
#   'la',
#   'n',
#   'os',
#   'un',
#   'estupendo',
#   'robert',
#   'que',
#   'termina',
#   'convirti',
#   'ndose',
#   'un',
#   'practicante',
#   'una',
#   'internet',
#   'e',
#   'definitivamente',
#   'able'],
#  ['la',
#   'qu',
#   'mica',
#   'hathaway',
#   'su',
#   'joven',
#   'jefe',
#   'e',
#   'maravillosa',
#   'y',
#   'hace',
#   'cinta',
#   'algo',
#   'muy',
#   'pero',
#   'muy',
#   'entretenido'],
#  ['good',
#   'chemistry',
#   'hathaway',
#   'de',
#   'niro',
#   'carry',
#   'movie',
#   'anyone',
#   'fifty',
#   'five',
#   'will',
#   'enjoy',
#   'ageless',
#   'focu'],
#  ['recommend'],
#  ['top', 'movie', 'really', 'enjoy', 'one'],
#  ['personally',
#   'one',
#   'favourite',
#   'movie',
#   'now',
#   'time',
#   'i',
#   'watch',
#   'i',
#   'still',
#   'love',
#   'great',
#   'film'],
#  ['intern', 'be', 'shadow', 'doubt', 'two', 'thousand', 'fifteen', 'film'],
#  ['twenty', 'year', 'intern', 'would', 'not', 'be', 'make'],
#  ['atleast', 'not'],
#  ['handle',
#   'driven',
#   'young',
#   'work',
#   'woman',
#   'seemingly',
#   'infinite',
#   'hustle',
#   'stay',
#   'home',
#   'father',
#   'nary',
#   'hint',
#   'ridicule'],
#  ['character', 'accept', 'as', 'simply', 'would', 'wear', 'sock', 'shoe'],
#  ['elephant',
#   'room',
#   'be',
#   'ben',
#   'play',
#   'supurbly',
#   'robert',
#   'just',
#   'right',
#   'mix',
#   'understated',
#   'sensitivity',
#   'decade',
#   'life',
#   'experience',
#   'i',
#   'tell',
#   'snark'],
#  ['ben',
#   's',
#   'very',
#   'senior',
#   'intern',
#   'anne',
#   'hathaway',
#   's',
#   'jule',
#   'ostin',
#   'hustlin',
#   'twenty',
#   'on',
#   'century',
#   'sister',
#   'doin',
#   'daughter',
#   'stay',
#   'home',
#   'husband'],
#  ['ben',
#   'never',
#   'condescend',
#   'be',
#   'always',
#   'humble',
#   'willing',
#   'go',
#   'good',
#   'motley',
#   'crew',
#   'co',
#   'worker'],
#  ['be',
#   'take',
#   'be',
#   'logical',
#   'conclusion',
#   'dare',
#   'heist',
#   'ben',
#   'head',
#   'up',
#   'fellow',
#   'desk',
#   'jockey',
#   'delete',
#   'disparage',
#   'email',
#   'not',
#   'so',
#   'fearless',
#   'female',
#   'leader',
#   'accidently',
#   'send',
#   'mother'],
#  ['easily',
#   'film',
#   's',
#   'most',
#   'ridiculous',
#   'moment',
#   'do',
#   'not',
#   'outstay',
#   'be',
#   'welcome',
#   'serve',
#   'effective',
#   'palate',
#   'cleanser',
#   'middle',
#   'movie'],
#  ['there',
#   'be',
#   'interesting',
#   'twist',
#   'little',
#   'hiest',
#   'which',
#   'be',
#   'definitely',
#   'need',
#   'because',
#   'as',
#   'good',
#   'intern',
#   'be',
#   'never',
#   'lay',
#   'down',
#   'firm',
#   'mission',
#   'statement',
#   'lead',
#   'accomplish',
#   'end',
#   'twist',
#   'give',
#   'welcome',
#   'drama',
#   'i',
#   'find',
#   'be',
#   'very',
#   'enjoyable',
#   'sweet',
#   'likable',
#   'film'],
#  ['fine', 'nothing', 'incredible', 'groundbreaking'],
#  ['have',
#   'solid',
#   'intriguing',
#   'premise',
#   'primarily',
#   'coast',
#   'chemistry',
#   'large',
#   'cast'],
#  ['bonu', 'point', 'interior', 'design', 'porn'],
#  ['make', 'feel', 'good'],
#  ['be', 'ice', 'cream'],
#  ['plain'],
#  ['simple'],
#  ['be',
#   'one',
#   'perfect',
#   'late',
#   'night',
#   'tb',
#   'flick',
#   'catch',
#   'be',
#   'hang',
#   'out',
#   'ironically',
#   'enough',
#   'grandparent',
#   's',
#   'house'],
#  ['film', 'be', 'simple', 'cast', 'be', 'earnest', 'charm'],
#  ['leave',
#   'cynicism',
#   'door',
#   'will',
#   'be',
#   'fine',
#   'even',
#   'get',
#   'abrupt',
#   'end'],
#  ['great',
#   'movie',
#   'lot',
#   'potential',
#   'film',
#   'perfect',
#   'flow',
#   'story',
#   'great',
#   'collection',
#   'plot',
#   'awesome',
#   'pair',
#   'incredible',
#   'cast',
#   'still',
#   'robert',
#   'di',
#   'nero'],
#  ['actor'],
#  ['never', 'fail', 'amaze', 'ur', 'charm', 'performance', 'never', 'ever'],
#  ['always', 'be', 'right', 'person', 'great', 'performance'],
#  ['anna', 'be', 'also', 'incredible', 'so', 'be', 'rest', 'cast'],
#  ['overall', 'full', 'fun', 'great', 'entertainment'],
#  ['nancy', 'make', 'incredible', 'film', 'hat', 'off'],
#  ['really', 'good'],
#  ['wan', 'watch', 'twond', 'time'],
#  ['eight',
#   'thirty',
#   'one',
#   'sixteen',
#   'i',
#   'actually',
#   'dislike',
#   'watching',
#   'film'],
#  ['begin', 'i', 'do', 'enjoy', 'be', 'cute'],
#  ['while',
#   'become',
#   'very',
#   'obvious',
#   'story',
#   'be',
#   'make',
#   'up',
#   'i',
#   'could',
#   'envision',
#   'someone',
#   'sit',
#   'there',
#   'write',
#   'script'],
#  ['authenticity', 'be', 'never', 'good', 'thing'],
#  ['then',
#   'half',
#   'way',
#   'film',
#   'becomes',
#   'much',
#   'darker',
#   'quite',
#   'frankly',
#   'just',
#   'depress'],
#  ['resolution', 'end', 'be', 'not', 'really', 'good', 'resolution'],
#  ['so', 'be', 'fake', 'depress'],
#  ['not', 'great', 'entertainment', 'ask'],
#  ['be',
#   'good',
#   'end',
#   'not',
#   'such',
#   'big',
#   'fan',
#   'end',
#   'other',
#   'then',
#   'be',
#   'great',
#   'movie',
#   'great',
#   'cast'],
#  ['be', 'quite', 'nice', 'film', 'be', 'honest'],
#  ['anne', 'hathaway', 'never', 'look', 'well'],
#  ['i', 'actually', 'kind', 'like', 'all', 'year'],
#  ['bit', 'cheesy', 'be', 'worth', 'watch'],
#  ['really', 'good', 'movie'],
#  ['brilliant', 'act', 'storyline'],
#  ['enjoyable', 'forgettable'],
#  ['well', 'movie', 'then', 'recent', 'stuff'],
#  ['end', 'leave', 'lot', 'be', 'desire'],
#  ['just', 'end'],
#  ['dumb'],
#  ['relatable', 'very', 'relevant'],
#  ['dynamic', 'character', 'be', 'sweet', 'funny'],
#  ['genuine'],
#  ['be', 'ok'],
#  ['i', 'felt', 'start', 'off', 'strong', 'kind', 'fizzle', 'wore'],
#  ['i',
#   'actually',
#   'think',
#   'would',
#   'be',
#   'more',
#   'comedy',
#   'joke',
#   'do',
#   'have',
#   'be',
#   'first',
#   'half',
#   'movie'],
#  ['act', 'hathaway', 'be', 'great', 'i', 'hat', 'abrupt', 'end'],
#  ['be', 'nice', 'storyline', 'i', 'enjoy', 'watch'],
#  ['great',
#   'movie',
#   'i',
#   'do',
#   'not',
#   'want',
#   'end',
#   'last',
#   'half',
#   'movie',
#   'i',
#   'keep',
#   'thinking',
#   'be',
#   'go',
#   'hire',
#   'ben',
#   'ceo'],
#  ['cute', 'yet', 'thin', 'storyline'],
#  ['enjoy', 'pair', 'hathaway', 'de'],
#  ['felt',
#   'cheat',
#   'hathaway',
#   's',
#   'character',
#   's',
#   'obvious',
#   'storyline',
#   'wish',
#   'would',
#   'give',
#   'de',
#   's',
#   'character',
#   'more',
#   'story',
#   'be',
#   'say',
#   'maybe',
#   'be',
#   'point',
#   'have',
#   'senior',
#   'character',
#   'quietly',
#   'resolutely',
#   'prominently',
#   'affect',
#   'one',
#   's',
#   'life'],
#  ['thought',
#   'niro',
#   'be',
#   'great',
#   'young',
#   'man',
#   'provide',
#   'guidance',
#   'support'],
#  ['nice', 'watch', 'young', 'man', 'evolve'],
#  ['disneyesque', 'predictability'],
#  ['i', 'be', 'not', 'one', 'watch', 'type', 'movie'],
#  ['i', 'tend', 'prefer', 'horror', 'action'],
#  ['however', 'one', 'strays', 'expectation', 'kind'],
#  ['spoiler'],
#  ['i',
#   'be',
#   'almost',
#   'expect',
#   'scene',
#   'deniro',
#   's',
#   'character',
#   'would',
#   'mess',
#   'up',
#   'everyone',
#   'would',
#   'see',
#   'be',
#   'not',
#   'perfect',
#   'end',
#   'would',
#   'find',
#   'love',
#   'anyway',
#   'be',
#   'i',
#   'hop',
#   'elder',
#   'wisdom',
#   'provide',
#   'seem',
#   'be',
#   'answer',
#   'everything',
#   'i',
#   'think',
#   'be',
#   'be',
#   'lack',
#   'recent',
#   'generation'],
#  ['i', 'be', 'glad', 'movie', 'be', 'make'],
#  ['show',
#   'be',
#   'miss',
#   'be',
#   'need',
#   'not',
#   'only',
#   'youth',
#   'today',
#   'company',
#   'today'],
#  ['good', 'job'],
#  ['funny',
#   'pretty',
#   'witty',
#   'satire',
#   'politic',
#   'today',
#   's',
#   'busines',
#   'office'],
#  ['just', 'right', 'mix', 'serious', 'humor'],
#  ['good', 'date', 'night', 'movie'],
#  ['heartfelt', 'movie', 'great', 'story', 'fantastic', 'acting'],
#  ['retire',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'ben',
#   'play',
#   'robert',
#   'be',
#   'bore',
#   'retired',
#   'life'],
#  ['apply',
#   'be',
#   'senior',
#   'intern',
#   'online',
#   'fashion',
#   'retailer',
#   'get',
#   'position'],
#  ['founder',
#   'company',
#   'be',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway',
#   'tireless',
#   'driven',
#   'demand',
#   'dynamic',
#   'workaholic'],
#  ['ben',
#   'be',
#   'make',
#   'intern',
#   'be',
#   'nominal',
#   'role',
#   'do',
#   'not',
#   'intend',
#   'give',
#   'work',
#   'be',
#   'just',
#   'window',
#   'dress'],
#  ['however',
#   'ben',
#   'prove',
#   'be',
#   'quite',
#   'useful',
#   'more',
#   'source',
#   'support',
#   'wisdom'],
#  ['good', 'surprisingly', 'so'],
#  ['i',
#   'be',
#   'expect',
#   'farcical',
#   'half',
#   'bake',
#   'comedy',
#   'old',
#   'guy',
#   'rejoin',
#   'work',
#   'force',
#   'struggle',
#   'modern',
#   'gadget',
#   'work',
#   'process'],
#  ['there',
#   'be',
#   'few',
#   'example',
#   'movie',
#   'be',
#   'far',
#   'more',
#   'story',
#   'generational',
#   'difference'],
#  ['be', 'more', 'drama', 'comedy', 'be', 'good', 'one', 'too'],
#  ['there',
#   'be',
#   'theme',
#   'generational',
#   'wisdom',
#   'not',
#   'judge',
#   'person',
#   'age',
#   'anything',
#   'superficial',
#   'make',
#   'most',
#   'person',
#   's',
#   'talent'],
#  ['be', 'also', 'movie', 'start', 'do', 'enjoy'],
#  ['moreover', 'be', 'simply', 'nice', 'story'],
#  ['solid', 'work', 'robert', 'lead', 'role'],
#  ['do',
#   'not',
#   'do',
#   'bad',
#   'performance',
#   'have',
#   'not',
#   'stop',
#   'past',
#   'take',
#   'role',
#   'movie',
#   'that',
#   'be',
#   'well',
#   'standard'],
#  ['be', 'not', 'one', 'role', 'movie'],
#  ['sensitively', 'play', 'ideal', 'role'],
#  ['good',
#   'work',
#   'too',
#   'anne',
#   'hathaway',
#   'be',
#   'very',
#   'convincing',
#   'go',
#   'get',
#   'entrepreneur'],
#  ['bottom', 'line', 'robert', 'd', 'make', 'movie'],
#  ['really', 'enjoy'],
#  ['anne', 'hathaway', 'also', 'play', 'great', 'part', 'also'],
#  ['film', 'that', 'differentiate', 'young', 'old', 'generation'],
#  ['i', 'would', 'definitely', 'say', 'be', 'director', 's', 'best', 'film'],
#  ['i', 'have', 'like', 'other', 'film', 'be', 'lot', 'different'],
#  ['i',
#   'mean',
#   'be',
#   'well',
#   'write',
#   'screenplay',
#   'much',
#   'good',
#   'understood',
#   'contemporary',
#   'world',
#   'just',
#   'focus',
#   'relationship',
#   'usual'],
#  ['so',
#   'addition',
#   'digital',
#   'world',
#   'stuff',
#   'make',
#   'all',
#   'difference',
#   'i',
#   'completely',
#   'enjoy'],
#  ['do',
#   'not',
#   'think',
#   'would',
#   'be',
#   'internship',
#   'i',
#   'initially',
#   'think',
#   'slightly',
#   'be',
#   'much',
#   'good',
#   'everyway'],
#  ['be',
#   'go',
#   'agree',
#   'film',
#   's',
#   'poster',
#   'trailer',
#   'be',
#   'not',
#   'very',
#   'impressive',
#   'actual',
#   'film',
#   'do',
#   'grab',
#   'full',
#   'attention'],
#  ['two',
#   'hour',
#   'film',
#   'be',
#   'always',
#   'concern',
#   'film',
#   'run',
#   'long',
#   'i',
#   'can',
#   'even',
#   'sit',
#   'half',
#   'hour'],
#  ['anyway', 'story', 'runtime', 'pace', 'be', 'incredible'],
#  ['there',
#   'be',
#   'something',
#   'interesting',
#   'be',
#   'go',
#   'forget',
#   'focu',
#   'flaw',
#   'enjoy',
#   'time',
#   'which',
#   'be',
#   'i',
#   'exactly',
#   'do',
#   'here'],
#  ['be',
#   'not',
#   'comedy',
#   'be',
#   'go',
#   'laugh',
#   'openly',
#   'loud',
#   'be',
#   'comedy',
#   'sense',
#   'set',
#   'character',
#   'film',
#   'have'],
#  ['i',
#   'mean',
#   'story',
#   'be',
#   'digital',
#   'busines',
#   'most',
#   'be',
#   'computer',
#   'be',
#   'consider',
#   'geek'],
#  ['so',
#   'theirs',
#   'world',
#   'be',
#   'nothing',
#   'just',
#   'hook',
#   'work',
#   'forget',
#   'actual',
#   'world'],
#  ['even', 'someone', 'next', 'room', 'tweet'],
#  ['remind',
#   'only',
#   'have',
#   'change',
#   'not',
#   'physical',
#   'world',
#   'be',
#   'main',
#   'character',
#   'be',
#   'old',
#   'wise',
#   'influence',
#   'young',
#   'generation',
#   'person'],
#  ['so',
#   'actor',
#   'be',
#   'undoubtedly',
#   'best',
#   'thing',
#   'apart',
#   'direction',
#   'story'],
#  ['seventy',
#   'three',
#   'year',
#   'old',
#   'robert',
#   'still',
#   'impress',
#   'extraordinary',
#   'character',
#   'display'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'whoever',
#   'be',
#   'mind',
#   'be',
#   'write',
#   'role',
#   'perfectly',
#   'fit',
#   'none',
#   'other'],
#  ['then',
#   'there',
#   'be',
#   'anne',
#   'hathaway',
#   'opposite',
#   'side',
#   'equal',
#   'part'],
#  ['narration',
#   'point',
#   'view',
#   'start',
#   'deniro',
#   's',
#   'quickly',
#   'middle',
#   'take',
#   'circle',
#   'cover',
#   'other',
#   'well'],
#  ['then',
#   'come',
#   'professional',
#   'personal',
#   'life',
#   'topic',
#   'be',
#   'develop',
#   'brought',
#   'small',
#   'family',
#   'be',
#   'affected',
#   'workaholic',
#   'mother'],
#  ['so',
#   'enter',
#   'expect',
#   'comedy',
#   'probably',
#   'will',
#   'not',
#   'disappoint',
#   'deliver',
#   'wish',
#   'which',
#   'be',
#   'heartwarming',
#   'drama',
#   'emotional',
#   'moment'],
#  ['surely',
#   'recommend',
#   'especially',
#   'youngster',
#   're',
#   'addict',
#   'digital',
#   'world'],
#  ['two', 'thousand', 'twenty', 'four', 'eight', 'ten', 'zero', 'zero', 'zero'],
#  ['love', 'movie', 'beggining', 'end'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'robert',
#   'seem',
#   'too',
#   'perfect',
#   'turn',
#   'off',
#   'here'],
#  ['really', 'enjoy', 'movie'],
#  ['two', 'thousand', 'twenty', 'four', 'ten', 'ten', 'zero', 'zero', 'zero'],
#  ['intern', 'be', 'funny', 'charm', 'heartwarming'],
#  ['movie',
#   'old',
#   'man',
#   'that',
#   'be',
#   'retire',
#   'go',
#   'back',
#   'outdoor',
#   'world',
#   'get',
#   'job',
#   'intern',
#   'young',
#   'person',
#   'work',
#   'place',
#   'be',
#   'great',
#   'plot'],
#  ['i', 'think', 'movie', 'be', 'go', 'be', 'bad', 'be', 'not'],
#  ['however', 'end', 'movie', 'do', 'get', 'kind', 'boring'],
#  ['overall', 'be', 'great', 'movie'],
#  ['robert', 's', 'anne', 'hathaway', 's', 'best', 'movie', 'yet'],
#  ['two', 'thumb'],
#  ['i', 'would', 'very', 'much', 'suggest', 'movie'],
#  ['average',
#   'i',
#   'be',
#   'internally',
#   'grateful',
#   'be',
#   'take',
#   'few',
#   'minute',
#   'day',
#   'read',
#   'cheesy',
#   'review',
#   'writer',
#   'director',
#   'nancy',
#   'meyer',
#   'comedy',
#   'intern'],
#  ['i', 'hope', 'make', 'puntership', 'fly', 'color'],
#  ['anyway', 'movie', 'star', 'ben', 'whittaker'],
#  ['ben',
#   'be',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'be',
#   'live',
#   'out',
#   'retired',
#   'day',
#   'need',
#   'fill',
#   'void'],
#  ['come',
#   'opportunity',
#   'be',
#   'intern',
#   'senior',
#   'citizen',
#   'internship',
#   'program',
#   'start',
#   'up',
#   'fashion',
#   'online',
#   'company'],
#  ['anne',
#   'hathaway',
#   'co',
#   'star',
#   'jule',
#   'founder',
#   'company',
#   'first',
#   'be',
#   'reluctant',
#   'work',
#   'older',
#   'crowd',
#   'then',
#   'take',
#   'genuine',
#   'like',
#   'ben',
#   'not',
#   'only',
#   'dependable',
#   'intern',
#   'father',
#   'figure'],
#  ['course',
#   'there',
#   'be',
#   'conflict',
#   'that',
#   'be',
#   'incorporate',
#   'film',
#   'that',
#   'cause',
#   'relationship',
#   'challenge',
#   'jule',
#   'own',
#   'relationship',
#   'husband'],
#  ['i',
#   'admire',
#   'meyer',
#   'direct',
#   'first',
#   'hour',
#   'movie',
#   'then',
#   'look',
#   'intern',
#   'ran',
#   'steam',
#   'second',
#   'half',
#   'too',
#   'many',
#   'elongated',
#   'scene',
#   'be',
#   'i',
#   'could',
#   'not',
#   'give',
#   'intern',
#   'review',
#   'promotion'],
#  ['i', 'do', 'de', 'ben', 'hathaway', 'jule', 'be', 'not', 'too', 'shabby'],
#  ['intern', 'be', 'two', 'hour', 'do', 'not', 'have', 'be'],
#  ['intern',
#   'could',
#   'have',
#   'do',
#   'be',
#   'job',
#   'sheer',
#   'ninety',
#   'minute',
#   'stay',
#   'not',
#   'need',
#   'overtime',
#   'i',
#   'can',
#   'not',
#   'highly',
#   'recommend',
#   'hire',
#   'intern',
#   'movie',
#   'watch',
#   'company'],
#  ['be',
#   'really',
#   'good',
#   'movie',
#   'wholesome',
#   'not',
#   'goofy',
#   'dirty',
#   'liberal',
#   'trash',
#   'heap'],
#  ['be', 'just', 'good', 'movie'],
#  ['be', 'film', 'i', 'like', 'make', 'fell', 'good', 'happy'],
#  ['as',
#   'long',
#   'do',
#   'not',
#   'really',
#   'pay',
#   'attention',
#   'plot',
#   'be',
#   'nice',
#   'movie'],
#  ['watch',
#   'preview',
#   'i',
#   'be',
#   'reluctant',
#   'watch',
#   'film',
#   'i',
#   'think',
#   'only',
#   'possible',
#   'story',
#   'line',
#   'be',
#   'old',
#   'intern',
#   'would',
#   'end',
#   'up',
#   'die'],
#  ['movie',
#   'be',
#   'nothing',
#   'instead',
#   'be',
#   'adorable',
#   'probably',
#   'one',
#   'new',
#   'favorite',
#   'movie'],
#  ['end', 'be', 'little', 'abrupt', 'overall', 'i', 'highly', 'recommend'],
#  ['i', 'actually', 'enjoy', 'movie'],
#  ['robert', 'di', 'nero', 'be', 'fun', 'hilarious', 'downright', 'adorable'],
#  ['i',
#   'have',
#   'always',
#   'love',
#   'anne',
#   'hathaway',
#   'i',
#   'think',
#   'be',
#   'great',
#   'film'],
#  ['only', 'part', 'annoy', 'be', 'small', 'husband', 'cheat', 'story'],
#  ...]

# %%
# stopwords
def remove_verbs(words):
    verbs_to_remove = {"am", "be", "are", "was", "were", "being", "is"}
    filtered_words = [word for word in words if word not in verbs_to_remove]
    return filtered_words

processed_sentences_no_stopwords = [remove_verbs(word) for word in processed_sentences]

# %%
processed_sentences_no_stopwords
# Out:
# [['not', 'i', 'expect'],
#  ['really', 'enjoy'],
#  ['include', 'hope', 'redemption', 'end'],
#  ['true', 'feel', 'good', 'movie', 'i', 'wish', 'i', 'saw', 'theater'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'deniro',
#   'have',
#   'great',
#   'chemistry',
#   'movie',
#   'tell',
#   'great',
#   'story',
#   'two',
#   'person',
#   'generation',
#   'apart',
#   'grow',
#   'closer',
#   'learn',
#   'other'],
#  ['there', 'strong', 'character', 'development', 'solid', 'cast'],
#  ['i', 'recommend', 'anyone'],
#  ['all', 'piece', 'seem', 'there', 'truly', 'appropriate', 'third', 'act'],
#  ['intern',
#   'have',
#   'chemistry',
#   'rich',
#   'lead',
#   'performance',
#   'tenure',
#   'auteur',
#   'camera'],
#  ['brilliant', 'movie'],
#  ['so', 'warm', 'satisfying', 'so', 'move'],
#  ['recommend'],
#  ['two',
#   'bonified',
#   'great',
#   'actor',
#   'somehow',
#   'have',
#   'great',
#   'chemistry',
#   'that',
#   'truly',
#   'make',
#   'movie',
#   'worth',
#   'watch'],
#  ['rush',
#   'story',
#   'do',
#   'not',
#   'take',
#   'away',
#   'heartwarming',
#   'affect',
#   'go'],
#  ['movie', 'very', 'good'],
#  ['i', 'can', 'not', 'believe', 'other', 'critic', 'rating', 'say', 'movie'],
#  ['two', 'legendary', 'actor', 'good', 'script'],
#  ['good',
#   'film',
#   'overall',
#   'love',
#   'robert',
#   'fit',
#   'role',
#   'really',
#   'well'],
#  ['story',
#   'pretty',
#   'standard',
#   'stuff',
#   'however',
#   'fun',
#   'watch',
#   'something',
#   'take',
#   'away'],
#  ['very', 'entertaining', 'movie', 'just', 'want', 'have', 'good', 'time'],
#  ['i', 'really', 'enjoy', 'lot'],
#  ['think', 'really', 'nailed', 'part', 'top', 'game'],
#  ['well', 'watch', 'i', 'wish', 'couple', 'ending', 'go', 'different', 'way'],
#  ['gentle', 'film', 'low', 'stake', 'surface', 'level', 'lesson', 'value'],
#  ['beautifully', 'shoot', 'well', 'acted', 'story', 'lack', 'depth'],
#  ['hathaway',
#   's',
#   'mad',
#   'act',
#   'skill',
#   'manage',
#   'raise',
#   'otherwise',
#   'boring',
#   'film',
#   'very',
#   'nearly',
#   'interesting'],
#  ['odd',
#   'hathaway',
#   's',
#   'meeting',
#   'never',
#   'one',
#   'consider',
#   'hire',
#   'female',
#   'ceo'],
#  ['sadly',
#   'successful',
#   'entrepreneur',
#   'will',
#   'continue',
#   'burn',
#   'out',
#   'can',
#   'not',
#   'let',
#   'go',
#   'struggle',
#   'delegate',
#   'flawles',
#   'person',
#   'always',
#   'say',
#   'right',
#   'thing',
#   'magically',
#   'show',
#   'up'],
#  ['o', 'filme', 'que', 'bom', 'bastante', 'divertido'],
#  ['ma',
#   'o',
#   'final',
#   'n',
#   'o',
#   'fez',
#   'nenhum',
#   'sentido',
#   'filme',
#   'bem',
#   'ses',
#   'da',
#   'tarde',
#   'mesmo'],
#  ['movie',
#   'good',
#   'one',
#   'just',
#   'throw',
#   'enjoy',
#   'usually',
#   'not',
#   'type',
#   'movie',
#   'i',
#   'quite',
#   'enjoy',
#   'duo',
#   'onscreen',
#   'lesson',
#   'learn',
#   'way'],
#  ['look', 'feel', 'good', 'film'],
#  ['fantastic', 'cast', 'compelling', 'story'],
#  ['know', 'spread', 'too', 'thin', 'feel', 'outsider'],
#  ['learn', 'something', 'work', 'life', 'balance', 'fit'],
#  ['i',
#   'come',
#   'movie',
#   'i',
#   'look',
#   'wholesome',
#   'movie',
#   'that',
#   'would',
#   'make',
#   'regain',
#   'sort',
#   'faith',
#   'humanity'],
#  ['most', 'part', 'movie', 'deliver'],
#  ['i',
#   'not',
#   'sure',
#   'i',
#   'agree',
#   'decision',
#   'end',
#   'decision',
#   'i',
#   'gues'],
#  ['idk', 'first', 'half', 'very', 'wholesome', 'get', 'messy', 'end'],
#  ['i', 'gues', 'that', 'life', 'messy'],
#  ['terrible', 'movie', 'awful', 'message'],
#  ['only',
#   'give',
#   'feminism',
#   'show',
#   'woman',
#   'can',
#   'top',
#   'do',
#   'most',
#   'disgraceful',
#   'way'],
#  ['hathaway',
#   's',
#   'character',
#   'out',
#   'control',
#   'clearly',
#   'not',
#   'able',
#   'handle',
#   'grow',
#   'company',
#   'completely',
#   'oblivious',
#   'tech',
#   'not',
#   'use',
#   'email',
#   'recall',
#   'sink',
#   'even',
#   'more',
#   'power',
#   'trip',
#   'not',
#   'have',
#   'bos'],
#  ['lot', 'sham', 'new', 'generation', 'man', 'glorify', 'boomer'],
#  ['extremely', 'capitalist', 'pro', 'destroy', 'everything', 'job'],
#  ['wtf',
#   'go',
#   'bar',
#   'employee',
#   'which',
#   'do',
#   'not',
#   'know',
#   'name',
#   'too',
#   'powerful',
#   'instead',
#   'go',
#   'home',
#   'spend',
#   'time',
#   'family'],
#  ['idea',
#   'feminism',
#   'become',
#   'well',
#   'collectively',
#   'not',
#   'woman',
#   'start',
#   'act',
#   'stereotypical',
#   'man'],
#  ['also', 'sexual', 'harrassment', 'out', 'there', 'joke', 'really'],
#  ['ok', 'do', 'guy'],
#  ['special',
#   'effect',
#   'one',
#   'zero',
#   'sound',
#   'effect',
#   'one',
#   'zero',
#   'act',
#   'one',
#   'zero',
#   'story',
#   'two',
#   'zero'],
#  ['just', 'classic', 'pull', 'all', 'good', 'heartstring', 'best', 'duo'],
#  ['so', 'well', 'write', 'character', 'adorable'],
#  ['funny', 'sad', 'suspenseful', 'action', 'pack'],
#  ['could', 'good'],
#  [],
#  ['i', 'bit', 'long', 'good', 'story'],
#  ['whyyy', 'movie', 'not', 'rat', 'ninety'],
#  [],
#  ['one', 'kind'],
#  ['so', 'fresh', 'warm', 'cozy', 'positive'],
#  ['somehow', 'teach', 'way', 'living'],
#  ['i', 'always', 'go', 'hopeful', 'happy', 'content', 'watch', 'movie'],
#  ['definitely', 'must', 'watch'],
#  [],
#  ['very', 'beautiful', 'well', 'write', 'movie'],
#  ['hat', 'off', 'creator'],
#  ['tell',
#   'phone',
#   'ring',
#   'background',
#   'heart',
#   'thought',
#   'stalk',
#   'baby',
#   'mama',
#   'have',
#   'quit',
#   'immediatly'],
#  ['make', 'feel', 'warm', 'cozy', 'chest', 'very', 'nostalgic', 'feeling'],
#  ['movie', 'one', 'sweetest', 'will', 'ever', 'watch'],
#  ['have', 'comedy', 'drama', 'as', 'well', 'really', 'sweet', 'story'],
#  ['overall', 'awsome', 'movie'],
#  ['want',
#   'simply',
#   'smile',
#   'two',
#   'hour',
#   'straight',
#   'go',
#   'ahead',
#   'watch',
#   'movie'],
#  ['i',
#   'have',
#   'zero',
#   'clue',
#   'anyone',
#   'would',
#   'rat',
#   'five',
#   'star',
#   'comedy',
#   'drama'],
#  ['chemistry', 'hathaway', 'tremendous'],
#  ['i',
#   'buy',
#   'whole',
#   'thing',
#   'somehow',
#   'there',
#   'actually',
#   'decent',
#   'premise',
#   'storyline'],
#  ['simple', 'sweet'],
#  ['i',
#   'would',
#   'have',
#   'terrible',
#   'week',
#   'everything',
#   'have',
#   'go',
#   'wrong',
#   'movie',
#   'tv',
#   'hotel',
#   'room',
#   'help',
#   'distract',
#   'bit'],
#  ['i', 'find', 'smile', 'part', 'overall', 'just', 'nice', 'movie'],
#  ['deniro',
#   'hathaway',
#   'have',
#   'good',
#   'chemistry',
#   'here',
#   'overall',
#   'emotional',
#   'tone',
#   'too',
#   'mushy',
#   'feel',
#   'manipulative'],
#  ['deniro', 's', 'character', 'too', 'good', 'true'],
#  ['can', 'almost', 'get', 'away'],
#  ['message',
#   'social',
#   'gender',
#   'role',
#   'seem',
#   'overly',
#   'simplify',
#   'sort',
#   'muddy',
#   'same',
#   'time'],
#  ['attempt', 'do', 'not', 'quite', 'pull', 'off'],
#  ['serviceable'],
#  ['have', 'low', 'key', 'feel'],
#  ['something', 'bring', 'back', 'watch', 'again'],
#  ['so',
#   'there',
#   'something',
#   'i',
#   'do',
#   'not',
#   'think',
#   'ever',
#   'really',
#   'hit',
#   'mark',
#   'aim'],
#  ['cute',
#   'movie',
#   'nice',
#   'two',
#   'hour',
#   'well',
#   'spend',
#   'have',
#   'nothing',
#   'well',
#   'do'],
#  ['solid', 'flick'],
#  ['watch'],
#  ['def', 'fresh'],
#  ['don', 't', 'vibe', 'charm', 'nancy', 'meyer', 'bring', 'just', 'move'],
#  ['very', 'boring'],
#  ['seem',
#   'film',
#   'more',
#   'interested',
#   'create',
#   'statement',
#   'make',
#   'enjoyable',
#   'film'],
#  ['movie',
#   'make',
#   'person',
#   'emotional',
#   'remind',
#   'senior',
#   'person',
#   'still',
#   'very',
#   'important',
#   'society'],
#  ['robert',
#   'make',
#   'such',
#   'amazing',
#   'character',
#   'that',
#   'actually',
#   'make',
#   'feel',
#   'calm'],
#  ['anne',
#   'hathway',
#   'also',
#   'make',
#   'awsome',
#   'character',
#   'power',
#   'woman',
#   'rmaking',
#   'refrence',
#   'work',
#   'mom',
#   'which',
#   'social',
#   'issue',
#   'today'],
#  ['plot', 'good'],
#  ['movie', 'that', 'make', 'smile', 'laught', 'little'],
#  ['movie',
#   'i',
#   'do',
#   'not',
#   'know',
#   'movie',
#   'have',
#   'low',
#   'rating',
#   'believe',
#   'masterpiece',
#   'mood',
#   'changer'],
#  ['esta',
#   'pelicula',
#   'da',
#   'una',
#   'buena',
#   'vibra',
#   'con',
#   'la',
#   'talento',
#   'protagonista'],
#  ['movie', 'old', 'gold'],
#  ['nancy', 'meyer', 's', 'take', 'movie', 'breath', 'air'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'deniro',
#   'play',
#   'character',
#   'very',
#   'well',
#   'make',
#   'movie',
#   'more',
#   'interesting',
#   'watch'],
#  ['i', 'love', 'movie', 'mix', 'old', 'modern', 'reference', 'amaze'],
#  ['movie',
#   'that',
#   'don',
#   't',
#   'take',
#   'life',
#   'seriously',
#   'just',
#   'lay',
#   'back'],
#  ['therapist', 'metro', 'film', 'too', 'dark', 'knight', 'esque'],
#  ['will',
#   'one',
#   'time',
#   'classic',
#   'as',
#   'good',
#   'wonderful',
#   'life',
#   'other'],
#  ['film',
#   'do',
#   'instil',
#   'good',
#   'old',
#   'value',
#   'attribute',
#   'modern',
#   'digital',
#   'world',
#   'mixed',
#   'emotion',
#   'old',
#   'school',
#   'gentleman'],
#  ['golden', 'future', 'classic'],
#  ['great', 'movie', 'show', 'different', 'story', 'one', 'movie'],
#  ['undemanding'],
#  ['pleasant', 'way', 'spend', 'couple', 'hour'],
#  ['movie',
#   'so',
#   'wholesome',
#   'amazing',
#   'there',
#   'time',
#   'i',
#   'almost',
#   'cry',
#   'alot',
#   'time',
#   'make',
#   'smile'],
#  ['i', 'have', 'choose', 'movie', 'i', 'great', 'anne', 'hathaway', 'fan'],
#  ['so', 'obviously', 'i', 'sure', 'movie', 'great'],
#  ['i',
#   'watch',
#   'i',
#   'find',
#   'movie',
#   'fresh',
#   'watch',
#   'something',
#   'so',
#   'subtle',
#   'touch',
#   'glimpse',
#   'laugh'],
#  ['thing',
#   'which',
#   'touch',
#   'most',
#   'story',
#   'performance',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['specially',
#   'moment',
#   'work',
#   'late',
#   'night',
#   'say',
#   'use',
#   'work',
#   'same',
#   'spot',
#   'year',
#   'ago'],
#  ['must', 'watch', 'movie'],
#  ['good', 'movie'],
#  ['story', 'good', 'music', 'beautiful'],
#  ['robert', 'play', 'wonderful', 'character'],
#  ['watch'],
#  ['less', 'say'],
#  ['more', 'say'],
#  ['simple', 'story', 'end', 'apparent', 'outset'],
#  ['point', 'film', 'watch', 'plot', 'unfold'],
#  ['nothing', 'deep'],
#  ['nothing', 'urge', 'set', 'date', 'watch', 'again'],
#  ['rather', 'more', 'something', 'person', 'can', 'feel'],
#  ['interaction'],
#  ['know', 'take', 'put', 'win', 'production', 'together'],
#  ['good', 'writing'],
#  ['good', 'acting'],
#  ['all', 'rest'],
#  ['go', 'wind', 'just', 'show'],
#  ['person'],
#  ['nothing', 'more'],
#  ['wind', 'up', 'pleased', 'smile'],
#  ['pick', 'own', 'person', 'identify'],
#  ['i', 'old', 'so', 'deniro'],
#  ['value', 'keep', 'mouth', 'shut', 'more', 'often'],
#  ['pay', 'off'],
#  ['perfect', 'three', 'star'],
#  ['i', 'like', 'movie', 'start', 'finish'],
#  ['love',
#   'relationship',
#   'intern',
#   'jule',
#   'make',
#   'think',
#   'very',
#   'proud',
#   'granddad',
#   'try',
#   'help',
#   'niece',
#   'out'],
#  ['two', 'very', 'well', 'spent', 'hour'],
#  ['enjoy', 'deniro', 'first', 'time', 'awhile'],
#  ['love', 'burglary', 'sequence'],
#  ['robert', 'comedy', 'movie', 'very', 'decent', 'movie'],
#  ['do', 'enjoy'],
#  ['seven', 'five', 'ten'],
#  ['very', 'lame', 'movie', 'acting', 'force', 'most', 'scene'],
#  ['not', 'recommend'],
#  ['feel',
#   'good',
#   'dramedy',
#   'which',
#   'drawn',
#   'place',
#   'have',
#   'moment',
#   'bound',
#   'make',
#   'smile'],
#  ['i', 'surprised', 'critic', 'give', 'one', 'such', 'poor', 'rating'],
#  ['make', 'wonder', 'ever', 'know', 'enjoy', 'good', 'movie'],
#  ['not',
#   'original',
#   'raise',
#   'few',
#   'issue',
#   'may',
#   'not',
#   'agree',
#   'whatever',
#   'movie',
#   'make',
#   'then',
#   'cry',
#   'end',
#   'leave',
#   'feeling',
#   'warmth'],
#  ['i', 'enjoy', 'so', 'much'],
#  ['i',
#   'use',
#   'watch',
#   'movie',
#   'base',
#   'critic',
#   's',
#   'rating',
#   'now',
#   'i',
#   'know',
#   'good'],
#  ['touch', 'story', 'great', 'actor'],
#  ['awesome'],
#  ['script',
#   'act',
#   'two',
#   'lead',
#   'story',
#   'much',
#   'feel',
#   'relationship',
#   'very',
#   'well',
#   'do',
#   'ander',
#   'holm',
#   'act'],
#  ['jule',
#   'husband',
#   'play',
#   'actor',
#   'well',
#   'act',
#   'would',
#   'have',
#   'stellar'],
#  ['ander', 'really', 'do', 'not', 'make', 'connect', 'feel', 'husband'],
#  ['face', 'same', 'ninety', 'nine', 'time', 'screen'],
#  ['anyhow',
#   'still',
#   'well',
#   'execute',
#   'emotionally',
#   'mature',
#   'well',
#   'write',
#   'movie',
#   'watch'],
#  ['kudo', 'robert', 'deniro', 'anne', 'hathaway'],
#  ['begin',
#   'i',
#   'felt',
#   'good',
#   'while',
#   'all',
#   'cringe',
#   'come',
#   'ruin',
#   'everything'],
#  ['not', 'so', 'feel', 'good', 'movie'],
#  ['good'],
#  ['so', 'cool', 'movie'],
#  ['la',
#   'cula',
#   'trata',
#   'horrible',
#   'lo',
#   'problema',
#   'una',
#   'pareja',
#   'al',
#   'acordar',
#   'su',
#   'propia',
#   'meta',
#   'la',
#   'historia',
#   'es',
#   'mal',
#   'sima',
#   'pero',
#   'robert',
#   'hathaway',
#   'la',
#   'vuelven',
#   'aburrida'],
#  ['really', 'enjoy', 'watch', 'movie'],
#  ['love', 'performance', 'anne', 'robert'],
#  ['all', 'great', 'review'],
#  ['bad', 'movie', 'i', 'have', 'see'],
#  ['movie',
#   'reflect',
#   'work',
#   'place',
#   'that',
#   'never',
#   'thousand',
#   'year',
#   'would',
#   'exist'],
#  ['i', 'just', 'narrow', 'mind'],
#  ['whatever', 'terrible'],
#  ['movie',
#   'just',
#   'such',
#   'feel',
#   'good',
#   'movie',
#   'i',
#   'always',
#   'end',
#   'up',
#   'so',
#   'happy',
#   'watching'],
#  ['robert',
#   'ha',
#   'trovato',
#   'ormai',
#   'casa',
#   'queste',
#   'commedie',
#   'cui',
#   'pu',
#   'esprimere',
#   'un',
#   'lato',
#   'pi',
#   'divertente',
#   's',
#   'lungo',
#   'sovrastato',
#   'da',
#   'grandi',
#   'performance',
#   'drammatiche'],
#  ['intern',
#   'un',
#   'film',
#   'piacevole',
#   'originale',
#   'e',
#   'con',
#   'davvero',
#   'pochi',
#   'difetti',
#   'lo',
#   'si',
#   'guarda',
#   'con',
#   'piacere',
#   'dall',
#   'inizio',
#   'alla',
#   'fine'],
#  ['magari',
#   'sarebbe',
#   'stato',
#   'interessante',
#   'completare',
#   'con',
#   'qualche',
#   'personaggio',
#   'di',
#   'contorno',
#   'pi',
#   'interessante',
#   'tratti',
#   'si',
#   'sente',
#   'un',
#   'po',
#   'la',
#   'mancanza'],
#  ['star', 'act', 'compliment', 'other'],
#  ['very', 'enjoyable', 'movie'],
#  ['movie', 'really', 'heal'],
#  ['i', 'could', 'see', 'importance', 'occupation', 'life'],
#  ['do',
#   'work',
#   'make',
#   'think',
#   'pride',
#   'esteem',
#   'rather',
#   'obsess',
#   'money'],
#  ['good',
#   'hearted',
#   'drama',
#   'comedy',
#   'that',
#   'entertain',
#   'become',
#   'overly',
#   'sentimental'],
#  ['relax', 'watch'],
#  ['robert', 'jako', 'alfa', 'i', 'omega'],
#  ['favorite', 'movie', 'ever', 'watch'],
#  [],
#  ['one',
#   'nancy',
#   'meyer',
#   'absolute',
#   'humane',
#   'best',
#   'usual',
#   'charm',
#   'turn',
#   'sweetness',
#   'something',
#   'unexpectedly',
#   'wholesomely',
#   'hearten',
#   'benefit',
#   'finely',
#   'cast',
#   'chemistry',
#   'that',
#   'enough',
#   'make',
#   'hilarious',
#   'insightful',
#   'comedy',
#   'one',
#   'best',
#   'feel',
#   'good',
#   'film',
#   'recent',
#   'memory'],
#  [],
#  ['not',
#   'even',
#   'inmense',
#   'act',
#   'chop',
#   'deniro',
#   'hathaway',
#   'could',
#   'save',
#   'film',
#   'lack',
#   'focu',
#   'story'],
#  ['isnt', 'bad', 'movie', 'just', 'not', 'interest', 'memorable'],
#  ['bland'],
#  ['so', 'fun', 'watch', 'begin', 'end'],
#  ['i',
#   'have',
#   'always',
#   'fan',
#   'story',
#   'build',
#   'friendship',
#   'young',
#   'old',
#   'person',
#   'particularly',
#   'exchange',
#   'wisdom',
#   'which',
#   'involve',
#   'respect',
#   'mutual',
#   'admiration',
#   'compassion'],
#  ['feel', 'good', 'story'],
#  ['great', 'movie', 'very', 'wholesome', 'watch'],
#  ['two',
#   'star',
#   'fantastic',
#   'well',
#   'match',
#   'hathaway',
#   's',
#   'character',
#   'get',
#   'terrible',
#   'sexist',
#   'arch',
#   'that',
#   'seem',
#   'defend',
#   'man',
#   'cheat',
#   'woman',
#   'too',
#   'impowered'],
#  ['mark', 'zuckerberg', 'never', 'bring', 'ceo', 'teenager'],
#  ['movie', 'love', 'life', 'lesson', 'fall', 'getup'],
#  ['surprisingly', 'touch', 'happy'],
#  ['puts', 'life', 'feminism', 'work', 'marriage', 'kid', 'table', 'discuss'],
#  ['life', 'lesson', 'demonstrate', 'naturally', 'not', 'boring', 'way'],
#  ['still', 'great', 'actor'],
#  ['now', 'old', 'do', 'more', 'dramatic', 'movie', 'man', 'still', 'fire'],
#  ['facial', 'expression', 'one', 'else', 'could', 'ever', 'do'],
#  ['chemistry', 'get', 'hathaway', 'touch', 'happy'],
#  ['almost', 'connect', 'other'],
#  ['hathaway'],
#  ['gorgeous', 'frenetic', 'as', 'expressive', 'niro'],
#  ['could', 'do', 'scene', 'even', 'talk'],
#  ['intern',
#   'have',
#   'slow',
#   'tire',
#   'narrative',
#   'script',
#   'barely',
#   'move',
#   'end',
#   'disappoint'],
#  ['movie',
#   'very',
#   'sweet',
#   'do',
#   'fantastic',
#   'job',
#   'build',
#   'relationship',
#   'two',
#   'main',
#   'character'],
#  ['really', 'good', 'movie'],
#  ['not',
#   'kind',
#   'movie',
#   'i',
#   'see',
#   'i',
#   'have',
#   'admit',
#   'hathaway',
#   'very',
#   'good',
#   'together',
#   'movie'],
#  ['story',
#   'quite',
#   'clich',
#   'redeem',
#   'thank',
#   'modern',
#   'approach',
#   'chemistry',
#   'lead'],
#  ['i', 'love', 'movie'],
#  ['i', 'have', 'see', 'several', 'time'],
#  ['feel', 'good', 'film'],
#  ['i',
#   'think',
#   'whole',
#   'world',
#   'should',
#   'have',
#   'senior',
#   'intern',
#   'help',
#   'adapt',
#   'new',
#   'norm'],
#  ['also', 'make', 'feel', 'belong', 'still', 'part', 'something', 'community'],
#  ['i', 'love', 'anne', 'hathaway'],
#  ['i', 'think', 'great', 'actres'],
#  ['relationship', 'jules', 'hathaway', 'ben', 'very', 'admirable'],
#  ['father', 'more', 'colleague'],
#  ['i',
#   'do',
#   'not',
#   'though',
#   'matt',
#   'jule',
#   'husband',
#   'have',
#   'affair',
#   'make',
#   'jule',
#   'feel',
#   'fault',
#   'company',
#   'become',
#   'successful',
#   'less',
#   'two',
#   'year'],
#  ['however', 'end', 'great'],
#  ['everything', 'just', 'fell', 'place'],
#  ['so', 'anne', 'hathaway', 'do', 'leave', 'runway', 'devil', 'wear', 'prada'],
#  ['sort', 'anne', 'hathaway', 'fashion', 'cinematic', 'universe', 'perhaps'],
#  ['even', 'i', 'would', 'not', 'mind'],
#  ['joke',
#   'aside',
#   'intern',
#   'truly',
#   'heartfelt',
#   'cheerful',
#   'emotionally',
#   'uplifting',
#   'film',
#   'power',
#   'beautiful',
#   'nuanced',
#   'performance',
#   'rober',
#   'anne',
#   'hathaway'],
#  ['subplot',
#   'can',
#   'feel',
#   'irrelevant',
#   'final',
#   'story',
#   'feel',
#   'cram',
#   'fit',
#   'runtime'],
#  ['mean',
#   'film',
#   'get',
#   'boring',
#   'feel',
#   'there',
#   'not',
#   'much',
#   'substance',
#   'here'],
#  ['film', 'look', 'good', 'cinematography', 'fantastic'],
#  ['dialogue', 'quirky', 'witty'],
#  ['chemistry', 'hathaway', 'lifts', 'film', 'average', 'good'],
#  ['recommend'],
#  ['best', 'thing', 'i', 'can', 'say', 'intern', 'do', 'not', 'suck'],
#  ['draw', 'so', 'well', 'want', 'good'],
#  ['then', 'punch', 'gut', 'never', 'recover'],
#  ['end',
#   'feel',
#   'writer',
#   'get',
#   'one',
#   'yard',
#   'line',
#   'then',
#   'drop',
#   'ball'],
#  ['great', 'run', 'touchdown'],
#  ['i',
#   'pleasantly',
#   'surprised',
#   'much',
#   'i',
#   'like',
#   'movie',
#   'retire',
#   'businessman',
#   'widower',
#   'decide',
#   'apply',
#   'intern',
#   'successful',
#   'online',
#   'fashion',
#   'start',
#   'up',
#   'company',
#   'found',
#   'ambitious',
#   'jule',
#   'ostin',
#   'ann',
#   'hathaway',
#   'generation',
#   'apart',
#   'find',
#   'way',
#   'successfully',
#   'work',
#   'support',
#   'other'],
#  ['way', 'able', 'find', 'friendship', 'reliable', 'person', 'can', 'count'],
#  ['highly', 'recommended'],
#  ['have',
#   'intriguing',
#   'premise',
#   'do',
#   'not',
#   'evolve',
#   'too',
#   'much',
#   'commentaire',
#   'aside',
#   'clich',
#   'd',
#   'situation'],
#  ['still',
#   'charm',
#   'movie',
#   'good',
#   'watch',
#   'really',
#   'work',
#   'chemistry',
#   'anne',
#   'hathaway',
#   'do',
#   'best',
#   'robert',
#   'truly',
#   'standout'],
#  ['commedia',
#   'pi',
#   'che',
#   'dignitosa',
#   'che',
#   'nasconde',
#   'una',
#   'morale',
#   'pi',
#   'profonda',
#   'del',
#   'previsto',
#   'e',
#   'del',
#   'necessario'],
#  ['nella',
#   'seconda',
#   'meet',
#   'del',
#   'film',
#   'si',
#   'sbarca',
#   'territori',
#   'pericolosi',
#   'proponendo',
#   'un',
#   'idea',
#   'di',
#   'fondo',
#   'forzata',
#   'con',
#   'risvolti',
#   'narrativi',
#   'inconsistenti'],
#  ['la',
#   'buona',
#   'sintonia',
#   'tra',
#   'la',
#   'coppia',
#   'dei',
#   'protagonisti',
#   'rende',
#   'comunque',
#   'il',
#   'film',
#   'assolutamente',
#   'un',
#   'esperienza',
#   'leggera',
#   'e',
#   'passeggera'],
#  ['one', 'movie', 'that', 'just', 'put', 'happy', 'mood'],
#  ['not', 'classic', 'cinema', 'also', 'not', 'meant'],
#  ['main',
#   'succes',
#   'chemistry',
#   'entire',
#   'cast',
#   'particularly',
#   'two',
#   'lead'],
#  ['i',
#   'do',
#   'not',
#   'necessarily',
#   'dislike',
#   'film',
#   'have',
#   'way',
#   'too',
#   'many',
#   'cheesy',
#   'cringey',
#   'moment',
#   'enjoy'],
#  ['robert',
#   'anne',
#   'hathaway',
#   'good',
#   'lot',
#   'meaningful',
#   'scene',
#   'feel',
#   'force',
#   'due',
#   'write',
#   'dialogue'],
#  ['i',
#   'would',
#   'have',
#   'let',
#   'slide',
#   'intern',
#   'not',
#   'two',
#   'hour',
#   'that',
#   'too',
#   'much',
#   'cheese'],
#  ['story', 'beautifully', 'portrayed', 'very', 'powerful', 'actor'],
#  ['breath',
#   'fresh',
#   'air',
#   'violence',
#   'swear',
#   'politic',
#   'just',
#   'considerate',
#   'person'],
#  ['niro',
#   'great',
#   'help',
#   'everyone',
#   'everything',
#   'two',
#   'way',
#   'street',
#   'all',
#   'young',
#   'employee',
#   'very',
#   'respectful',
#   'too'],
#  ['george',
#   'martin',
#   'say',
#   'billy',
#   'preston',
#   's',
#   'time',
#   'beatle',
#   'lubricant',
#   'everyone',
#   'love',
#   'all',
#   'band',
#   'member',
#   'politer',
#   'other',
#   'good',
#   'spirit',
#   'there',
#   'pettynes',
#   'john',
#   'want',
#   'band',
#   'permanently',
#   'preston',
#   'leave',
#   'really',
#   'miss'],
#  ['really',
#   'great',
#   'chemistry',
#   'hathaway',
#   'subtle',
#   'intelligent',
#   'dialogue'],
#  ['however',
#   'i',
#   'think',
#   'husband',
#   'wife',
#   'role',
#   'have',
#   'reverse',
#   'viewer',
#   'would',
#   'not',
#   'so',
#   'pleased',
#   'conclusion',
#   'homemaker',
#   'should',
#   'totally',
#   'breadwinner',
#   'shut',
#   'up',
#   'mind',
#   'child'],
#  ['intern', 'must', 'see'],
#  ['film', 'not', 'only', 'heartwarming', 'leaf', 'good', 'feeling'],
#  ['such',
#   'positive',
#   'message',
#   'that',
#   'drive',
#   'home',
#   'good',
#   'person',
#   'hard',
#   'worker',
#   'mean'],
#  ['one', 'favorite', 'movie', 'time'],
#  ['okay'],
#  ['really',
#   'liked',
#   'play',
#   'old',
#   'person',
#   'stereotype',
#   'not',
#   'bad',
#   'way',
#   'just',
#   'ham',
#   'fisted',
#   'way'],
#  ['i', 'do', 'not', 'really', 'know', 'movie', 'try', 'teach'],
#  ['i',
#   'get',
#   'woman',
#   'can',
#   'good',
#   'boss',
#   'also',
#   'should',
#   'forgive',
#   'cheater'],
#  ['i', 'can', 'not', 'wipe', 'smile', 'face', 'watch'],
#  ['ultimate',
#   'feel',
#   'good',
#   'movie',
#   'tackle',
#   'issue',
#   'most',
#   'wholesome',
#   'way',
#   'possible'],
#  ['stellar', 'act', 'niro', 'hathaway', 'as', 'well'],
#  ['one',
#   'best',
#   'feel',
#   'good',
#   'movie',
#   'generation',
#   'give',
#   'nod',
#   'old',
#   'school',
#   'custom'],
#  ['i',
#   'appreciate',
#   'gentlemanly',
#   'likable',
#   'character',
#   'hathaway',
#   's',
#   'character',
#   'development',
#   'micro',
#   'macro',
#   'horrendous',
#   'husband',
#   'debacle'],
#  ['personally',
#   'could',
#   'have',
#   'do',
#   'out',
#   'part',
#   'movie',
#   'critic',
#   'already',
#   'say',
#   'movie',
#   'not',
#   'edgy',
#   'enough'],
#  ['i', 'will', 'watch', 'again', 'say'],
#  ['intern', 'suffer', 'lack', 'ideas', 'development', 'history'],
#  ['everything',
#   'unfold',
#   'area',
#   'almost',
#   'white',
#   'phone',
#   'golden',
#   'age',
#   'hollywood'],
#  ['have', 'problem', 'other', 'workaholic'],
#  ['problem',
#   'arise',
#   'everything',
#   'will',
#   'resolve',
#   'sooner',
#   'rather',
#   'later'],
#  ['nice', 'movie', 'see', 'family'],
#  ['movie',
#   'make',
#   'zero',
#   'time',
#   'basically',
#   'movie',
#   'u',
#   'wan',
#   'c',
#   'robert',
#   'deniro',
#   'act',
#   'reg'],
#  ['guy'],
#  ['movie',
#   'cement',
#   'love',
#   'feel',
#   'good',
#   'movie',
#   'that',
#   'start',
#   'brilliantly',
#   'introduce',
#   'scary',
#   'side',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   's',
#   'insufferable',
#   'life',
#   'which',
#   'change',
#   'lot',
#   'accidentally',
#   'find',
#   'flyer',
#   'senior',
#   'internship',
#   'program'],
#  ['movie', 'best', 'ben', 'focus'],
#  ['which',
#   'do',
#   'not',
#   'happen',
#   'too',
#   'much',
#   'thank',
#   'anne',
#   'hathaway',
#   's',
#   'character',
#   'uninteresting',
#   'go',
#   'relationship',
#   'husband',
#   'bad',
#   'actor',
#   'way'],
#  ['great', 'cast', 'enjoyable', 'story'],
#  ['entertain', 'funny', 'sometimes', 'touch', 'plot'],
#  ['good', 'acting'],
#  ['i', 'find', 'hard', 'say', 'anything', 'negative', 'film'],
#  ['hathaway', 'really', 'work', 'well', 'together'],
#  ['funny',
#   'time',
#   'heart',
#   'warm',
#   'film',
#   'prove',
#   'talent',
#   'brilliantly',
#   'more',
#   'gentle',
#   'fatherly',
#   'role'],
#  ['s', 'cute', 'pathetic', 'terrible', 'actor'],
#  ['save', 'money'],
#  ['friend',
#   'mine',
#   'also',
#   'movie',
#   'lover',
#   'describe',
#   'movie',
#   'few',
#   'simple',
#   'word',
#   'do',
#   'robert',
#   'de',
#   'do',
#   'movie'],
#  ['normally', 'old', 'actor', 'project', 'really'],
#  ['good',
#   'story',
#   'tell',
#   'however',
#   'never',
#   'explain',
#   'man',
#   'all',
#   'experience',
#   'could',
#   'not',
#   'take',
#   'administrative',
#   'chore',
#   'boss'],
#  ['very', 'entertaining'],
#  ['refresh',
#   'see',
#   'deniro',
#   'take',
#   'role',
#   'that',
#   'do',
#   'not',
#   'tap',
#   'best',
#   'act',
#   'skill',
#   'still',
#   'play',
#   'role',
#   'perfectly'],
#  ['character'],
#  ['i',
#   'have',
#   'see',
#   'movie',
#   'least',
#   'three',
#   'time',
#   'always',
#   'enjoy',
#   'time'],
#  ['robert',
#   'deniro',
#   's',
#   'character',
#   'bring',
#   'calm',
#   'focu',
#   'very',
#   'upended',
#   'office',
#   'environment'],
#  ['favorite',
#   'scene',
#   'closet',
#   'explain',
#   'man',
#   'should',
#   'carry',
#   'handkerchief'],
#  ['cute', 'movie', 'would', 'recommend'],
#  ['sentimental', 'end'],
#  ['intern', 'funny', 'heartwarming'],
#  ['wonder', 'go', 'appal', 'dirty', 'grandpa'],
#  ['actually', 'pretty', 'funny', 'heart', 'warm'],
#  ['such', 'sweet', 'film'],
#  ['i', 'laugh', 'i', 'cry'],
#  ['major',
#   'feel',
#   'good',
#   'original',
#   'best',
#   'act',
#   'i',
#   'have',
#   'see',
#   'anne',
#   'hathaway',
#   'several',
#   'year'],
#  ['would', 'highly', 'recommend'],
#  ['feel',
#   'good',
#   'movie',
#   'i',
#   'sure',
#   'everyone',
#   'go',
#   'wish',
#   'intern',
#   'now'],
#  ['lovely', 'enjoyable', 'film'],
#  ['hathaway', 'deniro', 'great', 'film'],
#  ['ok', 'movie', 'suck', 'movie'],
#  ['really', 'liked', 'movie', 'cast', 'great', 'story', 'full', 'surprise'],
#  ['next', 'genocidal', 'uprising'],
#  ['hathaway', 'great', 'form', 'intern'],
#  ['really', 'believable', 'ceo', 'jule', 'ostin', 'really', 'excels', 'role'],
#  ['nancy',
#   'meyer',
#   'really',
#   'excel',
#   'rom',
#   'com',
#   'movie',
#   'that',
#   'make',
#   'feel',
#   'character',
#   'believable',
#   'storyline',
#   'even',
#   'matter',
#   'absurd',
#   'might',
#   'actually',
#   'believable'],
#  ['aside',
#   'hathaway',
#   'breath',
#   'fresh',
#   'air',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'just',
#   'try',
#   'figure',
#   'out',
#   'life',
#   'retiree'],
#  ['only',
#   'negative',
#   'i',
#   'could',
#   'grasp',
#   'movie',
#   'fact',
#   'all',
#   'young',
#   'person',
#   'take',
#   'page',
#   's',
#   'experience',
#   'start',
#   'mold',
#   'way',
#   'life',
#   'never',
#   'reciprocate',
#   'behavior'],
#  ['i', 'gues', 'have', 'sign', 'up', 'facebook'],
#  ['workaholic',
#   'fan',
#   'i',
#   'really',
#   'enjoy',
#   'see',
#   'ander',
#   'more',
#   'serious',
#   'role',
#   'really',
#   'perform',
#   'quite',
#   'well'],
#  ['well', 'have', 'cry'],
#  ['great', 'chemistry', 'robert', 'deniro', 'anne', 'hathaway'],
#  ['fun', 'funny'],
#  ['perfect', 'choice', 'datenight'],
#  ['write', 'garbage'],
#  ['feel', 'good', 'movie', 'heart', 'laugh', 'nothing', 'special'],
#  ['movie',
#   'earn',
#   'one',
#   'star',
#   'outstandingly',
#   'bland',
#   'point',
#   'would',
#   'fair',
#   'call',
#   'cinematic',
#   'equivalent',
#   'pack',
#   'white',
#   'k',
#   'mart',
#   'dres',
#   'shirt',
#   'watch',
#   'use',
#   'boxxy',
#   'software',
#   'yesterday'],
#  ['one', 'word', 'not', 'bad'],
#  ['great',
#   'movie',
#   'i',
#   'love',
#   'part',
#   'i',
#   'love',
#   'spontaneity',
#   'i',
#   'have',
#   'say',
#   'robert',
#   'anne',
#   'hathaway',
#   'dynamic',
#   'duo',
#   'i',
#   'would',
#   'kill',
#   'see',
#   'again',
#   'i',
#   'would',
#   'watch',
#   'masterpiece',
#   'multiple',
#   'time',
#   'still',
#   'happy',
#   'time'],
#  ['touch', 'heart', 'felt'],
#  ['great', 'performance', 'hathaway', 'deniro'],
#  ['smart', 'witty', 'great', 'match'],
#  ['i', 'get', 'other', 'say', 'act', 'tire', 'old', 'just'],
#  ['sad', 'got', 'stoop', 'crap'],
#  ['intern', 'stack', 'pancake'],
#  ['warm', 'sweet', 'leaf', 'touch', 'belly', 'ache'],
#  ['doubt',
#   'drawn',
#   'cast',
#   'could',
#   'resist',
#   'movie',
#   'that',
#   'bring',
#   'together',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['best', 'actor', 'respective', 'generation', 'wow'],
#  ['keep', 'wishing', 'could', 'find', 'other', 'good', 'movie'],
#  ['intern',
#   'not',
#   'bad',
#   'exactly',
#   'light',
#   'breezy',
#   'real',
#   'significance'],
#  ['niro',
#   'seem',
#   'have',
#   'retire',
#   'hard',
#   'boil',
#   'challenge',
#   'role',
#   'that',
#   'make',
#   'famous',
#   'play',
#   'good',
#   'hearted',
#   'retired',
#   'widower',
#   'name',
#   'ben',
#   'whittaker'],
#  ['retire',
#   'now',
#   'defunct',
#   'company',
#   'that',
#   'make',
#   'phone',
#   'book',
#   'now',
#   'spend',
#   'day',
#   'try',
#   'figure',
#   'out',
#   'spend',
#   'day'],
#  ['wife', 'forty', 'two', 'year', 'dead', 'need', 'challenge'],
#  ['so',
#   'answer',
#   'ad',
#   'outreach',
#   'program',
#   'senior',
#   'intern',
#   'senior',
#   'age',
#   'help',
#   'out',
#   'about',
#   'fit',
#   'successful',
#   'internet',
#   'company',
#   'that',
#   'specialize',
#   'woman',
#   's',
#   'clothing'],
#  ['ben',
#   'get',
#   'unenviable',
#   'task',
#   'intern',
#   'company',
#   's',
#   'ceo',
#   'supposedly',
#   'tough',
#   'nail',
#   'career',
#   'woman',
#   'name',
#   'jule',
#   'ostin',
#   'hathaway'],
#  ['claim',
#   'do',
#   'not',
#   'need',
#   'romantic',
#   'comedy',
#   'law',
#   'demand',
#   'discover',
#   'much',
#   'really',
#   'do',
#   'need',
#   'not',
#   'just',
#   'office',
#   'personal',
#   'life',
#   'as',
#   'well'],
#  ['become', 'driver', 'drive', 'miss', 'hathaway'],
#  ['eventually', 'become', 'confidant'],
#  ['two',
#   'build',
#   'nice',
#   'friendship',
#   'relief',
#   'report',
#   'do',
#   'not',
#   'bloom',
#   'may',
#   'december'],
#  ['problem'],
#  ['movie', 'bland', 'superfluous', 'get'],
#  ['director',
#   'nancy',
#   'meyer',
#   'set',
#   'up',
#   'inner',
#   'office',
#   'environment',
#   'reverie',
#   'shop',
#   'wear',
#   'sitcom'],
#  ['pleasant',
#   'nice',
#   'only',
#   'establish',
#   'so',
#   'ben',
#   's',
#   'old',
#   'school',
#   'experience',
#   'can',
#   'teach',
#   'young',
#   'thing',
#   'two',
#   'none',
#   'have',
#   'significant',
#   'payoff'],
#  ['person',
#   'office',
#   'young',
#   'snapper',
#   'whose',
#   'function',
#   'film',
#   'young',
#   'whipper',
#   'snapper',
#   'do',
#   'not',
#   'matter',
#   'either'],
#  ['not', 'developed', 'character', 'just', 'onlooker', 'ben', 's', 'success'],
#  ['ben',
#   'develop',
#   'half',
#   'write',
#   'pointless',
#   'semi',
#   'sorta',
#   'romance',
#   'company',
#   's',
#   'site',
#   'masseuse',
#   'rene',
#   'russo',
#   'which',
#   'go',
#   'nowhere',
#   'also',
#   'do',
#   'not',
#   'seem',
#   'matter'],
#  ['plot', 'development', 'pointless', 'too'],
#  ['surprised',
#   'find',
#   'jule',
#   'home',
#   'life',
#   'burden',
#   'fact',
#   'husband',
#   'matt',
#   'give',
#   'up',
#   'career',
#   'plan',
#   'stay',
#   'home',
#   'dad'],
#  ['nearly',
#   'jule',
#   'matt',
#   's',
#   'scene',
#   'dedicate',
#   'talk',
#   'fact',
#   'never',
#   'see',
#   'other'],
#  ['hmmm'],
#  ['first', 'hour', 'intern', 'i', 'fairly', 'bore'],
#  ['i',
#   'like',
#   'jule',
#   'ben',
#   'i',
#   'want',
#   'movie',
#   'clear',
#   'out',
#   'junky',
#   'plot',
#   'point',
#   'just',
#   'let',
#   'talk',
#   'let',
#   'human',
#   'connect',
#   'other'],
#  ['point', 'movie', 'have', 'real', 'dramatic', 'tension'],
#  ['then', 'happen'],
#  ['dramatic',
#   'situation',
#   'develop',
#   'actually',
#   'seem',
#   'give',
#   'movie',
#   'dramatic',
#   'weight'],
#  ['not',
#   'give',
#   'anything',
#   'away',
#   'ben',
#   'discover',
#   'something',
#   'matt',
#   'that',
#   'trouble'],
#  ['bring',
#   'jule',
#   'two',
#   'have',
#   'heartfelt',
#   'conversation',
#   'that',
#   'seem',
#   'draw',
#   'character',
#   'not',
#   'screenplay'],
#  ['unfortunately',
#   'result',
#   'dramatic',
#   'event',
#   'crush',
#   'resolution',
#   'nobody',
#   'nobody',
#   'go',
#   'happy'],
#  ['intern',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'specialize',
#   'cupcake',
#   'sweet',
#   'confection',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'give',
#   'father',
#   'bride',
#   'movie'],
#  ['film', 'seem', 'have', 'consistent', 'pattern'],
#  ['contain',
#   'germ',
#   'human',
#   'interest',
#   'wrap',
#   'up',
#   'gimmicky',
#   'script',
#   'that',
#   'fit',
#   'bad',
#   'television',
#   'sitcom'],
#  ['exception',
#   'great',
#   'comedy',
#   'make',
#   'thirty',
#   'year',
#   'ago',
#   'call',
#   'irreconcilable',
#   'difference',
#   'kid',
#   'divorce',
#   'squabble',
#   'parent'],
#  ['movie', 'have', 'truth', 'human', 'interest'],
#  ['intern', 'have', 'only', 'faint', 'echo', 'humanity'],
#  ['have', 'moment', 'here', 'there', 'show', 'promise', 'might', 'have'],
#  ['nice',
#   'sweet',
#   'uncomplicated',
#   'movie',
#   'that',
#   'will',
#   'begin',
#   'disappear',
#   'mind',
#   'get',
#   'theater',
#   'will',
#   'have',
#   'leave',
#   'completely',
#   'time',
#   'get',
#   'car'],
#  ['well', 'cup', 'tea'],
#  ['binge', 'watch', 'n', 'again'],
#  ['intern',
#   'tiene',
#   'mucho',
#   'que',
#   'contar',
#   'tampoco',
#   'que',
#   'trasmitir',
#   'e',
#   'un',
#   'film',
#   'que',
#   'ver',
#   'visto',
#   'por',
#   'que',
#   'tiene',
#   'grande',
#   'cosas',
#   'que',
#   'aportar',
#   'e',
#   'una',
#   'mala',
#   'cinta',
#   'pero',
#   'realmente',
#   'tiene',
#   'mucho',
#   'que',
#   'resaltar'],
#  ['enjoyed', 'way', 'more', 'i', 'expect'],
#  ['super', 'pleasant', 'easy', 'watch', 'need', 'something', 'feel', 'good'],
#  ['hathaway', 'awesome'],
#  ['heartwarming',
#   'movie',
#   'muddle',
#   'plot',
#   'uneven',
#   'performance',
#   'implausible',
#   'situation'],
#  ['robert',
#   'deniro',
#   'star',
#   'retiree',
#   'lead',
#   'traditional',
#   'busines',
#   'life',
#   'struggle',
#   'boredom',
#   'retire',
#   'year'],
#  ['want',
#   'get',
#   'back',
#   'out',
#   'meet',
#   'person',
#   'purpose',
#   'enroll',
#   'senior',
#   'intern',
#   'program',
#   'internet',
#   'startup'],
#  ['apparently',
#   'place',
#   'only',
#   'employ',
#   'person',
#   'thirty',
#   'five',
#   'also',
#   'happen',
#   'loveable',
#   'character',
#   'simple',
#   'problem',
#   'that',
#   'deniro',
#   's',
#   'character',
#   'can',
#   'solve'],
#  ['deniro',
#   'play',
#   'character',
#   'compellingly',
#   'little',
#   'too',
#   'straight',
#   'convincingly',
#   'able',
#   'win',
#   'heart',
#   'anyone',
#   'talk',
#   'just',
#   'couple',
#   'minute'],
#  ['sadly',
#   'other',
#   'actor',
#   'not',
#   'caliber',
#   'wincingly',
#   'badly',
#   'direct',
#   'badly',
#   'act',
#   'scene',
#   'climax',
#   'film'],
#  ['also',
#   'do',
#   'not',
#   'think',
#   'too',
#   'hard',
#   'movie',
#   'there',
#   'plot',
#   'hole'],
#  ['nice',
#   'see',
#   'movie',
#   'value',
#   'wisdom',
#   'that',
#   'often',
#   'come',
#   'age',
#   'even',
#   'overdo',
#   'quite',
#   'bit'],
#  ['pleasant'],
#  ['i', 'really', 'enjoy', 'watch', 'movie'],
#  ['robert', 'come', 'genuine', 'sincere'],
#  ['throw', 'back', 'man', 'man'],
#  ['where', 'hanky'],
#  ['anne', 'hathaway', 'give', 'terrific', 'performance', 'as', 'well'],
#  ['great', 'date', 'movie'],
#  ['amaze', 'performance', 'as', 'well', 'awesome', 'support', 'cast'],
#  ['movie', 'have', 'hook', 'word', 'go'],
#  ['i', 'laugh', 'i', 'cry', 'i', 'invest', 'character'],
#  ['absolutely', 'love', 'one'],
#  ['all', 'movie', 'great', 'depiction', 'unique', 'friendship', 'generation'],
#  ['movie',
#   'have',
#   'problem',
#   'plot',
#   'especially',
#   'family',
#   'husband',
#   'storyline'],
#  ['end', 'abrupt', 'place', 'extremely', 'unsatisfactory'],
#  ['movie', 'make', 'cryyyy', 'so', 'much'],
#  ['not', 'sad', 'kind', 'cry', 'tear', 'up', 'know', 'good', 'movie'],
#  ['bring', 'so', 'much', 'joy'],
#  ['movie', 'really', 'touch', 'bone'],
#  ['first',
#   'time',
#   'i',
#   'cry',
#   'so',
#   'much',
#   'movie',
#   'just',
#   'soooo',
#   'damn',
#   'good'],
#  ['truly', 'best', 'inspiring', 'movie'],
#  ['one', 'best', 'comedy', 'drama', 'film', 'i', 'have', 'ever', 'see'],
#  ['dialogue', 'hilarious'],
#  ['chemistry', 'anne', 'hathaway', 'robert', 'fantastic', 'funny'],
#  ['great', 'work', 'lesson', 'learn', 'life', 'senior'],
#  ['let', 'know', 'importance', 'gentleman'],
#  ['comedy', 'drama', 'film', 'one', 'pretty', 'good'],
#  ['intern', 'refresh', 'change', 'pace', 'theatrically', 'speak'],
#  ['story', 'heart', 'solid', 'act', 'quite', 'bit', 'realism'],
#  ['i',
#   'love',
#   'deniro',
#   'hathaway',
#   'anyway',
#   'chemistry',
#   'two',
#   'very',
#   'strong'],
#  ['performance',
#   'will',
#   'not',
#   'get',
#   'recognize',
#   'award',
#   'level',
#   'i',
#   'have',
#   'not',
#   'enjoy',
#   'deniro',
#   'much',
#   'long',
#   'time'],
#  ['departure', 'precious'],
#  ['vibe',
#   'film',
#   'reminiscent',
#   'similarly',
#   'theme',
#   'eightys',
#   'ninetys',
#   'film',
#   'i',
#   'have',
#   'not',
#   'really',
#   'see',
#   'anything',
#   'almost',
#   'twenty',
#   'year'],
#  ['just', 'do', 'not', 'make', 'kind', 'movie', 'anymore'],
#  ['someone', 'age', 'pleasure', 'watch'],
#  ['play',
#   'mary',
#   'poppin',
#   'jeeve',
#   'type',
#   'character',
#   'never',
#   'put',
#   'foot',
#   'wrong',
#   'unbelievable',
#   'sage',
#   'kindly',
#   'old',
#   'man',
#   'can',
#   'also',
#   'get',
#   'erection',
#   'character',
#   'fairly',
#   'two',
#   'dimensional'],
#  ['movie', 'try', 'too', 'hard', 'progressive'],
#  ['virtually', 'shove', 'modernity', 'down', 'throat'],
#  ['here',
#   's',
#   'feminism',
#   'take',
#   'kick',
#   'nut',
#   'ageism',
#   'gender',
#   'role',
#   'boom'],
#  ['see', 'ya'],
#  ['laugh', 'genuine', 'emotion'],
#  ['overall', 'just', 'pretty', 'meh'],
#  ['pretty',
#   'much',
#   'just',
#   'ok',
#   'have',
#   'kind',
#   'touch',
#   'dramatic',
#   'moment',
#   'as',
#   'well',
#   'funny',
#   'one',
#   'also',
#   'dig',
#   'little',
#   'deep',
#   'time',
#   'that',
#   'flow',
#   'well',
#   'movie',
#   'deal',
#   'topic',
#   'work',
#   'life',
#   'balance',
#   'woman',
#   'workplace',
#   'infidelity'],
#  ['felt',
#   'kind',
#   'slow',
#   'though',
#   'fact',
#   'character',
#   'do',
#   'go',
#   'hard',
#   'time',
#   'deniros',
#   'performance',
#   'movie',
#   'general',
#   'so',
#   'light',
#   'hearted',
#   'hard',
#   'really',
#   'believe',
#   'anything',
#   'stake',
#   'anything',
#   'bad',
#   'would',
#   'happen'],
#  ['also',
#   'movie',
#   'feel',
#   'kind',
#   'giant',
#   'apple',
#   'advertisement',
#   'maybe',
#   'just'],
#  ['i', 'enjoy', 'movie'],
#  ['taught', 'milleniel', 'classy'],
#  ['movie', 'have', 'lot', 'heart'],
#  ['s', 'list', 'comedy', 'i', 'must', 'say', 'laugh', 'good', 'sparse'],
#  ['should', 'list', 'drama'],
#  ['i', 'mood', 'laugh', 's', 'i', 'pick', 'movie'],
#  ['ll', 'see', 'll', 'actually', 'share', 'few', 'tear', 'end'],
#  ['s', 'drama', 's', 'four', 'star'],
#  ['look', 'comedy', 'i', 'would', 'give', 'only', 'one', 'star'],
#  ['good', 'luck'],
#  ['great', 'movie'],
#  ['well', 'write', 'wonderful', 'cast'],
#  ['ll', 'laugh', 'maybe', 'even', 'cry', 'little'],
#  ['academy',
#   'award',
#   'winner',
#   'robert',
#   'deniro',
#   'have',
#   'hit',
#   'bad',
#   'time',
#   'recently',
#   'term',
#   'quality',
#   'film'],
#  ['appear',
#   'garbage',
#   'such',
#   'meet',
#   'focker',
#   'little',
#   'focker',
#   'dirty',
#   'grandpa'],
#  ['nice', 'see', 'trash', 'movie', 'deserve', 'talent', 'worth', 'time'],
#  ['intern', 'not', 'specatular', 'mean'],
#  ['however', 'there', 'lot', 'like'],
#  ['thing', 'like', 'most', 'deniro'],
#  ['carry', 'movie', 'shoulder', 'do', 'so', 'very', 'well'],
#  ['also',
#   'have',
#   'very',
#   'good',
#   'chemistry',
#   'academy',
#   'award',
#   'winner',
#   'anne',
#   'hathaway'],
#  ['scene', 'together', 'seem', 'very', 'genuine'],
#  ['almost', 'not', 'script'],
#  ['alone', 'make', 'movie', 'see'],
#  ['script',
#   'little',
#   'formulaic',
#   'term',
#   'storyline',
#   'still',
#   'make',
#   'entertaining',
#   'film',
#   'i',
#   'do',
#   'recommend'],
#  ['original', 'mostly', 'clean', 'comedy'],
#  ['loved', 'side', 'deniro'],
#  ['so',
#   'known',
#   'tough',
#   'guy',
#   'role',
#   'refresh',
#   'see',
#   'very',
#   'reserved',
#   'performance'],
#  ['ann',
#   'hathaway',
#   'make',
#   'very',
#   'touching',
#   'movie',
#   'lot',
#   'commentary',
#   'life',
#   'should',
#   'important'],
#  ['sweet', 'touch', 'well', 'develop', 'story', 'today'],
#  ['diabolical',
#   'romantic',
#   'non',
#   'drama',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'so',
#   'all',
#   'blame',
#   'rest'],
#  ['de', 'niro', 'have', 'own', 'reason', 'line', 'up', 'turkey'],
#  ['only',
#   'decent',
#   'performance',
#   'try',
#   'extract',
#   'pathos',
#   'subtlety',
#   'there',
#   'none'],
#  ['anne', 'hathaway', 'incredibly', 'irritate'],
#  ['real', 'clunker'],
#  ['movie', 'really', 'charm', 'especially', 'begin'],
#  ['go',
#   'i',
#   'keep',
#   'think',
#   'do',
#   'not',
#   'mess',
#   'up',
#   'do',
#   'not',
#   'mess',
#   'up'],
#  ['i', 'think', 'go', 'adrift', 'bit', 'i', 'still', 'like', 'overall'],
#  ['i', 'can', 'see', 'person', 'would', 'not', 'like', 'movie'],
#  ['robert',
#   's',
#   'character',
#   'too',
#   'perfect',
#   'end',
#   'tie',
#   'up',
#   'way',
#   'too',
#   'neat',
#   'scene',
#   'break',
#   'mother',
#   's',
#   'house',
#   'belong',
#   'different',
#   'movie',
#   'so'],
#  ['i',
#   'try',
#   'not',
#   'let',
#   'thing',
#   'bother',
#   'i',
#   'really',
#   'enjoy',
#   'two',
#   'lead',
#   'i',
#   'want',
#   'see',
#   'story',
#   'would',
#   'go'],
#  ['have',
#   'see',
#   'other',
#   'nancy',
#   'meyer',
#   'movie',
#   'somehow',
#   'i',
#   'have',
#   'see',
#   'know',
#   'get',
#   'here'],
#  ['there',
#   'nothing',
#   'challenge',
#   'all',
#   'memorable',
#   'will',
#   'feel',
#   'good',
#   'watching'],
#  ['thoroughly', 'enjoy'],
#  ['generally', 'good', 'movie'],
#  ['movie', 'intrigue', 'heart', 'warm'],
#  ['nice', 'film', 'easy', 'watching'],
#  ['cute', 'funny', 'movie'],
#  ['cliched', 'delightfully', 'so'],
#  ['love'],
#  ['heart', 'warm', 'funny'],
#  ['nice', 'chemistry', 'hathaway'],
#  ['far', 'one', 'new', 'favorite', 'movie'],
#  ['definitely', 'top', 'ten'],
#  ['very', 'biased', 'obvious', 'propaganda', 'piece'],
#  ['write',
#   'directed',
#   'nancy',
#   'meyer',
#   'star',
#   'movie',
#   'veteran',
#   'icon',
#   'robert',
#   'deniro',
#   'ben',
#   'whittaker',
#   'come',
#   'retirement',
#   'eventually',
#   'accept',
#   'intern',
#   'internet',
#   'sell',
#   'sensation',
#   'ceo',
#   'magnet',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway'],
#  ['average', 'feel', 'good', 'movie'],
#  ['cool', 'concept'],
#  ['well', 'begin'],
#  ['pretty', 'good', 'not', 'amaze'],
#  ['scott',
#   'dr',
#   'scott',
#   'allison',
#   'professor',
#   'psychology',
#   'university',
#   'richmond',
#   'well',
#   'greg',
#   'robert',
#   'doesn',
#   't',
#   'appear',
#   'hurry',
#   'retire',
#   'real',
#   'life',
#   'movie'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'i',
#   'find',
#   'whole',
#   'thing',
#   're',
#   'tire'],
#  ['let',
#   'recap',
#   'scott',
#   'meet',
#   'ben',
#   'whitaker',
#   'robert',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'restless',
#   'dissatisfied',
#   'life',
#   'retiree'],
#  ['search',
#   'something',
#   'meaningful',
#   'do',
#   'time',
#   'stumble',
#   'advertisement',
#   'senior',
#   'internship',
#   'program'],
#  ['decide',
#   'apply',
#   'intern',
#   'company',
#   'call',
#   'fit',
#   'fast',
#   'grow',
#   'busines',
#   'that',
#   'sell',
#   'fashionable',
#   'clothing',
#   'online'],
#  ['ben', 's', 'interview', 'go', 'well', 'hire', 'intern'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'new',
#   'bos',
#   'jule',
#   'high',
#   'strung',
#   'workaholic',
#   'young',
#   'woman',
#   'anne',
#   'hathaway',
#   'micromanage',
#   'everyone'],
#  ['first', 'shun', 'ben', 'claim', 'doesn', 't', 'need', 'assistant'],
#  ['ben',
#   'employ',
#   'old',
#   'school',
#   'discipline',
#   'never',
#   'leave',
#   'building',
#   'bos',
#   'pick',
#   'up',
#   'boss',
#   's',
#   'loose',
#   'end'],
#  ['one',
#   'day',
#   'notice',
#   'driver',
#   'bit',
#   'too',
#   'drunk',
#   'drive',
#   'take',
#   'place',
#   'jule'],
#  ['know', 're', 'best', 'buddy'],
#  ['scott',
#   've',
#   'follow',
#   'movie',
#   'review',
#   'year',
#   'know',
#   'i',
#   'haven',
#   't',
#   'much',
#   'fan',
#   'robert',
#   'deniro',
#   's',
#   'recent',
#   'body',
#   'work'],
#  ['intern', 'there', 'now', 'promising', 'indication', 'slump'],
#  ['deniro',
#   'shine',
#   'portrayal',
#   'retire',
#   'gentleman',
#   'bygone',
#   'era',
#   'take',
#   'role',
#   'rookie',
#   'intern',
#   'quest',
#   'inject',
#   'geezerly',
#   'life',
#   'meaning'],
#  ['not',
#   'only',
#   'find',
#   'look',
#   'also',
#   'manage',
#   'endow',
#   'several',
#   'other',
#   'person',
#   's',
#   'live',
#   'richness',
#   'wisdom',
#   'direction'],
#  ['hero', 's', 'journey', 'here', 'take', 'unique', 'interesting', 'form'],
#  ['ben',
#   'start',
#   'out',
#   'useless',
#   'minion',
#   'jule',
#   'time',
#   'evolve',
#   'trust',
#   'sidekick'],
#  ['end', 'film', 'ben', 'arguably', 'jule', 'equal', 'also', 'mentor'],
#  ['extent',
#   'ben',
#   'jule',
#   'equal',
#   'one',
#   'could',
#   'argue',
#   'buddy',
#   'hero',
#   'follow',
#   'classic',
#   'pattern',
#   'odd',
#   'other',
#   'first',
#   'then',
#   'grow',
#   'bffl',
#   's',
#   'ben',
#   'sidekick',
#   'mentor',
#   'buddy',
#   'open',
#   'interpretation',
#   'here'],
#  ['regardless', 'relationship', 'evolve', 'become', 'transformative'],
#  ['greg',
#   'i',
#   'think',
#   'movie',
#   'too',
#   'reminiscent',
#   'last',
#   'year',
#   's',
#   'intern',
#   'star',
#   'vince',
#   'vaughn',
#   'owen',
#   'wilson'],
#  ['similarly',
#   'have',
#   'two',
#   'old',
#   'salesman',
#   'teach',
#   'old',
#   'school',
#   'lesson',
#   'internet',
#   'savvy',
#   'youngster',
#   'google'],
#  ['intern',
#   'little',
#   'more',
#   'personal',
#   'ben',
#   'take',
#   'more',
#   'mentorly',
#   'role',
#   'early',
#   'film'],
#  ['fact',
#   'much',
#   'remind',
#   'butler',
#   'similar',
#   'hobson',
#   'one',
#   'thousand',
#   'nine',
#   'hundred',
#   'eighty',
#   'one',
#   's',
#   'arthur',
#   'even',
#   'mary',
#   'poppin'],
#  ['take',
#   'jule',
#   'daughter',
#   'kindergarten',
#   'fixes',
#   'relationship',
#   'stay',
#   'home',
#   'husband'],
#  ['scott',
#   'just',
#   'review',
#   'martian',
#   'astronaut',
#   'watney',
#   'graduate',
#   'hero',
#   'teacher'],
#  ['review', 'note', 'ultimate', 'destination', 'hero', 'become', 'mentor'],
#  ['i', 'think', 'see', 'pattern', 'revisit', 'here', 'intern'],
#  ['ben',
#   'have',
#   'leader',
#   'major',
#   'company',
#   'have',
#   'retire',
#   'sedate',
#   'life'],
#  ['now',
#   'new',
#   'opportunity',
#   'have',
#   'chance',
#   'pas',
#   'wealth',
#   'knowledge',
#   'not',
#   'only',
#   'jules',
#   'also',
#   'all',
#   'member',
#   'staff'],
#  ['have', 'find', 'final', 'destination'],
#  ['scott',
#   'greg',
#   'movie',
#   'have',
#   'sweetnes',
#   'i',
#   'find',
#   'extremely',
#   'appeal'],
#  ['lead',
#   'character',
#   'need',
#   'something',
#   'need',
#   'can',
#   'only',
#   'find',
#   'help',
#   'other'],
#  ['jule', 'want', 'see', 'independent', 'so', 'resist', 'ben', 's', 'help'],
#  ['smart',
#   'enough',
#   'know',
#   'ben',
#   'represent',
#   'threat',
#   'authority',
#   'legitimacy',
#   'leader'],
#  ['so',
#   'bends',
#   'befit',
#   'good',
#   'hero',
#   'story',
#   'receptivity',
#   'change',
#   'bring',
#   'about',
#   'deep',
#   'hurt',
#   'devastate',
#   'reality',
#   'husband',
#   'cheat'],
#  ['point',
#   'out',
#   'greg',
#   'ben',
#   'have',
#   'already',
#   'accomplish',
#   'life',
#   'many',
#   'goal',
#   'jule',
#   'now',
#   'seek'],
#  ['so',
#   'developmentally',
#   'ready',
#   'just',
#   'assume',
#   'help',
#   'role',
#   'mentoring',
#   'function'],
#  ['say', 'student', 'ready', 'teacher', 'will', 'appear'],
#  ['first', 'half', 'movie', 'devote', 'jule', 'not', 'ready'],
#  ['hero', 'humble', 'way', 'end', 'up', 'key', 'opennes', 'transformation'],
#  ['i',
#   'enjoy',
#   'watch',
#   'two',
#   'hero',
#   'do',
#   'all',
#   'thing',
#   'that',
#   'hero',
#   'do',
#   'two',
#   'different',
#   'stage',
#   'life'],
#  ['thirty',
#   'forty',
#   'year',
#   'future',
#   'i',
#   'can',
#   'easily',
#   'envision',
#   'jule',
#   'do',
#   'all',
#   'thing',
#   'that',
#   'ben',
#   'do',
#   'movie'],
#  ['greg', 'actually', 'scott', 'i', 'find', 'movie', 'somewhat', 'patronize'],
#  ['aside',
#   'jule',
#   'all',
#   'other',
#   'character',
#   'story',
#   'caricature',
#   'stereotype',
#   'millennial'],
#  ['ben', 'seat', 'other', 'intern', 'recent', 'college', 'graduate'],
#  ['young', 'davi', 'kick', 'parent', 's', 'basement'],
#  ['so',
#   'ben',
#   'take',
#   'teach',
#   'importance',
#   'get',
#   'bed',
#   'time',
#   'dress',
#   'suit',
#   'tie'],
#  ['young',
#   'jason',
#   'too',
#   'interested',
#   'party',
#   'ben',
#   'show',
#   'way',
#   'moderation'],
#  ['young',
#   'administrative',
#   'assistant',
#   'becky',
#   'draw',
#   'tear',
#   'fear',
#   'ben',
#   'get',
#   'more',
#   'attention'],
#  ['i',
#   've',
#   'get',
#   'degree',
#   'marketing',
#   'harvard',
#   'wah',
#   'wah',
#   'wah',
#   'course',
#   'ben',
#   'calm',
#   'down',
#   'pat',
#   'hanky',
#   'then',
#   'push',
#   'jule',
#   'delegate',
#   'authority',
#   'becky'],
#  ['stereotype',
#   'that',
#   'will',
#   'appeal',
#   'old',
#   'crowd',
#   'appear',
#   'target',
#   'audience'],
#  ['there', 's', 'nuance', 'here'],
#  ['jule',
#   'female',
#   'mark',
# ...
#   'ceo',
#   'bike',
#   'office'],
#  ['easy',
#   'watch',
#   'not',
#   'too',
#   'tax',
#   'brain',
#   'crap',
#   'end',
#   'miscast',
#   'husband',
#   'anne',
#   'hathaway',
#   'completely'],
#  ['movie', 'surprise'],
#  ['i',
#   'think',
#   'go',
#   'constantly',
#   'make',
#   'joke',
#   'old',
#   'person',
#   'do',
#   'have',
#   'few',
#   'joke',
#   'nature',
#   'more',
#   'mentorship',
#   'can',
#   'positively',
#   'change'],
#  ['nice', 'see', 'movie', 'character', 'basically', 'good', 'flawed'],
#  ['also', 'make', 'feel', 'good', 'warm', 'heart'],
#  ['need', 'time', 'time'],
#  ['have',
#   'grow',
#   'up',
#   'watch',
#   'play',
#   'great',
#   'role',
#   'godfather',
#   'part',
#   'two',
#   'casino',
#   'goodfellow',
#   'etc'],
#  ['really',
#   'do',
#   'not',
#   'want',
#   'watch',
#   'movie',
#   'so',
#   'far',
#   'removed',
#   'genre'],
#  ['sit', 'down', 'watch', 'flick', 'three', 'girl', 'really', 'enjoy'],
#  ['btw',
#   'just',
#   'do',
#   'not',
#   'understand',
#   'bad',
#   'wrap',
#   'anne',
#   'hathaway',
#   'think',
#   'great'],
#  ['la',
#   'directora',
#   'nancy',
#   'meyer',
#   'sabe',
#   'hacer',
#   'unos',
#   'estupendo',
#   'chick',
#   'flick',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'ta',
#   'give',
#   'y',
#   'woman',
#   'want',
#   'son',
#   'alguno',
#   'ejemplos'],
#  ['intern',
#   'e',
#   'la',
#   'n',
#   'os',
#   'un',
#   'estupendo',
#   'robert',
#   'que',
#   'termina',
#   'convirti',
#   'ndose',
#   'un',
#   'practicante',
#   'una',
#   'internet',
#   'e',
#   'definitivamente',
#   'able'],
#  ['la',
#   'qu',
#   'mica',
#   'hathaway',
#   'su',
#   'joven',
#   'jefe',
#   'e',
#   'maravillosa',
#   'y',
#   'hace',
#   'cinta',
#   'algo',
#   'muy',
#   'pero',
#   'muy',
#   'entretenido'],
#  ['good',
#   'chemistry',
#   'hathaway',
#   'de',
#   'niro',
#   'carry',
#   'movie',
#   'anyone',
#   'fifty',
#   'five',
#   'will',
#   'enjoy',
#   'ageless',
#   'focu'],
#  ['recommend'],
#  ['top', 'movie', 'really', 'enjoy', 'one'],
#  ['personally',
#   'one',
#   'favourite',
#   'movie',
#   'now',
#   'time',
#   'i',
#   'watch',
#   'i',
#   'still',
#   'love',
#   'great',
#   'film'],
#  ['intern', 'shadow', 'doubt', 'two', 'thousand', 'fifteen', 'film'],
#  ['twenty', 'year', 'intern', 'would', 'not', 'make'],
#  ['atleast', 'not'],
#  ['handle',
#   'driven',
#   'young',
#   'work',
#   'woman',
#   'seemingly',
#   'infinite',
#   'hustle',
#   'stay',
#   'home',
#   'father',
#   'nary',
#   'hint',
#   'ridicule'],
#  ['character', 'accept', 'as', 'simply', 'would', 'wear', 'sock', 'shoe'],
#  ['elephant',
#   'room',
#   'ben',
#   'play',
#   'supurbly',
#   'robert',
#   'just',
#   'right',
#   'mix',
#   'understated',
#   'sensitivity',
#   'decade',
#   'life',
#   'experience',
#   'i',
#   'tell',
#   'snark'],
#  ['ben',
#   's',
#   'very',
#   'senior',
#   'intern',
#   'anne',
#   'hathaway',
#   's',
#   'jule',
#   'ostin',
#   'hustlin',
#   'twenty',
#   'on',
#   'century',
#   'sister',
#   'doin',
#   'daughter',
#   'stay',
#   'home',
#   'husband'],
#  ['ben',
#   'never',
#   'condescend',
#   'always',
#   'humble',
#   'willing',
#   'go',
#   'good',
#   'motley',
#   'crew',
#   'co',
#   'worker'],
#  ['take',
#   'logical',
#   'conclusion',
#   'dare',
#   'heist',
#   'ben',
#   'head',
#   'up',
#   'fellow',
#   'desk',
#   'jockey',
#   'delete',
#   'disparage',
#   'email',
#   'not',
#   'so',
#   'fearless',
#   'female',
#   'leader',
#   'accidently',
#   'send',
#   'mother'],
#  ['easily',
#   'film',
#   's',
#   'most',
#   'ridiculous',
#   'moment',
#   'do',
#   'not',
#   'outstay',
#   'welcome',
#   'serve',
#   'effective',
#   'palate',
#   'cleanser',
#   'middle',
#   'movie'],
#  ['there',
#   'interesting',
#   'twist',
#   'little',
#   'hiest',
#   'which',
#   'definitely',
#   'need',
#   'because',
#   'as',
#   'good',
#   'intern',
#   'never',
#   'lay',
#   'down',
#   'firm',
#   'mission',
#   'statement',
#   'lead',
#   'accomplish',
#   'end',
#   'twist',
#   'give',
#   'welcome',
#   'drama',
#   'i',
#   'find',
#   'very',
#   'enjoyable',
#   'sweet',
#   'likable',
#   'film'],
#  ['fine', 'nothing', 'incredible', 'groundbreaking'],
#  ['have',
#   'solid',
#   'intriguing',
#   'premise',
#   'primarily',
#   'coast',
#   'chemistry',
#   'large',
#   'cast'],
#  ['bonu', 'point', 'interior', 'design', 'porn'],
#  ['make', 'feel', 'good'],
#  ['ice', 'cream'],
#  ['plain'],
#  ['simple'],
#  ['one',
#   'perfect',
#   'late',
#   'night',
#   'tb',
#   'flick',
#   'catch',
#   'hang',
#   'out',
#   'ironically',
#   'enough',
#   'grandparent',
#   's',
#   'house'],
#  ['film', 'simple', 'cast', 'earnest', 'charm'],
#  ['leave', 'cynicism', 'door', 'will', 'fine', 'even', 'get', 'abrupt', 'end'],
#  ['great',
#   'movie',
#   'lot',
#   'potential',
#   'film',
#   'perfect',
#   'flow',
#   'story',
#   'great',
#   'collection',
#   'plot',
#   'awesome',
#   'pair',
#   'incredible',
#   'cast',
#   'still',
#   'robert',
#   'di',
#   'nero'],
#  ['actor'],
#  ['never', 'fail', 'amaze', 'ur', 'charm', 'performance', 'never', 'ever'],
#  ['always', 'right', 'person', 'great', 'performance'],
#  ['anna', 'also', 'incredible', 'so', 'rest', 'cast'],
#  ['overall', 'full', 'fun', 'great', 'entertainment'],
#  ['nancy', 'make', 'incredible', 'film', 'hat', 'off'],
#  ['really', 'good'],
#  ['wan', 'watch', 'twond', 'time'],
#  ['eight',
#   'thirty',
#   'one',
#   'sixteen',
#   'i',
#   'actually',
#   'dislike',
#   'watching',
#   'film'],
#  ['begin', 'i', 'do', 'enjoy', 'cute'],
#  ['while',
#   'become',
#   'very',
#   'obvious',
#   'story',
#   'make',
#   'up',
#   'i',
#   'could',
#   'envision',
#   'someone',
#   'sit',
#   'there',
#   'write',
#   'script'],
#  ['authenticity', 'never', 'good', 'thing'],
#  ['then',
#   'half',
#   'way',
#   'film',
#   'becomes',
#   'much',
#   'darker',
#   'quite',
#   'frankly',
#   'just',
#   'depress'],
#  ['resolution', 'end', 'not', 'really', 'good', 'resolution'],
#  ['so', 'fake', 'depress'],
#  ['not', 'great', 'entertainment', 'ask'],
#  ['good',
#   'end',
#   'not',
#   'such',
#   'big',
#   'fan',
#   'end',
#   'other',
#   'then',
#   'great',
#   'movie',
#   'great',
#   'cast'],
#  ['quite', 'nice', 'film', 'honest'],
#  ['anne', 'hathaway', 'never', 'look', 'well'],
#  ['i', 'actually', 'kind', 'like', 'all', 'year'],
#  ['bit', 'cheesy', 'worth', 'watch'],
#  ['really', 'good', 'movie'],
#  ['brilliant', 'act', 'storyline'],
#  ['enjoyable', 'forgettable'],
#  ['well', 'movie', 'then', 'recent', 'stuff'],
#  ['end', 'leave', 'lot', 'desire'],
#  ['just', 'end'],
#  ['dumb'],
#  ['relatable', 'very', 'relevant'],
#  ['dynamic', 'character', 'sweet', 'funny'],
#  ['genuine'],
#  ['ok'],
#  ['i', 'felt', 'start', 'off', 'strong', 'kind', 'fizzle', 'wore'],
#  ['i',
#   'actually',
#   'think',
#   'would',
#   'more',
#   'comedy',
#   'joke',
#   'do',
#   'have',
#   'first',
#   'half',
#   'movie'],
#  ['act', 'hathaway', 'great', 'i', 'hat', 'abrupt', 'end'],
#  ['nice', 'storyline', 'i', 'enjoy', 'watch'],
#  ['great',
#   'movie',
#   'i',
#   'do',
#   'not',
#   'want',
#   'end',
#   'last',
#   'half',
#   'movie',
#   'i',
#   'keep',
#   'thinking',
#   'go',
#   'hire',
#   'ben',
#   'ceo'],
#  ['cute', 'yet', 'thin', 'storyline'],
#  ['enjoy', 'pair', 'hathaway', 'de'],
#  ['felt',
#   'cheat',
#   'hathaway',
#   's',
#   'character',
#   's',
#   'obvious',
#   'storyline',
#   'wish',
#   'would',
#   'give',
#   'de',
#   's',
#   'character',
#   'more',
#   'story',
#   'say',
#   'maybe',
#   'point',
#   'have',
#   'senior',
#   'character',
#   'quietly',
#   'resolutely',
#   'prominently',
#   'affect',
#   'one',
#   's',
#   'life'],
#  ['thought',
#   'niro',
#   'great',
#   'young',
#   'man',
#   'provide',
#   'guidance',
#   'support'],
#  ['nice', 'watch', 'young', 'man', 'evolve'],
#  ['disneyesque', 'predictability'],
#  ['i', 'not', 'one', 'watch', 'type', 'movie'],
#  ['i', 'tend', 'prefer', 'horror', 'action'],
#  ['however', 'one', 'strays', 'expectation', 'kind'],
#  ['spoiler'],
#  ['i',
#   'almost',
#   'expect',
#   'scene',
#   'deniro',
#   's',
#   'character',
#   'would',
#   'mess',
#   'up',
#   'everyone',
#   'would',
#   'see',
#   'not',
#   'perfect',
#   'end',
#   'would',
#   'find',
#   'love',
#   'anyway',
#   'i',
#   'hop',
#   'elder',
#   'wisdom',
#   'provide',
#   'seem',
#   'answer',
#   'everything',
#   'i',
#   'think',
#   'lack',
#   'recent',
#   'generation'],
#  ['i', 'glad', 'movie', 'make'],
#  ['show', 'miss', 'need', 'not', 'only', 'youth', 'today', 'company', 'today'],
#  ['good', 'job'],
#  ['funny',
#   'pretty',
#   'witty',
#   'satire',
#   'politic',
#   'today',
#   's',
#   'busines',
#   'office'],
#  ['just', 'right', 'mix', 'serious', 'humor'],
#  ['good', 'date', 'night', 'movie'],
#  ['heartfelt', 'movie', 'great', 'story', 'fantastic', 'acting'],
#  ['retire',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'ben',
#   'play',
#   'robert',
#   'bore',
#   'retired',
#   'life'],
#  ['apply',
#   'senior',
#   'intern',
#   'online',
#   'fashion',
#   'retailer',
#   'get',
#   'position'],
#  ['founder',
#   'company',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway',
#   'tireless',
#   'driven',
#   'demand',
#   'dynamic',
#   'workaholic'],
#  ['ben',
#   'make',
#   'intern',
#   'nominal',
#   'role',
#   'do',
#   'not',
#   'intend',
#   'give',
#   'work',
#   'just',
#   'window',
#   'dress'],
#  ['however',
#   'ben',
#   'prove',
#   'quite',
#   'useful',
#   'more',
#   'source',
#   'support',
#   'wisdom'],
#  ['good', 'surprisingly', 'so'],
#  ['i',
#   'expect',
#   'farcical',
#   'half',
#   'bake',
#   'comedy',
#   'old',
#   'guy',
#   'rejoin',
#   'work',
#   'force',
#   'struggle',
#   'modern',
#   'gadget',
#   'work',
#   'process'],
#  ['there',
#   'few',
#   'example',
#   'movie',
#   'far',
#   'more',
#   'story',
#   'generational',
#   'difference'],
#  ['more', 'drama', 'comedy', 'good', 'one', 'too'],
#  ['there',
#   'theme',
#   'generational',
#   'wisdom',
#   'not',
#   'judge',
#   'person',
#   'age',
#   'anything',
#   'superficial',
#   'make',
#   'most',
#   'person',
#   's',
#   'talent'],
#  ['also', 'movie', 'start', 'do', 'enjoy'],
#  ['moreover', 'simply', 'nice', 'story'],
#  ['solid', 'work', 'robert', 'lead', 'role'],
#  ['do',
#   'not',
#   'do',
#   'bad',
#   'performance',
#   'have',
#   'not',
#   'stop',
#   'past',
#   'take',
#   'role',
#   'movie',
#   'that',
#   'well',
#   'standard'],
#  ['not', 'one', 'role', 'movie'],
#  ['sensitively', 'play', 'ideal', 'role'],
#  ['good',
#   'work',
#   'too',
#   'anne',
#   'hathaway',
#   'very',
#   'convincing',
#   'go',
#   'get',
#   'entrepreneur'],
#  ['bottom', 'line', 'robert', 'd', 'make', 'movie'],
#  ['really', 'enjoy'],
#  ['anne', 'hathaway', 'also', 'play', 'great', 'part', 'also'],
#  ['film', 'that', 'differentiate', 'young', 'old', 'generation'],
#  ['i', 'would', 'definitely', 'say', 'director', 's', 'best', 'film'],
#  ['i', 'have', 'like', 'other', 'film', 'lot', 'different'],
#  ['i',
#   'mean',
#   'well',
#   'write',
#   'screenplay',
#   'much',
#   'good',
#   'understood',
#   'contemporary',
#   'world',
#   'just',
#   'focus',
#   'relationship',
#   'usual'],
#  ['so',
#   'addition',
#   'digital',
#   'world',
#   'stuff',
#   'make',
#   'all',
#   'difference',
#   'i',
#   'completely',
#   'enjoy'],
#  ['do',
#   'not',
#   'think',
#   'would',
#   'internship',
#   'i',
#   'initially',
#   'think',
#   'slightly',
#   'much',
#   'good',
#   'everyway'],
#  ['go',
#   'agree',
#   'film',
#   's',
#   'poster',
#   'trailer',
#   'not',
#   'very',
#   'impressive',
#   'actual',
#   'film',
#   'do',
#   'grab',
#   'full',
#   'attention'],
#  ['two',
#   'hour',
#   'film',
#   'always',
#   'concern',
#   'film',
#   'run',
#   'long',
#   'i',
#   'can',
#   'even',
#   'sit',
#   'half',
#   'hour'],
#  ['anyway', 'story', 'runtime', 'pace', 'incredible'],
#  ['there',
#   'something',
#   'interesting',
#   'go',
#   'forget',
#   'focu',
#   'flaw',
#   'enjoy',
#   'time',
#   'which',
#   'i',
#   'exactly',
#   'do',
#   'here'],
#  ['not',
#   'comedy',
#   'go',
#   'laugh',
#   'openly',
#   'loud',
#   'comedy',
#   'sense',
#   'set',
#   'character',
#   'film',
#   'have'],
#  ['i',
#   'mean',
#   'story',
#   'digital',
#   'busines',
#   'most',
#   'computer',
#   'consider',
#   'geek'],
#  ['so',
#   'theirs',
#   'world',
#   'nothing',
#   'just',
#   'hook',
#   'work',
#   'forget',
#   'actual',
#   'world'],
#  ['even', 'someone', 'next', 'room', 'tweet'],
#  ['remind',
#   'only',
#   'have',
#   'change',
#   'not',
#   'physical',
#   'world',
#   'main',
#   'character',
#   'old',
#   'wise',
#   'influence',
#   'young',
#   'generation',
#   'person'],
#  ['so',
#   'actor',
#   'undoubtedly',
#   'best',
#   'thing',
#   'apart',
#   'direction',
#   'story'],
#  ['seventy',
#   'three',
#   'year',
#   'old',
#   'robert',
#   'still',
#   'impress',
#   'extraordinary',
#   'character',
#   'display'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'whoever',
#   'mind',
#   'write',
#   'role',
#   'perfectly',
#   'fit',
#   'none',
#   'other'],
#  ['then', 'there', 'anne', 'hathaway', 'opposite', 'side', 'equal', 'part'],
#  ['narration',
#   'point',
#   'view',
#   'start',
#   'deniro',
#   's',
#   'quickly',
#   'middle',
#   'take',
#   'circle',
#   'cover',
#   'other',
#   'well'],
#  ['then',
#   'come',
#   'professional',
#   'personal',
#   'life',
#   'topic',
#   'develop',
#   'brought',
#   'small',
#   'family',
#   'affected',
#   'workaholic',
#   'mother'],
#  ['so',
#   'enter',
#   'expect',
#   'comedy',
#   'probably',
#   'will',
#   'not',
#   'disappoint',
#   'deliver',
#   'wish',
#   'which',
#   'heartwarming',
#   'drama',
#   'emotional',
#   'moment'],
#  ['surely',
#   'recommend',
#   'especially',
#   'youngster',
#   're',
#   'addict',
#   'digital',
#   'world'],
#  ['two', 'thousand', 'twenty', 'four', 'eight', 'ten', 'zero', 'zero', 'zero'],
#  ['love', 'movie', 'beggining', 'end'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'robert',
#   'seem',
#   'too',
#   'perfect',
#   'turn',
#   'off',
#   'here'],
#  ['really', 'enjoy', 'movie'],
#  ['two', 'thousand', 'twenty', 'four', 'ten', 'ten', 'zero', 'zero', 'zero'],
#  ['intern', 'funny', 'charm', 'heartwarming'],
#  ['movie',
#   'old',
#   'man',
#   'that',
#   'retire',
#   'go',
#   'back',
#   'outdoor',
#   'world',
#   'get',
#   'job',
#   'intern',
#   'young',
#   'person',
#   'work',
#   'place',
#   'great',
#   'plot'],
#  ['i', 'think', 'movie', 'go', 'bad', 'not'],
#  ['however', 'end', 'movie', 'do', 'get', 'kind', 'boring'],
#  ['overall', 'great', 'movie'],
#  ['robert', 's', 'anne', 'hathaway', 's', 'best', 'movie', 'yet'],
#  ['two', 'thumb'],
#  ['i', 'would', 'very', 'much', 'suggest', 'movie'],
#  ['average',
#   'i',
#   'internally',
#   'grateful',
#   'take',
#   'few',
#   'minute',
#   'day',
#   'read',
#   'cheesy',
#   'review',
#   'writer',
#   'director',
#   'nancy',
#   'meyer',
#   'comedy',
#   'intern'],
#  ['i', 'hope', 'make', 'puntership', 'fly', 'color'],
#  ['anyway', 'movie', 'star', 'ben', 'whittaker'],
#  ['ben',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'live',
#   'out',
#   'retired',
#   'day',
#   'need',
#   'fill',
#   'void'],
#  ['come',
#   'opportunity',
#   'intern',
#   'senior',
#   'citizen',
#   'internship',
#   'program',
#   'start',
#   'up',
#   'fashion',
#   'online',
#   'company'],
#  ['anne',
#   'hathaway',
#   'co',
#   'star',
#   'jule',
#   'founder',
#   'company',
#   'first',
#   'reluctant',
#   'work',
#   'older',
#   'crowd',
#   'then',
#   'take',
#   'genuine',
#   'like',
#   'ben',
#   'not',
#   'only',
#   'dependable',
#   'intern',
#   'father',
#   'figure'],
#  ['course',
#   'there',
#   'conflict',
#   'that',
#   'incorporate',
#   'film',
#   'that',
#   'cause',
#   'relationship',
#   'challenge',
#   'jule',
#   'own',
#   'relationship',
#   'husband'],
#  ['i',
#   'admire',
#   'meyer',
#   'direct',
#   'first',
#   'hour',
#   'movie',
#   'then',
#   'look',
#   'intern',
#   'ran',
#   'steam',
#   'second',
#   'half',
#   'too',
#   'many',
#   'elongated',
#   'scene',
#   'i',
#   'could',
#   'not',
#   'give',
#   'intern',
#   'review',
#   'promotion'],
#  ['i', 'do', 'de', 'ben', 'hathaway', 'jule', 'not', 'too', 'shabby'],
#  ['intern', 'two', 'hour', 'do', 'not', 'have'],
#  ['intern',
#   'could',
#   'have',
#   'do',
#   'job',
#   'sheer',
#   'ninety',
#   'minute',
#   'stay',
#   'not',
#   'need',
#   'overtime',
#   'i',
#   'can',
#   'not',
#   'highly',
#   'recommend',
#   'hire',
#   'intern',
#   'movie',
#   'watch',
#   'company'],
#  ['really',
#   'good',
#   'movie',
#   'wholesome',
#   'not',
#   'goofy',
#   'dirty',
#   'liberal',
#   'trash',
#   'heap'],
#  ['just', 'good', 'movie'],
#  ['film', 'i', 'like', 'make', 'fell', 'good', 'happy'],
#  ['as',
#   'long',
#   'do',
#   'not',
#   'really',
#   'pay',
#   'attention',
#   'plot',
#   'nice',
#   'movie'],
#  ['watch',
#   'preview',
#   'i',
#   'reluctant',
#   'watch',
#   'film',
#   'i',
#   'think',
#   'only',
#   'possible',
#   'story',
#   'line',
#   'old',
#   'intern',
#   'would',
#   'end',
#   'up',
#   'die'],
#  ['movie',
#   'nothing',
#   'instead',
#   'adorable',
#   'probably',
#   'one',
#   'new',
#   'favorite',
#   'movie'],
#  ['end', 'little', 'abrupt', 'overall', 'i', 'highly', 'recommend'],
#  ['i', 'actually', 'enjoy', 'movie'],
#  ['robert', 'di', 'nero', 'fun', 'hilarious', 'downright', 'adorable'],
#  ['i',
#   'have',
#   'always',
#   'love',
#   'anne',
#   'hathaway',
#   'i',
#   'think',
#   'great',
#   'film'],
#  ['only', 'part', 'annoy', 'small', 'husband', 'cheat', 'story'],
#  ...]

# %%
# final..refine!

def replace_words(sentence):
    replacements = {
        r'\binternben\b': ['intern', 'ben'],
        r'\bexperiencesben\b': ['experience', 'ben'],
        r'\bbeingben\b': ['being', 'ben'],
        r'\bbentwo\b': ['ben', 'two'],
        r'\bbens\b': ['ben'],
        r'\bitben\b': ['it', 'ben'],
        r'\bheartben\b': ['heart', 'ben'],
        r'\botherben\b': ['other', 'ben'],
        r'\bbentheir\b': ['ben', 'their'],
        r'\bfamilyben\b': ['family', 'ben'],
        r'\bfunben\b': ['fun', 'ben'],
        r'\binternrobert\b': ['intern', 'robert'],
        r'\buprobert\b': ['up', 'robert'],
        r'\brealisticrobert\b': ['realistic', 'robert'],
        r'\btemperrobert\b': ['temper', 'robert'],
        r'\bplacerobert\b': ['place', 'robert'],
        r'\btimesrobert\b': ['time', 'robert'],
        r'\bniros\b': ['niro'],
        r'\bdeniro\b': ['niro'],
        r'\bniroi\b': ['niro', 'I'],
        r'\bmyershe\b': ['she'],
        r'\bmyersworking\b': ['working'],
        r'\banhathaway\b': ['hathaway'],
        r'\bsceneanhathaway\b': ['scene', 'hathaway'],
        r'\banhathawayhis\b': ['hathaway', 'his'],
        r'\bhathawayde\b': ['hathaway', 'de'],
        r'\bhathaways\b': ['hathaway'],
        r'\banhathaways\b': ['hathaway'],
        r'\brottenanhathaway\b': ['rotten', 'hathaway'],
        r'\btherejules\b': ['there', 'jule'],
        r'\bweakjule\b': ['weak', 'jule'],
        r'\bjules\b': ['jule'],
        r'\broutinejule\b': ['routine', 'jule'],
        r'\bagejule\b': ['age', 'jule'],
    }
    for pattern, replacement in replacements.items():
        sentence = re.sub(pattern, ' '.join(replacement), sentence)

    return sentence.split()

modified_sentences = [replace_words(' '.join(sentence)) for sentence in processed_sentences_no_stopwords]

# %%
modified_sentences
# Out:
# [['not', 'i', 'expect'],
#  ['really', 'enjoy'],
#  ['include', 'hope', 'redemption', 'end'],
#  ['true', 'feel', 'good', 'movie', 'i', 'wish', 'i', 'saw', 'theater'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'niro',
#   'have',
#   'great',
#   'chemistry',
#   'movie',
#   'tell',
#   'great',
#   'story',
#   'two',
#   'person',
#   'generation',
#   'apart',
#   'grow',
#   'closer',
#   'learn',
#   'other'],
#  ['there', 'strong', 'character', 'development', 'solid', 'cast'],
#  ['i', 'recommend', 'anyone'],
#  ['all', 'piece', 'seem', 'there', 'truly', 'appropriate', 'third', 'act'],
#  ['intern',
#   'have',
#   'chemistry',
#   'rich',
#   'lead',
#   'performance',
#   'tenure',
#   'auteur',
#   'camera'],
#  ['brilliant', 'movie'],
#  ['so', 'warm', 'satisfying', 'so', 'move'],
#  ['recommend'],
#  ['two',
#   'bonified',
#   'great',
#   'actor',
#   'somehow',
#   'have',
#   'great',
#   'chemistry',
#   'that',
#   'truly',
#   'make',
#   'movie',
#   'worth',
#   'watch'],
#  ['rush',
#   'story',
#   'do',
#   'not',
#   'take',
#   'away',
#   'heartwarming',
#   'affect',
#   'go'],
#  ['movie', 'very', 'good'],
#  ['i', 'can', 'not', 'believe', 'other', 'critic', 'rating', 'say', 'movie'],
#  ['two', 'legendary', 'actor', 'good', 'script'],
#  ['good',
#   'film',
#   'overall',
#   'love',
#   'robert',
#   'fit',
#   'role',
#   'really',
#   'well'],
#  ['story',
#   'pretty',
#   'standard',
#   'stuff',
#   'however',
#   'fun',
#   'watch',
#   'something',
#   'take',
#   'away'],
#  ['very', 'entertaining', 'movie', 'just', 'want', 'have', 'good', 'time'],
#  ['i', 'really', 'enjoy', 'lot'],
#  ['think', 'really', 'nailed', 'part', 'top', 'game'],
#  ['well', 'watch', 'i', 'wish', 'couple', 'ending', 'go', 'different', 'way'],
#  ['gentle', 'film', 'low', 'stake', 'surface', 'level', 'lesson', 'value'],
#  ['beautifully', 'shoot', 'well', 'acted', 'story', 'lack', 'depth'],
#  ['hathaway',
#   's',
#   'mad',
#   'act',
#   'skill',
#   'manage',
#   'raise',
#   'otherwise',
#   'boring',
#   'film',
#   'very',
#   'nearly',
#   'interesting'],
#  ['odd',
#   'hathaway',
#   's',
#   'meeting',
#   'never',
#   'one',
#   'consider',
#   'hire',
#   'female',
#   'ceo'],
#  ['sadly',
#   'successful',
#   'entrepreneur',
#   'will',
#   'continue',
#   'burn',
#   'out',
#   'can',
#   'not',
#   'let',
#   'go',
#   'struggle',
#   'delegate',
#   'flawles',
#   'person',
#   'always',
#   'say',
#   'right',
#   'thing',
#   'magically',
#   'show',
#   'up'],
#  ['o', 'filme', 'que', 'bom', 'bastante', 'divertido'],
#  ['ma',
#   'o',
#   'final',
#   'n',
#   'o',
#   'fez',
#   'nenhum',
#   'sentido',
#   'filme',
#   'bem',
#   'ses',
#   'da',
#   'tarde',
#   'mesmo'],
#  ['movie',
#   'good',
#   'one',
#   'just',
#   'throw',
#   'enjoy',
#   'usually',
#   'not',
#   'type',
#   'movie',
#   'i',
#   'quite',
#   'enjoy',
#   'duo',
#   'onscreen',
#   'lesson',
#   'learn',
#   'way'],
#  ['look', 'feel', 'good', 'film'],
#  ['fantastic', 'cast', 'compelling', 'story'],
#  ['know', 'spread', 'too', 'thin', 'feel', 'outsider'],
#  ['learn', 'something', 'work', 'life', 'balance', 'fit'],
#  ['i',
#   'come',
#   'movie',
#   'i',
#   'look',
#   'wholesome',
#   'movie',
#   'that',
#   'would',
#   'make',
#   'regain',
#   'sort',
#   'faith',
#   'humanity'],
#  ['most', 'part', 'movie', 'deliver'],
#  ['i',
#   'not',
#   'sure',
#   'i',
#   'agree',
#   'decision',
#   'end',
#   'decision',
#   'i',
#   'gues'],
#  ['idk', 'first', 'half', 'very', 'wholesome', 'get', 'messy', 'end'],
#  ['i', 'gues', 'that', 'life', 'messy'],
#  ['terrible', 'movie', 'awful', 'message'],
#  ['only',
#   'give',
#   'feminism',
#   'show',
#   'woman',
#   'can',
#   'top',
#   'do',
#   'most',
#   'disgraceful',
#   'way'],
#  ['hathaway',
#   's',
#   'character',
#   'out',
#   'control',
#   'clearly',
#   'not',
#   'able',
#   'handle',
#   'grow',
#   'company',
#   'completely',
#   'oblivious',
#   'tech',
#   'not',
#   'use',
#   'email',
#   'recall',
#   'sink',
#   'even',
#   'more',
#   'power',
#   'trip',
#   'not',
#   'have',
#   'bos'],
#  ['lot', 'sham', 'new', 'generation', 'man', 'glorify', 'boomer'],
#  ['extremely', 'capitalist', 'pro', 'destroy', 'everything', 'job'],
#  ['wtf',
#   'go',
#   'bar',
#   'employee',
#   'which',
#   'do',
#   'not',
#   'know',
#   'name',
#   'too',
#   'powerful',
#   'instead',
#   'go',
#   'home',
#   'spend',
#   'time',
#   'family'],
#  ['idea',
#   'feminism',
#   'become',
#   'well',
#   'collectively',
#   'not',
#   'woman',
#   'start',
#   'act',
#   'stereotypical',
#   'man'],
#  ['also', 'sexual', 'harrassment', 'out', 'there', 'joke', 'really'],
#  ['ok', 'do', 'guy'],
#  ['special',
#   'effect',
#   'one',
#   'zero',
#   'sound',
#   'effect',
#   'one',
#   'zero',
#   'act',
#   'one',
#   'zero',
#   'story',
#   'two',
#   'zero'],
#  ['just', 'classic', 'pull', 'all', 'good', 'heartstring', 'best', 'duo'],
#  ['so', 'well', 'write', 'character', 'adorable'],
#  ['funny', 'sad', 'suspenseful', 'action', 'pack'],
#  ['could', 'good'],
#  [],
#  ['i', 'bit', 'long', 'good', 'story'],
#  ['whyyy', 'movie', 'not', 'rat', 'ninety'],
#  [],
#  ['one', 'kind'],
#  ['so', 'fresh', 'warm', 'cozy', 'positive'],
#  ['somehow', 'teach', 'way', 'living'],
#  ['i', 'always', 'go', 'hopeful', 'happy', 'content', 'watch', 'movie'],
#  ['definitely', 'must', 'watch'],
#  [],
#  ['very', 'beautiful', 'well', 'write', 'movie'],
#  ['hat', 'off', 'creator'],
#  ['tell',
#   'phone',
#   'ring',
#   'background',
#   'heart',
#   'thought',
#   'stalk',
#   'baby',
#   'mama',
#   'have',
#   'quit',
#   'immediatly'],
#  ['make', 'feel', 'warm', 'cozy', 'chest', 'very', 'nostalgic', 'feeling'],
#  ['movie', 'one', 'sweetest', 'will', 'ever', 'watch'],
#  ['have', 'comedy', 'drama', 'as', 'well', 'really', 'sweet', 'story'],
#  ['overall', 'awsome', 'movie'],
#  ['want',
#   'simply',
#   'smile',
#   'two',
#   'hour',
#   'straight',
#   'go',
#   'ahead',
#   'watch',
#   'movie'],
#  ['i',
#   'have',
#   'zero',
#   'clue',
#   'anyone',
#   'would',
#   'rat',
#   'five',
#   'star',
#   'comedy',
#   'drama'],
#  ['chemistry', 'hathaway', 'tremendous'],
#  ['i',
#   'buy',
#   'whole',
#   'thing',
#   'somehow',
#   'there',
#   'actually',
#   'decent',
#   'premise',
#   'storyline'],
#  ['simple', 'sweet'],
#  ['i',
#   'would',
#   'have',
#   'terrible',
#   'week',
#   'everything',
#   'have',
#   'go',
#   'wrong',
#   'movie',
#   'tv',
#   'hotel',
#   'room',
#   'help',
#   'distract',
#   'bit'],
#  ['i', 'find', 'smile', 'part', 'overall', 'just', 'nice', 'movie'],
#  ['niro',
#   'hathaway',
#   'have',
#   'good',
#   'chemistry',
#   'here',
#   'overall',
#   'emotional',
#   'tone',
#   'too',
#   'mushy',
#   'feel',
#   'manipulative'],
#  ['niro', 's', 'character', 'too', 'good', 'true'],
#  ['can', 'almost', 'get', 'away'],
#  ['message',
#   'social',
#   'gender',
#   'role',
#   'seem',
#   'overly',
#   'simplify',
#   'sort',
#   'muddy',
#   'same',
#   'time'],
#  ['attempt', 'do', 'not', 'quite', 'pull', 'off'],
#  ['serviceable'],
#  ['have', 'low', 'key', 'feel'],
#  ['something', 'bring', 'back', 'watch', 'again'],
#  ['so',
#   'there',
#   'something',
#   'i',
#   'do',
#   'not',
#   'think',
#   'ever',
#   'really',
#   'hit',
#   'mark',
#   'aim'],
#  ['cute',
#   'movie',
#   'nice',
#   'two',
#   'hour',
#   'well',
#   'spend',
#   'have',
#   'nothing',
#   'well',
#   'do'],
#  ['solid', 'flick'],
#  ['watch'],
#  ['def', 'fresh'],
#  ['don', 't', 'vibe', 'charm', 'nancy', 'meyer', 'bring', 'just', 'move'],
#  ['very', 'boring'],
#  ['seem',
#   'film',
#   'more',
#   'interested',
#   'create',
#   'statement',
#   'make',
#   'enjoyable',
#   'film'],
#  ['movie',
#   'make',
#   'person',
#   'emotional',
#   'remind',
#   'senior',
#   'person',
#   'still',
#   'very',
#   'important',
#   'society'],
#  ['robert',
#   'make',
#   'such',
#   'amazing',
#   'character',
#   'that',
#   'actually',
#   'make',
#   'feel',
#   'calm'],
#  ['anne',
#   'hathway',
#   'also',
#   'make',
#   'awsome',
#   'character',
#   'power',
#   'woman',
#   'rmaking',
#   'refrence',
#   'work',
#   'mom',
#   'which',
#   'social',
#   'issue',
#   'today'],
#  ['plot', 'good'],
#  ['movie', 'that', 'make', 'smile', 'laught', 'little'],
#  ['movie',
#   'i',
#   'do',
#   'not',
#   'know',
#   'movie',
#   'have',
#   'low',
#   'rating',
#   'believe',
#   'masterpiece',
#   'mood',
#   'changer'],
#  ['esta',
#   'pelicula',
#   'da',
#   'una',
#   'buena',
#   'vibra',
#   'con',
#   'la',
#   'talento',
#   'protagonista'],
#  ['movie', 'old', 'gold'],
#  ['nancy', 'meyer', 's', 'take', 'movie', 'breath', 'air'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'niro',
#   'play',
#   'character',
#   'very',
#   'well',
#   'make',
#   'movie',
#   'more',
#   'interesting',
#   'watch'],
#  ['i', 'love', 'movie', 'mix', 'old', 'modern', 'reference', 'amaze'],
#  ['movie',
#   'that',
#   'don',
#   't',
#   'take',
#   'life',
#   'seriously',
#   'just',
#   'lay',
#   'back'],
#  ['therapist', 'metro', 'film', 'too', 'dark', 'knight', 'esque'],
#  ['will',
#   'one',
#   'time',
#   'classic',
#   'as',
#   'good',
#   'wonderful',
#   'life',
#   'other'],
#  ['film',
#   'do',
#   'instil',
#   'good',
#   'old',
#   'value',
#   'attribute',
#   'modern',
#   'digital',
#   'world',
#   'mixed',
#   'emotion',
#   'old',
#   'school',
#   'gentleman'],
#  ['golden', 'future', 'classic'],
#  ['great', 'movie', 'show', 'different', 'story', 'one', 'movie'],
#  ['undemanding'],
#  ['pleasant', 'way', 'spend', 'couple', 'hour'],
#  ['movie',
#   'so',
#   'wholesome',
#   'amazing',
#   'there',
#   'time',
#   'i',
#   'almost',
#   'cry',
#   'alot',
#   'time',
#   'make',
#   'smile'],
#  ['i', 'have', 'choose', 'movie', 'i', 'great', 'anne', 'hathaway', 'fan'],
#  ['so', 'obviously', 'i', 'sure', 'movie', 'great'],
#  ['i',
#   'watch',
#   'i',
#   'find',
#   'movie',
#   'fresh',
#   'watch',
#   'something',
#   'so',
#   'subtle',
#   'touch',
#   'glimpse',
#   'laugh'],
#  ['thing',
#   'which',
#   'touch',
#   'most',
#   'story',
#   'performance',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['specially',
#   'moment',
#   'work',
#   'late',
#   'night',
#   'say',
#   'use',
#   'work',
#   'same',
#   'spot',
#   'year',
#   'ago'],
#  ['must', 'watch', 'movie'],
#  ['good', 'movie'],
#  ['story', 'good', 'music', 'beautiful'],
#  ['robert', 'play', 'wonderful', 'character'],
#  ['watch'],
#  ['less', 'say'],
#  ['more', 'say'],
#  ['simple', 'story', 'end', 'apparent', 'outset'],
#  ['point', 'film', 'watch', 'plot', 'unfold'],
#  ['nothing', 'deep'],
#  ['nothing', 'urge', 'set', 'date', 'watch', 'again'],
#  ['rather', 'more', 'something', 'person', 'can', 'feel'],
#  ['interaction'],
#  ['know', 'take', 'put', 'win', 'production', 'together'],
#  ['good', 'writing'],
#  ['good', 'acting'],
#  ['all', 'rest'],
#  ['go', 'wind', 'just', 'show'],
#  ['person'],
#  ['nothing', 'more'],
#  ['wind', 'up', 'pleased', 'smile'],
#  ['pick', 'own', 'person', 'identify'],
#  ['i', 'old', 'so', 'niro'],
#  ['value', 'keep', 'mouth', 'shut', 'more', 'often'],
#  ['pay', 'off'],
#  ['perfect', 'three', 'star'],
#  ['i', 'like', 'movie', 'start', 'finish'],
#  ['love',
#   'relationship',
#   'intern',
#   'jule',
#   'make',
#   'think',
#   'very',
#   'proud',
#   'granddad',
#   'try',
#   'help',
#   'niece',
#   'out'],
#  ['two', 'very', 'well', 'spent', 'hour'],
#  ['enjoy', 'niro', 'first', 'time', 'awhile'],
#  ['love', 'burglary', 'sequence'],
#  ['robert', 'comedy', 'movie', 'very', 'decent', 'movie'],
#  ['do', 'enjoy'],
#  ['seven', 'five', 'ten'],
#  ['very', 'lame', 'movie', 'acting', 'force', 'most', 'scene'],
#  ['not', 'recommend'],
#  ['feel',
#   'good',
#   'dramedy',
#   'which',
#   'drawn',
#   'place',
#   'have',
#   'moment',
#   'bound',
#   'make',
#   'smile'],
#  ['i', 'surprised', 'critic', 'give', 'one', 'such', 'poor', 'rating'],
#  ['make', 'wonder', 'ever', 'know', 'enjoy', 'good', 'movie'],
#  ['not',
#   'original',
#   'raise',
#   'few',
#   'issue',
#   'may',
#   'not',
#   'agree',
#   'whatever',
#   'movie',
#   'make',
#   'then',
#   'cry',
#   'end',
#   'leave',
#   'feeling',
#   'warmth'],
#  ['i', 'enjoy', 'so', 'much'],
#  ['i',
#   'use',
#   'watch',
#   'movie',
#   'base',
#   'critic',
#   's',
#   'rating',
#   'now',
#   'i',
#   'know',
#   'good'],
#  ['touch', 'story', 'great', 'actor'],
#  ['awesome'],
#  ['script',
#   'act',
#   'two',
#   'lead',
#   'story',
#   'much',
#   'feel',
#   'relationship',
#   'very',
#   'well',
#   'do',
#   'ander',
#   'holm',
#   'act'],
#  ['jule',
#   'husband',
#   'play',
#   'actor',
#   'well',
#   'act',
#   'would',
#   'have',
#   'stellar'],
#  ['ander', 'really', 'do', 'not', 'make', 'connect', 'feel', 'husband'],
#  ['face', 'same', 'ninety', 'nine', 'time', 'screen'],
#  ['anyhow',
#   'still',
#   'well',
#   'execute',
#   'emotionally',
#   'mature',
#   'well',
#   'write',
#   'movie',
#   'watch'],
#  ['kudo', 'robert', 'niro', 'anne', 'hathaway'],
#  ['begin',
#   'i',
#   'felt',
#   'good',
#   'while',
#   'all',
#   'cringe',
#   'come',
#   'ruin',
#   'everything'],
#  ['not', 'so', 'feel', 'good', 'movie'],
#  ['good'],
#  ['so', 'cool', 'movie'],
#  ['la',
#   'cula',
#   'trata',
#   'horrible',
#   'lo',
#   'problema',
#   'una',
#   'pareja',
#   'al',
#   'acordar',
#   'su',
#   'propia',
#   'meta',
#   'la',
#   'historia',
#   'es',
#   'mal',
#   'sima',
#   'pero',
#   'robert',
#   'hathaway',
#   'la',
#   'vuelven',
#   'aburrida'],
#  ['really', 'enjoy', 'watch', 'movie'],
#  ['love', 'performance', 'anne', 'robert'],
#  ['all', 'great', 'review'],
#  ['bad', 'movie', 'i', 'have', 'see'],
#  ['movie',
#   'reflect',
#   'work',
#   'place',
#   'that',
#   'never',
#   'thousand',
#   'year',
#   'would',
#   'exist'],
#  ['i', 'just', 'narrow', 'mind'],
#  ['whatever', 'terrible'],
#  ['movie',
#   'just',
#   'such',
#   'feel',
#   'good',
#   'movie',
#   'i',
#   'always',
#   'end',
#   'up',
#   'so',
#   'happy',
#   'watching'],
#  ['robert',
#   'ha',
#   'trovato',
#   'ormai',
#   'casa',
#   'queste',
#   'commedie',
#   'cui',
#   'pu',
#   'esprimere',
#   'un',
#   'lato',
#   'pi',
#   'divertente',
#   's',
#   'lungo',
#   'sovrastato',
#   'da',
#   'grandi',
#   'performance',
#   'drammatiche'],
#  ['intern',
#   'un',
#   'film',
#   'piacevole',
#   'originale',
#   'e',
#   'con',
#   'davvero',
#   'pochi',
#   'difetti',
#   'lo',
#   'si',
#   'guarda',
#   'con',
#   'piacere',
#   'dall',
#   'inizio',
#   'alla',
#   'fine'],
#  ['magari',
#   'sarebbe',
#   'stato',
#   'interessante',
#   'completare',
#   'con',
#   'qualche',
#   'personaggio',
#   'di',
#   'contorno',
#   'pi',
#   'interessante',
#   'tratti',
#   'si',
#   'sente',
#   'un',
#   'po',
#   'la',
#   'mancanza'],
#  ['star', 'act', 'compliment', 'other'],
#  ['very', 'enjoyable', 'movie'],
#  ['movie', 'really', 'heal'],
#  ['i', 'could', 'see', 'importance', 'occupation', 'life'],
#  ['do',
#   'work',
#   'make',
#   'think',
#   'pride',
#   'esteem',
#   'rather',
#   'obsess',
#   'money'],
#  ['good',
#   'hearted',
#   'drama',
#   'comedy',
#   'that',
#   'entertain',
#   'become',
#   'overly',
#   'sentimental'],
#  ['relax', 'watch'],
#  ['robert', 'jako', 'alfa', 'i', 'omega'],
#  ['favorite', 'movie', 'ever', 'watch'],
#  [],
#  ['one',
#   'nancy',
#   'meyer',
#   'absolute',
#   'humane',
#   'best',
#   'usual',
#   'charm',
#   'turn',
#   'sweetness',
#   'something',
#   'unexpectedly',
#   'wholesomely',
#   'hearten',
#   'benefit',
#   'finely',
#   'cast',
#   'chemistry',
#   'that',
#   'enough',
#   'make',
#   'hilarious',
#   'insightful',
#   'comedy',
#   'one',
#   'best',
#   'feel',
#   'good',
#   'film',
#   'recent',
#   'memory'],
#  [],
#  ['not',
#   'even',
#   'inmense',
#   'act',
#   'chop',
#   'niro',
#   'hathaway',
#   'could',
#   'save',
#   'film',
#   'lack',
#   'focu',
#   'story'],
#  ['isnt', 'bad', 'movie', 'just', 'not', 'interest', 'memorable'],
#  ['bland'],
#  ['so', 'fun', 'watch', 'begin', 'end'],
#  ['i',
#   'have',
#   'always',
#   'fan',
#   'story',
#   'build',
#   'friendship',
#   'young',
#   'old',
#   'person',
#   'particularly',
#   'exchange',
#   'wisdom',
#   'which',
#   'involve',
#   'respect',
#   'mutual',
#   'admiration',
#   'compassion'],
#  ['feel', 'good', 'story'],
#  ['great', 'movie', 'very', 'wholesome', 'watch'],
#  ['two',
#   'star',
#   'fantastic',
#   'well',
#   'match',
#   'hathaway',
#   's',
#   'character',
#   'get',
#   'terrible',
#   'sexist',
#   'arch',
#   'that',
#   'seem',
#   'defend',
#   'man',
#   'cheat',
#   'woman',
#   'too',
#   'impowered'],
#  ['mark', 'zuckerberg', 'never', 'bring', 'ceo', 'teenager'],
#  ['movie', 'love', 'life', 'lesson', 'fall', 'getup'],
#  ['surprisingly', 'touch', 'happy'],
#  ['puts', 'life', 'feminism', 'work', 'marriage', 'kid', 'table', 'discuss'],
#  ['life', 'lesson', 'demonstrate', 'naturally', 'not', 'boring', 'way'],
#  ['still', 'great', 'actor'],
#  ['now', 'old', 'do', 'more', 'dramatic', 'movie', 'man', 'still', 'fire'],
#  ['facial', 'expression', 'one', 'else', 'could', 'ever', 'do'],
#  ['chemistry', 'get', 'hathaway', 'touch', 'happy'],
#  ['almost', 'connect', 'other'],
#  ['hathaway'],
#  ['gorgeous', 'frenetic', 'as', 'expressive', 'niro'],
#  ['could', 'do', 'scene', 'even', 'talk'],
#  ['intern',
#   'have',
#   'slow',
#   'tire',
#   'narrative',
#   'script',
#   'barely',
#   'move',
#   'end',
#   'disappoint'],
#  ['movie',
#   'very',
#   'sweet',
#   'do',
#   'fantastic',
#   'job',
#   'build',
#   'relationship',
#   'two',
#   'main',
#   'character'],
#  ['really', 'good', 'movie'],
#  ['not',
#   'kind',
#   'movie',
#   'i',
#   'see',
#   'i',
#   'have',
#   'admit',
#   'hathaway',
#   'very',
#   'good',
#   'together',
#   'movie'],
#  ['story',
#   'quite',
#   'clich',
#   'redeem',
#   'thank',
#   'modern',
#   'approach',
#   'chemistry',
#   'lead'],
#  ['i', 'love', 'movie'],
#  ['i', 'have', 'see', 'several', 'time'],
#  ['feel', 'good', 'film'],
#  ['i',
#   'think',
#   'whole',
#   'world',
#   'should',
#   'have',
#   'senior',
#   'intern',
#   'help',
#   'adapt',
#   'new',
#   'norm'],
#  ['also', 'make', 'feel', 'belong', 'still', 'part', 'something', 'community'],
#  ['i', 'love', 'anne', 'hathaway'],
#  ['i', 'think', 'great', 'actres'],
#  ['relationship', 'jule', 'hathaway', 'ben', 'very', 'admirable'],
#  ['father', 'more', 'colleague'],
#  ['i',
#   'do',
#   'not',
#   'though',
#   'matt',
#   'jule',
#   'husband',
#   'have',
#   'affair',
#   'make',
#   'jule',
#   'feel',
#   'fault',
#   'company',
#   'become',
#   'successful',
#   'less',
#   'two',
#   'year'],
#  ['however', 'end', 'great'],
#  ['everything', 'just', 'fell', 'place'],
#  ['so', 'anne', 'hathaway', 'do', 'leave', 'runway', 'devil', 'wear', 'prada'],
#  ['sort', 'anne', 'hathaway', 'fashion', 'cinematic', 'universe', 'perhaps'],
#  ['even', 'i', 'would', 'not', 'mind'],
#  ['joke',
#   'aside',
#   'intern',
#   'truly',
#   'heartfelt',
#   'cheerful',
#   'emotionally',
#   'uplifting',
#   'film',
#   'power',
#   'beautiful',
#   'nuanced',
#   'performance',
#   'rober',
#   'anne',
#   'hathaway'],
#  ['subplot',
#   'can',
#   'feel',
#   'irrelevant',
#   'final',
#   'story',
#   'feel',
#   'cram',
#   'fit',
#   'runtime'],
#  ['mean',
#   'film',
#   'get',
#   'boring',
#   'feel',
#   'there',
#   'not',
#   'much',
#   'substance',
#   'here'],
#  ['film', 'look', 'good', 'cinematography', 'fantastic'],
#  ['dialogue', 'quirky', 'witty'],
#  ['chemistry', 'hathaway', 'lifts', 'film', 'average', 'good'],
#  ['recommend'],
#  ['best', 'thing', 'i', 'can', 'say', 'intern', 'do', 'not', 'suck'],
#  ['draw', 'so', 'well', 'want', 'good'],
#  ['then', 'punch', 'gut', 'never', 'recover'],
#  ['end',
#   'feel',
#   'writer',
#   'get',
#   'one',
#   'yard',
#   'line',
#   'then',
#   'drop',
#   'ball'],
#  ['great', 'run', 'touchdown'],
#  ['i',
#   'pleasantly',
#   'surprised',
#   'much',
#   'i',
#   'like',
#   'movie',
#   'retire',
#   'businessman',
#   'widower',
#   'decide',
#   'apply',
#   'intern',
#   'successful',
#   'online',
#   'fashion',
#   'start',
#   'up',
#   'company',
#   'found',
#   'ambitious',
#   'jule',
#   'ostin',
#   'ann',
#   'hathaway',
#   'generation',
#   'apart',
#   'find',
#   'way',
#   'successfully',
#   'work',
#   'support',
#   'other'],
#  ['way', 'able', 'find', 'friendship', 'reliable', 'person', 'can', 'count'],
#  ['highly', 'recommended'],
#  ['have',
#   'intriguing',
#   'premise',
#   'do',
#   'not',
#   'evolve',
#   'too',
#   'much',
#   'commentaire',
#   'aside',
#   'clich',
#   'd',
#   'situation'],
#  ['still',
#   'charm',
#   'movie',
#   'good',
#   'watch',
#   'really',
#   'work',
#   'chemistry',
#   'anne',
#   'hathaway',
#   'do',
#   'best',
#   'robert',
#   'truly',
#   'standout'],
#  ['commedia',
#   'pi',
#   'che',
#   'dignitosa',
#   'che',
#   'nasconde',
#   'una',
#   'morale',
#   'pi',
#   'profonda',
#   'del',
#   'previsto',
#   'e',
#   'del',
#   'necessario'],
#  ['nella',
#   'seconda',
#   'meet',
#   'del',
#   'film',
#   'si',
#   'sbarca',
#   'territori',
#   'pericolosi',
#   'proponendo',
#   'un',
#   'idea',
#   'di',
#   'fondo',
#   'forzata',
#   'con',
#   'risvolti',
#   'narrativi',
#   'inconsistenti'],
#  ['la',
#   'buona',
#   'sintonia',
#   'tra',
#   'la',
#   'coppia',
#   'dei',
#   'protagonisti',
#   'rende',
#   'comunque',
#   'il',
#   'film',
#   'assolutamente',
#   'un',
#   'esperienza',
#   'leggera',
#   'e',
#   'passeggera'],
#  ['one', 'movie', 'that', 'just', 'put', 'happy', 'mood'],
#  ['not', 'classic', 'cinema', 'also', 'not', 'meant'],
#  ['main',
#   'succes',
#   'chemistry',
#   'entire',
#   'cast',
#   'particularly',
#   'two',
#   'lead'],
#  ['i',
#   'do',
#   'not',
#   'necessarily',
#   'dislike',
#   'film',
#   'have',
#   'way',
#   'too',
#   'many',
#   'cheesy',
#   'cringey',
#   'moment',
#   'enjoy'],
#  ['robert',
#   'anne',
#   'hathaway',
#   'good',
#   'lot',
#   'meaningful',
#   'scene',
#   'feel',
#   'force',
#   'due',
#   'write',
#   'dialogue'],
#  ['i',
#   'would',
#   'have',
#   'let',
#   'slide',
#   'intern',
#   'not',
#   'two',
#   'hour',
#   'that',
#   'too',
#   'much',
#   'cheese'],
#  ['story', 'beautifully', 'portrayed', 'very', 'powerful', 'actor'],
#  ['breath',
#   'fresh',
#   'air',
#   'violence',
#   'swear',
#   'politic',
#   'just',
#   'considerate',
#   'person'],
#  ['niro',
#   'great',
#   'help',
#   'everyone',
#   'everything',
#   'two',
#   'way',
#   'street',
#   'all',
#   'young',
#   'employee',
#   'very',
#   'respectful',
#   'too'],
#  ['george',
#   'martin',
#   'say',
#   'billy',
#   'preston',
#   's',
#   'time',
#   'beatle',
#   'lubricant',
#   'everyone',
#   'love',
#   'all',
#   'band',
#   'member',
#   'politer',
#   'other',
#   'good',
#   'spirit',
#   'there',
#   'pettynes',
#   'john',
#   'want',
#   'band',
#   'permanently',
#   'preston',
#   'leave',
#   'really',
#   'miss'],
#  ['really',
#   'great',
#   'chemistry',
#   'hathaway',
#   'subtle',
#   'intelligent',
#   'dialogue'],
#  ['however',
#   'i',
#   'think',
#   'husband',
#   'wife',
#   'role',
#   'have',
#   'reverse',
#   'viewer',
#   'would',
#   'not',
#   'so',
#   'pleased',
#   'conclusion',
#   'homemaker',
#   'should',
#   'totally',
#   'breadwinner',
#   'shut',
#   'up',
#   'mind',
#   'child'],
#  ['intern', 'must', 'see'],
#  ['film', 'not', 'only', 'heartwarming', 'leaf', 'good', 'feeling'],
#  ['such',
#   'positive',
#   'message',
#   'that',
#   'drive',
#   'home',
#   'good',
#   'person',
#   'hard',
#   'worker',
#   'mean'],
#  ['one', 'favorite', 'movie', 'time'],
#  ['okay'],
#  ['really',
#   'liked',
#   'play',
#   'old',
#   'person',
#   'stereotype',
#   'not',
#   'bad',
#   'way',
#   'just',
#   'ham',
#   'fisted',
#   'way'],
#  ['i', 'do', 'not', 'really', 'know', 'movie', 'try', 'teach'],
#  ['i',
#   'get',
#   'woman',
#   'can',
#   'good',
#   'boss',
#   'also',
#   'should',
#   'forgive',
#   'cheater'],
#  ['i', 'can', 'not', 'wipe', 'smile', 'face', 'watch'],
#  ['ultimate',
#   'feel',
#   'good',
#   'movie',
#   'tackle',
#   'issue',
#   'most',
#   'wholesome',
#   'way',
#   'possible'],
#  ['stellar', 'act', 'niro', 'hathaway', 'as', 'well'],
#  ['one',
#   'best',
#   'feel',
#   'good',
#   'movie',
#   'generation',
#   'give',
#   'nod',
#   'old',
#   'school',
#   'custom'],
#  ['i',
#   'appreciate',
#   'gentlemanly',
#   'likable',
#   'character',
#   'hathaway',
#   's',
#   'character',
#   'development',
#   'micro',
#   'macro',
#   'horrendous',
#   'husband',
#   'debacle'],
#  ['personally',
#   'could',
#   'have',
#   'do',
#   'out',
#   'part',
#   'movie',
#   'critic',
#   'already',
#   'say',
#   'movie',
#   'not',
#   'edgy',
#   'enough'],
#  ['i', 'will', 'watch', 'again', 'say'],
#  ['intern', 'suffer', 'lack', 'ideas', 'development', 'history'],
#  ['everything',
#   'unfold',
#   'area',
#   'almost',
#   'white',
#   'phone',
#   'golden',
#   'age',
#   'hollywood'],
#  ['have', 'problem', 'other', 'workaholic'],
#  ['problem',
#   'arise',
#   'everything',
#   'will',
#   'resolve',
#   'sooner',
#   'rather',
#   'later'],
#  ['nice', 'movie', 'see', 'family'],
#  ['movie',
#   'make',
#   'zero',
#   'time',
#   'basically',
#   'movie',
#   'u',
#   'wan',
#   'c',
#   'robert',
#   'niro',
#   'act',
#   'reg'],
#  ['guy'],
#  ['movie',
#   'cement',
#   'love',
#   'feel',
#   'good',
#   'movie',
#   'that',
#   'start',
#   'brilliantly',
#   'introduce',
#   'scary',
#   'side',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   's',
#   'insufferable',
#   'life',
#   'which',
#   'change',
#   'lot',
#   'accidentally',
#   'find',
#   'flyer',
#   'senior',
#   'internship',
#   'program'],
#  ['movie', 'best', 'ben', 'focus'],
#  ['which',
#   'do',
#   'not',
#   'happen',
#   'too',
#   'much',
#   'thank',
#   'anne',
#   'hathaway',
#   's',
#   'character',
#   'uninteresting',
#   'go',
#   'relationship',
#   'husband',
#   'bad',
#   'actor',
#   'way'],
#  ['great', 'cast', 'enjoyable', 'story'],
#  ['entertain', 'funny', 'sometimes', 'touch', 'plot'],
#  ['good', 'acting'],
#  ['i', 'find', 'hard', 'say', 'anything', 'negative', 'film'],
#  ['hathaway', 'really', 'work', 'well', 'together'],
#  ['funny',
#   'time',
#   'heart',
#   'warm',
#   'film',
#   'prove',
#   'talent',
#   'brilliantly',
#   'more',
#   'gentle',
#   'fatherly',
#   'role'],
#  ['s', 'cute', 'pathetic', 'terrible', 'actor'],
#  ['save', 'money'],
#  ['friend',
#   'mine',
#   'also',
#   'movie',
#   'lover',
#   'describe',
#   'movie',
#   'few',
#   'simple',
#   'word',
#   'do',
#   'robert',
#   'de',
#   'do',
#   'movie'],
#  ['normally', 'old', 'actor', 'project', 'really'],
#  ['good',
#   'story',
#   'tell',
#   'however',
#   'never',
#   'explain',
#   'man',
#   'all',
#   'experience',
#   'could',
#   'not',
#   'take',
#   'administrative',
#   'chore',
#   'boss'],
#  ['very', 'entertaining'],
#  ['refresh',
#   'see',
#   'niro',
#   'take',
#   'role',
#   'that',
#   'do',
#   'not',
#   'tap',
#   'best',
#   'act',
#   'skill',
#   'still',
#   'play',
#   'role',
#   'perfectly'],
#  ['character'],
#  ['i',
#   'have',
#   'see',
#   'movie',
#   'least',
#   'three',
#   'time',
#   'always',
#   'enjoy',
#   'time'],
#  ['robert',
#   'niro',
#   's',
#   'character',
#   'bring',
#   'calm',
#   'focu',
#   'very',
#   'upended',
#   'office',
#   'environment'],
#  ['favorite',
#   'scene',
#   'closet',
#   'explain',
#   'man',
#   'should',
#   'carry',
#   'handkerchief'],
#  ['cute', 'movie', 'would', 'recommend'],
#  ['sentimental', 'end'],
#  ['intern', 'funny', 'heartwarming'],
#  ['wonder', 'go', 'appal', 'dirty', 'grandpa'],
#  ['actually', 'pretty', 'funny', 'heart', 'warm'],
#  ['such', 'sweet', 'film'],
#  ['i', 'laugh', 'i', 'cry'],
#  ['major',
#   'feel',
#   'good',
#   'original',
#   'best',
#   'act',
#   'i',
#   'have',
#   'see',
#   'anne',
#   'hathaway',
#   'several',
#   'year'],
#  ['would', 'highly', 'recommend'],
#  ['feel',
#   'good',
#   'movie',
#   'i',
#   'sure',
#   'everyone',
#   'go',
#   'wish',
#   'intern',
#   'now'],
#  ['lovely', 'enjoyable', 'film'],
#  ['hathaway', 'niro', 'great', 'film'],
#  ['ok', 'movie', 'suck', 'movie'],
#  ['really', 'liked', 'movie', 'cast', 'great', 'story', 'full', 'surprise'],
#  ['next', 'genocidal', 'uprising'],
#  ['hathaway', 'great', 'form', 'intern'],
#  ['really', 'believable', 'ceo', 'jule', 'ostin', 'really', 'excels', 'role'],
#  ['nancy',
#   'meyer',
#   'really',
#   'excel',
#   'rom',
#   'com',
#   'movie',
#   'that',
#   'make',
#   'feel',
#   'character',
#   'believable',
#   'storyline',
#   'even',
#   'matter',
#   'absurd',
#   'might',
#   'actually',
#   'believable'],
#  ['aside',
#   'hathaway',
#   'breath',
#   'fresh',
#   'air',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'just',
#   'try',
#   'figure',
#   'out',
#   'life',
#   'retiree'],
#  ['only',
#   'negative',
#   'i',
#   'could',
#   'grasp',
#   'movie',
#   'fact',
#   'all',
#   'young',
#   'person',
#   'take',
#   'page',
#   's',
#   'experience',
#   'start',
#   'mold',
#   'way',
#   'life',
#   'never',
#   'reciprocate',
#   'behavior'],
#  ['i', 'gues', 'have', 'sign', 'up', 'facebook'],
#  ['workaholic',
#   'fan',
#   'i',
#   'really',
#   'enjoy',
#   'see',
#   'ander',
#   'more',
#   'serious',
#   'role',
#   'really',
#   'perform',
#   'quite',
#   'well'],
#  ['well', 'have', 'cry'],
#  ['great', 'chemistry', 'robert', 'niro', 'anne', 'hathaway'],
#  ['fun', 'funny'],
#  ['perfect', 'choice', 'datenight'],
#  ['write', 'garbage'],
#  ['feel', 'good', 'movie', 'heart', 'laugh', 'nothing', 'special'],
#  ['movie',
#   'earn',
#   'one',
#   'star',
#   'outstandingly',
#   'bland',
#   'point',
#   'would',
#   'fair',
#   'call',
#   'cinematic',
#   'equivalent',
#   'pack',
#   'white',
#   'k',
#   'mart',
#   'dres',
#   'shirt',
#   'watch',
#   'use',
#   'boxxy',
#   'software',
#   'yesterday'],
#  ['one', 'word', 'not', 'bad'],
#  ['great',
#   'movie',
#   'i',
#   'love',
#   'part',
#   'i',
#   'love',
#   'spontaneity',
#   'i',
#   'have',
#   'say',
#   'robert',
#   'anne',
#   'hathaway',
#   'dynamic',
#   'duo',
#   'i',
#   'would',
#   'kill',
#   'see',
#   'again',
#   'i',
#   'would',
#   'watch',
#   'masterpiece',
#   'multiple',
#   'time',
#   'still',
#   'happy',
#   'time'],
#  ['touch', 'heart', 'felt'],
#  ['great', 'performance', 'hathaway', 'niro'],
#  ['smart', 'witty', 'great', 'match'],
#  ['i', 'get', 'other', 'say', 'act', 'tire', 'old', 'just'],
#  ['sad', 'got', 'stoop', 'crap'],
#  ['intern', 'stack', 'pancake'],
#  ['warm', 'sweet', 'leaf', 'touch', 'belly', 'ache'],
#  ['doubt',
#   'drawn',
#   'cast',
#   'could',
#   'resist',
#   'movie',
#   'that',
#   'bring',
#   'together',
#   'robert',
#   'anne',
#   'hathaway'],
#  ['best', 'actor', 'respective', 'generation', 'wow'],
#  ['keep', 'wishing', 'could', 'find', 'other', 'good', 'movie'],
#  ['intern',
#   'not',
#   'bad',
#   'exactly',
#   'light',
#   'breezy',
#   'real',
#   'significance'],
#  ['niro',
#   'seem',
#   'have',
#   'retire',
#   'hard',
#   'boil',
#   'challenge',
#   'role',
#   'that',
#   'make',
#   'famous',
#   'play',
#   'good',
#   'hearted',
#   'retired',
#   'widower',
#   'name',
#   'ben',
#   'whittaker'],
#  ['retire',
#   'now',
#   'defunct',
#   'company',
#   'that',
#   'make',
#   'phone',
#   'book',
#   'now',
#   'spend',
#   'day',
#   'try',
#   'figure',
#   'out',
#   'spend',
#   'day'],
#  ['wife', 'forty', 'two', 'year', 'dead', 'need', 'challenge'],
#  ['so',
#   'answer',
#   'ad',
#   'outreach',
#   'program',
#   'senior',
#   'intern',
#   'senior',
#   'age',
#   'help',
#   'out',
#   'about',
#   'fit',
#   'successful',
#   'internet',
#   'company',
#   'that',
#   'specialize',
#   'woman',
#   's',
#   'clothing'],
#  ['ben',
#   'get',
#   'unenviable',
#   'task',
#   'intern',
#   'company',
#   's',
#   'ceo',
#   'supposedly',
#   'tough',
#   'nail',
#   'career',
#   'woman',
#   'name',
#   'jule',
#   'ostin',
#   'hathaway'],
#  ['claim',
#   'do',
#   'not',
#   'need',
#   'romantic',
#   'comedy',
#   'law',
#   'demand',
#   'discover',
#   'much',
#   'really',
#   'do',
#   'need',
#   'not',
#   'just',
#   'office',
#   'personal',
#   'life',
#   'as',
#   'well'],
#  ['become', 'driver', 'drive', 'miss', 'hathaway'],
#  ['eventually', 'become', 'confidant'],
#  ['two',
#   'build',
#   'nice',
#   'friendship',
#   'relief',
#   'report',
#   'do',
#   'not',
#   'bloom',
#   'may',
#   'december'],
#  ['problem'],
#  ['movie', 'bland', 'superfluous', 'get'],
#  ['director',
#   'nancy',
#   'meyer',
#   'set',
#   'up',
#   'inner',
#   'office',
#   'environment',
#   'reverie',
#   'shop',
#   'wear',
#   'sitcom'],
#  ['pleasant',
#   'nice',
#   'only',
#   'establish',
#   'so',
#   'ben',
#   's',
#   'old',
#   'school',
#   'experience',
#   'can',
#   'teach',
#   'young',
#   'thing',
#   'two',
#   'none',
#   'have',
#   'significant',
#   'payoff'],
#  ['person',
#   'office',
#   'young',
#   'snapper',
#   'whose',
#   'function',
#   'film',
#   'young',
#   'whipper',
#   'snapper',
#   'do',
#   'not',
#   'matter',
#   'either'],
#  ['not', 'developed', 'character', 'just', 'onlooker', 'ben', 's', 'success'],
#  ['ben',
#   'develop',
#   'half',
#   'write',
#   'pointless',
#   'semi',
#   'sorta',
#   'romance',
#   'company',
#   's',
#   'site',
#   'masseuse',
#   'rene',
#   'russo',
#   'which',
#   'go',
#   'nowhere',
#   'also',
#   'do',
#   'not',
#   'seem',
#   'matter'],
#  ['plot', 'development', 'pointless', 'too'],
#  ['surprised',
#   'find',
#   'jule',
#   'home',
#   'life',
#   'burden',
#   'fact',
#   'husband',
#   'matt',
#   'give',
#   'up',
#   'career',
#   'plan',
#   'stay',
#   'home',
#   'dad'],
#  ['nearly',
#   'jule',
#   'matt',
#   's',
#   'scene',
#   'dedicate',
#   'talk',
#   'fact',
#   'never',
#   'see',
#   'other'],
#  ['hmmm'],
#  ['first', 'hour', 'intern', 'i', 'fairly', 'bore'],
#  ['i',
#   'like',
#   'jule',
#   'ben',
#   'i',
#   'want',
#   'movie',
#   'clear',
#   'out',
#   'junky',
#   'plot',
#   'point',
#   'just',
#   'let',
#   'talk',
#   'let',
#   'human',
#   'connect',
#   'other'],
#  ['point', 'movie', 'have', 'real', 'dramatic', 'tension'],
#  ['then', 'happen'],
#  ['dramatic',
#   'situation',
#   'develop',
#   'actually',
#   'seem',
#   'give',
#   'movie',
#   'dramatic',
#   'weight'],
#  ['not',
#   'give',
#   'anything',
#   'away',
#   'ben',
#   'discover',
#   'something',
#   'matt',
#   'that',
#   'trouble'],
#  ['bring',
#   'jule',
#   'two',
#   'have',
#   'heartfelt',
#   'conversation',
#   'that',
#   'seem',
#   'draw',
#   'character',
#   'not',
#   'screenplay'],
#  ['unfortunately',
#   'result',
#   'dramatic',
#   'event',
#   'crush',
#   'resolution',
#   'nobody',
#   'nobody',
#   'go',
#   'happy'],
#  ['intern',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'specialize',
#   'cupcake',
#   'sweet',
#   'confection',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'give',
#   'father',
#   'bride',
#   'movie'],
#  ['film', 'seem', 'have', 'consistent', 'pattern'],
#  ['contain',
#   'germ',
#   'human',
#   'interest',
#   'wrap',
#   'up',
#   'gimmicky',
#   'script',
#   'that',
#   'fit',
#   'bad',
#   'television',
#   'sitcom'],
#  ['exception',
#   'great',
#   'comedy',
#   'make',
#   'thirty',
#   'year',
#   'ago',
#   'call',
#   'irreconcilable',
#   'difference',
#   'kid',
#   'divorce',
#   'squabble',
#   'parent'],
#  ['movie', 'have', 'truth', 'human', 'interest'],
#  ['intern', 'have', 'only', 'faint', 'echo', 'humanity'],
#  ['have', 'moment', 'here', 'there', 'show', 'promise', 'might', 'have'],
#  ['nice',
#   'sweet',
#   'uncomplicated',
#   'movie',
#   'that',
#   'will',
#   'begin',
#   'disappear',
#   'mind',
#   'get',
#   'theater',
#   'will',
#   'have',
#   'leave',
#   'completely',
#   'time',
#   'get',
#   'car'],
#  ['well', 'cup', 'tea'],
#  ['binge', 'watch', 'n', 'again'],
#  ['intern',
#   'tiene',
#   'mucho',
#   'que',
#   'contar',
#   'tampoco',
#   'que',
#   'trasmitir',
#   'e',
#   'un',
#   'film',
#   'que',
#   'ver',
#   'visto',
#   'por',
#   'que',
#   'tiene',
#   'grande',
#   'cosas',
#   'que',
#   'aportar',
#   'e',
#   'una',
#   'mala',
#   'cinta',
#   'pero',
#   'realmente',
#   'tiene',
#   'mucho',
#   'que',
#   'resaltar'],
#  ['enjoyed', 'way', 'more', 'i', 'expect'],
#  ['super', 'pleasant', 'easy', 'watch', 'need', 'something', 'feel', 'good'],
#  ['hathaway', 'awesome'],
#  ['heartwarming',
#   'movie',
#   'muddle',
#   'plot',
#   'uneven',
#   'performance',
#   'implausible',
#   'situation'],
#  ['robert',
#   'niro',
#   'star',
#   'retiree',
#   'lead',
#   'traditional',
#   'busines',
#   'life',
#   'struggle',
#   'boredom',
#   'retire',
#   'year'],
#  ['want',
#   'get',
#   'back',
#   'out',
#   'meet',
#   'person',
#   'purpose',
#   'enroll',
#   'senior',
#   'intern',
#   'program',
#   'internet',
#   'startup'],
#  ['apparently',
#   'place',
#   'only',
#   'employ',
#   'person',
#   'thirty',
#   'five',
#   'also',
#   'happen',
#   'loveable',
#   'character',
#   'simple',
#   'problem',
#   'that',
#   'niro',
#   's',
#   'character',
#   'can',
#   'solve'],
#  ['niro',
#   'play',
#   'character',
#   'compellingly',
#   'little',
#   'too',
#   'straight',
#   'convincingly',
#   'able',
#   'win',
#   'heart',
#   'anyone',
#   'talk',
#   'just',
#   'couple',
#   'minute'],
#  ['sadly',
#   'other',
#   'actor',
#   'not',
#   'caliber',
#   'wincingly',
#   'badly',
#   'direct',
#   'badly',
#   'act',
#   'scene',
#   'climax',
#   'film'],
#  ['also',
#   'do',
#   'not',
#   'think',
#   'too',
#   'hard',
#   'movie',
#   'there',
#   'plot',
#   'hole'],
#  ['nice',
#   'see',
#   'movie',
#   'value',
#   'wisdom',
#   'that',
#   'often',
#   'come',
#   'age',
#   'even',
#   'overdo',
#   'quite',
#   'bit'],
#  ['pleasant'],
#  ['i', 'really', 'enjoy', 'watch', 'movie'],
#  ['robert', 'come', 'genuine', 'sincere'],
#  ['throw', 'back', 'man', 'man'],
#  ['where', 'hanky'],
#  ['anne', 'hathaway', 'give', 'terrific', 'performance', 'as', 'well'],
#  ['great', 'date', 'movie'],
#  ['amaze', 'performance', 'as', 'well', 'awesome', 'support', 'cast'],
#  ['movie', 'have', 'hook', 'word', 'go'],
#  ['i', 'laugh', 'i', 'cry', 'i', 'invest', 'character'],
#  ['absolutely', 'love', 'one'],
#  ['all', 'movie', 'great', 'depiction', 'unique', 'friendship', 'generation'],
#  ['movie',
#   'have',
#   'problem',
#   'plot',
#   'especially',
#   'family',
#   'husband',
#   'storyline'],
#  ['end', 'abrupt', 'place', 'extremely', 'unsatisfactory'],
#  ['movie', 'make', 'cryyyy', 'so', 'much'],
#  ['not', 'sad', 'kind', 'cry', 'tear', 'up', 'know', 'good', 'movie'],
#  ['bring', 'so', 'much', 'joy'],
#  ['movie', 'really', 'touch', 'bone'],
#  ['first',
#   'time',
#   'i',
#   'cry',
#   'so',
#   'much',
#   'movie',
#   'just',
#   'soooo',
#   'damn',
#   'good'],
#  ['truly', 'best', 'inspiring', 'movie'],
#  ['one', 'best', 'comedy', 'drama', 'film', 'i', 'have', 'ever', 'see'],
#  ['dialogue', 'hilarious'],
#  ['chemistry', 'anne', 'hathaway', 'robert', 'fantastic', 'funny'],
#  ['great', 'work', 'lesson', 'learn', 'life', 'senior'],
#  ['let', 'know', 'importance', 'gentleman'],
#  ['comedy', 'drama', 'film', 'one', 'pretty', 'good'],
#  ['intern', 'refresh', 'change', 'pace', 'theatrically', 'speak'],
#  ['story', 'heart', 'solid', 'act', 'quite', 'bit', 'realism'],
#  ['i',
#   'love',
#   'niro',
#   'hathaway',
#   'anyway',
#   'chemistry',
#   'two',
#   'very',
#   'strong'],
#  ['performance',
#   'will',
#   'not',
#   'get',
#   'recognize',
#   'award',
#   'level',
#   'i',
#   'have',
#   'not',
#   'enjoy',
#   'niro',
#   'much',
#   'long',
#   'time'],
#  ['departure', 'precious'],
#  ['vibe',
#   'film',
#   'reminiscent',
#   'similarly',
#   'theme',
#   'eightys',
#   'ninetys',
#   'film',
#   'i',
#   'have',
#   'not',
#   'really',
#   'see',
#   'anything',
#   'almost',
#   'twenty',
#   'year'],
#  ['just', 'do', 'not', 'make', 'kind', 'movie', 'anymore'],
#  ['someone', 'age', 'pleasure', 'watch'],
#  ['play',
#   'mary',
#   'poppin',
#   'jeeve',
#   'type',
#   'character',
#   'never',
#   'put',
#   'foot',
#   'wrong',
#   'unbelievable',
#   'sage',
#   'kindly',
#   'old',
#   'man',
#   'can',
#   'also',
#   'get',
#   'erection',
#   'character',
#   'fairly',
#   'two',
#   'dimensional'],
#  ['movie', 'try', 'too', 'hard', 'progressive'],
#  ['virtually', 'shove', 'modernity', 'down', 'throat'],
#  ['here',
#   's',
#   'feminism',
#   'take',
#   'kick',
#   'nut',
#   'ageism',
#   'gender',
#   'role',
#   'boom'],
#  ['see', 'ya'],
#  ['laugh', 'genuine', 'emotion'],
#  ['overall', 'just', 'pretty', 'meh'],
#  ['pretty',
#   'much',
#   'just',
#   'ok',
#   'have',
#   'kind',
#   'touch',
#   'dramatic',
#   'moment',
#   'as',
#   'well',
#   'funny',
#   'one',
#   'also',
#   'dig',
#   'little',
#   'deep',
#   'time',
#   'that',
#   'flow',
#   'well',
#   'movie',
#   'deal',
#   'topic',
#   'work',
#   'life',
#   'balance',
#   'woman',
#   'workplace',
#   'infidelity'],
#  ['felt',
#   'kind',
#   'slow',
#   'though',
#   'fact',
#   'character',
#   'do',
#   'go',
#   'hard',
#   'time',
#   'deniros',
#   'performance',
#   'movie',
#   'general',
#   'so',
#   'light',
#   'hearted',
#   'hard',
#   'really',
#   'believe',
#   'anything',
#   'stake',
#   'anything',
#   'bad',
#   'would',
#   'happen'],
#  ['also',
#   'movie',
#   'feel',
#   'kind',
#   'giant',
#   'apple',
#   'advertisement',
#   'maybe',
#   'just'],
#  ['i', 'enjoy', 'movie'],
#  ['taught', 'milleniel', 'classy'],
#  ['movie', 'have', 'lot', 'heart'],
#  ['s', 'list', 'comedy', 'i', 'must', 'say', 'laugh', 'good', 'sparse'],
#  ['should', 'list', 'drama'],
#  ['i', 'mood', 'laugh', 's', 'i', 'pick', 'movie'],
#  ['ll', 'see', 'll', 'actually', 'share', 'few', 'tear', 'end'],
#  ['s', 'drama', 's', 'four', 'star'],
#  ['look', 'comedy', 'i', 'would', 'give', 'only', 'one', 'star'],
#  ['good', 'luck'],
#  ['great', 'movie'],
#  ['well', 'write', 'wonderful', 'cast'],
#  ['ll', 'laugh', 'maybe', 'even', 'cry', 'little'],
#  ['academy',
#   'award',
#   'winner',
#   'robert',
#   'niro',
#   'have',
#   'hit',
#   'bad',
#   'time',
#   'recently',
#   'term',
#   'quality',
#   'film'],
#  ['appear',
#   'garbage',
#   'such',
#   'meet',
#   'focker',
#   'little',
#   'focker',
#   'dirty',
#   'grandpa'],
#  ['nice', 'see', 'trash', 'movie', 'deserve', 'talent', 'worth', 'time'],
#  ['intern', 'not', 'specatular', 'mean'],
#  ['however', 'there', 'lot', 'like'],
#  ['thing', 'like', 'most', 'niro'],
#  ['carry', 'movie', 'shoulder', 'do', 'so', 'very', 'well'],
#  ['also',
#   'have',
#   'very',
#   'good',
#   'chemistry',
#   'academy',
#   'award',
#   'winner',
#   'anne',
#   'hathaway'],
#  ['scene', 'together', 'seem', 'very', 'genuine'],
#  ['almost', 'not', 'script'],
#  ['alone', 'make', 'movie', 'see'],
#  ['script',
#   'little',
#   'formulaic',
#   'term',
#   'storyline',
#   'still',
#   'make',
#   'entertaining',
#   'film',
#   'i',
#   'do',
#   'recommend'],
#  ['original', 'mostly', 'clean', 'comedy'],
#  ['loved', 'side', 'niro'],
#  ['so',
#   'known',
#   'tough',
#   'guy',
#   'role',
#   'refresh',
#   'see',
#   'very',
#   'reserved',
#   'performance'],
#  ['ann',
#   'hathaway',
#   'make',
#   'very',
#   'touching',
#   'movie',
#   'lot',
#   'commentary',
#   'life',
#   'should',
#   'important'],
#  ['sweet', 'touch', 'well', 'develop', 'story', 'today'],
#  ['diabolical',
#   'romantic',
#   'non',
#   'drama',
#   'write',
#   'directed',
#   'nancy',
#   'meyer',
#   'so',
#   'all',
#   'blame',
#   'rest'],
#  ['de', 'niro', 'have', 'own', 'reason', 'line', 'up', 'turkey'],
#  ['only',
#   'decent',
#   'performance',
#   'try',
#   'extract',
#   'pathos',
#   'subtlety',
#   'there',
#   'none'],
#  ['anne', 'hathaway', 'incredibly', 'irritate'],
#  ['real', 'clunker'],
#  ['movie', 'really', 'charm', 'especially', 'begin'],
#  ['go',
#   'i',
#   'keep',
#   'think',
#   'do',
#   'not',
#   'mess',
#   'up',
#   'do',
#   'not',
#   'mess',
#   'up'],
#  ['i', 'think', 'go', 'adrift', 'bit', 'i', 'still', 'like', 'overall'],
#  ['i', 'can', 'see', 'person', 'would', 'not', 'like', 'movie'],
#  ['robert',
#   's',
#   'character',
#   'too',
#   'perfect',
#   'end',
#   'tie',
#   'up',
#   'way',
#   'too',
#   'neat',
#   'scene',
#   'break',
#   'mother',
#   's',
#   'house',
#   'belong',
#   'different',
#   'movie',
#   'so'],
#  ['i',
#   'try',
#   'not',
#   'let',
#   'thing',
#   'bother',
#   'i',
#   'really',
#   'enjoy',
#   'two',
#   'lead',
#   'i',
#   'want',
#   'see',
#   'story',
#   'would',
#   'go'],
#  ['have',
#   'see',
#   'other',
#   'nancy',
#   'meyer',
#   'movie',
#   'somehow',
#   'i',
#   'have',
#   'see',
#   'know',
#   'get',
#   'here'],
#  ['there',
#   'nothing',
#   'challenge',
#   'all',
#   'memorable',
#   'will',
#   'feel',
#   'good',
#   'watching'],
#  ['thoroughly', 'enjoy'],
#  ['generally', 'good', 'movie'],
#  ['movie', 'intrigue', 'heart', 'warm'],
#  ['nice', 'film', 'easy', 'watching'],
#  ['cute', 'funny', 'movie'],
#  ['cliched', 'delightfully', 'so'],
#  ['love'],
#  ['heart', 'warm', 'funny'],
#  ['nice', 'chemistry', 'hathaway'],
#  ['far', 'one', 'new', 'favorite', 'movie'],
#  ['definitely', 'top', 'ten'],
#  ['very', 'biased', 'obvious', 'propaganda', 'piece'],
#  ['write',
#   'directed',
#   'nancy',
#   'meyer',
#   'star',
#   'movie',
#   'veteran',
#   'icon',
#   'robert',
#   'niro',
#   'ben',
#   'whittaker',
#   'come',
#   'retirement',
#   'eventually',
#   'accept',
#   'intern',
#   'internet',
#   'sell',
#   'sensation',
#   'ceo',
#   'magnet',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway'],
#  ['average', 'feel', 'good', 'movie'],
#  ['cool', 'concept'],
#  ['well', 'begin'],
#  ['pretty', 'good', 'not', 'amaze'],
#  ['scott',
#   'dr',
#   'scott',
#   'allison',
#   'professor',
#   'psychology',
#   'university',
#   'richmond',
#   'well',
#   'greg',
#   'robert',
#   'doesn',
#   't',
#   'appear',
#   'hurry',
#   'retire',
#   'real',
#   'life',
#   'movie'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'i',
#   'find',
#   'whole',
#   'thing',
#   're',
#   'tire'],
#  ['let',
#   'recap',
#   'scott',
#   'meet',
#   'ben',
#   'whitaker',
#   'robert',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'restless',
#   'dissatisfied',
#   'life',
#   'retiree'],
#  ['search',
#   'something',
#   'meaningful',
#   'do',
#   'time',
#   'stumble',
#   'advertisement',
#   'senior',
#   'internship',
#   'program'],
#  ['decide',
#   'apply',
#   'intern',
#   'company',
#   'call',
#   'fit',
#   'fast',
#   'grow',
#   'busines',
#   'that',
#   'sell',
#   'fashionable',
#   'clothing',
#   'online'],
#  ['ben', 's', 'interview', 'go', 'well', 'hire', 'intern'],
#  ['greg',
#   'greg',
#   'smith',
#   'founder',
#   'agile',
#   'writer',
#   'richmond',
#   'va',
#   'new',
#   'bos',
#   'jule',
#   'high',
#   'strung',
#   'workaholic',
#   'young',
#   'woman',
#   'anne',
#   'hathaway',
#   'micromanage',
#   'everyone'],
#  ['first', 'shun', 'ben', 'claim', 'doesn', 't', 'need', 'assistant'],
#  ['ben',
#   'employ',
#   'old',
#   'school',
#   'discipline',
#   'never',
#   'leave',
#   'building',
#   'bos',
#   'pick',
#   'up',
#   'boss',
#   's',
#   'loose',
#   'end'],
#  ['one',
#   'day',
#   'notice',
#   'driver',
#   'bit',
#   'too',
#   'drunk',
#   'drive',
#   'take',
#   'place',
#   'jule'],
#  ['know', 're', 'best', 'buddy'],
#  ['scott',
#   've',
#   'follow',
#   'movie',
#   'review',
#   'year',
#   'know',
#   'i',
#   'haven',
#   't',
#   'much',
#   'fan',
#   'robert',
#   'niro',
#   's',
#   'recent',
#   'body',
#   'work'],
#  ['intern', 'there', 'now', 'promising', 'indication', 'slump'],
#  ['niro',
#   'shine',
#   'portrayal',
#   'retire',
#   'gentleman',
#   'bygone',
#   'era',
#   'take',
#   'role',
#   'rookie',
#   'intern',
#   'quest',
#   'inject',
#   'geezerly',
#   'life',
#   'meaning'],
#  ['not',
#   'only',
#   'find',
#   'look',
#   'also',
#   'manage',
#   'endow',
#   'several',
#   'other',
#   'person',
#   's',
#   'live',
#   'richness',
#   'wisdom',
#   'direction'],
#  ['hero', 's', 'journey', 'here', 'take', 'unique', 'interesting', 'form'],
#  ['ben',
#   'start',
#   'out',
#   'useless',
#   'minion',
#   'jule',
#   'time',
#   'evolve',
#   'trust',
#   'sidekick'],
#  ['end', 'film', 'ben', 'arguably', 'jule', 'equal', 'also', 'mentor'],
#  ['extent',
#   'ben',
#   'jule',
#   'equal',
#   'one',
#   'could',
#   'argue',
#   'buddy',
#   'hero',
#   'follow',
#   'classic',
#   'pattern',
#   'odd',
#   'other',
#   'first',
#   'then',
#   'grow',
#   'bffl',
#   's',
#   'ben',
#   'sidekick',
#   'mentor',
#   'buddy',
#   'open',
#   'interpretation',
#   'here'],
#  ['regardless', 'relationship', 'evolve', 'become', 'transformative'],
#  ['greg',
#   'i',
#   'think',
#   'movie',
#   'too',
#   'reminiscent',
#   'last',
#   'year',
#   's',
#   'intern',
#   'star',
#   'vince',
#   'vaughn',
#   'owen',
#   'wilson'],
#  ['similarly',
#   'have',
#   'two',
#   'old',
#   'salesman',
#   'teach',
#   'old',
#   'school',
#   'lesson',
#   'internet',
#   'savvy',
#   'youngster',
#   'google'],
#  ['intern',
#   'little',
#   'more',
#   'personal',
#   'ben',
#   'take',
#   'more',
#   'mentorly',
#   'role',
#   'early',
#   'film'],
#  ['fact',
#   'much',
#   'remind',
#   'butler',
#   'similar',
#   'hobson',
#   'one',
#   'thousand',
#   'nine',
#   'hundred',
#   'eighty',
#   'one',
#   's',
#   'arthur',
#   'even',
#   'mary',
#   'poppin'],
#  ['take',
#   'jule',
#   'daughter',
#   'kindergarten',
#   'fixes',
#   'relationship',
#   'stay',
#   'home',
#   'husband'],
#  ['scott',
#   'just',
#   'review',
#   'martian',
#   'astronaut',
#   'watney',
#   'graduate',
#   'hero',
#   'teacher'],
#  ['review', 'note', 'ultimate', 'destination', 'hero', 'become', 'mentor'],
#  ['i', 'think', 'see', 'pattern', 'revisit', 'here', 'intern'],
#  ['ben',
#   'have',
#   'leader',
#   'major',
#   'company',
#   'have',
#   'retire',
#   'sedate',
#   'life'],
#  ['now',
#   'new',
#   'opportunity',
#   'have',
#   'chance',
#   'pas',
#   'wealth',
#   'knowledge',
#   'not',
#   'only',
#   'jule',
#   'also',
#   'all',
#   'member',
#   'staff'],
#  ['have', 'find', 'final', 'destination'],
#  ['scott',
#   'greg',
#   'movie',
#   'have',
#   'sweetnes',
#   'i',
#   'find',
#   'extremely',
#   'appeal'],
#  ['lead',
#   'character',
#   'need',
#   'something',
#   'need',
#   'can',
#   'only',
#   'find',
#   'help',
#   'other'],
#  ['jule', 'want', 'see', 'independent', 'so', 'resist', 'ben', 's', 'help'],
#  ['smart',
#   'enough',
#   'know',
#   'ben',
#   'represent',
#   'threat',
#   'authority',
#   'legitimacy',
#   'leader'],
#  ['so',
#   'bends',
#   'befit',
#   'good',
#   'hero',
#   'story',
#   'receptivity',
#   'change',
#   'bring',
#   'about',
#   'deep',
#   'hurt',
#   'devastate',
#   'reality',
#   'husband',
#   'cheat'],
#  ['point',
#   'out',
#   'greg',
#   'ben',
#   'have',
#   'already',
#   'accomplish',
#   'life',
#   'many',
#   'goal',
#   'jule',
#   'now',
#   'seek'],
#  ['so',
#   'developmentally',
#   'ready',
#   'just',
#   'assume',
#   'help',
#   'role',
#   'mentoring',
#   'function'],
#  ['say', 'student', 'ready', 'teacher', 'will', 'appear'],
#  ['first', 'half', 'movie', 'devote', 'jule', 'not', 'ready'],
#  ['hero', 'humble', 'way', 'end', 'up', 'key', 'opennes', 'transformation'],
#  ['i',
#   'enjoy',
#   'watch',
#   'two',
#   'hero',
#   'do',
#   'all',
#   'thing',
#   'that',
#   'hero',
#   'do',
#   'two',
#   'different',
#   'stage',
#   'life'],
#  ['thirty',
#   'forty',
#   'year',
#   'future',
#   'i',
#   'can',
#   'easily',
#   'envision',
#   'jule',
#   'do',
#   'all',
#   'thing',
#   'that',
#   'ben',
#   'do',
#   'movie'],
#  ['greg', 'actually', 'scott', 'i', 'find', 'movie', 'somewhat', 'patronize'],
#  ['aside',
#   'jule',
#   'all',
#   'other',
#   'character',
#   'story',
#   'caricature',
#   'stereotype',
#   'millennial'],
#  ['ben', 'seat', 'other', 'intern', 'recent', 'college', 'graduate'],
#  ['young', 'davi', 'kick', 'parent', 's', 'basement'],
#  ['so',
#   'ben',
#   'take',
#   'teach',
#   'importance',
#   'get',
#   'bed',
#   'time',
#   'dress',
#   'suit',
#   'tie'],
#  ['young',
#   'jason',
#   'too',
#   'interested',
#   'party',
#   'ben',
#   'show',
#   'way',
#   'moderation'],
#  ['young',
#   'administrative',
#   'assistant',
#   'becky',
#   'draw',
#   'tear',
#   'fear',
#   'ben',
#   'get',
#   'more',
#   'attention'],
#  ['i',
#   've',
#   'get',
#   'degree',
#   'marketing',
#   'harvard',
#   'wah',
#   'wah',
#   'wah',
#   'course',
#   'ben',
#   'calm',
#   'down',
#   'pat',
#   'hanky',
#   'then',
#   'push',
#   'jule',
#   'delegate',
#   'authority',
#   'becky'],
#  ['stereotype',
#   'that',
#   'will',
#   'appeal',
#   'old',
#   'crowd',
#   'appear',
#   'target',
#   'audience'],
#  ['there', 's', 'nuance', 'here'],
#  ['jule',
#   'female',
#   'mark',
#   'zuckerberg',
#   'need',
#   'nudge',
#   'realize',
#   's',
# ...
#   'ceo',
#   'bike',
#   'office'],
#  ['easy',
#   'watch',
#   'not',
#   'too',
#   'tax',
#   'brain',
#   'crap',
#   'end',
#   'miscast',
#   'husband',
#   'anne',
#   'hathaway',
#   'completely'],
#  ['movie', 'surprise'],
#  ['i',
#   'think',
#   'go',
#   'constantly',
#   'make',
#   'joke',
#   'old',
#   'person',
#   'do',
#   'have',
#   'few',
#   'joke',
#   'nature',
#   'more',
#   'mentorship',
#   'can',
#   'positively',
#   'change'],
#  ['nice', 'see', 'movie', 'character', 'basically', 'good', 'flawed'],
#  ['also', 'make', 'feel', 'good', 'warm', 'heart'],
#  ['need', 'time', 'time'],
#  ['have',
#   'grow',
#   'up',
#   'watch',
#   'play',
#   'great',
#   'role',
#   'godfather',
#   'part',
#   'two',
#   'casino',
#   'goodfellow',
#   'etc'],
#  ['really',
#   'do',
#   'not',
#   'want',
#   'watch',
#   'movie',
#   'so',
#   'far',
#   'removed',
#   'genre'],
#  ['sit', 'down', 'watch', 'flick', 'three', 'girl', 'really', 'enjoy'],
#  ['btw',
#   'just',
#   'do',
#   'not',
#   'understand',
#   'bad',
#   'wrap',
#   'anne',
#   'hathaway',
#   'think',
#   'great'],
#  ['la',
#   'directora',
#   'nancy',
#   'meyer',
#   'sabe',
#   'hacer',
#   'unos',
#   'estupendo',
#   'chick',
#   'flick',
#   'complicate',
#   'something',
#   's',
#   'get',
#   'ta',
#   'give',
#   'y',
#   'woman',
#   'want',
#   'son',
#   'alguno',
#   'ejemplos'],
#  ['intern',
#   'e',
#   'la',
#   'n',
#   'os',
#   'un',
#   'estupendo',
#   'robert',
#   'que',
#   'termina',
#   'convirti',
#   'ndose',
#   'un',
#   'practicante',
#   'una',
#   'internet',
#   'e',
#   'definitivamente',
#   'able'],
#  ['la',
#   'qu',
#   'mica',
#   'hathaway',
#   'su',
#   'joven',
#   'jefe',
#   'e',
#   'maravillosa',
#   'y',
#   'hace',
#   'cinta',
#   'algo',
#   'muy',
#   'pero',
#   'muy',
#   'entretenido'],
#  ['good',
#   'chemistry',
#   'hathaway',
#   'de',
#   'niro',
#   'carry',
#   'movie',
#   'anyone',
#   'fifty',
#   'five',
#   'will',
#   'enjoy',
#   'ageless',
#   'focu'],
#  ['recommend'],
#  ['top', 'movie', 'really', 'enjoy', 'one'],
#  ['personally',
#   'one',
#   'favourite',
#   'movie',
#   'now',
#   'time',
#   'i',
#   'watch',
#   'i',
#   'still',
#   'love',
#   'great',
#   'film'],
#  ['intern', 'shadow', 'doubt', 'two', 'thousand', 'fifteen', 'film'],
#  ['twenty', 'year', 'intern', 'would', 'not', 'make'],
#  ['atleast', 'not'],
#  ['handle',
#   'driven',
#   'young',
#   'work',
#   'woman',
#   'seemingly',
#   'infinite',
#   'hustle',
#   'stay',
#   'home',
#   'father',
#   'nary',
#   'hint',
#   'ridicule'],
#  ['character', 'accept', 'as', 'simply', 'would', 'wear', 'sock', 'shoe'],
#  ['elephant',
#   'room',
#   'ben',
#   'play',
#   'supurbly',
#   'robert',
#   'just',
#   'right',
#   'mix',
#   'understated',
#   'sensitivity',
#   'decade',
#   'life',
#   'experience',
#   'i',
#   'tell',
#   'snark'],
#  ['ben',
#   's',
#   'very',
#   'senior',
#   'intern',
#   'anne',
#   'hathaway',
#   's',
#   'jule',
#   'ostin',
#   'hustlin',
#   'twenty',
#   'on',
#   'century',
#   'sister',
#   'doin',
#   'daughter',
#   'stay',
#   'home',
#   'husband'],
#  ['ben',
#   'never',
#   'condescend',
#   'always',
#   'humble',
#   'willing',
#   'go',
#   'good',
#   'motley',
#   'crew',
#   'co',
#   'worker'],
#  ['take',
#   'logical',
#   'conclusion',
#   'dare',
#   'heist',
#   'ben',
#   'head',
#   'up',
#   'fellow',
#   'desk',
#   'jockey',
#   'delete',
#   'disparage',
#   'email',
#   'not',
#   'so',
#   'fearless',
#   'female',
#   'leader',
#   'accidently',
#   'send',
#   'mother'],
#  ['easily',
#   'film',
#   's',
#   'most',
#   'ridiculous',
#   'moment',
#   'do',
#   'not',
#   'outstay',
#   'welcome',
#   'serve',
#   'effective',
#   'palate',
#   'cleanser',
#   'middle',
#   'movie'],
#  ['there',
#   'interesting',
#   'twist',
#   'little',
#   'hiest',
#   'which',
#   'definitely',
#   'need',
#   'because',
#   'as',
#   'good',
#   'intern',
#   'never',
#   'lay',
#   'down',
#   'firm',
#   'mission',
#   'statement',
#   'lead',
#   'accomplish',
#   'end',
#   'twist',
#   'give',
#   'welcome',
#   'drama',
#   'i',
#   'find',
#   'very',
#   'enjoyable',
#   'sweet',
#   'likable',
#   'film'],
#  ['fine', 'nothing', 'incredible', 'groundbreaking'],
#  ['have',
#   'solid',
#   'intriguing',
#   'premise',
#   'primarily',
#   'coast',
#   'chemistry',
#   'large',
#   'cast'],
#  ['bonu', 'point', 'interior', 'design', 'porn'],
#  ['make', 'feel', 'good'],
#  ['ice', 'cream'],
#  ['plain'],
#  ['simple'],
#  ['one',
#   'perfect',
#   'late',
#   'night',
#   'tb',
#   'flick',
#   'catch',
#   'hang',
#   'out',
#   'ironically',
#   'enough',
#   'grandparent',
#   's',
#   'house'],
#  ['film', 'simple', 'cast', 'earnest', 'charm'],
#  ['leave', 'cynicism', 'door', 'will', 'fine', 'even', 'get', 'abrupt', 'end'],
#  ['great',
#   'movie',
#   'lot',
#   'potential',
#   'film',
#   'perfect',
#   'flow',
#   'story',
#   'great',
#   'collection',
#   'plot',
#   'awesome',
#   'pair',
#   'incredible',
#   'cast',
#   'still',
#   'robert',
#   'di',
#   'nero'],
#  ['actor'],
#  ['never', 'fail', 'amaze', 'ur', 'charm', 'performance', 'never', 'ever'],
#  ['always', 'right', 'person', 'great', 'performance'],
#  ['anna', 'also', 'incredible', 'so', 'rest', 'cast'],
#  ['overall', 'full', 'fun', 'great', 'entertainment'],
#  ['nancy', 'make', 'incredible', 'film', 'hat', 'off'],
#  ['really', 'good'],
#  ['wan', 'watch', 'twond', 'time'],
#  ['eight',
#   'thirty',
#   'one',
#   'sixteen',
#   'i',
#   'actually',
#   'dislike',
#   'watching',
#   'film'],
#  ['begin', 'i', 'do', 'enjoy', 'cute'],
#  ['while',
#   'become',
#   'very',
#   'obvious',
#   'story',
#   'make',
#   'up',
#   'i',
#   'could',
#   'envision',
#   'someone',
#   'sit',
#   'there',
#   'write',
#   'script'],
#  ['authenticity', 'never', 'good', 'thing'],
#  ['then',
#   'half',
#   'way',
#   'film',
#   'becomes',
#   'much',
#   'darker',
#   'quite',
#   'frankly',
#   'just',
#   'depress'],
#  ['resolution', 'end', 'not', 'really', 'good', 'resolution'],
#  ['so', 'fake', 'depress'],
#  ['not', 'great', 'entertainment', 'ask'],
#  ['good',
#   'end',
#   'not',
#   'such',
#   'big',
#   'fan',
#   'end',
#   'other',
#   'then',
#   'great',
#   'movie',
#   'great',
#   'cast'],
#  ['quite', 'nice', 'film', 'honest'],
#  ['anne', 'hathaway', 'never', 'look', 'well'],
#  ['i', 'actually', 'kind', 'like', 'all', 'year'],
#  ['bit', 'cheesy', 'worth', 'watch'],
#  ['really', 'good', 'movie'],
#  ['brilliant', 'act', 'storyline'],
#  ['enjoyable', 'forgettable'],
#  ['well', 'movie', 'then', 'recent', 'stuff'],
#  ['end', 'leave', 'lot', 'desire'],
#  ['just', 'end'],
#  ['dumb'],
#  ['relatable', 'very', 'relevant'],
#  ['dynamic', 'character', 'sweet', 'funny'],
#  ['genuine'],
#  ['ok'],
#  ['i', 'felt', 'start', 'off', 'strong', 'kind', 'fizzle', 'wore'],
#  ['i',
#   'actually',
#   'think',
#   'would',
#   'more',
#   'comedy',
#   'joke',
#   'do',
#   'have',
#   'first',
#   'half',
#   'movie'],
#  ['act', 'hathaway', 'great', 'i', 'hat', 'abrupt', 'end'],
#  ['nice', 'storyline', 'i', 'enjoy', 'watch'],
#  ['great',
#   'movie',
#   'i',
#   'do',
#   'not',
#   'want',
#   'end',
#   'last',
#   'half',
#   'movie',
#   'i',
#   'keep',
#   'thinking',
#   'go',
#   'hire',
#   'ben',
#   'ceo'],
#  ['cute', 'yet', 'thin', 'storyline'],
#  ['enjoy', 'pair', 'hathaway', 'de'],
#  ['felt',
#   'cheat',
#   'hathaway',
#   's',
#   'character',
#   's',
#   'obvious',
#   'storyline',
#   'wish',
#   'would',
#   'give',
#   'de',
#   's',
#   'character',
#   'more',
#   'story',
#   'say',
#   'maybe',
#   'point',
#   'have',
#   'senior',
#   'character',
#   'quietly',
#   'resolutely',
#   'prominently',
#   'affect',
#   'one',
#   's',
#   'life'],
#  ['thought',
#   'niro',
#   'great',
#   'young',
#   'man',
#   'provide',
#   'guidance',
#   'support'],
#  ['nice', 'watch', 'young', 'man', 'evolve'],
#  ['disneyesque', 'predictability'],
#  ['i', 'not', 'one', 'watch', 'type', 'movie'],
#  ['i', 'tend', 'prefer', 'horror', 'action'],
#  ['however', 'one', 'strays', 'expectation', 'kind'],
#  ['spoiler'],
#  ['i',
#   'almost',
#   'expect',
#   'scene',
#   'niro',
#   's',
#   'character',
#   'would',
#   'mess',
#   'up',
#   'everyone',
#   'would',
#   'see',
#   'not',
#   'perfect',
#   'end',
#   'would',
#   'find',
#   'love',
#   'anyway',
#   'i',
#   'hop',
#   'elder',
#   'wisdom',
#   'provide',
#   'seem',
#   'answer',
#   'everything',
#   'i',
#   'think',
#   'lack',
#   'recent',
#   'generation'],
#  ['i', 'glad', 'movie', 'make'],
#  ['show', 'miss', 'need', 'not', 'only', 'youth', 'today', 'company', 'today'],
#  ['good', 'job'],
#  ['funny',
#   'pretty',
#   'witty',
#   'satire',
#   'politic',
#   'today',
#   's',
#   'busines',
#   'office'],
#  ['just', 'right', 'mix', 'serious', 'humor'],
#  ['good', 'date', 'night', 'movie'],
#  ['heartfelt', 'movie', 'great', 'story', 'fantastic', 'acting'],
#  ['retire',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'ben',
#   'play',
#   'robert',
#   'bore',
#   'retired',
#   'life'],
#  ['apply',
#   'senior',
#   'intern',
#   'online',
#   'fashion',
#   'retailer',
#   'get',
#   'position'],
#  ['founder',
#   'company',
#   'jule',
#   'ostin',
#   'anne',
#   'hathaway',
#   'tireless',
#   'driven',
#   'demand',
#   'dynamic',
#   'workaholic'],
#  ['ben',
#   'make',
#   'intern',
#   'nominal',
#   'role',
#   'do',
#   'not',
#   'intend',
#   'give',
#   'work',
#   'just',
#   'window',
#   'dress'],
#  ['however',
#   'ben',
#   'prove',
#   'quite',
#   'useful',
#   'more',
#   'source',
#   'support',
#   'wisdom'],
#  ['good', 'surprisingly', 'so'],
#  ['i',
#   'expect',
#   'farcical',
#   'half',
#   'bake',
#   'comedy',
#   'old',
#   'guy',
#   'rejoin',
#   'work',
#   'force',
#   'struggle',
#   'modern',
#   'gadget',
#   'work',
#   'process'],
#  ['there',
#   'few',
#   'example',
#   'movie',
#   'far',
#   'more',
#   'story',
#   'generational',
#   'difference'],
#  ['more', 'drama', 'comedy', 'good', 'one', 'too'],
#  ['there',
#   'theme',
#   'generational',
#   'wisdom',
#   'not',
#   'judge',
#   'person',
#   'age',
#   'anything',
#   'superficial',
#   'make',
#   'most',
#   'person',
#   's',
#   'talent'],
#  ['also', 'movie', 'start', 'do', 'enjoy'],
#  ['moreover', 'simply', 'nice', 'story'],
#  ['solid', 'work', 'robert', 'lead', 'role'],
#  ['do',
#   'not',
#   'do',
#   'bad',
#   'performance',
#   'have',
#   'not',
#   'stop',
#   'past',
#   'take',
#   'role',
#   'movie',
#   'that',
#   'well',
#   'standard'],
#  ['not', 'one', 'role', 'movie'],
#  ['sensitively', 'play', 'ideal', 'role'],
#  ['good',
#   'work',
#   'too',
#   'anne',
#   'hathaway',
#   'very',
#   'convincing',
#   'go',
#   'get',
#   'entrepreneur'],
#  ['bottom', 'line', 'robert', 'd', 'make', 'movie'],
#  ['really', 'enjoy'],
#  ['anne', 'hathaway', 'also', 'play', 'great', 'part', 'also'],
#  ['film', 'that', 'differentiate', 'young', 'old', 'generation'],
#  ['i', 'would', 'definitely', 'say', 'director', 's', 'best', 'film'],
#  ['i', 'have', 'like', 'other', 'film', 'lot', 'different'],
#  ['i',
#   'mean',
#   'well',
#   'write',
#   'screenplay',
#   'much',
#   'good',
#   'understood',
#   'contemporary',
#   'world',
#   'just',
#   'focus',
#   'relationship',
#   'usual'],
#  ['so',
#   'addition',
#   'digital',
#   'world',
#   'stuff',
#   'make',
#   'all',
#   'difference',
#   'i',
#   'completely',
#   'enjoy'],
#  ['do',
#   'not',
#   'think',
#   'would',
#   'internship',
#   'i',
#   'initially',
#   'think',
#   'slightly',
#   'much',
#   'good',
#   'everyway'],
#  ['go',
#   'agree',
#   'film',
#   's',
#   'poster',
#   'trailer',
#   'not',
#   'very',
#   'impressive',
#   'actual',
#   'film',
#   'do',
#   'grab',
#   'full',
#   'attention'],
#  ['two',
#   'hour',
#   'film',
#   'always',
#   'concern',
#   'film',
#   'run',
#   'long',
#   'i',
#   'can',
#   'even',
#   'sit',
#   'half',
#   'hour'],
#  ['anyway', 'story', 'runtime', 'pace', 'incredible'],
#  ['there',
#   'something',
#   'interesting',
#   'go',
#   'forget',
#   'focu',
#   'flaw',
#   'enjoy',
#   'time',
#   'which',
#   'i',
#   'exactly',
#   'do',
#   'here'],
#  ['not',
#   'comedy',
#   'go',
#   'laugh',
#   'openly',
#   'loud',
#   'comedy',
#   'sense',
#   'set',
#   'character',
#   'film',
#   'have'],
#  ['i',
#   'mean',
#   'story',
#   'digital',
#   'busines',
#   'most',
#   'computer',
#   'consider',
#   'geek'],
#  ['so',
#   'theirs',
#   'world',
#   'nothing',
#   'just',
#   'hook',
#   'work',
#   'forget',
#   'actual',
#   'world'],
#  ['even', 'someone', 'next', 'room', 'tweet'],
#  ['remind',
#   'only',
#   'have',
#   'change',
#   'not',
#   'physical',
#   'world',
#   'main',
#   'character',
#   'old',
#   'wise',
#   'influence',
#   'young',
#   'generation',
#   'person'],
#  ['so',
#   'actor',
#   'undoubtedly',
#   'best',
#   'thing',
#   'apart',
#   'direction',
#   'story'],
#  ['seventy',
#   'three',
#   'year',
#   'old',
#   'robert',
#   'still',
#   'impress',
#   'extraordinary',
#   'character',
#   'display'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'whoever',
#   'mind',
#   'write',
#   'role',
#   'perfectly',
#   'fit',
#   'none',
#   'other'],
#  ['then', 'there', 'anne', 'hathaway', 'opposite', 'side', 'equal', 'part'],
#  ['narration',
#   'point',
#   'view',
#   'start',
#   'niro',
#   's',
#   'quickly',
#   'middle',
#   'take',
#   'circle',
#   'cover',
#   'other',
#   'well'],
#  ['then',
#   'come',
#   'professional',
#   'personal',
#   'life',
#   'topic',
#   'develop',
#   'brought',
#   'small',
#   'family',
#   'affected',
#   'workaholic',
#   'mother'],
#  ['so',
#   'enter',
#   'expect',
#   'comedy',
#   'probably',
#   'will',
#   'not',
#   'disappoint',
#   'deliver',
#   'wish',
#   'which',
#   'heartwarming',
#   'drama',
#   'emotional',
#   'moment'],
#  ['surely',
#   'recommend',
#   'especially',
#   'youngster',
#   're',
#   'addict',
#   'digital',
#   'world'],
#  ['two', 'thousand', 'twenty', 'four', 'eight', 'ten', 'zero', 'zero', 'zero'],
#  ['love', 'movie', 'beggining', 'end'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'robert',
#   'seem',
#   'too',
#   'perfect',
#   'turn',
#   'off',
#   'here'],
#  ['really', 'enjoy', 'movie'],
#  ['two', 'thousand', 'twenty', 'four', 'ten', 'ten', 'zero', 'zero', 'zero'],
#  ['intern', 'funny', 'charm', 'heartwarming'],
#  ['movie',
#   'old',
#   'man',
#   'that',
#   'retire',
#   'go',
#   'back',
#   'outdoor',
#   'world',
#   'get',
#   'job',
#   'intern',
#   'young',
#   'person',
#   'work',
#   'place',
#   'great',
#   'plot'],
#  ['i', 'think', 'movie', 'go', 'bad', 'not'],
#  ['however', 'end', 'movie', 'do', 'get', 'kind', 'boring'],
#  ['overall', 'great', 'movie'],
#  ['robert', 's', 'anne', 'hathaway', 's', 'best', 'movie', 'yet'],
#  ['two', 'thumb'],
#  ['i', 'would', 'very', 'much', 'suggest', 'movie'],
#  ['average',
#   'i',
#   'internally',
#   'grateful',
#   'take',
#   'few',
#   'minute',
#   'day',
#   'read',
#   'cheesy',
#   'review',
#   'writer',
#   'director',
#   'nancy',
#   'meyer',
#   'comedy',
#   'intern'],
#  ['i', 'hope', 'make', 'puntership', 'fly', 'color'],
#  ['anyway', 'movie', 'star', 'ben', 'whittaker'],
#  ['ben',
#   'seventy',
#   'year',
#   'old',
#   'widower',
#   'live',
#   'out',
#   'retired',
#   'day',
#   'need',
#   'fill',
#   'void'],
#  ['come',
#   'opportunity',
#   'intern',
#   'senior',
#   'citizen',
#   'internship',
#   'program',
#   'start',
#   'up',
#   'fashion',
#   'online',
#   'company'],
#  ['anne',
#   'hathaway',
#   'co',
#   'star',
#   'jule',
#   'founder',
#   'company',
#   'first',
#   'reluctant',
#   'work',
#   'older',
#   'crowd',
#   'then',
#   'take',
#   'genuine',
#   'like',
#   'ben',
#   'not',
#   'only',
#   'dependable',
#   'intern',
#   'father',
#   'figure'],
#  ['course',
#   'there',
#   'conflict',
#   'that',
#   'incorporate',
#   'film',
#   'that',
#   'cause',
#   'relationship',
#   'challenge',
#   'jule',
#   'own',
#   'relationship',
#   'husband'],
#  ['i',
#   'admire',
#   'meyer',
#   'direct',
#   'first',
#   'hour',
#   'movie',
#   'then',
#   'look',
#   'intern',
#   'ran',
#   'steam',
#   'second',
#   'half',
#   'too',
#   'many',
#   'elongated',
#   'scene',
#   'i',
#   'could',
#   'not',
#   'give',
#   'intern',
#   'review',
#   'promotion'],
#  ['i', 'do', 'de', 'ben', 'hathaway', 'jule', 'not', 'too', 'shabby'],
#  ['intern', 'two', 'hour', 'do', 'not', 'have'],
#  ['intern',
#   'could',
#   'have',
#   'do',
#   'job',
#   'sheer',
#   'ninety',
#   'minute',
#   'stay',
#   'not',
#   'need',
#   'overtime',
#   'i',
#   'can',
#   'not',
#   'highly',
#   'recommend',
#   'hire',
#   'intern',
#   'movie',
#   'watch',
#   'company'],
#  ['really',
#   'good',
#   'movie',
#   'wholesome',
#   'not',
#   'goofy',
#   'dirty',
#   'liberal',
#   'trash',
#   'heap'],
#  ['just', 'good', 'movie'],
#  ['film', 'i', 'like', 'make', 'fell', 'good', 'happy'],
#  ['as',
#   'long',
#   'do',
#   'not',
#   'really',
#   'pay',
#   'attention',
#   'plot',
#   'nice',
#   'movie'],
#  ['watch',
#   'preview',
#   'i',
#   'reluctant',
#   'watch',
#   'film',
#   'i',
#   'think',
#   'only',
#   'possible',
#   'story',
#   'line',
#   'old',
#   'intern',
#   'would',
#   'end',
#   'up',
#   'die'],
#  ['movie',
#   'nothing',
#   'instead',
#   'adorable',
#   'probably',
#   'one',
#   'new',
#   'favorite',
#   'movie'],
#  ['end', 'little', 'abrupt', 'overall', 'i', 'highly', 'recommend'],
#  ['i', 'actually', 'enjoy', 'movie'],
#  ['robert', 'di', 'nero', 'fun', 'hilarious', 'downright', 'adorable'],
#  ['i',
#   'have',
#   'always',
#   'love',
#   'anne',
#   'hathaway',
#   'i',
#   'think',
#   'great',
#   'film'],
#  ['only', 'part', 'annoy', 'small', 'husband', 'cheat', 'story'],
#  ...]

# %%
# remove empty list
modified_sentences = [sentence for sentence in modified_sentences if sentence]

# %%
## remove words with len=1

modified_sentences_2 = modified_sentences.copy()

modified_sentences_2 = [[i for i in word if len(i) > 1] for word in modified_sentences_2]


modified_sentences_2[:10]
# Out:
# [['not', 'expect'],
#  ['really', 'enjoy'],
#  ['include', 'hope', 'redemption', 'end'],
#  ['true', 'feel', 'good', 'movie', 'wish', 'saw', 'theater'],
#  ['anne',
#   'hathaway',
#   'robert',
#   'niro',
#   'have',
#   'great',
#   'chemistry',
#   'movie',
#   'tell',
#   'great',
#   'story',
#   'two',
#   'person',
#   'generation',
#   'apart',
#   'grow',
#   'closer',
#   'learn',
#   'other'],
#  ['there', 'strong', 'character', 'development', 'solid', 'cast'],
#  ['recommend', 'anyone'],
#  ['all', 'piece', 'seem', 'there', 'truly', 'appropriate', 'third', 'act'],
#  ['intern',
#   'have',
#   'chemistry',
#   'rich',
#   'lead',
#   'performance',
#   'tenure',
#   'auteur',
#   'camera'],
#  ['brilliant', 'movie']]

# %%
lengths = [len(sentence) for sentence in modified_sentences_2]

# sentence lenths discriptive analysis
median = np.median(lengths)
mean = np.mean(lengths)
percentile_75 = np.percentile(lengths, 75)
percentile_90 = np.percentile(lengths, 90)
percentile_95 = np.percentile(lengths, 95)

print ('median: ', median, 
       'mean: ', mean, 
       'per_75: ', percentile_75, 
       'per_90: ', percentile_90, 
       'per_95: ', percentile_95)
# Out:
# median:  8.0 mean:  9.360747365059087 per_75:  12.0 per_90:  18.0 per_95:  22.0

# %%
#wordcloud
from wordcloud import WordCloud
text_data_usa = " ".join([" ".join(sentence) for sentence in modified_sentences_2])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data_usa)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from collections import Counter
all_words = [word for sentence in modified_sentences_2 for word in sentence]
word_freq= Counter(all_words)
print(word_freq)
# Out:
# Counter({'movie': 3039, 'not': 2214, 'have': 2155, 'do': 1590, 'film': 1344, 'good': 1316, 'hathaway': 1174, 'intern': 1047, 'one': 880, 'great': 785, 'character': 782, 'make': 772, 'robert': 744, 'that': 737, 'very': 712, 'ben': 707, 'anne': 689, 'so': 686, 'see': 682, 'just': 680, 'watch': 655, 'old': 648, 'jule': 619, 'work': 615, 'well': 605, 'story': 604, 'niro': 599, 'really': 586, 'life': 586, 'feel': 585, 'get': 575, 'can': 569, 'would': 537, 'two': 532, 'more': 532, 'time': 526, 'there': 523, 'love': 489, 'person': 472, 'end': 468, 'go': 468, 'comedy': 465, 'will': 434, 'much': 399, 'up': 397, 'company': 396, 'too': 386, 'funny': 367, 'think': 366, 'give': 359, 'also': 353, 'play': 344, 'meyer': 336, 'woman': 335, 'way': 333, 'year': 333, 'say': 329, 'role': 319, 'want': 319, 'young': 317, 'find': 315, 'even': 314, 'which': 314, 'out': 313, 'other': 312, 'take': 304, 'could': 303, 'nice': 300, 'man': 291, 'actor': 287, 'thing': 287, 'nancy': 285, 'enjoy': 280, 'little': 276, 'something': 275, 'chemistry': 274, 'act': 258, 'come': 258, 'need': 257, 'scene': 253, 'cast': 252, 'know': 249, 'performance': 248, 'plot': 248, 'start': 243, 'still': 238, 'age': 234, 'never': 232, 'best': 232, 'new': 230, 'all': 226, 'senior': 226, 'busines': 226, 'most': 223, 'show': 222, 'only': 222, 'husband': 212, 'look': 210, 'fun': 209, 'first': 206, 'as': 206, 'like': 201, 'lot': 200, 'many': 199, 'charm': 198, 'day': 196, 'sweet': 194, 'become': 193, 'heart': 192, 'seem': 191, 'moment': 191, 'generation': 190, 'bad': 188, 'try': 187, 'experience': 185, 'laugh': 184, 'perfect': 184, 'family': 181, 'seventy': 181, 'enjoyable': 177, 'such': 177, 'then': 174, 'should': 174, 'star': 172, 'expect': 170, 'job': 169, 'part': 168, 'bit': 166, 'write': 165, 'drama': 165, 'five': 160, 'cute': 160, 'keep': 160, 'help': 159, 'again': 159, 'relationship': 158, 'warm': 156, 'kind': 156, 'here': 156, 'lead': 155, 'enough': 154, 'always': 152, 'right': 152, 'long': 152, 'back': 152, 'few': 152, 'nothing': 149, 'world': 146, 'real': 146, 'home': 145, 'ceo': 143, 'bring': 143, 'overall': 141, 'point': 141, 'fashion': 141, 'together': 139, 'run': 136, 'retire': 136, 'touch': 133, 'hour': 132, 'script': 130, 'predictable': 127, 'quite': 126, 'everyone': 126, 'problem': 123, 'big': 122, 'ten': 121, 'now': 121, 'line': 121, 'light': 120, 'three': 119, 'de': 119, 'recommend': 118, 'use': 118, 'hard': 118, 'everything': 117, 'review': 116, 'however': 115, 'same': 114, 'thousand': 114, 'actually': 113, 'helpful': 113, 'pretty': 112, 'happy': 112, 'different': 111, 'leave': 111, 'entertain': 111, 'widower': 110, 'audience': 109, 'own': 108, 'russo': 107, 'guy': 106, 'office': 106, 'tell': 105, 'ever': 105, 'happen': 103, 'beautiful': 102, 'modern': 101, 'support': 101, 'learn': 100, 'stay': 100, 'successful': 99, 'sure': 99, 'turn': 99, 'smile': 98, 'anything': 98, 'wonderful': 97, 'must': 96, 'may': 96, 'director': 96, 'whole': 94, 'flick': 94, 'place': 94, 'face': 93, 'screen': 93, 'change': 93, 'down': 93, 'half': 92, 'definitely': 92, 'off': 92, 'begin': 92, 'rene': 92, 'felt': 91, 'wife': 90, 'main': 89, 'friend': 89, 'minute': 89, 'live': 89, 'idea': 88, 'twenty': 88, 'heartwarming': 87, 'message': 87, 'simple': 87, 'someone': 87, 'internship': 85, 'might': 84, 'daughter': 84, 'excellent': 84, 'strong': 83, 'put': 83, 'online': 83, 'grow': 82, 'whittaker': 82, 'especially': 82, 'far': 81, 'once': 81, 'almost': 80, 'mean': 80, 'humor': 80, 'yet': 80, 'pleasant': 79, 'clich': 79, 'wear': 79, 'rather': 78, 'value': 77, 'ostin': 77, 'type': 76, 'internet': 76, 'personal': 76, 'easy': 76, 'probably': 76, 'move': 75, 'let': 75, 'career': 75, 'maybe': 75, 'mother': 75, 'interest': 74, 'friendship': 74, 'hundred': 74, 'fit': 73, 'situation': 73, 'fifteen': 73, 'true': 72, 'believe': 72, 'last': 71, 'zero': 70, 'fan': 70, 'absolutely': 70, 'female': 69, 'emotional': 69, 'today': 69, 'date': 69, 'positive': 68, 'premise': 68, 'four': 68, 'anyone': 67, 'balance': 67, ...

# %%
df_word_freq = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency'])
df_word_freq.sort_values(by='Frequency', ascending=False, inplace=True)
df_word_freq
# Out:
#               Word  Frequency
# 11           movie       3039
# 0              not       2214
# 19            have       2155
# 67              do       1590
# 81            film       1344
# ...            ...        ...
# 5023        benign          1
# 5019          plug          1
# 5016     adamantly          1
# 5015           tag          1
# 8928  screenwriter          1
#
# [8929 rows x 2 columns]

# %%
#! pip install openpyxl
df_word_freq.to_excel('word_freq_america.xlsx')

# %% [markdown]
# # word2Vec

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences=modified_sentences_2, vector_size=100, window=22, min_count=2, workers=1)

# %%
model.save("word2vec_america.model")

# %%
word_vectors = model.wv

# %%
similar_words = word_vectors.most_similar('intern')
print(similar_words)
# Out:
# [('retirement', 0.9959020018577576), ('apply', 0.9955831170082092), ('internship', 0.9943088293075562), ('whitaker', 0.9942000508308411), ('site', 0.9928991198539734), ('fashion', 0.9924650192260742), ('retire', 0.9923211336135864), ('commerce', 0.9921563863754272), ('online', 0.9916172623634338), ('program', 0.9908620715141296)]

# %%
similar_words_100 = word_vectors.most_similar('ben', topn=100)
print("Top 100 similar words:", similar_words_100)
# Out:
# Top 100 similar words: [('online', 0.997878909111023), ('fashion', 0.9976353049278259), ('retire', 0.9972067475318909), ('retired', 0.9967267513275146), ('jule', 0.996306836605072), ('company', 0.9961379766464233), ('senior', 0.9955204725265503), ('run', 0.9954521656036377), ('apply', 0.9946756362915039), ('program', 0.9943433403968811), ('young', 0.993930995464325), ('whitaker', 0.9919191598892212), ('commerce', 0.9910964965820312), ('retailer', 0.988544225692749), ('retirement', 0.9880651831626892), ('internship', 0.9868780970573425), ('old', 0.9867656826972961), ('year', 0.9867207407951355), ('ceo', 0.9852834939956665), ('intern', 0.9852529764175415), ('website', 0.9848876595497131), ('join', 0.98395836353302), ('busy', 0.9835464358329773), ('site', 0.9830223917961121), ('work', 0.9822518825531006), ('whittaker', 0.9809632897377014), ('president', 0.9809448719024658), ('seize', 0.9806617498397827), ('position', 0.9794400930404663), ('citizen', 0.9787900447845459), ('ostin', 0.9787729978561401), ('programme', 0.9787405133247375), ('internet', 0.97804194688797), ('bored', 0.9767600893974304), ('widow', 0.9762355089187622), ('hire', 0.9758817553520203), ('widower', 0.9742750525474548), ('assign', 0.9738451838493347), ('shopping', 0.9719946384429932), ('founder', 0.9704869985580444), ('owner', 0.9694395065307617), ('become', 0.969010055065155), ('new', 0.9688500165939331), ('seventy', 0.9678952693939209), ('busines', 0.9677367210388184), ('man', 0.9674931168556213), ('directly', 0.9662284255027771), ('clothing', 0.9653657078742981), ('web', 0.9651051759719849), ('ecommerce', 0.9649521112442017), ('opportunity', 0.9632392525672913), ('found', 0.9628312587738037), ('void', 0.9620234966278076), ('confidant', 0.9610028862953186), ('woman', 0.960759162902832), ('successful', 0.9584252834320068), ('phonebook', 0.9583727717399597), ('ad', 0.9583290815353394), ('retiree', 0.9573045969009399), ('enter', 0.9566535353660583), ('glimpse', 0.9557239413261414), ('play', 0.9556521773338318), ('life', 0.9547939896583557), ('upstart', 0.9534171223640442), ('entrepreneur', 0.9533332586288452), ('game', 0.9525269865989685), ('dot', 0.952202320098877), ('telephone', 0.9520124197006226), ('executive', 0.9515823125839233), ('businessman', 0.9508313536643982), ('beck', 0.9502393007278442), ('sign', 0.9492401480674744), ('voice', 0.9491996765136719), ('struggle', 0.9465476870536804), ('pensioner', 0.9447603821754456), ('salary', 0.9447302222251892), ('kindly', 0.9441532492637634), ('sensation', 0.9433439373970032), ('grow', 0.9403563141822815), ('skeptical', 0.9403387904167175), ('flyer', 0.9402337670326233), ('magnet', 0.9402329921722412), ('eachother', 0.9400635957717896), ('startup', 0.9396483302116394), ('lease', 0.9392616152763367), ('married', 0.9389551281929016), ('management', 0.9388435482978821), ('school', 0.9386271834373474), ('job', 0.9382687211036682), ('help', 0.9369182586669922), ('start', 0.936760663986206), ('befriend', 0.9364222884178162), ('home', 0.9361796379089355), ('defy', 0.9361558556556702), ('trendy', 0.936052143573761), ('bore', 0.9358644485473633), ('lonely', 0.9358623623847961), ('bos', 0.9351110458374023), ('death', 0.9337729811668396), ('decide', 0.9334301948547363)]

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

# %%
df_word_freq = pd.read_excel('C:/Users/seowoo kim/Desktop/노나없/word_freq_america.xlsx')

# %%
df_word_freq_new = df_word_freq[df_word_freq['Frequency']>1]

# %%
from transformers import pipeline

# %%
model = pipeline('sentiment-analysis', model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# WARNING:tensorflow:From c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
sentiment_label = []
confidence_score = []

# Analyze sentiment and store results
for word in df_word_freq_new['Word']:
    result = model(word)
    sentiment_label.append(result[0]['label'])
    confidence_score.append(result[0]['score'])

# Add the sentiment results to the original DataFrame
df_word_freq_new['Sentiment Label'] = sentiment_label
df_word_freq_new['Confidence Score'] = confidence_score

# Display the updated DataFrame
print(df_word_freq_new)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 6
#       4 # Analyze sentiment and store results
#       5 for word in df_word_freq_new['Word']:
# ----> 6     result = model(word)
#       7     sentiment_label.append(result[0]['label'])
#       8     confidence_score.append(result[0]['score'])
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\text_classification.py:156, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     122 """
#     123 Classify the text(s) given as inputs.
#     124
#    (...)
#     153     If `top_k` is used, one such dictionary is returned per label.
#     154 """
#     155 inputs = (inputs,)
# --> 156 result = super().__call__(*inputs, **kwargs)
#     157 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158 _legacy = "top_k" not in kwargs
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\base.py:1257, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1249     return next(
#    1250         iter(
#    1251             self.get_iterator(
#    (...)
#    1254         )
#    1255     )
#    1256 else:
# -> 1257     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\base.py:1264, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1262 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1263     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1264     model_outputs = self.forward(model_inputs, **forward_params)
#    1265     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1266     return outputs
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\base.py:1164, in Pipeline.forward(self, model_inputs, **forward_params)
#    1162     with inference_context():
#    1163         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1164         model_outputs = self._forward(model_inputs, **forward_params)
#    1165         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1166 else:
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pipelines\text_classification.py:187, in TextClassificationPipeline._forward(self, model_inputs)
#     185 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186     model_inputs["use_cache"] = False
# --> 187 return self.model(**model_inputs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:1195, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1187 r"""
#    1188 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1189     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1190     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1191     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1192 """
#    1193 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1195 outputs = self.roberta(
#    1196     input_ids,
#    1197     attention_mask=attention_mask,
#    1198     token_type_ids=token_type_ids,
#    1199     position_ids=position_ids,
#    1200     head_mask=head_mask,
#    1201     inputs_embeds=inputs_embeds,
#    1202     output_attentions=output_attentions,
#    1203     output_hidden_states=output_hidden_states,
#    1204     return_dict=return_dict,
#    1205 )
#    1206 sequence_output = outputs[0]
#    1207 logits = self.classifier(sequence_output)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:832, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     823 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     825 embedding_output = self.embeddings(
#     826     input_ids=input_ids,
#     827     position_ids=position_ids,
#    (...)
#     830     past_key_values_length=past_key_values_length,
#     831 )
# --> 832 encoder_outputs = self.encoder(
#     833     embedding_output,
#     834     attention_mask=extended_attention_mask,
#     835     head_mask=head_mask,
#     836     encoder_hidden_states=encoder_hidden_states,
#     837     encoder_attention_mask=encoder_extended_attention_mask,
#     838     past_key_values=past_key_values,
#     839     use_cache=use_cache,
#     840     output_attentions=output_attentions,
#     841     output_hidden_states=output_hidden_states,
#     842     return_dict=return_dict,
#     843 )
#     844 sequence_output = encoder_outputs[0]
#     845 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:521, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     510     layer_outputs = self._gradient_checkpointing_func(
#     511         layer_module.__call__,
#     512         hidden_states,
#    (...)
#     518         output_attentions,
#     519     )
#     520 else:
# --> 521     layer_outputs = layer_module(
#     522         hidden_states,
#     523         attention_mask,
#     524         layer_head_mask,
#     525         encoder_hidden_states,
#     526         encoder_attention_mask,
#     527         past_key_value,
#     528         output_attentions,
#     529     )
#     531 hidden_states = layer_outputs[0]
#     532 if use_cache:
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:410, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     398 def forward(
#     399     self,
#     400     hidden_states: torch.Tensor,
#    (...)
#     407 ) -> Tuple[torch.Tensor]:
#     408     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     409     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 410     self_attention_outputs = self.attention(
#     411         hidden_states,
#     412         attention_mask,
#     413         head_mask,
#     414         output_attentions=output_attentions,
#     415         past_key_value=self_attn_past_key_value,
#     416     )
#     417     attention_output = self_attention_outputs[0]
#     419     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:337, in RobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     327 def forward(
#     328     self,
#     329     hidden_states: torch.Tensor,
#    (...)
#     335     output_attentions: Optional[bool] = False,
#     336 ) -> Tuple[torch.Tensor]:
# --> 337     self_outputs = self.self(
#     338         hidden_states,
#     339         attention_mask,
#     340         head_mask,
#     341         encoder_hidden_states,
#     342         encoder_attention_mask,
#     343         past_key_value,
#     344         output_attentions,
#     345     )
#     346     attention_output = self.output(self_outputs[0], hidden_states)
#     347     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:210, in RobertaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     208 else:
#     209     key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 210     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     212 query_layer = self.transpose_for_scores(mixed_query_layer)
#     214 use_cache = past_key_value is not None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
df_word_freq_new.to_excel('sentiment_word_usa.xlsx')

# %%
NEU = df_word_freq_new[df_word_freq_new['Sentiment Label']=='NEU']
len(NEU)
POS = df_word_freq_new[df_word_freq_new['Sentiment Label']=='POS']
len(POS)
NEG = df_word_freq_new[df_word_freq_new['Sentiment Label']=='NEG']
len(NEG)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sentiment Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 NEU = df_word_freq_new[df_word_freq_new['Sentiment Label']=='NEU']
#       2 len(NEU)
#       3 POS = df_word_freq_new[df_word_freq_new['Sentiment Label']=='POS']
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\seowoo kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Sentiment Label'

# %%
from gensim.models import Word2Vec
model_path = "C:/Users/seowoo kim/Desktop/노나없/word2vec_usa.model"
model = Word2Vec.load(model_path)

# %%
old_words = ['ben']
young_words = ['jule']

# %%
temp_dict = pd.read_excel('C:/Users/seowoo kim/Desktop/노나없/sentiment_word_usa.xlsx')

# %%
temp_words = temp_dict['Word'].tolist()
print(temp_words)
# Out:
# ['movie', 'not', 'have', 'do', 'film', 'good', 'hathaway', 'intern', 'one', 'great', 'character', 'make', 'robert', 'that', 'very', 'ben', 'anne', 'so', 'see', 'just', 'watch', 'old', 'jule', 'work', 'well', 'story', 'niro', 'life', 'really', 'feel', 'get', 'can', 'would', 'more', 'two', 'time', 'there', 'love', 'person', 'go', 'end', 'comedy', 'will', 'much', 'up', 'company', 'too', 'funny', 'think', 'give', 'also', 'play', 'meyer', 'woman', 'year', 'way', 'say', 'want', 'role', 'young', 'find', 'even', 'which', 'out', 'other', 'take', 'could', 'nice', 'man', 'actor', 'thing', 'nancy', 'enjoy', 'little', 'something', 'chemistry', 'come', 'act', 'need', 'scene', 'cast', 'know', 'performance', 'plot', 'start', 'still', 'age', 'best', 'never', 'new', 'senior', 'all', 'busines', 'most', 'only', 'show', 'husband', 'look', 'fun', 'first', 'as', 'like', 'lot', 'many', 'charm', 'day', 'sweet', 'become', 'heart', 'moment', 'seem', 'generation', 'bad', 'try', 'experience', 'perfect', 'laugh', 'family', 'seventy', 'enjoyable', 'such', 'should', 'then', 'star', 'expect', 'job', 'part', 'bit', 'write', 'drama', 'cute', 'five', 'keep', 'help', 'again', 'relationship', 'here', 'warm', 'kind', 'lead', 'enough', 'right', 'always', 'long', 'few', 'back', 'nothing', 'real', 'world', 'home', 'ceo', 'bring', 'point', 'overall', 'fashion', 'together', 'run', 'retire', 'touch', 'hour', 'script', 'predictable', 'quite', 'everyone', 'problem', 'big', 'now', 'line', 'ten', 'light', 'three', 'de', 'hard', 'recommend', 'use', 'everything', 'review', 'however', 'same', 'thousand', 'actually', 'helpful', 'happy', 'pretty', 'leave', 'entertain', 'different', 'widower', 'audience', 'own', 'russo', 'office', 'guy', 'ever', 'tell', 'happen', 'beautiful', 'support', 'modern', 'learn', 'stay', 'sure', 'successful', 'turn', 'smile', 'anything', 'wonderful', 'must', 'may', 'director', 'whole', 'place', 'flick', 'change', 'down', 'screen', 'face', 'rene', 'half', 'off', 'begin', 'definitely', 'felt', 'wife', 'friend', 'main', 'minute', 'live', 'twenty', 'idea', 'simple', 'someone', 'heartwarming', 'message', 'internship', 'might', 'excellent', 'daughter', 'strong', 'online', 'put', 'especially', 'whittaker', 'grow', 'far', 'once', 'almost', 'yet', 'mean', 'humor', 'clich', 'pleasant', 'wear', 'rather', 'ostin', 'value', 'personal', 'type', 'easy', 'internet', 'probably', 'mother', 'career', 'move', 'let', 'maybe', 'hundred', 'friendship', 'interest', 'situation', 'fifteen', 'fit', 'true', 'believe', 'last', 'fan', 'zero', 'absolutely', 'date', 'female', 'emotional', 'today', 'four', 'positive', 'premise', 'balance', 'employee', 'anyone', 'high', 'wisdom', 'set', 'retirement', 'school', 'lack', 'writer', 'add', 'saw', 'fact', 'bos', 'bore', 'worth', 'away', 'fantastic', 'interesting', 'talk', 'instead', 'offer', 'meet', 'issue', 'lovely', 'follow', 'fill', 'decide', 'mind', 'second', 'program', 'word', 'house', 'least', 'deliver', 'surprise', 'struggle', 'hollywood', 'care', 'devil', 'acting', 'likable', 'able', 'create', 'night', 'sometimes', 'call', 'storyline', 'conflict', 'awesome', 'fine', 'believable', 'entertaining', 'course', 'break', 'nine', 'joke', 'cry', 'amaze', 'founder', 'matt', 'pace', 'father', 'feeling', 'lesson', 'brilliant', 'matter', 'amazing', 'hope', 'full', 'prada', 'top', 'music', 'less', 'heartfelt', 'holm', 'seven', 'truly', 'gentleman', 'cheat', 'mom', 'manage', 'important', 'sort', 'develop', 'romantic', 'decent', 'miss', 'critic', 'challenge', 'remind', 'reason', 'lose', 'hilarious', 'deal', 'twist', 'thought', 'thirty', 'wrong', 'usual', 'couple', 'ander', 'parent', 'completely', 'hit', 'que', 'hire', 'simply', 'romance', 'ann', 'worker', 'wise', 'eye', 'rating', 'theater', 'com', 'fall', 'trailer', 'direction', 'teach', 'sit', 'entire', 'head', 'totally', 'sad', 'understand', 'tech', 'hand', 'else', 'succes', 'refresh', 'fast', 'mentor', 'hearted', 'present', 'side', 'chick', 'emotion', 'save', 'spend', 'prove', 'drive', 'pay', 'relat ...

# %%
words = ["Team-minded", "confident", "dedicated", "collaborative"]

# %%
pos_words = [
    "gentlemanly", "strong", "helpful", "handsome", "likable", "hope", "smart", "adorable", "cool", "intelligent", 
    "successful", "healthy", "powerful", "talented", "charming", "courage", "encouragement", "respect", "clever", 
    "optimistic", "attractive", "courteous", "wise", "wisdom", "passion", "passionate", "compassion", "lovely", "beloved",
    "proud", "commendable", "productive", "sweetness", "enthusiasm", "genius", "goodhearted", "flawless","dependable","brilliance"
]
neg_words = [
    "arrogant", "stupid", "bully", "angry", "fear", "rude", "awful",
    "stubborn", "negative", "ridiculous", "pathetic", "tired", "shame", "useless", "foul", "bitch","embarrass",
    "pity", "dumb", "creepy", "ugly", "irritate", "ignorance","incompetent", "neurotic","disrespect","insult",
    "fool", "manipulative", "subvert","bully", "immature", "frustrating", "loser"
]

# %%
# cosine similarity 
def cos_sim(i, j):
    return dot(i, j.T)/(norm(i)*norm(j))

def s(w, A, B):
    c_a = np.array([cos_sim(w, a) for a in A])
    c_b = np.array([cos_sim(w, b) for b in B])
    mean_A = np.mean(c_a)
    mean_B = np.mean(c_b)
    return mean_A - mean_B

# Target A - Target B
def s_group(X, A, B):
    return np.array([s(x, A, B) for x in X])

#WEAT
def weat_score(X, Y, A, B):
    s_X = s_group(X, A, B)
    s_Y = s_group(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    return (mean_X - mean_Y) / std_dev

# %%
X = np.array([model.wv.get_vector(word) for word in old_words if word in model.wv])
Y = np.array([model.wv.get_vector(word) for word in young_words if word in model.wv])
A = np.array([model.wv.get_vector(word) for word in pos_words if word in model.wv])
B = np.array([model.wv.get_vector(word) for word in neg_words if word in model.wv])

# %%
# WEAT score result
weat_result = round(weat_score(X, Y, A, B), 3)
print("WEAT Score:", weat_result)
# Out:
# WEAT Score: -0.27

# %%
def weat_score(X, Y, A, B):
    s_X = s_group(X, A, B)
    s_Y = s_group(Y, A, B)

    mean_X = np.mean(s_X)
    mean_Y = np.mean(s_Y)
    
    std_dev = np.std(np.concatenate([s_X, s_Y], axis=0))
    
    # 표준 편차 출력
    print("Standard Deviation:", std_dev)
    
    if std_dev == 0:
        return float('nan')
    
    return (mean_X - mean_Y) / std_dev

X = np.array([model.wv.get_vector(word) for word in old_words if word in model.wv])
Y = np.array([model.wv.get_vector(word) for word in young_words if word in model.wv])
A = np.array([model.wv.get_vector(word) for word in pos_words if word in model.wv])
B = np.array([model.wv.get_vector(word) for word in neg_words if word in model.wv])

# WEAT score result
weat_result = round(weat_score(X, Y, A, B), 3)
print("WEAT Score:", weat_result)
# Out:
# Standard Deviation: 0.0069878725
# WEAT Score: -0.27

# %%
import itertools
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt

old_words = ['ben', 'senior', 'old', 'older', 'elderly', 'elder']
young_words = ['jule', 'young', 'younger', 'youngster']

co_occurrence = defaultdict(int)

co_occurrence
window_size = 20

for sentence in modified_sentences_2:
    effective_window_size = min(len(sentence), window_size)
    for i in range(len(sentence)):
        window = sentence[i:i+effective_window_size]
        for pair in itertools.combinations(window, 2):
            co_occurrence[pair] += 1
            
G = nx.MultiGraph()

for (word1, word2), weight in co_occurrence.items():
    G.add_edge(word1, word2, weight=weight)

relevant_words = set(old_words + young_words)
filtered_edges = [(u, v, d) for u, v, d in G.edges(data=True) if u in relevant_words or v in relevant_words]

H = nx.Graph()
H.add_edges_from(filtered_edges)

H_old_filtered = nx.Graph()

for word in old_words:
    # 각 단어에 대해 가중치가 높은 순서로 엣지를 정렬하고, 최대 20개의 엣지만 선택
    edges_for_word = [(u, v, d) for u, v, d in G.edges(data=True) if (u == word or v == word)]
    sorted_edges = sorted(edges_for_word, key=lambda x: x[2]['weight'], reverse=True)[:20]
    H_old_filtered.add_edges_from(sorted_edges)

# old_words 관련 서브그래프 시각화
# old_words 관련 서브그래프 시각화
plt.figure(figsize=(20,20))
pos_old_filtered = nx.spring_layout(H_old_filtered, seed=42, k=1)  # k 값을 조정하여 노드 간 거리 조절
nx.draw_networkx_nodes(H_old_filtered, pos_old_filtered, node_size=700, node_color='lightblue')
nx.draw_networkx_edges(H_old_filtered, pos_old_filtered, width=1.0, alpha=0.5)
nx.draw_networkx_labels(H_old_filtered, pos_old_filtered, font_size=10, font_family="sans-serif")  # 폰트 크기 조정
plt.title("Co-occurrence Network for Old Words (Top 20 Edges per Word)")
plt.axis("off")
plt.show()

# %%
H_young_filtered = nx.Graph()

for word in young_words:
    # 각 단어에 대해 가중치가 높은 순서로 엣지를 정렬하고, 최대 20개의 엣지만 선택
    edges_for_word = [(u, v, d) for u, v, d in G.edges(data=True) if (u == word or v == word)]
    sorted_edges = sorted(edges_for_word, key=lambda x: x[2]['weight'], reverse=True)[:20]
    H_young_filtered.add_edges_from(sorted_edges)
    
plt.figure(figsize=(30,30))
pos_young_filtered = nx.spring_layout(H_young_filtered, seed=42, k=2)  # k 값을 조정하여 노드 간 거리 조절
nx.draw_networkx_nodes(H_young_filtered, pos_young_filtered, node_size=700, node_color='lightblue')
nx.draw_networkx_edges(H_young_filtered, pos_young_filtered, width=1.0, alpha=0.5)
nx.draw_networkx_labels(H_young_filtered, pos_young_filtered, font_size=10, font_family="sans-serif")  # 폰트 크기 조정
plt.title("Co-occurrence Network for Young Words (Top 20 Edges per Word)")
plt.axis("off")
plt.show()
